# %% [markdown]
# ### Display the versions of the libraries used for reference purposes.

# %%
import sys
import numpy as np
import tensorflow as tf
import sklearn
import torch
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import notebook
import os

# Print Python version
print(f'Python version: {sys.version}')

# Print Jupyter Notebook version
print(f'Jupyter Notebook version: {notebook.__version__}')

# Print library versions
print(f'NumPy version: {np.__version__}')
print(f'TensorFlow version: {tf.__version__}')
print(f'Torch version: {torch.__version__}')
print(f'Scikit-learn version: {sklearn.__version__}')

os.makedirs("Models and Data splits", exist_ok=True)
# Out:
# Python version: 3.12.9 | packaged by Anaconda, Inc. | (main, Feb  6 2025, 18:49:16) [MSC v.1929 64 bit (AMD64)]
# Jupyter Notebook version: 7.3.2
# NumPy version: 2.0.1
# TensorFlow version: 2.19.0
# Torch version: 2.6.0+cu126
# Scikit-learn version: 1.6.1

# %% [markdown]
# ### Untargeted Attack on test set; k=100

# %%
import os
import warnings
import numpy as np
import torch
import joblib
import pandas as pd
from PIL import Image
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import torch.nn.functional as F
import time


# Set seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# ─────────────── PATHS ────────────────────────────────────────────────────
LENET_MODEL_PATH = os.path.normpath("Models and Data splits/lenet.pt")  # TorchScript model
DATA_PKL = os.path.normpath("Models and Data splits/data_[SCALED] Train_Test_Splits.pkl")
RF_ALL_CLASSES_PATH = os.path.normpath("Models and Data splits/random_forest.pkl")
OUT_DIR = "adversarial_8bit_K100_test_images"
os.makedirs(OUT_DIR, exist_ok=True)

if not os.path.exists(RF_ALL_CLASSES_PATH):
    raise FileNotFoundError(f"Random Forest model not found at {RF_ALL_CLASSES_PATH}")

# ─────────── HYPER-PARAMETERS ─────────────────────────────────────────────
EPSILON_STEP = 0.01
ITERATIONS = 100
TOTAL_EPSILON = 0.5
TOP_K_FEATURES = 100
SAMPLES_PER_DIGIT = 100
MAX_L2 = 10000

def plot_adversarial_example(original_img, adv_img, true_label, adv_label, l2_mag, sample_idx, queries, title_suffix=""):
    if original_img.size == 784:
        original_img = original_img.reshape(28, 28)
    if adv_img.size == 784:
        adv_img = adv_img.reshape(28, 28)
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(original_img, cmap='gray')
    axes[0].set_title(f"Original\nTrue: {true_label}")
    axes[0].axis('off')
    axes[1].imshow(adv_img, cmap='gray')
    axes[1].set_title(f"Adversarial\nPred: {adv_label}")
    axes[1].axis('off')
    fig.suptitle(f"Sample {sample_idx} | L2: {l2_mag:.2f} | Queries: {queries} {title_suffix}")
    plt.show()
    plt.close(fig)  # <-- added here


# ─────────── Load Data ─────────────────────────────────────────────────────
try:
    data = joblib.load(DATA_PKL)
    _, X_samples , _, y_samples = data
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PKL}. Please check the path.")
    exit()

if X_samples.max() > 1.0:
    X_samples = X_samples.astype(np.float32) / 255.0
    warnings.warn("Data appeared in [0,255]; normalized to [0,1].")

# ─────────── Load TorchScripted LeNet ──────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
try:
    model = torch.jit.load(LENET_MODEL_PATH, map_location=device)
    model.eval()
    print(f"LeNet TorchScript model loaded from: {LENET_MODEL_PATH}")
except Exception as e:
    print(f"Error loading TorchScript LeNet model: {e}")
    exit()

def to_model(x01_batch):
    if x01_batch.ndim == 2 and x01_batch.shape == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)
    elif x01_batch.ndim == 3 and x01_batch.shape[1:] == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(1)
    elif x01_batch.ndim == 4 and x01_batch.shape[1] == 1:
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device)
    elif x01_batch.ndim == 1 and x01_batch.size == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(1, 1, 28, 28), dtype=torch.float32, device=device)
    elif x01_batch.ndim == 2 and x01_batch.shape[1] == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(x01_batch.shape[0], 1, 28, 28), dtype=torch.float32, device=device)
    else:
        raise ValueError(f"Unsupported input shape for to_model: {x01_batch.shape}")
    return tensor_batch


def model_query(x_tensor_batch):
    with torch.no_grad():
        return model(x_tensor_batch)

# ─────────── Load Random Forest Model ──────────────────────────────────────
rf_all_classes = None
top_feature_indices = None
print("Loading Random Forest Classifier for all classes...")
try:
    rf_all_classes = joblib.load(RF_ALL_CLASSES_PATH)
    feature_importances = rf_all_classes.feature_importances_
    #top_feature_indices = np.argsort(feature_importances)[:TOP_K_FEATURES]
    
    top_feature_indices = np.argsort(-feature_importances)[:TOP_K_FEATURES]
    print(f"Random Forest loaded. Using top {TOP_K_FEATURES} features.")
except Exception as e:
    print(f"Error loading Random Forest: {e}")
    top_feature_indices = np.arange(28 * 28)

# ─────────── I-FGSM Attack ─────────────────────────────────────────────────
def ifgsm_attack(original_image_np, true_label, model_target, epsilon_step, iterations,
                 total_epsilon_budget, features_to_perturb, query_count_tracker):
    if original_image_np.ndim == 1 and original_image_np.size == 784:
        original_image_np = original_image_np.reshape(28, 28)

    perturbed_image_np = original_image_np.copy()
    final_pred_label = true_label

    for i in range(iterations):
        image_tensor = to_model(perturbed_image_np)
        image_tensor.requires_grad = True
        output = model_target(image_tensor)
        query_count_tracker[0] += 1
        loss = F.cross_entropy(output, torch.tensor([true_label], device=device))
        model_target.zero_grad()
        loss.backward()
        data_grad_sign = torch.sign(image_tensor.grad.data).cpu().numpy()

        gradient_mask = np.zeros_like(data_grad_sign, dtype=np.float32)
        h, w = perturbed_image_np.shape
        rows, cols = np.unravel_index(features_to_perturb, (h, w))
        gradient_mask[0, 0, rows, cols] = data_grad_sign[0, 0, rows, cols]
        gradient_mask_for_update = gradient_mask.reshape(perturbed_image_np.shape)

        perturbed_image_np += epsilon_step * gradient_mask_for_update
        perturbation = perturbed_image_np - original_image_np
        perturbation = np.clip(perturbation, -total_epsilon_budget, total_epsilon_budget)
        perturbed_image_np = original_image_np + perturbation
        perturbed_image_np = np.clip(perturbed_image_np, 0, 1)

        # Discretize and check prediction on discretized image
        adv_uint8_temp = np.round(perturbed_image_np * 255).astype(np.uint8)
        adv_float_temp = adv_uint8_temp.astype(np.float32) / 255.0
        with torch.no_grad():
            output_temp = model_target(to_model(adv_float_temp))
            pred_temp = output_temp.argmax(dim=1).item()
            query_count_tracker[0] += 1

        if pred_temp != true_label:
            final_pred_label = pred_temp
            break

    # Final adversarial image (discretized)
    adv_uint8 = np.round(perturbed_image_np * 255).astype(np.uint8)
    adv_float = adv_uint8.astype(np.float32) / 255.0
    with torch.no_grad():
        output_final = model_target(to_model(adv_float))
        final_pred_label = output_final.argmax(dim=1).item()

    l2_norm = np.linalg.norm(adv_uint8.astype(np.float32) - (original_image_np * 255).astype(np.float32))
    success = (final_pred_label != true_label) and (l2_norm <= MAX_L2)

    return adv_uint8, final_pred_label, l2_norm, success


# ─────────── Attack Execution ──────────────────────────────────────────────
print(f"\n===== Starting Adversarial Attack =====")
total_trials, succ_total, misclassified = 0, 0, 0
records = []


start_time = time.time()


for digit in range(10):
    idxs = np.where(y_samples == digit)[0][:SAMPLES_PER_DIGIT]
    for rank, idx in enumerate(idxs, 1):
        x0 = X_samples[idx].copy()
        y0 = int(y_samples[idx])
        query_count_tracker = [0]
        pred0 = model_query(to_model(x0)).argmax(dim=1).item()
        query_count_tracker[0] += 1

        if pred0 != y0:
            misclassified += 1
            records.append({
                'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
                'adv_label': None, 'success': False, 'queries': query_count_tracker[0],
                'l2_mag': np.nan, 'note': 'Already misclassified'
            })
            continue

        total_trials += 1
        print(f"Attacking sample {rank}/{SAMPLES_PER_DIGIT} (True: {y0}, Index: {idx})...")
        adv_img_uint8, adv_label, l2_mag, success = ifgsm_attack(
            x0, y0, model, EPSILON_STEP, ITERATIONS, TOTAL_EPSILON,
            top_feature_indices, query_count_tracker
        )

        if success:
            succ_total += 1
            fname = f"true{y0}_adv{adv_label}_mag{l2_mag:.1f}_sample{idx}.png"
            Image.fromarray(adv_img_uint8, mode="L").save(os.path.join(OUT_DIR, fname))

        records.append({
            'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
            'adv_label': adv_label, 'success': success, 'queries': query_count_tracker[0],
            'l2_mag': l2_mag if success else np.nan, 'note': 'I-FGSM' + (' successful' if success else ' failed')
        })

        print(f"  {'Success' if success else 'Failed'}! Adv label: {adv_label}, L2: {l2_mag:.2f}, Queries: {query_count_tracker[0]}")


end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to generate adversarial samples: {elapsed_time:.4f} seconds")


# ─────────── Save Results ──────────────────────────────────────────────────
df = pd.DataFrame(records)
csv_path = os.path.join(OUT_DIR, "per_sample_stats.csv")
df.to_csv(csv_path, index=False)
print(f"\nStats saved to: {csv_path}")

# ─────────── Summary ───────────────────────────────────────────────────────
print(f"\n===== Attack Summary =====")
print(f"Total trials: {total_trials}")
print(f"Misclassified before attack: {misclassified}")
if total_trials > 0:
    success_rate = succ_total / total_trials * 100
    print(f"Success rate: {succ_total}/{total_trials} ({success_rate:.1f}%)")
    if succ_total > 0:
        print(f"Mean L2 (successful): {df[df['success']]['l2_mag'].mean():.2f}")
        print(f"Mean queries (successful): {df[df['success']]['queries'].mean():.2f}")

# ─────────── Display Examples ──────────────────────────────────────────────
success_df = df[df['success']]
if not success_df.empty:
    print("\nShowing successful adversarial examples...")
    show_ids = success_df.sample(min(3, len(success_df))).index.tolist()
    for record_idx in show_ids:
        r = df.loc[record_idx]
        fname_prefix = f"true{r['true_label']}_adv{r['adv_label']}_mag{r['l2_mag']:.1f}_sample{r['sample_idx']}"
        match_files = [f for f in os.listdir(OUT_DIR) if f.startswith(fname_prefix)]
        if match_files:
            adv_img_path = os.path.join(OUT_DIR, match_files[0])
            plot_adversarial_example(X_samples[r['sample_idx']], np.array(Image.open(adv_img_path)),
                                     r['true_label'], r['adv_label'], r['l2_mag'],
                                     r['sample_idx'], r['queries'], "(I-FGSM)")
else:
    print("No successful attacks to display. Showing original samples instead.")
    for i in range(min(3, len(df))):
        r = df.iloc[i]
        plot_adversarial_example(X_samples[r['sample_idx']], X_samples[r['sample_idx']],
                                 r['true_label'], r['initial_pred'], 0.0,
                                 r['sample_idx'], r['queries'], "(Original)")
# Out:
# LeNet TorchScript model loaded from: Models and Data splits\lenet.pt
# Loading Random Forest Classifier for all classes...
# Random Forest loaded. Using top 100 features.
#
# ===== Starting Adversarial Attack =====
# Attacking sample 1/100 (True: 0, Index: 29)...
#   Failed! Adv label: 0, L2: 979.33, Queries: 201
# Attacking sample 2/100 (True: 0, Index: 40)...
#   Failed! Adv label: 0, L2: 911.63, Queries: 201
# Attacking sample 3/100 (True: 0, Index: 44)...
#   Success! Adv label: 8, L2: 737.82, Queries: 83
# Attacking sample 4/100 (True: 0, Index: 59)...
#   Success! Adv label: 8, L2: 830.94, Queries: 89
# Attacking sample 5/100 (True: 0, Index: 64)...
#   Failed! Adv label: 0, L2: 946.87, Queries: 201
# Attacking sample 6/100 (True: 0, Index: 75)...
#   Success! Adv label: 8, L2: 785.37, Queries: 93
# Attacking sample 7/100 (True: 0, Index: 80)...
#   Success! Adv label: 9, L2: 756.04, Queries: 91
# Attacking sample 8/100 (True: 0, Index: 97)...
#   Success! Adv label: 6, L2: 903.84, Queries: 173
# Attacking sample 9/100 (True: 0, Index: 115)...
#   Success! Adv label: 6, L2: 915.92, Queries: 107
# Attacking sample 10/100 (True: 0, Index: 141)...
#   Success! Adv label: 7, L2: 233.48, Queries: 25
# Attacking sample 11/100 (True: 0, Index: 146)...
#   Success! Adv label: 9, L2: 732.94, Queries: 89
# Attacking sample 12/100 (True: 0, Index: 156)...
#   Failed! Adv label: 0, L2: 728.21, Queries: 201
# Attacking sample 13/100 (True: 0, Index: 173)...
#   Success! Adv label: 3, L2: 784.59, Queries: 101
# Attacking sample 14/100 (True: 0, Index: 175)...
#   Success! Adv label: 8, L2: 487.02, Queries: 53
# Attacking sample 15/100 (True: 0, Index: 193)...
#   Failed! Adv label: 0, L2: 834.32, Queries: 201
# Attacking sample 16/100 (True: 0, Index: 200)...
#   Success! Adv label: 9, L2: 735.38, Queries: 89
# Attacking sample 17/100 (True: 0, Index: 205)...
#   Success! Adv label: 9, L2: 852.48, Queries: 115
# Attacking sample 18/100 (True: 0, Index: 210)...
#   Success! Adv label: 8, L2: 754.64, Queries: 89
# Attacking sample 19/100 (True: 0, Index: 221)...
#   Success! Adv label: 3, L2: 692.52, Queries: 83
# Attacking sample 20/100 (True: 0, Index: 229)...
#   Failed! Adv label: 0, L2: 756.05, Queries: 201
# Attacking sample 21/100 (True: 0, Index: 249)...
#   Failed! Adv label: 0, L2: 708.41, Queries: 201
# Attacking sample 22/100 (True: 0, Index: 258)...
#   Success! Adv label: 8, L2: 906.22, Queries: 117
# Attacking sample 23/100 (True: 0, Index: 275)...
#   Failed! Adv label: 0, L2: 844.43, Queries: 201
# Attacking sample 24/100 (True: 0, Index: 292)...
#   Failed! Adv label: 0, L2: 755.94, Queries: 201
# Attacking sample 25/100 (True: 0, Index: 296)...
#   Success! Adv label: 9, L2: 718.47, Queries: 81
# Attacking sample 26/100 (True: 0, Index: 301)...
#   Success! Adv label: 9, L2: 748.84, Queries: 89
# Attacking sample 27/100 (True: 0, Index: 314)...
#   Success! Adv label: 6, L2: 782.25, Queries: 85
# Attacking sample 28/100 (True: 0, Index: 325)...
#   Failed! Adv label: 0, L2: 891.26, Queries: 201
# Attacking sample 29/100 (True: 0, Index: 333)...
#   Success! Adv label: 9, L2: 823.80, Queries: 131
# Attacking sample 30/100 (True: 0, Index: 345)...
#   Success! Adv label: 6, L2: 683.44, Queries: 73
# Attacking sample 31/100 (True: 0, Index: 349)...
#   Success! Adv label: 9, L2: 682.20, Queries: 79
# Attacking sample 32/100 (True: 0, Index: 360)...
#   Failed! Adv label: 0, L2: 964.13, Queries: 201
# Attacking sample 33/100 (True: 0, Index: 365)...
#   Success! Adv label: 9, L2: 858.46, Queries: 161
# Attacking sample 34/100 (True: 0, Index: 366)...
#   Success! Adv label: 8, L2: 868.16, Queries: 97
# Attacking sample 35/100 (True: 0, Index: 379)...
#   Success! Adv label: 8, L2: 921.98, Queries: 121
# Attacking sample 36/100 (True: 0, Index: 385)...
#   Failed! Adv label: 0, L2: 941.54, Queries: 201
# Attacking sample 37/100 (True: 0, Index: 397)...
#   Failed! Adv label: 0, L2: 776.43, Queries: 201
# Attacking sample 38/100 (True: 0, Index: 400)...
#   Failed! Adv label: 0, L2: 946.81, Queries: 201
# Attacking sample 39/100 (True: 0, Index: 405)...
#   Failed! Adv label: 0, L2: 908.85, Queries: 201
# Attacking sample 40/100 (True: 0, Index: 410)...
#   Success! Adv label: 9, L2: 847.22, Queries: 127
# Attacking sample 41/100 (True: 0, Index: 420)...
#   Failed! Adv label: 0, L2: 822.89, Queries: 201
# Attacking sample 42/100 (True: 0, Index: 424)...
#   Failed! Adv label: 0, L2: 873.13, Queries: 201
# Attacking sample 43/100 (True: 0, Index: 447)...
#   Success! Adv label: 2, L2: 720.23, Queries: 87
# Attacking sample 44/100 (True: 0, Index: 453)...
#   Success! Adv label: 2, L2: 814.90, Queries: 95
# Attacking sample 45/100 (True: 0, Index: 457)...
#   Failed! Adv label: 0, L2: 986.30, Queries: 201
# Attacking sample 46/100 (True: 0, Index: 466)...
#   Success! Adv label: 2, L2: 865.83, Queries: 97
# Attacking sample 47/100 (True: 0, Index: 475)...
#   Success! Adv label: 9, L2: 322.03, Queries: 35
# Attacking sample 48/100 (True: 0, Index: 483)...
#   Failed! Adv label: 0, L2: 890.39, Queries: 201
# Attacking sample 49/100 (True: 0, Index: 484)...
#   Success! Adv label: 8, L2: 546.05, Queries: 53
# Attacking sample 50/100 (True: 0, Index: 486)...
#   Failed! Adv label: 0, L2: 847.21, Queries: 201
# Attacking sample 51/100 (True: 0, Index: 487)...
#   Success! Adv label: 6, L2: 745.97, Queries: 87
# Attacking sample 52/100 (True: 0, Index: 489)...
#   Success! Adv label: 9, L2: 789.58, Queries: 91
# Attacking sample 53/100 (True: 0, Index: 492)...
#   Success! Adv label: 9, L2: 831.62, Queries: 97
# Attacking sample 54/100 (True: 0, Index: 506)...
#   Failed! Adv label: 0, L2: 968.05, Queries: 201
# Attacking sample 55/100 (True: 0, Index: 513)...
#   Failed! Adv label: 0, L2: 842.65, Queries: 201
# Attacking sample 56/100 (True: 0, Index: 518)...
#   Failed! Adv label: 0, L2: 855.72, Queries: 201
# Attacking sample 57/100 (True: 0, Index: 521)...
#   Failed! Adv label: 0, L2: 913.69, Queries: 201
# Attacking sample 58/100 (True: 0, Index: 527)...
#   Success! Adv label: 2, L2: 779.74, Queries: 89
# Attacking sample 59/100 (True: 0, Index: 529)...
#   Failed! Adv label: 0, L2: 679.69, Queries: 201
# Attacking sample 60/100 (True: 0, Index: 531)...
#   Failed! Adv label: 0, L2: 1024.88, Queries: 201
# Attacking sample 61/100 (True: 0, Index: 546)...
#   Success! Adv label: 9, L2: 660.27, Queries: 79
# Attacking sample 62/100 (True: 0, Index: 551)...
#   Success! Adv label: 6, L2: 463.51, Queries: 45
# Attacking sample 63/100 (True: 0, Index: 555)...
#   Success! Adv label: 6, L2: 1011.23, Queries: 149
# Attacking sample 64/100 (True: 0, Index: 587)...
#   Success! Adv label: 8, L2: 865.58, Queries: 101
# Attacking sample 65/100 (True: 0, Index: 604)...
#   Success! Adv label: 8, L2: 717.24, Queries: 73
# Attacking sample 66/100 (True: 0, Index: 614)...
#   Success! Adv label: 8, L2: 864.79, Queries: 107
# Attacking sample 67/100 (True: 0, Index: 615)...
#   Success! Adv label: 9, L2: 457.13, Queries: 47
# Attacking sample 68/100 (True: 0, Index: 618)...
#   Success! Adv label: 6, L2: 335.48, Queries: 33
# Attacking sample 69/100 (True: 0, Index: 638)...
#   Success! Adv label: 8, L2: 463.71, Queries: 47
# Attacking sample 70/100 (True: 0, Index: 642)...
#   Success! Adv label: 9, L2: 847.78, Queries: 139
# Attacking sample 71/100 (True: 0, Index: 655)...
#   Success! Adv label: 6, L2: 888.98, Queries: 95
# Attacking sample 72/100 (True: 0, Index: 658)...
#   Success! Adv label: 6, L2: 787.52, Queries: 85
# Attacking sample 73/100 (True: 0, Index: 665)...
#   Success! Adv label: 2, L2: 687.86, Queries: 77
# Attacking sample 74/100 (True: 0, Index: 671)...
#   Success! Adv label: 6, L2: 863.01, Queries: 99
# Attacking sample 75/100 (True: 0, Index: 681)...
#   Success! Adv label: 9, L2: 922.45, Queries: 117
# Attacking sample 76/100 (True: 0, Index: 691)...
#   Failed! Adv label: 0, L2: 920.78, Queries: 201
# Attacking sample 77/100 (True: 0, Index: 700)...
#   Success! Adv label: 8, L2: 709.12, Queries: 83
# Attacking sample 78/100 (True: 0, Index: 706)...
#   Failed! Adv label: 0, L2: 672.19, Queries: 201
# Attacking sample 79/100 (True: 0, Index: 712)...
#   Success! Adv label: 8, L2: 946.46, Queries: 199
# Attacking sample 80/100 (True: 0, Index: 713)...
#   Success! Adv label: 9, L2: 803.57, Queries: 89
# Attacking sample 81/100 (True: 0, Index: 736)...
#   Success! Adv label: 9, L2: 809.64, Queries: 101
# Attacking sample 82/100 (True: 0, Index: 742)...
#   Success! Adv label: 8, L2: 731.86, Queries: 85
# Attacking sample 83/100 (True: 0, Index: 744)...
#   Success! Adv label: 2, L2: 675.32, Queries: 77
# Attacking sample 84/100 (True: 0, Index: 760)...
#   Success! Adv label: 9, L2: 660.36, Queries: 79
# Attacking sample 85/100 (True: 0, Index: 772)...
#   Success! Adv label: 9, L2: 369.25, Queries: 37
# Attacking sample 86/100 (True: 0, Index: 781)...
#   Success! Adv label: 6, L2: 532.12, Queries: 55
# Attacking sample 87/100 (True: 0, Index: 809)...
#   Failed! Adv label: 0, L2: 705.11, Queries: 201
# Attacking sample 88/100 (True: 0, Index: 813)...
#   Success! Adv label: 9, L2: 508.41, Queries: 59
# Attacking sample 89/100 (True: 0, Index: 820)...
#   Failed! Adv label: 0, L2: 837.48, Queries: 201
# Attacking sample 90/100 (True: 0, Index: 823)...
#   Success! Adv label: 9, L2: 704.85, Queries: 91
# Attacking sample 91/100 (True: 0, Index: 844)...
#   Failed! Adv label: 0, L2: 1057.57, Queries: 201
# Attacking sample 92/100 (True: 0, Index: 848)...
#   Success! Adv label: 9, L2: 307.96, Queries: 31
# Attacking sample 93/100 (True: 0, Index: 861)...
#   Failed! Adv label: 0, L2: 1046.64, Queries: 201
# Attacking sample 94/100 (True: 0, Index: 865)...
#   Failed! Adv label: 0, L2: 1078.74, Queries: 201
# Attacking sample 95/100 (True: 0, Index: 869)...
#   Failed! Adv label: 0, L2: 980.83, Queries: 201
# Attacking sample 96/100 (True: 0, Index: 876)...
#   Success! Adv label: 9, L2: 756.14, Queries: 83
# Attacking sample 97/100 (True: 0, Index: 885)...
#   Failed! Adv label: 0, L2: 850.81, Queries: 201
# Attacking sample 98/100 (True: 0, Index: 906)...
#   Failed! Adv label: 0, L2: 950.44, Queries: 201
# Attacking sample 99/100 (True: 0, Index: 907)...
#   Failed! Adv label: 0, L2: 965.57, Queries: 201
# Attacking sample 100/100 (True: 0, Index: 918)...
#   Failed! Adv label: 0, L2: 877.61, Queries: 201
# Attacking sample 1/100 (True: 1, Index: 2)...
#   Success! Adv label: 7, L2: 404.65, Queries: 39
# Attacking sample 2/100 (True: 1, Index: 3)...
#   Success! Adv label: 7, L2: 489.30, Queries: 47
# Attacking sample 3/100 (True: 1, Index: 9)...
#   Success! Adv label: 2, L2: 397.81, Queries: 41
# Attacking sample 4/100 (True: 1, Index: 25)...
#   Success! Adv label: 4, L2: 391.59, Queries: 35
# Attacking sample 5/100 (True: 1, Index: 36)...
#   Success! Adv label: 2, L2: 388.99, Queries: 39
# Attacking sample 6/100 (True: 1, Index: 63)...
#   Success! Adv label: 8, L2: 429.63, Queries: 43
# Attacking sample 7/100 (True: 1, Index: 65)...
#   Success! Adv label: 8, L2: 437.42, Queries: 41
# Attacking sample 8/100 (True: 1, Index: 68)...
#   Success! Adv label: 4, L2: 428.92, Queries: 41
# Attacking sample 9/100 (True: 1, Index: 76)...
#   Success! Adv label: 8, L2: 349.18, Queries: 33
# Attacking sample 10/100 (True: 1, Index: 83)...
#   Success! Adv label: 4, L2: 394.52, Queries: 37
# Attacking sample 11/100 (True: 1, Index: 90)...
#   Success! Adv label: 9, L2: 25.18, Queries: 3
# Attacking sample 12/100 (True: 1, Index: 94)...
#   Success! Adv label: 8, L2: 307.09, Queries: 29
# Attacking sample 13/100 (True: 1, Index: 100)...
#   Success! Adv label: 8, L2: 323.31, Queries: 31
# Attacking sample 14/100 (True: 1, Index: 123)...
#   Success! Adv label: 8, L2: 306.72, Queries: 29
# Attacking sample 15/100 (True: 1, Index: 150)...
#   Success! Adv label: 4, L2: 445.61, Queries: 41
# Attacking sample 16/100 (True: 1, Index: 152)...
#   Success! Adv label: 9, L2: 404.44, Queries: 39
# Attacking sample 17/100 (True: 1, Index: 178)...
#   Success! Adv label: 4, L2: 415.62, Queries: 39
# Attacking sample 18/100 (True: 1, Index: 185)...
#   Success! Adv label: 8, L2: 462.47, Queries: 49
# Attacking sample 19/100 (True: 1, Index: 191)...
#   Success! Adv label: 4, L2: 402.46, Queries: 39
# Attacking sample 20/100 (True: 1, Index: 201)...
#   Success! Adv label: 8, L2: 398.80, Queries: 37
# Attacking sample 21/100 (True: 1, Index: 203)...
#   Success! Adv label: 4, L2: 321.68, Queries: 29
# Attacking sample 22/100 (True: 1, Index: 213)...
#   Success! Adv label: 8, L2: 372.67, Queries: 35
# Attacking sample 23/100 (True: 1, Index: 220)...
#   Success! Adv label: 4, L2: 318.85, Queries: 29
# Attacking sample 24/100 (True: 1, Index: 223)...
#   Success! Adv label: 4, L2: 414.18, Queries: 37
# Attacking sample 25/100 (True: 1, Index: 226)...
#   Success! Adv label: 4, L2: 363.26, Queries: 33
# Attacking sample 26/100 (True: 1, Index: 232)...
#   Success! Adv label: 4, L2: 486.76, Queries: 43
# Attacking sample 27/100 (True: 1, Index: 241)...
#   Success! Adv label: 4, L2: 312.38, Queries: 29
# Attacking sample 28/100 (True: 1, Index: 254)...
#   Success! Adv label: 4, L2: 356.87, Queries: 33
# Attacking sample 29/100 (True: 1, Index: 281)...
#   Success! Adv label: 8, L2: 357.99, Queries: 35
# Attacking sample 30/100 (True: 1, Index: 284)...
#   Success! Adv label: 8, L2: 403.97, Queries: 39
# Attacking sample 31/100 (True: 1, Index: 285)...
#   Success! Adv label: 4, L2: 265.53, Queries: 25
# Attacking sample 32/100 (True: 1, Index: 286)...
#   Success! Adv label: 4, L2: 320.06, Queries: 31
# Attacking sample 33/100 (True: 1, Index: 287)...
#   Success! Adv label: 4, L2: 332.35, Queries: 33
# Attacking sample 34/100 (True: 1, Index: 294)...
#   Success! Adv label: 4, L2: 403.91, Queries: 37
# Attacking sample 35/100 (True: 1, Index: 298)...
#   Success! Adv label: 4, L2: 471.22, Queries: 45
# Attacking sample 36/100 (True: 1, Index: 306)...
#   Success! Adv label: 4, L2: 456.01, Queries: 41
# Attacking sample 37/100 (True: 1, Index: 312)...
#   Success! Adv label: 8, L2: 425.45, Queries: 43
# Attacking sample 38/100 (True: 1, Index: 317)...
#   Success! Adv label: 4, L2: 390.86, Queries: 37
# Attacking sample 39/100 (True: 1, Index: 334)...
#   Success! Adv label: 4, L2: 425.94, Queries: 39
# Attacking sample 40/100 (True: 1, Index: 337)...
#   Success! Adv label: 4, L2: 471.41, Queries: 41
# Attacking sample 41/100 (True: 1, Index: 338)...
#   Success! Adv label: 4, L2: 462.19, Queries: 45
# Attacking sample 42/100 (True: 1, Index: 348)...
#   Success! Adv label: 4, L2: 496.16, Queries: 47
# Attacking sample 43/100 (True: 1, Index: 361)...
#   Success! Adv label: 4, L2: 318.08, Queries: 29
# Attacking sample 44/100 (True: 1, Index: 363)...
#   Success! Adv label: 8, L2: 440.98, Queries: 39
# Attacking sample 45/100 (True: 1, Index: 367)...
#   Success! Adv label: 8, L2: 269.66, Queries: 25
# Attacking sample 46/100 (True: 1, Index: 375)...
#   Success! Adv label: 4, L2: 489.51, Queries: 47
# Attacking sample 47/100 (True: 1, Index: 384)...
#   Success! Adv label: 8, L2: 365.10, Queries: 35
# Attacking sample 48/100 (True: 1, Index: 412)...
#   Success! Adv label: 4, L2: 497.83, Queries: 43
# Attacking sample 49/100 (True: 1, Index: 425)...
#   Success! Adv label: 9, L2: 484.63, Queries: 45
# Attacking sample 50/100 (True: 1, Index: 428)...
#   Success! Adv label: 4, L2: 424.14, Queries: 39
# Attacking sample 51/100 (True: 1, Index: 463)...
#   Success! Adv label: 4, L2: 305.58, Queries: 29
# Attacking sample 52/100 (True: 1, Index: 499)...
#   Success! Adv label: 4, L2: 472.08, Queries: 43
# Attacking sample 53/100 (True: 1, Index: 502)...
#   Success! Adv label: 4, L2: 418.41, Queries: 39
# Attacking sample 54/100 (True: 1, Index: 526)...
#   Success! Adv label: 4, L2: 340.53, Queries: 31
# Attacking sample 55/100 (True: 1, Index: 532)...
#   Success! Adv label: 4, L2: 408.35, Queries: 37
# Attacking sample 56/100 (True: 1, Index: 536)...
#   Success! Adv label: 9, L2: 345.98, Queries: 33
# Attacking sample 57/100 (True: 1, Index: 537)...
#   Success! Adv label: 8, L2: 446.81, Queries: 43
# Attacking sample 58/100 (True: 1, Index: 539)...
#   Success! Adv label: 4, L2: 447.47, Queries: 41
# Attacking sample 60/100 (True: 1, Index: 560)...
#   Success! Adv label: 4, L2: 373.71, Queries: 35
# Attacking sample 61/100 (True: 1, Index: 561)...
#   Success! Adv label: 8, L2: 374.64, Queries: 35
# Attacking sample 62/100 (True: 1, Index: 570)...
#   Success! Adv label: 8, L2: 393.23, Queries: 37
# Attacking sample 63/100 (True: 1, Index: 573)...
#   Success! Adv label: 2, L2: 27.98, Queries: 3
# Attacking sample 64/100 (True: 1, Index: 576)...
#   Success! Adv label: 7, L2: 420.95, Queries: 43
# Attacking sample 65/100 (True: 1, Index: 580)...
#   Success! Adv label: 4, L2: 332.31, Queries: 31
# Attacking sample 66/100 (True: 1, Index: 588)...
#   Success! Adv label: 7, L2: 656.67, Queries: 65
# Attacking sample 67/100 (True: 1, Index: 620)...
#   Success! Adv label: 4, L2: 398.33, Queries: 37
# Attacking sample 68/100 (True: 1, Index: 621)...
#   Success! Adv label: 4, L2: 391.21, Queries: 37
# Attacking sample 69/100 (True: 1, Index: 622)...
#   Success! Adv label: 2, L2: 153.46, Queries: 15
# Attacking sample 70/100 (True: 1, Index: 627)...
#   Success! Adv label: 8, L2: 347.85, Queries: 35
# Attacking sample 71/100 (True: 1, Index: 630)...
#   Success! Adv label: 4, L2: 281.28, Queries: 25
# Attacking sample 72/100 (True: 1, Index: 632)...
#   Success! Adv label: 4, L2: 297.73, Queries: 27
# Attacking sample 73/100 (True: 1, Index: 644)...
#   Success! Adv label: 4, L2: 327.82, Queries: 31
# Attacking sample 74/100 (True: 1, Index: 646)...
#   Success! Adv label: 7, L2: 446.66, Queries: 47
# Attacking sample 75/100 (True: 1, Index: 649)...
#   Success! Adv label: 4, L2: 432.53, Queries: 39
# Attacking sample 76/100 (True: 1, Index: 662)...
#   Success! Adv label: 4, L2: 481.54, Queries: 43
# Attacking sample 77/100 (True: 1, Index: 663)...
#   Success! Adv label: 4, L2: 304.98, Queries: 29
# Attacking sample 78/100 (True: 1, Index: 669)...
#   Success! Adv label: 4, L2: 492.71, Queries: 47
# Attacking sample 79/100 (True: 1, Index: 677)...
#   Success! Adv label: 4, L2: 313.19, Queries: 29
# Attacking sample 80/100 (True: 1, Index: 686)...
#   Success! Adv label: 4, L2: 518.35, Queries: 47
# Attacking sample 81/100 (True: 1, Index: 689)...
#   Success! Adv label: 4, L2: 413.74, Queries: 37
# Attacking sample 82/100 (True: 1, Index: 703)...
#   Success! Adv label: 8, L2: 473.96, Queries: 43
# Attacking sample 83/100 (True: 1, Index: 705)...
#   Success! Adv label: 4, L2: 500.98, Queries: 49
# Attacking sample 84/100 (True: 1, Index: 709)...
#   Success! Adv label: 4, L2: 349.80, Queries: 33
# Attacking sample 85/100 (True: 1, Index: 724)...
#   Success! Adv label: 4, L2: 267.93, Queries: 25
# Attacking sample 86/100 (True: 1, Index: 727)...
#   Success! Adv label: 8, L2: 386.19, Queries: 35
# Attacking sample 87/100 (True: 1, Index: 734)...
#   Success! Adv label: 8, L2: 259.80, Queries: 27
# Attacking sample 88/100 (True: 1, Index: 740)...
#   Success! Adv label: 4, L2: 409.82, Queries: 37
# Attacking sample 89/100 (True: 1, Index: 741)...
#   Success! Adv label: 8, L2: 340.62, Queries: 33
# Attacking sample 90/100 (True: 1, Index: 743)...
#   Success! Adv label: 8, L2: 388.58, Queries: 35
# Attacking sample 91/100 (True: 1, Index: 759)...
#   Success! Adv label: 4, L2: 390.70, Queries: 37
# Attacking sample 92/100 (True: 1, Index: 768)...
#   Success! Adv label: 8, L2: 385.28, Queries: 35
# Attacking sample 93/100 (True: 1, Index: 775)...
#   Success! Adv label: 4, L2: 283.09, Queries: 27
# Attacking sample 94/100 (True: 1, Index: 782)...
#   Success! Adv label: 4, L2: 391.63, Queries: 37
# Attacking sample 95/100 (True: 1, Index: 798)...
#   Success! Adv label: 9, L2: 378.70, Queries: 37
# Attacking sample 96/100 (True: 1, Index: 799)...
#   Success! Adv label: 4, L2: 488.11, Queries: 45
# Attacking sample 97/100 (True: 1, Index: 808)...
#   Success! Adv label: 4, L2: 352.22, Queries: 35
# Attacking sample 98/100 (True: 1, Index: 819)...
#   Success! Adv label: 4, L2: 529.43, Queries: 49
# Attacking sample 99/100 (True: 1, Index: 843)...
#   Success! Adv label: 4, L2: 522.09, Queries: 47
# Attacking sample 100/100 (True: 1, Index: 853)...
#   Success! Adv label: 4, L2: 406.13, Queries: 37
# Attacking sample 1/100 (True: 2, Index: 4)...
#   Success! Adv label: 3, L2: 610.69, Queries: 65
# Attacking sample 2/100 (True: 2, Index: 22)...
#   Success! Adv label: 3, L2: 801.12, Queries: 147
# Attacking sample 3/100 (True: 2, Index: 32)...
#   Failed! Adv label: 2, L2: 1045.27, Queries: 201
# Attacking sample 4/100 (True: 2, Index: 34)...
#   Success! Adv label: 4, L2: 41.33, Queries: 5
# Attacking sample 5/100 (True: 2, Index: 42)...
#   Success! Adv label: 3, L2: 284.87, Queries: 31
# Attacking sample 6/100 (True: 2, Index: 49)...
#   Failed! Adv label: 2, L2: 771.24, Queries: 201
# Attacking sample 7/100 (True: 2, Index: 52)...
#   Success! Adv label: 3, L2: 908.40, Queries: 163
# Attacking sample 8/100 (True: 2, Index: 69)...
#   Success! Adv label: 3, L2: 834.67, Queries: 93
# Attacking sample 9/100 (True: 2, Index: 70)...
#   Success! Adv label: 3, L2: 579.67, Queries: 75
# Attacking sample 10/100 (True: 2, Index: 81)...
#   Failed! Adv label: 2, L2: 1099.02, Queries: 201
# Attacking sample 11/100 (True: 2, Index: 110)...
#   Failed! Adv label: 2, L2: 906.15, Queries: 201
# Attacking sample 12/100 (True: 2, Index: 118)...
#   Success! Adv label: 3, L2: 615.34, Queries: 63
# Attacking sample 13/100 (True: 2, Index: 121)...
#   Success! Adv label: 3, L2: 770.75, Queries: 81
# Attacking sample 14/100 (True: 2, Index: 138)...
#   Success! Adv label: 3, L2: 863.30, Queries: 99
# Attacking sample 15/100 (True: 2, Index: 144)...
#   Success! Adv label: 0, L2: 773.62, Queries: 77
# Attacking sample 16/100 (True: 2, Index: 155)...
#   Success! Adv label: 8, L2: 1016.46, Queries: 117
# Attacking sample 17/100 (True: 2, Index: 160)...
#   Success! Adv label: 6, L2: 469.10, Queries: 55
# Attacking sample 18/100 (True: 2, Index: 161)...
#   Success! Adv label: 3, L2: 686.94, Queries: 75
# Attacking sample 19/100 (True: 2, Index: 176)...
#   Success! Adv label: 3, L2: 734.99, Queries: 77
# Attacking sample 21/100 (True: 2, Index: 186)...
#   Success! Adv label: 3, L2: 795.58, Queries: 127
# Attacking sample 22/100 (True: 2, Index: 197)...
#   Failed! Adv label: 2, L2: 1013.91, Queries: 201
# Attacking sample 23/100 (True: 2, Index: 208)...
#   Failed! Adv label: 2, L2: 994.16, Queries: 201
# Attacking sample 25/100 (True: 2, Index: 216)...
#   Success! Adv label: 3, L2: 823.08, Queries: 103
# Attacking sample 26/100 (True: 2, Index: 219)...
#   Success! Adv label: 3, L2: 485.14, Queries: 57
# Attacking sample 27/100 (True: 2, Index: 235)...
#   Success! Adv label: 3, L2: 828.32, Queries: 101
# Attacking sample 28/100 (True: 2, Index: 260)...
#   Success! Adv label: 0, L2: 641.84, Queries: 69
# Attacking sample 29/100 (True: 2, Index: 276)...
#   Success! Adv label: 4, L2: 673.28, Queries: 85
# Attacking sample 30/100 (True: 2, Index: 293)...
#   Success! Adv label: 3, L2: 736.27, Queries: 97
# Attacking sample 31/100 (True: 2, Index: 295)...
#   Success! Adv label: 3, L2: 671.87, Queries: 75
# Attacking sample 32/100 (True: 2, Index: 311)...
#   Success! Adv label: 3, L2: 613.06, Queries: 67
# Attacking sample 33/100 (True: 2, Index: 313)...
#   Success! Adv label: 3, L2: 169.57, Queries: 19
# Attacking sample 34/100 (True: 2, Index: 322)...
#   Success! Adv label: 7, L2: 821.00, Queries: 95
# Attacking sample 35/100 (True: 2, Index: 328)...
#   Success! Adv label: 8, L2: 860.69, Queries: 93
# Attacking sample 36/100 (True: 2, Index: 357)...
#   Success! Adv label: 7, L2: 600.69, Queries: 67
# Attacking sample 37/100 (True: 2, Index: 374)...
#   Success! Adv label: 8, L2: 605.90, Queries: 63
# Attacking sample 38/100 (True: 2, Index: 395)...
#   Success! Adv label: 8, L2: 454.35, Queries: 51
# Attacking sample 39/100 (True: 2, Index: 396)...
#   Success! Adv label: 8, L2: 778.82, Queries: 83
# Attacking sample 40/100 (True: 2, Index: 398)...
#   Success! Adv label: 3, L2: 792.50, Queries: 93
# Attacking sample 41/100 (True: 2, Index: 433)...
#   Success! Adv label: 3, L2: 717.82, Queries: 79
# Attacking sample 42/100 (True: 2, Index: 439)...
#   Success! Adv label: 9, L2: 821.01, Queries: 87
# Attacking sample 43/100 (True: 2, Index: 441)...
#   Success! Adv label: 8, L2: 409.84, Queries: 39
# Attacking sample 44/100 (True: 2, Index: 442)...
#   Success! Adv label: 9, L2: 967.42, Queries: 127
# Attacking sample 45/100 (True: 2, Index: 451)...
#   Failed! Adv label: 2, L2: 1068.26, Queries: 201
# Attacking sample 46/100 (True: 2, Index: 462)...
#   Success! Adv label: 3, L2: 655.71, Queries: 65
# Attacking sample 47/100 (True: 2, Index: 470)...
#   Success! Adv label: 3, L2: 664.48, Queries: 69
# Attacking sample 48/100 (True: 2, Index: 477)...
#   Success! Adv label: 3, L2: 864.65, Queries: 109
# Attacking sample 49/100 (True: 2, Index: 485)...
#   Success! Adv label: 7, L2: 247.51, Queries: 25
# Attacking sample 50/100 (True: 2, Index: 491)...
#   Success! Adv label: 8, L2: 765.32, Queries: 79
# Attacking sample 51/100 (True: 2, Index: 493)...
#   Success! Adv label: 7, L2: 839.48, Queries: 151
# Attacking sample 52/100 (True: 2, Index: 495)...
#   Success! Adv label: 3, L2: 666.45, Queries: 75
# Attacking sample 53/100 (True: 2, Index: 519)...
#   Success! Adv label: 3, L2: 916.52, Queries: 155
# Attacking sample 54/100 (True: 2, Index: 523)...
#   Success! Adv label: 6, L2: 850.10, Queries: 99
# Attacking sample 55/100 (True: 2, Index: 557)...
#   Success! Adv label: 8, L2: 940.02, Queries: 115
# Attacking sample 56/100 (True: 2, Index: 567)...
#   Success! Adv label: 0, L2: 628.32, Queries: 67
# Attacking sample 57/100 (True: 2, Index: 571)...
#   Success! Adv label: 7, L2: 817.62, Queries: 97
# Attacking sample 58/100 (True: 2, Index: 584)...
#   Failed! Adv label: 2, L2: 906.21, Queries: 201
# Attacking sample 59/100 (True: 2, Index: 591)...
#   Success! Adv label: 8, L2: 1036.08, Queries: 175
# Attacking sample 60/100 (True: 2, Index: 592)...
#   Success! Adv label: 3, L2: 822.41, Queries: 131
# Attacking sample 61/100 (True: 2, Index: 610)...
#   Failed! Adv label: 2, L2: 990.35, Queries: 201
# Attacking sample 62/100 (True: 2, Index: 612)...
#   Success! Adv label: 8, L2: 893.15, Queries: 89
# Attacking sample 63/100 (True: 2, Index: 616)...
#   Success! Adv label: 3, L2: 901.72, Queries: 97
# Attacking sample 64/100 (True: 2, Index: 624)...
#   Success! Adv label: 3, L2: 841.24, Queries: 89
# Attacking sample 65/100 (True: 2, Index: 631)...
#   Success! Adv label: 3, L2: 618.65, Queries: 71
# Attacking sample 66/100 (True: 2, Index: 636)...
#   Success! Adv label: 8, L2: 1003.24, Queries: 193
# Attacking sample 67/100 (True: 2, Index: 647)...
#   Success! Adv label: 1, L2: 139.76, Queries: 17
# Attacking sample 68/100 (True: 2, Index: 650)...
#   Success! Adv label: 3, L2: 242.61, Queries: 25
# Attacking sample 69/100 (True: 2, Index: 664)...
#   Failed! Adv label: 2, L2: 922.38, Queries: 201
# Attacking sample 70/100 (True: 2, Index: 704)...
#   Success! Adv label: 3, L2: 718.13, Queries: 81
# Attacking sample 71/100 (True: 2, Index: 720)...
#   Success! Adv label: 4, L2: 269.59, Queries: 29
# Attacking sample 72/100 (True: 2, Index: 725)...
#   Success! Adv label: 3, L2: 572.04, Queries: 59
# Attacking sample 73/100 (True: 2, Index: 750)...
#   Failed! Adv label: 2, L2: 779.38, Queries: 201
# Attacking sample 74/100 (True: 2, Index: 764)...
#   Success! Adv label: 3, L2: 498.99, Queries: 65
# Attacking sample 75/100 (True: 2, Index: 780)...
#   Success! Adv label: 8, L2: 974.56, Queries: 139
# Attacking sample 76/100 (True: 2, Index: 784)...
#   Success! Adv label: 8, L2: 1033.45, Queries: 125
# Attacking sample 77/100 (True: 2, Index: 788)...
#   Success! Adv label: 1, L2: 634.71, Queries: 67
# Attacking sample 78/100 (True: 2, Index: 790)...
#   Success! Adv label: 3, L2: 952.37, Queries: 161
# Attacking sample 79/100 (True: 2, Index: 797)...
#   Success! Adv label: 8, L2: 659.27, Queries: 71
# Attacking sample 80/100 (True: 2, Index: 803)...
#   Success! Adv label: 0, L2: 1034.51, Queries: 107
# Attacking sample 81/100 (True: 2, Index: 807)...
#   Failed! Adv label: 2, L2: 896.51, Queries: 201
# Attacking sample 82/100 (True: 2, Index: 828)...
#   Success! Adv label: 3, L2: 543.38, Queries: 61
# Attacking sample 83/100 (True: 2, Index: 842)...
#   Success! Adv label: 3, L2: 730.78, Queries: 85
# Attacking sample 84/100 (True: 2, Index: 845)...
#   Failed! Adv label: 2, L2: 1005.65, Queries: 201
# Attacking sample 85/100 (True: 2, Index: 859)...
#   Success! Adv label: 3, L2: 619.09, Queries: 67
# Attacking sample 86/100 (True: 2, Index: 871)...
#   Success! Adv label: 7, L2: 745.59, Queries: 83
# Attacking sample 87/100 (True: 2, Index: 881)...
#   Success! Adv label: 3, L2: 614.95, Queries: 81
# Attacking sample 88/100 (True: 2, Index: 883)...
#   Success! Adv label: 0, L2: 513.41, Queries: 55
# Attacking sample 89/100 (True: 2, Index: 896)...
#   Success! Adv label: 3, L2: 611.23, Queries: 71
# Attacking sample 90/100 (True: 2, Index: 897)...
#   Success! Adv label: 3, L2: 571.88, Queries: 77
# Attacking sample 92/100 (True: 2, Index: 922)...
#   Success! Adv label: 7, L2: 655.97, Queries: 81
# Attacking sample 93/100 (True: 2, Index: 932)...
#   Success! Adv label: 8, L2: 813.88, Queries: 85
# Attacking sample 94/100 (True: 2, Index: 944)...
#   Success! Adv label: 3, L2: 549.22, Queries: 59
# Attacking sample 95/100 (True: 2, Index: 949)...
#   Success! Adv label: 3, L2: 861.14, Queries: 91
# Attacking sample 96/100 (True: 2, Index: 952)...
#   Failed! Adv label: 2, L2: 765.90, Queries: 201
# Attacking sample 97/100 (True: 2, Index: 959)...
#   Success! Adv label: 3, L2: 683.49, Queries: 69
# Attacking sample 98/100 (True: 2, Index: 966)...
#   Success! Adv label: 7, L2: 252.13, Queries: 29
# Attacking sample 99/100 (True: 2, Index: 967)...
#   Failed! Adv label: 2, L2: 884.76, Queries: 201
# Attacking sample 100/100 (True: 2, Index: 985)...
#   Success! Adv label: 3, L2: 736.34, Queries: 91
# Attacking sample 1/100 (True: 3, Index: 1)...
#   Success! Adv label: 9, L2: 474.13, Queries: 49
# Attacking sample 2/100 (True: 3, Index: 12)...
#   Success! Adv label: 8, L2: 355.29, Queries: 41
# Attacking sample 3/100 (True: 3, Index: 20)...
#   Success! Adv label: 2, L2: 785.52, Queries: 79
# Attacking sample 4/100 (True: 3, Index: 27)...
#   Success! Adv label: 2, L2: 804.94, Queries: 137
# Attacking sample 5/100 (True: 3, Index: 37)...
#   Success! Adv label: 2, L2: 985.00, Queries: 169
# Attacking sample 6/100 (True: 3, Index: 43)...
#   Failed! Adv label: 3, L2: 851.82, Queries: 201
# Attacking sample 7/100 (True: 3, Index: 53)...
#   Success! Adv label: 8, L2: 601.56, Queries: 61
# Attacking sample 8/100 (True: 3, Index: 61)...
#   Success! Adv label: 8, L2: 669.42, Queries: 67
# Attacking sample 9/100 (True: 3, Index: 73)...
#   Success! Adv label: 8, L2: 667.36, Queries: 79
# Attacking sample 10/100 (True: 3, Index: 102)...
#   Success! Adv label: 2, L2: 460.12, Queries: 47
# Attacking sample 11/100 (True: 3, Index: 108)...
#   Success! Adv label: 2, L2: 101.53, Queries: 11
# Attacking sample 12/100 (True: 3, Index: 109)...
#   Success! Adv label: 8, L2: 650.70, Queries: 61
# Attacking sample 13/100 (True: 3, Index: 117)...
#   Failed! Adv label: 3, L2: 893.19, Queries: 201
# Attacking sample 14/100 (True: 3, Index: 131)...
#   Success! Adv label: 8, L2: 174.88, Queries: 17
# Attacking sample 15/100 (True: 3, Index: 159)...
#   Success! Adv label: 2, L2: 933.27, Queries: 135
# Attacking sample 16/100 (True: 3, Index: 162)...
#   Failed! Adv label: 3, L2: 873.15, Queries: 201
# Attacking sample 17/100 (True: 3, Index: 166)...
#   Success! Adv label: 2, L2: 772.69, Queries: 139
# Attacking sample 18/100 (True: 3, Index: 177)...
#   Success! Adv label: 2, L2: 603.45, Queries: 59
# Attacking sample 19/100 (True: 3, Index: 181)...
#   Success! Adv label: 8, L2: 596.08, Queries: 75
# Attacking sample 20/100 (True: 3, Index: 187)...
#   Success! Adv label: 8, L2: 726.36, Queries: 71
# Attacking sample 21/100 (True: 3, Index: 196)...
#   Success! Adv label: 2, L2: 535.12, Queries: 51
# Attacking sample 22/100 (True: 3, Index: 204)...
#   Failed! Adv label: 3, L2: 862.64, Queries: 201
# Attacking sample 23/100 (True: 3, Index: 227)...
#   Failed! Adv label: 3, L2: 786.14, Queries: 201
# Attacking sample 24/100 (True: 3, Index: 231)...
#   Failed! Adv label: 3, L2: 886.45, Queries: 201
# Attacking sample 25/100 (True: 3, Index: 237)...
#   Success! Adv label: 8, L2: 898.39, Queries: 177
# Attacking sample 26/100 (True: 3, Index: 244)...
#   Failed! Adv label: 3, L2: 872.99, Queries: 201
# Attacking sample 27/100 (True: 3, Index: 257)...
#   Success! Adv label: 8, L2: 611.95, Queries: 61
# Attacking sample 28/100 (True: 3, Index: 259)...
#   Failed! Adv label: 3, L2: 963.37, Queries: 201
# Attacking sample 29/100 (True: 3, Index: 265)...
#   Success! Adv label: 5, L2: 631.92, Queries: 69
# Attacking sample 30/100 (True: 3, Index: 270)...
#   Success! Adv label: 5, L2: 331.27, Queries: 33
# Attacking sample 31/100 (True: 3, Index: 288)...
#   Success! Adv label: 8, L2: 991.50, Queries: 99
# Attacking sample 32/100 (True: 3, Index: 308)...
#   Success! Adv label: 8, L2: 672.49, Queries: 73
# Attacking sample 33/100 (True: 3, Index: 309)...
#   Success! Adv label: 8, L2: 629.41, Queries: 63
# Attacking sample 34/100 (True: 3, Index: 327)...
#   Success! Adv label: 1, L2: 394.64, Queries: 49
# Attacking sample 35/100 (True: 3, Index: 331)...
#   Success! Adv label: 8, L2: 825.28, Queries: 99
# Attacking sample 36/100 (True: 3, Index: 340)...
#   Success! Adv label: 8, L2: 1045.09, Queries: 187
# Attacking sample 37/100 (True: 3, Index: 341)...
#   Success! Adv label: 8, L2: 903.64, Queries: 119
# Attacking sample 38/100 (True: 3, Index: 342)...
#   Success! Adv label: 5, L2: 647.36, Queries: 71
# Attacking sample 39/100 (True: 3, Index: 362)...
#   Success! Adv label: 2, L2: 542.42, Queries: 59
# Attacking sample 40/100 (True: 3, Index: 383)...
#   Success! Adv label: 2, L2: 602.46, Queries: 67
# Attacking sample 41/100 (True: 3, Index: 394)...
#   Success! Adv label: 8, L2: 570.11, Queries: 55
# Attacking sample 42/100 (True: 3, Index: 406)...
#   Failed! Adv label: 3, L2: 755.95, Queries: 201
# Attacking sample 43/100 (True: 3, Index: 409)...
#   Success! Adv label: 2, L2: 974.95, Queries: 173
# Attacking sample 44/100 (True: 3, Index: 445)...
#   Success! Adv label: 2, L2: 406.95, Queries: 41
# Attacking sample 45/100 (True: 3, Index: 456)...
#   Success! Adv label: 8, L2: 656.36, Queries: 63
# Attacking sample 46/100 (True: 3, Index: 459)...
#   Failed! Adv label: 3, L2: 874.08, Queries: 201
# Attacking sample 47/100 (True: 3, Index: 461)...
#   Failed! Adv label: 3, L2: 925.19, Queries: 201
# Attacking sample 48/100 (True: 3, Index: 471)...
#   Success! Adv label: 8, L2: 935.87, Queries: 97
# Attacking sample 49/100 (True: 3, Index: 474)...
#   Success! Adv label: 5, L2: 603.90, Queries: 67
# Attacking sample 50/100 (True: 3, Index: 481)...
#   Success! Adv label: 8, L2: 894.72, Queries: 175
# Attacking sample 51/100 (True: 3, Index: 504)...
#   Success! Adv label: 8, L2: 711.06, Queries: 85
# Attacking sample 52/100 (True: 3, Index: 510)...
#   Success! Adv label: 5, L2: 385.72, Queries: 41
# Attacking sample 53/100 (True: 3, Index: 512)...
#   Failed! Adv label: 3, L2: 791.27, Queries: 201
# Attacking sample 54/100 (True: 3, Index: 524)...
#   Success! Adv label: 8, L2: 700.46, Queries: 69
# Attacking sample 55/100 (True: 3, Index: 549)...
#   Success! Adv label: 2, L2: 591.22, Queries: 65
# Attacking sample 56/100 (True: 3, Index: 556)...
#   Success! Adv label: 9, L2: 834.76, Queries: 93
# Attacking sample 57/100 (True: 3, Index: 564)...
#   Success! Adv label: 9, L2: 670.19, Queries: 71
# Attacking sample 58/100 (True: 3, Index: 586)...
#   Failed! Adv label: 3, L2: 877.54, Queries: 201
# Attacking sample 59/100 (True: 3, Index: 589)...
#   Failed! Adv label: 3, L2: 1023.45, Queries: 201
# Attacking sample 60/100 (True: 3, Index: 609)...
#   Success! Adv label: 9, L2: 864.78, Queries: 101
# Attacking sample 61/100 (True: 3, Index: 613)...
#   Success! Adv label: 8, L2: 731.36, Queries: 73
# Attacking sample 62/100 (True: 3, Index: 623)...
#   Success! Adv label: 9, L2: 472.07, Queries: 49
# Attacking sample 63/100 (True: 3, Index: 639)...
#   Success! Adv label: 2, L2: 887.89, Queries: 189
# Attacking sample 64/100 (True: 3, Index: 648)...
#   Success! Adv label: 8, L2: 536.56, Queries: 51
# Attacking sample 65/100 (True: 3, Index: 651)...
#   Success! Adv label: 8, L2: 448.91, Queries: 45
# Attacking sample 66/100 (True: 3, Index: 659)...
#   Success! Adv label: 9, L2: 798.77, Queries: 91
# Attacking sample 67/100 (True: 3, Index: 661)...
#   Success! Adv label: 8, L2: 1008.76, Queries: 149
# Attacking sample 68/100 (True: 3, Index: 667)...
#   Failed! Adv label: 3, L2: 752.27, Queries: 201
# Attacking sample 69/100 (True: 3, Index: 678)...
#   Failed! Adv label: 3, L2: 776.46, Queries: 201
# Attacking sample 70/100 (True: 3, Index: 690)...
#   Success! Adv label: 8, L2: 1036.46, Queries: 115
# Attacking sample 71/100 (True: 3, Index: 693)...
#   Failed! Adv label: 3, L2: 744.35, Queries: 201
# Attacking sample 72/100 (True: 3, Index: 694)...
#   Success! Adv label: 9, L2: 907.06, Queries: 95
# Attacking sample 73/100 (True: 3, Index: 695)...
#   Success! Adv label: 0, L2: 271.46, Queries: 27
# Attacking sample 74/100 (True: 3, Index: 702)...
#   Success! Adv label: 8, L2: 492.43, Queries: 47
# Attacking sample 75/100 (True: 3, Index: 718)...
#   Failed! Adv label: 3, L2: 843.73, Queries: 201
# Attacking sample 76/100 (True: 3, Index: 749)...
#   Failed! Adv label: 3, L2: 924.15, Queries: 201
# Attacking sample 77/100 (True: 3, Index: 769)...
#   Success! Adv label: 2, L2: 981.09, Queries: 107
# Attacking sample 79/100 (True: 3, Index: 779)...
#   Success! Adv label: 8, L2: 462.51, Queries: 47
# Attacking sample 80/100 (True: 3, Index: 800)...
#   Success! Adv label: 8, L2: 933.21, Queries: 87
# Attacking sample 81/100 (True: 3, Index: 816)...
#   Success! Adv label: 5, L2: 385.55, Queries: 45
# Attacking sample 82/100 (True: 3, Index: 829)...
#   Success! Adv label: 2, L2: 601.60, Queries: 61
# Attacking sample 83/100 (True: 3, Index: 833)...
#   Failed! Adv label: 3, L2: 824.14, Queries: 201
# Attacking sample 84/100 (True: 3, Index: 839)...
#   Success! Adv label: 8, L2: 656.60, Queries: 71
# Attacking sample 85/100 (True: 3, Index: 854)...
#   Success! Adv label: 5, L2: 403.64, Queries: 45
# Attacking sample 86/100 (True: 3, Index: 856)...
#   Success! Adv label: 2, L2: 546.43, Queries: 59
# Attacking sample 87/100 (True: 3, Index: 858)...
#   Success! Adv label: 5, L2: 141.78, Queries: 15
# Attacking sample 89/100 (True: 3, Index: 886)...
#   Success! Adv label: 8, L2: 899.60, Queries: 93
# Attacking sample 90/100 (True: 3, Index: 900)...
#   Success! Adv label: 8, L2: 723.47, Queries: 75
# Attacking sample 91/100 (True: 3, Index: 916)...
#   Success! Adv label: 5, L2: 645.70, Queries: 85
# Attacking sample 92/100 (True: 3, Index: 921)...
#   Success! Adv label: 2, L2: 524.50, Queries: 59
# Attacking sample 93/100 (True: 3, Index: 937)...
#   Success! Adv label: 8, L2: 1028.19, Queries: 117
# Attacking sample 94/100 (True: 3, Index: 938)...
#   Success! Adv label: 8, L2: 831.31, Queries: 77
# Attacking sample 95/100 (True: 3, Index: 939)...
#   Success! Adv label: 8, L2: 418.60, Queries: 41
# Attacking sample 96/100 (True: 3, Index: 942)...
#   Failed! Adv label: 3, L2: 869.26, Queries: 201
# Attacking sample 97/100 (True: 3, Index: 951)...
#   Success! Adv label: 8, L2: 643.74, Queries: 69
# Attacking sample 98/100 (True: 3, Index: 953)...
#   Failed! Adv label: 3, L2: 753.00, Queries: 201
# Attacking sample 99/100 (True: 3, Index: 975)...
#   Failed! Adv label: 3, L2: 927.68, Queries: 201
# Attacking sample 1/100 (True: 4, Index: 16)...
#   Success! Adv label: 9, L2: 338.10, Queries: 37
# Attacking sample 2/100 (True: 4, Index: 17)...
#   Success! Adv label: 6, L2: 536.91, Queries: 61
# Attacking sample 3/100 (True: 4, Index: 30)...
#   Success! Adv label: 8, L2: 880.85, Queries: 95
# Attacking sample 4/100 (True: 4, Index: 33)...
#   Success! Adv label: 9, L2: 618.02, Queries: 65
# Attacking sample 5/100 (True: 4, Index: 45)...
#   Success! Adv label: 8, L2: 154.74, Queries: 15
# Attacking sample 6/100 (True: 4, Index: 48)...
#   Success! Adv label: 9, L2: 918.34, Queries: 97
# Attacking sample 7/100 (True: 4, Index: 58)...
#   Success! Adv label: 9, L2: 896.72, Queries: 87
# Attacking sample 8/100 (True: 4, Index: 66)...
#   Success! Adv label: 6, L2: 703.60, Queries: 77
# Attacking sample 9/100 (True: 4, Index: 89)...
#   Success! Adv label: 9, L2: 439.18, Queries: 45
# Attacking sample 10/100 (True: 4, Index: 92)...
#   Failed! Adv label: 4, L2: 1017.02, Queries: 201
# Attacking sample 11/100 (True: 4, Index: 113)...
#   Success! Adv label: 2, L2: 790.88, Queries: 85
# Attacking sample 12/100 (True: 4, Index: 116)...
#   Success! Adv label: 9, L2: 719.18, Queries: 69
# Attacking sample 13/100 (True: 4, Index: 126)...
#   Success! Adv label: 9, L2: 606.48, Queries: 63
# Attacking sample 14/100 (True: 4, Index: 130)...
#   Success! Adv label: 9, L2: 420.02, Queries: 41
# Attacking sample 15/100 (True: 4, Index: 139)...
#   Success! Adv label: 9, L2: 664.98, Queries: 65
# Attacking sample 16/100 (True: 4, Index: 149)...
#   Failed! Adv label: 4, L2: 955.99, Queries: 201
# Attacking sample 17/100 (True: 4, Index: 153)...
#   Success! Adv label: 8, L2: 632.00, Queries: 65
# Attacking sample 18/100 (True: 4, Index: 154)...
#   Success! Adv label: 7, L2: 970.96, Queries: 139
# Attacking sample 19/100 (True: 4, Index: 163)...
#   Success! Adv label: 9, L2: 698.06, Queries: 71
# Attacking sample 20/100 (True: 4, Index: 167)...
#   Success! Adv label: 9, L2: 913.86, Queries: 99
# Attacking sample 21/100 (True: 4, Index: 183)...
#   Success! Adv label: 9, L2: 485.94, Queries: 53
# Attacking sample 22/100 (True: 4, Index: 184)...
#   Success! Adv label: 9, L2: 642.23, Queries: 65
# Attacking sample 23/100 (True: 4, Index: 192)...
#   Success! Adv label: 9, L2: 335.86, Queries: 33
# Attacking sample 24/100 (True: 4, Index: 194)...
#   Success! Adv label: 9, L2: 644.91, Queries: 71
# Attacking sample 25/100 (True: 4, Index: 233)...
#   Success! Adv label: 9, L2: 830.05, Queries: 91
# Attacking sample 26/100 (True: 4, Index: 240)...
#   Success! Adv label: 8, L2: 688.73, Queries: 67
# Attacking sample 27/100 (True: 4, Index: 263)...
#   Success! Adv label: 9, L2: 340.08, Queries: 33
# Attacking sample 28/100 (True: 4, Index: 269)...
#   Success! Adv label: 9, L2: 473.01, Queries: 47
# Attacking sample 29/100 (True: 4, Index: 280)...
#   Success! Adv label: 9, L2: 505.61, Queries: 51
# Attacking sample 30/100 (True: 4, Index: 290)...
#   Success! Adv label: 9, L2: 784.55, Queries: 75
# Attacking sample 31/100 (True: 4, Index: 297)...
#   Success! Adv label: 6, L2: 491.51, Queries: 49
# Attacking sample 32/100 (True: 4, Index: 299)...
#   Success! Adv label: 9, L2: 441.89, Queries: 43
# Attacking sample 33/100 (True: 4, Index: 310)...
#   Success! Adv label: 9, L2: 344.53, Queries: 33
# Attacking sample 34/100 (True: 4, Index: 316)...
#   Success! Adv label: 9, L2: 522.71, Queries: 51
# Attacking sample 35/100 (True: 4, Index: 320)...
#   Success! Adv label: 9, L2: 510.50, Queries: 51
# Attacking sample 36/100 (True: 4, Index: 324)...
#   Success! Adv label: 9, L2: 564.37, Queries: 59
# Attacking sample 37/100 (True: 4, Index: 326)...
#   Success! Adv label: 9, L2: 628.39, Queries: 65
# Attacking sample 38/100 (True: 4, Index: 332)...
#   Success! Adv label: 9, L2: 24.92, Queries: 3
# Attacking sample 39/100 (True: 4, Index: 335)...
#   Success! Adv label: 9, L2: 773.94, Queries: 77
# Attacking sample 40/100 (True: 4, Index: 344)...
#   Success! Adv label: 7, L2: 566.46, Queries: 61
# Attacking sample 42/100 (True: 4, Index: 359)...
#   Success! Adv label: 9, L2: 549.65, Queries: 53
# Attacking sample 43/100 (True: 4, Index: 376)...
#   Success! Adv label: 9, L2: 783.56, Queries: 85
# Attacking sample 44/100 (True: 4, Index: 393)...
#   Success! Adv label: 9, L2: 642.81, Queries: 67
# Attacking sample 45/100 (True: 4, Index: 401)...
#   Success! Adv label: 2, L2: 912.61, Queries: 97
# Attacking sample 46/100 (True: 4, Index: 402)...
#   Success! Adv label: 9, L2: 615.76, Queries: 63
# Attacking sample 47/100 (True: 4, Index: 422)...
#   Success! Adv label: 9, L2: 390.84, Queries: 37
# Attacking sample 48/100 (True: 4, Index: 423)...
#   Success! Adv label: 9, L2: 230.64, Queries: 25
# Attacking sample 49/100 (True: 4, Index: 427)...
#   Success! Adv label: 1, L2: 683.10, Queries: 81
# Attacking sample 50/100 (True: 4, Index: 432)...
#   Success! Adv label: 9, L2: 483.45, Queries: 49
# Attacking sample 51/100 (True: 4, Index: 434)...
#   Success! Adv label: 9, L2: 376.80, Queries: 37
# Attacking sample 52/100 (True: 4, Index: 454)...
#   Success! Adv label: 9, L2: 603.03, Queries: 63
# Attacking sample 53/100 (True: 4, Index: 467)...
#   Success! Adv label: 9, L2: 367.41, Queries: 39
# Attacking sample 54/100 (True: 4, Index: 501)...
#   Success! Adv label: 9, L2: 321.33, Queries: 35
# Attacking sample 55/100 (True: 4, Index: 515)...
#   Success! Adv label: 9, L2: 440.19, Queries: 43
# Attacking sample 56/100 (True: 4, Index: 540)...
#   Success! Adv label: 9, L2: 670.97, Queries: 73
# Attacking sample 57/100 (True: 4, Index: 544)...
#   Success! Adv label: 0, L2: 562.74, Queries: 69
# Attacking sample 58/100 (True: 4, Index: 545)...
#   Success! Adv label: 2, L2: 559.84, Queries: 59
# Attacking sample 59/100 (True: 4, Index: 547)...
#   Failed! Adv label: 4, L2: 821.25, Queries: 201
# Attacking sample 60/100 (True: 4, Index: 566)...
#   Success! Adv label: 9, L2: 513.46, Queries: 51
# Attacking sample 61/100 (True: 4, Index: 590)...
#   Success! Adv label: 0, L2: 569.76, Queries: 59
# Attacking sample 62/100 (True: 4, Index: 593)...
#   Success! Adv label: 9, L2: 390.02, Queries: 37
# Attacking sample 63/100 (True: 4, Index: 599)...
#   Success! Adv label: 8, L2: 864.34, Queries: 97
# Attacking sample 64/100 (True: 4, Index: 602)...
#   Success! Adv label: 9, L2: 613.91, Queries: 63
# Attacking sample 65/100 (True: 4, Index: 607)...
#   Success! Adv label: 7, L2: 647.39, Queries: 79
# Attacking sample 66/100 (True: 4, Index: 611)...
#   Success! Adv label: 9, L2: 933.70, Queries: 103
# Attacking sample 67/100 (True: 4, Index: 617)...
#   Success! Adv label: 9, L2: 701.25, Queries: 65
# Attacking sample 68/100 (True: 4, Index: 657)...
#   Success! Adv label: 9, L2: 379.35, Queries: 41
# Attacking sample 69/100 (True: 4, Index: 680)...
#   Success! Adv label: 9, L2: 484.04, Queries: 47
# Attacking sample 70/100 (True: 4, Index: 684)...
#   Success! Adv label: 9, L2: 799.90, Queries: 91
# Attacking sample 71/100 (True: 4, Index: 687)...
#   Success! Adv label: 9, L2: 659.58, Queries: 65
# Attacking sample 72/100 (True: 4, Index: 692)...
#   Success! Adv label: 9, L2: 1007.42, Queries: 163
# Attacking sample 73/100 (True: 4, Index: 696)...
#   Success! Adv label: 9, L2: 204.55, Queries: 21
# Attacking sample 74/100 (True: 4, Index: 697)...
#   Success! Adv label: 9, L2: 1025.98, Queries: 103
# Attacking sample 75/100 (True: 4, Index: 708)...
#   Success! Adv label: 9, L2: 669.62, Queries: 65
# Attacking sample 76/100 (True: 4, Index: 717)...
#   Success! Adv label: 9, L2: 463.34, Queries: 45
# Attacking sample 77/100 (True: 4, Index: 746)...
#   Success! Adv label: 9, L2: 633.36, Queries: 73
# Attacking sample 78/100 (True: 4, Index: 752)...
#   Failed! Adv label: 4, L2: 1008.23, Queries: 201
# Attacking sample 79/100 (True: 4, Index: 755)...
#   Failed! Adv label: 4, L2: 881.80, Queries: 201
# Attacking sample 80/100 (True: 4, Index: 757)...
#   Success! Adv label: 9, L2: 545.73, Queries: 55
# Attacking sample 81/100 (True: 4, Index: 766)...
#   Success! Adv label: 7, L2: 525.50, Queries: 59
# Attacking sample 82/100 (True: 4, Index: 771)...
#   Success! Adv label: 9, L2: 375.04, Queries: 37
# Attacking sample 83/100 (True: 4, Index: 776)...
#   Success! Adv label: 2, L2: 733.53, Queries: 73
# Attacking sample 84/100 (True: 4, Index: 777)...
#   Failed! Adv label: 4, L2: 882.80, Queries: 201
# Attacking sample 85/100 (True: 4, Index: 786)...
#   Success! Adv label: 9, L2: 274.21, Queries: 27
# Attacking sample 86/100 (True: 4, Index: 811)...
#   Success! Adv label: 9, L2: 325.55, Queries: 33
# Attacking sample 87/100 (True: 4, Index: 815)...
#   Success! Adv label: 6, L2: 830.63, Queries: 95
# Attacking sample 88/100 (True: 4, Index: 817)...
#   Failed! Adv label: 4, L2: 970.15, Queries: 201
# Attacking sample 89/100 (True: 4, Index: 840)...
#   Success! Adv label: 6, L2: 853.79, Queries: 87
# Attacking sample 91/100 (True: 4, Index: 849)...
#   Success! Adv label: 8, L2: 828.08, Queries: 81
# Attacking sample 92/100 (True: 4, Index: 857)...
#   Success! Adv label: 9, L2: 634.76, Queries: 63
# Attacking sample 93/100 (True: 4, Index: 872)...
#   Success! Adv label: 9, L2: 886.59, Queries: 101
# Attacking sample 94/100 (True: 4, Index: 877)...
#   Success! Adv label: 9, L2: 573.84, Queries: 63
# Attacking sample 95/100 (True: 4, Index: 894)...
#   Success! Adv label: 9, L2: 297.74, Queries: 29
# Attacking sample 96/100 (True: 4, Index: 902)...
#   Success! Adv label: 9, L2: 469.65, Queries: 45
# Attacking sample 97/100 (True: 4, Index: 911)...
# ...
#   Success! Adv label: 3, L2: 609.54, Queries: 63
# Attacking sample 40/100 (True: 8, Index: 505)...
#   Success! Adv label: 2, L2: 736.11, Queries: 83
# Attacking sample 41/100 (True: 8, Index: 509)...
#   Success! Adv label: 3, L2: 698.20, Queries: 91
# Attacking sample 42/100 (True: 8, Index: 525)...
#   Success! Adv label: 3, L2: 604.19, Queries: 69
# Attacking sample 43/100 (True: 8, Index: 528)...
#   Success! Adv label: 3, L2: 759.91, Queries: 97
# Attacking sample 44/100 (True: 8, Index: 541)...
#   Failed! Adv label: 8, L2: 906.83, Queries: 201
# Attacking sample 45/100 (True: 8, Index: 543)...
#   Success! Adv label: 6, L2: 449.84, Queries: 49
# Attacking sample 46/100 (True: 8, Index: 550)...
#   Success! Adv label: 9, L2: 573.50, Queries: 67
# Attacking sample 47/100 (True: 8, Index: 558)...
#   Failed! Adv label: 8, L2: 922.60, Queries: 201
# Attacking sample 48/100 (True: 8, Index: 575)...
#   Success! Adv label: 9, L2: 595.94, Queries: 71
# Attacking sample 49/100 (True: 8, Index: 594)...
#   Success! Adv label: 2, L2: 505.10, Queries: 61
# Attacking sample 50/100 (True: 8, Index: 600)...
#   Failed! Adv label: 8, L2: 943.19, Queries: 201
# Attacking sample 51/100 (True: 8, Index: 605)...
#   Success! Adv label: 2, L2: 741.27, Queries: 81
# Attacking sample 52/100 (True: 8, Index: 619)...
#   Success! Adv label: 3, L2: 646.98, Queries: 85
# Attacking sample 53/100 (True: 8, Index: 625)...
#   Success! Adv label: 3, L2: 863.70, Queries: 89
# Attacking sample 54/100 (True: 8, Index: 629)...
#   Success! Adv label: 2, L2: 597.02, Queries: 63
# Attacking sample 55/100 (True: 8, Index: 645)...
#   Failed! Adv label: 8, L2: 946.85, Queries: 201
# Attacking sample 56/100 (True: 8, Index: 652)...
#   Success! Adv label: 3, L2: 839.56, Queries: 171
# Attacking sample 57/100 (True: 8, Index: 672)...
#   Success! Adv label: 3, L2: 666.68, Queries: 85
# Attacking sample 58/100 (True: 8, Index: 683)...
#   Success! Adv label: 3, L2: 358.17, Queries: 45
# Attacking sample 59/100 (True: 8, Index: 701)...
#   Success! Adv label: 5, L2: 795.15, Queries: 91
# Attacking sample 60/100 (True: 8, Index: 714)...
#   Success! Adv label: 3, L2: 707.47, Queries: 85
# Attacking sample 61/100 (True: 8, Index: 721)...
#   Success! Adv label: 3, L2: 511.86, Queries: 57
# Attacking sample 62/100 (True: 8, Index: 730)...
#   Success! Adv label: 2, L2: 716.13, Queries: 77
# Attacking sample 63/100 (True: 8, Index: 731)...
#   Failed! Adv label: 8, L2: 962.52, Queries: 201
# Attacking sample 64/100 (True: 8, Index: 738)...
#   Failed! Adv label: 8, L2: 943.12, Queries: 201
# Attacking sample 65/100 (True: 8, Index: 791)...
#   Success! Adv label: 5, L2: 859.03, Queries: 103
# Attacking sample 66/100 (True: 8, Index: 832)...
#   Success! Adv label: 6, L2: 709.87, Queries: 79
# Attacking sample 67/100 (True: 8, Index: 838)...
#   Success! Adv label: 5, L2: 696.64, Queries: 89
# Attacking sample 68/100 (True: 8, Index: 860)...
#   Success! Adv label: 3, L2: 799.06, Queries: 99
# Attacking sample 69/100 (True: 8, Index: 864)...
#   Failed! Adv label: 8, L2: 845.20, Queries: 201
# Attacking sample 70/100 (True: 8, Index: 889)...
#   Success! Adv label: 3, L2: 679.79, Queries: 83
# Attacking sample 71/100 (True: 8, Index: 905)...
#   Success! Adv label: 9, L2: 811.65, Queries: 99
# Attacking sample 73/100 (True: 8, Index: 919)...
#   Success! Adv label: 3, L2: 558.64, Queries: 65
# Attacking sample 74/100 (True: 8, Index: 923)...
#   Success! Adv label: 3, L2: 734.28, Queries: 91
# Attacking sample 75/100 (True: 8, Index: 926)...
#   Success! Adv label: 5, L2: 863.20, Queries: 109
# Attacking sample 76/100 (True: 8, Index: 933)...
#   Success! Adv label: 3, L2: 732.57, Queries: 93
# Attacking sample 78/100 (True: 8, Index: 971)...
#   Success! Adv label: 3, L2: 821.15, Queries: 97
# Attacking sample 79/100 (True: 8, Index: 1014)...
#   Success! Adv label: 3, L2: 570.34, Queries: 71
# Attacking sample 80/100 (True: 8, Index: 1034)...
#   Success! Adv label: 5, L2: 888.53, Queries: 139
# Attacking sample 81/100 (True: 8, Index: 1053)...
#   Success! Adv label: 6, L2: 667.62, Queries: 73
# Attacking sample 82/100 (True: 8, Index: 1057)...
#   Success! Adv label: 6, L2: 534.81, Queries: 53
# Attacking sample 83/100 (True: 8, Index: 1061)...
#   Failed! Adv label: 8, L2: 796.84, Queries: 201
# Attacking sample 84/100 (True: 8, Index: 1062)...
#   Success! Adv label: 3, L2: 654.19, Queries: 83
# Attacking sample 85/100 (True: 8, Index: 1063)...
#   Success! Adv label: 3, L2: 628.79, Queries: 69
# Attacking sample 86/100 (True: 8, Index: 1078)...
#   Success! Adv label: 9, L2: 379.36, Queries: 37
# Attacking sample 87/100 (True: 8, Index: 1088)...
#   Success! Adv label: 2, L2: 814.11, Queries: 95
# Attacking sample 88/100 (True: 8, Index: 1100)...
#   Failed! Adv label: 8, L2: 964.66, Queries: 201
# Attacking sample 89/100 (True: 8, Index: 1106)...
#   Failed! Adv label: 8, L2: 925.55, Queries: 201
# Attacking sample 90/100 (True: 8, Index: 1120)...
#   Success! Adv label: 3, L2: 621.82, Queries: 73
# Attacking sample 91/100 (True: 8, Index: 1132)...
#   Success! Adv label: 2, L2: 722.09, Queries: 85
# Attacking sample 92/100 (True: 8, Index: 1134)...
#   Failed! Adv label: 8, L2: 1018.67, Queries: 201
# Attacking sample 93/100 (True: 8, Index: 1140)...
#   Success! Adv label: 5, L2: 364.07, Queries: 41
# Attacking sample 94/100 (True: 8, Index: 1150)...
#   Success! Adv label: 9, L2: 605.57, Queries: 63
# Attacking sample 95/100 (True: 8, Index: 1165)...
#   Failed! Adv label: 8, L2: 977.20, Queries: 201
# Attacking sample 96/100 (True: 8, Index: 1179)...
#   Success! Adv label: 9, L2: 701.58, Queries: 83
# Attacking sample 97/100 (True: 8, Index: 1182)...
#   Success! Adv label: 9, L2: 590.40, Queries: 65
# Attacking sample 98/100 (True: 8, Index: 1186)...
#   Failed! Adv label: 8, L2: 886.40, Queries: 201
# Attacking sample 99/100 (True: 8, Index: 1189)...
#   Success! Adv label: 3, L2: 290.81, Queries: 35
# Attacking sample 100/100 (True: 8, Index: 1207)...
#   Success! Adv label: 9, L2: 898.69, Queries: 99
# Attacking sample 1/100 (True: 9, Index: 6)...
#   Success! Adv label: 7, L2: 393.43, Queries: 43
# Attacking sample 2/100 (True: 9, Index: 38)...
#   Success! Adv label: 7, L2: 80.56, Queries: 9
# Attacking sample 3/100 (True: 9, Index: 55)...
#   Success! Adv label: 0, L2: 168.89, Queries: 19
# Attacking sample 4/100 (True: 9, Index: 56)...
#   Success! Adv label: 4, L2: 543.42, Queries: 57
# Attacking sample 5/100 (True: 9, Index: 91)...
#   Success! Adv label: 3, L2: 328.96, Queries: 33
# Attacking sample 6/100 (True: 9, Index: 99)...
#   Success! Adv label: 7, L2: 484.60, Queries: 55
# Attacking sample 7/100 (True: 9, Index: 101)...
#   Success! Adv label: 5, L2: 787.19, Queries: 97
# Attacking sample 8/100 (True: 9, Index: 114)...
#   Success! Adv label: 8, L2: 811.67, Queries: 83
# Attacking sample 9/100 (True: 9, Index: 133)...
#   Success! Adv label: 8, L2: 809.25, Queries: 83
# Attacking sample 10/100 (True: 9, Index: 171)...
#   Success! Adv label: 8, L2: 112.23, Queries: 11
# Attacking sample 11/100 (True: 9, Index: 179)...
#   Success! Adv label: 7, L2: 671.69, Queries: 83
# Attacking sample 12/100 (True: 9, Index: 195)...
#   Success! Adv label: 1, L2: 265.10, Queries: 27
# Attacking sample 13/100 (True: 9, Index: 214)...
#   Success! Adv label: 4, L2: 608.01, Queries: 73
# Attacking sample 14/100 (True: 9, Index: 218)...
#   Success! Adv label: 4, L2: 438.34, Queries: 51
# Attacking sample 15/100 (True: 9, Index: 222)...
#   Success! Adv label: 8, L2: 483.94, Queries: 55
# Attacking sample 16/100 (True: 9, Index: 224)...
#   Success! Adv label: 6, L2: 647.99, Queries: 71
# Attacking sample 17/100 (True: 9, Index: 238)...
#   Success! Adv label: 4, L2: 579.86, Queries: 59
# Attacking sample 18/100 (True: 9, Index: 243)...
#   Success! Adv label: 8, L2: 827.81, Queries: 89
# Attacking sample 19/100 (True: 9, Index: 245)...
#   Success! Adv label: 4, L2: 641.11, Queries: 73
# Attacking sample 20/100 (True: 9, Index: 246)...
#   Success! Adv label: 8, L2: 723.48, Queries: 71
# Attacking sample 21/100 (True: 9, Index: 251)...
#   Success! Adv label: 7, L2: 317.65, Queries: 35
# Attacking sample 22/100 (True: 9, Index: 303)...
#   Success! Adv label: 4, L2: 336.88, Queries: 37
# Attacking sample 23/100 (True: 9, Index: 305)...
#   Success! Adv label: 8, L2: 311.27, Queries: 33
# Attacking sample 24/100 (True: 9, Index: 307)...
#   Success! Adv label: 3, L2: 668.97, Queries: 83
# Attacking sample 25/100 (True: 9, Index: 315)...
#   Success! Adv label: 8, L2: 830.73, Queries: 91
# Attacking sample 26/100 (True: 9, Index: 354)...
#   Success! Adv label: 4, L2: 688.06, Queries: 81
# Attacking sample 27/100 (True: 9, Index: 364)...
#   Success! Adv label: 8, L2: 888.12, Queries: 95
# Attacking sample 28/100 (True: 9, Index: 389)...
#   Success! Adv label: 4, L2: 403.88, Queries: 43
# Attacking sample 29/100 (True: 9, Index: 407)...
#   Success! Adv label: 8, L2: 303.08, Queries: 29
# Attacking sample 30/100 (True: 9, Index: 411)...
#   Success! Adv label: 4, L2: 294.08, Queries: 29
# Attacking sample 31/100 (True: 9, Index: 417)...
#   Success! Adv label: 7, L2: 515.35, Queries: 71
# Attacking sample 32/100 (True: 9, Index: 421)...
#   Success! Adv label: 4, L2: 535.27, Queries: 59
# Attacking sample 33/100 (True: 9, Index: 438)...
#   Success! Adv label: 4, L2: 537.60, Queries: 59
# Attacking sample 34/100 (True: 9, Index: 443)...
#   Success! Adv label: 8, L2: 748.08, Queries: 81
# Attacking sample 35/100 (True: 9, Index: 444)...
#   Success! Adv label: 4, L2: 368.62, Queries: 41
# Attacking sample 36/100 (True: 9, Index: 446)...
#   Success! Adv label: 7, L2: 697.96, Queries: 87
# Attacking sample 37/100 (True: 9, Index: 455)...
#   Success! Adv label: 7, L2: 358.50, Queries: 41
# Attacking sample 38/100 (True: 9, Index: 469)...
#   Success! Adv label: 7, L2: 841.80, Queries: 153
# Attacking sample 39/100 (True: 9, Index: 472)...
#   Success! Adv label: 3, L2: 935.58, Queries: 103
# Attacking sample 40/100 (True: 9, Index: 473)...
#   Success! Adv label: 7, L2: 795.32, Queries: 91
# Attacking sample 41/100 (True: 9, Index: 482)...
#   Success! Adv label: 4, L2: 554.58, Queries: 55
# Attacking sample 42/100 (True: 9, Index: 490)...
#   Success! Adv label: 8, L2: 1022.44, Queries: 133
# Attacking sample 43/100 (True: 9, Index: 496)...
#   Success! Adv label: 4, L2: 584.92, Queries: 69
# Attacking sample 44/100 (True: 9, Index: 507)...
#   Success! Adv label: 8, L2: 497.13, Queries: 49
# Attacking sample 45/100 (True: 9, Index: 508)...
#   Success! Adv label: 7, L2: 527.39, Queries: 59
# Attacking sample 46/100 (True: 9, Index: 514)...
#   Success! Adv label: 4, L2: 275.16, Queries: 27
# Attacking sample 47/100 (True: 9, Index: 522)...
#   Success! Adv label: 4, L2: 82.14, Queries: 9
# Attacking sample 48/100 (True: 9, Index: 535)...
#   Success! Adv label: 4, L2: 588.25, Queries: 69
# Attacking sample 49/100 (True: 9, Index: 542)...
#   Success! Adv label: 8, L2: 504.29, Queries: 59
# Attacking sample 50/100 (True: 9, Index: 553)...
#   Success! Adv label: 4, L2: 823.07, Queries: 97
# Attacking sample 51/100 (True: 9, Index: 554)...
#   Success! Adv label: 8, L2: 887.75, Queries: 91
# Attacking sample 52/100 (True: 9, Index: 565)...
#   Success! Adv label: 0, L2: 529.24, Queries: 61
# Attacking sample 53/100 (True: 9, Index: 569)...
#   Success! Adv label: 4, L2: 589.06, Queries: 73
# Attacking sample 54/100 (True: 9, Index: 572)...
#   Success! Adv label: 5, L2: 483.48, Queries: 57
# Attacking sample 55/100 (True: 9, Index: 574)...
#   Success! Adv label: 8, L2: 538.59, Queries: 61
# Attacking sample 56/100 (True: 9, Index: 601)...
#   Success! Adv label: 8, L2: 433.93, Queries: 43
# Attacking sample 57/100 (True: 9, Index: 634)...
#   Success! Adv label: 5, L2: 546.52, Queries: 59
# Attacking sample 58/100 (True: 9, Index: 635)...
#   Success! Adv label: 4, L2: 799.25, Queries: 99
# Attacking sample 59/100 (True: 9, Index: 637)...
#   Success! Adv label: 4, L2: 681.98, Queries: 75
# Attacking sample 60/100 (True: 9, Index: 640)...
#   Success! Adv label: 4, L2: 632.59, Queries: 71
# Attacking sample 61/100 (True: 9, Index: 653)...
#   Success! Adv label: 8, L2: 622.44, Queries: 63
# Attacking sample 62/100 (True: 9, Index: 654)...
#   Success! Adv label: 4, L2: 676.49, Queries: 81
# Attacking sample 63/100 (True: 9, Index: 656)...
#   Success! Adv label: 4, L2: 672.44, Queries: 75
# Attacking sample 64/100 (True: 9, Index: 666)...
#   Success! Adv label: 4, L2: 489.92, Queries: 59
# Attacking sample 65/100 (True: 9, Index: 685)...
#   Success! Adv label: 7, L2: 733.99, Queries: 89
# Attacking sample 66/100 (True: 9, Index: 711)...
#   Success! Adv label: 4, L2: 314.45, Queries: 33
# Attacking sample 67/100 (True: 9, Index: 729)...
#   Success! Adv label: 8, L2: 550.01, Queries: 57
# Attacking sample 68/100 (True: 9, Index: 739)...
#   Success! Adv label: 4, L2: 512.14, Queries: 59
# Attacking sample 69/100 (True: 9, Index: 747)...
#   Success! Adv label: 8, L2: 426.99, Queries: 43
# Attacking sample 70/100 (True: 9, Index: 767)...
#   Success! Adv label: 8, L2: 580.37, Queries: 65
# Attacking sample 71/100 (True: 9, Index: 783)...
#   Success! Adv label: 5, L2: 743.93, Queries: 91
# Attacking sample 72/100 (True: 9, Index: 787)...
#   Success! Adv label: 8, L2: 644.48, Queries: 65
# Attacking sample 73/100 (True: 9, Index: 796)...
#   Success! Adv label: 7, L2: 497.52, Queries: 55
# Attacking sample 74/100 (True: 9, Index: 804)...
#   Success! Adv label: 7, L2: 675.66, Queries: 91
# Attacking sample 75/100 (True: 9, Index: 818)...
#   Success! Adv label: 4, L2: 717.59, Queries: 85
# Attacking sample 76/100 (True: 9, Index: 825)...
#   Success! Adv label: 8, L2: 414.98, Queries: 43
# Attacking sample 77/100 (True: 9, Index: 826)...
#   Success! Adv label: 7, L2: 251.63, Queries: 29
# Attacking sample 78/100 (True: 9, Index: 831)...
#   Success! Adv label: 4, L2: 608.30, Queries: 67
# Attacking sample 79/100 (True: 9, Index: 880)...
#   Success! Adv label: 5, L2: 796.96, Queries: 89
# Attacking sample 80/100 (True: 9, Index: 884)...
#   Success! Adv label: 4, L2: 603.03, Queries: 65
# Attacking sample 81/100 (True: 9, Index: 891)...
#   Success! Adv label: 4, L2: 174.37, Queries: 19
# Attacking sample 82/100 (True: 9, Index: 893)...
#   Success! Adv label: 2, L2: 799.77, Queries: 105
# Attacking sample 83/100 (True: 9, Index: 899)...
#   Success! Adv label: 4, L2: 564.10, Queries: 67
# Attacking sample 84/100 (True: 9, Index: 912)...
#   Success! Adv label: 5, L2: 669.71, Queries: 75
# Attacking sample 85/100 (True: 9, Index: 920)...
#   Success! Adv label: 4, L2: 743.17, Queries: 83
# Attacking sample 86/100 (True: 9, Index: 925)...
#   Success! Adv label: 8, L2: 454.94, Queries: 45
# Attacking sample 87/100 (True: 9, Index: 940)...
#   Success! Adv label: 4, L2: 424.44, Queries: 51
# Attacking sample 88/100 (True: 9, Index: 958)...
#   Success! Adv label: 4, L2: 612.82, Queries: 65
# Attacking sample 89/100 (True: 9, Index: 969)...
#   Success! Adv label: 8, L2: 443.62, Queries: 43
# Attacking sample 90/100 (True: 9, Index: 978)...
#   Success! Adv label: 4, L2: 619.74, Queries: 79
# Attacking sample 91/100 (True: 9, Index: 979)...
#   Success! Adv label: 4, L2: 543.07, Queries: 57
# Attacking sample 92/100 (True: 9, Index: 980)...
#   Success! Adv label: 8, L2: 400.83, Queries: 43
# Attacking sample 93/100 (True: 9, Index: 991)...
#   Success! Adv label: 7, L2: 559.29, Queries: 71
# Attacking sample 94/100 (True: 9, Index: 997)...
#   Success! Adv label: 4, L2: 289.52, Queries: 35
# Attacking sample 95/100 (True: 9, Index: 1006)...
#   Success! Adv label: 7, L2: 619.44, Queries: 81
# Attacking sample 96/100 (True: 9, Index: 1011)...
#   Failed! Adv label: 9, L2: 943.91, Queries: 201
# Attacking sample 97/100 (True: 9, Index: 1020)...
#   Success! Adv label: 8, L2: 552.09, Queries: 61
# Attacking sample 98/100 (True: 9, Index: 1023)...
#   Failed! Adv label: 9, L2: 868.70, Queries: 201
# Attacking sample 99/100 (True: 9, Index: 1042)...
#   Success! Adv label: 4, L2: 415.69, Queries: 41
# Attacking sample 100/100 (True: 9, Index: 1046)...
#   Success! Adv label: 4, L2: 400.12, Queries: 43
# Time taken to generate adversarial samples: 182.3965 seconds
#
# Stats saved to: adversarial_8bit_K100_test_images\per_sample_stats.csv
#
# ===== Attack Summary =====
# Total trials: 986
# Misclassified before attack: 14
# Success rate: 844/986 (85.6%)
# Mean L2 (successful): 608.60
# Mean queries (successful): 69.06
#
# Showing successful adversarial examples...

# %% [markdown]
# ### Untargeted Attack on test set; k=110

# %%
import os
import warnings
import numpy as np
import torch
import joblib
import pandas as pd
from PIL import Image
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import torch.nn.functional as F
import time


# Set seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# ─────────────── PATHS ────────────────────────────────────────────────────
LENET_MODEL_PATH = os.path.normpath("Models and Data splits/lenet.pt")  # TorchScript model
DATA_PKL = os.path.normpath("Models and Data splits/data_[SCALED] Train_Test_Splits.pkl")
RF_ALL_CLASSES_PATH = os.path.normpath("Models and Data splits/random_forest.pkl")
OUT_DIR = "adversarial_8bit_K110_test_images"
os.makedirs(OUT_DIR, exist_ok=True)

if not os.path.exists(RF_ALL_CLASSES_PATH):
    raise FileNotFoundError(f"Random Forest model not found at {RF_ALL_CLASSES_PATH}")

# ─────────── HYPER-PARAMETERS ─────────────────────────────────────────────
EPSILON_STEP = 0.01
ITERATIONS = 100
TOTAL_EPSILON = 0.5
TOP_K_FEATURES = 110
SAMPLES_PER_DIGIT = 100
MAX_L2 = 10000

def plot_adversarial_example(original_img, adv_img, true_label, adv_label, l2_mag, sample_idx, queries, title_suffix=""):
    if original_img.size == 784:
        original_img = original_img.reshape(28, 28)
    if adv_img.size == 784:
        adv_img = adv_img.reshape(28, 28)
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(original_img, cmap='gray')
    axes[0].set_title(f"Original\nTrue: {true_label}")
    axes[0].axis('off')
    axes[1].imshow(adv_img, cmap='gray')
    axes[1].set_title(f"Adversarial\nPred: {adv_label}")
    axes[1].axis('off')
    fig.suptitle(f"Sample {sample_idx} | L2: {l2_mag:.2f} | Queries: {queries} {title_suffix}")
    plt.show()
    plt.close(fig)  # <-- added here


# ─────────── Load Data ─────────────────────────────────────────────────────
try:
    data = joblib.load(DATA_PKL)
    _, X_samples , _, y_samples = data
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PKL}. Please check the path.")
    exit()

if X_samples.max() > 1.0:
    X_samples = X_samples.astype(np.float32) / 255.0
    warnings.warn("Data appeared in [0,255]; normalized to [0,1].")

# ─────────── Load TorchScripted LeNet ──────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
try:
    model = torch.jit.load(LENET_MODEL_PATH, map_location=device)
    model.eval()
    print(f"LeNet TorchScript model loaded from: {LENET_MODEL_PATH}")
except Exception as e:
    print(f"Error loading TorchScript LeNet model: {e}")
    exit()

def to_model(x01_batch):
    if x01_batch.ndim == 2 and x01_batch.shape == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)
    elif x01_batch.ndim == 3 and x01_batch.shape[1:] == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(1)
    elif x01_batch.ndim == 4 and x01_batch.shape[1] == 1:
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device)
    elif x01_batch.ndim == 1 and x01_batch.size == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(1, 1, 28, 28), dtype=torch.float32, device=device)
    elif x01_batch.ndim == 2 and x01_batch.shape[1] == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(x01_batch.shape[0], 1, 28, 28), dtype=torch.float32, device=device)
    else:
        raise ValueError(f"Unsupported input shape for to_model: {x01_batch.shape}")
    return tensor_batch


def model_query(x_tensor_batch):
    with torch.no_grad():
        return model(x_tensor_batch)

# ─────────── Load Random Forest Model ──────────────────────────────────────
rf_all_classes = None
top_feature_indices = None
print("Loading Random Forest Classifier for all classes...")
try:
    rf_all_classes = joblib.load(RF_ALL_CLASSES_PATH)
    feature_importances = rf_all_classes.feature_importances_
    #top_feature_indices = np.argsort(feature_importances)[:TOP_K_FEATURES]
    
    top_feature_indices = np.argsort(-feature_importances)[:TOP_K_FEATURES]
    print(f"Random Forest loaded. Using top {TOP_K_FEATURES} features.")
except Exception as e:
    print(f"Error loading Random Forest: {e}")
    top_feature_indices = np.arange(28 * 28)

# ─────────── I-FGSM Attack ─────────────────────────────────────────────────
def ifgsm_attack(original_image_np, true_label, model_target, epsilon_step, iterations,
                 total_epsilon_budget, features_to_perturb, query_count_tracker):
    if original_image_np.ndim == 1 and original_image_np.size == 784:
        original_image_np = original_image_np.reshape(28, 28)

    perturbed_image_np = original_image_np.copy()
    final_pred_label = true_label

    for i in range(iterations):
        image_tensor = to_model(perturbed_image_np)
        image_tensor.requires_grad = True
        output = model_target(image_tensor)
        query_count_tracker[0] += 1
        loss = F.cross_entropy(output, torch.tensor([true_label], device=device))
        model_target.zero_grad()
        loss.backward()
        data_grad_sign = torch.sign(image_tensor.grad.data).cpu().numpy()

        gradient_mask = np.zeros_like(data_grad_sign, dtype=np.float32)
        h, w = perturbed_image_np.shape
        rows, cols = np.unravel_index(features_to_perturb, (h, w))
        gradient_mask[0, 0, rows, cols] = data_grad_sign[0, 0, rows, cols]
        gradient_mask_for_update = gradient_mask.reshape(perturbed_image_np.shape)

        perturbed_image_np += epsilon_step * gradient_mask_for_update
        perturbation = perturbed_image_np - original_image_np
        perturbation = np.clip(perturbation, -total_epsilon_budget, total_epsilon_budget)
        perturbed_image_np = original_image_np + perturbation
        perturbed_image_np = np.clip(perturbed_image_np, 0, 1)

        # Discretize and check prediction on discretized image
        adv_uint8_temp = np.round(perturbed_image_np * 255).astype(np.uint8)
        adv_float_temp = adv_uint8_temp.astype(np.float32) / 255.0
        with torch.no_grad():
            output_temp = model_target(to_model(adv_float_temp))
            pred_temp = output_temp.argmax(dim=1).item()
            query_count_tracker[0] += 1

        if pred_temp != true_label:
            final_pred_label = pred_temp
            break

    # Final adversarial image (discretized)
    adv_uint8 = np.round(perturbed_image_np * 255).astype(np.uint8)
    adv_float = adv_uint8.astype(np.float32) / 255.0
    with torch.no_grad():
        output_final = model_target(to_model(adv_float))
        final_pred_label = output_final.argmax(dim=1).item()

    l2_norm = np.linalg.norm(adv_uint8.astype(np.float32) - (original_image_np * 255).astype(np.float32))
    success = (final_pred_label != true_label) and (l2_norm <= MAX_L2)

    return adv_uint8, final_pred_label, l2_norm, success


# ─────────── Attack Execution ──────────────────────────────────────────────
print(f"\n===== Starting Adversarial Attack =====")
total_trials, succ_total, misclassified = 0, 0, 0
records = []


start_time = time.time()


for digit in range(10):
    idxs = np.where(y_samples == digit)[0][:SAMPLES_PER_DIGIT]
    for rank, idx in enumerate(idxs, 1):
        x0 = X_samples[idx].copy()
        y0 = int(y_samples[idx])
        query_count_tracker = [0]
        pred0 = model_query(to_model(x0)).argmax(dim=1).item()
        query_count_tracker[0] += 1

        if pred0 != y0:
            misclassified += 1
            records.append({
                'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
                'adv_label': None, 'success': False, 'queries': query_count_tracker[0],
                'l2_mag': np.nan, 'note': 'Already misclassified'
            })
            continue

        total_trials += 1
        print(f"Attacking sample {rank}/{SAMPLES_PER_DIGIT} (True: {y0}, Index: {idx})...")
        adv_img_uint8, adv_label, l2_mag, success = ifgsm_attack(
            x0, y0, model, EPSILON_STEP, ITERATIONS, TOTAL_EPSILON,
            top_feature_indices, query_count_tracker
        )

        if success:
            succ_total += 1
            fname = f"true{y0}_adv{adv_label}_mag{l2_mag:.1f}_sample{idx}.png"
            Image.fromarray(adv_img_uint8, mode="L").save(os.path.join(OUT_DIR, fname))

        records.append({
            'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
            'adv_label': adv_label, 'success': success, 'queries': query_count_tracker[0],
            'l2_mag': l2_mag if success else np.nan, 'note': 'I-FGSM' + (' successful' if success else ' failed')
        })

        print(f"  {'Success' if success else 'Failed'}! Adv label: {adv_label}, L2: {l2_mag:.2f}, Queries: {query_count_tracker[0]}")


end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to generate adversarial samples: {elapsed_time:.4f} seconds")


# ─────────── Save Results ──────────────────────────────────────────────────
df = pd.DataFrame(records)
csv_path = os.path.join(OUT_DIR, "per_sample_stats.csv")
df.to_csv(csv_path, index=False)
print(f"\nStats saved to: {csv_path}")

# ─────────── Summary ───────────────────────────────────────────────────────
print(f"\n===== Attack Summary =====")
print(f"Total trials: {total_trials}")
print(f"Misclassified before attack: {misclassified}")
if total_trials > 0:
    success_rate = succ_total / total_trials * 100
    print(f"Success rate: {succ_total}/{total_trials} ({success_rate:.1f}%)")
    if succ_total > 0:
        print(f"Mean L2 (successful): {df[df['success']]['l2_mag'].mean():.2f}")
        print(f"Mean queries (successful): {df[df['success']]['queries'].mean():.2f}")

# ─────────── Display Examples ──────────────────────────────────────────────
success_df = df[df['success']]
if not success_df.empty:
    print("\nShowing successful adversarial examples...")
    show_ids = success_df.sample(min(3, len(success_df))).index.tolist()
    for record_idx in show_ids:
        r = df.loc[record_idx]
        fname_prefix = f"true{r['true_label']}_adv{r['adv_label']}_mag{r['l2_mag']:.1f}_sample{r['sample_idx']}"
        match_files = [f for f in os.listdir(OUT_DIR) if f.startswith(fname_prefix)]
        if match_files:
            adv_img_path = os.path.join(OUT_DIR, match_files[0])
            plot_adversarial_example(X_samples[r['sample_idx']], np.array(Image.open(adv_img_path)),
                                     r['true_label'], r['adv_label'], r['l2_mag'],
                                     r['sample_idx'], r['queries'], "(I-FGSM)")
else:
    print("No successful attacks to display. Showing original samples instead.")
    for i in range(min(3, len(df))):
        r = df.iloc[i]
        plot_adversarial_example(X_samples[r['sample_idx']], X_samples[r['sample_idx']],
                                 r['true_label'], r['initial_pred'], 0.0,
                                 r['sample_idx'], r['queries'], "(Original)")
# Out:
# LeNet TorchScript model loaded from: Models and Data splits\lenet.pt
# Loading Random Forest Classifier for all classes...
# Random Forest loaded. Using top 110 features.
#
# ===== Starting Adversarial Attack =====
# Attacking sample 1/100 (True: 0, Index: 29)...
#   Success! Adv label: 6, L2: 953.78, Queries: 147
# Attacking sample 2/100 (True: 0, Index: 40)...
#   Failed! Adv label: 0, L2: 925.08, Queries: 201
# Attacking sample 3/100 (True: 0, Index: 44)...
#   Success! Adv label: 5, L2: 718.24, Queries: 79
# Attacking sample 4/100 (True: 0, Index: 59)...
#   Success! Adv label: 6, L2: 773.45, Queries: 79
# Attacking sample 5/100 (True: 0, Index: 64)...
#   Failed! Adv label: 0, L2: 1082.66, Queries: 201
# Attacking sample 6/100 (True: 0, Index: 75)...
#   Success! Adv label: 8, L2: 724.32, Queries: 81
# Attacking sample 7/100 (True: 0, Index: 80)...
#   Success! Adv label: 9, L2: 763.56, Queries: 89
# Attacking sample 8/100 (True: 0, Index: 97)...
#   Success! Adv label: 6, L2: 870.57, Queries: 135
# Attacking sample 9/100 (True: 0, Index: 115)...
#   Success! Adv label: 6, L2: 897.45, Queries: 97
# Attacking sample 10/100 (True: 0, Index: 141)...
#   Success! Adv label: 7, L2: 238.45, Queries: 25
# Attacking sample 11/100 (True: 0, Index: 146)...
#   Success! Adv label: 9, L2: 706.39, Queries: 81
# Attacking sample 12/100 (True: 0, Index: 156)...
#   Failed! Adv label: 0, L2: 780.28, Queries: 201
# Attacking sample 13/100 (True: 0, Index: 173)...
#   Success! Adv label: 3, L2: 734.83, Queries: 91
# Attacking sample 14/100 (True: 0, Index: 175)...
#   Success! Adv label: 8, L2: 477.62, Queries: 51
# Attacking sample 15/100 (True: 0, Index: 193)...
#   Failed! Adv label: 0, L2: 859.56, Queries: 201
# Attacking sample 16/100 (True: 0, Index: 200)...
#   Success! Adv label: 9, L2: 693.20, Queries: 81
# Attacking sample 17/100 (True: 0, Index: 205)...
#   Success! Adv label: 9, L2: 823.96, Queries: 99
# Attacking sample 18/100 (True: 0, Index: 210)...
#   Success! Adv label: 8, L2: 730.25, Queries: 83
# Attacking sample 19/100 (True: 0, Index: 221)...
#   Success! Adv label: 3, L2: 687.06, Queries: 77
# Attacking sample 20/100 (True: 0, Index: 229)...
#   Failed! Adv label: 0, L2: 824.82, Queries: 201
# Attacking sample 21/100 (True: 0, Index: 249)...
#   Failed! Adv label: 0, L2: 746.08, Queries: 201
# Attacking sample 22/100 (True: 0, Index: 258)...
#   Success! Adv label: 8, L2: 855.36, Queries: 95
# Attacking sample 23/100 (True: 0, Index: 275)...
#   Failed! Adv label: 0, L2: 933.21, Queries: 201
# Attacking sample 24/100 (True: 0, Index: 292)...
#   Failed! Adv label: 0, L2: 790.37, Queries: 201
# Attacking sample 25/100 (True: 0, Index: 296)...
#   Success! Adv label: 9, L2: 705.35, Queries: 77
# Attacking sample 26/100 (True: 0, Index: 301)...
#   Success! Adv label: 9, L2: 727.24, Queries: 81
# Attacking sample 27/100 (True: 0, Index: 314)...
#   Success! Adv label: 6, L2: 727.47, Queries: 75
# Attacking sample 28/100 (True: 0, Index: 325)...
#   Failed! Adv label: 0, L2: 918.23, Queries: 201
# Attacking sample 29/100 (True: 0, Index: 333)...
#   Success! Adv label: 9, L2: 842.61, Queries: 129
# Attacking sample 30/100 (True: 0, Index: 345)...
#   Success! Adv label: 6, L2: 658.09, Queries: 67
# Attacking sample 31/100 (True: 0, Index: 349)...
#   Success! Adv label: 9, L2: 669.93, Queries: 73
# Attacking sample 32/100 (True: 0, Index: 360)...
#   Failed! Adv label: 0, L2: 992.80, Queries: 201
# Attacking sample 33/100 (True: 0, Index: 365)...
#   Success! Adv label: 9, L2: 855.97, Queries: 145
# Attacking sample 34/100 (True: 0, Index: 366)...
#   Success! Adv label: 8, L2: 830.30, Queries: 89
# Attacking sample 35/100 (True: 0, Index: 379)...
#   Success! Adv label: 8, L2: 917.04, Queries: 101
# Attacking sample 36/100 (True: 0, Index: 385)...
#   Failed! Adv label: 0, L2: 982.33, Queries: 201
# Attacking sample 37/100 (True: 0, Index: 397)...
#   Failed! Adv label: 0, L2: 789.32, Queries: 201
# Attacking sample 38/100 (True: 0, Index: 400)...
#   Failed! Adv label: 0, L2: 988.90, Queries: 201
# Attacking sample 39/100 (True: 0, Index: 405)...
#   Success! Adv label: 2, L2: 852.61, Queries: 91
# Attacking sample 40/100 (True: 0, Index: 410)...
#   Success! Adv label: 9, L2: 842.03, Queries: 107
# Attacking sample 41/100 (True: 0, Index: 420)...
#   Failed! Adv label: 0, L2: 870.14, Queries: 201
# Attacking sample 42/100 (True: 0, Index: 424)...
#   Failed! Adv label: 0, L2: 895.11, Queries: 201
# Attacking sample 43/100 (True: 0, Index: 447)...
#   Success! Adv label: 2, L2: 720.03, Queries: 83
# Attacking sample 44/100 (True: 0, Index: 453)...
#   Success! Adv label: 2, L2: 833.83, Queries: 95
# Attacking sample 45/100 (True: 0, Index: 457)...
#   Success! Adv label: 6, L2: 1017.28, Queries: 181
# Attacking sample 46/100 (True: 0, Index: 466)...
#   Success! Adv label: 2, L2: 867.09, Queries: 95
# Attacking sample 47/100 (True: 0, Index: 475)...
#   Success! Adv label: 9, L2: 284.66, Queries: 29
# Attacking sample 48/100 (True: 0, Index: 483)...
#   Failed! Adv label: 0, L2: 960.37, Queries: 201
# Attacking sample 49/100 (True: 0, Index: 484)...
#   Success! Adv label: 8, L2: 513.82, Queries: 47
# Attacking sample 50/100 (True: 0, Index: 486)...
#   Failed! Adv label: 0, L2: 902.13, Queries: 201
# Attacking sample 51/100 (True: 0, Index: 487)...
#   Success! Adv label: 6, L2: 698.84, Queries: 77
# Attacking sample 52/100 (True: 0, Index: 489)...
#   Success! Adv label: 9, L2: 759.96, Queries: 83
# Attacking sample 53/100 (True: 0, Index: 492)...
#   Success! Adv label: 9, L2: 828.49, Queries: 91
# Attacking sample 54/100 (True: 0, Index: 506)...
#   Failed! Adv label: 0, L2: 1021.05, Queries: 201
# Attacking sample 55/100 (True: 0, Index: 513)...
#   Failed! Adv label: 0, L2: 936.78, Queries: 201
# Attacking sample 56/100 (True: 0, Index: 518)...
#   Failed! Adv label: 0, L2: 898.10, Queries: 201
# Attacking sample 57/100 (True: 0, Index: 521)...
#   Failed! Adv label: 0, L2: 929.07, Queries: 201
# Attacking sample 58/100 (True: 0, Index: 527)...
#   Success! Adv label: 2, L2: 780.17, Queries: 87
# Attacking sample 59/100 (True: 0, Index: 529)...
#   Failed! Adv label: 0, L2: 738.88, Queries: 201
# Attacking sample 60/100 (True: 0, Index: 531)...
#   Success! Adv label: 8, L2: 1024.84, Queries: 157
# Attacking sample 61/100 (True: 0, Index: 546)...
#   Success! Adv label: 9, L2: 634.25, Queries: 73
# Attacking sample 62/100 (True: 0, Index: 551)...
#   Success! Adv label: 6, L2: 445.74, Queries: 41
# Attacking sample 63/100 (True: 0, Index: 555)...
#   Success! Adv label: 6, L2: 1021.95, Queries: 129
# Attacking sample 64/100 (True: 0, Index: 587)...
#   Success! Adv label: 8, L2: 858.41, Queries: 95
# Attacking sample 65/100 (True: 0, Index: 604)...
#   Success! Adv label: 8, L2: 691.31, Queries: 67
# Attacking sample 66/100 (True: 0, Index: 614)...
#   Success! Adv label: 8, L2: 854.95, Queries: 93
# Attacking sample 67/100 (True: 0, Index: 615)...
#   Success! Adv label: 9, L2: 464.19, Queries: 45
# Attacking sample 68/100 (True: 0, Index: 618)...
#   Success! Adv label: 6, L2: 322.47, Queries: 31
# Attacking sample 69/100 (True: 0, Index: 638)...
#   Success! Adv label: 8, L2: 429.88, Queries: 41
# Attacking sample 70/100 (True: 0, Index: 642)...
#   Success! Adv label: 9, L2: 841.03, Queries: 117
# Attacking sample 71/100 (True: 0, Index: 655)...
#   Success! Adv label: 6, L2: 837.61, Queries: 85
# Attacking sample 72/100 (True: 0, Index: 658)...
#   Success! Adv label: 6, L2: 760.57, Queries: 79
# Attacking sample 73/100 (True: 0, Index: 665)...
#   Success! Adv label: 2, L2: 688.30, Queries: 75
# Attacking sample 74/100 (True: 0, Index: 671)...
#   Success! Adv label: 6, L2: 821.58, Queries: 89
# Attacking sample 75/100 (True: 0, Index: 681)...
#   Success! Adv label: 9, L2: 886.74, Queries: 101
# Attacking sample 76/100 (True: 0, Index: 691)...
#   Success! Adv label: 2, L2: 893.78, Queries: 95
# Attacking sample 77/100 (True: 0, Index: 700)...
#   Success! Adv label: 8, L2: 673.40, Queries: 77
# Attacking sample 78/100 (True: 0, Index: 706)...
#   Failed! Adv label: 0, L2: 736.66, Queries: 201
# Attacking sample 79/100 (True: 0, Index: 712)...
#   Success! Adv label: 3, L2: 875.20, Queries: 137
# Attacking sample 80/100 (True: 0, Index: 713)...
#   Success! Adv label: 9, L2: 785.49, Queries: 83
# Attacking sample 81/100 (True: 0, Index: 736)...
#   Success! Adv label: 9, L2: 780.36, Queries: 95
# Attacking sample 82/100 (True: 0, Index: 742)...
#   Success! Adv label: 8, L2: 697.49, Queries: 77
# Attacking sample 83/100 (True: 0, Index: 744)...
#   Success! Adv label: 2, L2: 623.49, Queries: 67
# Attacking sample 84/100 (True: 0, Index: 760)...
#   Success! Adv label: 9, L2: 650.06, Queries: 75
# Attacking sample 85/100 (True: 0, Index: 772)...
#   Success! Adv label: 9, L2: 340.85, Queries: 33
# Attacking sample 86/100 (True: 0, Index: 781)...
#   Success! Adv label: 6, L2: 512.78, Queries: 51
# Attacking sample 87/100 (True: 0, Index: 809)...
#   Failed! Adv label: 0, L2: 766.71, Queries: 201
# Attacking sample 88/100 (True: 0, Index: 813)...
#   Success! Adv label: 9, L2: 494.95, Queries: 55
# Attacking sample 89/100 (True: 0, Index: 820)...
#   Failed! Adv label: 0, L2: 882.75, Queries: 201
# Attacking sample 90/100 (True: 0, Index: 823)...
#   Success! Adv label: 9, L2: 673.71, Queries: 85
# Attacking sample 91/100 (True: 0, Index: 844)...
#   Failed! Adv label: 0, L2: 1072.97, Queries: 201
# Attacking sample 92/100 (True: 0, Index: 848)...
#   Success! Adv label: 9, L2: 302.86, Queries: 29
# Attacking sample 93/100 (True: 0, Index: 861)...
#   Success! Adv label: 8, L2: 1091.95, Queries: 165
# Attacking sample 94/100 (True: 0, Index: 865)...
#   Failed! Adv label: 0, L2: 1140.04, Queries: 201
# Attacking sample 95/100 (True: 0, Index: 869)...
#   Failed! Adv label: 0, L2: 1060.92, Queries: 201
# Attacking sample 96/100 (True: 0, Index: 876)...
#   Success! Adv label: 9, L2: 718.37, Queries: 75
# Attacking sample 97/100 (True: 0, Index: 885)...
#   Failed! Adv label: 0, L2: 923.94, Queries: 201
# Attacking sample 98/100 (True: 0, Index: 906)...
#   Failed! Adv label: 0, L2: 1025.85, Queries: 201
# Attacking sample 99/100 (True: 0, Index: 907)...
#   Failed! Adv label: 0, L2: 1000.22, Queries: 201
# Attacking sample 100/100 (True: 0, Index: 918)...
#   Failed! Adv label: 0, L2: 925.99, Queries: 201
# Attacking sample 1/100 (True: 1, Index: 2)...
#   Success! Adv label: 7, L2: 380.38, Queries: 35
# Attacking sample 2/100 (True: 1, Index: 3)...
#   Success! Adv label: 7, L2: 447.50, Queries: 41
# Attacking sample 3/100 (True: 1, Index: 9)...
#   Success! Adv label: 2, L2: 379.61, Queries: 37
# Attacking sample 4/100 (True: 1, Index: 25)...
#   Success! Adv label: 4, L2: 390.04, Queries: 33
# Attacking sample 5/100 (True: 1, Index: 36)...
#   Success! Adv label: 2, L2: 358.54, Queries: 33
# Attacking sample 6/100 (True: 1, Index: 63)...
#   Success! Adv label: 8, L2: 358.60, Queries: 35
# Attacking sample 7/100 (True: 1, Index: 65)...
#   Success! Adv label: 8, L2: 421.28, Queries: 37
# Attacking sample 8/100 (True: 1, Index: 68)...
#   Success! Adv label: 4, L2: 412.19, Queries: 37
# Attacking sample 9/100 (True: 1, Index: 76)...
#   Success! Adv label: 8, L2: 283.76, Queries: 27
# Attacking sample 10/100 (True: 1, Index: 83)...
#   Success! Adv label: 4, L2: 408.81, Queries: 37
# Attacking sample 11/100 (True: 1, Index: 90)...
#   Success! Adv label: 9, L2: 26.74, Queries: 3
# Attacking sample 12/100 (True: 1, Index: 94)...
#   Success! Adv label: 8, L2: 250.34, Queries: 23
# Attacking sample 13/100 (True: 1, Index: 100)...
#   Success! Adv label: 8, L2: 318.60, Queries: 29
# Attacking sample 14/100 (True: 1, Index: 123)...
#   Success! Adv label: 8, L2: 252.09, Queries: 23
# Attacking sample 15/100 (True: 1, Index: 150)...
#   Success! Adv label: 4, L2: 442.29, Queries: 39
# Attacking sample 16/100 (True: 1, Index: 152)...
#   Success! Adv label: 9, L2: 407.35, Queries: 37
# Attacking sample 17/100 (True: 1, Index: 178)...
#   Success! Adv label: 4, L2: 420.68, Queries: 37
# Attacking sample 18/100 (True: 1, Index: 185)...
#   Success! Adv label: 8, L2: 452.68, Queries: 45
# Attacking sample 19/100 (True: 1, Index: 191)...
#   Success! Adv label: 4, L2: 429.62, Queries: 39
# Attacking sample 20/100 (True: 1, Index: 201)...
#   Success! Adv label: 8, L2: 370.69, Queries: 33
# Attacking sample 21/100 (True: 1, Index: 203)...
#   Success! Adv label: 4, L2: 309.87, Queries: 27
# Attacking sample 22/100 (True: 1, Index: 213)...
#   Success! Adv label: 8, L2: 340.58, Queries: 31
# Attacking sample 23/100 (True: 1, Index: 220)...
#   Success! Adv label: 8, L2: 313.93, Queries: 27
# Attacking sample 24/100 (True: 1, Index: 223)...
#   Success! Adv label: 4, L2: 402.66, Queries: 35
# Attacking sample 25/100 (True: 1, Index: 226)...
#   Success! Adv label: 4, L2: 356.13, Queries: 31
# Attacking sample 26/100 (True: 1, Index: 232)...
#   Success! Adv label: 4, L2: 486.16, Queries: 41
# Attacking sample 27/100 (True: 1, Index: 241)...
#   Success! Adv label: 4, L2: 301.00, Queries: 27
# Attacking sample 28/100 (True: 1, Index: 254)...
#   Success! Adv label: 4, L2: 350.92, Queries: 31
# Attacking sample 29/100 (True: 1, Index: 281)...
#   Success! Adv label: 8, L2: 334.28, Queries: 31
# Attacking sample 30/100 (True: 1, Index: 284)...
#   Success! Adv label: 8, L2: 399.93, Queries: 37
# Attacking sample 31/100 (True: 1, Index: 285)...
#   Success! Adv label: 9, L2: 248.29, Queries: 23
# Attacking sample 32/100 (True: 1, Index: 286)...
#   Success! Adv label: 4, L2: 340.83, Queries: 31
# Attacking sample 33/100 (True: 1, Index: 287)...
#   Success! Adv label: 4, L2: 328.56, Queries: 31
# Attacking sample 34/100 (True: 1, Index: 294)...
#   Success! Adv label: 4, L2: 424.49, Queries: 37
# Attacking sample 35/100 (True: 1, Index: 298)...
#   Success! Adv label: 4, L2: 475.49, Queries: 43
# Attacking sample 36/100 (True: 1, Index: 306)...
#   Success! Adv label: 4, L2: 447.82, Queries: 39
# Attacking sample 37/100 (True: 1, Index: 312)...
#   Success! Adv label: 8, L2: 419.23, Queries: 41
# Attacking sample 38/100 (True: 1, Index: 317)...
#   Success! Adv label: 4, L2: 380.42, Queries: 35
# Attacking sample 39/100 (True: 1, Index: 334)...
#   Success! Adv label: 4, L2: 434.04, Queries: 37
# Attacking sample 40/100 (True: 1, Index: 337)...
#   Success! Adv label: 8, L2: 456.50, Queries: 39
# Attacking sample 41/100 (True: 1, Index: 338)...
#   Success! Adv label: 4, L2: 503.67, Queries: 45
# Attacking sample 42/100 (True: 1, Index: 348)...
#   Success! Adv label: 4, L2: 528.16, Queries: 47
# Attacking sample 43/100 (True: 1, Index: 361)...
#   Success! Adv label: 9, L2: 337.93, Queries: 29
# Attacking sample 44/100 (True: 1, Index: 363)...
#   Success! Adv label: 8, L2: 412.23, Queries: 35
# Attacking sample 45/100 (True: 1, Index: 367)...
#   Success! Adv label: 8, L2: 257.61, Queries: 23
# Attacking sample 46/100 (True: 1, Index: 375)...
#   Success! Adv label: 4, L2: 485.49, Queries: 45
# Attacking sample 47/100 (True: 1, Index: 384)...
#   Success! Adv label: 8, L2: 340.52, Queries: 31
# Attacking sample 48/100 (True: 1, Index: 412)...
#   Success! Adv label: 4, L2: 490.15, Queries: 41
# Attacking sample 49/100 (True: 1, Index: 425)...
#   Success! Adv label: 9, L2: 459.63, Queries: 41
# Attacking sample 50/100 (True: 1, Index: 428)...
#   Success! Adv label: 4, L2: 425.86, Queries: 37
# Attacking sample 51/100 (True: 1, Index: 463)...
#   Success! Adv label: 4, L2: 293.75, Queries: 27
# Attacking sample 52/100 (True: 1, Index: 499)...
#   Success! Adv label: 4, L2: 473.91, Queries: 41
# Attacking sample 53/100 (True: 1, Index: 502)...
#   Success! Adv label: 4, L2: 423.88, Queries: 37
# Attacking sample 54/100 (True: 1, Index: 526)...
#   Success! Adv label: 8, L2: 337.34, Queries: 29
# Attacking sample 55/100 (True: 1, Index: 532)...
#   Success! Adv label: 4, L2: 403.41, Queries: 35
# Attacking sample 56/100 (True: 1, Index: 536)...
#   Success! Adv label: 9, L2: 293.44, Queries: 27
# Attacking sample 57/100 (True: 1, Index: 537)...
#   Success! Adv label: 8, L2: 414.40, Queries: 39
# Attacking sample 58/100 (True: 1, Index: 539)...
#   Success! Adv label: 4, L2: 445.95, Queries: 39
# Attacking sample 60/100 (True: 1, Index: 560)...
#   Success! Adv label: 4, L2: 377.38, Queries: 33
# Attacking sample 61/100 (True: 1, Index: 561)...
#   Success! Adv label: 8, L2: 324.90, Queries: 29
# Attacking sample 62/100 (True: 1, Index: 570)...
#   Success! Adv label: 8, L2: 386.72, Queries: 35
# Attacking sample 63/100 (True: 1, Index: 573)...
#   Success! Adv label: 2, L2: 29.41, Queries: 3
# Attacking sample 64/100 (True: 1, Index: 576)...
#   Success! Adv label: 7, L2: 415.50, Queries: 41
# Attacking sample 65/100 (True: 1, Index: 580)...
#   Success! Adv label: 4, L2: 331.90, Queries: 29
# Attacking sample 66/100 (True: 1, Index: 588)...
#   Success! Adv label: 7, L2: 580.54, Queries: 55
# Attacking sample 67/100 (True: 1, Index: 620)...
#   Success! Adv label: 4, L2: 393.29, Queries: 35
# Attacking sample 68/100 (True: 1, Index: 621)...
#   Success! Adv label: 4, L2: 389.90, Queries: 35
# Attacking sample 69/100 (True: 1, Index: 622)...
#   Success! Adv label: 2, L2: 137.85, Queries: 13
# Attacking sample 70/100 (True: 1, Index: 627)...
#   Success! Adv label: 8, L2: 324.76, Queries: 31
# Attacking sample 71/100 (True: 1, Index: 630)...
#   Success! Adv label: 4, L2: 295.66, Queries: 25
# Attacking sample 72/100 (True: 1, Index: 632)...
#   Success! Adv label: 4, L2: 294.45, Queries: 25
# Attacking sample 73/100 (True: 1, Index: 644)...
#   Success! Adv label: 4, L2: 331.42, Queries: 29
# Attacking sample 74/100 (True: 1, Index: 646)...
#   Success! Adv label: 7, L2: 405.15, Queries: 41
# Attacking sample 75/100 (True: 1, Index: 649)...
#   Success! Adv label: 4, L2: 434.42, Queries: 37
# Attacking sample 76/100 (True: 1, Index: 662)...
#   Success! Adv label: 4, L2: 477.63, Queries: 41
# Attacking sample 77/100 (True: 1, Index: 663)...
#   Success! Adv label: 4, L2: 299.60, Queries: 27
# Attacking sample 78/100 (True: 1, Index: 669)...
#   Success! Adv label: 9, L2: 485.31, Queries: 43
# Attacking sample 79/100 (True: 1, Index: 677)...
#   Success! Adv label: 9, L2: 300.17, Queries: 27
# Attacking sample 80/100 (True: 1, Index: 686)...
#   Success! Adv label: 8, L2: 547.39, Queries: 47
# Attacking sample 81/100 (True: 1, Index: 689)...
#   Success! Adv label: 4, L2: 391.85, Queries: 33
# Attacking sample 82/100 (True: 1, Index: 703)...
#   Success! Adv label: 8, L2: 441.35, Queries: 39
# Attacking sample 83/100 (True: 1, Index: 705)...
#   Success! Adv label: 4, L2: 519.87, Queries: 49
# Attacking sample 84/100 (True: 1, Index: 709)...
#   Success! Adv label: 4, L2: 333.10, Queries: 31
# Attacking sample 85/100 (True: 1, Index: 724)...
#   Success! Adv label: 4, L2: 258.35, Queries: 23
# Attacking sample 86/100 (True: 1, Index: 727)...
#   Success! Adv label: 8, L2: 381.07, Queries: 33
# Attacking sample 87/100 (True: 1, Index: 734)...
#   Success! Adv label: 8, L2: 257.88, Queries: 25
# Attacking sample 88/100 (True: 1, Index: 740)...
#   Success! Adv label: 4, L2: 383.95, Queries: 33
# Attacking sample 89/100 (True: 1, Index: 741)...
#   Success! Adv label: 8, L2: 317.10, Queries: 29
# Attacking sample 90/100 (True: 1, Index: 743)...
#   Success! Adv label: 8, L2: 363.71, Queries: 31
# Attacking sample 91/100 (True: 1, Index: 759)...
#   Success! Adv label: 4, L2: 386.07, Queries: 35
# Attacking sample 92/100 (True: 1, Index: 768)...
#   Success! Adv label: 8, L2: 352.95, Queries: 31
# Attacking sample 93/100 (True: 1, Index: 775)...
#   Success! Adv label: 4, L2: 295.04, Queries: 27
# Attacking sample 94/100 (True: 1, Index: 782)...
#   Success! Adv label: 4, L2: 416.36, Queries: 37
# Attacking sample 95/100 (True: 1, Index: 798)...
#   Success! Adv label: 9, L2: 370.98, Queries: 35
# Attacking sample 96/100 (True: 1, Index: 799)...
#   Success! Adv label: 4, L2: 506.30, Queries: 43
# Attacking sample 97/100 (True: 1, Index: 808)...
#   Success! Adv label: 4, L2: 377.74, Queries: 35
# Attacking sample 98/100 (True: 1, Index: 819)...
#   Success! Adv label: 4, L2: 514.77, Queries: 45
# Attacking sample 99/100 (True: 1, Index: 843)...
#   Success! Adv label: 4, L2: 516.17, Queries: 45
# Attacking sample 100/100 (True: 1, Index: 853)...
#   Success! Adv label: 4, L2: 423.81, Queries: 37
# Attacking sample 1/100 (True: 2, Index: 4)...
#   Success! Adv label: 3, L2: 622.27, Queries: 63
# Attacking sample 2/100 (True: 2, Index: 22)...
#   Success! Adv label: 3, L2: 801.03, Queries: 145
# Attacking sample 3/100 (True: 2, Index: 32)...
#   Success! Adv label: 3, L2: 1024.58, Queries: 123
# Attacking sample 4/100 (True: 2, Index: 34)...
#   Success! Adv label: 4, L2: 42.81, Queries: 5
# Attacking sample 5/100 (True: 2, Index: 42)...
#   Success! Adv label: 3, L2: 249.42, Queries: 25
# Attacking sample 6/100 (True: 2, Index: 49)...
#   Success! Adv label: 3, L2: 902.22, Queries: 181
# Attacking sample 7/100 (True: 2, Index: 52)...
#   Success! Adv label: 3, L2: 905.41, Queries: 135
# Attacking sample 8/100 (True: 2, Index: 69)...
#   Success! Adv label: 3, L2: 878.47, Queries: 93
# Attacking sample 9/100 (True: 2, Index: 70)...
#   Success! Adv label: 3, L2: 591.74, Queries: 73
# Attacking sample 10/100 (True: 2, Index: 81)...
#   Success! Adv label: 8, L2: 1116.86, Queries: 157
# Attacking sample 11/100 (True: 2, Index: 110)...
#   Failed! Adv label: 2, L2: 991.07, Queries: 201
# Attacking sample 12/100 (True: 2, Index: 118)...
#   Success! Adv label: 3, L2: 610.03, Queries: 61
# Attacking sample 13/100 (True: 2, Index: 121)...
#   Success! Adv label: 3, L2: 752.07, Queries: 73
# Attacking sample 14/100 (True: 2, Index: 138)...
#   Success! Adv label: 3, L2: 861.06, Queries: 95
# Attacking sample 15/100 (True: 2, Index: 144)...
#   Success! Adv label: 0, L2: 777.66, Queries: 75
# Attacking sample 16/100 (True: 2, Index: 155)...
#   Success! Adv label: 8, L2: 951.65, Queries: 89
# Attacking sample 17/100 (True: 2, Index: 160)...
#   Success! Adv label: 6, L2: 481.45, Queries: 53
# Attacking sample 18/100 (True: 2, Index: 161)...
#   Success! Adv label: 3, L2: 692.82, Queries: 73
# Attacking sample 19/100 (True: 2, Index: 176)...
#   Success! Adv label: 3, L2: 740.02, Queries: 73
# Attacking sample 21/100 (True: 2, Index: 186)...
#   Success! Adv label: 3, L2: 849.12, Queries: 127
# Attacking sample 22/100 (True: 2, Index: 197)...
#   Success! Adv label: 3, L2: 1035.49, Queries: 137
# Attacking sample 23/100 (True: 2, Index: 208)...
#   Success! Adv label: 3, L2: 1005.81, Queries: 143
# Attacking sample 25/100 (True: 2, Index: 216)...
#   Success! Adv label: 3, L2: 839.36, Queries: 99
# Attacking sample 26/100 (True: 2, Index: 219)...
#   Success! Adv label: 3, L2: 448.11, Queries: 49
# Attacking sample 27/100 (True: 2, Index: 235)...
#   Success! Adv label: 3, L2: 831.38, Queries: 95
# Attacking sample 28/100 (True: 2, Index: 260)...
#   Success! Adv label: 0, L2: 640.64, Queries: 65
# Attacking sample 29/100 (True: 2, Index: 276)...
#   Success! Adv label: 4, L2: 634.78, Queries: 77
# Attacking sample 30/100 (True: 2, Index: 293)...
#   Success! Adv label: 3, L2: 721.77, Queries: 87
# Attacking sample 31/100 (True: 2, Index: 295)...
#   Success! Adv label: 3, L2: 604.29, Queries: 65
# Attacking sample 32/100 (True: 2, Index: 311)...
#   Success! Adv label: 3, L2: 568.15, Queries: 59
# Attacking sample 33/100 (True: 2, Index: 313)...
#   Success! Adv label: 3, L2: 155.79, Queries: 17
# Attacking sample 34/100 (True: 2, Index: 322)...
#   Success! Adv label: 0, L2: 777.33, Queries: 85
# Attacking sample 35/100 (True: 2, Index: 328)...
#   Success! Adv label: 8, L2: 804.09, Queries: 81
# Attacking sample 36/100 (True: 2, Index: 357)...
#   Success! Adv label: 7, L2: 564.31, Queries: 59
# Attacking sample 37/100 (True: 2, Index: 374)...
#   Success! Adv label: 8, L2: 571.42, Queries: 57
# Attacking sample 38/100 (True: 2, Index: 395)...
#   Success! Adv label: 8, L2: 439.88, Queries: 47
# Attacking sample 39/100 (True: 2, Index: 396)...
#   Success! Adv label: 8, L2: 739.18, Queries: 75
# Attacking sample 40/100 (True: 2, Index: 398)...
#   Success! Adv label: 3, L2: 802.97, Queries: 89
# Attacking sample 41/100 (True: 2, Index: 433)...
#   Success! Adv label: 3, L2: 730.33, Queries: 75
# Attacking sample 42/100 (True: 2, Index: 439)...
#   Success! Adv label: 9, L2: 824.99, Queries: 83
# Attacking sample 43/100 (True: 2, Index: 441)...
#   Success! Adv label: 8, L2: 413.56, Queries: 37
# Attacking sample 44/100 (True: 2, Index: 442)...
#   Success! Adv label: 3, L2: 935.60, Queries: 99
# Attacking sample 45/100 (True: 2, Index: 451)...
#   Failed! Adv label: 2, L2: 1106.79, Queries: 201
# Attacking sample 46/100 (True: 2, Index: 462)...
#   Success! Adv label: 3, L2: 671.27, Queries: 65
# Attacking sample 47/100 (True: 2, Index: 470)...
#   Success! Adv label: 3, L2: 666.47, Queries: 65
# Attacking sample 48/100 (True: 2, Index: 477)...
#   Success! Adv label: 3, L2: 884.49, Queries: 99
# Attacking sample 49/100 (True: 2, Index: 485)...
#   Success! Adv label: 7, L2: 255.76, Queries: 25
# Attacking sample 50/100 (True: 2, Index: 491)...
#   Success! Adv label: 8, L2: 734.72, Queries: 69
# Attacking sample 51/100 (True: 2, Index: 493)...
#   Success! Adv label: 7, L2: 868.92, Queries: 145
# Attacking sample 52/100 (True: 2, Index: 495)...
#   Success! Adv label: 3, L2: 674.74, Queries: 73
# Attacking sample 53/100 (True: 2, Index: 519)...
#   Success! Adv label: 3, L2: 884.75, Queries: 95
# Attacking sample 54/100 (True: 2, Index: 523)...
#   Success! Adv label: 6, L2: 831.89, Queries: 95
# Attacking sample 55/100 (True: 2, Index: 557)...
#   Success! Adv label: 8, L2: 913.64, Queries: 91
# Attacking sample 56/100 (True: 2, Index: 567)...
#   Success! Adv label: 0, L2: 592.54, Queries: 59
# Attacking sample 57/100 (True: 2, Index: 571)...
#   Success! Adv label: 7, L2: 801.32, Queries: 89
# Attacking sample 58/100 (True: 2, Index: 584)...
#   Success! Adv label: 3, L2: 938.29, Queries: 103
# Attacking sample 59/100 (True: 2, Index: 591)...
#   Success! Adv label: 8, L2: 1028.83, Queries: 153
# Attacking sample 60/100 (True: 2, Index: 592)...
#   Success! Adv label: 3, L2: 824.73, Queries: 123
# Attacking sample 61/100 (True: 2, Index: 610)...
#   Failed! Adv label: 2, L2: 1025.86, Queries: 201
# Attacking sample 62/100 (True: 2, Index: 612)...
#   Success! Adv label: 8, L2: 839.03, Queries: 79
# Attacking sample 63/100 (True: 2, Index: 616)...
#   Success! Adv label: 3, L2: 875.23, Queries: 89
# Attacking sample 64/100 (True: 2, Index: 624)...
#   Success! Adv label: 3, L2: 788.09, Queries: 77
# Attacking sample 65/100 (True: 2, Index: 631)...
#   Success! Adv label: 3, L2: 628.35, Queries: 69
# Attacking sample 66/100 (True: 2, Index: 636)...
#   Success! Adv label: 3, L2: 963.91, Queries: 95
# Attacking sample 67/100 (True: 2, Index: 647)...
#   Success! Adv label: 1, L2: 133.79, Queries: 15
# Attacking sample 68/100 (True: 2, Index: 650)...
#   Success! Adv label: 3, L2: 232.35, Queries: 23
# Attacking sample 69/100 (True: 2, Index: 664)...
#   Failed! Adv label: 2, L2: 1009.75, Queries: 201
# Attacking sample 70/100 (True: 2, Index: 704)...
#   Success! Adv label: 3, L2: 718.12, Queries: 77
# Attacking sample 71/100 (True: 2, Index: 720)...
#   Success! Adv label: 4, L2: 260.49, Queries: 27
# Attacking sample 72/100 (True: 2, Index: 725)...
#   Success! Adv label: 3, L2: 531.99, Queries: 53
# Attacking sample 73/100 (True: 2, Index: 750)...
#   Failed! Adv label: 2, L2: 798.99, Queries: 201
# Attacking sample 74/100 (True: 2, Index: 764)...
#   Success! Adv label: 3, L2: 535.88, Queries: 69
# Attacking sample 75/100 (True: 2, Index: 780)...
#   Success! Adv label: 8, L2: 929.33, Queries: 95
# Attacking sample 76/100 (True: 2, Index: 784)...
#   Success! Adv label: 8, L2: 1007.11, Queries: 101
# Attacking sample 77/100 (True: 2, Index: 788)...
#   Success! Adv label: 1, L2: 622.25, Queries: 63
# Attacking sample 78/100 (True: 2, Index: 790)...
#   Success! Adv label: 3, L2: 933.89, Queries: 153
# Attacking sample 79/100 (True: 2, Index: 797)...
#   Success! Adv label: 8, L2: 615.98, Queries: 61
# Attacking sample 80/100 (True: 2, Index: 803)...
#   Success! Adv label: 0, L2: 1011.80, Queries: 97
# Attacking sample 81/100 (True: 2, Index: 807)...
#   Failed! Adv label: 2, L2: 922.69, Queries: 201
# Attacking sample 82/100 (True: 2, Index: 828)...
#   Success! Adv label: 3, L2: 515.77, Queries: 53
# Attacking sample 83/100 (True: 2, Index: 842)...
#   Success! Adv label: 3, L2: 730.59, Queries: 81
# Attacking sample 84/100 (True: 2, Index: 845)...
#   Success! Adv label: 3, L2: 983.17, Queries: 97
# Attacking sample 85/100 (True: 2, Index: 859)...
#   Success! Adv label: 3, L2: 543.63, Queries: 55
# Attacking sample 86/100 (True: 2, Index: 871)...
#   Success! Adv label: 7, L2: 731.31, Queries: 81
# Attacking sample 87/100 (True: 2, Index: 881)...
#   Success! Adv label: 3, L2: 587.04, Queries: 73
# Attacking sample 88/100 (True: 2, Index: 883)...
#   Success! Adv label: 0, L2: 488.29, Queries: 49
# Attacking sample 89/100 (True: 2, Index: 896)...
#   Success! Adv label: 3, L2: 549.34, Queries: 59
# Attacking sample 90/100 (True: 2, Index: 897)...
#   Success! Adv label: 3, L2: 552.16, Queries: 69
# Attacking sample 92/100 (True: 2, Index: 922)...
#   Success! Adv label: 7, L2: 604.82, Queries: 67
# Attacking sample 93/100 (True: 2, Index: 932)...
#   Success! Adv label: 8, L2: 819.33, Queries: 83
# Attacking sample 94/100 (True: 2, Index: 944)...
#   Success! Adv label: 3, L2: 547.70, Queries: 55
# Attacking sample 95/100 (True: 2, Index: 949)...
#   Success! Adv label: 3, L2: 851.33, Queries: 85
# Attacking sample 96/100 (True: 2, Index: 952)...
#   Failed! Adv label: 2, L2: 860.69, Queries: 201
# Attacking sample 97/100 (True: 2, Index: 959)...
#   Success! Adv label: 3, L2: 664.96, Queries: 65
# Attacking sample 98/100 (True: 2, Index: 966)...
#   Success! Adv label: 7, L2: 242.86, Queries: 27
# Attacking sample 99/100 (True: 2, Index: 967)...
#   Success! Adv label: 7, L2: 848.56, Queries: 99
# Attacking sample 100/100 (True: 2, Index: 985)...
#   Success! Adv label: 3, L2: 696.96, Queries: 81
# Attacking sample 1/100 (True: 3, Index: 1)...
#   Success! Adv label: 5, L2: 421.95, Queries: 41
# Attacking sample 2/100 (True: 3, Index: 12)...
#   Success! Adv label: 8, L2: 370.10, Queries: 41
# Attacking sample 3/100 (True: 3, Index: 20)...
#   Success! Adv label: 8, L2: 779.61, Queries: 73
# Attacking sample 4/100 (True: 3, Index: 27)...
#   Success! Adv label: 2, L2: 776.44, Queries: 119
# Attacking sample 5/100 (True: 3, Index: 37)...
#   Success! Adv label: 2, L2: 969.56, Queries: 133
# Attacking sample 6/100 (True: 3, Index: 43)...
#   Failed! Adv label: 3, L2: 871.59, Queries: 201
# Attacking sample 7/100 (True: 3, Index: 53)...
#   Success! Adv label: 8, L2: 608.87, Queries: 59
# Attacking sample 8/100 (True: 3, Index: 61)...
#   Success! Adv label: 8, L2: 661.74, Queries: 63
# Attacking sample 9/100 (True: 3, Index: 73)...
#   Success! Adv label: 8, L2: 634.94, Queries: 71
# Attacking sample 10/100 (True: 3, Index: 102)...
#   Success! Adv label: 2, L2: 456.99, Queries: 45
# Attacking sample 11/100 (True: 3, Index: 108)...
#   Success! Adv label: 2, L2: 108.06, Queries: 11
# Attacking sample 12/100 (True: 3, Index: 109)...
#   Success! Adv label: 8, L2: 631.28, Queries: 57
# Attacking sample 13/100 (True: 3, Index: 117)...
#   Failed! Adv label: 3, L2: 913.27, Queries: 201
# Attacking sample 14/100 (True: 3, Index: 131)...
#   Success! Adv label: 8, L2: 166.61, Queries: 15
# Attacking sample 15/100 (True: 3, Index: 159)...
#   Success! Adv label: 2, L2: 910.27, Queries: 117
# Attacking sample 16/100 (True: 3, Index: 162)...
#   Success! Adv label: 8, L2: 937.35, Queries: 189
# Attacking sample 17/100 (True: 3, Index: 166)...
#   Success! Adv label: 2, L2: 787.13, Queries: 127
# Attacking sample 18/100 (True: 3, Index: 177)...
#   Success! Adv label: 2, L2: 579.55, Queries: 53
# Attacking sample 19/100 (True: 3, Index: 181)...
#   Success! Adv label: 8, L2: 712.97, Queries: 87
# Attacking sample 20/100 (True: 3, Index: 187)...
#   Success! Adv label: 8, L2: 701.71, Queries: 65
# Attacking sample 21/100 (True: 3, Index: 196)...
#   Success! Adv label: 2, L2: 521.26, Queries: 47
# Attacking sample 22/100 (True: 3, Index: 204)...
#   Failed! Adv label: 3, L2: 924.95, Queries: 201
# Attacking sample 23/100 (True: 3, Index: 227)...
#   Failed! Adv label: 3, L2: 806.27, Queries: 201
# Attacking sample 24/100 (True: 3, Index: 231)...
#   Success! Adv label: 5, L2: 886.15, Queries: 99
# Attacking sample 25/100 (True: 3, Index: 237)...
#   Success! Adv label: 8, L2: 933.40, Queries: 153
# Attacking sample 26/100 (True: 3, Index: 244)...
#   Failed! Adv label: 3, L2: 907.58, Queries: 201
# Attacking sample 27/100 (True: 3, Index: 257)...
#   Success! Adv label: 8, L2: 609.26, Queries: 57
# Attacking sample 28/100 (True: 3, Index: 259)...
#   Success! Adv label: 8, L2: 1035.83, Queries: 195
# Attacking sample 29/100 (True: 3, Index: 265)...
#   Success! Adv label: 5, L2: 579.66, Queries: 59
# Attacking sample 30/100 (True: 3, Index: 270)...
#   Success! Adv label: 5, L2: 284.23, Queries: 27
# Attacking sample 31/100 (True: 3, Index: 288)...
#   Success! Adv label: 8, L2: 967.78, Queries: 91
# Attacking sample 32/100 (True: 3, Index: 308)...
#   Success! Adv label: 8, L2: 641.19, Queries: 67
# Attacking sample 33/100 (True: 3, Index: 309)...
#   Success! Adv label: 8, L2: 601.27, Queries: 59
# Attacking sample 34/100 (True: 3, Index: 327)...
#   Success! Adv label: 1, L2: 374.68, Queries: 45
# Attacking sample 35/100 (True: 3, Index: 331)...
#   Success! Adv label: 8, L2: 809.93, Queries: 93
# Attacking sample 36/100 (True: 3, Index: 340)...
#   Success! Adv label: 2, L2: 1033.57, Queries: 141
# Attacking sample 37/100 (True: 3, Index: 341)...
#   Success! Adv label: 8, L2: 912.74, Queries: 107
# Attacking sample 38/100 (True: 3, Index: 342)...
#   Success! Adv label: 5, L2: 577.39, Queries: 59
# Attacking sample 39/100 (True: 3, Index: 362)...
#   Success! Adv label: 2, L2: 547.35, Queries: 55
# Attacking sample 40/100 (True: 3, Index: 383)...
#   Success! Adv label: 2, L2: 565.35, Queries: 59
# Attacking sample 41/100 (True: 3, Index: 394)...
#   Success! Adv label: 8, L2: 541.64, Queries: 51
# Attacking sample 42/100 (True: 3, Index: 406)...
#   Failed! Adv label: 3, L2: 786.27, Queries: 201
# Attacking sample 43/100 (True: 3, Index: 409)...
#   Success! Adv label: 2, L2: 912.25, Queries: 119
# Attacking sample 44/100 (True: 3, Index: 445)...
#   Success! Adv label: 2, L2: 386.02, Queries: 37
# Attacking sample 45/100 (True: 3, Index: 456)...
#   Success! Adv label: 8, L2: 631.38, Queries: 59
# Attacking sample 46/100 (True: 3, Index: 459)...
#   Failed! Adv label: 3, L2: 891.50, Queries: 201
# Attacking sample 47/100 (True: 3, Index: 461)...
#   Failed! Adv label: 3, L2: 948.54, Queries: 201
# Attacking sample 48/100 (True: 3, Index: 471)...
#   Success! Adv label: 8, L2: 924.25, Queries: 91
# Attacking sample 49/100 (True: 3, Index: 474)...
#   Success! Adv label: 5, L2: 568.95, Queries: 61
# Attacking sample 50/100 (True: 3, Index: 481)...
#   Success! Adv label: 5, L2: 877.08, Queries: 141
# Attacking sample 51/100 (True: 3, Index: 504)...
#   Success! Adv label: 8, L2: 705.86, Queries: 81
# Attacking sample 52/100 (True: 3, Index: 510)...
#   Success! Adv label: 5, L2: 373.05, Queries: 37
# Attacking sample 53/100 (True: 3, Index: 512)...
#   Failed! Adv label: 3, L2: 794.25, Queries: 201
# Attacking sample 54/100 (True: 3, Index: 524)...
#   Success! Adv label: 8, L2: 672.33, Queries: 63
# Attacking sample 55/100 (True: 3, Index: 549)...
#   Success! Adv label: 8, L2: 544.26, Queries: 57
# Attacking sample 56/100 (True: 3, Index: 556)...
#   Success! Adv label: 9, L2: 805.94, Queries: 87
# Attacking sample 57/100 (True: 3, Index: 564)...
#   Success! Adv label: 8, L2: 617.97, Queries: 59
# Attacking sample 58/100 (True: 3, Index: 586)...
#   Failed! Adv label: 3, L2: 897.92, Queries: 201
# Attacking sample 59/100 (True: 3, Index: 589)...
#   Success! Adv label: 0, L2: 1065.09, Queries: 181
# Attacking sample 60/100 (True: 3, Index: 609)...
#   Success! Adv label: 9, L2: 854.29, Queries: 95
# Attacking sample 61/100 (True: 3, Index: 613)...
#   Success! Adv label: 8, L2: 708.51, Queries: 67
# Attacking sample 62/100 (True: 3, Index: 623)...
#   Success! Adv label: 9, L2: 480.60, Queries: 47
# Attacking sample 63/100 (True: 3, Index: 639)...
#   Success! Adv label: 6, L2: 939.61, Queries: 149
# Attacking sample 64/100 (True: 3, Index: 648)...
#   Success! Adv label: 8, L2: 518.71, Queries: 47
# Attacking sample 65/100 (True: 3, Index: 651)...
#   Success! Adv label: 8, L2: 450.79, Queries: 43
# Attacking sample 66/100 (True: 3, Index: 659)...
#   Success! Adv label: 9, L2: 825.89, Queries: 91
# Attacking sample 67/100 (True: 3, Index: 661)...
#   Success! Adv label: 8, L2: 1048.84, Queries: 151
# Attacking sample 68/100 (True: 3, Index: 667)...
#   Failed! Adv label: 3, L2: 783.17, Queries: 201
# Attacking sample 69/100 (True: 3, Index: 678)...
#   Success! Adv label: 2, L2: 806.59, Queries: 191
# Attacking sample 70/100 (True: 3, Index: 690)...
#   Success! Adv label: 8, L2: 1017.14, Queries: 95
# Attacking sample 71/100 (True: 3, Index: 693)...
#   Failed! Adv label: 3, L2: 772.73, Queries: 201
# Attacking sample 72/100 (True: 3, Index: 694)...
#   Success! Adv label: 8, L2: 881.70, Queries: 85
# Attacking sample 73/100 (True: 3, Index: 695)...
#   Success! Adv label: 0, L2: 265.26, Queries: 25
# Attacking sample 74/100 (True: 3, Index: 702)...
#   Success! Adv label: 8, L2: 468.91, Queries: 43
# Attacking sample 75/100 (True: 3, Index: 718)...
#   Failed! Adv label: 3, L2: 864.75, Queries: 201
# Attacking sample 76/100 (True: 3, Index: 749)...
#   Success! Adv label: 8, L2: 953.47, Queries: 171
# Attacking sample 77/100 (True: 3, Index: 769)...
#   Success! Adv label: 2, L2: 951.87, Queries: 91
# Attacking sample 79/100 (True: 3, Index: 779)...
#   Success! Adv label: 8, L2: 457.17, Queries: 45
# Attacking sample 80/100 (True: 3, Index: 800)...
#   Success! Adv label: 8, L2: 903.60, Queries: 81
# Attacking sample 81/100 (True: 3, Index: 816)...
#   Success! Adv label: 5, L2: 367.80, Queries: 41
# Attacking sample 82/100 (True: 3, Index: 829)...
#   Success! Adv label: 2, L2: 570.44, Queries: 55
# Attacking sample 83/100 (True: 3, Index: 833)...
#   Failed! Adv label: 3, L2: 830.41, Queries: 201
# Attacking sample 84/100 (True: 3, Index: 839)...
#   Success! Adv label: 8, L2: 683.15, Queries: 69
# Attacking sample 85/100 (True: 3, Index: 854)...
#   Success! Adv label: 5, L2: 378.10, Queries: 41
# Attacking sample 86/100 (True: 3, Index: 856)...
#   Success! Adv label: 2, L2: 522.29, Queries: 55
# Attacking sample 87/100 (True: 3, Index: 858)...
#   Success! Adv label: 5, L2: 147.28, Queries: 15
# Attacking sample 89/100 (True: 3, Index: 886)...
#   Success! Adv label: 8, L2: 894.16, Queries: 87
# Attacking sample 90/100 (True: 3, Index: 900)...
#   Success! Adv label: 8, L2: 710.99, Queries: 69
# Attacking sample 91/100 (True: 3, Index: 916)...
#   Success! Adv label: 5, L2: 566.61, Queries: 69
# Attacking sample 92/100 (True: 3, Index: 921)...
#   Success! Adv label: 2, L2: 493.91, Queries: 53
# Attacking sample 93/100 (True: 3, Index: 937)...
#   Success! Adv label: 8, L2: 1033.84, Queries: 99
# Attacking sample 94/100 (True: 3, Index: 938)...
#   Success! Adv label: 8, L2: 808.88, Queries: 71
# Attacking sample 95/100 (True: 3, Index: 939)...
#   Success! Adv label: 8, L2: 400.31, Queries: 37
# Attacking sample 96/100 (True: 3, Index: 942)...
#   Failed! Adv label: 3, L2: 894.06, Queries: 201
# Attacking sample 97/100 (True: 3, Index: 951)...
#   Success! Adv label: 8, L2: 643.48, Queries: 65
# Attacking sample 98/100 (True: 3, Index: 953)...
#   Failed! Adv label: 3, L2: 825.40, Queries: 201
# Attacking sample 99/100 (True: 3, Index: 975)...
#   Failed! Adv label: 3, L2: 998.87, Queries: 201
# Attacking sample 1/100 (True: 4, Index: 16)...
#   Success! Adv label: 9, L2: 339.80, Queries: 35
# Attacking sample 2/100 (True: 4, Index: 17)...
#   Success! Adv label: 6, L2: 473.86, Queries: 49
# Attacking sample 3/100 (True: 4, Index: 30)...
#   Success! Adv label: 8, L2: 897.83, Queries: 91
# Attacking sample 4/100 (True: 4, Index: 33)...
#   Success! Adv label: 9, L2: 563.70, Queries: 55
# Attacking sample 5/100 (True: 4, Index: 45)...
#   Success! Adv label: 8, L2: 163.90, Queries: 15
# Attacking sample 6/100 (True: 4, Index: 48)...
#   Success! Adv label: 9, L2: 814.38, Queries: 79
# Attacking sample 7/100 (True: 4, Index: 58)...
#   Success! Adv label: 9, L2: 819.10, Queries: 77
# Attacking sample 8/100 (True: 4, Index: 66)...
#   Success! Adv label: 6, L2: 675.68, Queries: 69
# Attacking sample 9/100 (True: 4, Index: 89)...
#   Success! Adv label: 9, L2: 423.37, Queries: 41
# Attacking sample 10/100 (True: 4, Index: 92)...
#   Success! Adv label: 6, L2: 999.12, Queries: 119
# Attacking sample 11/100 (True: 4, Index: 113)...
#   Success! Adv label: 2, L2: 786.92, Queries: 81
# Attacking sample 12/100 (True: 4, Index: 116)...
#   Success! Adv label: 9, L2: 718.75, Queries: 67
# Attacking sample 13/100 (True: 4, Index: 126)...
#   Success! Adv label: 9, L2: 604.40, Queries: 59
# Attacking sample 14/100 (True: 4, Index: 130)...
#   Success! Adv label: 9, L2: 415.40, Queries: 39
# Attacking sample 15/100 (True: 4, Index: 139)...
#   Success! Adv label: 9, L2: 640.15, Queries: 61
# Attacking sample 16/100 (True: 4, Index: 149)...
#   Failed! Adv label: 4, L2: 1023.81, Queries: 201
# Attacking sample 17/100 (True: 4, Index: 153)...
#   Success! Adv label: 8, L2: 562.35, Queries: 55
# Attacking sample 18/100 (True: 4, Index: 154)...
#   Success! Adv label: 7, L2: 965.58, Queries: 97
# Attacking sample 19/100 (True: 4, Index: 163)...
#   Success! Adv label: 9, L2: 671.29, Queries: 65
# Attacking sample 20/100 (True: 4, Index: 167)...
#   Success! Adv label: 9, L2: 885.10, Queries: 91
# Attacking sample 21/100 (True: 4, Index: 183)...
#   Success! Adv label: 9, L2: 491.67, Queries: 51
# Attacking sample 22/100 (True: 4, Index: 184)...
#   Success! Adv label: 9, L2: 630.45, Queries: 61
# Attacking sample 23/100 (True: 4, Index: 192)...
#   Success! Adv label: 9, L2: 322.75, Queries: 31
# Attacking sample 24/100 (True: 4, Index: 194)...
#   Success! Adv label: 9, L2: 587.83, Queries: 61
# Attacking sample 25/100 (True: 4, Index: 233)...
#   Success! Adv label: 9, L2: 763.19, Queries: 77
# Attacking sample 26/100 (True: 4, Index: 240)...
#   Success! Adv label: 8, L2: 681.47, Queries: 63
# Attacking sample 27/100 (True: 4, Index: 263)...
#   Success! Adv label: 9, L2: 312.77, Queries: 29
# Attacking sample 28/100 (True: 4, Index: 269)...
#   Success! Adv label: 9, L2: 458.37, Queries: 43
# Attacking sample 29/100 (True: 4, Index: 280)...
#   Success! Adv label: 9, L2: 491.22, Queries: 47
# Attacking sample 30/100 (True: 4, Index: 290)...
#   Success! Adv label: 9, L2: 732.89, Queries: 67
# Attacking sample 31/100 (True: 4, Index: 297)...
#   Success! Adv label: 6, L2: 454.13, Queries: 43
# Attacking sample 32/100 (True: 4, Index: 299)...
#   Success! Adv label: 9, L2: 442.89, Queries: 41
# Attacking sample 33/100 (True: 4, Index: 310)...
#   Success! Adv label: 9, L2: 360.22, Queries: 33
# Attacking sample 34/100 (True: 4, Index: 316)...
#   Success! Adv label: 9, L2: 524.28, Queries: 49
# Attacking sample 35/100 (True: 4, Index: 320)...
#   Success! Adv label: 9, L2: 468.76, Queries: 45
# Attacking sample 36/100 (True: 4, Index: 324)...
#   Success! Adv label: 9, L2: 561.19, Queries: 55
# Attacking sample 37/100 (True: 4, Index: 326)...
#   Success! Adv label: 9, L2: 603.30, Queries: 61
# Attacking sample 38/100 (True: 4, Index: 332)...
#   Success! Adv label: 9, L2: 26.57, Queries: 3
# Attacking sample 39/100 (True: 4, Index: 335)...
#   Success! Adv label: 9, L2: 769.25, Queries: 73
# Attacking sample 40/100 (True: 4, Index: 344)...
#   Success! Adv label: 7, L2: 556.37, Queries: 57
# Attacking sample 42/100 (True: 4, Index: 359)...
#   Success! Adv label: 9, L2: 494.72, Queries: 45
# Attacking sample 43/100 (True: 4, Index: 376)...
#   Success! Adv label: 9, L2: 764.05, Queries: 79
# Attacking sample 44/100 (True: 4, Index: 393)...
#   Success! Adv label: 9, L2: 623.58, Queries: 61
# Attacking sample 45/100 (True: 4, Index: 401)...
#   Success! Adv label: 2, L2: 881.06, Queries: 91
# Attacking sample 46/100 (True: 4, Index: 402)...
#   Success! Adv label: 9, L2: 605.29, Queries: 59
# Attacking sample 47/100 (True: 4, Index: 422)...
#   Success! Adv label: 9, L2: 387.04, Queries: 35
# Attacking sample 48/100 (True: 4, Index: 423)...
#   Success! Adv label: 9, L2: 245.28, Queries: 25
# Attacking sample 49/100 (True: 4, Index: 427)...
#   Success! Adv label: 1, L2: 679.70, Queries: 81
# Attacking sample 50/100 (True: 4, Index: 432)...
#   Success! Adv label: 9, L2: 482.03, Queries: 47
# Attacking sample 51/100 (True: 4, Index: 434)...
#   Success! Adv label: 9, L2: 355.57, Queries: 33
# Attacking sample 52/100 (True: 4, Index: 454)...
#   Success! Adv label: 9, L2: 600.83, Queries: 61
# Attacking sample 53/100 (True: 4, Index: 467)...
#   Success! Adv label: 9, L2: 383.89, Queries: 37
# Attacking sample 54/100 (True: 4, Index: 501)...
#   Success! Adv label: 9, L2: 328.13, Queries: 33
# Attacking sample 55/100 (True: 4, Index: 515)...
#   Success! Adv label: 9, L2: 439.69, Queries: 41
# Attacking sample 56/100 (True: 4, Index: 540)...
#   Success! Adv label: 9, L2: 646.88, Queries: 67
# Attacking sample 57/100 (True: 4, Index: 544)...
#   Success! Adv label: 6, L2: 679.75, Queries: 73
# Attacking sample 58/100 (True: 4, Index: 545)...
#   Success! Adv label: 2, L2: 555.88, Queries: 57
# Attacking sample 59/100 (True: 4, Index: 547)...
#   Success! Adv label: 7, L2: 784.91, Queries: 109
# Attacking sample 60/100 (True: 4, Index: 566)...
#   Success! Adv label: 9, L2: 463.38, Queries: 43
# Attacking sample 61/100 (True: 4, Index: 590)...
#   Success! Adv label: 0, L2: 521.62, Queries: 51
# Attacking sample 62/100 (True: 4, Index: 593)...
#   Success! Adv label: 9, L2: 386.92, Queries: 35
# Attacking sample 63/100 (True: 4, Index: 599)...
#   Success! Adv label: 8, L2: 857.31, Queries: 91
# Attacking sample 64/100 (True: 4, Index: 602)...
#   Success! Adv label: 9, L2: 610.00, Queries: 59
# Attacking sample 65/100 (True: 4, Index: 607)...
#   Success! Adv label: 7, L2: 654.28, Queries: 75
# Attacking sample 66/100 (True: 4, Index: 611)...
#   Success! Adv label: 9, L2: 891.27, Queries: 93
# Attacking sample 67/100 (True: 4, Index: 617)...
#   Success! Adv label: 9, L2: 651.35, Queries: 59
# Attacking sample 68/100 (True: 4, Index: 657)...
#   Success! Adv label: 9, L2: 370.86, Queries: 39
# Attacking sample 69/100 (True: 4, Index: 680)...
#   Success! Adv label: 9, L2: 467.05, Queries: 43
# Attacking sample 70/100 (True: 4, Index: 684)...
#   Success! Adv label: 9, L2: 775.61, Queries: 85
# Attacking sample 71/100 (True: 4, Index: 687)...
#   Success! Adv label: 9, L2: 625.05, Queries: 59
# Attacking sample 72/100 (True: 4, Index: 692)...
#   Success! Adv label: 9, L2: 947.29, Queries: 99
# Attacking sample 73/100 (True: 4, Index: 696)...
#   Success! Adv label: 9, L2: 199.36, Queries: 19
# Attacking sample 74/100 (True: 4, Index: 697)...
#   Success! Adv label: 9, L2: 1022.77, Queries: 97
# Attacking sample 75/100 (True: 4, Index: 708)...
#   Success! Adv label: 9, L2: 660.86, Queries: 63
# Attacking sample 76/100 (True: 4, Index: 717)...
#   Success! Adv label: 9, L2: 466.06, Queries: 43
# Attacking sample 77/100 (True: 4, Index: 746)...
#   Success! Adv label: 9, L2: 595.24, Queries: 63
# Attacking sample 78/100 (True: 4, Index: 752)...
#   Failed! Adv label: 4, L2: 1053.85, Queries: 201
# Attacking sample 79/100 (True: 4, Index: 755)...
#   Success! Adv label: 7, L2: 851.33, Queries: 139
# Attacking sample 80/100 (True: 4, Index: 757)...
#   Success! Adv label: 9, L2: 548.93, Queries: 53
# Attacking sample 81/100 (True: 4, Index: 766)...
#   Success! Adv label: 7, L2: 492.26, Queries: 51
# Attacking sample 82/100 (True: 4, Index: 771)...
#   Success! Adv label: 9, L2: 353.19, Queries: 33
# Attacking sample 83/100 (True: 4, Index: 776)...
#   Success! Adv label: 2, L2: 712.27, Queries: 71
# Attacking sample 84/100 (True: 4, Index: 777)...
#   Failed! Adv label: 4, L2: 948.38, Queries: 201
# Attacking sample 85/100 (True: 4, Index: 786)...
#   Success! Adv label: 9, L2: 270.51, Queries: 25
# Attacking sample 86/100 (True: 4, Index: 811)...
#   Success! Adv label: 9, L2: 342.44, Queries: 33
# Attacking sample 87/100 (True: 4, Index: 815)...
#   Success! Adv label: 6, L2: 771.78, Queries: 81
# Attacking sample 88/100 (True: 4, Index: 817)...
#   Success! Adv label: 7, L2: 905.51, Queries: 141
# Attacking sample 89/100 (True: 4, Index: 840)...
#   Success! Adv label: 6, L2: 826.28, Queries: 81
# Attacking sample 91/100 (True: 4, Index: 849)...
#   Success! Adv label: 8, L2: 788.52, Queries: 73
# Attacking sample 92/100 (True: 4, Index: 857)...
#   Success! Adv label: 9, L2: 613.24, Queries: 59
# Attacking sample 93/100 (True: 4, Index: 872)...
#   Success! Adv label: 9, L2: 861.08, Queries: 95
# Attacking sample 94/100 (True: 4, Index: 877)...
#   Success! Adv label: 9, L2: 569.84, Queries: 59
# Attacking sample 95/100 (True: 4, Index: 894)...
#   Success! Adv label: 9, L2: 309.42, Queries: 29
# Attacking sample 96/100 (True: 4, Index: 902)...
#   Success! Adv label: 9, L2: 453.02, Queries: 41
# Attacking sample 97/100 (True: 4, Index: 911)...
# ...
#   Success! Adv label: 3, L2: 619.43, Queries: 63
# Attacking sample 40/100 (True: 8, Index: 505)...
#   Success! Adv label: 2, L2: 716.75, Queries: 77
# Attacking sample 41/100 (True: 8, Index: 509)...
#   Success! Adv label: 3, L2: 679.12, Queries: 83
# Attacking sample 42/100 (True: 8, Index: 525)...
#   Success! Adv label: 3, L2: 609.16, Queries: 67
# Attacking sample 43/100 (True: 8, Index: 528)...
#   Success! Adv label: 3, L2: 747.58, Queries: 93
# Attacking sample 44/100 (True: 8, Index: 541)...
#   Success! Adv label: 2, L2: 902.68, Queries: 99
# Attacking sample 45/100 (True: 8, Index: 543)...
#   Success! Adv label: 6, L2: 436.73, Queries: 45
# Attacking sample 46/100 (True: 8, Index: 550)...
#   Success! Adv label: 9, L2: 576.77, Queries: 61
# Attacking sample 47/100 (True: 8, Index: 558)...
#   Failed! Adv label: 8, L2: 940.39, Queries: 201
# Attacking sample 48/100 (True: 8, Index: 575)...
#   Success! Adv label: 9, L2: 534.70, Queries: 61
# Attacking sample 49/100 (True: 8, Index: 594)...
#   Success! Adv label: 2, L2: 492.39, Queries: 55
# Attacking sample 50/100 (True: 8, Index: 600)...
#   Failed! Adv label: 8, L2: 977.57, Queries: 201
# Attacking sample 51/100 (True: 8, Index: 605)...
#   Success! Adv label: 2, L2: 743.67, Queries: 79
# Attacking sample 52/100 (True: 8, Index: 619)...
#   Success! Adv label: 3, L2: 639.03, Queries: 83
# Attacking sample 53/100 (True: 8, Index: 625)...
#   Success! Adv label: 3, L2: 832.74, Queries: 85
# Attacking sample 54/100 (True: 8, Index: 629)...
#   Success! Adv label: 2, L2: 587.36, Queries: 59
# Attacking sample 55/100 (True: 8, Index: 645)...
#   Failed! Adv label: 8, L2: 973.47, Queries: 201
# Attacking sample 56/100 (True: 8, Index: 652)...
#   Success! Adv label: 3, L2: 866.76, Queries: 125
# Attacking sample 57/100 (True: 8, Index: 672)...
#   Success! Adv label: 3, L2: 656.67, Queries: 81
# Attacking sample 58/100 (True: 8, Index: 683)...
#   Success! Adv label: 3, L2: 363.56, Queries: 43
# Attacking sample 59/100 (True: 8, Index: 701)...
#   Success! Adv label: 5, L2: 781.62, Queries: 87
# Attacking sample 60/100 (True: 8, Index: 714)...
#   Success! Adv label: 3, L2: 691.93, Queries: 79
# Attacking sample 61/100 (True: 8, Index: 721)...
#   Success! Adv label: 3, L2: 512.65, Queries: 55
# Attacking sample 62/100 (True: 8, Index: 730)...
#   Success! Adv label: 2, L2: 708.37, Queries: 73
# Attacking sample 63/100 (True: 8, Index: 731)...
#   Failed! Adv label: 8, L2: 974.06, Queries: 201
# Attacking sample 64/100 (True: 8, Index: 738)...
#   Success! Adv label: 3, L2: 906.33, Queries: 137
# Attacking sample 65/100 (True: 8, Index: 791)...
#   Success! Adv label: 5, L2: 858.79, Queries: 97
# Attacking sample 66/100 (True: 8, Index: 832)...
#   Success! Adv label: 6, L2: 686.50, Queries: 73
# Attacking sample 67/100 (True: 8, Index: 838)...
#   Success! Adv label: 5, L2: 639.29, Queries: 75
# Attacking sample 68/100 (True: 8, Index: 860)...
#   Success! Adv label: 3, L2: 778.47, Queries: 91
# Attacking sample 69/100 (True: 8, Index: 864)...
#   Failed! Adv label: 8, L2: 891.52, Queries: 201
# Attacking sample 70/100 (True: 8, Index: 889)...
#   Success! Adv label: 3, L2: 697.88, Queries: 81
# Attacking sample 71/100 (True: 8, Index: 905)...
#   Success! Adv label: 9, L2: 806.67, Queries: 97
# Attacking sample 73/100 (True: 8, Index: 919)...
#   Success! Adv label: 3, L2: 553.64, Queries: 61
# Attacking sample 74/100 (True: 8, Index: 923)...
#   Success! Adv label: 3, L2: 702.27, Queries: 83
# Attacking sample 75/100 (True: 8, Index: 926)...
#   Success! Adv label: 5, L2: 762.67, Queries: 83
# Attacking sample 76/100 (True: 8, Index: 933)...
#   Success! Adv label: 3, L2: 682.85, Queries: 81
# Attacking sample 78/100 (True: 8, Index: 971)...
#   Success! Adv label: 3, L2: 810.14, Queries: 91
# Attacking sample 79/100 (True: 8, Index: 1014)...
#   Success! Adv label: 3, L2: 595.76, Queries: 69
# Attacking sample 80/100 (True: 8, Index: 1034)...
#   Success! Adv label: 5, L2: 871.93, Queries: 109
# Attacking sample 81/100 (True: 8, Index: 1053)...
#   Success! Adv label: 6, L2: 652.23, Queries: 69
# Attacking sample 82/100 (True: 8, Index: 1057)...
#   Success! Adv label: 6, L2: 520.19, Queries: 49
# Attacking sample 83/100 (True: 8, Index: 1061)...
#   Failed! Adv label: 8, L2: 816.38, Queries: 201
# Attacking sample 84/100 (True: 8, Index: 1062)...
#   Success! Adv label: 3, L2: 628.59, Queries: 75
# Attacking sample 85/100 (True: 8, Index: 1063)...
#   Success! Adv label: 3, L2: 648.21, Queries: 69
# Attacking sample 86/100 (True: 8, Index: 1078)...
#   Success! Adv label: 9, L2: 356.60, Queries: 33
# Attacking sample 87/100 (True: 8, Index: 1088)...
#   Success! Adv label: 2, L2: 784.00, Queries: 89
# Attacking sample 88/100 (True: 8, Index: 1100)...
#   Failed! Adv label: 8, L2: 991.79, Queries: 201
# Attacking sample 89/100 (True: 8, Index: 1106)...
#   Failed! Adv label: 8, L2: 963.99, Queries: 201
# Attacking sample 90/100 (True: 8, Index: 1120)...
#   Success! Adv label: 3, L2: 615.06, Queries: 69
# Attacking sample 91/100 (True: 8, Index: 1132)...
#   Success! Adv label: 2, L2: 722.34, Queries: 81
# Attacking sample 92/100 (True: 8, Index: 1134)...
#   Failed! Adv label: 8, L2: 1055.06, Queries: 201
# Attacking sample 93/100 (True: 8, Index: 1140)...
#   Success! Adv label: 5, L2: 357.72, Queries: 39
# Attacking sample 94/100 (True: 8, Index: 1150)...
#   Success! Adv label: 9, L2: 617.89, Queries: 63
# Attacking sample 95/100 (True: 8, Index: 1165)...
#   Failed! Adv label: 8, L2: 1036.91, Queries: 201
# Attacking sample 96/100 (True: 8, Index: 1179)...
#   Success! Adv label: 9, L2: 663.79, Queries: 75
# Attacking sample 97/100 (True: 8, Index: 1182)...
#   Success! Adv label: 9, L2: 565.90, Queries: 59
# Attacking sample 98/100 (True: 8, Index: 1186)...
#   Success! Adv label: 2, L2: 898.96, Queries: 99
# Attacking sample 99/100 (True: 8, Index: 1189)...
#   Success! Adv label: 3, L2: 293.55, Queries: 33
# Attacking sample 100/100 (True: 8, Index: 1207)...
#   Success! Adv label: 9, L2: 874.61, Queries: 91
# Attacking sample 1/100 (True: 9, Index: 6)...
#   Success! Adv label: 7, L2: 371.75, Queries: 39
# Attacking sample 2/100 (True: 9, Index: 38)...
#   Success! Adv label: 7, L2: 67.68, Queries: 7
# Attacking sample 3/100 (True: 9, Index: 55)...
#   Success! Adv label: 0, L2: 155.46, Queries: 17
# Attacking sample 4/100 (True: 9, Index: 56)...
#   Success! Adv label: 4, L2: 524.89, Queries: 53
# Attacking sample 5/100 (True: 9, Index: 91)...
#   Success! Adv label: 3, L2: 322.01, Queries: 31
# Attacking sample 6/100 (True: 9, Index: 99)...
#   Success! Adv label: 7, L2: 471.53, Queries: 51
# Attacking sample 7/100 (True: 9, Index: 101)...
#   Success! Adv label: 5, L2: 768.86, Queries: 91
# Attacking sample 8/100 (True: 9, Index: 114)...
#   Success! Adv label: 8, L2: 797.19, Queries: 79
# Attacking sample 9/100 (True: 9, Index: 133)...
#   Success! Adv label: 8, L2: 777.58, Queries: 77
# Attacking sample 10/100 (True: 9, Index: 171)...
#   Success! Adv label: 8, L2: 118.08, Queries: 11
# Attacking sample 11/100 (True: 9, Index: 179)...
#   Success! Adv label: 7, L2: 673.48, Queries: 79
# Attacking sample 12/100 (True: 9, Index: 195)...
#   Success! Adv label: 1, L2: 257.74, Queries: 25
# Attacking sample 13/100 (True: 9, Index: 214)...
#   Success! Adv label: 4, L2: 594.11, Queries: 69
# Attacking sample 14/100 (True: 9, Index: 218)...
#   Success! Adv label: 4, L2: 443.36, Queries: 49
# Attacking sample 15/100 (True: 9, Index: 222)...
#   Success! Adv label: 8, L2: 457.69, Queries: 49
# Attacking sample 16/100 (True: 9, Index: 224)...
#   Success! Adv label: 6, L2: 625.76, Queries: 65
# Attacking sample 17/100 (True: 9, Index: 238)...
#   Success! Adv label: 4, L2: 564.08, Queries: 57
# Attacking sample 18/100 (True: 9, Index: 243)...
#   Success! Adv label: 8, L2: 800.21, Queries: 81
# Attacking sample 19/100 (True: 9, Index: 245)...
#   Success! Adv label: 4, L2: 630.12, Queries: 71
# Attacking sample 20/100 (True: 9, Index: 246)...
#   Success! Adv label: 8, L2: 694.39, Queries: 65
# Attacking sample 21/100 (True: 9, Index: 251)...
#   Success! Adv label: 7, L2: 315.66, Queries: 33
# Attacking sample 22/100 (True: 9, Index: 303)...
#   Success! Adv label: 4, L2: 325.43, Queries: 35
# Attacking sample 23/100 (True: 9, Index: 305)...
#   Success! Adv label: 8, L2: 292.22, Queries: 29
# Attacking sample 24/100 (True: 9, Index: 307)...
#   Success! Adv label: 3, L2: 612.11, Queries: 73
# Attacking sample 25/100 (True: 9, Index: 315)...
#   Success! Adv label: 8, L2: 855.69, Queries: 91
# Attacking sample 26/100 (True: 9, Index: 354)...
#   Success! Adv label: 4, L2: 660.53, Queries: 75
# Attacking sample 27/100 (True: 9, Index: 364)...
#   Success! Adv label: 8, L2: 755.82, Queries: 77
# Attacking sample 28/100 (True: 9, Index: 389)...
#   Success! Adv label: 4, L2: 393.78, Queries: 41
# Attacking sample 29/100 (True: 9, Index: 407)...
#   Success! Adv label: 8, L2: 312.19, Queries: 29
# Attacking sample 30/100 (True: 9, Index: 411)...
#   Success! Adv label: 4, L2: 277.85, Queries: 27
# Attacking sample 31/100 (True: 9, Index: 417)...
#   Success! Adv label: 7, L2: 483.62, Queries: 63
# Attacking sample 32/100 (True: 9, Index: 421)...
#   Success! Adv label: 4, L2: 523.01, Queries: 55
# Attacking sample 33/100 (True: 9, Index: 438)...
#   Success! Adv label: 4, L2: 511.90, Queries: 53
# Attacking sample 34/100 (True: 9, Index: 443)...
#   Success! Adv label: 8, L2: 758.06, Queries: 81
# Attacking sample 35/100 (True: 9, Index: 444)...
#   Success! Adv label: 4, L2: 346.30, Queries: 37
# Attacking sample 36/100 (True: 9, Index: 446)...
#   Success! Adv label: 7, L2: 729.59, Queries: 87
# Attacking sample 37/100 (True: 9, Index: 455)...
#   Success! Adv label: 7, L2: 340.01, Queries: 37
# Attacking sample 38/100 (True: 9, Index: 469)...
#   Failed! Adv label: 9, L2: 980.02, Queries: 201
# Attacking sample 39/100 (True: 9, Index: 472)...
#   Success! Adv label: 3, L2: 923.74, Queries: 97
# Attacking sample 40/100 (True: 9, Index: 473)...
#   Success! Adv label: 7, L2: 778.80, Queries: 85
# Attacking sample 41/100 (True: 9, Index: 482)...
#   Success! Adv label: 4, L2: 536.12, Queries: 51
# Attacking sample 42/100 (True: 9, Index: 490)...
#   Success! Adv label: 8, L2: 999.70, Queries: 107
# Attacking sample 43/100 (True: 9, Index: 496)...
#   Success! Adv label: 4, L2: 605.47, Queries: 69
# Attacking sample 44/100 (True: 9, Index: 507)...
#   Success! Adv label: 8, L2: 477.24, Queries: 45
# Attacking sample 45/100 (True: 9, Index: 508)...
#   Success! Adv label: 7, L2: 509.55, Queries: 55
# Attacking sample 46/100 (True: 9, Index: 514)...
#   Success! Adv label: 4, L2: 267.85, Queries: 25
# Attacking sample 47/100 (True: 9, Index: 522)...
#   Success! Adv label: 4, L2: 85.29, Queries: 9
# Attacking sample 48/100 (True: 9, Index: 535)...
#   Success! Adv label: 4, L2: 558.21, Queries: 63
# Attacking sample 49/100 (True: 9, Index: 542)...
#   Success! Adv label: 8, L2: 503.20, Queries: 55
# Attacking sample 50/100 (True: 9, Index: 553)...
#   Success! Adv label: 4, L2: 797.52, Queries: 91
# Attacking sample 51/100 (True: 9, Index: 554)...
#   Success! Adv label: 8, L2: 885.92, Queries: 89
# Attacking sample 52/100 (True: 9, Index: 565)...
#   Success! Adv label: 0, L2: 495.97, Queries: 53
# Attacking sample 53/100 (True: 9, Index: 569)...
#   Success! Adv label: 4, L2: 562.68, Queries: 65
# Attacking sample 54/100 (True: 9, Index: 572)...
#   Success! Adv label: 5, L2: 443.23, Queries: 49
# Attacking sample 55/100 (True: 9, Index: 574)...
#   Success! Adv label: 8, L2: 456.50, Queries: 49
# Attacking sample 56/100 (True: 9, Index: 601)...
#   Success! Adv label: 8, L2: 412.66, Queries: 39
# Attacking sample 57/100 (True: 9, Index: 634)...
#   Success! Adv label: 5, L2: 550.94, Queries: 57
# Attacking sample 58/100 (True: 9, Index: 635)...
#   Success! Adv label: 4, L2: 785.64, Queries: 95
# Attacking sample 59/100 (True: 9, Index: 637)...
#   Success! Adv label: 4, L2: 662.87, Queries: 71
# Attacking sample 60/100 (True: 9, Index: 640)...
#   Success! Adv label: 4, L2: 615.69, Queries: 65
# Attacking sample 61/100 (True: 9, Index: 653)...
#   Success! Adv label: 8, L2: 617.81, Queries: 61
# Attacking sample 62/100 (True: 9, Index: 654)...
#   Success! Adv label: 4, L2: 637.89, Queries: 71
# Attacking sample 63/100 (True: 9, Index: 656)...
#   Success! Adv label: 4, L2: 691.02, Queries: 73
# Attacking sample 64/100 (True: 9, Index: 666)...
#   Success! Adv label: 4, L2: 485.22, Queries: 55
# Attacking sample 65/100 (True: 9, Index: 685)...
#   Success! Adv label: 7, L2: 708.60, Queries: 83
# Attacking sample 66/100 (True: 9, Index: 711)...
#   Success! Adv label: 4, L2: 274.30, Queries: 27
# Attacking sample 67/100 (True: 9, Index: 729)...
#   Success! Adv label: 8, L2: 545.53, Queries: 55
# Attacking sample 68/100 (True: 9, Index: 739)...
#   Success! Adv label: 4, L2: 501.94, Queries: 55
# Attacking sample 69/100 (True: 9, Index: 747)...
#   Success! Adv label: 8, L2: 416.96, Queries: 41
# Attacking sample 70/100 (True: 9, Index: 767)...
#   Success! Adv label: 8, L2: 541.51, Queries: 57
# Attacking sample 71/100 (True: 9, Index: 783)...
#   Success! Adv label: 5, L2: 697.14, Queries: 81
# Attacking sample 72/100 (True: 9, Index: 787)...
#   Success! Adv label: 8, L2: 631.63, Queries: 61
# Attacking sample 73/100 (True: 9, Index: 796)...
#   Success! Adv label: 7, L2: 473.99, Queries: 51
# Attacking sample 74/100 (True: 9, Index: 804)...
#   Success! Adv label: 7, L2: 680.58, Queries: 87
# Attacking sample 75/100 (True: 9, Index: 818)...
#   Success! Adv label: 4, L2: 703.03, Queries: 81
# Attacking sample 76/100 (True: 9, Index: 825)...
#   Success! Adv label: 8, L2: 418.98, Queries: 41
# Attacking sample 77/100 (True: 9, Index: 826)...
#   Success! Adv label: 1, L2: 212.93, Queries: 23
# Attacking sample 78/100 (True: 9, Index: 831)...
#   Success! Adv label: 4, L2: 586.07, Queries: 59
# Attacking sample 79/100 (True: 9, Index: 880)...
#   Success! Adv label: 5, L2: 754.48, Queries: 77
# Attacking sample 80/100 (True: 9, Index: 884)...
#   Success! Adv label: 4, L2: 599.57, Queries: 63
# Attacking sample 81/100 (True: 9, Index: 891)...
#   Success! Adv label: 4, L2: 156.76, Queries: 17
# Attacking sample 82/100 (True: 9, Index: 893)...
#   Success! Adv label: 2, L2: 780.58, Queries: 93
# Attacking sample 83/100 (True: 9, Index: 899)...
#   Success! Adv label: 4, L2: 548.79, Queries: 63
# Attacking sample 84/100 (True: 9, Index: 912)...
#   Success! Adv label: 5, L2: 693.06, Queries: 73
# Attacking sample 85/100 (True: 9, Index: 920)...
#   Success! Adv label: 4, L2: 706.83, Queries: 75
# Attacking sample 86/100 (True: 9, Index: 925)...
#   Success! Adv label: 8, L2: 439.39, Queries: 41
# Attacking sample 87/100 (True: 9, Index: 940)...
#   Success! Adv label: 4, L2: 402.60, Queries: 47
# Attacking sample 88/100 (True: 9, Index: 958)...
#   Success! Adv label: 4, L2: 597.37, Queries: 61
# Attacking sample 89/100 (True: 9, Index: 969)...
#   Success! Adv label: 8, L2: 456.72, Queries: 43
# Attacking sample 90/100 (True: 9, Index: 978)...
#   Success! Adv label: 4, L2: 620.90, Queries: 75
# Attacking sample 91/100 (True: 9, Index: 979)...
#   Success! Adv label: 4, L2: 516.51, Queries: 51
# Attacking sample 92/100 (True: 9, Index: 980)...
#   Success! Adv label: 8, L2: 375.07, Queries: 39
# Attacking sample 93/100 (True: 9, Index: 991)...
#   Success! Adv label: 7, L2: 548.39, Queries: 67
# Attacking sample 94/100 (True: 9, Index: 997)...
#   Success! Adv label: 4, L2: 304.81, Queries: 35
# Attacking sample 95/100 (True: 9, Index: 1006)...
#   Success! Adv label: 7, L2: 591.42, Queries: 71
# Attacking sample 96/100 (True: 9, Index: 1011)...
#   Success! Adv label: 4, L2: 899.40, Queries: 101
# Attacking sample 97/100 (True: 9, Index: 1020)...
#   Success! Adv label: 8, L2: 560.00, Queries: 59
# Attacking sample 98/100 (True: 9, Index: 1023)...
#   Success! Adv label: 4, L2: 818.25, Queries: 95
# Attacking sample 99/100 (True: 9, Index: 1042)...
#   Success! Adv label: 4, L2: 409.45, Queries: 39
# Attacking sample 100/100 (True: 9, Index: 1046)...
#   Success! Adv label: 4, L2: 392.24, Queries: 41
# Time taken to generate adversarial samples: 194.2434 seconds
#
# Stats saved to: adversarial_8bit_K110_test_images\per_sample_stats.csv
#
# ===== Attack Summary =====
# Total trials: 986
# Misclassified before attack: 14
# Success rate: 901/986 (91.4%)
# Mean L2 (successful): 611.57
# Mean queries (successful): 66.21
#
# Showing successful adversarial examples...

# %% [markdown]
# ### Untargeted Attack on test set; k=120

# %%
import os
import warnings
import numpy as np
import torch
import joblib
import pandas as pd
from PIL import Image
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import torch.nn.functional as F
import time


# Set seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# ─────────────── PATHS ────────────────────────────────────────────────────
LENET_MODEL_PATH = os.path.normpath("Models and Data splits/lenet.pt")  # TorchScript model
DATA_PKL = os.path.normpath("Models and Data splits/data_[SCALED] Train_Test_Splits.pkl")
RF_ALL_CLASSES_PATH = os.path.normpath("Models and Data splits/random_forest.pkl")
OUT_DIR = "adversarial_8bit_K120_test_images"
os.makedirs(OUT_DIR, exist_ok=True)

if not os.path.exists(RF_ALL_CLASSES_PATH):
    raise FileNotFoundError(f"Random Forest model not found at {RF_ALL_CLASSES_PATH}")

# ─────────── HYPER-PARAMETERS ─────────────────────────────────────────────
EPSILON_STEP = 0.01
ITERATIONS = 100
TOTAL_EPSILON = 0.5
TOP_K_FEATURES = 120
SAMPLES_PER_DIGIT = 100
MAX_L2 = 10000

def plot_adversarial_example(original_img, adv_img, true_label, adv_label, l2_mag, sample_idx, queries, title_suffix=""):
    if original_img.size == 784:
        original_img = original_img.reshape(28, 28)
    if adv_img.size == 784:
        adv_img = adv_img.reshape(28, 28)
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(original_img, cmap='gray')
    axes[0].set_title(f"Original\nTrue: {true_label}")
    axes[0].axis('off')
    axes[1].imshow(adv_img, cmap='gray')
    axes[1].set_title(f"Adversarial\nPred: {adv_label}")
    axes[1].axis('off')
    fig.suptitle(f"Sample {sample_idx} | L2: {l2_mag:.2f} | Queries: {queries} {title_suffix}")
    plt.show()
    plt.close(fig)  # <-- added here


# ─────────── Load Data ─────────────────────────────────────────────────────
try:
    data = joblib.load(DATA_PKL)
    _, X_samples , _, y_samples = data
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PKL}. Please check the path.")
    exit()

if X_samples.max() > 1.0:
    X_samples = X_samples.astype(np.float32) / 255.0
    warnings.warn("Data appeared in [0,255]; normalized to [0,1].")

# ─────────── Load TorchScripted LeNet ──────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
try:
    model = torch.jit.load(LENET_MODEL_PATH, map_location=device)
    model.eval()
    print(f"LeNet TorchScript model loaded from: {LENET_MODEL_PATH}")
except Exception as e:
    print(f"Error loading TorchScript LeNet model: {e}")
    exit()

def to_model(x01_batch):
    if x01_batch.ndim == 2 and x01_batch.shape == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)
    elif x01_batch.ndim == 3 and x01_batch.shape[1:] == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(1)
    elif x01_batch.ndim == 4 and x01_batch.shape[1] == 1:
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device)
    elif x01_batch.ndim == 1 and x01_batch.size == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(1, 1, 28, 28), dtype=torch.float32, device=device)
    elif x01_batch.ndim == 2 and x01_batch.shape[1] == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(x01_batch.shape[0], 1, 28, 28), dtype=torch.float32, device=device)
    else:
        raise ValueError(f"Unsupported input shape for to_model: {x01_batch.shape}")
    return tensor_batch


def model_query(x_tensor_batch):
    with torch.no_grad():
        return model(x_tensor_batch)

# ─────────── Load Random Forest Model ──────────────────────────────────────
rf_all_classes = None
top_feature_indices = None
print("Loading Random Forest Classifier for all classes...")
try:
    rf_all_classes = joblib.load(RF_ALL_CLASSES_PATH)
    feature_importances = rf_all_classes.feature_importances_
    #top_feature_indices = np.argsort(feature_importances)[:TOP_K_FEATURES]
    
    top_feature_indices = np.argsort(-feature_importances)[:TOP_K_FEATURES]
    print(f"Random Forest loaded. Using top {TOP_K_FEATURES} features.")
except Exception as e:
    print(f"Error loading Random Forest: {e}")
    top_feature_indices = np.arange(28 * 28)

# ─────────── I-FGSM Attack ─────────────────────────────────────────────────
def ifgsm_attack(original_image_np, true_label, model_target, epsilon_step, iterations,
                 total_epsilon_budget, features_to_perturb, query_count_tracker):
    if original_image_np.ndim == 1 and original_image_np.size == 784:
        original_image_np = original_image_np.reshape(28, 28)

    perturbed_image_np = original_image_np.copy()
    final_pred_label = true_label

    for i in range(iterations):
        image_tensor = to_model(perturbed_image_np)
        image_tensor.requires_grad = True
        output = model_target(image_tensor)
        query_count_tracker[0] += 1
        loss = F.cross_entropy(output, torch.tensor([true_label], device=device))
        model_target.zero_grad()
        loss.backward()
        data_grad_sign = torch.sign(image_tensor.grad.data).cpu().numpy()

        gradient_mask = np.zeros_like(data_grad_sign, dtype=np.float32)
        h, w = perturbed_image_np.shape
        rows, cols = np.unravel_index(features_to_perturb, (h, w))
        gradient_mask[0, 0, rows, cols] = data_grad_sign[0, 0, rows, cols]
        gradient_mask_for_update = gradient_mask.reshape(perturbed_image_np.shape)

        perturbed_image_np += epsilon_step * gradient_mask_for_update
        perturbation = perturbed_image_np - original_image_np
        perturbation = np.clip(perturbation, -total_epsilon_budget, total_epsilon_budget)
        perturbed_image_np = original_image_np + perturbation
        perturbed_image_np = np.clip(perturbed_image_np, 0, 1)

        # Discretize and check prediction on discretized image
        adv_uint8_temp = np.round(perturbed_image_np * 255).astype(np.uint8)
        adv_float_temp = adv_uint8_temp.astype(np.float32) / 255.0
        with torch.no_grad():
            output_temp = model_target(to_model(adv_float_temp))
            pred_temp = output_temp.argmax(dim=1).item()
            query_count_tracker[0] += 1

        if pred_temp != true_label:
            final_pred_label = pred_temp
            break

    # Final adversarial image (discretized)
    adv_uint8 = np.round(perturbed_image_np * 255).astype(np.uint8)
    adv_float = adv_uint8.astype(np.float32) / 255.0
    with torch.no_grad():
        output_final = model_target(to_model(adv_float))
        final_pred_label = output_final.argmax(dim=1).item()

    l2_norm = np.linalg.norm(adv_uint8.astype(np.float32) - (original_image_np * 255).astype(np.float32))
    success = (final_pred_label != true_label) and (l2_norm <= MAX_L2)

    return adv_uint8, final_pred_label, l2_norm, success


# ─────────── Attack Execution ──────────────────────────────────────────────
print(f"\n===== Starting Adversarial Attack =====")
total_trials, succ_total, misclassified = 0, 0, 0
records = []


start_time = time.time()


for digit in range(10):
    idxs = np.where(y_samples == digit)[0][:SAMPLES_PER_DIGIT]
    for rank, idx in enumerate(idxs, 1):
        x0 = X_samples[idx].copy()
        y0 = int(y_samples[idx])
        query_count_tracker = [0]
        pred0 = model_query(to_model(x0)).argmax(dim=1).item()
        query_count_tracker[0] += 1

        if pred0 != y0:
            misclassified += 1
            records.append({
                'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
                'adv_label': None, 'success': False, 'queries': query_count_tracker[0],
                'l2_mag': np.nan, 'note': 'Already misclassified'
            })
            continue

        total_trials += 1
        print(f"Attacking sample {rank}/{SAMPLES_PER_DIGIT} (True: {y0}, Index: {idx})...")
        adv_img_uint8, adv_label, l2_mag, success = ifgsm_attack(
            x0, y0, model, EPSILON_STEP, ITERATIONS, TOTAL_EPSILON,
            top_feature_indices, query_count_tracker
        )

        if success:
            succ_total += 1
            fname = f"true{y0}_adv{adv_label}_mag{l2_mag:.1f}_sample{idx}.png"
            Image.fromarray(adv_img_uint8, mode="L").save(os.path.join(OUT_DIR, fname))

        records.append({
            'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
            'adv_label': adv_label, 'success': success, 'queries': query_count_tracker[0],
            'l2_mag': l2_mag if success else np.nan, 'note': 'I-FGSM' + (' successful' if success else ' failed')
        })

        print(f"  {'Success' if success else 'Failed'}! Adv label: {adv_label}, L2: {l2_mag:.2f}, Queries: {query_count_tracker[0]}")


end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to generate adversarial samples: {elapsed_time:.4f} seconds")


# ─────────── Save Results ──────────────────────────────────────────────────
df = pd.DataFrame(records)
csv_path = os.path.join(OUT_DIR, "per_sample_stats.csv")
df.to_csv(csv_path, index=False)
print(f"\nStats saved to: {csv_path}")

# ─────────── Summary ───────────────────────────────────────────────────────
print(f"\n===== Attack Summary =====")
print(f"Total trials: {total_trials}")
print(f"Misclassified before attack: {misclassified}")
if total_trials > 0:
    success_rate = succ_total / total_trials * 100
    print(f"Success rate: {succ_total}/{total_trials} ({success_rate:.1f}%)")
    if succ_total > 0:
        print(f"Mean L2 (successful): {df[df['success']]['l2_mag'].mean():.2f}")
        print(f"Mean queries (successful): {df[df['success']]['queries'].mean():.2f}")

# ─────────── Display Examples ──────────────────────────────────────────────
success_df = df[df['success']]
if not success_df.empty:
    print("\nShowing successful adversarial examples...")
    show_ids = success_df.sample(min(3, len(success_df))).index.tolist()
    for record_idx in show_ids:
        r = df.loc[record_idx]
        fname_prefix = f"true{r['true_label']}_adv{r['adv_label']}_mag{r['l2_mag']:.1f}_sample{r['sample_idx']}"
        match_files = [f for f in os.listdir(OUT_DIR) if f.startswith(fname_prefix)]
        if match_files:
            adv_img_path = os.path.join(OUT_DIR, match_files[0])
            plot_adversarial_example(X_samples[r['sample_idx']], np.array(Image.open(adv_img_path)),
                                     r['true_label'], r['adv_label'], r['l2_mag'],
                                     r['sample_idx'], r['queries'], "(I-FGSM)")
else:
    print("No successful attacks to display. Showing original samples instead.")
    for i in range(min(3, len(df))):
        r = df.iloc[i]
        plot_adversarial_example(X_samples[r['sample_idx']], X_samples[r['sample_idx']],
                                 r['true_label'], r['initial_pred'], 0.0,
                                 r['sample_idx'], r['queries'], "(Original)")
# Out:
# LeNet TorchScript model loaded from: Models and Data splits\lenet.pt
# Loading Random Forest Classifier for all classes...
# Random Forest loaded. Using top 120 features.
#
# ===== Starting Adversarial Attack =====
# Attacking sample 1/100 (True: 0, Index: 29)...
#   Success! Adv label: 6, L2: 934.96, Queries: 121
# Attacking sample 2/100 (True: 0, Index: 40)...
#   Failed! Adv label: 0, L2: 986.06, Queries: 201
# Attacking sample 3/100 (True: 0, Index: 44)...
#   Success! Adv label: 5, L2: 694.08, Queries: 73
# Attacking sample 4/100 (True: 0, Index: 59)...
#   Success! Adv label: 6, L2: 768.18, Queries: 77
# Attacking sample 5/100 (True: 0, Index: 64)...
#   Failed! Adv label: 0, L2: 1020.79, Queries: 201
# Attacking sample 6/100 (True: 0, Index: 75)...
#   Success! Adv label: 8, L2: 695.03, Queries: 75
# Attacking sample 7/100 (True: 0, Index: 80)...
#   Success! Adv label: 9, L2: 770.81, Queries: 87
# Attacking sample 8/100 (True: 0, Index: 97)...
#   Success! Adv label: 6, L2: 881.30, Queries: 111
# Attacking sample 9/100 (True: 0, Index: 115)...
#   Success! Adv label: 6, L2: 878.67, Queries: 93
# Attacking sample 10/100 (True: 0, Index: 141)...
#   Success! Adv label: 7, L2: 222.75, Queries: 23
# Attacking sample 11/100 (True: 0, Index: 146)...
#   Success! Adv label: 9, L2: 720.51, Queries: 81
# Attacking sample 12/100 (True: 0, Index: 156)...
#   Failed! Adv label: 0, L2: 828.88, Queries: 201
# Attacking sample 13/100 (True: 0, Index: 173)...
#   Success! Adv label: 3, L2: 725.16, Queries: 87
# Attacking sample 14/100 (True: 0, Index: 175)...
#   Success! Adv label: 8, L2: 494.19, Queries: 51
# Attacking sample 15/100 (True: 0, Index: 193)...
#   Success! Adv label: 9, L2: 900.32, Queries: 189
# Attacking sample 16/100 (True: 0, Index: 200)...
#   Success! Adv label: 9, L2: 701.51, Queries: 79
# Attacking sample 17/100 (True: 0, Index: 205)...
#   Success! Adv label: 9, L2: 803.32, Queries: 93
# Attacking sample 18/100 (True: 0, Index: 210)...
#   Success! Adv label: 8, L2: 717.53, Queries: 79
# Attacking sample 19/100 (True: 0, Index: 221)...
#   Success! Adv label: 3, L2: 727.80, Queries: 79
# Attacking sample 20/100 (True: 0, Index: 229)...
#   Failed! Adv label: 0, L2: 873.56, Queries: 201
# Attacking sample 21/100 (True: 0, Index: 249)...
#   Failed! Adv label: 0, L2: 782.97, Queries: 201
# Attacking sample 22/100 (True: 0, Index: 258)...
#   Success! Adv label: 8, L2: 830.43, Queries: 89
# Attacking sample 23/100 (True: 0, Index: 275)...
#   Failed! Adv label: 0, L2: 974.44, Queries: 201
# Attacking sample 24/100 (True: 0, Index: 292)...
#   Failed! Adv label: 0, L2: 829.75, Queries: 201
# Attacking sample 25/100 (True: 0, Index: 296)...
#   Success! Adv label: 9, L2: 708.99, Queries: 75
# Attacking sample 26/100 (True: 0, Index: 301)...
#   Success! Adv label: 9, L2: 716.16, Queries: 77
# Attacking sample 27/100 (True: 0, Index: 314)...
#   Success! Adv label: 6, L2: 720.04, Queries: 71
# Attacking sample 28/100 (True: 0, Index: 325)...
#   Failed! Adv label: 0, L2: 982.03, Queries: 201
# Attacking sample 29/100 (True: 0, Index: 333)...
#   Success! Adv label: 9, L2: 857.38, Queries: 111
# Attacking sample 30/100 (True: 0, Index: 345)...
#   Success! Adv label: 6, L2: 662.23, Queries: 65
# Attacking sample 31/100 (True: 0, Index: 349)...
#   Success! Adv label: 9, L2: 648.82, Queries: 69
# Attacking sample 32/100 (True: 0, Index: 360)...
#   Failed! Adv label: 0, L2: 1016.62, Queries: 201
# Attacking sample 33/100 (True: 0, Index: 365)...
#   Success! Adv label: 9, L2: 875.95, Queries: 175
# Attacking sample 34/100 (True: 0, Index: 366)...
#   Success! Adv label: 8, L2: 808.36, Queries: 85
# Attacking sample 35/100 (True: 0, Index: 379)...
#   Success! Adv label: 8, L2: 900.17, Queries: 97
# Attacking sample 36/100 (True: 0, Index: 385)...
#   Failed! Adv label: 0, L2: 992.08, Queries: 201
# Attacking sample 37/100 (True: 0, Index: 397)...
#   Failed! Adv label: 0, L2: 834.29, Queries: 201
# Attacking sample 38/100 (True: 0, Index: 400)...
#   Failed! Adv label: 0, L2: 1019.75, Queries: 201
# Attacking sample 39/100 (True: 0, Index: 405)...
#   Success! Adv label: 2, L2: 829.25, Queries: 85
# Attacking sample 40/100 (True: 0, Index: 410)...
#   Success! Adv label: 9, L2: 874.03, Queries: 99
# Attacking sample 41/100 (True: 0, Index: 420)...
#   Failed! Adv label: 0, L2: 915.15, Queries: 201
# Attacking sample 42/100 (True: 0, Index: 424)...
#   Failed! Adv label: 0, L2: 927.39, Queries: 201
# Attacking sample 43/100 (True: 0, Index: 447)...
#   Success! Adv label: 2, L2: 743.23, Queries: 83
# Attacking sample 44/100 (True: 0, Index: 453)...
#   Success! Adv label: 2, L2: 860.22, Queries: 93
# Attacking sample 45/100 (True: 0, Index: 457)...
#   Success! Adv label: 6, L2: 1020.06, Queries: 121
# Attacking sample 46/100 (True: 0, Index: 466)...
#   Success! Adv label: 2, L2: 858.50, Queries: 93
# Attacking sample 47/100 (True: 0, Index: 475)...
#   Success! Adv label: 9, L2: 291.55, Queries: 29
# Attacking sample 48/100 (True: 0, Index: 483)...
#   Failed! Adv label: 0, L2: 1031.83, Queries: 201
# Attacking sample 49/100 (True: 0, Index: 484)...
#   Success! Adv label: 8, L2: 510.86, Queries: 45
# Attacking sample 50/100 (True: 0, Index: 486)...
#   Failed! Adv label: 0, L2: 952.09, Queries: 201
# Attacking sample 51/100 (True: 0, Index: 487)...
#   Success! Adv label: 6, L2: 697.37, Queries: 73
# Attacking sample 52/100 (True: 0, Index: 489)...
#   Success! Adv label: 9, L2: 743.27, Queries: 79
# Attacking sample 53/100 (True: 0, Index: 492)...
#   Success! Adv label: 9, L2: 794.54, Queries: 83
# Attacking sample 54/100 (True: 0, Index: 506)...
#   Success! Adv label: 2, L2: 1019.35, Queries: 125
# Attacking sample 55/100 (True: 0, Index: 513)...
#   Failed! Adv label: 0, L2: 1003.67, Queries: 201
# Attacking sample 56/100 (True: 0, Index: 518)...
#   Failed! Adv label: 0, L2: 958.85, Queries: 201
# Attacking sample 57/100 (True: 0, Index: 521)...
#   Failed! Adv label: 0, L2: 955.40, Queries: 201
# Attacking sample 58/100 (True: 0, Index: 527)...
#   Success! Adv label: 2, L2: 773.46, Queries: 85
# Attacking sample 59/100 (True: 0, Index: 529)...
#   Failed! Adv label: 0, L2: 814.69, Queries: 201
# Attacking sample 60/100 (True: 0, Index: 531)...
#   Success! Adv label: 8, L2: 1018.68, Queries: 151
# Attacking sample 61/100 (True: 0, Index: 546)...
#   Success! Adv label: 9, L2: 637.81, Queries: 71
# Attacking sample 62/100 (True: 0, Index: 551)...
#   Success! Adv label: 6, L2: 434.56, Queries: 39
# Attacking sample 63/100 (True: 0, Index: 555)...
#   Success! Adv label: 6, L2: 1088.92, Queries: 137
# Attacking sample 64/100 (True: 0, Index: 587)...
#   Success! Adv label: 8, L2: 888.39, Queries: 97
# Attacking sample 65/100 (True: 0, Index: 604)...
#   Success! Adv label: 8, L2: 688.27, Queries: 65
# Attacking sample 66/100 (True: 0, Index: 614)...
#   Success! Adv label: 8, L2: 855.88, Queries: 89
# Attacking sample 67/100 (True: 0, Index: 615)...
#   Success! Adv label: 9, L2: 463.08, Queries: 43
# Attacking sample 68/100 (True: 0, Index: 618)...
#   Success! Adv label: 6, L2: 313.08, Queries: 29
# Attacking sample 69/100 (True: 0, Index: 638)...
#   Success! Adv label: 8, L2: 444.81, Queries: 41
# Attacking sample 70/100 (True: 0, Index: 642)...
#   Success! Adv label: 9, L2: 868.09, Queries: 117
# Attacking sample 71/100 (True: 0, Index: 655)...
#   Success! Adv label: 6, L2: 826.57, Queries: 81
# Attacking sample 72/100 (True: 0, Index: 658)...
#   Success! Adv label: 6, L2: 740.74, Queries: 75
# Attacking sample 73/100 (True: 0, Index: 665)...
#   Success! Adv label: 2, L2: 708.28, Queries: 73
# Attacking sample 74/100 (True: 0, Index: 671)...
#   Success! Adv label: 6, L2: 816.54, Queries: 83
# Attacking sample 75/100 (True: 0, Index: 681)...
#   Success! Adv label: 9, L2: 894.64, Queries: 101
# Attacking sample 76/100 (True: 0, Index: 691)...
#   Success! Adv label: 2, L2: 849.36, Queries: 87
# Attacking sample 77/100 (True: 0, Index: 700)...
#   Success! Adv label: 5, L2: 680.12, Queries: 75
# Attacking sample 78/100 (True: 0, Index: 706)...
#   Failed! Adv label: 0, L2: 754.08, Queries: 201
# Attacking sample 79/100 (True: 0, Index: 712)...
#   Success! Adv label: 3, L2: 903.95, Queries: 187
# Attacking sample 80/100 (True: 0, Index: 713)...
#   Success! Adv label: 9, L2: 760.23, Queries: 79
# Attacking sample 81/100 (True: 0, Index: 736)...
#   Success! Adv label: 9, L2: 803.00, Queries: 95
# Attacking sample 82/100 (True: 0, Index: 742)...
#   Success! Adv label: 8, L2: 694.79, Queries: 75
# Attacking sample 83/100 (True: 0, Index: 744)...
#   Success! Adv label: 2, L2: 630.16, Queries: 65
# Attacking sample 84/100 (True: 0, Index: 760)...
#   Success! Adv label: 9, L2: 643.79, Queries: 71
# Attacking sample 85/100 (True: 0, Index: 772)...
#   Success! Adv label: 9, L2: 350.48, Queries: 33
# Attacking sample 86/100 (True: 0, Index: 781)...
#   Success! Adv label: 6, L2: 523.20, Queries: 51
# Attacking sample 87/100 (True: 0, Index: 809)...
#   Failed! Adv label: 0, L2: 821.72, Queries: 201
# Attacking sample 88/100 (True: 0, Index: 813)...
#   Success! Adv label: 9, L2: 492.35, Queries: 53
# Attacking sample 89/100 (True: 0, Index: 820)...
#   Success! Adv label: 9, L2: 898.03, Queries: 165
# Attacking sample 90/100 (True: 0, Index: 823)...
#   Success! Adv label: 9, L2: 700.90, Queries: 87
# Attacking sample 91/100 (True: 0, Index: 844)...
#   Failed! Adv label: 0, L2: 1062.95, Queries: 201
# Attacking sample 92/100 (True: 0, Index: 848)...
#   Success! Adv label: 9, L2: 308.56, Queries: 29
# Attacking sample 93/100 (True: 0, Index: 861)...
#   Success! Adv label: 6, L2: 1050.38, Queries: 99
# Attacking sample 94/100 (True: 0, Index: 865)...
#   Failed! Adv label: 0, L2: 1162.53, Queries: 201
# Attacking sample 95/100 (True: 0, Index: 869)...
#   Success! Adv label: 6, L2: 1118.54, Queries: 175
# Attacking sample 96/100 (True: 0, Index: 876)...
#   Success! Adv label: 9, L2: 709.95, Queries: 73
# Attacking sample 97/100 (True: 0, Index: 885)...
#   Failed! Adv label: 0, L2: 967.46, Queries: 201
# Attacking sample 98/100 (True: 0, Index: 906)...
#   Success! Adv label: 3, L2: 1047.72, Queries: 191
# Attacking sample 99/100 (True: 0, Index: 907)...
#   Failed! Adv label: 0, L2: 1026.49, Queries: 201
# Attacking sample 100/100 (True: 0, Index: 918)...
#   Failed! Adv label: 0, L2: 947.88, Queries: 201
# Attacking sample 1/100 (True: 1, Index: 2)...
#   Success! Adv label: 7, L2: 375.40, Queries: 33
# Attacking sample 2/100 (True: 1, Index: 3)...
#   Success! Adv label: 7, L2: 440.05, Queries: 39
# Attacking sample 3/100 (True: 1, Index: 9)...
#   Success! Adv label: 2, L2: 373.82, Queries: 35
# Attacking sample 4/100 (True: 1, Index: 25)...
#   Success! Adv label: 4, L2: 403.61, Queries: 33
# Attacking sample 5/100 (True: 1, Index: 36)...
#   Success! Adv label: 2, L2: 352.16, Queries: 31
# Attacking sample 6/100 (True: 1, Index: 63)...
#   Success! Adv label: 8, L2: 355.58, Queries: 33
# Attacking sample 7/100 (True: 1, Index: 65)...
#   Success! Adv label: 8, L2: 413.95, Queries: 35
# Attacking sample 8/100 (True: 1, Index: 68)...
#   Success! Adv label: 4, L2: 428.68, Queries: 37
# Attacking sample 9/100 (True: 1, Index: 76)...
#   Success! Adv label: 8, L2: 277.67, Queries: 25
# Attacking sample 10/100 (True: 1, Index: 83)...
#   Success! Adv label: 4, L2: 392.59, Queries: 35
# Attacking sample 11/100 (True: 1, Index: 90)...
#   Success! Adv label: 9, L2: 27.89, Queries: 3
# Attacking sample 12/100 (True: 1, Index: 94)...
#   Success! Adv label: 8, L2: 233.47, Queries: 21
# Attacking sample 13/100 (True: 1, Index: 100)...
#   Success! Adv label: 8, L2: 306.98, Queries: 27
# Attacking sample 14/100 (True: 1, Index: 123)...
#   Success! Adv label: 8, L2: 255.58, Queries: 23
# Attacking sample 15/100 (True: 1, Index: 150)...
#   Success! Adv label: 8, L2: 438.47, Queries: 37
# Attacking sample 16/100 (True: 1, Index: 152)...
#   Success! Adv label: 9, L2: 391.58, Queries: 35
# Attacking sample 17/100 (True: 1, Index: 178)...
#   Success! Adv label: 4, L2: 411.55, Queries: 35
# Attacking sample 18/100 (True: 1, Index: 185)...
#   Success! Adv label: 8, L2: 429.89, Queries: 41
# Attacking sample 19/100 (True: 1, Index: 191)...
#   Success! Adv label: 4, L2: 426.04, Queries: 37
# Attacking sample 20/100 (True: 1, Index: 201)...
#   Success! Adv label: 8, L2: 361.06, Queries: 31
# Attacking sample 21/100 (True: 1, Index: 203)...
#   Success! Adv label: 4, L2: 325.96, Queries: 27
# Attacking sample 22/100 (True: 1, Index: 213)...
#   Success! Adv label: 8, L2: 335.21, Queries: 29
# Attacking sample 23/100 (True: 1, Index: 220)...
#   Success! Adv label: 8, L2: 304.50, Queries: 25
# Attacking sample 24/100 (True: 1, Index: 223)...
#   Success! Adv label: 4, L2: 396.80, Queries: 33
# Attacking sample 25/100 (True: 1, Index: 226)...
#   Success! Adv label: 4, L2: 346.38, Queries: 29
# Attacking sample 26/100 (True: 1, Index: 232)...
#   Success! Adv label: 4, L2: 499.66, Queries: 41
# Attacking sample 27/100 (True: 1, Index: 241)...
#   Success! Adv label: 4, L2: 291.59, Queries: 25
# Attacking sample 28/100 (True: 1, Index: 254)...
#   Success! Adv label: 4, L2: 349.46, Queries: 29
# Attacking sample 29/100 (True: 1, Index: 281)...
#   Success! Adv label: 8, L2: 327.17, Queries: 29
# Attacking sample 30/100 (True: 1, Index: 284)...
#   Success! Adv label: 8, L2: 384.03, Queries: 35
# Attacking sample 31/100 (True: 1, Index: 285)...
#   Success! Adv label: 9, L2: 256.79, Queries: 23
# Attacking sample 32/100 (True: 1, Index: 286)...
#   Success! Adv label: 4, L2: 335.91, Queries: 29
# Attacking sample 33/100 (True: 1, Index: 287)...
#   Success! Adv label: 4, L2: 341.36, Queries: 31
# Attacking sample 34/100 (True: 1, Index: 294)...
#   Success! Adv label: 4, L2: 409.56, Queries: 35
# Attacking sample 35/100 (True: 1, Index: 298)...
#   Success! Adv label: 4, L2: 465.96, Queries: 41
# Attacking sample 36/100 (True: 1, Index: 306)...
#   Success! Adv label: 4, L2: 439.39, Queries: 37
# Attacking sample 37/100 (True: 1, Index: 312)...
#   Success! Adv label: 8, L2: 373.95, Queries: 35
# Attacking sample 38/100 (True: 1, Index: 317)...
#   Success! Adv label: 4, L2: 373.76, Queries: 33
# Attacking sample 39/100 (True: 1, Index: 334)...
#   Success! Adv label: 4, L2: 450.15, Queries: 37
# Attacking sample 40/100 (True: 1, Index: 337)...
#   Success! Adv label: 8, L2: 427.18, Queries: 35
# Attacking sample 41/100 (True: 1, Index: 338)...
#   Success! Adv label: 4, L2: 515.80, Queries: 43
# Attacking sample 42/100 (True: 1, Index: 348)...
#   Success! Adv label: 2, L2: 522.62, Queries: 45
# Attacking sample 43/100 (True: 1, Index: 361)...
#   Success! Adv label: 9, L2: 320.81, Queries: 27
# Attacking sample 44/100 (True: 1, Index: 363)...
#   Success! Adv label: 8, L2: 407.12, Queries: 33
# Attacking sample 45/100 (True: 1, Index: 367)...
#   Success! Adv label: 8, L2: 219.13, Queries: 19
# Attacking sample 46/100 (True: 1, Index: 375)...
#   Success! Adv label: 9, L2: 498.44, Queries: 43
# Attacking sample 47/100 (True: 1, Index: 384)...
#   Success! Adv label: 8, L2: 338.91, Queries: 29
# Attacking sample 48/100 (True: 1, Index: 412)...
#   Success! Adv label: 9, L2: 512.00, Queries: 41
# Attacking sample 49/100 (True: 1, Index: 425)...
#   Success! Adv label: 9, L2: 453.91, Queries: 39
# Attacking sample 50/100 (True: 1, Index: 428)...
#   Success! Adv label: 4, L2: 418.34, Queries: 35
# Attacking sample 51/100 (True: 1, Index: 463)...
#   Success! Adv label: 4, L2: 299.67, Queries: 27
# Attacking sample 52/100 (True: 1, Index: 499)...
#   Success! Adv label: 4, L2: 466.02, Queries: 39
# Attacking sample 53/100 (True: 1, Index: 502)...
#   Success! Adv label: 4, L2: 437.66, Queries: 37
# Attacking sample 54/100 (True: 1, Index: 526)...
#   Success! Adv label: 8, L2: 302.27, Queries: 25
# Attacking sample 55/100 (True: 1, Index: 532)...
#   Success! Adv label: 4, L2: 402.82, Queries: 33
# Attacking sample 56/100 (True: 1, Index: 536)...
#   Success! Adv label: 9, L2: 286.45, Queries: 25
# Attacking sample 57/100 (True: 1, Index: 537)...
#   Success! Adv label: 8, L2: 418.82, Queries: 37
# Attacking sample 58/100 (True: 1, Index: 539)...
#   Success! Adv label: 4, L2: 445.81, Queries: 37
# Attacking sample 60/100 (True: 1, Index: 560)...
#   Success! Adv label: 4, L2: 393.07, Queries: 33
# Attacking sample 61/100 (True: 1, Index: 561)...
#   Success! Adv label: 8, L2: 314.34, Queries: 27
# Attacking sample 62/100 (True: 1, Index: 570)...
#   Success! Adv label: 8, L2: 381.41, Queries: 33
# Attacking sample 63/100 (True: 1, Index: 573)...
#   Success! Adv label: 2, L2: 30.77, Queries: 3
# Attacking sample 64/100 (True: 1, Index: 576)...
#   Success! Adv label: 7, L2: 389.80, Queries: 37
# Attacking sample 65/100 (True: 1, Index: 580)...
#   Success! Adv label: 4, L2: 340.30, Queries: 29
# Attacking sample 66/100 (True: 1, Index: 588)...
#   Success! Adv label: 7, L2: 522.70, Queries: 47
# Attacking sample 67/100 (True: 1, Index: 620)...
#   Success! Adv label: 4, L2: 388.30, Queries: 33
# Attacking sample 68/100 (True: 1, Index: 621)...
#   Success! Adv label: 4, L2: 383.16, Queries: 33
# Attacking sample 69/100 (True: 1, Index: 622)...
#   Success! Adv label: 2, L2: 125.01, Queries: 11
# Attacking sample 70/100 (True: 1, Index: 627)...
#   Success! Adv label: 8, L2: 324.96, Queries: 29
# Attacking sample 71/100 (True: 1, Index: 630)...
#   Success! Adv label: 4, L2: 278.55, Queries: 23
# Attacking sample 72/100 (True: 1, Index: 632)...
#   Success! Adv label: 4, L2: 305.25, Queries: 25
# Attacking sample 73/100 (True: 1, Index: 644)...
#   Success! Adv label: 4, L2: 340.55, Queries: 29
# Attacking sample 74/100 (True: 1, Index: 646)...
#   Success! Adv label: 7, L2: 384.51, Queries: 37
# Attacking sample 75/100 (True: 1, Index: 649)...
#   Success! Adv label: 4, L2: 445.19, Queries: 37
# Attacking sample 76/100 (True: 1, Index: 662)...
#   Success! Adv label: 4, L2: 468.53, Queries: 39
# Attacking sample 77/100 (True: 1, Index: 663)...
#   Success! Adv label: 4, L2: 347.69, Queries: 29
# Attacking sample 78/100 (True: 1, Index: 669)...
#   Success! Adv label: 9, L2: 504.16, Queries: 43
# Attacking sample 79/100 (True: 1, Index: 677)...
#   Success! Adv label: 9, L2: 288.17, Queries: 25
# Attacking sample 80/100 (True: 1, Index: 686)...
#   Success! Adv label: 8, L2: 427.22, Queries: 37
# Attacking sample 81/100 (True: 1, Index: 689)...
#   Success! Adv label: 4, L2: 411.39, Queries: 33
# Attacking sample 82/100 (True: 1, Index: 703)...
#   Success! Adv label: 8, L2: 437.90, Queries: 37
# Attacking sample 83/100 (True: 1, Index: 705)...
#   Success! Adv label: 4, L2: 521.31, Queries: 47
# Attacking sample 84/100 (True: 1, Index: 709)...
#   Success! Adv label: 4, L2: 338.91, Queries: 31
# Attacking sample 85/100 (True: 1, Index: 724)...
#   Success! Adv label: 4, L2: 269.32, Queries: 23
# Attacking sample 86/100 (True: 1, Index: 727)...
#   Success! Adv label: 8, L2: 351.86, Queries: 29
# Attacking sample 87/100 (True: 1, Index: 734)...
#   Success! Adv label: 8, L2: 246.16, Queries: 23
# Attacking sample 88/100 (True: 1, Index: 740)...
#   Success! Adv label: 4, L2: 398.79, Queries: 33
# Attacking sample 89/100 (True: 1, Index: 741)...
#   Success! Adv label: 8, L2: 305.31, Queries: 27
# Attacking sample 90/100 (True: 1, Index: 743)...
#   Success! Adv label: 8, L2: 361.48, Queries: 29
# Attacking sample 91/100 (True: 1, Index: 759)...
#   Success! Adv label: 4, L2: 397.69, Queries: 35
# Attacking sample 92/100 (True: 1, Index: 768)...
#   Success! Adv label: 8, L2: 344.03, Queries: 29
# Attacking sample 93/100 (True: 1, Index: 775)...
#   Success! Adv label: 4, L2: 286.33, Queries: 25
# Attacking sample 94/100 (True: 1, Index: 782)...
#   Success! Adv label: 4, L2: 400.40, Queries: 35
# Attacking sample 95/100 (True: 1, Index: 798)...
#   Success! Adv label: 9, L2: 362.49, Queries: 33
# Attacking sample 96/100 (True: 1, Index: 799)...
#   Success! Adv label: 8, L2: 496.90, Queries: 41
# Attacking sample 97/100 (True: 1, Index: 808)...
#   Success! Adv label: 4, L2: 399.86, Queries: 35
# Attacking sample 98/100 (True: 1, Index: 819)...
#   Success! Adv label: 4, L2: 523.18, Queries: 43
# Attacking sample 99/100 (True: 1, Index: 843)...
#   Success! Adv label: 4, L2: 518.21, Queries: 43
# Attacking sample 100/100 (True: 1, Index: 853)...
#   Success! Adv label: 4, L2: 410.52, Queries: 35
# Attacking sample 1/100 (True: 2, Index: 4)...
#   Success! Adv label: 3, L2: 603.99, Queries: 59
# Attacking sample 2/100 (True: 2, Index: 22)...
#   Success! Adv label: 1, L2: 814.04, Queries: 135
# Attacking sample 3/100 (True: 2, Index: 32)...
#   Success! Adv label: 3, L2: 998.76, Queries: 99
# Attacking sample 4/100 (True: 2, Index: 34)...
#   Success! Adv label: 4, L2: 43.97, Queries: 5
# Attacking sample 5/100 (True: 2, Index: 42)...
#   Success! Adv label: 3, L2: 242.67, Queries: 23
# Attacking sample 6/100 (True: 2, Index: 49)...
#   Success! Adv label: 3, L2: 877.84, Queries: 139
# Attacking sample 7/100 (True: 2, Index: 52)...
#   Success! Adv label: 3, L2: 907.35, Queries: 121
# Attacking sample 8/100 (True: 2, Index: 69)...
#   Success! Adv label: 3, L2: 927.05, Queries: 91
# Attacking sample 9/100 (True: 2, Index: 70)...
#   Success! Adv label: 3, L2: 594.26, Queries: 71
# Attacking sample 10/100 (True: 2, Index: 81)...
#   Success! Adv label: 8, L2: 1090.82, Queries: 99
# Attacking sample 11/100 (True: 2, Index: 110)...
#   Failed! Adv label: 2, L2: 1035.93, Queries: 201
# Attacking sample 12/100 (True: 2, Index: 118)...
#   Success! Adv label: 3, L2: 613.63, Queries: 59
# Attacking sample 13/100 (True: 2, Index: 121)...
#   Success! Adv label: 3, L2: 741.31, Queries: 69
# Attacking sample 14/100 (True: 2, Index: 138)...
#   Success! Adv label: 3, L2: 845.38, Queries: 89
# Attacking sample 15/100 (True: 2, Index: 144)...
#   Success! Adv label: 3, L2: 762.53, Queries: 75
# Attacking sample 16/100 (True: 2, Index: 155)...
#   Success! Adv label: 8, L2: 921.98, Queries: 81
# Attacking sample 17/100 (True: 2, Index: 160)...
#   Success! Adv label: 6, L2: 445.18, Queries: 47
# Attacking sample 18/100 (True: 2, Index: 161)...
#   Success! Adv label: 3, L2: 686.71, Queries: 67
# Attacking sample 19/100 (True: 2, Index: 176)...
#   Success! Adv label: 3, L2: 732.25, Queries: 69
# Attacking sample 21/100 (True: 2, Index: 186)...
#   Success! Adv label: 3, L2: 849.28, Queries: 125
# Attacking sample 22/100 (True: 2, Index: 197)...
#   Success! Adv label: 8, L2: 1007.52, Queries: 113
# Attacking sample 23/100 (True: 2, Index: 208)...
#   Success! Adv label: 3, L2: 1031.13, Queries: 121
# Attacking sample 25/100 (True: 2, Index: 216)...
#   Success! Adv label: 3, L2: 847.09, Queries: 93
# Attacking sample 26/100 (True: 2, Index: 219)...
#   Success! Adv label: 3, L2: 457.46, Queries: 47
# Attacking sample 27/100 (True: 2, Index: 235)...
#   Success! Adv label: 3, L2: 804.65, Queries: 87
# Attacking sample 28/100 (True: 2, Index: 260)...
#   Success! Adv label: 0, L2: 647.74, Queries: 63
# Attacking sample 29/100 (True: 2, Index: 276)...
#   Success! Adv label: 4, L2: 593.63, Queries: 67
# Attacking sample 30/100 (True: 2, Index: 293)...
#   Success! Adv label: 3, L2: 728.42, Queries: 85
# Attacking sample 31/100 (True: 2, Index: 295)...
#   Success! Adv label: 3, L2: 605.63, Queries: 63
# Attacking sample 32/100 (True: 2, Index: 311)...
#   Success! Adv label: 3, L2: 564.05, Queries: 55
# Attacking sample 33/100 (True: 2, Index: 313)...
#   Success! Adv label: 3, L2: 145.46, Queries: 15
# Attacking sample 34/100 (True: 2, Index: 322)...
#   Success! Adv label: 0, L2: 740.42, Queries: 77
# Attacking sample 35/100 (True: 2, Index: 328)...
#   Success! Adv label: 8, L2: 790.08, Queries: 77
# Attacking sample 36/100 (True: 2, Index: 357)...
#   Success! Adv label: 7, L2: 573.29, Queries: 57
# Attacking sample 37/100 (True: 2, Index: 374)...
#   Success! Adv label: 8, L2: 549.53, Queries: 53
# Attacking sample 38/100 (True: 2, Index: 395)...
#   Success! Adv label: 8, L2: 446.23, Queries: 47
# Attacking sample 39/100 (True: 2, Index: 396)...
#   Success! Adv label: 8, L2: 725.60, Queries: 71
# Attacking sample 40/100 (True: 2, Index: 398)...
#   Success! Adv label: 3, L2: 809.75, Queries: 87
# Attacking sample 41/100 (True: 2, Index: 433)...
#   Success! Adv label: 3, L2: 708.21, Queries: 69
# Attacking sample 42/100 (True: 2, Index: 439)...
#   Success! Adv label: 9, L2: 816.99, Queries: 79
# Attacking sample 43/100 (True: 2, Index: 441)...
#   Success! Adv label: 8, L2: 398.98, Queries: 35
# Attacking sample 44/100 (True: 2, Index: 442)...
#   Success! Adv label: 3, L2: 863.51, Queries: 85
# Attacking sample 45/100 (True: 2, Index: 451)...
#   Failed! Adv label: 2, L2: 1142.41, Queries: 201
# Attacking sample 46/100 (True: 2, Index: 462)...
#   Success! Adv label: 3, L2: 682.58, Queries: 63
# Attacking sample 47/100 (True: 2, Index: 470)...
#   Success! Adv label: 3, L2: 666.20, Queries: 63
# Attacking sample 48/100 (True: 2, Index: 477)...
#   Success! Adv label: 3, L2: 879.33, Queries: 93
# Attacking sample 49/100 (True: 2, Index: 485)...
#   Success! Adv label: 7, L2: 240.73, Queries: 23
# Attacking sample 50/100 (True: 2, Index: 491)...
#   Success! Adv label: 8, L2: 740.42, Queries: 65
# Attacking sample 51/100 (True: 2, Index: 493)...
#   Success! Adv label: 7, L2: 870.15, Queries: 123
# Attacking sample 52/100 (True: 2, Index: 495)...
#   Success! Adv label: 3, L2: 682.21, Queries: 69
# Attacking sample 53/100 (True: 2, Index: 519)...
#   Success! Adv label: 3, L2: 860.79, Queries: 85
# Attacking sample 54/100 (True: 2, Index: 523)...
#   Success! Adv label: 6, L2: 780.65, Queries: 85
# Attacking sample 55/100 (True: 2, Index: 557)...
#   Success! Adv label: 8, L2: 900.52, Queries: 83
# Attacking sample 56/100 (True: 2, Index: 567)...
#   Success! Adv label: 0, L2: 576.50, Queries: 55
# Attacking sample 57/100 (True: 2, Index: 571)...
#   Success! Adv label: 7, L2: 786.34, Queries: 83
# Attacking sample 58/100 (True: 2, Index: 584)...
#   Success! Adv label: 3, L2: 965.03, Queries: 99
# Attacking sample 59/100 (True: 2, Index: 591)...
#   Success! Adv label: 3, L2: 943.88, Queries: 143
# Attacking sample 60/100 (True: 2, Index: 592)...
#   Success! Adv label: 3, L2: 850.88, Queries: 111
# Attacking sample 61/100 (True: 2, Index: 610)...
#   Failed! Adv label: 2, L2: 1075.92, Queries: 201
# Attacking sample 62/100 (True: 2, Index: 612)...
#   Success! Adv label: 8, L2: 808.98, Queries: 71
# Attacking sample 63/100 (True: 2, Index: 616)...
#   Success! Adv label: 3, L2: 890.02, Queries: 87
# Attacking sample 64/100 (True: 2, Index: 624)...
#   Success! Adv label: 3, L2: 779.45, Queries: 73
# Attacking sample 65/100 (True: 2, Index: 631)...
#   Success! Adv label: 3, L2: 570.99, Queries: 59
# Attacking sample 66/100 (True: 2, Index: 636)...
#   Success! Adv label: 3, L2: 889.46, Queries: 83
# Attacking sample 67/100 (True: 2, Index: 647)...
#   Success! Adv label: 1, L2: 140.27, Queries: 15
# Attacking sample 68/100 (True: 2, Index: 650)...
#   Success! Adv label: 3, L2: 235.47, Queries: 23
# Attacking sample 69/100 (True: 2, Index: 664)...
#   Success! Adv label: 3, L2: 1060.77, Queries: 155
# Attacking sample 70/100 (True: 2, Index: 704)...
#   Success! Adv label: 3, L2: 699.11, Queries: 71
# Attacking sample 71/100 (True: 2, Index: 720)...
#   Success! Adv label: 4, L2: 258.68, Queries: 25
# Attacking sample 72/100 (True: 2, Index: 725)...
#   Success! Adv label: 3, L2: 516.86, Queries: 49
# Attacking sample 73/100 (True: 2, Index: 750)...
#   Success! Adv label: 3, L2: 841.13, Queries: 173
# Attacking sample 74/100 (True: 2, Index: 764)...
#   Success! Adv label: 3, L2: 604.93, Queries: 75
# Attacking sample 75/100 (True: 2, Index: 780)...
#   Success! Adv label: 8, L2: 892.09, Queries: 87
# Attacking sample 76/100 (True: 2, Index: 784)...
#   Success! Adv label: 8, L2: 983.16, Queries: 95
# Attacking sample 77/100 (True: 2, Index: 788)...
#   Success! Adv label: 1, L2: 592.42, Queries: 57
# Attacking sample 78/100 (True: 2, Index: 790)...
#   Success! Adv label: 3, L2: 932.90, Queries: 133
# Attacking sample 79/100 (True: 2, Index: 797)...
#   Success! Adv label: 8, L2: 628.71, Queries: 59
# Attacking sample 80/100 (True: 2, Index: 803)...
#   Success! Adv label: 0, L2: 1008.35, Queries: 93
# Attacking sample 81/100 (True: 2, Index: 807)...
#   Failed! Adv label: 2, L2: 992.32, Queries: 201
# Attacking sample 82/100 (True: 2, Index: 828)...
#   Success! Adv label: 3, L2: 504.92, Queries: 49
# Attacking sample 83/100 (True: 2, Index: 842)...
#   Success! Adv label: 3, L2: 738.42, Queries: 79
# Attacking sample 84/100 (True: 2, Index: 845)...
#   Success! Adv label: 3, L2: 967.36, Queries: 89
# Attacking sample 85/100 (True: 2, Index: 859)...
#   Success! Adv label: 3, L2: 511.88, Queries: 49
# Attacking sample 86/100 (True: 2, Index: 871)...
#   Success! Adv label: 7, L2: 744.14, Queries: 77
# Attacking sample 87/100 (True: 2, Index: 881)...
#   Success! Adv label: 3, L2: 630.12, Queries: 77
# Attacking sample 88/100 (True: 2, Index: 883)...
#   Success! Adv label: 0, L2: 450.55, Queries: 43
# Attacking sample 89/100 (True: 2, Index: 896)...
#   Success! Adv label: 3, L2: 523.44, Queries: 53
# Attacking sample 90/100 (True: 2, Index: 897)...
#   Success! Adv label: 3, L2: 560.55, Queries: 67
# Attacking sample 92/100 (True: 2, Index: 922)...
#   Success! Adv label: 7, L2: 585.47, Queries: 61
# Attacking sample 93/100 (True: 2, Index: 932)...
#   Success! Adv label: 8, L2: 804.52, Queries: 77
# Attacking sample 94/100 (True: 2, Index: 944)...
#   Success! Adv label: 3, L2: 558.38, Queries: 53
# Attacking sample 95/100 (True: 2, Index: 949)...
#   Success! Adv label: 3, L2: 829.78, Queries: 79
# Attacking sample 96/100 (True: 2, Index: 952)...
#   Failed! Adv label: 2, L2: 917.85, Queries: 201
# Attacking sample 97/100 (True: 2, Index: 959)...
#   Success! Adv label: 3, L2: 654.83, Queries: 61
# Attacking sample 98/100 (True: 2, Index: 966)...
#   Success! Adv label: 7, L2: 237.34, Queries: 25
# Attacking sample 99/100 (True: 2, Index: 967)...
#   Success! Adv label: 7, L2: 849.64, Queries: 93
# Attacking sample 100/100 (True: 2, Index: 985)...
#   Success! Adv label: 3, L2: 719.67, Queries: 77
# Attacking sample 1/100 (True: 3, Index: 1)...
#   Success! Adv label: 5, L2: 406.39, Queries: 37
# Attacking sample 2/100 (True: 3, Index: 12)...
#   Success! Adv label: 8, L2: 385.50, Queries: 41
# Attacking sample 3/100 (True: 3, Index: 20)...
#   Success! Adv label: 8, L2: 799.74, Queries: 73
# Attacking sample 4/100 (True: 3, Index: 27)...
#   Success! Adv label: 2, L2: 867.97, Queries: 127
# Attacking sample 5/100 (True: 3, Index: 37)...
#   Success! Adv label: 2, L2: 971.25, Queries: 119
# Attacking sample 6/100 (True: 3, Index: 43)...
#   Failed! Adv label: 3, L2: 922.51, Queries: 201
# Attacking sample 7/100 (True: 3, Index: 53)...
#   Success! Adv label: 8, L2: 607.99, Queries: 57
# Attacking sample 8/100 (True: 3, Index: 61)...
#   Success! Adv label: 8, L2: 662.89, Queries: 61
# Attacking sample 9/100 (True: 3, Index: 73)...
#   Success! Adv label: 8, L2: 713.03, Queries: 75
# Attacking sample 10/100 (True: 3, Index: 102)...
#   Success! Adv label: 2, L2: 457.73, Queries: 43
# Attacking sample 11/100 (True: 3, Index: 108)...
#   Success! Adv label: 2, L2: 87.64, Queries: 9
# Attacking sample 12/100 (True: 3, Index: 109)...
#   Success! Adv label: 8, L2: 591.09, Queries: 51
# Attacking sample 13/100 (True: 3, Index: 117)...
#   Success! Adv label: 5, L2: 963.22, Queries: 171
# Attacking sample 14/100 (True: 3, Index: 131)...
#   Success! Adv label: 8, L2: 175.16, Queries: 15
# Attacking sample 15/100 (True: 3, Index: 159)...
#   Success! Adv label: 2, L2: 930.81, Queries: 111
# Attacking sample 16/100 (True: 3, Index: 162)...
#   Success! Adv label: 8, L2: 984.89, Queries: 183
# Attacking sample 17/100 (True: 3, Index: 166)...
#   Success! Adv label: 2, L2: 804.51, Queries: 125
# Attacking sample 18/100 (True: 3, Index: 177)...
#   Success! Adv label: 2, L2: 609.32, Queries: 53
# Attacking sample 19/100 (True: 3, Index: 181)...
#   Success! Adv label: 5, L2: 679.29, Queries: 83
# Attacking sample 20/100 (True: 3, Index: 187)...
#   Success! Adv label: 8, L2: 714.52, Queries: 63
# Attacking sample 21/100 (True: 3, Index: 196)...
#   Success! Adv label: 2, L2: 514.93, Queries: 45
# Attacking sample 22/100 (True: 3, Index: 204)...
#   Failed! Adv label: 3, L2: 986.96, Queries: 201
# Attacking sample 23/100 (True: 3, Index: 227)...
#   Failed! Adv label: 3, L2: 826.19, Queries: 201
# Attacking sample 24/100 (True: 3, Index: 231)...
#   Success! Adv label: 5, L2: 781.36, Queries: 79
# Attacking sample 25/100 (True: 3, Index: 237)...
#   Success! Adv label: 8, L2: 1004.42, Queries: 145
# Attacking sample 26/100 (True: 3, Index: 244)...
#   Failed! Adv label: 3, L2: 921.26, Queries: 201
# Attacking sample 27/100 (True: 3, Index: 257)...
#   Success! Adv label: 8, L2: 605.65, Queries: 55
# Attacking sample 28/100 (True: 3, Index: 259)...
#   Success! Adv label: 5, L2: 972.58, Queries: 131
# Attacking sample 29/100 (True: 3, Index: 265)...
#   Success! Adv label: 5, L2: 575.82, Queries: 55
# Attacking sample 30/100 (True: 3, Index: 270)...
#   Success! Adv label: 5, L2: 275.94, Queries: 25
# Attacking sample 31/100 (True: 3, Index: 288)...
#   Success! Adv label: 8, L2: 965.20, Queries: 87
# Attacking sample 32/100 (True: 3, Index: 308)...
#   Success! Adv label: 8, L2: 612.05, Queries: 59
# Attacking sample 33/100 (True: 3, Index: 309)...
#   Success! Adv label: 8, L2: 591.97, Queries: 57
# Attacking sample 34/100 (True: 3, Index: 327)...
#   Success! Adv label: 1, L2: 378.53, Queries: 43
# Attacking sample 35/100 (True: 3, Index: 331)...
#   Success! Adv label: 8, L2: 808.28, Queries: 87
# Attacking sample 36/100 (True: 3, Index: 340)...
#   Success! Adv label: 2, L2: 1058.03, Queries: 127
# Attacking sample 37/100 (True: 3, Index: 341)...
#   Success! Adv label: 5, L2: 812.42, Queries: 85
# Attacking sample 38/100 (True: 3, Index: 342)...
#   Success! Adv label: 5, L2: 526.27, Queries: 51
# Attacking sample 39/100 (True: 3, Index: 362)...
#   Success! Adv label: 2, L2: 537.04, Queries: 51
# Attacking sample 40/100 (True: 3, Index: 383)...
#   Success! Adv label: 2, L2: 557.64, Queries: 55
# Attacking sample 41/100 (True: 3, Index: 394)...
#   Success! Adv label: 8, L2: 535.07, Queries: 49
# Attacking sample 42/100 (True: 3, Index: 406)...
#   Failed! Adv label: 3, L2: 834.87, Queries: 201
# Attacking sample 43/100 (True: 3, Index: 409)...
#   Success! Adv label: 2, L2: 914.51, Queries: 105
# Attacking sample 44/100 (True: 3, Index: 445)...
#   Success! Adv label: 2, L2: 403.90, Queries: 37
# Attacking sample 45/100 (True: 3, Index: 456)...
#   Success! Adv label: 8, L2: 607.53, Queries: 55
# Attacking sample 46/100 (True: 3, Index: 459)...
#   Failed! Adv label: 3, L2: 943.51, Queries: 201
# Attacking sample 47/100 (True: 3, Index: 461)...
#   Failed! Adv label: 3, L2: 987.13, Queries: 201
# Attacking sample 48/100 (True: 3, Index: 471)...
#   Success! Adv label: 8, L2: 896.09, Queries: 83
# Attacking sample 49/100 (True: 3, Index: 474)...
#   Success! Adv label: 5, L2: 555.24, Queries: 57
# Attacking sample 50/100 (True: 3, Index: 481)...
#   Success! Adv label: 5, L2: 825.08, Queries: 93
# Attacking sample 51/100 (True: 3, Index: 504)...
#   Success! Adv label: 8, L2: 725.79, Queries: 79
# Attacking sample 52/100 (True: 3, Index: 510)...
#   Success! Adv label: 5, L2: 365.41, Queries: 35
# Attacking sample 53/100 (True: 3, Index: 512)...
#   Failed! Adv label: 3, L2: 834.86, Queries: 201
# Attacking sample 54/100 (True: 3, Index: 524)...
#   Success! Adv label: 8, L2: 674.23, Queries: 61
# Attacking sample 55/100 (True: 3, Index: 549)...
#   Success! Adv label: 2, L2: 547.82, Queries: 57
# Attacking sample 56/100 (True: 3, Index: 556)...
#   Success! Adv label: 9, L2: 767.87, Queries: 79
# Attacking sample 57/100 (True: 3, Index: 564)...
#   Success! Adv label: 8, L2: 594.46, Queries: 55
# Attacking sample 58/100 (True: 3, Index: 586)...
#   Failed! Adv label: 3, L2: 902.61, Queries: 201
# Attacking sample 59/100 (True: 3, Index: 589)...
#   Success! Adv label: 0, L2: 1074.65, Queries: 165
# Attacking sample 60/100 (True: 3, Index: 609)...
#   Success! Adv label: 9, L2: 833.90, Queries: 87
# Attacking sample 61/100 (True: 3, Index: 613)...
#   Success! Adv label: 8, L2: 711.51, Queries: 65
# Attacking sample 62/100 (True: 3, Index: 623)...
#   Success! Adv label: 9, L2: 466.78, Queries: 43
# Attacking sample 63/100 (True: 3, Index: 639)...
#   Success! Adv label: 5, L2: 902.17, Queries: 99
# Attacking sample 64/100 (True: 3, Index: 648)...
#   Success! Adv label: 8, L2: 527.77, Queries: 47
# Attacking sample 65/100 (True: 3, Index: 651)...
#   Success! Adv label: 8, L2: 446.79, Queries: 41
# Attacking sample 66/100 (True: 3, Index: 659)...
#   Success! Adv label: 9, L2: 804.60, Queries: 85
# Attacking sample 67/100 (True: 3, Index: 661)...
#   Success! Adv label: 8, L2: 1076.05, Queries: 185
# Attacking sample 68/100 (True: 3, Index: 667)...
#   Failed! Adv label: 3, L2: 854.78, Queries: 201
# Attacking sample 69/100 (True: 3, Index: 678)...
#   Failed! Adv label: 3, L2: 832.53, Queries: 201
# Attacking sample 70/100 (True: 3, Index: 690)...
#   Success! Adv label: 8, L2: 1019.94, Queries: 93
# Attacking sample 71/100 (True: 3, Index: 693)...
#   Failed! Adv label: 3, L2: 802.55, Queries: 201
# Attacking sample 72/100 (True: 3, Index: 694)...
#   Success! Adv label: 8, L2: 892.43, Queries: 83
# Attacking sample 73/100 (True: 3, Index: 695)...
#   Success! Adv label: 0, L2: 274.76, Queries: 25
# Attacking sample 74/100 (True: 3, Index: 702)...
#   Success! Adv label: 8, L2: 445.24, Queries: 39
# Attacking sample 75/100 (True: 3, Index: 718)...
#   Failed! Adv label: 3, L2: 894.30, Queries: 201
# Attacking sample 76/100 (True: 3, Index: 749)...
#   Success! Adv label: 8, L2: 1002.03, Queries: 159
# Attacking sample 77/100 (True: 3, Index: 769)...
#   Success! Adv label: 2, L2: 935.21, Queries: 85
# Attacking sample 79/100 (True: 3, Index: 779)...
#   Success! Adv label: 8, L2: 451.05, Queries: 43
# Attacking sample 80/100 (True: 3, Index: 800)...
#   Success! Adv label: 8, L2: 914.04, Queries: 79
# Attacking sample 81/100 (True: 3, Index: 816)...
#   Success! Adv label: 5, L2: 334.79, Queries: 35
# Attacking sample 82/100 (True: 3, Index: 829)...
#   Success! Adv label: 2, L2: 568.22, Queries: 53
# Attacking sample 83/100 (True: 3, Index: 833)...
#   Failed! Adv label: 3, L2: 865.75, Queries: 201
# Attacking sample 84/100 (True: 3, Index: 839)...
#   Success! Adv label: 8, L2: 709.16, Queries: 69
# Attacking sample 85/100 (True: 3, Index: 854)...
#   Success! Adv label: 5, L2: 365.52, Queries: 37
# Attacking sample 86/100 (True: 3, Index: 856)...
#   Success! Adv label: 2, L2: 485.26, Queries: 49
# Attacking sample 87/100 (True: 3, Index: 858)...
#   Success! Adv label: 5, L2: 129.38, Queries: 13
# Attacking sample 89/100 (True: 3, Index: 886)...
#   Success! Adv label: 8, L2: 887.41, Queries: 83
# Attacking sample 90/100 (True: 3, Index: 900)...
#   Success! Adv label: 8, L2: 736.72, Queries: 69
# Attacking sample 91/100 (True: 3, Index: 916)...
#   Success! Adv label: 5, L2: 539.20, Queries: 63
# Attacking sample 92/100 (True: 3, Index: 921)...
#   Success! Adv label: 2, L2: 479.38, Queries: 49
# Attacking sample 93/100 (True: 3, Index: 937)...
#   Success! Adv label: 9, L2: 998.08, Queries: 93
# Attacking sample 94/100 (True: 3, Index: 938)...
#   Success! Adv label: 8, L2: 801.33, Queries: 67
# Attacking sample 95/100 (True: 3, Index: 939)...
#   Success! Adv label: 8, L2: 388.97, Queries: 35
# Attacking sample 96/100 (True: 3, Index: 942)...
#   Success! Adv label: 5, L2: 993.25, Queries: 153
# Attacking sample 97/100 (True: 3, Index: 951)...
#   Success! Adv label: 8, L2: 624.10, Queries: 59
# Attacking sample 98/100 (True: 3, Index: 953)...
#   Failed! Adv label: 3, L2: 890.71, Queries: 201
# Attacking sample 99/100 (True: 3, Index: 975)...
#   Failed! Adv label: 3, L2: 1024.38, Queries: 201
# Attacking sample 1/100 (True: 4, Index: 16)...
#   Success! Adv label: 9, L2: 342.14, Queries: 33
# Attacking sample 2/100 (True: 4, Index: 17)...
#   Success! Adv label: 6, L2: 446.02, Queries: 43
# Attacking sample 3/100 (True: 4, Index: 30)...
#   Success! Adv label: 8, L2: 901.61, Queries: 87
# Attacking sample 4/100 (True: 4, Index: 33)...
#   Success! Adv label: 9, L2: 543.55, Queries: 51
# Attacking sample 5/100 (True: 4, Index: 45)...
#   Success! Adv label: 8, L2: 144.40, Queries: 13
# Attacking sample 6/100 (True: 4, Index: 48)...
#   Success! Adv label: 9, L2: 786.64, Queries: 73
# Attacking sample 7/100 (True: 4, Index: 58)...
#   Success! Adv label: 9, L2: 776.09, Queries: 71
# Attacking sample 8/100 (True: 4, Index: 66)...
#   Success! Adv label: 6, L2: 664.04, Queries: 67
# Attacking sample 9/100 (True: 4, Index: 89)...
#   Success! Adv label: 9, L2: 381.72, Queries: 35
# Attacking sample 10/100 (True: 4, Index: 92)...
#   Success! Adv label: 6, L2: 925.18, Queries: 91
# Attacking sample 11/100 (True: 4, Index: 113)...
#   Success! Adv label: 2, L2: 789.89, Queries: 77
# Attacking sample 12/100 (True: 4, Index: 116)...
#   Success! Adv label: 9, L2: 679.92, Queries: 61
# Attacking sample 13/100 (True: 4, Index: 126)...
#   Success! Adv label: 9, L2: 529.60, Queries: 49
# Attacking sample 14/100 (True: 4, Index: 130)...
#   Success! Adv label: 9, L2: 388.75, Queries: 35
# Attacking sample 15/100 (True: 4, Index: 139)...
#   Success! Adv label: 9, L2: 607.05, Queries: 55
# Attacking sample 16/100 (True: 4, Index: 149)...
#   Failed! Adv label: 4, L2: 1075.92, Queries: 201
# Attacking sample 17/100 (True: 4, Index: 153)...
#   Success! Adv label: 8, L2: 490.76, Queries: 45
# Attacking sample 18/100 (True: 4, Index: 154)...
#   Success! Adv label: 7, L2: 959.28, Queries: 93
# Attacking sample 19/100 (True: 4, Index: 163)...
#   Success! Adv label: 9, L2: 627.35, Queries: 59
# Attacking sample 20/100 (True: 4, Index: 167)...
#   Success! Adv label: 9, L2: 830.95, Queries: 81
# Attacking sample 21/100 (True: 4, Index: 183)...
#   Success! Adv label: 9, L2: 458.50, Queries: 45
# Attacking sample 22/100 (True: 4, Index: 184)...
#   Success! Adv label: 9, L2: 609.62, Queries: 57
# Attacking sample 23/100 (True: 4, Index: 192)...
#   Success! Adv label: 9, L2: 294.92, Queries: 27
# Attacking sample 24/100 (True: 4, Index: 194)...
#   Success! Adv label: 9, L2: 506.91, Queries: 49
# Attacking sample 25/100 (True: 4, Index: 233)...
#   Success! Adv label: 9, L2: 702.81, Queries: 67
# Attacking sample 26/100 (True: 4, Index: 240)...
#   Success! Adv label: 8, L2: 626.05, Queries: 55
# Attacking sample 27/100 (True: 4, Index: 263)...
#   Success! Adv label: 9, L2: 323.52, Queries: 29
# Attacking sample 28/100 (True: 4, Index: 269)...
#   Success! Adv label: 9, L2: 450.14, Queries: 41
# Attacking sample 29/100 (True: 4, Index: 280)...
#   Success! Adv label: 9, L2: 468.31, Queries: 43
# Attacking sample 30/100 (True: 4, Index: 290)...
#   Success! Adv label: 9, L2: 714.72, Queries: 63
# Attacking sample 31/100 (True: 4, Index: 297)...
#   Success! Adv label: 6, L2: 446.10, Queries: 41
# Attacking sample 32/100 (True: 4, Index: 299)...
#   Success! Adv label: 9, L2: 428.26, Queries: 39
# Attacking sample 33/100 (True: 4, Index: 310)...
#   Success! Adv label: 9, L2: 344.75, Queries: 31
# Attacking sample 34/100 (True: 4, Index: 316)...
#   Success! Adv label: 9, L2: 499.04, Queries: 45
# Attacking sample 35/100 (True: 4, Index: 320)...
#   Success! Adv label: 9, L2: 460.52, Queries: 43
# Attacking sample 36/100 (True: 4, Index: 324)...
#   Success! Adv label: 9, L2: 542.21, Queries: 51
# Attacking sample 37/100 (True: 4, Index: 326)...
#   Success! Adv label: 9, L2: 576.07, Queries: 57
# Attacking sample 38/100 (True: 4, Index: 332)...
#   Success! Adv label: 9, L2: 27.73, Queries: 3
# Attacking sample 39/100 (True: 4, Index: 335)...
#   Success! Adv label: 9, L2: 758.17, Queries: 69
# Attacking sample 40/100 (True: 4, Index: 344)...
#   Success! Adv label: 7, L2: 551.81, Queries: 53
# Attacking sample 42/100 (True: 4, Index: 359)...
#   Success! Adv label: 9, L2: 471.58, Queries: 41
# Attacking sample 43/100 (True: 4, Index: 376)...
#   Success! Adv label: 9, L2: 662.70, Queries: 65
# Attacking sample 44/100 (True: 4, Index: 393)...
#   Success! Adv label: 9, L2: 614.13, Queries: 57
# Attacking sample 45/100 (True: 4, Index: 401)...
#   Success! Adv label: 2, L2: 871.13, Queries: 85
# Attacking sample 46/100 (True: 4, Index: 402)...
#   Success! Adv label: 9, L2: 578.24, Queries: 55
# Attacking sample 47/100 (True: 4, Index: 422)...
#   Success! Adv label: 9, L2: 388.53, Queries: 33
# Attacking sample 48/100 (True: 4, Index: 423)...
#   Success! Adv label: 9, L2: 233.02, Queries: 23
# Attacking sample 49/100 (True: 4, Index: 427)...
#   Success! Adv label: 1, L2: 678.11, Queries: 77
# Attacking sample 50/100 (True: 4, Index: 432)...
#   Success! Adv label: 9, L2: 436.94, Queries: 41
# Attacking sample 51/100 (True: 4, Index: 434)...
#   Success! Adv label: 9, L2: 331.37, Queries: 29
# Attacking sample 52/100 (True: 4, Index: 454)...
#   Success! Adv label: 9, L2: 608.80, Queries: 59
# Attacking sample 53/100 (True: 4, Index: 467)...
#   Success! Adv label: 8, L2: 360.78, Queries: 33
# Attacking sample 54/100 (True: 4, Index: 501)...
#   Success! Adv label: 9, L2: 304.12, Queries: 29
# Attacking sample 55/100 (True: 4, Index: 515)...
#   Success! Adv label: 9, L2: 414.18, Queries: 37
# Attacking sample 56/100 (True: 4, Index: 540)...
#   Success! Adv label: 9, L2: 633.49, Queries: 63
# Attacking sample 57/100 (True: 4, Index: 544)...
#   Success! Adv label: 0, L2: 647.36, Queries: 67
# Attacking sample 58/100 (True: 4, Index: 545)...
#   Success! Adv label: 9, L2: 549.46, Queries: 51
# Attacking sample 59/100 (True: 4, Index: 547)...
#   Success! Adv label: 7, L2: 815.03, Queries: 99
# Attacking sample 60/100 (True: 4, Index: 566)...
#   Success! Adv label: 9, L2: 437.85, Queries: 39
# Attacking sample 61/100 (True: 4, Index: 590)...
#   Success! Adv label: 0, L2: 483.02, Queries: 45
# Attacking sample 62/100 (True: 4, Index: 593)...
#   Success! Adv label: 9, L2: 378.71, Queries: 33
# Attacking sample 63/100 (True: 4, Index: 599)...
#   Success! Adv label: 8, L2: 816.42, Queries: 83
# Attacking sample 64/100 (True: 4, Index: 602)...
#   Success! Adv label: 9, L2: 593.40, Queries: 55
# Attacking sample 65/100 (True: 4, Index: 607)...
#   Success! Adv label: 7, L2: 629.79, Queries: 69
# Attacking sample 66/100 (True: 4, Index: 611)...
#   Success! Adv label: 9, L2: 801.47, Queries: 79
# Attacking sample 67/100 (True: 4, Index: 617)...
#   Success! Adv label: 9, L2: 639.08, Queries: 55
# Attacking sample 68/100 (True: 4, Index: 657)...
#   Success! Adv label: 9, L2: 350.71, Queries: 35
# Attacking sample 69/100 (True: 4, Index: 680)...
#   Success! Adv label: 9, L2: 418.30, Queries: 37
# Attacking sample 70/100 (True: 4, Index: 684)...
#   Success! Adv label: 9, L2: 755.70, Queries: 81
# Attacking sample 71/100 (True: 4, Index: 687)...
#   Success! Adv label: 9, L2: 573.18, Queries: 51
# Attacking sample 72/100 (True: 4, Index: 692)...
#   Success! Adv label: 9, L2: 763.15, Queries: 73
# Attacking sample 73/100 (True: 4, Index: 696)...
#   Success! Adv label: 9, L2: 182.05, Queries: 17
# Attacking sample 74/100 (True: 4, Index: 697)...
#   Success! Adv label: 9, L2: 963.03, Queries: 89
# Attacking sample 75/100 (True: 4, Index: 708)...
#   Success! Adv label: 9, L2: 600.65, Queries: 55
# Attacking sample 76/100 (True: 4, Index: 717)...
#   Success! Adv label: 9, L2: 413.33, Queries: 37
# Attacking sample 77/100 (True: 4, Index: 746)...
#   Success! Adv label: 9, L2: 521.79, Queries: 51
# Attacking sample 78/100 (True: 4, Index: 752)...
#   Success! Adv label: 9, L2: 1032.16, Queries: 117
# Attacking sample 79/100 (True: 4, Index: 755)...
#   Success! Adv label: 7, L2: 826.77, Queries: 117
# Attacking sample 80/100 (True: 4, Index: 757)...
#   Success! Adv label: 9, L2: 498.48, Queries: 45
# Attacking sample 81/100 (True: 4, Index: 766)...
#   Success! Adv label: 7, L2: 492.74, Queries: 49
# Attacking sample 82/100 (True: 4, Index: 771)...
#   Success! Adv label: 9, L2: 326.84, Queries: 29
# Attacking sample 83/100 (True: 4, Index: 776)...
#   Success! Adv label: 2, L2: 690.54, Queries: 67
# Attacking sample 84/100 (True: 4, Index: 777)...
#   Failed! Adv label: 4, L2: 993.60, Queries: 201
# Attacking sample 85/100 (True: 4, Index: 786)...
#   Success! Adv label: 9, L2: 231.01, Queries: 21
# Attacking sample 86/100 (True: 4, Index: 811)...
#   Success! Adv label: 9, L2: 316.74, Queries: 29
# Attacking sample 87/100 (True: 4, Index: 815)...
#   Success! Adv label: 6, L2: 747.03, Queries: 73
# Attacking sample 88/100 (True: 4, Index: 817)...
#   Success! Adv label: 7, L2: 884.89, Queries: 95
# Attacking sample 89/100 (True: 4, Index: 840)...
#   Success! Adv label: 6, L2: 757.72, Queries: 71
# Attacking sample 91/100 (True: 4, Index: 849)...
#   Success! Adv label: 8, L2: 771.00, Queries: 69
# Attacking sample 92/100 (True: 4, Index: 857)...
#   Success! Adv label: 9, L2: 587.76, Queries: 55
# Attacking sample 93/100 (True: 4, Index: 872)...
#   Success! Adv label: 9, L2: 833.78, Queries: 87
# Attacking sample 94/100 (True: 4, Index: 877)...
#   Success! Adv label: 9, L2: 526.27, Queries: 51
# Attacking sample 95/100 (True: 4, Index: 894)...
#   Success! Adv label: 9, L2: 278.25, Queries: 25
# Attacking sample 96/100 (True: 4, Index: 902)...
#   Success! Adv label: 9, L2: 425.65, Queries: 37
# Attacking sample 97/100 (True: 4, Index: 911)...
# ...
#   Success! Adv label: 3, L2: 601.32, Queries: 59
# Attacking sample 40/100 (True: 8, Index: 505)...
#   Success! Adv label: 2, L2: 746.34, Queries: 77
# Attacking sample 41/100 (True: 8, Index: 509)...
#   Success! Adv label: 3, L2: 664.15, Queries: 75
# Attacking sample 42/100 (True: 8, Index: 525)...
#   Success! Adv label: 3, L2: 614.73, Queries: 65
# Attacking sample 43/100 (True: 8, Index: 528)...
#   Success! Adv label: 3, L2: 741.73, Queries: 89
# Attacking sample 44/100 (True: 8, Index: 541)...
#   Success! Adv label: 3, L2: 903.90, Queries: 97
# Attacking sample 45/100 (True: 8, Index: 543)...
#   Success! Adv label: 6, L2: 430.63, Queries: 43
# Attacking sample 46/100 (True: 8, Index: 550)...
#   Success! Adv label: 9, L2: 571.75, Queries: 57
# Attacking sample 47/100 (True: 8, Index: 558)...
#   Success! Adv label: 2, L2: 948.63, Queries: 141
# Attacking sample 48/100 (True: 8, Index: 575)...
#   Success! Adv label: 9, L2: 514.50, Queries: 55
# Attacking sample 49/100 (True: 8, Index: 594)...
#   Success! Adv label: 2, L2: 478.95, Queries: 51
# Attacking sample 50/100 (True: 8, Index: 600)...
#   Failed! Adv label: 8, L2: 1015.00, Queries: 201
# Attacking sample 51/100 (True: 8, Index: 605)...
#   Success! Adv label: 2, L2: 729.94, Queries: 75
# Attacking sample 52/100 (True: 8, Index: 619)...
#   Success! Adv label: 3, L2: 640.72, Queries: 79
# Attacking sample 53/100 (True: 8, Index: 625)...
#   Success! Adv label: 3, L2: 835.62, Queries: 81
# Attacking sample 54/100 (True: 8, Index: 629)...
#   Success! Adv label: 2, L2: 585.04, Queries: 57
# Attacking sample 55/100 (True: 8, Index: 645)...
#   Success! Adv label: 9, L2: 948.64, Queries: 99
# Attacking sample 56/100 (True: 8, Index: 652)...
#   Success! Adv label: 3, L2: 879.81, Queries: 123
# Attacking sample 57/100 (True: 8, Index: 672)...
#   Success! Adv label: 3, L2: 666.52, Queries: 81
# Attacking sample 58/100 (True: 8, Index: 683)...
#   Success! Adv label: 3, L2: 356.60, Queries: 41
# Attacking sample 59/100 (True: 8, Index: 701)...
#   Success! Adv label: 5, L2: 768.29, Queries: 83
# Attacking sample 60/100 (True: 8, Index: 714)...
#   Success! Adv label: 3, L2: 716.45, Queries: 79
# Attacking sample 61/100 (True: 8, Index: 721)...
#   Success! Adv label: 3, L2: 512.12, Queries: 53
# Attacking sample 62/100 (True: 8, Index: 730)...
#   Success! Adv label: 2, L2: 704.47, Queries: 69
# Attacking sample 63/100 (True: 8, Index: 731)...
#   Failed! Adv label: 8, L2: 1009.07, Queries: 201
# Attacking sample 64/100 (True: 8, Index: 738)...
#   Success! Adv label: 3, L2: 902.33, Queries: 145
# Attacking sample 65/100 (True: 8, Index: 791)...
#   Success! Adv label: 5, L2: 844.21, Queries: 93
# Attacking sample 66/100 (True: 8, Index: 832)...
#   Success! Adv label: 6, L2: 642.64, Queries: 65
# Attacking sample 67/100 (True: 8, Index: 838)...
#   Success! Adv label: 5, L2: 637.16, Queries: 71
# Attacking sample 68/100 (True: 8, Index: 860)...
#   Success! Adv label: 3, L2: 784.33, Queries: 89
# Attacking sample 69/100 (True: 8, Index: 864)...
#   Failed! Adv label: 8, L2: 929.31, Queries: 201
# Attacking sample 70/100 (True: 8, Index: 889)...
#   Success! Adv label: 3, L2: 716.64, Queries: 79
# Attacking sample 71/100 (True: 8, Index: 905)...
#   Success! Adv label: 9, L2: 798.43, Queries: 91
# Attacking sample 73/100 (True: 8, Index: 919)...
#   Success! Adv label: 3, L2: 574.54, Queries: 61
# Attacking sample 74/100 (True: 8, Index: 923)...
#   Success! Adv label: 3, L2: 699.65, Queries: 77
# Attacking sample 75/100 (True: 8, Index: 926)...
#   Success! Adv label: 5, L2: 726.90, Queries: 77
# Attacking sample 76/100 (True: 8, Index: 933)...
#   Success! Adv label: 3, L2: 628.71, Queries: 69
# Attacking sample 78/100 (True: 8, Index: 971)...
#   Success! Adv label: 3, L2: 810.04, Queries: 89
# Attacking sample 79/100 (True: 8, Index: 1014)...
#   Success! Adv label: 3, L2: 598.27, Queries: 65
# Attacking sample 80/100 (True: 8, Index: 1034)...
#   Success! Adv label: 5, L2: 845.65, Queries: 97
# Attacking sample 81/100 (True: 8, Index: 1053)...
#   Success! Adv label: 6, L2: 645.56, Queries: 67
# Attacking sample 82/100 (True: 8, Index: 1057)...
#   Success! Adv label: 6, L2: 521.02, Queries: 47
# Attacking sample 83/100 (True: 8, Index: 1061)...
#   Failed! Adv label: 8, L2: 854.04, Queries: 201
# Attacking sample 84/100 (True: 8, Index: 1062)...
#   Success! Adv label: 3, L2: 639.62, Queries: 73
# Attacking sample 85/100 (True: 8, Index: 1063)...
#   Success! Adv label: 3, L2: 652.47, Queries: 67
# Attacking sample 86/100 (True: 8, Index: 1078)...
#   Success! Adv label: 9, L2: 371.05, Queries: 33
# Attacking sample 87/100 (True: 8, Index: 1088)...
#   Success! Adv label: 2, L2: 795.83, Queries: 89
# Attacking sample 88/100 (True: 8, Index: 1100)...
#   Success! Adv label: 0, L2: 1042.74, Queries: 173
# Attacking sample 89/100 (True: 8, Index: 1106)...
#   Failed! Adv label: 8, L2: 985.55, Queries: 201
# Attacking sample 90/100 (True: 8, Index: 1120)...
#   Success! Adv label: 3, L2: 564.47, Queries: 61
# Attacking sample 91/100 (True: 8, Index: 1132)...
#   Success! Adv label: 2, L2: 734.43, Queries: 79
# Attacking sample 92/100 (True: 8, Index: 1134)...
#   Failed! Adv label: 8, L2: 1097.17, Queries: 201
# Attacking sample 93/100 (True: 8, Index: 1140)...
#   Success! Adv label: 5, L2: 336.37, Queries: 35
# Attacking sample 94/100 (True: 8, Index: 1150)...
#   Success! Adv label: 9, L2: 597.89, Queries: 59
# Attacking sample 95/100 (True: 8, Index: 1165)...
#   Success! Adv label: 3, L2: 938.62, Queries: 119
# Attacking sample 96/100 (True: 8, Index: 1179)...
#   Success! Adv label: 9, L2: 634.15, Queries: 67
# Attacking sample 97/100 (True: 8, Index: 1182)...
#   Success! Adv label: 9, L2: 555.65, Queries: 55
# Attacking sample 98/100 (True: 8, Index: 1186)...
#   Success! Adv label: 2, L2: 885.70, Queries: 91
# Attacking sample 99/100 (True: 8, Index: 1189)...
#   Success! Adv label: 3, L2: 285.00, Queries: 31
# Attacking sample 100/100 (True: 8, Index: 1207)...
#   Success! Adv label: 9, L2: 850.70, Queries: 85
# Attacking sample 1/100 (True: 9, Index: 6)...
#   Success! Adv label: 7, L2: 373.51, Queries: 37
# Attacking sample 2/100 (True: 9, Index: 38)...
#   Success! Adv label: 7, L2: 69.28, Queries: 7
# Attacking sample 3/100 (True: 9, Index: 55)...
#   Success! Adv label: 0, L2: 164.30, Queries: 17
# Attacking sample 4/100 (True: 9, Index: 56)...
#   Success! Adv label: 4, L2: 508.38, Queries: 49
# Attacking sample 5/100 (True: 9, Index: 91)...
#   Success! Adv label: 3, L2: 315.87, Queries: 29
# Attacking sample 6/100 (True: 9, Index: 99)...
#   Success! Adv label: 7, L2: 470.74, Queries: 49
# Attacking sample 7/100 (True: 9, Index: 101)...
#   Success! Adv label: 5, L2: 760.51, Queries: 85
# Attacking sample 8/100 (True: 9, Index: 114)...
#   Success! Adv label: 8, L2: 781.21, Queries: 73
# Attacking sample 9/100 (True: 9, Index: 133)...
#   Success! Adv label: 8, L2: 708.15, Queries: 67
# Attacking sample 10/100 (True: 9, Index: 171)...
#   Success! Adv label: 8, L2: 122.34, Queries: 11
# Attacking sample 11/100 (True: 9, Index: 179)...
#   Success! Adv label: 7, L2: 666.74, Queries: 75
# Attacking sample 12/100 (True: 9, Index: 195)...
#   Success! Adv label: 1, L2: 244.39, Queries: 23
# Attacking sample 13/100 (True: 9, Index: 214)...
#   Success! Adv label: 4, L2: 565.33, Queries: 63
# Attacking sample 14/100 (True: 9, Index: 218)...
#   Success! Adv label: 4, L2: 444.86, Queries: 47
# Attacking sample 15/100 (True: 9, Index: 222)...
#   Success! Adv label: 8, L2: 413.13, Queries: 41
# Attacking sample 16/100 (True: 9, Index: 224)...
#   Success! Adv label: 6, L2: 618.04, Queries: 63
# Attacking sample 17/100 (True: 9, Index: 238)...
#   Success! Adv label: 4, L2: 547.62, Queries: 53
# Attacking sample 18/100 (True: 9, Index: 243)...
#   Success! Adv label: 8, L2: 756.78, Queries: 73
# Attacking sample 19/100 (True: 9, Index: 245)...
#   Success! Adv label: 4, L2: 592.15, Queries: 63
# Attacking sample 20/100 (True: 9, Index: 246)...
#   Success! Adv label: 8, L2: 700.96, Queries: 63
# Attacking sample 21/100 (True: 9, Index: 251)...
#   Success! Adv label: 7, L2: 306.15, Queries: 31
# Attacking sample 22/100 (True: 9, Index: 303)...
#   Success! Adv label: 4, L2: 332.19, Queries: 35
# Attacking sample 23/100 (True: 9, Index: 305)...
#   Success! Adv label: 8, L2: 283.53, Queries: 27
# Attacking sample 24/100 (True: 9, Index: 307)...
#   Success! Adv label: 5, L2: 703.50, Queries: 81
# Attacking sample 25/100 (True: 9, Index: 315)...
#   Success! Adv label: 8, L2: 762.86, Queries: 79
# Attacking sample 26/100 (True: 9, Index: 354)...
#   Success! Adv label: 4, L2: 683.52, Queries: 75
# Attacking sample 27/100 (True: 9, Index: 364)...
#   Success! Adv label: 8, L2: 676.95, Queries: 67
# Attacking sample 28/100 (True: 9, Index: 389)...
#   Success! Adv label: 4, L2: 384.59, Queries: 39
# Attacking sample 29/100 (True: 9, Index: 407)...
#   Success! Adv label: 8, L2: 281.54, Queries: 25
# Attacking sample 30/100 (True: 9, Index: 411)...
#   Success! Adv label: 4, L2: 272.30, Queries: 25
# Attacking sample 31/100 (True: 9, Index: 417)...
#   Success! Adv label: 7, L2: 459.26, Queries: 57
# Attacking sample 32/100 (True: 9, Index: 421)...
#   Success! Adv label: 4, L2: 514.74, Queries: 51
# Attacking sample 33/100 (True: 9, Index: 438)...
#   Success! Adv label: 4, L2: 515.30, Queries: 51
# Attacking sample 34/100 (True: 9, Index: 443)...
#   Success! Adv label: 8, L2: 705.72, Queries: 73
# Attacking sample 35/100 (True: 9, Index: 444)...
#   Success! Adv label: 4, L2: 352.73, Queries: 37
# Attacking sample 36/100 (True: 9, Index: 446)...
#   Success! Adv label: 8, L2: 639.99, Queries: 71
# Attacking sample 37/100 (True: 9, Index: 455)...
#   Success! Adv label: 7, L2: 363.37, Queries: 37
# Attacking sample 38/100 (True: 9, Index: 469)...
#   Success! Adv label: 4, L2: 985.35, Queries: 145
# Attacking sample 39/100 (True: 9, Index: 472)...
#   Success! Adv label: 3, L2: 907.77, Queries: 91
# Attacking sample 40/100 (True: 9, Index: 473)...
#   Success! Adv label: 4, L2: 802.02, Queries: 81
# Attacking sample 41/100 (True: 9, Index: 482)...
#   Success! Adv label: 4, L2: 527.38, Queries: 49
# Attacking sample 42/100 (True: 9, Index: 490)...
#   Success! Adv label: 8, L2: 917.02, Queries: 91
# Attacking sample 43/100 (True: 9, Index: 496)...
#   Success! Adv label: 4, L2: 550.92, Queries: 59
# Attacking sample 44/100 (True: 9, Index: 507)...
#   Success! Adv label: 8, L2: 451.29, Queries: 41
# Attacking sample 45/100 (True: 9, Index: 508)...
#   Success! Adv label: 7, L2: 515.49, Queries: 53
# Attacking sample 46/100 (True: 9, Index: 514)...
#   Success! Adv label: 4, L2: 254.72, Queries: 23
# Attacking sample 47/100 (True: 9, Index: 522)...
#   Success! Adv label: 4, L2: 72.67, Queries: 7
# Attacking sample 48/100 (True: 9, Index: 535)...
#   Success! Adv label: 4, L2: 544.99, Queries: 59
# Attacking sample 49/100 (True: 9, Index: 542)...
#   Success! Adv label: 8, L2: 472.54, Queries: 49
# Attacking sample 50/100 (True: 9, Index: 553)...
#   Success! Adv label: 4, L2: 789.97, Queries: 87
# Attacking sample 51/100 (True: 9, Index: 554)...
#   Success! Adv label: 8, L2: 864.35, Queries: 83
# Attacking sample 52/100 (True: 9, Index: 565)...
#   Success! Adv label: 0, L2: 479.44, Queries: 49
# Attacking sample 53/100 (True: 9, Index: 569)...
#   Success! Adv label: 4, L2: 539.62, Queries: 59
# Attacking sample 54/100 (True: 9, Index: 572)...
#   Success! Adv label: 5, L2: 402.09, Queries: 41
# Attacking sample 55/100 (True: 9, Index: 574)...
#   Success! Adv label: 8, L2: 412.31, Queries: 41
# Attacking sample 56/100 (True: 9, Index: 601)...
#   Success! Adv label: 8, L2: 410.93, Queries: 37
# Attacking sample 57/100 (True: 9, Index: 634)...
#   Success! Adv label: 5, L2: 507.47, Queries: 49
# Attacking sample 58/100 (True: 9, Index: 635)...
#   Success! Adv label: 4, L2: 755.76, Queries: 91
# Attacking sample 59/100 (True: 9, Index: 637)...
#   Success! Adv label: 4, L2: 656.52, Queries: 67
# Attacking sample 60/100 (True: 9, Index: 640)...
#   Success! Adv label: 4, L2: 619.54, Queries: 63
# Attacking sample 61/100 (True: 9, Index: 653)...
#   Success! Adv label: 8, L2: 643.10, Queries: 61
# Attacking sample 62/100 (True: 9, Index: 654)...
#   Success! Adv label: 4, L2: 623.26, Queries: 65
# Attacking sample 63/100 (True: 9, Index: 656)...
#   Success! Adv label: 4, L2: 751.20, Queries: 73
# Attacking sample 64/100 (True: 9, Index: 666)...
#   Success! Adv label: 4, L2: 496.41, Queries: 55
# Attacking sample 65/100 (True: 9, Index: 685)...
#   Success! Adv label: 7, L2: 725.80, Queries: 81
# Attacking sample 66/100 (True: 9, Index: 711)...
#   Success! Adv label: 4, L2: 268.27, Queries: 25
# Attacking sample 67/100 (True: 9, Index: 729)...
#   Success! Adv label: 8, L2: 525.39, Queries: 51
# Attacking sample 68/100 (True: 9, Index: 739)...
#   Success! Adv label: 4, L2: 492.70, Queries: 51
# Attacking sample 69/100 (True: 9, Index: 747)...
#   Success! Adv label: 8, L2: 407.25, Queries: 39
# Attacking sample 70/100 (True: 9, Index: 767)...
#   Success! Adv label: 8, L2: 516.92, Queries: 51
# Attacking sample 71/100 (True: 9, Index: 783)...
#   Success! Adv label: 5, L2: 628.71, Queries: 67
# Attacking sample 72/100 (True: 9, Index: 787)...
#   Success! Adv label: 8, L2: 615.93, Queries: 57
# Attacking sample 73/100 (True: 9, Index: 796)...
#   Success! Adv label: 7, L2: 469.48, Queries: 49
# Attacking sample 74/100 (True: 9, Index: 804)...
#   Success! Adv label: 7, L2: 680.75, Queries: 83
# Attacking sample 75/100 (True: 9, Index: 818)...
#   Success! Adv label: 4, L2: 676.24, Queries: 75
# Attacking sample 76/100 (True: 9, Index: 825)...
#   Success! Adv label: 8, L2: 399.53, Queries: 37
# Attacking sample 77/100 (True: 9, Index: 826)...
#   Success! Adv label: 1, L2: 187.45, Queries: 19
# Attacking sample 78/100 (True: 9, Index: 831)...
#   Success! Adv label: 4, L2: 582.35, Queries: 55
# Attacking sample 79/100 (True: 9, Index: 880)...
#   Success! Adv label: 5, L2: 686.53, Queries: 65
# Attacking sample 80/100 (True: 9, Index: 884)...
#   Success! Adv label: 4, L2: 590.43, Queries: 59
# Attacking sample 81/100 (True: 9, Index: 891)...
#   Success! Adv label: 4, L2: 148.86, Queries: 15
# Attacking sample 82/100 (True: 9, Index: 893)...
#   Success! Adv label: 2, L2: 794.54, Queries: 91
# Attacking sample 83/100 (True: 9, Index: 899)...
#   Success! Adv label: 4, L2: 552.02, Queries: 61
# Attacking sample 84/100 (True: 9, Index: 912)...
#   Success! Adv label: 5, L2: 674.95, Queries: 65
# Attacking sample 85/100 (True: 9, Index: 920)...
#   Success! Adv label: 4, L2: 693.28, Queries: 69
# Attacking sample 86/100 (True: 9, Index: 925)...
#   Success! Adv label: 8, L2: 391.28, Queries: 35
# Attacking sample 87/100 (True: 9, Index: 940)...
#   Success! Adv label: 4, L2: 396.63, Queries: 45
# Attacking sample 88/100 (True: 9, Index: 958)...
#   Success! Adv label: 4, L2: 567.97, Queries: 55
# Attacking sample 89/100 (True: 9, Index: 969)...
#   Success! Adv label: 8, L2: 424.49, Queries: 39
# Attacking sample 90/100 (True: 9, Index: 978)...
#   Success! Adv label: 4, L2: 621.47, Queries: 71
# Attacking sample 91/100 (True: 9, Index: 979)...
#   Success! Adv label: 4, L2: 495.85, Queries: 47
# Attacking sample 92/100 (True: 9, Index: 980)...
#   Success! Adv label: 8, L2: 369.64, Queries: 37
# Attacking sample 93/100 (True: 9, Index: 991)...
#   Success! Adv label: 7, L2: 564.62, Queries: 65
# Attacking sample 94/100 (True: 9, Index: 997)...
#   Success! Adv label: 4, L2: 285.39, Queries: 31
# Attacking sample 95/100 (True: 9, Index: 1006)...
#   Success! Adv label: 7, L2: 595.03, Queries: 69
# Attacking sample 96/100 (True: 9, Index: 1011)...
#   Success! Adv label: 4, L2: 855.87, Queries: 91
# Attacking sample 97/100 (True: 9, Index: 1020)...
#   Success! Adv label: 8, L2: 515.72, Queries: 53
# Attacking sample 98/100 (True: 9, Index: 1023)...
#   Success! Adv label: 4, L2: 823.43, Queries: 91
# Attacking sample 99/100 (True: 9, Index: 1042)...
#   Success! Adv label: 4, L2: 388.95, Queries: 35
# Attacking sample 100/100 (True: 9, Index: 1046)...
#   Success! Adv label: 4, L2: 398.99, Queries: 41
# Time taken to generate adversarial samples: 166.2074 seconds
#
# Stats saved to: adversarial_8bit_K120_test_images\per_sample_stats.csv
#
# ===== Attack Summary =====
# Total trials: 986
# Misclassified before attack: 14
# Success rate: 922/986 (93.5%)
# Mean L2 (successful): 606.59
# Mean queries (successful): 62.74
#
# Showing successful adversarial examples...

# %% [markdown]
# ### Untargeted Attack on test set; k=130

# %%
import os
import warnings
import numpy as np
import torch
import joblib
import pandas as pd
from PIL import Image
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import torch.nn.functional as F
import time


# Set seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# ─────────────── PATHS ────────────────────────────────────────────────────
LENET_MODEL_PATH = os.path.normpath("Models and Data splits/lenet.pt")  # TorchScript model
DATA_PKL = os.path.normpath("Models and Data splits/data_[SCALED] Train_Test_Splits.pkl")
RF_ALL_CLASSES_PATH = os.path.normpath("Models and Data splits/random_forest.pkl")
OUT_DIR = "adversarial_8bit_K130_test_images"
os.makedirs(OUT_DIR, exist_ok=True)

if not os.path.exists(RF_ALL_CLASSES_PATH):
    raise FileNotFoundError(f"Random Forest model not found at {RF_ALL_CLASSES_PATH}")

# ─────────── HYPER-PARAMETERS ─────────────────────────────────────────────
EPSILON_STEP = 0.01
ITERATIONS = 100
TOTAL_EPSILON = 0.5
TOP_K_FEATURES = 130
SAMPLES_PER_DIGIT = 100
MAX_L2 = 10000

def plot_adversarial_example(original_img, adv_img, true_label, adv_label, l2_mag, sample_idx, queries, title_suffix=""):
    if original_img.size == 784:
        original_img = original_img.reshape(28, 28)
    if adv_img.size == 784:
        adv_img = adv_img.reshape(28, 28)
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(original_img, cmap='gray')
    axes[0].set_title(f"Original\nTrue: {true_label}")
    axes[0].axis('off')
    axes[1].imshow(adv_img, cmap='gray')
    axes[1].set_title(f"Adversarial\nPred: {adv_label}")
    axes[1].axis('off')
    fig.suptitle(f"Sample {sample_idx} | L2: {l2_mag:.2f} | Queries: {queries} {title_suffix}")
    plt.show()
    plt.close(fig)  # <-- added here


# ─────────── Load Data ─────────────────────────────────────────────────────
try:
    data = joblib.load(DATA_PKL)
    _, X_samples , _, y_samples = data
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PKL}. Please check the path.")
    exit()

if X_samples.max() > 1.0:
    X_samples = X_samples.astype(np.float32) / 255.0
    warnings.warn("Data appeared in [0,255]; normalized to [0,1].")

# ─────────── Load TorchScripted LeNet ──────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
try:
    model = torch.jit.load(LENET_MODEL_PATH, map_location=device)
    model.eval()
    print(f"LeNet TorchScript model loaded from: {LENET_MODEL_PATH}")
except Exception as e:
    print(f"Error loading TorchScript LeNet model: {e}")
    exit()

def to_model(x01_batch):
    if x01_batch.ndim == 2 and x01_batch.shape == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)
    elif x01_batch.ndim == 3 and x01_batch.shape[1:] == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(1)
    elif x01_batch.ndim == 4 and x01_batch.shape[1] == 1:
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device)
    elif x01_batch.ndim == 1 and x01_batch.size == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(1, 1, 28, 28), dtype=torch.float32, device=device)
    elif x01_batch.ndim == 2 and x01_batch.shape[1] == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(x01_batch.shape[0], 1, 28, 28), dtype=torch.float32, device=device)
    else:
        raise ValueError(f"Unsupported input shape for to_model: {x01_batch.shape}")
    return tensor_batch


def model_query(x_tensor_batch):
    with torch.no_grad():
        return model(x_tensor_batch)

# ─────────── Load Random Forest Model ──────────────────────────────────────
rf_all_classes = None
top_feature_indices = None
print("Loading Random Forest Classifier for all classes...")
try:
    rf_all_classes = joblib.load(RF_ALL_CLASSES_PATH)
    feature_importances = rf_all_classes.feature_importances_
    #top_feature_indices = np.argsort(feature_importances)[:TOP_K_FEATURES]
    
    top_feature_indices = np.argsort(-feature_importances)[:TOP_K_FEATURES]
    print(f"Random Forest loaded. Using top {TOP_K_FEATURES} features.")
except Exception as e:
    print(f"Error loading Random Forest: {e}")
    top_feature_indices = np.arange(28 * 28)

# ─────────── I-FGSM Attack ─────────────────────────────────────────────────
def ifgsm_attack(original_image_np, true_label, model_target, epsilon_step, iterations,
                 total_epsilon_budget, features_to_perturb, query_count_tracker):
    if original_image_np.ndim == 1 and original_image_np.size == 784:
        original_image_np = original_image_np.reshape(28, 28)

    perturbed_image_np = original_image_np.copy()
    final_pred_label = true_label

    for i in range(iterations):
        image_tensor = to_model(perturbed_image_np)
        image_tensor.requires_grad = True
        output = model_target(image_tensor)
        query_count_tracker[0] += 1
        loss = F.cross_entropy(output, torch.tensor([true_label], device=device))
        model_target.zero_grad()
        loss.backward()
        data_grad_sign = torch.sign(image_tensor.grad.data).cpu().numpy()

        gradient_mask = np.zeros_like(data_grad_sign, dtype=np.float32)
        h, w = perturbed_image_np.shape
        rows, cols = np.unravel_index(features_to_perturb, (h, w))
        gradient_mask[0, 0, rows, cols] = data_grad_sign[0, 0, rows, cols]
        gradient_mask_for_update = gradient_mask.reshape(perturbed_image_np.shape)

        perturbed_image_np += epsilon_step * gradient_mask_for_update
        perturbation = perturbed_image_np - original_image_np
        perturbation = np.clip(perturbation, -total_epsilon_budget, total_epsilon_budget)
        perturbed_image_np = original_image_np + perturbation
        perturbed_image_np = np.clip(perturbed_image_np, 0, 1)

        # Discretize and check prediction on discretized image
        adv_uint8_temp = np.round(perturbed_image_np * 255).astype(np.uint8)
        adv_float_temp = adv_uint8_temp.astype(np.float32) / 255.0
        with torch.no_grad():
            output_temp = model_target(to_model(adv_float_temp))
            pred_temp = output_temp.argmax(dim=1).item()
            query_count_tracker[0] += 1

        if pred_temp != true_label:
            final_pred_label = pred_temp
            break

    # Final adversarial image (discretized)
    adv_uint8 = np.round(perturbed_image_np * 255).astype(np.uint8)
    adv_float = adv_uint8.astype(np.float32) / 255.0
    with torch.no_grad():
        output_final = model_target(to_model(adv_float))
        final_pred_label = output_final.argmax(dim=1).item()

    l2_norm = np.linalg.norm(adv_uint8.astype(np.float32) - (original_image_np * 255).astype(np.float32))
    success = (final_pred_label != true_label) and (l2_norm <= MAX_L2)

    return adv_uint8, final_pred_label, l2_norm, success


# ─────────── Attack Execution ──────────────────────────────────────────────
print(f"\n===== Starting Adversarial Attack =====")
total_trials, succ_total, misclassified = 0, 0, 0
records = []


start_time = time.time()


for digit in range(10):
    idxs = np.where(y_samples == digit)[0][:SAMPLES_PER_DIGIT]
    for rank, idx in enumerate(idxs, 1):
        x0 = X_samples[idx].copy()
        y0 = int(y_samples[idx])
        query_count_tracker = [0]
        pred0 = model_query(to_model(x0)).argmax(dim=1).item()
        query_count_tracker[0] += 1

        if pred0 != y0:
            misclassified += 1
            records.append({
                'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
                'adv_label': None, 'success': False, 'queries': query_count_tracker[0],
                'l2_mag': np.nan, 'note': 'Already misclassified'
            })
            continue

        total_trials += 1
        print(f"Attacking sample {rank}/{SAMPLES_PER_DIGIT} (True: {y0}, Index: {idx})...")
        adv_img_uint8, adv_label, l2_mag, success = ifgsm_attack(
            x0, y0, model, EPSILON_STEP, ITERATIONS, TOTAL_EPSILON,
            top_feature_indices, query_count_tracker
        )

        if success:
            succ_total += 1
            fname = f"true{y0}_adv{adv_label}_mag{l2_mag:.1f}_sample{idx}.png"
            Image.fromarray(adv_img_uint8, mode="L").save(os.path.join(OUT_DIR, fname))

        records.append({
            'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
            'adv_label': adv_label, 'success': success, 'queries': query_count_tracker[0],
            'l2_mag': l2_mag if success else np.nan, 'note': 'I-FGSM' + (' successful' if success else ' failed')
        })

        print(f"  {'Success' if success else 'Failed'}! Adv label: {adv_label}, L2: {l2_mag:.2f}, Queries: {query_count_tracker[0]}")


end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to generate adversarial samples: {elapsed_time:.4f} seconds")


# ─────────── Save Results ──────────────────────────────────────────────────
df = pd.DataFrame(records)
csv_path = os.path.join(OUT_DIR, "per_sample_stats.csv")
df.to_csv(csv_path, index=False)
print(f"\nStats saved to: {csv_path}")

# ─────────── Summary ───────────────────────────────────────────────────────
print(f"\n===== Attack Summary =====")
print(f"Total trials: {total_trials}")
print(f"Misclassified before attack: {misclassified}")
if total_trials > 0:
    success_rate = succ_total / total_trials * 100
    print(f"Success rate: {succ_total}/{total_trials} ({success_rate:.1f}%)")
    if succ_total > 0:
        print(f"Mean L2 (successful): {df[df['success']]['l2_mag'].mean():.2f}")
        print(f"Mean queries (successful): {df[df['success']]['queries'].mean():.2f}")

# ─────────── Display Examples ──────────────────────────────────────────────
success_df = df[df['success']]
if not success_df.empty:
    print("\nShowing successful adversarial examples...")
    show_ids = success_df.sample(min(3, len(success_df))).index.tolist()
    for record_idx in show_ids:
        r = df.loc[record_idx]
        fname_prefix = f"true{r['true_label']}_adv{r['adv_label']}_mag{r['l2_mag']:.1f}_sample{r['sample_idx']}"
        match_files = [f for f in os.listdir(OUT_DIR) if f.startswith(fname_prefix)]
        if match_files:
            adv_img_path = os.path.join(OUT_DIR, match_files[0])
            plot_adversarial_example(X_samples[r['sample_idx']], np.array(Image.open(adv_img_path)),
                                     r['true_label'], r['adv_label'], r['l2_mag'],
                                     r['sample_idx'], r['queries'], "(I-FGSM)")
else:
    print("No successful attacks to display. Showing original samples instead.")
    for i in range(min(3, len(df))):
        r = df.iloc[i]
        plot_adversarial_example(X_samples[r['sample_idx']], X_samples[r['sample_idx']],
                                 r['true_label'], r['initial_pred'], 0.0,
                                 r['sample_idx'], r['queries'], "(Original)")
# Out:
# LeNet TorchScript model loaded from: Models and Data splits\lenet.pt
# Loading Random Forest Classifier for all classes...
# Random Forest loaded. Using top 130 features.
#
# ===== Starting Adversarial Attack =====
# Attacking sample 1/100 (True: 0, Index: 29)...
#   Success! Adv label: 6, L2: 975.79, Queries: 105
# Attacking sample 2/100 (True: 0, Index: 40)...
#   Failed! Adv label: 0, L2: 1038.85, Queries: 201
# Attacking sample 3/100 (True: 0, Index: 44)...
#   Success! Adv label: 5, L2: 674.66, Queries: 67
# Attacking sample 4/100 (True: 0, Index: 59)...
#   Success! Adv label: 6, L2: 751.12, Queries: 73
# Attacking sample 5/100 (True: 0, Index: 64)...
#   Failed! Adv label: 0, L2: 1070.13, Queries: 201
# Attacking sample 6/100 (True: 0, Index: 75)...
#   Success! Adv label: 8, L2: 703.78, Queries: 73
# Attacking sample 7/100 (True: 0, Index: 80)...
#   Success! Adv label: 9, L2: 746.63, Queries: 81
# Attacking sample 8/100 (True: 0, Index: 97)...
#   Success! Adv label: 6, L2: 892.13, Queries: 101
# Attacking sample 9/100 (True: 0, Index: 115)...
#   Success! Adv label: 6, L2: 849.82, Queries: 85
# Attacking sample 10/100 (True: 0, Index: 141)...
#   Success! Adv label: 7, L2: 234.66, Queries: 23
# Attacking sample 11/100 (True: 0, Index: 146)...
#   Success! Adv label: 9, L2: 710.01, Queries: 79
# Attacking sample 12/100 (True: 0, Index: 156)...
#   Failed! Adv label: 0, L2: 885.39, Queries: 201
# Attacking sample 13/100 (True: 0, Index: 173)...
#   Success! Adv label: 6, L2: 694.44, Queries: 81
# Attacking sample 14/100 (True: 0, Index: 175)...
#   Success! Adv label: 8, L2: 488.87, Queries: 49
# Attacking sample 15/100 (True: 0, Index: 193)...
#   Success! Adv label: 9, L2: 882.07, Queries: 161
# Attacking sample 16/100 (True: 0, Index: 200)...
#   Success! Adv label: 9, L2: 711.18, Queries: 81
# Attacking sample 17/100 (True: 0, Index: 205)...
#   Success! Adv label: 9, L2: 799.02, Queries: 89
# Attacking sample 18/100 (True: 0, Index: 210)...
#   Success! Adv label: 8, L2: 720.51, Queries: 77
# Attacking sample 19/100 (True: 0, Index: 221)...
#   Success! Adv label: 3, L2: 811.94, Queries: 81
# Attacking sample 20/100 (True: 0, Index: 229)...
#   Failed! Adv label: 0, L2: 894.38, Queries: 201
# Attacking sample 21/100 (True: 0, Index: 249)...
#   Success! Adv label: 5, L2: 850.81, Queries: 187
# Attacking sample 22/100 (True: 0, Index: 258)...
#   Success! Adv label: 8, L2: 820.70, Queries: 83
# Attacking sample 23/100 (True: 0, Index: 275)...
#   Success! Adv label: 8, L2: 1101.71, Queries: 201
# Attacking sample 24/100 (True: 0, Index: 292)...
#   Failed! Adv label: 0, L2: 877.49, Queries: 201
# Attacking sample 25/100 (True: 0, Index: 296)...
#   Success! Adv label: 9, L2: 703.17, Queries: 73
# Attacking sample 26/100 (True: 0, Index: 301)...
#   Success! Adv label: 9, L2: 653.80, Queries: 65
# Attacking sample 27/100 (True: 0, Index: 314)...
#   Success! Adv label: 9, L2: 679.80, Queries: 63
# Attacking sample 28/100 (True: 0, Index: 325)...
#   Failed! Adv label: 0, L2: 1014.88, Queries: 201
# Attacking sample 29/100 (True: 0, Index: 333)...
#   Success! Adv label: 9, L2: 881.89, Queries: 101
# Attacking sample 30/100 (True: 0, Index: 345)...
#   Success! Adv label: 6, L2: 679.11, Queries: 65
# Attacking sample 31/100 (True: 0, Index: 349)...
#   Success! Adv label: 9, L2: 640.18, Queries: 65
# Attacking sample 32/100 (True: 0, Index: 360)...
#   Failed! Adv label: 0, L2: 1065.13, Queries: 201
# Attacking sample 33/100 (True: 0, Index: 365)...
#   Success! Adv label: 9, L2: 922.48, Queries: 159
# Attacking sample 34/100 (True: 0, Index: 366)...
#   Success! Adv label: 8, L2: 805.39, Queries: 81
# Attacking sample 35/100 (True: 0, Index: 379)...
#   Success! Adv label: 8, L2: 898.41, Queries: 91
# Attacking sample 36/100 (True: 0, Index: 385)...
#   Success! Adv label: 8, L2: 1027.32, Queries: 173
# Attacking sample 37/100 (True: 0, Index: 397)...
#   Failed! Adv label: 0, L2: 901.71, Queries: 201
# Attacking sample 38/100 (True: 0, Index: 400)...
#   Failed! Adv label: 0, L2: 1076.16, Queries: 201
# Attacking sample 39/100 (True: 0, Index: 405)...
#   Success! Adv label: 2, L2: 818.03, Queries: 81
# Attacking sample 40/100 (True: 0, Index: 410)...
#   Success! Adv label: 9, L2: 795.09, Queries: 87
# Attacking sample 41/100 (True: 0, Index: 420)...
#   Success! Adv label: 2, L2: 921.60, Queries: 171
# Attacking sample 42/100 (True: 0, Index: 424)...
#   Failed! Adv label: 0, L2: 979.57, Queries: 201
# Attacking sample 43/100 (True: 0, Index: 447)...
#   Success! Adv label: 2, L2: 742.11, Queries: 79
# Attacking sample 44/100 (True: 0, Index: 453)...
#   Success! Adv label: 2, L2: 852.55, Queries: 91
# Attacking sample 45/100 (True: 0, Index: 457)...
#   Success! Adv label: 6, L2: 1014.65, Queries: 105
# Attacking sample 46/100 (True: 0, Index: 466)...
#   Success! Adv label: 2, L2: 838.60, Queries: 89
# Attacking sample 47/100 (True: 0, Index: 475)...
#   Success! Adv label: 9, L2: 266.24, Queries: 25
# Attacking sample 48/100 (True: 0, Index: 483)...
#   Failed! Adv label: 0, L2: 1103.87, Queries: 201
# Attacking sample 49/100 (True: 0, Index: 484)...
#   Success! Adv label: 8, L2: 485.12, Queries: 41
# Attacking sample 50/100 (True: 0, Index: 486)...
#   Failed! Adv label: 0, L2: 979.49, Queries: 201
# Attacking sample 51/100 (True: 0, Index: 487)...
#   Success! Adv label: 6, L2: 697.52, Queries: 69
# Attacking sample 52/100 (True: 0, Index: 489)...
#   Success! Adv label: 9, L2: 703.45, Queries: 73
# Attacking sample 53/100 (True: 0, Index: 492)...
#   Success! Adv label: 9, L2: 765.12, Queries: 77
# Attacking sample 54/100 (True: 0, Index: 506)...
#   Success! Adv label: 2, L2: 1008.67, Queries: 99
# Attacking sample 55/100 (True: 0, Index: 513)...
#   Failed! Adv label: 0, L2: 1016.12, Queries: 201
# Attacking sample 56/100 (True: 0, Index: 518)...
#   Failed! Adv label: 0, L2: 1020.94, Queries: 201
# Attacking sample 57/100 (True: 0, Index: 521)...
#   Failed! Adv label: 0, L2: 1016.83, Queries: 201
# Attacking sample 58/100 (True: 0, Index: 527)...
#   Success! Adv label: 2, L2: 755.38, Queries: 79
# Attacking sample 59/100 (True: 0, Index: 529)...
#   Failed! Adv label: 0, L2: 860.43, Queries: 201
# Attacking sample 60/100 (True: 0, Index: 531)...
#   Failed! Adv label: 0, L2: 1022.64, Queries: 201
# Attacking sample 61/100 (True: 0, Index: 546)...
#   Success! Adv label: 9, L2: 634.04, Queries: 69
# Attacking sample 62/100 (True: 0, Index: 551)...
#   Success! Adv label: 6, L2: 403.80, Queries: 35
# Attacking sample 63/100 (True: 0, Index: 555)...
#   Success! Adv label: 8, L2: 1063.62, Queries: 103
# Attacking sample 64/100 (True: 0, Index: 587)...
#   Success! Adv label: 2, L2: 875.64, Queries: 93
# Attacking sample 65/100 (True: 0, Index: 604)...
#   Success! Adv label: 8, L2: 684.46, Queries: 63
# Attacking sample 66/100 (True: 0, Index: 614)...
#   Success! Adv label: 8, L2: 870.34, Queries: 89
# Attacking sample 67/100 (True: 0, Index: 615)...
#   Success! Adv label: 9, L2: 456.19, Queries: 41
# Attacking sample 68/100 (True: 0, Index: 618)...
#   Success! Adv label: 6, L2: 319.57, Queries: 29
# Attacking sample 69/100 (True: 0, Index: 638)...
#   Success! Adv label: 8, L2: 441.59, Queries: 39
# Attacking sample 70/100 (True: 0, Index: 642)...
#   Success! Adv label: 9, L2: 881.78, Queries: 107
# Attacking sample 71/100 (True: 0, Index: 655)...
#   Success! Adv label: 6, L2: 830.87, Queries: 77
# Attacking sample 72/100 (True: 0, Index: 658)...
#   Success! Adv label: 6, L2: 749.25, Queries: 73
# Attacking sample 73/100 (True: 0, Index: 665)...
#   Success! Adv label: 2, L2: 719.92, Queries: 73
# Attacking sample 74/100 (True: 0, Index: 671)...
#   Success! Adv label: 6, L2: 788.43, Queries: 77
# Attacking sample 75/100 (True: 0, Index: 681)...
#   Success! Adv label: 9, L2: 901.14, Queries: 95
# Attacking sample 76/100 (True: 0, Index: 691)...
#   Success! Adv label: 2, L2: 825.25, Queries: 81
# Attacking sample 77/100 (True: 0, Index: 700)...
#   Success! Adv label: 5, L2: 645.64, Queries: 65
# Attacking sample 78/100 (True: 0, Index: 706)...
#   Failed! Adv label: 0, L2: 810.78, Queries: 201
# Attacking sample 79/100 (True: 0, Index: 712)...
#   Failed! Adv label: 0, L2: 1025.55, Queries: 201
# Attacking sample 80/100 (True: 0, Index: 713)...
#   Success! Adv label: 9, L2: 741.85, Queries: 73
# Attacking sample 81/100 (True: 0, Index: 736)...
#   Success! Adv label: 5, L2: 747.78, Queries: 87
# Attacking sample 82/100 (True: 0, Index: 742)...
#   Success! Adv label: 8, L2: 696.99, Queries: 73
# Attacking sample 83/100 (True: 0, Index: 744)...
#   Success! Adv label: 2, L2: 606.60, Queries: 61
# Attacking sample 84/100 (True: 0, Index: 760)...
#   Success! Adv label: 9, L2: 640.90, Queries: 67
# Attacking sample 85/100 (True: 0, Index: 772)...
#   Success! Adv label: 9, L2: 328.76, Queries: 29
# Attacking sample 86/100 (True: 0, Index: 781)...
#   Success! Adv label: 6, L2: 520.36, Queries: 49
# Attacking sample 87/100 (True: 0, Index: 809)...
#   Success! Adv label: 5, L2: 846.73, Queries: 151
# Attacking sample 88/100 (True: 0, Index: 813)...
#   Success! Adv label: 9, L2: 504.13, Queries: 51
# Attacking sample 89/100 (True: 0, Index: 820)...
#   Success! Adv label: 9, L2: 829.01, Queries: 95
# Attacking sample 90/100 (True: 0, Index: 823)...
#   Success! Adv label: 9, L2: 683.24, Queries: 83
# Attacking sample 91/100 (True: 0, Index: 844)...
#   Success! Adv label: 6, L2: 991.84, Queries: 175
# Attacking sample 92/100 (True: 0, Index: 848)...
#   Success! Adv label: 9, L2: 296.46, Queries: 27
# Attacking sample 93/100 (True: 0, Index: 861)...
#   Success! Adv label: 6, L2: 1055.32, Queries: 95
# Attacking sample 94/100 (True: 0, Index: 865)...
#   Failed! Adv label: 0, L2: 1233.85, Queries: 201
# Attacking sample 95/100 (True: 0, Index: 869)...
#   Success! Adv label: 6, L2: 1087.57, Queries: 139
# Attacking sample 96/100 (True: 0, Index: 876)...
#   Success! Adv label: 9, L2: 693.65, Queries: 67
# Attacking sample 97/100 (True: 0, Index: 885)...
#   Failed! Adv label: 0, L2: 998.71, Queries: 201
# Attacking sample 98/100 (True: 0, Index: 906)...
#   Success! Adv label: 3, L2: 1041.79, Queries: 163
# Attacking sample 99/100 (True: 0, Index: 907)...
#   Success! Adv label: 9, L2: 973.06, Queries: 137
# Attacking sample 100/100 (True: 0, Index: 918)...
#   Success! Adv label: 9, L2: 1034.44, Queries: 175
# Attacking sample 1/100 (True: 1, Index: 2)...
#   Success! Adv label: 7, L2: 351.19, Queries: 29
# Attacking sample 2/100 (True: 1, Index: 3)...
#   Success! Adv label: 7, L2: 442.76, Queries: 37
# Attacking sample 3/100 (True: 1, Index: 9)...
#   Success! Adv label: 2, L2: 364.10, Queries: 33
# Attacking sample 4/100 (True: 1, Index: 25)...
#   Success! Adv label: 4, L2: 393.48, Queries: 31
# Attacking sample 5/100 (True: 1, Index: 36)...
#   Success! Adv label: 2, L2: 347.84, Queries: 29
# Attacking sample 6/100 (True: 1, Index: 63)...
#   Success! Adv label: 8, L2: 326.23, Queries: 29
# Attacking sample 7/100 (True: 1, Index: 65)...
#   Success! Adv label: 8, L2: 378.80, Queries: 31
# Attacking sample 8/100 (True: 1, Index: 68)...
#   Success! Adv label: 4, L2: 405.74, Queries: 33
# Attacking sample 9/100 (True: 1, Index: 76)...
#   Success! Adv label: 8, L2: 264.01, Queries: 23
# Attacking sample 10/100 (True: 1, Index: 83)...
#   Success! Adv label: 4, L2: 387.36, Queries: 33
# Attacking sample 11/100 (True: 1, Index: 90)...
#   Success! Adv label: 9, L2: 28.91, Queries: 3
# Attacking sample 12/100 (True: 1, Index: 94)...
#   Success! Adv label: 8, L2: 225.19, Queries: 19
# Attacking sample 13/100 (True: 1, Index: 100)...
#   Success! Adv label: 8, L2: 301.00, Queries: 25
# Attacking sample 14/100 (True: 1, Index: 123)...
#   Success! Adv label: 8, L2: 240.45, Queries: 21
# Attacking sample 15/100 (True: 1, Index: 150)...
#   Success! Adv label: 8, L2: 385.70, Queries: 31
# Attacking sample 16/100 (True: 1, Index: 152)...
#   Success! Adv label: 9, L2: 387.34, Queries: 33
# Attacking sample 17/100 (True: 1, Index: 178)...
#   Success! Adv label: 4, L2: 363.60, Queries: 29
# Attacking sample 18/100 (True: 1, Index: 185)...
#   Success! Adv label: 8, L2: 438.33, Queries: 41
# Attacking sample 19/100 (True: 1, Index: 191)...
#   Success! Adv label: 4, L2: 426.96, Queries: 35
# Attacking sample 20/100 (True: 1, Index: 201)...
#   Success! Adv label: 8, L2: 358.34, Queries: 29
# Attacking sample 21/100 (True: 1, Index: 203)...
#   Success! Adv label: 8, L2: 320.96, Queries: 25
# Attacking sample 22/100 (True: 1, Index: 213)...
#   Success! Adv label: 8, L2: 319.64, Queries: 27
# Attacking sample 23/100 (True: 1, Index: 220)...
#   Success! Adv label: 8, L2: 287.38, Queries: 23
# Attacking sample 24/100 (True: 1, Index: 223)...
#   Success! Adv label: 4, L2: 378.73, Queries: 31
# Attacking sample 25/100 (True: 1, Index: 226)...
#   Success! Adv label: 4, L2: 361.23, Queries: 29
# Attacking sample 26/100 (True: 1, Index: 232)...
#   Success! Adv label: 8, L2: 467.59, Queries: 37
# Attacking sample 27/100 (True: 1, Index: 241)...
#   Success! Adv label: 4, L2: 302.14, Queries: 25
# Attacking sample 28/100 (True: 1, Index: 254)...
#   Success! Adv label: 8, L2: 334.44, Queries: 27
# Attacking sample 29/100 (True: 1, Index: 281)...
#   Success! Adv label: 8, L2: 315.78, Queries: 27
# Attacking sample 30/100 (True: 1, Index: 284)...
#   Success! Adv label: 8, L2: 355.23, Queries: 31
# Attacking sample 31/100 (True: 1, Index: 285)...
#   Success! Adv label: 9, L2: 241.38, Queries: 21
# Attacking sample 32/100 (True: 1, Index: 286)...
#   Success! Adv label: 4, L2: 298.74, Queries: 25
# Attacking sample 33/100 (True: 1, Index: 287)...
#   Success! Adv label: 4, L2: 335.71, Queries: 29
# Attacking sample 34/100 (True: 1, Index: 294)...
#   Success! Adv label: 4, L2: 410.99, Queries: 33
# Attacking sample 35/100 (True: 1, Index: 298)...
#   Success! Adv label: 4, L2: 490.29, Queries: 41
# Attacking sample 36/100 (True: 1, Index: 306)...
#   Success! Adv label: 4, L2: 428.11, Queries: 35
# Attacking sample 37/100 (True: 1, Index: 312)...
#   Success! Adv label: 8, L2: 384.22, Queries: 35
# Attacking sample 38/100 (True: 1, Index: 317)...
#   Success! Adv label: 4, L2: 361.23, Queries: 31
# Attacking sample 39/100 (True: 1, Index: 334)...
#   Success! Adv label: 4, L2: 415.71, Queries: 33
# Attacking sample 40/100 (True: 1, Index: 337)...
#   Success! Adv label: 8, L2: 420.49, Queries: 33
# Attacking sample 41/100 (True: 1, Index: 338)...
#   Success! Adv label: 4, L2: 516.42, Queries: 41
# Attacking sample 42/100 (True: 1, Index: 348)...
#   Success! Adv label: 4, L2: 493.18, Queries: 41
# Attacking sample 43/100 (True: 1, Index: 361)...
#   Success! Adv label: 9, L2: 313.16, Queries: 25
# Attacking sample 44/100 (True: 1, Index: 363)...
#   Success! Adv label: 8, L2: 371.31, Queries: 29
# Attacking sample 45/100 (True: 1, Index: 367)...
#   Success! Adv label: 8, L2: 227.71, Queries: 19
# Attacking sample 46/100 (True: 1, Index: 375)...
#   Success! Adv label: 9, L2: 494.92, Queries: 41
# Attacking sample 47/100 (True: 1, Index: 384)...
#   Success! Adv label: 8, L2: 306.07, Queries: 25
# Attacking sample 48/100 (True: 1, Index: 412)...
#   Success! Adv label: 9, L2: 502.57, Queries: 39
# Attacking sample 49/100 (True: 1, Index: 425)...
#   Success! Adv label: 9, L2: 424.90, Queries: 35
# Attacking sample 50/100 (True: 1, Index: 428)...
#   Success! Adv label: 4, L2: 366.71, Queries: 29
# Attacking sample 51/100 (True: 1, Index: 463)...
#   Success! Adv label: 4, L2: 294.33, Queries: 25
# Attacking sample 52/100 (True: 1, Index: 499)...
#   Success! Adv label: 4, L2: 466.26, Queries: 37
# Attacking sample 53/100 (True: 1, Index: 502)...
#   Success! Adv label: 4, L2: 423.64, Queries: 35
# Attacking sample 54/100 (True: 1, Index: 526)...
#   Success! Adv label: 4, L2: 315.93, Queries: 25
# Attacking sample 55/100 (True: 1, Index: 532)...
#   Success! Adv label: 4, L2: 367.91, Queries: 29
# Attacking sample 56/100 (True: 1, Index: 536)...
#   Success! Adv label: 9, L2: 299.81, Queries: 25
# Attacking sample 57/100 (True: 1, Index: 537)...
#   Success! Adv label: 8, L2: 387.64, Queries: 33
# Attacking sample 58/100 (True: 1, Index: 539)...
#   Success! Adv label: 4, L2: 411.98, Queries: 33
# Attacking sample 60/100 (True: 1, Index: 560)...
#   Success! Adv label: 4, L2: 359.54, Queries: 29
# Attacking sample 61/100 (True: 1, Index: 561)...
#   Success! Adv label: 8, L2: 305.87, Queries: 25
# Attacking sample 62/100 (True: 1, Index: 570)...
#   Success! Adv label: 8, L2: 349.60, Queries: 29
# Attacking sample 63/100 (True: 1, Index: 573)...
#   Success! Adv label: 2, L2: 32.06, Queries: 3
# Attacking sample 64/100 (True: 1, Index: 576)...
#   Success! Adv label: 7, L2: 362.56, Queries: 33
# Attacking sample 65/100 (True: 1, Index: 580)...
#   Success! Adv label: 4, L2: 328.43, Queries: 27
# Attacking sample 66/100 (True: 1, Index: 588)...
#   Success! Adv label: 7, L2: 494.69, Queries: 43
# Attacking sample 67/100 (True: 1, Index: 620)...
#   Success! Adv label: 4, L2: 404.38, Queries: 33
# Attacking sample 68/100 (True: 1, Index: 621)...
#   Success! Adv label: 4, L2: 373.62, Queries: 31
# Attacking sample 69/100 (True: 1, Index: 622)...
#   Success! Adv label: 2, L2: 129.63, Queries: 11
# Attacking sample 70/100 (True: 1, Index: 627)...
#   Success! Adv label: 8, L2: 291.13, Queries: 25
# Attacking sample 71/100 (True: 1, Index: 630)...
#   Success! Adv label: 8, L2: 260.49, Queries: 21
# Attacking sample 72/100 (True: 1, Index: 632)...
#   Success! Adv label: 4, L2: 287.09, Queries: 23
# Attacking sample 73/100 (True: 1, Index: 644)...
#   Success! Adv label: 4, L2: 308.21, Queries: 25
# Attacking sample 74/100 (True: 1, Index: 646)...
#   Success! Adv label: 7, L2: 358.50, Queries: 33
# Attacking sample 75/100 (True: 1, Index: 649)...
#   Success! Adv label: 4, L2: 439.60, Queries: 35
# Attacking sample 76/100 (True: 1, Index: 662)...
#   Success! Adv label: 4, L2: 434.74, Queries: 35
# Attacking sample 77/100 (True: 1, Index: 663)...
#   Success! Adv label: 8, L2: 320.20, Queries: 25
# Attacking sample 78/100 (True: 1, Index: 669)...
#   Success! Adv label: 9, L2: 464.60, Queries: 39
# Attacking sample 79/100 (True: 1, Index: 677)...
#   Success! Adv label: 4, L2: 298.57, Queries: 25
# Attacking sample 80/100 (True: 1, Index: 686)...
#   Success! Adv label: 8, L2: 391.92, Queries: 33
# Attacking sample 81/100 (True: 1, Index: 689)...
#   Success! Adv label: 4, L2: 379.96, Queries: 29
# Attacking sample 82/100 (True: 1, Index: 703)...
#   Success! Adv label: 8, L2: 404.71, Queries: 33
# Attacking sample 83/100 (True: 1, Index: 705)...
#   Success! Adv label: 4, L2: 534.21, Queries: 47
# Attacking sample 84/100 (True: 1, Index: 709)...
#   Success! Adv label: 4, L2: 338.60, Queries: 29
# Attacking sample 85/100 (True: 1, Index: 724)...
#   Success! Adv label: 4, L2: 232.09, Queries: 19
# Attacking sample 86/100 (True: 1, Index: 727)...
#   Success! Adv label: 8, L2: 337.38, Queries: 27
# Attacking sample 87/100 (True: 1, Index: 734)...
#   Success! Adv label: 8, L2: 253.96, Queries: 23
# Attacking sample 88/100 (True: 1, Index: 740)...
#   Success! Adv label: 4, L2: 367.10, Queries: 29
# Attacking sample 89/100 (True: 1, Index: 741)...
#   Success! Adv label: 8, L2: 271.64, Queries: 23
# Attacking sample 90/100 (True: 1, Index: 743)...
#   Success! Adv label: 8, L2: 344.26, Queries: 27
# Attacking sample 91/100 (True: 1, Index: 759)...
#   Success! Adv label: 4, L2: 394.14, Queries: 33
# Attacking sample 92/100 (True: 1, Index: 768)...
#   Success! Adv label: 8, L2: 329.09, Queries: 27
# Attacking sample 93/100 (True: 1, Index: 775)...
#   Success! Adv label: 4, L2: 271.69, Queries: 23
# Attacking sample 94/100 (True: 1, Index: 782)...
#   Success! Adv label: 4, L2: 410.30, Queries: 33
# Attacking sample 95/100 (True: 1, Index: 798)...
#   Success! Adv label: 9, L2: 353.69, Queries: 31
# Attacking sample 96/100 (True: 1, Index: 799)...
#   Success! Adv label: 8, L2: 482.55, Queries: 39
# Attacking sample 97/100 (True: 1, Index: 808)...
#   Success! Adv label: 4, L2: 393.23, Queries: 33
# Attacking sample 98/100 (True: 1, Index: 819)...
#   Success! Adv label: 4, L2: 483.92, Queries: 39
# Attacking sample 99/100 (True: 1, Index: 843)...
#   Success! Adv label: 4, L2: 459.87, Queries: 37
# Attacking sample 100/100 (True: 1, Index: 853)...
#   Success! Adv label: 4, L2: 404.91, Queries: 33
# Attacking sample 1/100 (True: 2, Index: 4)...
#   Success! Adv label: 3, L2: 609.95, Queries: 57
# Attacking sample 2/100 (True: 2, Index: 22)...
#   Success! Adv label: 1, L2: 792.18, Queries: 105
# Attacking sample 3/100 (True: 2, Index: 32)...
#   Success! Adv label: 3, L2: 950.96, Queries: 91
# Attacking sample 4/100 (True: 2, Index: 34)...
#   Success! Adv label: 4, L2: 28.21, Queries: 3
# Attacking sample 5/100 (True: 2, Index: 42)...
#   Success! Adv label: 3, L2: 252.82, Queries: 23
# Attacking sample 6/100 (True: 2, Index: 49)...
#   Success! Adv label: 3, L2: 864.81, Queries: 127
# Attacking sample 7/100 (True: 2, Index: 52)...
#   Success! Adv label: 3, L2: 938.73, Queries: 109
# Attacking sample 8/100 (True: 2, Index: 69)...
#   Success! Adv label: 8, L2: 894.60, Queries: 83
# Attacking sample 9/100 (True: 2, Index: 70)...
#   Success! Adv label: 3, L2: 578.84, Queries: 67
# Attacking sample 10/100 (True: 2, Index: 81)...
#   Success! Adv label: 8, L2: 943.08, Queries: 81
# Attacking sample 11/100 (True: 2, Index: 110)...
#   Success! Adv label: 7, L2: 1021.53, Queries: 115
# Attacking sample 12/100 (True: 2, Index: 118)...
#   Success! Adv label: 3, L2: 601.47, Queries: 55
# Attacking sample 13/100 (True: 2, Index: 121)...
#   Success! Adv label: 3, L2: 706.88, Queries: 63
# Attacking sample 14/100 (True: 2, Index: 138)...
#   Success! Adv label: 8, L2: 752.24, Queries: 71
# Attacking sample 15/100 (True: 2, Index: 144)...
#   Success! Adv label: 0, L2: 797.06, Queries: 73
# Attacking sample 16/100 (True: 2, Index: 155)...
#   Success! Adv label: 8, L2: 835.30, Queries: 69
# Attacking sample 17/100 (True: 2, Index: 160)...
#   Success! Adv label: 6, L2: 442.94, Queries: 45
# Attacking sample 18/100 (True: 2, Index: 161)...
#   Success! Adv label: 3, L2: 636.01, Queries: 59
# Attacking sample 19/100 (True: 2, Index: 176)...
#   Success! Adv label: 3, L2: 716.24, Queries: 65
# Attacking sample 21/100 (True: 2, Index: 186)...
#   Success! Adv label: 7, L2: 800.30, Queries: 97
# Attacking sample 22/100 (True: 2, Index: 197)...
#   Success! Adv label: 8, L2: 920.15, Queries: 93
# Attacking sample 23/100 (True: 2, Index: 208)...
#   Success! Adv label: 8, L2: 885.46, Queries: 83
# Attacking sample 25/100 (True: 2, Index: 216)...
#   Success! Adv label: 3, L2: 816.92, Queries: 87
# Attacking sample 26/100 (True: 2, Index: 219)...
#   Success! Adv label: 3, L2: 433.34, Queries: 43
# Attacking sample 27/100 (True: 2, Index: 235)...
#   Success! Adv label: 3, L2: 769.76, Queries: 77
# Attacking sample 28/100 (True: 2, Index: 260)...
#   Success! Adv label: 0, L2: 586.78, Queries: 55
# Attacking sample 29/100 (True: 2, Index: 276)...
#   Success! Adv label: 4, L2: 526.12, Queries: 55
# Attacking sample 30/100 (True: 2, Index: 293)...
#   Success! Adv label: 3, L2: 715.70, Queries: 83
# Attacking sample 31/100 (True: 2, Index: 295)...
#   Success! Adv label: 3, L2: 579.27, Queries: 57
# Attacking sample 32/100 (True: 2, Index: 311)...
#   Success! Adv label: 3, L2: 537.98, Queries: 51
# Attacking sample 33/100 (True: 2, Index: 313)...
#   Success! Adv label: 3, L2: 150.75, Queries: 15
# Attacking sample 34/100 (True: 2, Index: 322)...
#   Success! Adv label: 0, L2: 687.24, Queries: 65
# Attacking sample 35/100 (True: 2, Index: 328)...
#   Success! Adv label: 8, L2: 722.62, Queries: 67
# Attacking sample 36/100 (True: 2, Index: 357)...
#   Success! Adv label: 7, L2: 541.54, Queries: 53
# Attacking sample 37/100 (True: 2, Index: 374)...
#   Success! Adv label: 8, L2: 475.64, Queries: 43
# Attacking sample 38/100 (True: 2, Index: 395)...
#   Success! Adv label: 8, L2: 457.52, Queries: 47
# Attacking sample 39/100 (True: 2, Index: 396)...
#   Success! Adv label: 8, L2: 698.63, Queries: 65
# Attacking sample 40/100 (True: 2, Index: 398)...
#   Success! Adv label: 3, L2: 797.18, Queries: 81
# Attacking sample 41/100 (True: 2, Index: 433)...
#   Success! Adv label: 3, L2: 661.31, Queries: 61
# Attacking sample 42/100 (True: 2, Index: 439)...
#   Success! Adv label: 9, L2: 732.22, Queries: 67
# Attacking sample 43/100 (True: 2, Index: 441)...
#   Success! Adv label: 8, L2: 350.17, Queries: 29
# Attacking sample 44/100 (True: 2, Index: 442)...
#   Success! Adv label: 9, L2: 723.91, Queries: 67
# Attacking sample 45/100 (True: 2, Index: 451)...
#   Success! Adv label: 0, L2: 1156.49, Queries: 155
# Attacking sample 46/100 (True: 2, Index: 462)...
#   Success! Adv label: 3, L2: 662.54, Queries: 59
# Attacking sample 47/100 (True: 2, Index: 470)...
#   Success! Adv label: 3, L2: 624.08, Queries: 57
# Attacking sample 48/100 (True: 2, Index: 477)...
#   Success! Adv label: 3, L2: 877.65, Queries: 85
# Attacking sample 49/100 (True: 2, Index: 485)...
#   Success! Adv label: 7, L2: 253.59, Queries: 23
# Attacking sample 50/100 (True: 2, Index: 491)...
#   Success! Adv label: 8, L2: 745.61, Queries: 63
# Attacking sample 51/100 (True: 2, Index: 493)...
#   Success! Adv label: 7, L2: 830.32, Queries: 97
# Attacking sample 52/100 (True: 2, Index: 495)...
#   Success! Adv label: 3, L2: 665.93, Queries: 65
# Attacking sample 53/100 (True: 2, Index: 519)...
#   Success! Adv label: 3, L2: 820.29, Queries: 77
# Attacking sample 54/100 (True: 2, Index: 523)...
#   Success! Adv label: 6, L2: 739.46, Queries: 79
# Attacking sample 55/100 (True: 2, Index: 557)...
#   Success! Adv label: 8, L2: 822.07, Queries: 73
# Attacking sample 56/100 (True: 2, Index: 567)...
#   Success! Adv label: 0, L2: 525.15, Queries: 47
# Attacking sample 57/100 (True: 2, Index: 571)...
#   Success! Adv label: 7, L2: 695.35, Queries: 69
# Attacking sample 58/100 (True: 2, Index: 584)...
#   Success! Adv label: 3, L2: 982.28, Queries: 95
# Attacking sample 59/100 (True: 2, Index: 591)...
#   Success! Adv label: 8, L2: 1018.42, Queries: 105
# Attacking sample 60/100 (True: 2, Index: 592)...
#   Success! Adv label: 8, L2: 873.44, Queries: 99
# Attacking sample 61/100 (True: 2, Index: 610)...
#   Success! Adv label: 3, L2: 1011.41, Queries: 101
# Attacking sample 62/100 (True: 2, Index: 612)...
#   Success! Adv label: 8, L2: 709.32, Queries: 59
# Attacking sample 63/100 (True: 2, Index: 616)...
#   Success! Adv label: 3, L2: 847.48, Queries: 81
# Attacking sample 64/100 (True: 2, Index: 624)...
#   Success! Adv label: 3, L2: 714.29, Queries: 63
# Attacking sample 65/100 (True: 2, Index: 631)...
#   Success! Adv label: 3, L2: 531.71, Queries: 53
# Attacking sample 66/100 (True: 2, Index: 636)...
#   Success! Adv label: 3, L2: 858.80, Queries: 77
# Attacking sample 67/100 (True: 2, Index: 647)...
#   Success! Adv label: 1, L2: 144.88, Queries: 15
# Attacking sample 68/100 (True: 2, Index: 650)...
#   Success! Adv label: 3, L2: 219.55, Queries: 21
# Attacking sample 69/100 (True: 2, Index: 664)...
#   Success! Adv label: 3, L2: 987.78, Queries: 95
# Attacking sample 70/100 (True: 2, Index: 704)...
#   Success! Adv label: 3, L2: 663.17, Queries: 63
# Attacking sample 71/100 (True: 2, Index: 720)...
#   Success! Adv label: 4, L2: 249.05, Queries: 23
# Attacking sample 72/100 (True: 2, Index: 725)...
#   Success! Adv label: 3, L2: 520.61, Queries: 47
# Attacking sample 73/100 (True: 2, Index: 750)...
#   Success! Adv label: 3, L2: 876.45, Queries: 169
# Attacking sample 74/100 (True: 2, Index: 764)...
#   Success! Adv label: 3, L2: 631.43, Queries: 75
# Attacking sample 75/100 (True: 2, Index: 780)...
#   Success! Adv label: 8, L2: 845.75, Queries: 77
# Attacking sample 76/100 (True: 2, Index: 784)...
#   Success! Adv label: 8, L2: 923.75, Queries: 85
# Attacking sample 77/100 (True: 2, Index: 788)...
#   Success! Adv label: 1, L2: 594.68, Queries: 55
# Attacking sample 78/100 (True: 2, Index: 790)...
#   Success! Adv label: 3, L2: 915.43, Queries: 103
# Attacking sample 79/100 (True: 2, Index: 797)...
#   Success! Adv label: 8, L2: 591.65, Queries: 53
# Attacking sample 80/100 (True: 2, Index: 803)...
#   Success! Adv label: 0, L2: 967.94, Queries: 87
# Attacking sample 81/100 (True: 2, Index: 807)...
#   Failed! Adv label: 2, L2: 1032.97, Queries: 201
# Attacking sample 82/100 (True: 2, Index: 828)...
#   Success! Adv label: 3, L2: 471.36, Queries: 43
# Attacking sample 83/100 (True: 2, Index: 842)...
#   Success! Adv label: 3, L2: 721.92, Queries: 73
# Attacking sample 84/100 (True: 2, Index: 845)...
#   Success! Adv label: 3, L2: 953.12, Queries: 83
# Attacking sample 85/100 (True: 2, Index: 859)...
#   Success! Adv label: 3, L2: 491.56, Queries: 45
# Attacking sample 86/100 (True: 2, Index: 871)...
#   Success! Adv label: 7, L2: 764.74, Queries: 77
# Attacking sample 87/100 (True: 2, Index: 881)...
#   Success! Adv label: 3, L2: 586.15, Queries: 67
# Attacking sample 88/100 (True: 2, Index: 883)...
#   Success! Adv label: 8, L2: 412.91, Queries: 37
# Attacking sample 89/100 (True: 2, Index: 896)...
#   Success! Adv label: 3, L2: 541.15, Queries: 51
# Attacking sample 90/100 (True: 2, Index: 897)...
#   Success! Adv label: 3, L2: 521.32, Queries: 59
# Attacking sample 92/100 (True: 2, Index: 922)...
#   Success! Adv label: 7, L2: 573.75, Queries: 59
# Attacking sample 93/100 (True: 2, Index: 932)...
#   Success! Adv label: 8, L2: 734.64, Queries: 67
# Attacking sample 94/100 (True: 2, Index: 944)...
#   Success! Adv label: 3, L2: 558.38, Queries: 51
# Attacking sample 95/100 (True: 2, Index: 949)...
#   Success! Adv label: 3, L2: 813.96, Queries: 73
# Attacking sample 96/100 (True: 2, Index: 952)...
#   Failed! Adv label: 2, L2: 936.39, Queries: 201
# Attacking sample 97/100 (True: 2, Index: 959)...
#   Success! Adv label: 3, L2: 600.93, Queries: 53
# Attacking sample 98/100 (True: 2, Index: 966)...
#   Success! Adv label: 7, L2: 202.47, Queries: 21
# Attacking sample 99/100 (True: 2, Index: 967)...
#   Success! Adv label: 7, L2: 820.19, Queries: 87
# Attacking sample 100/100 (True: 2, Index: 985)...
#   Success! Adv label: 3, L2: 632.65, Queries: 67
# Attacking sample 1/100 (True: 3, Index: 1)...
#   Success! Adv label: 5, L2: 364.65, Queries: 33
# Attacking sample 2/100 (True: 3, Index: 12)...
#   Success! Adv label: 8, L2: 385.40, Queries: 39
# Attacking sample 3/100 (True: 3, Index: 20)...
#   Success! Adv label: 2, L2: 791.04, Queries: 69
# Attacking sample 4/100 (True: 3, Index: 27)...
#   Success! Adv label: 8, L2: 936.73, Queries: 125
# Attacking sample 5/100 (True: 3, Index: 37)...
#   Success! Adv label: 2, L2: 972.44, Queries: 99
# Attacking sample 6/100 (True: 3, Index: 43)...
#   Failed! Adv label: 3, L2: 931.60, Queries: 201
# Attacking sample 7/100 (True: 3, Index: 53)...
#   Success! Adv label: 8, L2: 590.55, Queries: 53
# Attacking sample 8/100 (True: 3, Index: 61)...
#   Success! Adv label: 8, L2: 604.41, Queries: 53
# Attacking sample 9/100 (True: 3, Index: 73)...
#   Success! Adv label: 8, L2: 663.37, Queries: 67
# Attacking sample 10/100 (True: 3, Index: 102)...
#   Success! Adv label: 2, L2: 419.64, Queries: 39
# Attacking sample 11/100 (True: 3, Index: 108)...
#   Success! Adv label: 2, L2: 91.56, Queries: 9
# Attacking sample 12/100 (True: 3, Index: 109)...
#   Success! Adv label: 8, L2: 579.58, Queries: 49
# Attacking sample 13/100 (True: 3, Index: 117)...
#   Success! Adv label: 5, L2: 938.25, Queries: 147
# Attacking sample 14/100 (True: 3, Index: 131)...
#   Success! Adv label: 8, L2: 152.07, Queries: 13
# Attacking sample 15/100 (True: 3, Index: 159)...
#   Success! Adv label: 2, L2: 941.50, Queries: 105
# Attacking sample 16/100 (True: 3, Index: 162)...
#   Success! Adv label: 2, L2: 994.34, Queries: 173
# Attacking sample 17/100 (True: 3, Index: 166)...
#   Success! Adv label: 2, L2: 800.57, Queries: 117
# Attacking sample 18/100 (True: 3, Index: 177)...
#   Success! Adv label: 8, L2: 567.41, Queries: 47
# Attacking sample 19/100 (True: 3, Index: 181)...
#   Success! Adv label: 5, L2: 607.32, Queries: 67
# Attacking sample 20/100 (True: 3, Index: 187)...
#   Success! Adv label: 8, L2: 702.49, Queries: 59
# Attacking sample 21/100 (True: 3, Index: 196)...
#   Success! Adv label: 2, L2: 511.19, Queries: 43
# Attacking sample 22/100 (True: 3, Index: 204)...
#   Success! Adv label: 5, L2: 950.13, Queries: 143
# Attacking sample 23/100 (True: 3, Index: 227)...
#   Failed! Adv label: 3, L2: 858.59, Queries: 201
# Attacking sample 24/100 (True: 3, Index: 231)...
#   Success! Adv label: 5, L2: 736.86, Queries: 71
# Attacking sample 25/100 (True: 3, Index: 237)...
#   Success! Adv label: 5, L2: 991.43, Queries: 119
# Attacking sample 26/100 (True: 3, Index: 244)...
#   Success! Adv label: 7, L2: 896.33, Queries: 101
# Attacking sample 27/100 (True: 3, Index: 257)...
#   Success! Adv label: 8, L2: 562.04, Queries: 49
# Attacking sample 28/100 (True: 3, Index: 259)...
#   Success! Adv label: 5, L2: 942.73, Queries: 101
# Attacking sample 29/100 (True: 3, Index: 265)...
#   Success! Adv label: 5, L2: 520.87, Queries: 47
# Attacking sample 30/100 (True: 3, Index: 270)...
#   Success! Adv label: 5, L2: 261.46, Queries: 23
# Attacking sample 31/100 (True: 3, Index: 288)...
#   Success! Adv label: 8, L2: 936.19, Queries: 81
# Attacking sample 32/100 (True: 3, Index: 308)...
#   Success! Adv label: 8, L2: 586.91, Queries: 55
# Attacking sample 33/100 (True: 3, Index: 309)...
#   Success! Adv label: 8, L2: 580.15, Queries: 53
# Attacking sample 34/100 (True: 3, Index: 327)...
#   Success! Adv label: 1, L2: 370.77, Queries: 41
# Attacking sample 35/100 (True: 3, Index: 331)...
#   Success! Adv label: 8, L2: 788.28, Queries: 79
# Attacking sample 36/100 (True: 3, Index: 340)...
#   Failed! Adv label: 3, L2: 1004.08, Queries: 201
# Attacking sample 37/100 (True: 3, Index: 341)...
#   Success! Adv label: 5, L2: 805.67, Queries: 81
# Attacking sample 38/100 (True: 3, Index: 342)...
#   Success! Adv label: 5, L2: 521.81, Queries: 49
# Attacking sample 39/100 (True: 3, Index: 362)...
#   Success! Adv label: 2, L2: 519.95, Queries: 47
# Attacking sample 40/100 (True: 3, Index: 383)...
#   Success! Adv label: 2, L2: 548.37, Queries: 53
# Attacking sample 41/100 (True: 3, Index: 394)...
#   Success! Adv label: 8, L2: 495.69, Queries: 43
# Attacking sample 42/100 (True: 3, Index: 406)...
#   Failed! Adv label: 3, L2: 884.63, Queries: 201
# Attacking sample 43/100 (True: 3, Index: 409)...
#   Success! Adv label: 2, L2: 882.61, Queries: 93
# Attacking sample 44/100 (True: 3, Index: 445)...
#   Success! Adv label: 2, L2: 394.95, Queries: 35
# Attacking sample 45/100 (True: 3, Index: 456)...
#   Success! Adv label: 8, L2: 551.62, Queries: 47
# Attacking sample 46/100 (True: 3, Index: 459)...
#   Failed! Adv label: 3, L2: 1015.15, Queries: 201
# Attacking sample 47/100 (True: 3, Index: 461)...
#   Failed! Adv label: 3, L2: 1021.61, Queries: 201
# Attacking sample 48/100 (True: 3, Index: 471)...
#   Success! Adv label: 8, L2: 860.37, Queries: 77
# Attacking sample 49/100 (True: 3, Index: 474)...
#   Success! Adv label: 5, L2: 493.60, Queries: 47
# Attacking sample 50/100 (True: 3, Index: 481)...
#   Success! Adv label: 5, L2: 806.18, Queries: 87
# Attacking sample 51/100 (True: 3, Index: 504)...
#   Success! Adv label: 5, L2: 727.50, Queries: 71
# Attacking sample 52/100 (True: 3, Index: 510)...
#   Success! Adv label: 5, L2: 361.35, Queries: 33
# Attacking sample 53/100 (True: 3, Index: 512)...
#   Failed! Adv label: 3, L2: 864.05, Queries: 201
# Attacking sample 54/100 (True: 3, Index: 524)...
#   Success! Adv label: 8, L2: 640.99, Queries: 55
# Attacking sample 55/100 (True: 3, Index: 549)...
#   Success! Adv label: 8, L2: 542.31, Queries: 53
# Attacking sample 56/100 (True: 3, Index: 556)...
#   Success! Adv label: 9, L2: 707.14, Queries: 69
# Attacking sample 57/100 (True: 3, Index: 564)...
#   Success! Adv label: 9, L2: 535.14, Queries: 47
# Attacking sample 58/100 (True: 3, Index: 586)...
#   Failed! Adv label: 3, L2: 929.42, Queries: 201
# Attacking sample 59/100 (True: 3, Index: 589)...
#   Success! Adv label: 0, L2: 1078.46, Queries: 141
# Attacking sample 60/100 (True: 3, Index: 609)...
#   Success! Adv label: 9, L2: 781.53, Queries: 77
# Attacking sample 61/100 (True: 3, Index: 613)...
#   Success! Adv label: 2, L2: 713.68, Queries: 63
# Attacking sample 62/100 (True: 3, Index: 623)...
#   Success! Adv label: 9, L2: 432.73, Queries: 39
# Attacking sample 63/100 (True: 3, Index: 639)...
#   Success! Adv label: 5, L2: 772.87, Queries: 77
# Attacking sample 64/100 (True: 3, Index: 648)...
#   Success! Adv label: 8, L2: 472.60, Queries: 41
# Attacking sample 65/100 (True: 3, Index: 651)...
#   Success! Adv label: 8, L2: 426.56, Queries: 37
# Attacking sample 66/100 (True: 3, Index: 659)...
#   Success! Adv label: 9, L2: 682.61, Queries: 71
# Attacking sample 67/100 (True: 3, Index: 661)...
#   Success! Adv label: 5, L2: 1018.17, Queries: 117
# Attacking sample 68/100 (True: 3, Index: 667)...
#   Failed! Adv label: 3, L2: 881.71, Queries: 201
# Attacking sample 69/100 (True: 3, Index: 678)...
#   Success! Adv label: 5, L2: 891.07, Queries: 173
# Attacking sample 70/100 (True: 3, Index: 690)...
#   Success! Adv label: 8, L2: 977.61, Queries: 85
# Attacking sample 71/100 (True: 3, Index: 693)...
#   Failed! Adv label: 3, L2: 832.63, Queries: 201
# Attacking sample 72/100 (True: 3, Index: 694)...
#   Success! Adv label: 8, L2: 823.13, Queries: 75
# Attacking sample 73/100 (True: 3, Index: 695)...
#   Success! Adv label: 0, L2: 288.06, Queries: 25
# Attacking sample 74/100 (True: 3, Index: 702)...
#   Success! Adv label: 8, L2: 403.46, Queries: 33
# Attacking sample 75/100 (True: 3, Index: 718)...
#   Failed! Adv label: 3, L2: 911.56, Queries: 201
# Attacking sample 76/100 (True: 3, Index: 749)...
#   Success! Adv label: 5, L2: 997.43, Queries: 137
# Attacking sample 77/100 (True: 3, Index: 769)...
#   Success! Adv label: 9, L2: 859.87, Queries: 77
# Attacking sample 79/100 (True: 3, Index: 779)...
#   Success! Adv label: 8, L2: 437.13, Queries: 41
# Attacking sample 80/100 (True: 3, Index: 800)...
#   Success! Adv label: 8, L2: 899.27, Queries: 75
# Attacking sample 81/100 (True: 3, Index: 816)...
#   Success! Adv label: 5, L2: 318.94, Queries: 31
# Attacking sample 82/100 (True: 3, Index: 829)...
#   Success! Adv label: 2, L2: 561.21, Queries: 51
# Attacking sample 83/100 (True: 3, Index: 833)...
#   Failed! Adv label: 3, L2: 869.95, Queries: 201
# Attacking sample 84/100 (True: 3, Index: 839)...
#   Success! Adv label: 8, L2: 703.52, Queries: 65
# Attacking sample 85/100 (True: 3, Index: 854)...
#   Success! Adv label: 5, L2: 345.10, Queries: 33
# Attacking sample 86/100 (True: 3, Index: 856)...
#   Success! Adv label: 2, L2: 480.40, Queries: 47
# Attacking sample 87/100 (True: 3, Index: 858)...
#   Success! Adv label: 5, L2: 115.25, Queries: 11
# Attacking sample 89/100 (True: 3, Index: 886)...
#   Success! Adv label: 8, L2: 844.11, Queries: 77
# Attacking sample 90/100 (True: 3, Index: 900)...
#   Success! Adv label: 8, L2: 731.76, Queries: 65
# Attacking sample 91/100 (True: 3, Index: 916)...
#   Success! Adv label: 5, L2: 496.90, Queries: 53
# Attacking sample 92/100 (True: 3, Index: 921)...
#   Success! Adv label: 2, L2: 443.72, Queries: 43
# Attacking sample 93/100 (True: 3, Index: 937)...
#   Success! Adv label: 9, L2: 969.13, Queries: 87
# Attacking sample 94/100 (True: 3, Index: 938)...
#   Success! Adv label: 8, L2: 735.58, Queries: 59
# Attacking sample 95/100 (True: 3, Index: 939)...
#   Success! Adv label: 8, L2: 385.74, Queries: 33
# Attacking sample 96/100 (True: 3, Index: 942)...
#   Success! Adv label: 5, L2: 964.09, Queries: 123
# Attacking sample 97/100 (True: 3, Index: 951)...
#   Success! Adv label: 8, L2: 600.93, Queries: 55
# Attacking sample 98/100 (True: 3, Index: 953)...
#   Failed! Adv label: 3, L2: 894.11, Queries: 201
# Attacking sample 99/100 (True: 3, Index: 975)...
#   Failed! Adv label: 3, L2: 978.64, Queries: 201
# Attacking sample 1/100 (True: 4, Index: 16)...
#   Success! Adv label: 9, L2: 329.92, Queries: 31
# Attacking sample 2/100 (True: 4, Index: 17)...
#   Success! Adv label: 6, L2: 443.49, Queries: 41
# Attacking sample 3/100 (True: 4, Index: 30)...
#   Success! Adv label: 8, L2: 830.57, Queries: 77
# Attacking sample 4/100 (True: 4, Index: 33)...
#   Success! Adv label: 9, L2: 518.82, Queries: 47
# Attacking sample 5/100 (True: 4, Index: 45)...
#   Success! Adv label: 8, L2: 131.19, Queries: 11
# Attacking sample 6/100 (True: 4, Index: 48)...
#   Success! Adv label: 9, L2: 769.87, Queries: 69
# Attacking sample 7/100 (True: 4, Index: 58)...
#   Success! Adv label: 9, L2: 721.66, Queries: 63
# Attacking sample 8/100 (True: 4, Index: 66)...
#   Success! Adv label: 6, L2: 649.10, Queries: 63
# Attacking sample 9/100 (True: 4, Index: 89)...
#   Success! Adv label: 9, L2: 378.07, Queries: 33
# Attacking sample 10/100 (True: 4, Index: 92)...
#   Success! Adv label: 6, L2: 905.33, Queries: 87
# Attacking sample 11/100 (True: 4, Index: 113)...
#   Success! Adv label: 9, L2: 782.89, Queries: 73
# Attacking sample 12/100 (True: 4, Index: 116)...
#   Success! Adv label: 9, L2: 660.80, Queries: 57
# Attacking sample 13/100 (True: 4, Index: 126)...
#   Success! Adv label: 9, L2: 505.51, Queries: 45
# Attacking sample 14/100 (True: 4, Index: 130)...
#   Success! Adv label: 9, L2: 385.79, Queries: 33
# Attacking sample 15/100 (True: 4, Index: 139)...
#   Success! Adv label: 9, L2: 583.12, Queries: 51
# Attacking sample 16/100 (True: 4, Index: 149)...
#   Failed! Adv label: 4, L2: 1100.00, Queries: 201
# Attacking sample 17/100 (True: 4, Index: 153)...
#   Success! Adv label: 8, L2: 497.98, Queries: 45
# Attacking sample 18/100 (True: 4, Index: 154)...
#   Success! Adv label: 7, L2: 874.94, Queries: 81
# Attacking sample 19/100 (True: 4, Index: 163)...
#   Success! Adv label: 9, L2: 584.58, Queries: 53
# Attacking sample 20/100 (True: 4, Index: 167)...
#   Success! Adv label: 9, L2: 788.71, Queries: 73
# Attacking sample 21/100 (True: 4, Index: 183)...
#   Success! Adv label: 9, L2: 458.00, Queries: 43
# Attacking sample 22/100 (True: 4, Index: 184)...
#   Success! Adv label: 9, L2: 586.14, Queries: 53
# Attacking sample 23/100 (True: 4, Index: 192)...
#   Success! Adv label: 9, L2: 286.13, Queries: 25
# Attacking sample 24/100 (True: 4, Index: 194)...
#   Success! Adv label: 9, L2: 507.42, Queries: 47
# Attacking sample 25/100 (True: 4, Index: 233)...
#   Success! Adv label: 9, L2: 709.29, Queries: 65
# Attacking sample 26/100 (True: 4, Index: 240)...
#   Success! Adv label: 8, L2: 616.56, Queries: 53
# Attacking sample 27/100 (True: 4, Index: 263)...
#   Success! Adv label: 9, L2: 294.02, Queries: 25
# Attacking sample 28/100 (True: 4, Index: 269)...
#   Success! Adv label: 9, L2: 422.42, Queries: 37
# Attacking sample 29/100 (True: 4, Index: 280)...
#   Success! Adv label: 9, L2: 414.85, Queries: 37
# Attacking sample 30/100 (True: 4, Index: 290)...
#   Success! Adv label: 9, L2: 665.10, Queries: 57
# Attacking sample 31/100 (True: 4, Index: 297)...
#   Success! Adv label: 6, L2: 448.94, Queries: 41
# Attacking sample 32/100 (True: 4, Index: 299)...
#   Success! Adv label: 9, L2: 381.92, Queries: 33
# Attacking sample 33/100 (True: 4, Index: 310)...
#   Success! Adv label: 9, L2: 336.21, Queries: 29
# Attacking sample 34/100 (True: 4, Index: 316)...
#   Success! Adv label: 9, L2: 495.53, Queries: 43
# Attacking sample 35/100 (True: 4, Index: 320)...
#   Success! Adv label: 9, L2: 433.72, Queries: 39
# Attacking sample 36/100 (True: 4, Index: 324)...
#   Success! Adv label: 9, L2: 513.30, Queries: 47
# Attacking sample 37/100 (True: 4, Index: 326)...
#   Success! Adv label: 9, L2: 558.56, Queries: 53
# Attacking sample 38/100 (True: 4, Index: 332)...
#   Success! Adv label: 9, L2: 29.15, Queries: 3
# Attacking sample 39/100 (True: 4, Index: 335)...
#   Success! Adv label: 9, L2: 687.64, Queries: 61
# Attacking sample 40/100 (True: 4, Index: 344)...
#   Success! Adv label: 7, L2: 526.41, Queries: 49
# Attacking sample 42/100 (True: 4, Index: 359)...
#   Success! Adv label: 9, L2: 445.28, Queries: 37
# Attacking sample 43/100 (True: 4, Index: 376)...
#   Success! Adv label: 9, L2: 635.32, Queries: 61
# Attacking sample 44/100 (True: 4, Index: 393)...
#   Success! Adv label: 9, L2: 585.32, Queries: 51
# Attacking sample 45/100 (True: 4, Index: 401)...
#   Success! Adv label: 2, L2: 836.98, Queries: 77
# Attacking sample 46/100 (True: 4, Index: 402)...
#   Success! Adv label: 9, L2: 538.68, Queries: 49
# Attacking sample 47/100 (True: 4, Index: 422)...
#   Success! Adv label: 9, L2: 371.87, Queries: 31
# Attacking sample 48/100 (True: 4, Index: 423)...
#   Success! Adv label: 9, L2: 198.69, Queries: 19
# Attacking sample 49/100 (True: 4, Index: 427)...
#   Success! Adv label: 1, L2: 619.18, Queries: 63
# Attacking sample 50/100 (True: 4, Index: 432)...
#   Success! Adv label: 9, L2: 446.56, Queries: 41
# Attacking sample 51/100 (True: 4, Index: 434)...
#   Success! Adv label: 9, L2: 315.23, Queries: 27
# Attacking sample 52/100 (True: 4, Index: 454)...
#   Success! Adv label: 9, L2: 556.72, Queries: 51
# Attacking sample 53/100 (True: 4, Index: 467)...
#   Success! Adv label: 8, L2: 371.26, Queries: 33
# Attacking sample 54/100 (True: 4, Index: 501)...
#   Success! Adv label: 9, L2: 288.17, Queries: 27
# Attacking sample 55/100 (True: 4, Index: 515)...
#   Success! Adv label: 9, L2: 399.61, Queries: 35
# Attacking sample 56/100 (True: 4, Index: 540)...
#   Success! Adv label: 9, L2: 609.01, Queries: 57
# Attacking sample 57/100 (True: 4, Index: 544)...
#   Success! Adv label: 6, L2: 596.08, Queries: 57
# Attacking sample 58/100 (True: 4, Index: 545)...
#   Success! Adv label: 9, L2: 494.47, Queries: 45
# Attacking sample 59/100 (True: 4, Index: 547)...
#   Success! Adv label: 7, L2: 820.97, Queries: 93
# Attacking sample 60/100 (True: 4, Index: 566)...
#   Success! Adv label: 9, L2: 439.29, Queries: 37
# Attacking sample 61/100 (True: 4, Index: 590)...
#   Success! Adv label: 0, L2: 485.02, Queries: 43
# Attacking sample 62/100 (True: 4, Index: 593)...
#   Success! Adv label: 9, L2: 360.61, Queries: 31
# Attacking sample 63/100 (True: 4, Index: 599)...
#   Success! Adv label: 9, L2: 763.27, Queries: 77
# Attacking sample 64/100 (True: 4, Index: 602)...
#   Success! Adv label: 9, L2: 536.52, Queries: 47
# Attacking sample 65/100 (True: 4, Index: 607)...
#   Success! Adv label: 7, L2: 614.75, Queries: 65
# Attacking sample 66/100 (True: 4, Index: 611)...
#   Success! Adv label: 9, L2: 740.13, Queries: 69
# Attacking sample 67/100 (True: 4, Index: 617)...
#   Success! Adv label: 9, L2: 617.43, Queries: 51
# Attacking sample 68/100 (True: 4, Index: 657)...
#   Success! Adv label: 9, L2: 349.66, Queries: 33
# Attacking sample 69/100 (True: 4, Index: 680)...
#   Success! Adv label: 9, L2: 404.13, Queries: 35
# Attacking sample 70/100 (True: 4, Index: 684)...
#   Success! Adv label: 9, L2: 679.49, Queries: 67
# Attacking sample 71/100 (True: 4, Index: 687)...
#   Success! Adv label: 9, L2: 561.43, Queries: 49
# Attacking sample 72/100 (True: 4, Index: 692)...
#   Success! Adv label: 9, L2: 903.43, Queries: 83
# Attacking sample 73/100 (True: 4, Index: 696)...
#   Success! Adv label: 9, L2: 187.33, Queries: 17
# Attacking sample 74/100 (True: 4, Index: 697)...
#   Success! Adv label: 9, L2: 940.05, Queries: 83
# Attacking sample 75/100 (True: 4, Index: 708)...
#   Success! Adv label: 9, L2: 597.95, Queries: 53
# Attacking sample 76/100 (True: 4, Index: 717)...
#   Success! Adv label: 9, L2: 396.22, Queries: 35
# Attacking sample 77/100 (True: 4, Index: 746)...
#   Success! Adv label: 9, L2: 517.36, Queries: 49
# Attacking sample 78/100 (True: 4, Index: 752)...
#   Success! Adv label: 9, L2: 1030.94, Queries: 95
# Attacking sample 79/100 (True: 4, Index: 755)...
#   Success! Adv label: 7, L2: 800.93, Queries: 97
# Attacking sample 80/100 (True: 4, Index: 757)...
#   Success! Adv label: 9, L2: 467.61, Queries: 41
# Attacking sample 81/100 (True: 4, Index: 766)...
#   Success! Adv label: 7, L2: 488.26, Queries: 47
# Attacking sample 82/100 (True: 4, Index: 771)...
#   Success! Adv label: 9, L2: 333.97, Queries: 29
# Attacking sample 83/100 (True: 4, Index: 776)...
#   Success! Adv label: 2, L2: 691.63, Queries: 65
# Attacking sample 84/100 (True: 4, Index: 777)...
#   Success! Adv label: 1, L2: 975.66, Queries: 127
# Attacking sample 85/100 (True: 4, Index: 786)...
#   Success! Adv label: 9, L2: 220.41, Queries: 19
# Attacking sample 86/100 (True: 4, Index: 811)...
#   Success! Adv label: 9, L2: 302.59, Queries: 27
# Attacking sample 87/100 (True: 4, Index: 815)...
#   Success! Adv label: 6, L2: 715.53, Queries: 67
# Attacking sample 88/100 (True: 4, Index: 817)...
#   Success! Adv label: 7, L2: 866.04, Queries: 89
# Attacking sample 89/100 (True: 4, Index: 840)...
#   Success! Adv label: 6, L2: 763.62, Queries: 69
# Attacking sample 91/100 (True: 4, Index: 849)...
#   Success! Adv label: 8, L2: 745.70, Queries: 65
# Attacking sample 92/100 (True: 4, Index: 857)...
#   Success! Adv label: 9, L2: 578.84, Queries: 51
# Attacking sample 93/100 (True: 4, Index: 872)...
#   Success! Adv label: 9, L2: 779.28, Queries: 77
# Attacking sample 94/100 (True: 4, Index: 877)...
#   Success! Adv label: 9, L2: 500.74, Queries: 47
# Attacking sample 95/100 (True: 4, Index: 894)...
#   Success! Adv label: 9, L2: 283.95, Queries: 25
# Attacking sample 96/100 (True: 4, Index: 902)...
#   Success! Adv label: 9, L2: 432.87, Queries: 37
# Attacking sample 97/100 (True: 4, Index: 911)...
# ...
#   Success! Adv label: 3, L2: 574.99, Queries: 55
# Attacking sample 40/100 (True: 8, Index: 505)...
#   Success! Adv label: 2, L2: 735.04, Queries: 73
# Attacking sample 41/100 (True: 8, Index: 509)...
#   Success! Adv label: 3, L2: 663.46, Queries: 75
# Attacking sample 42/100 (True: 8, Index: 525)...
#   Success! Adv label: 3, L2: 591.49, Queries: 61
# Attacking sample 43/100 (True: 8, Index: 528)...
#   Success! Adv label: 3, L2: 697.53, Queries: 79
# Attacking sample 44/100 (True: 8, Index: 541)...
#   Success! Adv label: 3, L2: 862.92, Queries: 87
# Attacking sample 45/100 (True: 8, Index: 543)...
#   Success! Adv label: 6, L2: 401.47, Queries: 39
# Attacking sample 46/100 (True: 8, Index: 550)...
#   Success! Adv label: 5, L2: 512.45, Queries: 51
# Attacking sample 47/100 (True: 8, Index: 558)...
#   Success! Adv label: 2, L2: 912.57, Queries: 93
# Attacking sample 48/100 (True: 8, Index: 575)...
#   Success! Adv label: 9, L2: 510.14, Queries: 53
# Attacking sample 49/100 (True: 8, Index: 594)...
#   Success! Adv label: 2, L2: 418.07, Queries: 43
# Attacking sample 50/100 (True: 8, Index: 600)...
#   Success! Adv label: 3, L2: 1023.31, Queries: 125
# Attacking sample 51/100 (True: 8, Index: 605)...
#   Success! Adv label: 2, L2: 648.11, Queries: 63
# Attacking sample 52/100 (True: 8, Index: 619)...
#   Success! Adv label: 3, L2: 587.83, Queries: 63
# Attacking sample 53/100 (True: 8, Index: 625)...
#   Success! Adv label: 3, L2: 816.40, Queries: 77
# Attacking sample 54/100 (True: 8, Index: 629)...
#   Success! Adv label: 2, L2: 583.29, Queries: 55
# Attacking sample 55/100 (True: 8, Index: 645)...
#   Success! Adv label: 9, L2: 970.29, Queries: 97
# Attacking sample 56/100 (True: 8, Index: 652)...
#   Success! Adv label: 2, L2: 709.54, Queries: 77
# Attacking sample 57/100 (True: 8, Index: 672)...
#   Success! Adv label: 3, L2: 583.19, Queries: 65
# Attacking sample 58/100 (True: 8, Index: 683)...
#   Success! Adv label: 3, L2: 359.60, Queries: 41
# Attacking sample 59/100 (True: 8, Index: 701)...
#   Success! Adv label: 5, L2: 779.88, Queries: 83
# Attacking sample 60/100 (True: 8, Index: 714)...
#   Success! Adv label: 3, L2: 729.98, Queries: 77
# Attacking sample 61/100 (True: 8, Index: 721)...
#   Success! Adv label: 3, L2: 496.07, Queries: 49
# Attacking sample 62/100 (True: 8, Index: 730)...
#   Success! Adv label: 2, L2: 629.03, Queries: 59
# Attacking sample 63/100 (True: 8, Index: 731)...
#   Failed! Adv label: 8, L2: 1033.82, Queries: 201
# Attacking sample 64/100 (True: 8, Index: 738)...
#   Success! Adv label: 3, L2: 768.51, Queries: 89
# Attacking sample 65/100 (True: 8, Index: 791)...
#   Success! Adv label: 5, L2: 808.49, Queries: 85
# Attacking sample 66/100 (True: 8, Index: 832)...
#   Success! Adv label: 6, L2: 619.31, Queries: 61
# Attacking sample 67/100 (True: 8, Index: 838)...
#   Success! Adv label: 5, L2: 616.61, Queries: 65
# Attacking sample 68/100 (True: 8, Index: 860)...
#   Success! Adv label: 3, L2: 750.52, Queries: 83
# Attacking sample 69/100 (True: 8, Index: 864)...
#   Success! Adv label: 3, L2: 884.27, Queries: 103
# Attacking sample 70/100 (True: 8, Index: 889)...
#   Success! Adv label: 3, L2: 657.98, Queries: 71
# Attacking sample 71/100 (True: 8, Index: 905)...
#   Success! Adv label: 9, L2: 754.18, Queries: 83
# Attacking sample 73/100 (True: 8, Index: 919)...
#   Success! Adv label: 3, L2: 565.41, Queries: 57
# Attacking sample 74/100 (True: 8, Index: 923)...
#   Success! Adv label: 3, L2: 693.36, Queries: 73
# Attacking sample 75/100 (True: 8, Index: 926)...
#   Success! Adv label: 5, L2: 725.63, Queries: 73
# Attacking sample 76/100 (True: 8, Index: 933)...
#   Success! Adv label: 3, L2: 633.92, Queries: 67
# Attacking sample 78/100 (True: 8, Index: 971)...
#   Success! Adv label: 3, L2: 778.69, Queries: 81
# Attacking sample 79/100 (True: 8, Index: 1014)...
#   Success! Adv label: 3, L2: 577.41, Queries: 61
# Attacking sample 80/100 (True: 8, Index: 1034)...
#   Success! Adv label: 6, L2: 845.70, Queries: 93
# Attacking sample 81/100 (True: 8, Index: 1053)...
#   Success! Adv label: 6, L2: 643.55, Queries: 65
# Attacking sample 82/100 (True: 8, Index: 1057)...
#   Success! Adv label: 6, L2: 502.16, Queries: 43
# Attacking sample 83/100 (True: 8, Index: 1061)...
#   Failed! Adv label: 8, L2: 868.05, Queries: 201
# Attacking sample 84/100 (True: 8, Index: 1062)...
#   Success! Adv label: 3, L2: 622.12, Queries: 67
# Attacking sample 85/100 (True: 8, Index: 1063)...
#   Success! Adv label: 3, L2: 625.61, Queries: 63
# Attacking sample 86/100 (True: 8, Index: 1078)...
#   Success! Adv label: 9, L2: 357.51, Queries: 31
# Attacking sample 87/100 (True: 8, Index: 1088)...
#   Success! Adv label: 2, L2: 785.78, Queries: 85
# Attacking sample 88/100 (True: 8, Index: 1100)...
#   Success! Adv label: 4, L2: 1068.27, Queries: 151
# Attacking sample 89/100 (True: 8, Index: 1106)...
#   Failed! Adv label: 8, L2: 1035.34, Queries: 201
# Attacking sample 90/100 (True: 8, Index: 1120)...
#   Success! Adv label: 3, L2: 548.28, Queries: 57
# Attacking sample 91/100 (True: 8, Index: 1132)...
#   Success! Adv label: 2, L2: 709.05, Queries: 73
# Attacking sample 92/100 (True: 8, Index: 1134)...
#   Failed! Adv label: 8, L2: 1113.02, Queries: 201
# Attacking sample 93/100 (True: 8, Index: 1140)...
#   Success! Adv label: 5, L2: 333.82, Queries: 33
# Attacking sample 94/100 (True: 8, Index: 1150)...
#   Success! Adv label: 9, L2: 605.54, Queries: 59
# Attacking sample 95/100 (True: 8, Index: 1165)...
#   Success! Adv label: 3, L2: 758.89, Queries: 77
# Attacking sample 96/100 (True: 8, Index: 1179)...
#   Success! Adv label: 9, L2: 641.63, Queries: 65
# Attacking sample 97/100 (True: 8, Index: 1182)...
#   Success! Adv label: 9, L2: 548.24, Queries: 53
# Attacking sample 98/100 (True: 8, Index: 1186)...
#   Success! Adv label: 2, L2: 869.47, Queries: 87
# Attacking sample 99/100 (True: 8, Index: 1189)...
#   Success! Adv label: 3, L2: 280.46, Queries: 29
# Attacking sample 100/100 (True: 8, Index: 1207)...
#   Success! Adv label: 9, L2: 741.46, Queries: 69
# Attacking sample 1/100 (True: 9, Index: 6)...
#   Success! Adv label: 7, L2: 380.71, Queries: 37
# Attacking sample 2/100 (True: 9, Index: 38)...
#   Success! Adv label: 7, L2: 72.28, Queries: 7
# Attacking sample 3/100 (True: 9, Index: 55)...
#   Success! Adv label: 0, L2: 170.09, Queries: 17
# Attacking sample 4/100 (True: 9, Index: 56)...
#   Success! Adv label: 4, L2: 498.24, Queries: 47
# Attacking sample 5/100 (True: 9, Index: 91)...
#   Success! Adv label: 3, L2: 324.18, Queries: 29
# Attacking sample 6/100 (True: 9, Index: 99)...
#   Success! Adv label: 7, L2: 467.04, Queries: 47
# Attacking sample 7/100 (True: 9, Index: 101)...
#   Success! Adv label: 5, L2: 841.58, Queries: 85
# Attacking sample 8/100 (True: 9, Index: 114)...
#   Success! Adv label: 8, L2: 738.39, Queries: 67
# Attacking sample 9/100 (True: 9, Index: 133)...
#   Success! Adv label: 8, L2: 690.62, Queries: 63
# Attacking sample 10/100 (True: 9, Index: 171)...
#   Success! Adv label: 8, L2: 127.12, Queries: 11
# Attacking sample 11/100 (True: 9, Index: 179)...
#   Success! Adv label: 7, L2: 688.75, Queries: 77
# Attacking sample 12/100 (True: 9, Index: 195)...
#   Success! Adv label: 1, L2: 252.89, Queries: 23
# Attacking sample 13/100 (True: 9, Index: 214)...
#   Success! Adv label: 4, L2: 555.08, Queries: 59
# Attacking sample 14/100 (True: 9, Index: 218)...
#   Success! Adv label: 4, L2: 410.54, Queries: 41
# Attacking sample 15/100 (True: 9, Index: 222)...
#   Success! Adv label: 8, L2: 420.05, Queries: 41
# Attacking sample 16/100 (True: 9, Index: 224)...
#   Success! Adv label: 6, L2: 608.68, Queries: 59
# Attacking sample 17/100 (True: 9, Index: 238)...
#   Success! Adv label: 4, L2: 499.90, Queries: 45
# Attacking sample 18/100 (True: 9, Index: 243)...
#   Success! Adv label: 8, L2: 745.86, Queries: 69
# Attacking sample 19/100 (True: 9, Index: 245)...
#   Success! Adv label: 4, L2: 580.81, Queries: 61
# Attacking sample 20/100 (True: 9, Index: 246)...
#   Success! Adv label: 8, L2: 691.00, Queries: 59
# Attacking sample 21/100 (True: 9, Index: 251)...
#   Success! Adv label: 7, L2: 297.87, Queries: 29
# Attacking sample 22/100 (True: 9, Index: 303)...
#   Success! Adv label: 4, L2: 310.19, Queries: 31
# Attacking sample 23/100 (True: 9, Index: 305)...
#   Success! Adv label: 8, L2: 273.11, Queries: 25
# Attacking sample 24/100 (True: 9, Index: 307)...
#   Success! Adv label: 5, L2: 711.70, Queries: 77
# Attacking sample 25/100 (True: 9, Index: 315)...
#   Success! Adv label: 8, L2: 742.64, Queries: 73
# Attacking sample 26/100 (True: 9, Index: 354)...
#   Success! Adv label: 4, L2: 607.72, Queries: 63
# Attacking sample 27/100 (True: 9, Index: 364)...
#   Success! Adv label: 8, L2: 661.74, Queries: 63
# Attacking sample 28/100 (True: 9, Index: 389)...
#   Success! Adv label: 4, L2: 379.54, Queries: 37
# Attacking sample 29/100 (True: 9, Index: 407)...
#   Success! Adv label: 8, L2: 289.95, Queries: 25
# Attacking sample 30/100 (True: 9, Index: 411)...
#   Success! Adv label: 4, L2: 230.30, Queries: 21
# Attacking sample 31/100 (True: 9, Index: 417)...
#   Success! Adv label: 7, L2: 454.70, Queries: 55
# Attacking sample 32/100 (True: 9, Index: 421)...
#   Success! Adv label: 4, L2: 469.57, Queries: 43
# Attacking sample 33/100 (True: 9, Index: 438)...
#   Success! Adv label: 4, L2: 507.98, Queries: 49
# Attacking sample 34/100 (True: 9, Index: 443)...
#   Success! Adv label: 8, L2: 702.51, Queries: 69
# Attacking sample 35/100 (True: 9, Index: 444)...
#   Success! Adv label: 4, L2: 356.13, Queries: 37
# Attacking sample 36/100 (True: 9, Index: 446)...
#   Success! Adv label: 7, L2: 655.49, Queries: 73
# Attacking sample 37/100 (True: 9, Index: 455)...
#   Success! Adv label: 7, L2: 345.81, Queries: 35
# Attacking sample 38/100 (True: 9, Index: 469)...
#   Success! Adv label: 4, L2: 972.74, Queries: 111
# Attacking sample 39/100 (True: 9, Index: 472)...
#   Success! Adv label: 3, L2: 849.64, Queries: 81
# Attacking sample 40/100 (True: 9, Index: 473)...
#   Success! Adv label: 4, L2: 796.72, Queries: 79
# Attacking sample 41/100 (True: 9, Index: 482)...
#   Success! Adv label: 4, L2: 505.44, Queries: 45
# Attacking sample 42/100 (True: 9, Index: 490)...
#   Success! Adv label: 8, L2: 880.34, Queries: 85
# Attacking sample 43/100 (True: 9, Index: 496)...
#   Success! Adv label: 4, L2: 524.45, Queries: 53
# Attacking sample 44/100 (True: 9, Index: 507)...
#   Success! Adv label: 8, L2: 443.43, Queries: 39
# Attacking sample 45/100 (True: 9, Index: 508)...
#   Success! Adv label: 7, L2: 506.17, Queries: 49
# Attacking sample 46/100 (True: 9, Index: 514)...
#   Success! Adv label: 4, L2: 238.29, Queries: 21
# Attacking sample 47/100 (True: 9, Index: 522)...
#   Success! Adv label: 4, L2: 76.11, Queries: 7
# Attacking sample 48/100 (True: 9, Index: 535)...
#   Success! Adv label: 4, L2: 519.92, Queries: 55
# Attacking sample 49/100 (True: 9, Index: 542)...
#   Success! Adv label: 8, L2: 471.47, Queries: 47
# Attacking sample 50/100 (True: 9, Index: 553)...
#   Success! Adv label: 4, L2: 766.17, Queries: 81
# Attacking sample 51/100 (True: 9, Index: 554)...
#   Success! Adv label: 8, L2: 853.47, Queries: 81
# Attacking sample 52/100 (True: 9, Index: 565)...
#   Success! Adv label: 0, L2: 477.69, Queries: 47
# Attacking sample 53/100 (True: 9, Index: 569)...
#   Success! Adv label: 4, L2: 523.30, Queries: 55
# Attacking sample 54/100 (True: 9, Index: 572)...
#   Success! Adv label: 5, L2: 418.87, Queries: 41
# Attacking sample 55/100 (True: 9, Index: 574)...
#   Success! Adv label: 8, L2: 423.18, Queries: 41
# Attacking sample 56/100 (True: 9, Index: 601)...
#   Success! Adv label: 8, L2: 396.62, Queries: 35
# Attacking sample 57/100 (True: 9, Index: 634)...
#   Success! Adv label: 5, L2: 507.87, Queries: 47
# Attacking sample 58/100 (True: 9, Index: 635)...
#   Success! Adv label: 4, L2: 704.38, Queries: 79
# Attacking sample 59/100 (True: 9, Index: 637)...
#   Success! Adv label: 4, L2: 643.06, Queries: 63
# Attacking sample 60/100 (True: 9, Index: 640)...
#   Success! Adv label: 4, L2: 599.03, Queries: 59
# Attacking sample 61/100 (True: 9, Index: 653)...
#   Success! Adv label: 8, L2: 634.96, Queries: 57
# Attacking sample 62/100 (True: 9, Index: 654)...
#   Success! Adv label: 4, L2: 575.42, Queries: 57
# Attacking sample 63/100 (True: 9, Index: 656)...
#   Success! Adv label: 4, L2: 645.27, Queries: 63
# Attacking sample 64/100 (True: 9, Index: 666)...
#   Success! Adv label: 4, L2: 461.92, Queries: 49
# Attacking sample 65/100 (True: 9, Index: 685)...
#   Success! Adv label: 7, L2: 703.84, Queries: 77
# Attacking sample 66/100 (True: 9, Index: 711)...
#   Success! Adv label: 4, L2: 253.86, Queries: 23
# Attacking sample 67/100 (True: 9, Index: 729)...
#   Success! Adv label: 8, L2: 526.52, Queries: 49
# Attacking sample 68/100 (True: 9, Index: 739)...
#   Success! Adv label: 4, L2: 485.37, Queries: 47
# Attacking sample 69/100 (True: 9, Index: 747)...
#   Success! Adv label: 8, L2: 401.18, Queries: 37
# Attacking sample 70/100 (True: 9, Index: 767)...
#   Success! Adv label: 8, L2: 503.68, Queries: 47
# Attacking sample 71/100 (True: 9, Index: 783)...
#   Success! Adv label: 5, L2: 628.81, Queries: 65
# Attacking sample 72/100 (True: 9, Index: 787)...
#   Success! Adv label: 8, L2: 636.46, Queries: 55
# Attacking sample 73/100 (True: 9, Index: 796)...
#   Success! Adv label: 7, L2: 462.32, Queries: 45
# Attacking sample 74/100 (True: 9, Index: 804)...
#   Success! Adv label: 7, L2: 686.16, Queries: 79
# Attacking sample 75/100 (True: 9, Index: 818)...
#   Success! Adv label: 4, L2: 671.84, Queries: 73
# Attacking sample 76/100 (True: 9, Index: 825)...
#   Success! Adv label: 8, L2: 380.81, Queries: 35
# Attacking sample 77/100 (True: 9, Index: 826)...
#   Success! Adv label: 1, L2: 197.97, Queries: 19
# Attacking sample 78/100 (True: 9, Index: 831)...
#   Success! Adv label: 4, L2: 557.31, Queries: 51
# Attacking sample 79/100 (True: 9, Index: 880)...
#   Success! Adv label: 5, L2: 637.04, Queries: 59
# Attacking sample 80/100 (True: 9, Index: 884)...
#   Success! Adv label: 4, L2: 558.73, Queries: 53
# Attacking sample 81/100 (True: 9, Index: 891)...
#   Success! Adv label: 4, L2: 131.07, Queries: 13
# Attacking sample 82/100 (True: 9, Index: 893)...
#   Success! Adv label: 2, L2: 756.63, Queries: 85
# Attacking sample 83/100 (True: 9, Index: 899)...
#   Success! Adv label: 4, L2: 504.27, Queries: 51
# Attacking sample 84/100 (True: 9, Index: 912)...
#   Success! Adv label: 5, L2: 645.91, Queries: 59
# Attacking sample 85/100 (True: 9, Index: 920)...
#   Success! Adv label: 4, L2: 662.20, Queries: 63
# Attacking sample 86/100 (True: 9, Index: 925)...
#   Success! Adv label: 8, L2: 385.12, Queries: 33
# Attacking sample 87/100 (True: 9, Index: 940)...
#   Success! Adv label: 4, L2: 378.44, Queries: 41
# Attacking sample 88/100 (True: 9, Index: 958)...
#   Success! Adv label: 4, L2: 553.82, Queries: 51
# Attacking sample 89/100 (True: 9, Index: 969)...
#   Success! Adv label: 8, L2: 420.13, Queries: 37
# Attacking sample 90/100 (True: 9, Index: 978)...
#   Success! Adv label: 4, L2: 539.54, Queries: 55
# Attacking sample 91/100 (True: 9, Index: 979)...
#   Success! Adv label: 4, L2: 450.22, Queries: 41
# Attacking sample 92/100 (True: 9, Index: 980)...
#   Success! Adv label: 8, L2: 357.83, Queries: 35
# Attacking sample 93/100 (True: 9, Index: 991)...
#   Success! Adv label: 7, L2: 549.02, Queries: 59
# Attacking sample 94/100 (True: 9, Index: 997)...
#   Success! Adv label: 4, L2: 263.58, Queries: 27
# Attacking sample 95/100 (True: 9, Index: 1006)...
#   Success! Adv label: 7, L2: 597.89, Queries: 65
# Attacking sample 96/100 (True: 9, Index: 1011)...
#   Success! Adv label: 4, L2: 826.02, Queries: 85
# Attacking sample 97/100 (True: 9, Index: 1020)...
#   Success! Adv label: 8, L2: 522.92, Queries: 51
# Attacking sample 98/100 (True: 9, Index: 1023)...
#   Success! Adv label: 4, L2: 820.84, Queries: 87
# Attacking sample 99/100 (True: 9, Index: 1042)...
#   Success! Adv label: 4, L2: 384.22, Queries: 33
# Attacking sample 100/100 (True: 9, Index: 1046)...
#   Success! Adv label: 4, L2: 391.74, Queries: 39
# Time taken to generate adversarial samples: 141.4975 seconds
#
# Stats saved to: adversarial_8bit_K130_test_images\per_sample_stats.csv
#
# ===== Attack Summary =====
# Total trials: 986
# Misclassified before attack: 14
# Success rate: 939/986 (95.2%)
# Mean L2 (successful): 593.14
# Mean queries (successful): 58.42
#
# Showing successful adversarial examples...

# %% [markdown]
# ### Untargeted Attack on test set; k=140

# %%
import os
import warnings
import numpy as np
import torch
import joblib
import pandas as pd
from PIL import Image
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import torch.nn.functional as F
import time


# Set seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# ─────────────── PATHS ────────────────────────────────────────────────────
LENET_MODEL_PATH = os.path.normpath("Models and Data splits/lenet.pt")  # TorchScript model
DATA_PKL = os.path.normpath("Models and Data splits/data_[SCALED] Train_Test_Splits.pkl")
RF_ALL_CLASSES_PATH = os.path.normpath("Models and Data splits/random_forest.pkl")
OUT_DIR = "adversarial_8bit_K140_test_images"
os.makedirs(OUT_DIR, exist_ok=True)

if not os.path.exists(RF_ALL_CLASSES_PATH):
    raise FileNotFoundError(f"Random Forest model not found at {RF_ALL_CLASSES_PATH}")

# ─────────── HYPER-PARAMETERS ─────────────────────────────────────────────
EPSILON_STEP = 0.01
ITERATIONS = 100
TOTAL_EPSILON = 0.5
TOP_K_FEATURES = 140
SAMPLES_PER_DIGIT = 100
MAX_L2 = 10000

def plot_adversarial_example(original_img, adv_img, true_label, adv_label, l2_mag, sample_idx, queries, title_suffix=""):
    if original_img.size == 784:
        original_img = original_img.reshape(28, 28)
    if adv_img.size == 784:
        adv_img = adv_img.reshape(28, 28)
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(original_img, cmap='gray')
    axes[0].set_title(f"Original\nTrue: {true_label}")
    axes[0].axis('off')
    axes[1].imshow(adv_img, cmap='gray')
    axes[1].set_title(f"Adversarial\nPred: {adv_label}")
    axes[1].axis('off')
    fig.suptitle(f"Sample {sample_idx} | L2: {l2_mag:.2f} | Queries: {queries} {title_suffix}")
    plt.show()
    plt.close(fig)  # <-- added here


# ─────────── Load Data ─────────────────────────────────────────────────────
try:
    data = joblib.load(DATA_PKL)
    _, X_samples , _, y_samples = data
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PKL}. Please check the path.")
    exit()

if X_samples.max() > 1.0:
    X_samples = X_samples.astype(np.float32) / 255.0
    warnings.warn("Data appeared in [0,255]; normalized to [0,1].")

# ─────────── Load TorchScripted LeNet ──────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
try:
    model = torch.jit.load(LENET_MODEL_PATH, map_location=device)
    model.eval()
    print(f"LeNet TorchScript model loaded from: {LENET_MODEL_PATH}")
except Exception as e:
    print(f"Error loading TorchScript LeNet model: {e}")
    exit()

def to_model(x01_batch):
    if x01_batch.ndim == 2 and x01_batch.shape == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)
    elif x01_batch.ndim == 3 and x01_batch.shape[1:] == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(1)
    elif x01_batch.ndim == 4 and x01_batch.shape[1] == 1:
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device)
    elif x01_batch.ndim == 1 and x01_batch.size == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(1, 1, 28, 28), dtype=torch.float32, device=device)
    elif x01_batch.ndim == 2 and x01_batch.shape[1] == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(x01_batch.shape[0], 1, 28, 28), dtype=torch.float32, device=device)
    else:
        raise ValueError(f"Unsupported input shape for to_model: {x01_batch.shape}")
    return tensor_batch


def model_query(x_tensor_batch):
    with torch.no_grad():
        return model(x_tensor_batch)

# ─────────── Load Random Forest Model ──────────────────────────────────────
rf_all_classes = None
top_feature_indices = None
print("Loading Random Forest Classifier for all classes...")
try:
    rf_all_classes = joblib.load(RF_ALL_CLASSES_PATH)
    feature_importances = rf_all_classes.feature_importances_
    #top_feature_indices = np.argsort(feature_importances)[:TOP_K_FEATURES]
    
    top_feature_indices = np.argsort(-feature_importances)[:TOP_K_FEATURES]
    print(f"Random Forest loaded. Using top {TOP_K_FEATURES} features.")
except Exception as e:
    print(f"Error loading Random Forest: {e}")
    top_feature_indices = np.arange(28 * 28)

# ─────────── I-FGSM Attack ─────────────────────────────────────────────────
def ifgsm_attack(original_image_np, true_label, model_target, epsilon_step, iterations,
                 total_epsilon_budget, features_to_perturb, query_count_tracker):
    if original_image_np.ndim == 1 and original_image_np.size == 784:
        original_image_np = original_image_np.reshape(28, 28)

    perturbed_image_np = original_image_np.copy()
    final_pred_label = true_label

    for i in range(iterations):
        image_tensor = to_model(perturbed_image_np)
        image_tensor.requires_grad = True
        output = model_target(image_tensor)
        query_count_tracker[0] += 1
        loss = F.cross_entropy(output, torch.tensor([true_label], device=device))
        model_target.zero_grad()
        loss.backward()
        data_grad_sign = torch.sign(image_tensor.grad.data).cpu().numpy()

        gradient_mask = np.zeros_like(data_grad_sign, dtype=np.float32)
        h, w = perturbed_image_np.shape
        rows, cols = np.unravel_index(features_to_perturb, (h, w))
        gradient_mask[0, 0, rows, cols] = data_grad_sign[0, 0, rows, cols]
        gradient_mask_for_update = gradient_mask.reshape(perturbed_image_np.shape)

        perturbed_image_np += epsilon_step * gradient_mask_for_update
        perturbation = perturbed_image_np - original_image_np
        perturbation = np.clip(perturbation, -total_epsilon_budget, total_epsilon_budget)
        perturbed_image_np = original_image_np + perturbation
        perturbed_image_np = np.clip(perturbed_image_np, 0, 1)

        # Discretize and check prediction on discretized image
        adv_uint8_temp = np.round(perturbed_image_np * 255).astype(np.uint8)
        adv_float_temp = adv_uint8_temp.astype(np.float32) / 255.0
        with torch.no_grad():
            output_temp = model_target(to_model(adv_float_temp))
            pred_temp = output_temp.argmax(dim=1).item()
            query_count_tracker[0] += 1

        if pred_temp != true_label:
            final_pred_label = pred_temp
            break

    # Final adversarial image (discretized)
    adv_uint8 = np.round(perturbed_image_np * 255).astype(np.uint8)
    adv_float = adv_uint8.astype(np.float32) / 255.0
    with torch.no_grad():
        output_final = model_target(to_model(adv_float))
        final_pred_label = output_final.argmax(dim=1).item()

    l2_norm = np.linalg.norm(adv_uint8.astype(np.float32) - (original_image_np * 255).astype(np.float32))
    success = (final_pred_label != true_label) and (l2_norm <= MAX_L2)

    return adv_uint8, final_pred_label, l2_norm, success


# ─────────── Attack Execution ──────────────────────────────────────────────
print(f"\n===== Starting Adversarial Attack =====")
total_trials, succ_total, misclassified = 0, 0, 0
records = []


start_time = time.time()


for digit in range(10):
    idxs = np.where(y_samples == digit)[0][:SAMPLES_PER_DIGIT]
    for rank, idx in enumerate(idxs, 1):
        x0 = X_samples[idx].copy()
        y0 = int(y_samples[idx])
        query_count_tracker = [0]
        pred0 = model_query(to_model(x0)).argmax(dim=1).item()
        query_count_tracker[0] += 1

        if pred0 != y0:
            misclassified += 1
            records.append({
                'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
                'adv_label': None, 'success': False, 'queries': query_count_tracker[0],
                'l2_mag': np.nan, 'note': 'Already misclassified'
            })
            continue

        total_trials += 1
        print(f"Attacking sample {rank}/{SAMPLES_PER_DIGIT} (True: {y0}, Index: {idx})...")
        adv_img_uint8, adv_label, l2_mag, success = ifgsm_attack(
            x0, y0, model, EPSILON_STEP, ITERATIONS, TOTAL_EPSILON,
            top_feature_indices, query_count_tracker
        )

        if success:
            succ_total += 1
            fname = f"true{y0}_adv{adv_label}_mag{l2_mag:.1f}_sample{idx}.png"
            Image.fromarray(adv_img_uint8, mode="L").save(os.path.join(OUT_DIR, fname))

        records.append({
            'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
            'adv_label': adv_label, 'success': success, 'queries': query_count_tracker[0],
            'l2_mag': l2_mag if success else np.nan, 'note': 'I-FGSM' + (' successful' if success else ' failed')
        })

        print(f"  {'Success' if success else 'Failed'}! Adv label: {adv_label}, L2: {l2_mag:.2f}, Queries: {query_count_tracker[0]}")


end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to generate adversarial samples: {elapsed_time:.4f} seconds")


# ─────────── Save Results ──────────────────────────────────────────────────
df = pd.DataFrame(records)
csv_path = os.path.join(OUT_DIR, "per_sample_stats.csv")
df.to_csv(csv_path, index=False)
print(f"\nStats saved to: {csv_path}")

# ─────────── Summary ───────────────────────────────────────────────────────
print(f"\n===== Attack Summary =====")
print(f"Total trials: {total_trials}")
print(f"Misclassified before attack: {misclassified}")
if total_trials > 0:
    success_rate = succ_total / total_trials * 100
    print(f"Success rate: {succ_total}/{total_trials} ({success_rate:.1f}%)")
    if succ_total > 0:
        print(f"Mean L2 (successful): {df[df['success']]['l2_mag'].mean():.2f}")
        print(f"Mean queries (successful): {df[df['success']]['queries'].mean():.2f}")

# ─────────── Display Examples ──────────────────────────────────────────────
success_df = df[df['success']]
if not success_df.empty:
    print("\nShowing successful adversarial examples...")
    show_ids = success_df.sample(min(3, len(success_df))).index.tolist()
    for record_idx in show_ids:
        r = df.loc[record_idx]
        fname_prefix = f"true{r['true_label']}_adv{r['adv_label']}_mag{r['l2_mag']:.1f}_sample{r['sample_idx']}"
        match_files = [f for f in os.listdir(OUT_DIR) if f.startswith(fname_prefix)]
        if match_files:
            adv_img_path = os.path.join(OUT_DIR, match_files[0])
            plot_adversarial_example(X_samples[r['sample_idx']], np.array(Image.open(adv_img_path)),
                                     r['true_label'], r['adv_label'], r['l2_mag'],
                                     r['sample_idx'], r['queries'], "(I-FGSM)")
else:
    print("No successful attacks to display. Showing original samples instead.")
    for i in range(min(3, len(df))):
        r = df.iloc[i]
        plot_adversarial_example(X_samples[r['sample_idx']], X_samples[r['sample_idx']],
                                 r['true_label'], r['initial_pred'], 0.0,
                                 r['sample_idx'], r['queries'], "(Original)")
# Out:
# LeNet TorchScript model loaded from: Models and Data splits\lenet.pt
# Loading Random Forest Classifier for all classes...
# Random Forest loaded. Using top 140 features.
#
# ===== Starting Adversarial Attack =====
# Attacking sample 1/100 (True: 0, Index: 29)...
#   Success! Adv label: 6, L2: 951.61, Queries: 97
# Attacking sample 2/100 (True: 0, Index: 40)...
#   Failed! Adv label: 0, L2: 1086.48, Queries: 201
# Attacking sample 3/100 (True: 0, Index: 44)...
#   Success! Adv label: 5, L2: 655.82, Queries: 63
# Attacking sample 4/100 (True: 0, Index: 59)...
#   Success! Adv label: 6, L2: 720.43, Queries: 69
# Attacking sample 5/100 (True: 0, Index: 64)...
#   Failed! Adv label: 0, L2: 1122.51, Queries: 201
# Attacking sample 6/100 (True: 0, Index: 75)...
#   Success! Adv label: 8, L2: 706.43, Queries: 71
# Attacking sample 7/100 (True: 0, Index: 80)...
#   Success! Adv label: 9, L2: 697.32, Queries: 71
# Attacking sample 8/100 (True: 0, Index: 97)...
#   Success! Adv label: 6, L2: 874.68, Queries: 93
# Attacking sample 9/100 (True: 0, Index: 115)...
#   Success! Adv label: 6, L2: 845.07, Queries: 81
# Attacking sample 10/100 (True: 0, Index: 141)...
#   Success! Adv label: 7, L2: 215.92, Queries: 21
# Attacking sample 11/100 (True: 0, Index: 146)...
#   Success! Adv label: 9, L2: 716.03, Queries: 75
# Attacking sample 12/100 (True: 0, Index: 156)...
#   Failed! Adv label: 0, L2: 967.36, Queries: 201
# Attacking sample 13/100 (True: 0, Index: 173)...
#   Success! Adv label: 6, L2: 671.93, Queries: 77
# Attacking sample 14/100 (True: 0, Index: 175)...
#   Success! Adv label: 8, L2: 500.12, Queries: 47
# Attacking sample 15/100 (True: 0, Index: 193)...
#   Success! Adv label: 9, L2: 898.87, Queries: 137
# Attacking sample 16/100 (True: 0, Index: 200)...
#   Success! Adv label: 9, L2: 695.73, Queries: 75
# Attacking sample 17/100 (True: 0, Index: 205)...
#   Success! Adv label: 9, L2: 813.27, Queries: 85
# Attacking sample 18/100 (True: 0, Index: 210)...
#   Success! Adv label: 8, L2: 760.57, Queries: 77
# Attacking sample 19/100 (True: 0, Index: 221)...
#   Success! Adv label: 3, L2: 864.07, Queries: 81
# Attacking sample 20/100 (True: 0, Index: 229)...
#   Failed! Adv label: 0, L2: 911.47, Queries: 201
# Attacking sample 21/100 (True: 0, Index: 249)...
#   Success! Adv label: 5, L2: 857.21, Queries: 139
# Attacking sample 22/100 (True: 0, Index: 258)...
#   Success! Adv label: 8, L2: 857.82, Queries: 83
# Attacking sample 23/100 (True: 0, Index: 275)...
#   Success! Adv label: 8, L2: 1100.87, Queries: 185
# Attacking sample 24/100 (True: 0, Index: 292)...
#   Failed! Adv label: 0, L2: 887.57, Queries: 201
# Attacking sample 25/100 (True: 0, Index: 296)...
#   Success! Adv label: 9, L2: 691.08, Queries: 69
# Attacking sample 26/100 (True: 0, Index: 301)...
#   Success! Adv label: 9, L2: 660.78, Queries: 63
# Attacking sample 27/100 (True: 0, Index: 314)...
#   Success! Adv label: 9, L2: 697.37, Queries: 63
# Attacking sample 28/100 (True: 0, Index: 325)...
#   Success! Adv label: 9, L2: 989.74, Queries: 135
# Attacking sample 29/100 (True: 0, Index: 333)...
#   Success! Adv label: 9, L2: 856.81, Queries: 93
# Attacking sample 30/100 (True: 0, Index: 345)...
#   Success! Adv label: 6, L2: 658.84, Queries: 61
# Attacking sample 31/100 (True: 0, Index: 349)...
#   Success! Adv label: 9, L2: 657.73, Queries: 63
# Attacking sample 32/100 (True: 0, Index: 360)...
#   Failed! Adv label: 0, L2: 1112.50, Queries: 201
# Attacking sample 33/100 (True: 0, Index: 365)...
#   Success! Adv label: 9, L2: 960.23, Queries: 121
# Attacking sample 34/100 (True: 0, Index: 366)...
#   Success! Adv label: 8, L2: 829.03, Queries: 83
# Attacking sample 35/100 (True: 0, Index: 379)...
#   Success! Adv label: 8, L2: 953.00, Queries: 93
# Attacking sample 36/100 (True: 0, Index: 385)...
#   Failed! Adv label: 0, L2: 953.67, Queries: 201
# Attacking sample 37/100 (True: 0, Index: 397)...
#   Failed! Adv label: 0, L2: 937.45, Queries: 201
# Attacking sample 38/100 (True: 0, Index: 400)...
#   Failed! Adv label: 0, L2: 1125.56, Queries: 201
# Attacking sample 39/100 (True: 0, Index: 405)...
#   Success! Adv label: 2, L2: 790.40, Queries: 73
# Attacking sample 40/100 (True: 0, Index: 410)...
#   Success! Adv label: 9, L2: 817.29, Queries: 83
# Attacking sample 41/100 (True: 0, Index: 420)...
#   Success! Adv label: 2, L2: 869.58, Queries: 99
# Attacking sample 42/100 (True: 0, Index: 424)...
#   Failed! Adv label: 0, L2: 1017.97, Queries: 201
# Attacking sample 43/100 (True: 0, Index: 447)...
#   Success! Adv label: 2, L2: 706.41, Queries: 71
# Attacking sample 44/100 (True: 0, Index: 453)...
#   Success! Adv label: 2, L2: 881.28, Queries: 89
# Attacking sample 45/100 (True: 0, Index: 457)...
#   Success! Adv label: 6, L2: 1001.97, Queries: 97
# Attacking sample 46/100 (True: 0, Index: 466)...
#   Success! Adv label: 2, L2: 822.24, Queries: 85
# Attacking sample 47/100 (True: 0, Index: 475)...
#   Success! Adv label: 9, L2: 245.35, Queries: 23
# Attacking sample 48/100 (True: 0, Index: 483)...
#   Success! Adv label: 2, L2: 1037.87, Queries: 145
# Attacking sample 49/100 (True: 0, Index: 484)...
#   Success! Adv label: 8, L2: 499.35, Queries: 41
# Attacking sample 50/100 (True: 0, Index: 486)...
#   Failed! Adv label: 0, L2: 1000.51, Queries: 201
# Attacking sample 51/100 (True: 0, Index: 487)...
#   Success! Adv label: 6, L2: 681.27, Queries: 65
# Attacking sample 52/100 (True: 0, Index: 489)...
#   Success! Adv label: 9, L2: 725.05, Queries: 73
# Attacking sample 53/100 (True: 0, Index: 492)...
#   Success! Adv label: 9, L2: 738.63, Queries: 71
# Attacking sample 54/100 (True: 0, Index: 506)...
#   Success! Adv label: 2, L2: 978.32, Queries: 91
# Attacking sample 55/100 (True: 0, Index: 513)...
#   Failed! Adv label: 0, L2: 1057.04, Queries: 201
# Attacking sample 56/100 (True: 0, Index: 518)...
#   Success! Adv label: 5, L2: 1018.89, Queries: 153
# Attacking sample 57/100 (True: 0, Index: 521)...
#   Failed! Adv label: 0, L2: 1079.62, Queries: 201
# Attacking sample 58/100 (True: 0, Index: 527)...
#   Success! Adv label: 2, L2: 754.75, Queries: 75
# Attacking sample 59/100 (True: 0, Index: 529)...
#   Success! Adv label: 5, L2: 860.17, Queries: 145
# Attacking sample 60/100 (True: 0, Index: 531)...
#   Failed! Adv label: 0, L2: 1053.98, Queries: 201
# Attacking sample 61/100 (True: 0, Index: 546)...
#   Success! Adv label: 9, L2: 658.03, Queries: 69
# Attacking sample 62/100 (True: 0, Index: 551)...
#   Success! Adv label: 6, L2: 399.78, Queries: 33
# Attacking sample 63/100 (True: 0, Index: 555)...
#   Success! Adv label: 8, L2: 1027.39, Queries: 93
# Attacking sample 64/100 (True: 0, Index: 587)...
#   Success! Adv label: 2, L2: 891.78, Queries: 93
# Attacking sample 65/100 (True: 0, Index: 604)...
#   Success! Adv label: 8, L2: 702.17, Queries: 63
# Attacking sample 66/100 (True: 0, Index: 614)...
#   Success! Adv label: 8, L2: 852.19, Queries: 85
# Attacking sample 67/100 (True: 0, Index: 615)...
#   Success! Adv label: 9, L2: 447.90, Queries: 39
# Attacking sample 68/100 (True: 0, Index: 618)...
#   Success! Adv label: 6, L2: 334.03, Queries: 29
# Attacking sample 69/100 (True: 0, Index: 638)...
#   Success! Adv label: 8, L2: 434.53, Queries: 37
# Attacking sample 70/100 (True: 0, Index: 642)...
#   Success! Adv label: 9, L2: 900.37, Queries: 101
# Attacking sample 71/100 (True: 0, Index: 655)...
#   Success! Adv label: 6, L2: 819.16, Queries: 73
# Attacking sample 72/100 (True: 0, Index: 658)...
#   Success! Adv label: 6, L2: 721.25, Queries: 67
# Attacking sample 73/100 (True: 0, Index: 665)...
#   Success! Adv label: 2, L2: 692.42, Queries: 67
# Attacking sample 74/100 (True: 0, Index: 671)...
#   Success! Adv label: 6, L2: 762.58, Queries: 71
# Attacking sample 75/100 (True: 0, Index: 681)...
#   Success! Adv label: 9, L2: 936.17, Queries: 95
# Attacking sample 76/100 (True: 0, Index: 691)...
#   Success! Adv label: 2, L2: 781.49, Queries: 73
# Attacking sample 77/100 (True: 0, Index: 700)...
#   Success! Adv label: 5, L2: 587.06, Queries: 57
# Attacking sample 78/100 (True: 0, Index: 706)...
#   Failed! Adv label: 0, L2: 854.55, Queries: 201
# Attacking sample 79/100 (True: 0, Index: 712)...
#   Failed! Adv label: 0, L2: 1018.32, Queries: 201
# Attacking sample 80/100 (True: 0, Index: 713)...
#   Success! Adv label: 9, L2: 751.50, Queries: 71
# Attacking sample 81/100 (True: 0, Index: 736)...
#   Success! Adv label: 5, L2: 714.62, Queries: 79
# Attacking sample 82/100 (True: 0, Index: 742)...
#   Success! Adv label: 8, L2: 716.35, Queries: 73
# Attacking sample 83/100 (True: 0, Index: 744)...
#   Success! Adv label: 2, L2: 606.12, Queries: 59
# Attacking sample 84/100 (True: 0, Index: 760)...
#   Success! Adv label: 9, L2: 645.17, Queries: 65
# Attacking sample 85/100 (True: 0, Index: 772)...
#   Success! Adv label: 9, L2: 315.28, Queries: 27
# Attacking sample 86/100 (True: 0, Index: 781)...
#   Success! Adv label: 6, L2: 523.83, Queries: 47
# Attacking sample 87/100 (True: 0, Index: 809)...
#   Success! Adv label: 5, L2: 837.01, Queries: 99
# Attacking sample 88/100 (True: 0, Index: 813)...
#   Success! Adv label: 9, L2: 499.29, Queries: 49
# Attacking sample 89/100 (True: 0, Index: 820)...
#   Success! Adv label: 9, L2: 761.12, Queries: 81
# Attacking sample 90/100 (True: 0, Index: 823)...
#   Success! Adv label: 5, L2: 745.32, Queries: 83
# Attacking sample 91/100 (True: 0, Index: 844)...
#   Success! Adv label: 6, L2: 935.75, Queries: 131
# Attacking sample 92/100 (True: 0, Index: 848)...
#   Success! Adv label: 9, L2: 304.50, Queries: 27
# Attacking sample 93/100 (True: 0, Index: 861)...
#   Success! Adv label: 6, L2: 1006.08, Queries: 87
# Attacking sample 94/100 (True: 0, Index: 865)...
#   Failed! Adv label: 0, L2: 1270.85, Queries: 201
# Attacking sample 95/100 (True: 0, Index: 869)...
#   Success! Adv label: 6, L2: 1074.07, Queries: 119
# Attacking sample 96/100 (True: 0, Index: 876)...
#   Success! Adv label: 9, L2: 703.77, Queries: 65
# Attacking sample 97/100 (True: 0, Index: 885)...
#   Failed! Adv label: 0, L2: 1048.57, Queries: 201
# Attacking sample 98/100 (True: 0, Index: 906)...
#   Success! Adv label: 3, L2: 1014.90, Queries: 135
# Attacking sample 99/100 (True: 0, Index: 907)...
#   Success! Adv label: 9, L2: 978.27, Queries: 121
# Attacking sample 100/100 (True: 0, Index: 918)...
#   Failed! Adv label: 0, L2: 1054.65, Queries: 201
# Attacking sample 1/100 (True: 1, Index: 2)...
#   Success! Adv label: 7, L2: 334.22, Queries: 27
# Attacking sample 2/100 (True: 1, Index: 3)...
#   Success! Adv label: 7, L2: 411.92, Queries: 33
# Attacking sample 3/100 (True: 1, Index: 9)...
#   Success! Adv label: 2, L2: 350.87, Queries: 31
# Attacking sample 4/100 (True: 1, Index: 25)...
#   Success! Adv label: 4, L2: 384.68, Queries: 29
# Attacking sample 5/100 (True: 1, Index: 36)...
#   Success! Adv label: 2, L2: 310.46, Queries: 25
# Attacking sample 6/100 (True: 1, Index: 63)...
#   Success! Adv label: 8, L2: 314.19, Queries: 27
# Attacking sample 7/100 (True: 1, Index: 65)...
#   Success! Adv label: 8, L2: 372.36, Queries: 29
# Attacking sample 8/100 (True: 1, Index: 68)...
#   Success! Adv label: 4, L2: 395.11, Queries: 31
# Attacking sample 9/100 (True: 1, Index: 76)...
#   Success! Adv label: 8, L2: 244.27, Queries: 21
# Attacking sample 10/100 (True: 1, Index: 83)...
#   Success! Adv label: 4, L2: 399.88, Queries: 33
# Attacking sample 11/100 (True: 1, Index: 90)...
#   Success! Adv label: 9, L2: 29.83, Queries: 3
# Attacking sample 12/100 (True: 1, Index: 94)...
#   Success! Adv label: 8, L2: 233.83, Queries: 19
# Attacking sample 13/100 (True: 1, Index: 100)...
#   Success! Adv label: 8, L2: 283.73, Queries: 23
# Attacking sample 14/100 (True: 1, Index: 123)...
#   Success! Adv label: 8, L2: 229.84, Queries: 19
# Attacking sample 15/100 (True: 1, Index: 150)...
#   Success! Adv label: 8, L2: 379.43, Queries: 29
# Attacking sample 16/100 (True: 1, Index: 152)...
#   Success! Adv label: 9, L2: 374.14, Queries: 31
# Attacking sample 17/100 (True: 1, Index: 178)...
#   Success! Adv label: 4, L2: 375.05, Queries: 29
# Attacking sample 18/100 (True: 1, Index: 185)...
#   Success! Adv label: 8, L2: 410.11, Queries: 37
# Attacking sample 19/100 (True: 1, Index: 191)...
#   Success! Adv label: 4, L2: 426.11, Queries: 33
# Attacking sample 20/100 (True: 1, Index: 201)...
#   Success! Adv label: 8, L2: 341.81, Queries: 27
# Attacking sample 21/100 (True: 1, Index: 203)...
#   Success! Adv label: 8, L2: 299.23, Queries: 23
# Attacking sample 22/100 (True: 1, Index: 213)...
#   Success! Adv label: 8, L2: 310.16, Queries: 25
# Attacking sample 23/100 (True: 1, Index: 220)...
#   Success! Adv label: 8, L2: 263.94, Queries: 21
# Attacking sample 24/100 (True: 1, Index: 223)...
#   Success! Adv label: 4, L2: 368.42, Queries: 29
# Attacking sample 25/100 (True: 1, Index: 226)...
#   Success! Adv label: 4, L2: 343.31, Queries: 27
# Attacking sample 26/100 (True: 1, Index: 232)...
#   Success! Adv label: 4, L2: 451.82, Queries: 35
# Attacking sample 27/100 (True: 1, Index: 241)...
#   Success! Adv label: 4, L2: 284.71, Queries: 23
# Attacking sample 28/100 (True: 1, Index: 254)...
#   Success! Adv label: 8, L2: 325.22, Queries: 25
# Attacking sample 29/100 (True: 1, Index: 281)...
#   Success! Adv label: 8, L2: 307.08, Queries: 25
# Attacking sample 30/100 (True: 1, Index: 284)...
#   Success! Adv label: 8, L2: 346.38, Queries: 29
# Attacking sample 31/100 (True: 1, Index: 285)...
#   Success! Adv label: 9, L2: 250.85, Queries: 21
# Attacking sample 32/100 (True: 1, Index: 286)...
#   Success! Adv label: 4, L2: 309.13, Queries: 25
# Attacking sample 33/100 (True: 1, Index: 287)...
#   Success! Adv label: 4, L2: 322.12, Queries: 27
# Attacking sample 34/100 (True: 1, Index: 294)...
#   Success! Adv label: 4, L2: 391.64, Queries: 31
# Attacking sample 35/100 (True: 1, Index: 298)...
#   Success! Adv label: 4, L2: 495.13, Queries: 39
# Attacking sample 36/100 (True: 1, Index: 306)...
#   Success! Adv label: 4, L2: 423.82, Queries: 33
# Attacking sample 37/100 (True: 1, Index: 312)...
#   Success! Adv label: 8, L2: 379.26, Queries: 33
# Attacking sample 38/100 (True: 1, Index: 317)...
#   Success! Adv label: 4, L2: 370.09, Queries: 31
# Attacking sample 39/100 (True: 1, Index: 334)...
#   Success! Adv label: 4, L2: 399.11, Queries: 31
# Attacking sample 40/100 (True: 1, Index: 337)...
#   Success! Adv label: 8, L2: 400.91, Queries: 31
# Attacking sample 41/100 (True: 1, Index: 338)...
#   Success! Adv label: 4, L2: 507.84, Queries: 39
# Attacking sample 42/100 (True: 1, Index: 348)...
#   Success! Adv label: 2, L2: 514.02, Queries: 41
# Attacking sample 43/100 (True: 1, Index: 361)...
#   Success! Adv label: 9, L2: 289.83, Queries: 23
# Attacking sample 44/100 (True: 1, Index: 363)...
#   Success! Adv label: 8, L2: 381.48, Queries: 29
# Attacking sample 45/100 (True: 1, Index: 367)...
#   Success! Adv label: 8, L2: 204.43, Queries: 17
# Attacking sample 46/100 (True: 1, Index: 375)...
#   Success! Adv label: 9, L2: 485.38, Queries: 39
# Attacking sample 47/100 (True: 1, Index: 384)...
#   Success! Adv label: 8, L2: 318.86, Queries: 25
# Attacking sample 48/100 (True: 1, Index: 412)...
#   Success! Adv label: 8, L2: 465.25, Queries: 35
# Attacking sample 49/100 (True: 1, Index: 425)...
#   Success! Adv label: 9, L2: 421.82, Queries: 33
# Attacking sample 50/100 (True: 1, Index: 428)...
#   Success! Adv label: 4, L2: 379.72, Queries: 29
# Attacking sample 51/100 (True: 1, Index: 463)...
#   Success! Adv label: 4, L2: 308.61, Queries: 25
# Attacking sample 52/100 (True: 1, Index: 499)...
#   Success! Adv label: 4, L2: 428.30, Queries: 33
# Attacking sample 53/100 (True: 1, Index: 502)...
#   Success! Adv label: 4, L2: 418.31, Queries: 33
# Attacking sample 54/100 (True: 1, Index: 526)...
#   Success! Adv label: 8, L2: 292.84, Queries: 23
# Attacking sample 55/100 (True: 1, Index: 532)...
#   Success! Adv label: 4, L2: 377.71, Queries: 29
# Attacking sample 56/100 (True: 1, Index: 536)...
#   Success! Adv label: 9, L2: 280.37, Queries: 23
# Attacking sample 57/100 (True: 1, Index: 537)...
#   Success! Adv label: 8, L2: 369.39, Queries: 31
# Attacking sample 58/100 (True: 1, Index: 539)...
#   Success! Adv label: 4, L2: 393.13, Queries: 31
# Attacking sample 60/100 (True: 1, Index: 560)...
#   Success! Adv label: 4, L2: 370.21, Queries: 29
# Attacking sample 61/100 (True: 1, Index: 561)...
#   Success! Adv label: 8, L2: 315.27, Queries: 25
# Attacking sample 62/100 (True: 1, Index: 570)...
#   Success! Adv label: 8, L2: 360.02, Queries: 29
# Attacking sample 63/100 (True: 1, Index: 573)...
#   Success! Adv label: 2, L2: 33.44, Queries: 3
# Attacking sample 64/100 (True: 1, Index: 576)...
#   Success! Adv label: 7, L2: 337.97, Queries: 29
# Attacking sample 65/100 (True: 1, Index: 580)...
#   Success! Adv label: 4, L2: 317.56, Queries: 25
# Attacking sample 66/100 (True: 1, Index: 588)...
#   Success! Adv label: 7, L2: 464.02, Queries: 39
# Attacking sample 67/100 (True: 1, Index: 620)...
#   Success! Adv label: 4, L2: 395.28, Queries: 31
# Attacking sample 68/100 (True: 1, Index: 621)...
#   Success! Adv label: 4, L2: 366.08, Queries: 29
# Attacking sample 69/100 (True: 1, Index: 622)...
#   Success! Adv label: 2, L2: 134.39, Queries: 11
# Attacking sample 70/100 (True: 1, Index: 627)...
#   Success! Adv label: 8, L2: 300.65, Queries: 25
# Attacking sample 71/100 (True: 1, Index: 630)...
#   Success! Adv label: 8, L2: 246.69, Queries: 19
# Attacking sample 72/100 (True: 1, Index: 632)...
#   Success! Adv label: 4, L2: 265.82, Queries: 21
# Attacking sample 73/100 (True: 1, Index: 644)...
#   Success! Adv label: 4, L2: 316.36, Queries: 25
# Attacking sample 74/100 (True: 1, Index: 646)...
#   Success! Adv label: 7, L2: 331.94, Queries: 29
# Attacking sample 75/100 (True: 1, Index: 649)...
#   Success! Adv label: 4, L2: 431.43, Queries: 33
# Attacking sample 76/100 (True: 1, Index: 662)...
#   Success! Adv label: 4, L2: 427.32, Queries: 33
# Attacking sample 77/100 (True: 1, Index: 663)...
#   Success! Adv label: 8, L2: 297.53, Queries: 23
# Attacking sample 78/100 (True: 1, Index: 669)...
#   Success! Adv label: 9, L2: 464.43, Queries: 37
# Attacking sample 79/100 (True: 1, Index: 677)...
#   Success! Adv label: 4, L2: 281.39, Queries: 23
# Attacking sample 80/100 (True: 1, Index: 686)...
#   Success! Adv label: 8, L2: 370.44, Queries: 31
# Attacking sample 81/100 (True: 1, Index: 689)...
#   Success! Adv label: 4, L2: 361.95, Queries: 27
# Attacking sample 82/100 (True: 1, Index: 703)...
#   Success! Adv label: 8, L2: 389.79, Queries: 31
# Attacking sample 83/100 (True: 1, Index: 705)...
#   Success! Adv label: 4, L2: 548.85, Queries: 45
# Attacking sample 84/100 (True: 1, Index: 709)...
#   Success! Adv label: 4, L2: 324.48, Queries: 27
# Attacking sample 85/100 (True: 1, Index: 724)...
#   Success! Adv label: 4, L2: 239.90, Queries: 19
# Attacking sample 86/100 (True: 1, Index: 727)...
#   Success! Adv label: 8, L2: 330.18, Queries: 25
# Attacking sample 87/100 (True: 1, Index: 734)...
#   Success! Adv label: 8, L2: 236.82, Queries: 21
# Attacking sample 88/100 (True: 1, Index: 740)...
#   Success! Adv label: 4, L2: 348.34, Queries: 27
# Attacking sample 89/100 (True: 1, Index: 741)...
#   Success! Adv label: 8, L2: 253.22, Queries: 21
# Attacking sample 90/100 (True: 1, Index: 743)...
#   Success! Adv label: 8, L2: 333.45, Queries: 25
# Attacking sample 91/100 (True: 1, Index: 759)...
#   Success! Adv label: 4, L2: 377.21, Queries: 31
# Attacking sample 92/100 (True: 1, Index: 768)...
#   Success! Adv label: 8, L2: 315.41, Queries: 25
# Attacking sample 93/100 (True: 1, Index: 775)...
#   Success! Adv label: 4, L2: 278.42, Queries: 23
# Attacking sample 94/100 (True: 1, Index: 782)...
#   Success! Adv label: 4, L2: 396.35, Queries: 31
# Attacking sample 95/100 (True: 1, Index: 798)...
#   Success! Adv label: 9, L2: 350.05, Queries: 29
# Attacking sample 96/100 (True: 1, Index: 799)...
#   Success! Adv label: 8, L2: 447.47, Queries: 35
# Attacking sample 97/100 (True: 1, Index: 808)...
#   Success! Adv label: 4, L2: 417.70, Queries: 33
# Attacking sample 98/100 (True: 1, Index: 819)...
#   Success! Adv label: 4, L2: 482.89, Queries: 37
# Attacking sample 99/100 (True: 1, Index: 843)...
#   Success! Adv label: 4, L2: 448.54, Queries: 35
# Attacking sample 100/100 (True: 1, Index: 853)...
#   Success! Adv label: 4, L2: 385.76, Queries: 31
# Attacking sample 1/100 (True: 2, Index: 4)...
#   Success! Adv label: 3, L2: 608.35, Queries: 55
# Attacking sample 2/100 (True: 2, Index: 22)...
#   Success! Adv label: 6, L2: 793.36, Queries: 93
# Attacking sample 3/100 (True: 2, Index: 32)...
#   Success! Adv label: 3, L2: 930.19, Queries: 87
# Attacking sample 4/100 (True: 2, Index: 34)...
#   Success! Adv label: 4, L2: 29.31, Queries: 3
# Attacking sample 5/100 (True: 2, Index: 42)...
#   Success! Adv label: 3, L2: 240.15, Queries: 21
# Attacking sample 6/100 (True: 2, Index: 49)...
#   Success! Adv label: 3, L2: 884.56, Queries: 131
# Attacking sample 7/100 (True: 2, Index: 52)...
#   Success! Adv label: 3, L2: 946.36, Queries: 101
# Attacking sample 8/100 (True: 2, Index: 69)...
#   Success! Adv label: 8, L2: 859.80, Queries: 75
# Attacking sample 9/100 (True: 2, Index: 70)...
#   Success! Adv label: 3, L2: 584.61, Queries: 67
# Attacking sample 10/100 (True: 2, Index: 81)...
#   Success! Adv label: 8, L2: 938.74, Queries: 77
# Attacking sample 11/100 (True: 2, Index: 110)...
#   Success! Adv label: 7, L2: 1017.66, Queries: 99
# Attacking sample 12/100 (True: 2, Index: 118)...
#   Success! Adv label: 3, L2: 589.86, Queries: 53
# Attacking sample 13/100 (True: 2, Index: 121)...
#   Success! Adv label: 3, L2: 659.87, Queries: 57
# Attacking sample 14/100 (True: 2, Index: 138)...
#   Success! Adv label: 3, L2: 711.08, Queries: 65
# Attacking sample 15/100 (True: 2, Index: 144)...
#   Success! Adv label: 0, L2: 722.98, Queries: 63
# Attacking sample 16/100 (True: 2, Index: 155)...
#   Success! Adv label: 8, L2: 829.91, Queries: 67
# Attacking sample 17/100 (True: 2, Index: 160)...
#   Success! Adv label: 6, L2: 425.54, Queries: 41
# Attacking sample 18/100 (True: 2, Index: 161)...
#   Success! Adv label: 3, L2: 634.96, Queries: 57
# Attacking sample 19/100 (True: 2, Index: 176)...
#   Success! Adv label: 3, L2: 684.59, Queries: 61
# Attacking sample 21/100 (True: 2, Index: 186)...
#   Success! Adv label: 7, L2: 743.49, Queries: 83
# Attacking sample 22/100 (True: 2, Index: 197)...
#   Success! Adv label: 8, L2: 871.39, Queries: 83
# Attacking sample 23/100 (True: 2, Index: 208)...
#   Success! Adv label: 8, L2: 918.46, Queries: 85
# Attacking sample 25/100 (True: 2, Index: 216)...
#   Success! Adv label: 3, L2: 823.14, Queries: 83
# Attacking sample 26/100 (True: 2, Index: 219)...
#   Success! Adv label: 3, L2: 432.51, Queries: 41
# Attacking sample 27/100 (True: 2, Index: 235)...
#   Success! Adv label: 3, L2: 740.46, Queries: 71
# Attacking sample 28/100 (True: 2, Index: 260)...
#   Success! Adv label: 0, L2: 599.17, Queries: 55
# Attacking sample 29/100 (True: 2, Index: 276)...
#   Success! Adv label: 4, L2: 525.32, Queries: 53
# Attacking sample 30/100 (True: 2, Index: 293)...
#   Success! Adv label: 3, L2: 710.56, Queries: 81
# Attacking sample 31/100 (True: 2, Index: 295)...
#   Success! Adv label: 3, L2: 587.34, Queries: 55
# Attacking sample 32/100 (True: 2, Index: 311)...
#   Success! Adv label: 3, L2: 528.93, Queries: 49
# Attacking sample 33/100 (True: 2, Index: 313)...
#   Success! Adv label: 3, L2: 154.92, Queries: 15
# Attacking sample 34/100 (True: 2, Index: 322)...
#   Success! Adv label: 0, L2: 690.99, Queries: 65
# Attacking sample 35/100 (True: 2, Index: 328)...
#   Success! Adv label: 8, L2: 727.95, Queries: 65
# Attacking sample 36/100 (True: 2, Index: 357)...
#   Success! Adv label: 7, L2: 533.82, Queries: 51
# Attacking sample 37/100 (True: 2, Index: 374)...
#   Success! Adv label: 8, L2: 466.76, Queries: 41
# Attacking sample 38/100 (True: 2, Index: 395)...
#   Success! Adv label: 8, L2: 451.47, Queries: 45
# Attacking sample 39/100 (True: 2, Index: 396)...
#   Success! Adv label: 8, L2: 618.95, Queries: 55
# Attacking sample 40/100 (True: 2, Index: 398)...
#   Success! Adv label: 3, L2: 772.75, Queries: 75
# Attacking sample 41/100 (True: 2, Index: 433)...
#   Success! Adv label: 3, L2: 652.21, Queries: 57
# Attacking sample 42/100 (True: 2, Index: 439)...
#   Success! Adv label: 9, L2: 715.23, Queries: 63
# Attacking sample 43/100 (True: 2, Index: 441)...
#   Success! Adv label: 8, L2: 358.63, Queries: 29
# Attacking sample 44/100 (True: 2, Index: 442)...
#   Success! Adv label: 9, L2: 769.28, Queries: 69
# Attacking sample 45/100 (True: 2, Index: 451)...
#   Success! Adv label: 0, L2: 1123.75, Queries: 113
# Attacking sample 46/100 (True: 2, Index: 462)...
#   Success! Adv label: 3, L2: 661.68, Queries: 57
# Attacking sample 47/100 (True: 2, Index: 470)...
#   Success! Adv label: 3, L2: 622.94, Queries: 55
# Attacking sample 48/100 (True: 2, Index: 477)...
#   Success! Adv label: 3, L2: 882.82, Queries: 81
# Attacking sample 49/100 (True: 2, Index: 485)...
#   Success! Adv label: 7, L2: 256.97, Queries: 23
# Attacking sample 50/100 (True: 2, Index: 491)...
#   Success! Adv label: 8, L2: 739.87, Queries: 61
# Attacking sample 51/100 (True: 2, Index: 493)...
#   Success! Adv label: 7, L2: 839.33, Queries: 95
# Attacking sample 52/100 (True: 2, Index: 495)...
#   Success! Adv label: 3, L2: 659.31, Queries: 63
# Attacking sample 53/100 (True: 2, Index: 519)...
#   Success! Adv label: 3, L2: 776.95, Queries: 71
# Attacking sample 54/100 (True: 2, Index: 523)...
#   Success! Adv label: 6, L2: 700.88, Queries: 71
# Attacking sample 55/100 (True: 2, Index: 557)...
#   Success! Adv label: 8, L2: 755.83, Queries: 63
# Attacking sample 56/100 (True: 2, Index: 567)...
#   Success! Adv label: 0, L2: 498.65, Queries: 43
# Attacking sample 57/100 (True: 2, Index: 571)...
#   Success! Adv label: 7, L2: 679.97, Queries: 65
# Attacking sample 58/100 (True: 2, Index: 584)...
#   Success! Adv label: 3, L2: 1009.00, Queries: 93
# Attacking sample 59/100 (True: 2, Index: 591)...
#   Success! Adv label: 8, L2: 1025.78, Queries: 99
# Attacking sample 60/100 (True: 2, Index: 592)...
#   Success! Adv label: 8, L2: 875.84, Queries: 95
# Attacking sample 61/100 (True: 2, Index: 610)...
#   Success! Adv label: 3, L2: 997.58, Queries: 95
# Attacking sample 62/100 (True: 2, Index: 612)...
#   Success! Adv label: 8, L2: 687.87, Queries: 55
# Attacking sample 63/100 (True: 2, Index: 616)...
#   Success! Adv label: 3, L2: 833.29, Queries: 77
# Attacking sample 64/100 (True: 2, Index: 624)...
#   Success! Adv label: 3, L2: 718.52, Queries: 61
# Attacking sample 65/100 (True: 2, Index: 631)...
#   Success! Adv label: 3, L2: 533.85, Queries: 51
# Attacking sample 66/100 (True: 2, Index: 636)...
#   Success! Adv label: 3, L2: 857.78, Queries: 75
# Attacking sample 67/100 (True: 2, Index: 647)...
#   Success! Adv label: 1, L2: 124.70, Queries: 13
# Attacking sample 68/100 (True: 2, Index: 650)...
#   Success! Adv label: 3, L2: 209.32, Queries: 19
# Attacking sample 69/100 (True: 2, Index: 664)...
#   Success! Adv label: 3, L2: 965.90, Queries: 89
# Attacking sample 70/100 (True: 2, Index: 704)...
#   Success! Adv label: 3, L2: 666.77, Queries: 61
# Attacking sample 71/100 (True: 2, Index: 720)...
#   Success! Adv label: 4, L2: 255.48, Queries: 23
# Attacking sample 72/100 (True: 2, Index: 725)...
#   Success! Adv label: 3, L2: 505.80, Queries: 45
# Attacking sample 73/100 (True: 2, Index: 750)...
#   Success! Adv label: 3, L2: 891.95, Queries: 157
# Attacking sample 74/100 (True: 2, Index: 764)...
#   Success! Adv label: 3, L2: 676.54, Queries: 77
# Attacking sample 75/100 (True: 2, Index: 780)...
#   Success! Adv label: 8, L2: 808.36, Queries: 69
# Attacking sample 76/100 (True: 2, Index: 784)...
#   Success! Adv label: 8, L2: 899.57, Queries: 81
# Attacking sample 77/100 (True: 2, Index: 788)...
#   Success! Adv label: 1, L2: 562.43, Queries: 51
# Attacking sample 78/100 (True: 2, Index: 790)...
#   Success! Adv label: 3, L2: 921.06, Queries: 95
# Attacking sample 79/100 (True: 2, Index: 797)...
#   Success! Adv label: 8, L2: 598.38, Queries: 51
# Attacking sample 80/100 (True: 2, Index: 803)...
#   Success! Adv label: 0, L2: 936.86, Queries: 83
# Attacking sample 81/100 (True: 2, Index: 807)...
#   Success! Adv label: 1, L2: 1002.75, Queries: 135
# Attacking sample 82/100 (True: 2, Index: 828)...
#   Success! Adv label: 3, L2: 464.88, Queries: 41
# Attacking sample 83/100 (True: 2, Index: 842)...
#   Success! Adv label: 3, L2: 712.33, Queries: 69
# Attacking sample 84/100 (True: 2, Index: 845)...
#   Success! Adv label: 3, L2: 950.72, Queries: 81
# Attacking sample 85/100 (True: 2, Index: 859)...
#   Success! Adv label: 3, L2: 489.93, Queries: 43
# Attacking sample 86/100 (True: 2, Index: 871)...
#   Success! Adv label: 1, L2: 714.03, Queries: 69
# Attacking sample 87/100 (True: 2, Index: 881)...
#   Success! Adv label: 1, L2: 639.02, Queries: 77
# Attacking sample 88/100 (True: 2, Index: 883)...
#   Success! Adv label: 8, L2: 401.87, Queries: 35
# Attacking sample 89/100 (True: 2, Index: 896)...
#   Success! Adv label: 3, L2: 548.27, Queries: 49
# Attacking sample 90/100 (True: 2, Index: 897)...
#   Success! Adv label: 3, L2: 519.47, Queries: 57
# Attacking sample 92/100 (True: 2, Index: 922)...
#   Success! Adv label: 7, L2: 574.27, Queries: 57
# Attacking sample 93/100 (True: 2, Index: 932)...
#   Success! Adv label: 8, L2: 745.20, Queries: 65
# Attacking sample 94/100 (True: 2, Index: 944)...
#   Success! Adv label: 3, L2: 565.72, Queries: 51
# Attacking sample 95/100 (True: 2, Index: 949)...
#   Success! Adv label: 3, L2: 803.35, Queries: 71
# Attacking sample 96/100 (True: 2, Index: 952)...
#   Failed! Adv label: 2, L2: 994.46, Queries: 201
# Attacking sample 97/100 (True: 2, Index: 959)...
#   Success! Adv label: 3, L2: 603.42, Queries: 51
# Attacking sample 98/100 (True: 2, Index: 966)...
#   Success! Adv label: 7, L2: 196.07, Queries: 19
# Attacking sample 99/100 (True: 2, Index: 967)...
#   Success! Adv label: 7, L2: 815.93, Queries: 85
# Attacking sample 100/100 (True: 2, Index: 985)...
#   Success! Adv label: 3, L2: 629.02, Queries: 63
# Attacking sample 1/100 (True: 3, Index: 1)...
#   Success! Adv label: 5, L2: 376.76, Queries: 33
# Attacking sample 2/100 (True: 3, Index: 12)...
#   Success! Adv label: 5, L2: 386.85, Queries: 37
# Attacking sample 3/100 (True: 3, Index: 20)...
#   Success! Adv label: 8, L2: 778.23, Queries: 65
# Attacking sample 4/100 (True: 3, Index: 27)...
#   Success! Adv label: 5, L2: 1022.99, Queries: 127
# Attacking sample 5/100 (True: 3, Index: 37)...
#   Success! Adv label: 2, L2: 994.90, Queries: 99
# Attacking sample 6/100 (True: 3, Index: 43)...
#   Failed! Adv label: 3, L2: 946.98, Queries: 201
# Attacking sample 7/100 (True: 3, Index: 53)...
#   Success! Adv label: 8, L2: 568.23, Queries: 49
# Attacking sample 8/100 (True: 3, Index: 61)...
#   Success! Adv label: 8, L2: 599.55, Queries: 51
# Attacking sample 9/100 (True: 3, Index: 73)...
#   Success! Adv label: 8, L2: 659.79, Queries: 63
# Attacking sample 10/100 (True: 3, Index: 102)...
#   Success! Adv label: 2, L2: 423.49, Queries: 39
# Attacking sample 11/100 (True: 3, Index: 108)...
#   Success! Adv label: 2, L2: 95.46, Queries: 9
# Attacking sample 12/100 (True: 3, Index: 109)...
#   Success! Adv label: 8, L2: 552.66, Queries: 45
# Attacking sample 13/100 (True: 3, Index: 117)...
#   Success! Adv label: 5, L2: 901.43, Queries: 123
# Attacking sample 14/100 (True: 3, Index: 131)...
#   Success! Adv label: 8, L2: 158.68, Queries: 13
# Attacking sample 15/100 (True: 3, Index: 159)...
#   Success! Adv label: 2, L2: 938.45, Queries: 97
# Attacking sample 16/100 (True: 3, Index: 162)...
#   Success! Adv label: 2, L2: 1002.23, Queries: 169
# Attacking sample 17/100 (True: 3, Index: 166)...
#   Success! Adv label: 2, L2: 839.78, Queries: 103
# Attacking sample 18/100 (True: 3, Index: 177)...
#   Success! Adv label: 8, L2: 552.88, Queries: 45
# Attacking sample 19/100 (True: 3, Index: 181)...
#   Success! Adv label: 5, L2: 585.15, Queries: 61
# Attacking sample 20/100 (True: 3, Index: 187)...
#   Success! Adv label: 8, L2: 655.75, Queries: 53
# Attacking sample 21/100 (True: 3, Index: 196)...
#   Success! Adv label: 2, L2: 500.50, Queries: 41
# Attacking sample 22/100 (True: 3, Index: 204)...
#   Success! Adv label: 5, L2: 926.64, Queries: 101
# Attacking sample 23/100 (True: 3, Index: 227)...
#   Failed! Adv label: 3, L2: 915.83, Queries: 201
# Attacking sample 24/100 (True: 3, Index: 231)...
#   Success! Adv label: 5, L2: 709.43, Queries: 65
# Attacking sample 25/100 (True: 3, Index: 237)...
#   Success! Adv label: 5, L2: 990.09, Queries: 109
# Attacking sample 26/100 (True: 3, Index: 244)...
#   Success! Adv label: 7, L2: 864.65, Queries: 93
# Attacking sample 27/100 (True: 3, Index: 257)...
#   Success! Adv label: 8, L2: 558.41, Queries: 47
# Attacking sample 28/100 (True: 3, Index: 259)...
#   Success! Adv label: 5, L2: 877.05, Queries: 91
# Attacking sample 29/100 (True: 3, Index: 265)...
#   Success! Adv label: 5, L2: 500.20, Queries: 43
# Attacking sample 30/100 (True: 3, Index: 270)...
#   Success! Adv label: 5, L2: 241.41, Queries: 21
# Attacking sample 31/100 (True: 3, Index: 288)...
#   Success! Adv label: 8, L2: 943.00, Queries: 79
# Attacking sample 32/100 (True: 3, Index: 308)...
#   Success! Adv label: 8, L2: 580.37, Queries: 51
# Attacking sample 33/100 (True: 3, Index: 309)...
#   Success! Adv label: 8, L2: 561.67, Queries: 49
# Attacking sample 34/100 (True: 3, Index: 327)...
#   Success! Adv label: 1, L2: 362.44, Queries: 39
# Attacking sample 35/100 (True: 3, Index: 331)...
#   Success! Adv label: 8, L2: 779.68, Queries: 75
# Attacking sample 36/100 (True: 3, Index: 340)...
#   Failed! Adv label: 3, L2: 1048.13, Queries: 201
# Attacking sample 37/100 (True: 3, Index: 341)...
#   Success! Adv label: 5, L2: 740.41, Queries: 71
# Attacking sample 38/100 (True: 3, Index: 342)...
#   Success! Adv label: 5, L2: 501.33, Queries: 45
# Attacking sample 39/100 (True: 3, Index: 362)...
#   Success! Adv label: 2, L2: 534.26, Queries: 47
# Attacking sample 40/100 (True: 3, Index: 383)...
#   Success! Adv label: 2, L2: 524.96, Queries: 49
# Attacking sample 41/100 (True: 3, Index: 394)...
#   Success! Adv label: 8, L2: 491.09, Queries: 41
# Attacking sample 42/100 (True: 3, Index: 406)...
#   Failed! Adv label: 3, L2: 923.37, Queries: 201
# Attacking sample 43/100 (True: 3, Index: 409)...
#   Success! Adv label: 2, L2: 901.64, Queries: 91
# Attacking sample 44/100 (True: 3, Index: 445)...
#   Success! Adv label: 2, L2: 388.05, Queries: 33
# Attacking sample 45/100 (True: 3, Index: 456)...
#   Success! Adv label: 8, L2: 543.46, Queries: 45
# Attacking sample 46/100 (True: 3, Index: 459)...
#   Success! Adv label: 5, L2: 1019.89, Queries: 173
# Attacking sample 47/100 (True: 3, Index: 461)...
#   Failed! Adv label: 3, L2: 1070.81, Queries: 201
# Attacking sample 48/100 (True: 3, Index: 471)...
#   Success! Adv label: 8, L2: 864.19, Queries: 75
# Attacking sample 49/100 (True: 3, Index: 474)...
#   Success! Adv label: 5, L2: 505.04, Queries: 47
# Attacking sample 50/100 (True: 3, Index: 481)...
#   Success! Adv label: 5, L2: 807.56, Queries: 85
# Attacking sample 51/100 (True: 3, Index: 504)...
#   Success! Adv label: 5, L2: 738.30, Queries: 69
# Attacking sample 52/100 (True: 3, Index: 510)...
#   Success! Adv label: 5, L2: 350.76, Queries: 31
# Attacking sample 53/100 (True: 3, Index: 512)...
#   Failed! Adv label: 3, L2: 881.93, Queries: 201
# Attacking sample 54/100 (True: 3, Index: 524)...
#   Success! Adv label: 8, L2: 626.34, Queries: 51
# Attacking sample 55/100 (True: 3, Index: 549)...
#   Success! Adv label: 8, L2: 551.38, Queries: 53
# Attacking sample 56/100 (True: 3, Index: 556)...
#   Success! Adv label: 9, L2: 661.95, Queries: 63
# Attacking sample 57/100 (True: 3, Index: 564)...
#   Success! Adv label: 8, L2: 508.50, Queries: 43
# Attacking sample 58/100 (True: 3, Index: 586)...
#   Failed! Adv label: 3, L2: 940.03, Queries: 201
# Attacking sample 59/100 (True: 3, Index: 589)...
#   Success! Adv label: 0, L2: 1095.47, Queries: 125
# Attacking sample 60/100 (True: 3, Index: 609)...
#   Success! Adv label: 9, L2: 750.59, Queries: 71
# Attacking sample 61/100 (True: 3, Index: 613)...
#   Success! Adv label: 2, L2: 702.09, Queries: 59
# Attacking sample 62/100 (True: 3, Index: 623)...
#   Success! Adv label: 9, L2: 432.65, Queries: 37
# Attacking sample 63/100 (True: 3, Index: 639)...
#   Success! Adv label: 5, L2: 719.56, Queries: 69
# Attacking sample 64/100 (True: 3, Index: 648)...
#   Success! Adv label: 8, L2: 445.82, Queries: 37
# Attacking sample 65/100 (True: 3, Index: 651)...
#   Success! Adv label: 8, L2: 393.95, Queries: 33
# Attacking sample 66/100 (True: 3, Index: 659)...
#   Success! Adv label: 9, L2: 649.05, Queries: 65
# Attacking sample 67/100 (True: 3, Index: 661)...
#   Success! Adv label: 5, L2: 986.80, Queries: 99
# Attacking sample 68/100 (True: 3, Index: 667)...
#   Failed! Adv label: 3, L2: 896.60, Queries: 201
# Attacking sample 69/100 (True: 3, Index: 678)...
#   Failed! Adv label: 3, L2: 913.93, Queries: 201
# Attacking sample 70/100 (True: 3, Index: 690)...
#   Success! Adv label: 8, L2: 919.99, Queries: 75
# Attacking sample 71/100 (True: 3, Index: 693)...
#   Failed! Adv label: 3, L2: 874.53, Queries: 201
# Attacking sample 72/100 (True: 3, Index: 694)...
#   Success! Adv label: 8, L2: 797.93, Queries: 69
# Attacking sample 73/100 (True: 3, Index: 695)...
#   Success! Adv label: 0, L2: 270.39, Queries: 23
# Attacking sample 74/100 (True: 3, Index: 702)...
#   Success! Adv label: 8, L2: 417.19, Queries: 33
# Attacking sample 75/100 (True: 3, Index: 718)...
#   Success! Adv label: 2, L2: 1022.79, Queries: 121
# Attacking sample 76/100 (True: 3, Index: 749)...
#   Success! Adv label: 5, L2: 1036.55, Queries: 123
# Attacking sample 77/100 (True: 3, Index: 769)...
#   Success! Adv label: 9, L2: 849.64, Queries: 73
# Attacking sample 79/100 (True: 3, Index: 779)...
#   Success! Adv label: 8, L2: 436.49, Queries: 39
# Attacking sample 80/100 (True: 3, Index: 800)...
#   Success! Adv label: 8, L2: 901.97, Queries: 71
# Attacking sample 81/100 (True: 3, Index: 816)...
#   Success! Adv label: 5, L2: 290.45, Queries: 27
# Attacking sample 82/100 (True: 3, Index: 829)...
#   Success! Adv label: 2, L2: 531.89, Queries: 47
# Attacking sample 83/100 (True: 3, Index: 833)...
#   Failed! Adv label: 3, L2: 917.42, Queries: 201
# Attacking sample 84/100 (True: 3, Index: 839)...
#   Success! Adv label: 8, L2: 678.97, Queries: 61
# Attacking sample 85/100 (True: 3, Index: 854)...
#   Success! Adv label: 5, L2: 338.31, Queries: 31
# Attacking sample 86/100 (True: 3, Index: 856)...
#   Success! Adv label: 2, L2: 457.81, Queries: 43
# Attacking sample 87/100 (True: 3, Index: 858)...
#   Success! Adv label: 5, L2: 117.81, Queries: 11
# Attacking sample 89/100 (True: 3, Index: 886)...
#   Success! Adv label: 8, L2: 834.67, Queries: 73
# Attacking sample 90/100 (True: 3, Index: 900)...
#   Success! Adv label: 8, L2: 725.26, Queries: 63
# Attacking sample 91/100 (True: 3, Index: 916)...
#   Success! Adv label: 5, L2: 467.75, Queries: 47
# Attacking sample 92/100 (True: 3, Index: 921)...
#   Success! Adv label: 2, L2: 436.07, Queries: 41
# Attacking sample 93/100 (True: 3, Index: 937)...
#   Success! Adv label: 9, L2: 898.71, Queries: 77
# Attacking sample 94/100 (True: 3, Index: 938)...
#   Success! Adv label: 8, L2: 706.99, Queries: 55
# Attacking sample 95/100 (True: 3, Index: 939)...
#   Success! Adv label: 8, L2: 369.62, Queries: 31
# Attacking sample 96/100 (True: 3, Index: 942)...
#   Success! Adv label: 5, L2: 977.05, Queries: 113
# Attacking sample 97/100 (True: 3, Index: 951)...
#   Success! Adv label: 8, L2: 596.23, Queries: 53
# Attacking sample 98/100 (True: 3, Index: 953)...
#   Failed! Adv label: 3, L2: 988.13, Queries: 201
# Attacking sample 99/100 (True: 3, Index: 975)...
#   Failed! Adv label: 3, L2: 1053.65, Queries: 201
# Attacking sample 1/100 (True: 4, Index: 16)...
#   Success! Adv label: 9, L2: 327.47, Queries: 29
# Attacking sample 2/100 (True: 4, Index: 17)...
#   Success! Adv label: 6, L2: 436.96, Queries: 39
# Attacking sample 3/100 (True: 4, Index: 30)...
#   Success! Adv label: 8, L2: 788.90, Queries: 71
# Attacking sample 4/100 (True: 4, Index: 33)...
#   Success! Adv label: 9, L2: 509.92, Queries: 45
# Attacking sample 5/100 (True: 4, Index: 45)...
#   Success! Adv label: 8, L2: 136.25, Queries: 11
# Attacking sample 6/100 (True: 4, Index: 48)...
#   Success! Adv label: 9, L2: 763.55, Queries: 67
# Attacking sample 7/100 (True: 4, Index: 58)...
#   Success! Adv label: 9, L2: 722.30, Queries: 61
# Attacking sample 8/100 (True: 4, Index: 66)...
#   Success! Adv label: 6, L2: 625.30, Queries: 59
# Attacking sample 9/100 (True: 4, Index: 89)...
#   Success! Adv label: 9, L2: 367.90, Queries: 31
# Attacking sample 10/100 (True: 4, Index: 92)...
#   Success! Adv label: 6, L2: 880.32, Queries: 81
# Attacking sample 11/100 (True: 4, Index: 113)...
#   Success! Adv label: 9, L2: 717.49, Queries: 63
# Attacking sample 12/100 (True: 4, Index: 116)...
#   Success! Adv label: 9, L2: 620.70, Queries: 51
# Attacking sample 13/100 (True: 4, Index: 126)...
#   Success! Adv label: 9, L2: 490.96, Queries: 41
# Attacking sample 14/100 (True: 4, Index: 130)...
#   Success! Adv label: 9, L2: 351.71, Queries: 29
# Attacking sample 15/100 (True: 4, Index: 139)...
#   Success! Adv label: 9, L2: 534.34, Queries: 45
# Attacking sample 16/100 (True: 4, Index: 149)...
#   Success! Adv label: 2, L2: 1087.13, Queries: 127
# Attacking sample 17/100 (True: 4, Index: 153)...
#   Success! Adv label: 8, L2: 499.42, Queries: 43
# Attacking sample 18/100 (True: 4, Index: 154)...
#   Success! Adv label: 7, L2: 861.56, Queries: 77
# Attacking sample 19/100 (True: 4, Index: 163)...
#   Success! Adv label: 9, L2: 565.97, Queries: 49
# Attacking sample 20/100 (True: 4, Index: 167)...
#   Success! Adv label: 9, L2: 716.50, Queries: 63
# Attacking sample 21/100 (True: 4, Index: 183)...
#   Success! Adv label: 9, L2: 424.95, Queries: 39
# Attacking sample 22/100 (True: 4, Index: 184)...
#   Success! Adv label: 9, L2: 586.13, Queries: 51
# Attacking sample 23/100 (True: 4, Index: 192)...
#   Success! Adv label: 9, L2: 269.65, Queries: 23
# Attacking sample 24/100 (True: 4, Index: 194)...
#   Success! Adv label: 9, L2: 501.80, Queries: 45
# Attacking sample 25/100 (True: 4, Index: 233)...
#   Success! Adv label: 9, L2: 710.27, Queries: 63
# Attacking sample 26/100 (True: 4, Index: 240)...
#   Success! Adv label: 8, L2: 579.23, Queries: 47
# Attacking sample 27/100 (True: 4, Index: 263)...
#   Success! Adv label: 9, L2: 276.13, Queries: 23
# Attacking sample 28/100 (True: 4, Index: 269)...
#   Success! Adv label: 9, L2: 410.85, Queries: 35
# Attacking sample 29/100 (True: 4, Index: 280)...
#   Success! Adv label: 9, L2: 390.39, Queries: 33
# Attacking sample 30/100 (True: 4, Index: 290)...
#   Success! Adv label: 9, L2: 673.31, Queries: 55
# Attacking sample 31/100 (True: 4, Index: 297)...
#   Success! Adv label: 6, L2: 435.17, Queries: 39
# Attacking sample 32/100 (True: 4, Index: 299)...
#   Success! Adv label: 9, L2: 395.31, Queries: 33
# Attacking sample 33/100 (True: 4, Index: 310)...
#   Success! Adv label: 9, L2: 321.05, Queries: 27
# Attacking sample 34/100 (True: 4, Index: 316)...
#   Success! Adv label: 9, L2: 490.98, Queries: 41
# Attacking sample 35/100 (True: 4, Index: 320)...
#   Success! Adv label: 9, L2: 447.47, Queries: 39
# Attacking sample 36/100 (True: 4, Index: 324)...
#   Success! Adv label: 9, L2: 492.71, Queries: 43
# Attacking sample 37/100 (True: 4, Index: 326)...
#   Success! Adv label: 9, L2: 540.44, Queries: 49
# Attacking sample 38/100 (True: 4, Index: 332)...
#   Success! Adv label: 9, L2: 30.22, Queries: 3
# Attacking sample 39/100 (True: 4, Index: 335)...
#   Success! Adv label: 9, L2: 689.52, Queries: 59
# Attacking sample 40/100 (True: 4, Index: 344)...
#   Success! Adv label: 7, L2: 538.04, Queries: 49
# Attacking sample 42/100 (True: 4, Index: 359)...
#   Success! Adv label: 9, L2: 431.05, Queries: 35
# Attacking sample 43/100 (True: 4, Index: 376)...
#   Success! Adv label: 9, L2: 616.96, Queries: 55
# Attacking sample 44/100 (True: 4, Index: 393)...
#   Success! Adv label: 9, L2: 569.85, Queries: 47
# Attacking sample 45/100 (True: 4, Index: 401)...
#   Success! Adv label: 2, L2: 785.28, Queries: 69
# Attacking sample 46/100 (True: 4, Index: 402)...
#   Success! Adv label: 9, L2: 517.68, Queries: 45
# Attacking sample 47/100 (True: 4, Index: 422)...
#   Success! Adv label: 9, L2: 368.43, Queries: 29
# Attacking sample 48/100 (True: 4, Index: 423)...
#   Success! Adv label: 9, L2: 182.37, Queries: 17
# Attacking sample 49/100 (True: 4, Index: 427)...
#   Success! Adv label: 1, L2: 585.56, Queries: 57
# Attacking sample 50/100 (True: 4, Index: 432)...
#   Success! Adv label: 9, L2: 423.26, Queries: 37
# Attacking sample 51/100 (True: 4, Index: 434)...
#   Success! Adv label: 9, L2: 311.91, Queries: 25
# Attacking sample 52/100 (True: 4, Index: 454)...
#   Success! Adv label: 9, L2: 557.96, Queries: 49
# Attacking sample 53/100 (True: 4, Index: 467)...
#   Success! Adv label: 8, L2: 343.10, Queries: 29
# Attacking sample 54/100 (True: 4, Index: 501)...
#   Success! Adv label: 9, L2: 285.47, Queries: 25
# Attacking sample 55/100 (True: 4, Index: 515)...
#   Success! Adv label: 9, L2: 367.16, Queries: 31
# Attacking sample 56/100 (True: 4, Index: 540)...
#   Success! Adv label: 9, L2: 612.83, Queries: 55
# Attacking sample 57/100 (True: 4, Index: 544)...
#   Success! Adv label: 0, L2: 523.45, Queries: 49
# Attacking sample 58/100 (True: 4, Index: 545)...
#   Success! Adv label: 9, L2: 444.59, Queries: 39
# Attacking sample 59/100 (True: 4, Index: 547)...
#   Success! Adv label: 7, L2: 824.60, Queries: 89
# Attacking sample 60/100 (True: 4, Index: 566)...
#   Success! Adv label: 9, L2: 407.00, Queries: 33
# Attacking sample 61/100 (True: 4, Index: 590)...
#   Success! Adv label: 0, L2: 471.57, Queries: 41
# Attacking sample 62/100 (True: 4, Index: 593)...
#   Success! Adv label: 9, L2: 353.61, Queries: 29
# Attacking sample 63/100 (True: 4, Index: 599)...
#   Success! Adv label: 9, L2: 731.86, Queries: 71
# Attacking sample 64/100 (True: 4, Index: 602)...
#   Success! Adv label: 9, L2: 530.89, Queries: 45
# Attacking sample 65/100 (True: 4, Index: 607)...
#   Success! Adv label: 7, L2: 593.34, Queries: 61
# Attacking sample 66/100 (True: 4, Index: 611)...
#   Success! Adv label: 9, L2: 712.38, Queries: 63
# Attacking sample 67/100 (True: 4, Index: 617)...
#   Success! Adv label: 9, L2: 591.41, Queries: 47
# Attacking sample 68/100 (True: 4, Index: 657)...
#   Success! Adv label: 9, L2: 337.65, Queries: 31
# Attacking sample 69/100 (True: 4, Index: 680)...
#   Success! Adv label: 9, L2: 400.64, Queries: 33
# Attacking sample 70/100 (True: 4, Index: 684)...
#   Success! Adv label: 9, L2: 666.80, Queries: 63
# Attacking sample 71/100 (True: 4, Index: 687)...
#   Success! Adv label: 9, L2: 543.75, Queries: 45
# Attacking sample 72/100 (True: 4, Index: 692)...
#   Success! Adv label: 9, L2: 833.22, Queries: 73
# Attacking sample 73/100 (True: 4, Index: 696)...
#   Success! Adv label: 9, L2: 176.56, Queries: 15
# Attacking sample 74/100 (True: 4, Index: 697)...
#   Success! Adv label: 9, L2: 927.91, Queries: 79
# Attacking sample 75/100 (True: 4, Index: 708)...
#   Success! Adv label: 9, L2: 574.53, Queries: 49
# Attacking sample 76/100 (True: 4, Index: 717)...
#   Success! Adv label: 9, L2: 391.81, Queries: 33
# Attacking sample 77/100 (True: 4, Index: 746)...
#   Success! Adv label: 9, L2: 489.52, Queries: 43
# Attacking sample 78/100 (True: 4, Index: 752)...
#   Success! Adv label: 9, L2: 1009.21, Queries: 89
# Attacking sample 79/100 (True: 4, Index: 755)...
#   Success! Adv label: 7, L2: 802.27, Queries: 91
# Attacking sample 80/100 (True: 4, Index: 757)...
#   Success! Adv label: 9, L2: 442.25, Queries: 37
# Attacking sample 81/100 (True: 4, Index: 766)...
#   Success! Adv label: 7, L2: 497.86, Queries: 47
# Attacking sample 82/100 (True: 4, Index: 771)...
#   Success! Adv label: 9, L2: 319.05, Queries: 27
# Attacking sample 83/100 (True: 4, Index: 776)...
#   Success! Adv label: 2, L2: 612.48, Queries: 55
# Attacking sample 84/100 (True: 4, Index: 777)...
#   Success! Adv label: 1, L2: 969.76, Queries: 111
# Attacking sample 85/100 (True: 4, Index: 786)...
#   Success! Adv label: 9, L2: 199.42, Queries: 17
# Attacking sample 86/100 (True: 4, Index: 811)...
#   Success! Adv label: 9, L2: 269.82, Queries: 23
# Attacking sample 87/100 (True: 4, Index: 815)...
#   Success! Adv label: 6, L2: 700.39, Queries: 63
# Attacking sample 88/100 (True: 4, Index: 817)...
#   Success! Adv label: 7, L2: 917.07, Queries: 87
# Attacking sample 89/100 (True: 4, Index: 840)...
#   Success! Adv label: 6, L2: 724.86, Queries: 63
# Attacking sample 91/100 (True: 4, Index: 849)...
#   Success! Adv label: 8, L2: 717.38, Queries: 61
# Attacking sample 92/100 (True: 4, Index: 857)...
#   Success! Adv label: 9, L2: 551.43, Queries: 47
# Attacking sample 93/100 (True: 4, Index: 872)...
#   Success! Adv label: 9, L2: 737.69, Queries: 69
# Attacking sample 94/100 (True: 4, Index: 877)...
#   Success! Adv label: 9, L2: 474.88, Queries: 43
# Attacking sample 95/100 (True: 4, Index: 894)...
#   Success! Adv label: 9, L2: 266.50, Queries: 23
# Attacking sample 96/100 (True: 4, Index: 902)...
#   Success! Adv label: 9, L2: 398.94, Queries: 33
# Attacking sample 97/100 (True: 4, Index: 911)...
#   Success! Adv label: 9, L2: 553.73, Queries: 49
# ...
#   Success! Adv label: 3, L2: 553.29, Queries: 51
# Attacking sample 40/100 (True: 8, Index: 505)...
#   Success! Adv label: 2, L2: 725.31, Queries: 69
# Attacking sample 41/100 (True: 8, Index: 509)...
#   Success! Adv label: 3, L2: 669.45, Queries: 73
# Attacking sample 42/100 (True: 8, Index: 525)...
#   Success! Adv label: 3, L2: 581.26, Queries: 57
# Attacking sample 43/100 (True: 8, Index: 528)...
#   Success! Adv label: 3, L2: 709.90, Queries: 77
# Attacking sample 44/100 (True: 8, Index: 541)...
#   Success! Adv label: 3, L2: 859.03, Queries: 83
# Attacking sample 45/100 (True: 8, Index: 543)...
#   Success! Adv label: 6, L2: 397.15, Queries: 37
# Attacking sample 46/100 (True: 8, Index: 550)...
#   Success! Adv label: 5, L2: 493.35, Queries: 47
# Attacking sample 47/100 (True: 8, Index: 558)...
#   Success! Adv label: 2, L2: 855.44, Queries: 83
# Attacking sample 48/100 (True: 8, Index: 575)...
#   Success! Adv label: 9, L2: 480.99, Queries: 47
# Attacking sample 49/100 (True: 8, Index: 594)...
#   Success! Adv label: 2, L2: 415.99, Queries: 41
# Attacking sample 50/100 (True: 8, Index: 600)...
#   Success! Adv label: 3, L2: 1016.44, Queries: 99
# Attacking sample 51/100 (True: 8, Index: 605)...
#   Success! Adv label: 2, L2: 643.09, Queries: 61
# Attacking sample 52/100 (True: 8, Index: 619)...
#   Success! Adv label: 3, L2: 563.79, Queries: 57
# Attacking sample 53/100 (True: 8, Index: 625)...
#   Success! Adv label: 3, L2: 804.31, Queries: 73
# Attacking sample 54/100 (True: 8, Index: 629)...
#   Success! Adv label: 2, L2: 540.34, Queries: 49
# Attacking sample 55/100 (True: 8, Index: 645)...
#   Success! Adv label: 9, L2: 991.24, Queries: 97
# Attacking sample 56/100 (True: 8, Index: 652)...
#   Success! Adv label: 2, L2: 681.21, Queries: 69
# Attacking sample 57/100 (True: 8, Index: 672)...
#   Success! Adv label: 3, L2: 589.47, Queries: 63
# Attacking sample 58/100 (True: 8, Index: 683)...
#   Success! Adv label: 3, L2: 374.70, Queries: 41
# Attacking sample 59/100 (True: 8, Index: 701)...
#   Success! Adv label: 5, L2: 748.52, Queries: 77
# Attacking sample 60/100 (True: 8, Index: 714)...
#   Success! Adv label: 3, L2: 680.52, Queries: 71
# Attacking sample 61/100 (True: 8, Index: 721)...
#   Success! Adv label: 3, L2: 501.02, Queries: 49
# Attacking sample 62/100 (True: 8, Index: 730)...
#   Success! Adv label: 2, L2: 628.85, Queries: 57
# Attacking sample 63/100 (True: 8, Index: 731)...
#   Failed! Adv label: 8, L2: 1090.72, Queries: 201
# Attacking sample 64/100 (True: 8, Index: 738)...
#   Success! Adv label: 3, L2: 760.17, Queries: 83
# Attacking sample 65/100 (True: 8, Index: 791)...
#   Success! Adv label: 5, L2: 776.45, Queries: 79
# Attacking sample 66/100 (True: 8, Index: 832)...
#   Success! Adv label: 6, L2: 586.48, Queries: 55
# Attacking sample 67/100 (True: 8, Index: 838)...
#   Success! Adv label: 5, L2: 587.14, Queries: 59
# Attacking sample 68/100 (True: 8, Index: 860)...
#   Success! Adv label: 3, L2: 741.25, Queries: 77
# Attacking sample 69/100 (True: 8, Index: 864)...
#   Success! Adv label: 9, L2: 825.76, Queries: 87
# Attacking sample 70/100 (True: 8, Index: 889)...
#   Success! Adv label: 3, L2: 673.51, Queries: 69
# Attacking sample 71/100 (True: 8, Index: 905)...
#   Success! Adv label: 9, L2: 771.09, Queries: 81
# Attacking sample 73/100 (True: 8, Index: 919)...
#   Success! Adv label: 3, L2: 577.90, Queries: 57
# Attacking sample 74/100 (True: 8, Index: 923)...
#   Success! Adv label: 3, L2: 685.57, Queries: 69
# Attacking sample 75/100 (True: 8, Index: 926)...
#   Success! Adv label: 5, L2: 721.64, Queries: 69
# Attacking sample 76/100 (True: 8, Index: 933)...
#   Success! Adv label: 3, L2: 646.37, Queries: 65
# Attacking sample 78/100 (True: 8, Index: 971)...
#   Success! Adv label: 2, L2: 775.08, Queries: 77
# Attacking sample 79/100 (True: 8, Index: 1014)...
#   Success! Adv label: 3, L2: 587.24, Queries: 59
# Attacking sample 80/100 (True: 8, Index: 1034)...
#   Success! Adv label: 6, L2: 865.23, Queries: 93
# Attacking sample 81/100 (True: 8, Index: 1053)...
#   Success! Adv label: 6, L2: 619.45, Queries: 61
# Attacking sample 82/100 (True: 8, Index: 1057)...
#   Success! Adv label: 6, L2: 487.45, Queries: 41
# Attacking sample 83/100 (True: 8, Index: 1061)...
#   Success! Adv label: 1, L2: 953.74, Queries: 201
# Attacking sample 84/100 (True: 8, Index: 1062)...
#   Success! Adv label: 3, L2: 612.53, Queries: 63
# Attacking sample 85/100 (True: 8, Index: 1063)...
#   Success! Adv label: 3, L2: 655.65, Queries: 63
# Attacking sample 86/100 (True: 8, Index: 1078)...
#   Success! Adv label: 9, L2: 368.58, Queries: 31
# Attacking sample 87/100 (True: 8, Index: 1088)...
#   Success! Adv label: 2, L2: 757.16, Queries: 79
# Attacking sample 88/100 (True: 8, Index: 1100)...
#   Success! Adv label: 0, L2: 1068.61, Queries: 137
# Attacking sample 89/100 (True: 8, Index: 1106)...
#   Failed! Adv label: 8, L2: 1084.90, Queries: 201
# Attacking sample 90/100 (True: 8, Index: 1120)...
#   Success! Adv label: 3, L2: 554.41, Queries: 55
# Attacking sample 91/100 (True: 8, Index: 1132)...
#   Success! Adv label: 2, L2: 678.90, Queries: 65
# Attacking sample 92/100 (True: 8, Index: 1134)...
#   Failed! Adv label: 8, L2: 1162.33, Queries: 201
# Attacking sample 93/100 (True: 8, Index: 1140)...
#   Success! Adv label: 5, L2: 325.94, Queries: 31
# Attacking sample 94/100 (True: 8, Index: 1150)...
#   Success! Adv label: 9, L2: 604.16, Queries: 57
# Attacking sample 95/100 (True: 8, Index: 1165)...
#   Success! Adv label: 3, L2: 761.67, Queries: 73
# Attacking sample 96/100 (True: 8, Index: 1179)...
#   Success! Adv label: 9, L2: 660.95, Queries: 65
# Attacking sample 97/100 (True: 8, Index: 1182)...
#   Success! Adv label: 9, L2: 545.27, Queries: 51
# Attacking sample 98/100 (True: 8, Index: 1186)...
#   Success! Adv label: 2, L2: 813.82, Queries: 77
# Attacking sample 99/100 (True: 8, Index: 1189)...
#   Success! Adv label: 3, L2: 268.65, Queries: 27
# Attacking sample 100/100 (True: 8, Index: 1207)...
#   Success! Adv label: 9, L2: 703.23, Queries: 63
# Attacking sample 1/100 (True: 9, Index: 6)...
#   Success! Adv label: 7, L2: 356.52, Queries: 33
# Attacking sample 2/100 (True: 9, Index: 38)...
#   Success! Adv label: 7, L2: 74.38, Queries: 7
# Attacking sample 3/100 (True: 9, Index: 55)...
#   Success! Adv label: 0, L2: 161.53, Queries: 15
# Attacking sample 4/100 (True: 9, Index: 56)...
#   Success! Adv label: 4, L2: 470.22, Queries: 43
# Attacking sample 5/100 (True: 9, Index: 91)...
#   Success! Adv label: 3, L2: 312.99, Queries: 27
# Attacking sample 6/100 (True: 9, Index: 99)...
#   Success! Adv label: 7, L2: 477.87, Queries: 47
# Attacking sample 7/100 (True: 9, Index: 101)...
#   Success! Adv label: 5, L2: 744.03, Queries: 75
# Attacking sample 8/100 (True: 9, Index: 114)...
#   Success! Adv label: 8, L2: 723.92, Queries: 63
# Attacking sample 9/100 (True: 9, Index: 133)...
#   Success! Adv label: 8, L2: 689.96, Queries: 61
# Attacking sample 10/100 (True: 9, Index: 171)...
#   Success! Adv label: 8, L2: 102.25, Queries: 9
# Attacking sample 11/100 (True: 9, Index: 179)...
#   Success! Adv label: 7, L2: 686.21, Queries: 73
# Attacking sample 12/100 (True: 9, Index: 195)...
#   Success! Adv label: 1, L2: 234.38, Queries: 21
# Attacking sample 13/100 (True: 9, Index: 214)...
#   Success! Adv label: 4, L2: 525.54, Queries: 53
# Attacking sample 14/100 (True: 9, Index: 218)...
#   Success! Adv label: 4, L2: 388.65, Queries: 37
# Attacking sample 15/100 (True: 9, Index: 222)...
#   Success! Adv label: 8, L2: 415.80, Queries: 39
# Attacking sample 16/100 (True: 9, Index: 224)...
#   Success! Adv label: 6, L2: 570.08, Queries: 53
# Attacking sample 17/100 (True: 9, Index: 238)...
#   Success! Adv label: 4, L2: 490.69, Queries: 43
# Attacking sample 18/100 (True: 9, Index: 243)...
#   Success! Adv label: 8, L2: 708.42, Queries: 63
# Attacking sample 19/100 (True: 9, Index: 245)...
#   Success! Adv label: 4, L2: 555.29, Queries: 57
# Attacking sample 20/100 (True: 9, Index: 246)...
#   Success! Adv label: 8, L2: 676.68, Queries: 55
# Attacking sample 21/100 (True: 9, Index: 251)...
#   Success! Adv label: 7, L2: 289.18, Queries: 27
# Attacking sample 22/100 (True: 9, Index: 303)...
#   Success! Adv label: 4, L2: 302.65, Queries: 29
# Attacking sample 23/100 (True: 9, Index: 305)...
#   Success! Adv label: 8, L2: 281.90, Queries: 25
# Attacking sample 24/100 (True: 9, Index: 307)...
#   Success! Adv label: 4, L2: 664.68, Queries: 71
# Attacking sample 25/100 (True: 9, Index: 315)...
#   Success! Adv label: 8, L2: 729.78, Queries: 67
# Attacking sample 26/100 (True: 9, Index: 354)...
#   Success! Adv label: 4, L2: 581.77, Queries: 57
# Attacking sample 27/100 (True: 9, Index: 364)...
#   Success! Adv label: 8, L2: 698.20, Queries: 65
# Attacking sample 28/100 (True: 9, Index: 389)...
#   Success! Adv label: 4, L2: 355.57, Queries: 33
# Attacking sample 29/100 (True: 9, Index: 407)...
#   Success! Adv label: 8, L2: 273.88, Queries: 23
# Attacking sample 30/100 (True: 9, Index: 411)...
#   Success! Adv label: 4, L2: 221.70, Queries: 19
# Attacking sample 31/100 (True: 9, Index: 417)...
#   Success! Adv label: 7, L2: 424.08, Queries: 47
# Attacking sample 32/100 (True: 9, Index: 421)...
#   Success! Adv label: 4, L2: 457.04, Queries: 41
# Attacking sample 33/100 (True: 9, Index: 438)...
#   Success! Adv label: 4, L2: 470.62, Queries: 43
# Attacking sample 34/100 (True: 9, Index: 443)...
#   Success! Adv label: 8, L2: 666.16, Queries: 63
# Attacking sample 35/100 (True: 9, Index: 444)...
#   Success! Adv label: 4, L2: 336.87, Queries: 33
# Attacking sample 36/100 (True: 9, Index: 446)...
#   Success! Adv label: 7, L2: 617.03, Queries: 65
# Attacking sample 37/100 (True: 9, Index: 455)...
#   Success! Adv label: 7, L2: 341.87, Queries: 33
# Attacking sample 38/100 (True: 9, Index: 469)...
#   Success! Adv label: 4, L2: 981.29, Queries: 97
# Attacking sample 39/100 (True: 9, Index: 472)...
#   Success! Adv label: 3, L2: 850.91, Queries: 79
# Attacking sample 40/100 (True: 9, Index: 473)...
#   Success! Adv label: 4, L2: 767.08, Queries: 71
# Attacking sample 41/100 (True: 9, Index: 482)...
#   Success! Adv label: 4, L2: 495.14, Queries: 43
# Attacking sample 42/100 (True: 9, Index: 490)...
#   Success! Adv label: 8, L2: 867.78, Queries: 79
# Attacking sample 43/100 (True: 9, Index: 496)...
#   Success! Adv label: 4, L2: 477.21, Queries: 45
# Attacking sample 44/100 (True: 9, Index: 507)...
#   Success! Adv label: 8, L2: 439.07, Queries: 37
# Attacking sample 45/100 (True: 9, Index: 508)...
#   Success! Adv label: 7, L2: 502.34, Queries: 47
# Attacking sample 46/100 (True: 9, Index: 514)...
#   Success! Adv label: 4, L2: 229.91, Queries: 19
# Attacking sample 47/100 (True: 9, Index: 522)...
#   Success! Adv label: 4, L2: 78.25, Queries: 7
# Attacking sample 48/100 (True: 9, Index: 535)...
#   Success! Adv label: 4, L2: 511.75, Queries: 51
# Attacking sample 49/100 (True: 9, Index: 542)...
#   Success! Adv label: 8, L2: 446.62, Queries: 43
# Attacking sample 50/100 (True: 9, Index: 553)...
#   Success! Adv label: 4, L2: 703.05, Queries: 71
# Attacking sample 51/100 (True: 9, Index: 554)...
#   Success! Adv label: 7, L2: 851.58, Queries: 81
# Attacking sample 52/100 (True: 9, Index: 565)...
#   Success! Adv label: 0, L2: 457.37, Queries: 43
# Attacking sample 53/100 (True: 9, Index: 569)...
#   Success! Adv label: 4, L2: 520.72, Queries: 51
# Attacking sample 54/100 (True: 9, Index: 572)...
#   Success! Adv label: 5, L2: 398.02, Queries: 37
# Attacking sample 55/100 (True: 9, Index: 574)...
#   Success! Adv label: 8, L2: 426.72, Queries: 39
# Attacking sample 56/100 (True: 9, Index: 601)...
#   Success! Adv label: 8, L2: 396.58, Queries: 33
# Attacking sample 57/100 (True: 9, Index: 634)...
#   Success! Adv label: 5, L2: 462.74, Queries: 41
# Attacking sample 58/100 (True: 9, Index: 635)...
#   Success! Adv label: 4, L2: 655.15, Queries: 71
# Attacking sample 59/100 (True: 9, Index: 637)...
#   Success! Adv label: 4, L2: 596.77, Queries: 55
# Attacking sample 60/100 (True: 9, Index: 640)...
#   Success! Adv label: 4, L2: 585.44, Queries: 55
# Attacking sample 61/100 (True: 9, Index: 653)...
#   Success! Adv label: 8, L2: 642.59, Queries: 55
# Attacking sample 62/100 (True: 9, Index: 654)...
#   Success! Adv label: 4, L2: 578.01, Queries: 55
# Attacking sample 63/100 (True: 9, Index: 656)...
#   Success! Adv label: 4, L2: 643.48, Queries: 61
# Attacking sample 64/100 (True: 9, Index: 666)...
#   Success! Adv label: 4, L2: 468.64, Queries: 47
# Attacking sample 65/100 (True: 9, Index: 685)...
#   Success! Adv label: 7, L2: 695.91, Queries: 73
# Attacking sample 66/100 (True: 9, Index: 711)...
#   Success! Adv label: 4, L2: 258.53, Queries: 23
# Attacking sample 67/100 (True: 9, Index: 729)...
#   Success! Adv label: 8, L2: 531.89, Queries: 47
# Attacking sample 68/100 (True: 9, Index: 739)...
#   Success! Adv label: 4, L2: 470.86, Queries: 45
# Attacking sample 69/100 (True: 9, Index: 747)...
#   Success! Adv label: 8, L2: 416.59, Queries: 37
# Attacking sample 70/100 (True: 9, Index: 767)...
#   Success! Adv label: 8, L2: 482.24, Queries: 43
# Attacking sample 71/100 (True: 9, Index: 783)...
#   Success! Adv label: 5, L2: 621.22, Queries: 63
# Attacking sample 72/100 (True: 9, Index: 787)...
#   Success! Adv label: 8, L2: 618.41, Queries: 51
# Attacking sample 73/100 (True: 9, Index: 796)...
#   Success! Adv label: 7, L2: 461.75, Queries: 43
# Attacking sample 74/100 (True: 9, Index: 804)...
#   Success! Adv label: 7, L2: 671.64, Queries: 73
# Attacking sample 75/100 (True: 9, Index: 818)...
#   Success! Adv label: 4, L2: 661.86, Queries: 69
# Attacking sample 76/100 (True: 9, Index: 825)...
#   Success! Adv label: 8, L2: 374.54, Queries: 33
# Attacking sample 77/100 (True: 9, Index: 826)...
#   Success! Adv label: 1, L2: 179.51, Queries: 17
# Attacking sample 78/100 (True: 9, Index: 831)...
#   Success! Adv label: 4, L2: 547.42, Queries: 49
# Attacking sample 79/100 (True: 9, Index: 880)...
#   Success! Adv label: 5, L2: 622.06, Queries: 55
# Attacking sample 80/100 (True: 9, Index: 884)...
#   Success! Adv label: 4, L2: 512.77, Queries: 47
# Attacking sample 81/100 (True: 9, Index: 891)...
#   Success! Adv label: 4, L2: 135.61, Queries: 13
# Attacking sample 82/100 (True: 9, Index: 893)...
#   Success! Adv label: 2, L2: 713.88, Queries: 75
# Attacking sample 83/100 (True: 9, Index: 899)...
#   Success! Adv label: 4, L2: 496.36, Queries: 49
# Attacking sample 84/100 (True: 9, Index: 912)...
#   Success! Adv label: 5, L2: 607.35, Queries: 53
# Attacking sample 85/100 (True: 9, Index: 920)...
#   Success! Adv label: 4, L2: 643.87, Queries: 61
# Attacking sample 86/100 (True: 9, Index: 925)...
#   Success! Adv label: 8, L2: 397.77, Queries: 33
# Attacking sample 87/100 (True: 9, Index: 940)...
#   Success! Adv label: 4, L2: 382.15, Queries: 39
# Attacking sample 88/100 (True: 9, Index: 958)...
#   Success! Adv label: 4, L2: 531.54, Queries: 47
# Attacking sample 89/100 (True: 9, Index: 969)...
#   Success! Adv label: 8, L2: 415.50, Queries: 35
# Attacking sample 90/100 (True: 9, Index: 978)...
#   Success! Adv label: 4, L2: 530.41, Queries: 53
# Attacking sample 91/100 (True: 9, Index: 979)...
#   Success! Adv label: 4, L2: 438.61, Queries: 39
# Attacking sample 92/100 (True: 9, Index: 980)...
#   Success! Adv label: 8, L2: 369.77, Queries: 35
# Attacking sample 93/100 (True: 9, Index: 991)...
#   Success! Adv label: 7, L2: 558.04, Queries: 59
# Attacking sample 94/100 (True: 9, Index: 997)...
#   Success! Adv label: 4, L2: 257.93, Queries: 25
# Attacking sample 95/100 (True: 9, Index: 1006)...
#   Success! Adv label: 7, L2: 574.52, Queries: 61
# Attacking sample 96/100 (True: 9, Index: 1011)...
#   Success! Adv label: 4, L2: 832.06, Queries: 83
# Attacking sample 97/100 (True: 9, Index: 1020)...
#   Success! Adv label: 8, L2: 516.48, Queries: 49
# Attacking sample 98/100 (True: 9, Index: 1023)...
#   Success! Adv label: 4, L2: 839.44, Queries: 85
# Attacking sample 99/100 (True: 9, Index: 1042)...
#   Success! Adv label: 4, L2: 347.11, Queries: 29
# Attacking sample 100/100 (True: 9, Index: 1046)...
#   Success! Adv label: 4, L2: 385.65, Queries: 37
# Time taken to generate adversarial samples: 119.5493 seconds
#
# Stats saved to: adversarial_8bit_K140_test_images\per_sample_stats.csv
#
# ===== Attack Summary =====
# Total trials: 986
# Misclassified before attack: 14
# Success rate: 949/986 (96.2%)
# Mean L2 (successful): 584.70
# Mean queries (successful): 55.16
#
# Showing successful adversarial examples...

# %% [markdown]
# ### Untargeted Attack on test set; k=150

# %%
import os
import warnings
import numpy as np
import torch
import joblib
import pandas as pd
from PIL import Image
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import torch.nn.functional as F
import time


# Set seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# ─────────────── PATHS ────────────────────────────────────────────────────
LENET_MODEL_PATH = os.path.normpath("Models and Data splits/lenet.pt")  # TorchScript model
DATA_PKL = os.path.normpath("Models and Data splits/data_[SCALED] Train_Test_Splits.pkl")
RF_ALL_CLASSES_PATH = os.path.normpath("Models and Data splits/random_forest.pkl")
OUT_DIR = "adversarial_8bit_K150_test_images"
os.makedirs(OUT_DIR, exist_ok=True)

if not os.path.exists(RF_ALL_CLASSES_PATH):
    raise FileNotFoundError(f"Random Forest model not found at {RF_ALL_CLASSES_PATH}")

# ─────────── HYPER-PARAMETERS ─────────────────────────────────────────────
EPSILON_STEP = 0.01
ITERATIONS = 100
TOTAL_EPSILON = 0.5
TOP_K_FEATURES = 150
SAMPLES_PER_DIGIT = 100
MAX_L2 = 10000

def plot_adversarial_example(original_img, adv_img, true_label, adv_label, l2_mag, sample_idx, queries, title_suffix=""):
    if original_img.size == 784:
        original_img = original_img.reshape(28, 28)
    if adv_img.size == 784:
        adv_img = adv_img.reshape(28, 28)
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(original_img, cmap='gray')
    axes[0].set_title(f"Original\nTrue: {true_label}")
    axes[0].axis('off')
    axes[1].imshow(adv_img, cmap='gray')
    axes[1].set_title(f"Adversarial\nPred: {adv_label}")
    axes[1].axis('off')
    fig.suptitle(f"Sample {sample_idx} | L2: {l2_mag:.2f} | Queries: {queries} {title_suffix}")
    plt.show()
    plt.close(fig)  # <-- added here


# ─────────── Load Data ─────────────────────────────────────────────────────
try:
    data = joblib.load(DATA_PKL)
    _, X_samples , _, y_samples = data
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PKL}. Please check the path.")
    exit()

if X_samples.max() > 1.0:
    X_samples = X_samples.astype(np.float32) / 255.0
    warnings.warn("Data appeared in [0,255]; normalized to [0,1].")

# ─────────── Load TorchScripted LeNet ──────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
try:
    model = torch.jit.load(LENET_MODEL_PATH, map_location=device)
    model.eval()
    print(f"LeNet TorchScript model loaded from: {LENET_MODEL_PATH}")
except Exception as e:
    print(f"Error loading TorchScript LeNet model: {e}")
    exit()

def to_model(x01_batch):
    if x01_batch.ndim == 2 and x01_batch.shape == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)
    elif x01_batch.ndim == 3 and x01_batch.shape[1:] == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(1)
    elif x01_batch.ndim == 4 and x01_batch.shape[1] == 1:
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device)
    elif x01_batch.ndim == 1 and x01_batch.size == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(1, 1, 28, 28), dtype=torch.float32, device=device)
    elif x01_batch.ndim == 2 and x01_batch.shape[1] == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(x01_batch.shape[0], 1, 28, 28), dtype=torch.float32, device=device)
    else:
        raise ValueError(f"Unsupported input shape for to_model: {x01_batch.shape}")
    return tensor_batch


def model_query(x_tensor_batch):
    with torch.no_grad():
        return model(x_tensor_batch)

# ─────────── Load Random Forest Model ──────────────────────────────────────
rf_all_classes = None
top_feature_indices = None
print("Loading Random Forest Classifier for all classes...")
try:
    rf_all_classes = joblib.load(RF_ALL_CLASSES_PATH)
    feature_importances = rf_all_classes.feature_importances_
    #top_feature_indices = np.argsort(feature_importances)[:TOP_K_FEATURES]
    
    top_feature_indices = np.argsort(-feature_importances)[:TOP_K_FEATURES]
    print(f"Random Forest loaded. Using top {TOP_K_FEATURES} features.")
except Exception as e:
    print(f"Error loading Random Forest: {e}")
    top_feature_indices = np.arange(28 * 28)

# ─────────── I-FGSM Attack ─────────────────────────────────────────────────
def ifgsm_attack(original_image_np, true_label, model_target, epsilon_step, iterations,
                 total_epsilon_budget, features_to_perturb, query_count_tracker):
    if original_image_np.ndim == 1 and original_image_np.size == 784:
        original_image_np = original_image_np.reshape(28, 28)

    perturbed_image_np = original_image_np.copy()
    final_pred_label = true_label

    for i in range(iterations):
        image_tensor = to_model(perturbed_image_np)
        image_tensor.requires_grad = True
        output = model_target(image_tensor)
        query_count_tracker[0] += 1
        loss = F.cross_entropy(output, torch.tensor([true_label], device=device))
        model_target.zero_grad()
        loss.backward()
        data_grad_sign = torch.sign(image_tensor.grad.data).cpu().numpy()

        gradient_mask = np.zeros_like(data_grad_sign, dtype=np.float32)
        h, w = perturbed_image_np.shape
        rows, cols = np.unravel_index(features_to_perturb, (h, w))
        gradient_mask[0, 0, rows, cols] = data_grad_sign[0, 0, rows, cols]
        gradient_mask_for_update = gradient_mask.reshape(perturbed_image_np.shape)

        perturbed_image_np += epsilon_step * gradient_mask_for_update
        perturbation = perturbed_image_np - original_image_np
        perturbation = np.clip(perturbation, -total_epsilon_budget, total_epsilon_budget)
        perturbed_image_np = original_image_np + perturbation
        perturbed_image_np = np.clip(perturbed_image_np, 0, 1)

        # Discretize and check prediction on discretized image
        adv_uint8_temp = np.round(perturbed_image_np * 255).astype(np.uint8)
        adv_float_temp = adv_uint8_temp.astype(np.float32) / 255.0
        with torch.no_grad():
            output_temp = model_target(to_model(adv_float_temp))
            pred_temp = output_temp.argmax(dim=1).item()
            query_count_tracker[0] += 1

        if pred_temp != true_label:
            final_pred_label = pred_temp
            break

    # Final adversarial image (discretized)
    adv_uint8 = np.round(perturbed_image_np * 255).astype(np.uint8)
    adv_float = adv_uint8.astype(np.float32) / 255.0
    with torch.no_grad():
        output_final = model_target(to_model(adv_float))
        final_pred_label = output_final.argmax(dim=1).item()

    l2_norm = np.linalg.norm(adv_uint8.astype(np.float32) - (original_image_np * 255).astype(np.float32))
    success = (final_pred_label != true_label) and (l2_norm <= MAX_L2)

    return adv_uint8, final_pred_label, l2_norm, success


# ─────────── Attack Execution ──────────────────────────────────────────────
print(f"\n===== Starting Adversarial Attack =====")
total_trials, succ_total, misclassified = 0, 0, 0
records = []


start_time = time.time()


for digit in range(10):
    idxs = np.where(y_samples == digit)[0][:SAMPLES_PER_DIGIT]
    for rank, idx in enumerate(idxs, 1):
        x0 = X_samples[idx].copy()
        y0 = int(y_samples[idx])
        query_count_tracker = [0]
        pred0 = model_query(to_model(x0)).argmax(dim=1).item()
        query_count_tracker[0] += 1

        if pred0 != y0:
            misclassified += 1
            records.append({
                'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
                'adv_label': None, 'success': False, 'queries': query_count_tracker[0],
                'l2_mag': np.nan, 'note': 'Already misclassified'
            })
            continue

        total_trials += 1
        print(f"Attacking sample {rank}/{SAMPLES_PER_DIGIT} (True: {y0}, Index: {idx})...")
        adv_img_uint8, adv_label, l2_mag, success = ifgsm_attack(
            x0, y0, model, EPSILON_STEP, ITERATIONS, TOTAL_EPSILON,
            top_feature_indices, query_count_tracker
        )

        if success:
            succ_total += 1
            fname = f"true{y0}_adv{adv_label}_mag{l2_mag:.1f}_sample{idx}.png"
            Image.fromarray(adv_img_uint8, mode="L").save(os.path.join(OUT_DIR, fname))

        records.append({
            'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
            'adv_label': adv_label, 'success': success, 'queries': query_count_tracker[0],
            'l2_mag': l2_mag if success else np.nan, 'note': 'I-FGSM' + (' successful' if success else ' failed')
        })

        print(f"  {'Success' if success else 'Failed'}! Adv label: {adv_label}, L2: {l2_mag:.2f}, Queries: {query_count_tracker[0]}")


end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to generate adversarial samples: {elapsed_time:.4f} seconds")


# ─────────── Save Results ──────────────────────────────────────────────────
df = pd.DataFrame(records)
csv_path = os.path.join(OUT_DIR, "per_sample_stats.csv")
df.to_csv(csv_path, index=False)
print(f"\nStats saved to: {csv_path}")

# ─────────── Summary ───────────────────────────────────────────────────────
print(f"\n===== Attack Summary =====")
print(f"Total trials: {total_trials}")
print(f"Misclassified before attack: {misclassified}")
if total_trials > 0:
    success_rate = succ_total / total_trials * 100
    print(f"Success rate: {succ_total}/{total_trials} ({success_rate:.1f}%)")
    if succ_total > 0:
        print(f"Mean L2 (successful): {df[df['success']]['l2_mag'].mean():.2f}")
        print(f"Mean queries (successful): {df[df['success']]['queries'].mean():.2f}")

# ─────────── Display Examples ──────────────────────────────────────────────
success_df = df[df['success']]
if not success_df.empty:
    print("\nShowing successful adversarial examples...")
    show_ids = success_df.sample(min(3, len(success_df))).index.tolist()
    for record_idx in show_ids:
        r = df.loc[record_idx]
        fname_prefix = f"true{r['true_label']}_adv{r['adv_label']}_mag{r['l2_mag']:.1f}_sample{r['sample_idx']}"
        match_files = [f for f in os.listdir(OUT_DIR) if f.startswith(fname_prefix)]
        if match_files:
            adv_img_path = os.path.join(OUT_DIR, match_files[0])
            plot_adversarial_example(X_samples[r['sample_idx']], np.array(Image.open(adv_img_path)),
                                     r['true_label'], r['adv_label'], r['l2_mag'],
                                     r['sample_idx'], r['queries'], "(I-FGSM)")
else:
    print("No successful attacks to display. Showing original samples instead.")
    for i in range(min(3, len(df))):
        r = df.iloc[i]
        plot_adversarial_example(X_samples[r['sample_idx']], X_samples[r['sample_idx']],
                                 r['true_label'], r['initial_pred'], 0.0,
                                 r['sample_idx'], r['queries'], "(Original)")
# Out:
# LeNet TorchScript model loaded from: Models and Data splits\lenet.pt
# Loading Random Forest Classifier for all classes...
# Random Forest loaded. Using top 150 features.
#
# ===== Starting Adversarial Attack =====
# Attacking sample 1/100 (True: 0, Index: 29)...
#   Success! Adv label: 6, L2: 953.80, Queries: 93
# Attacking sample 2/100 (True: 0, Index: 40)...
#   Failed! Adv label: 0, L2: 1136.96, Queries: 201
# Attacking sample 3/100 (True: 0, Index: 44)...
#   Success! Adv label: 5, L2: 635.38, Queries: 59
# Attacking sample 4/100 (True: 0, Index: 59)...
#   Success! Adv label: 6, L2: 678.69, Queries: 63
# Attacking sample 5/100 (True: 0, Index: 64)...
#   Failed! Adv label: 0, L2: 1218.74, Queries: 201
# Attacking sample 6/100 (True: 0, Index: 75)...
#   Success! Adv label: 8, L2: 714.30, Queries: 69
# Attacking sample 7/100 (True: 0, Index: 80)...
#   Success! Adv label: 9, L2: 688.46, Queries: 67
# Attacking sample 8/100 (True: 0, Index: 97)...
#   Success! Adv label: 6, L2: 779.93, Queries: 77
# Attacking sample 9/100 (True: 0, Index: 115)...
#   Success! Adv label: 6, L2: 844.37, Queries: 79
# Attacking sample 10/100 (True: 0, Index: 141)...
#   Success! Adv label: 7, L2: 205.25, Queries: 19
# Attacking sample 11/100 (True: 0, Index: 146)...
#   Success! Adv label: 9, L2: 720.12, Queries: 73
# Attacking sample 12/100 (True: 0, Index: 156)...
#   Failed! Adv label: 0, L2: 1014.82, Queries: 201
# Attacking sample 13/100 (True: 0, Index: 173)...
#   Success! Adv label: 6, L2: 660.59, Queries: 75
# Attacking sample 14/100 (True: 0, Index: 175)...
#   Success! Adv label: 8, L2: 487.72, Queries: 45
# Attacking sample 15/100 (True: 0, Index: 193)...
#   Success! Adv label: 9, L2: 926.08, Queries: 115
# Attacking sample 16/100 (True: 0, Index: 200)...
#   Success! Adv label: 9, L2: 723.24, Queries: 73
# Attacking sample 17/100 (True: 0, Index: 205)...
#   Success! Adv label: 9, L2: 835.23, Queries: 83
# Attacking sample 18/100 (True: 0, Index: 210)...
#   Success! Adv label: 8, L2: 770.90, Queries: 75
# Attacking sample 19/100 (True: 0, Index: 221)...
#   Success! Adv label: 3, L2: 870.95, Queries: 77
# Attacking sample 20/100 (True: 0, Index: 229)...
#   Failed! Adv label: 0, L2: 957.80, Queries: 201
# Attacking sample 21/100 (True: 0, Index: 249)...
#   Success! Adv label: 5, L2: 818.08, Queries: 95
# Attacking sample 22/100 (True: 0, Index: 258)...
#   Success! Adv label: 2, L2: 898.01, Queries: 87
# Attacking sample 23/100 (True: 0, Index: 275)...
#   Success! Adv label: 8, L2: 1103.69, Queries: 169
# Attacking sample 24/100 (True: 0, Index: 292)...
#   Failed! Adv label: 0, L2: 947.25, Queries: 201
# Attacking sample 25/100 (True: 0, Index: 296)...
#   Success! Adv label: 9, L2: 688.96, Queries: 65
# Attacking sample 26/100 (True: 0, Index: 301)...
#   Success! Adv label: 9, L2: 643.74, Queries: 59
# Attacking sample 27/100 (True: 0, Index: 314)...
#   Success! Adv label: 9, L2: 698.67, Queries: 61
# Attacking sample 28/100 (True: 0, Index: 325)...
#   Success! Adv label: 9, L2: 1036.49, Queries: 121
# Attacking sample 29/100 (True: 0, Index: 333)...
#   Success! Adv label: 9, L2: 848.47, Queries: 89
# Attacking sample 30/100 (True: 0, Index: 345)...
#   Success! Adv label: 6, L2: 661.71, Queries: 59
# Attacking sample 31/100 (True: 0, Index: 349)...
#   Success! Adv label: 9, L2: 663.16, Queries: 61
# Attacking sample 32/100 (True: 0, Index: 360)...
#   Failed! Adv label: 0, L2: 1140.20, Queries: 201
# Attacking sample 33/100 (True: 0, Index: 365)...
#   Success! Adv label: 9, L2: 1004.04, Queries: 107
# Attacking sample 34/100 (True: 0, Index: 366)...
#   Success! Adv label: 9, L2: 824.77, Queries: 79
# Attacking sample 35/100 (True: 0, Index: 379)...
#   Success! Adv label: 8, L2: 950.54, Queries: 89
# Attacking sample 36/100 (True: 0, Index: 385)...
#   Failed! Adv label: 0, L2: 1040.12, Queries: 201
# Attacking sample 37/100 (True: 0, Index: 397)...
#   Failed! Adv label: 0, L2: 955.25, Queries: 201
# Attacking sample 38/100 (True: 0, Index: 400)...
#   Failed! Adv label: 0, L2: 1152.76, Queries: 201
# Attacking sample 39/100 (True: 0, Index: 405)...
#   Success! Adv label: 2, L2: 779.51, Queries: 69
# Attacking sample 40/100 (True: 0, Index: 410)...
#   Success! Adv label: 9, L2: 823.79, Queries: 79
# Attacking sample 41/100 (True: 0, Index: 420)...
#   Success! Adv label: 2, L2: 841.48, Queries: 91
# Attacking sample 42/100 (True: 0, Index: 424)...
#   Failed! Adv label: 0, L2: 1081.49, Queries: 201
# Attacking sample 43/100 (True: 0, Index: 447)...
#   Success! Adv label: 2, L2: 716.76, Queries: 69
# Attacking sample 44/100 (True: 0, Index: 453)...
#   Success! Adv label: 6, L2: 938.50, Queries: 91
# Attacking sample 45/100 (True: 0, Index: 457)...
#   Success! Adv label: 6, L2: 1007.53, Queries: 95
# Attacking sample 46/100 (True: 0, Index: 466)...
#   Success! Adv label: 2, L2: 825.83, Queries: 83
# Attacking sample 47/100 (True: 0, Index: 475)...
#   Success! Adv label: 9, L2: 250.41, Queries: 23
# Attacking sample 48/100 (True: 0, Index: 483)...
#   Success! Adv label: 2, L2: 937.59, Queries: 95
# Attacking sample 49/100 (True: 0, Index: 484)...
#   Success! Adv label: 8, L2: 469.13, Queries: 37
# Attacking sample 50/100 (True: 0, Index: 486)...
#   Failed! Adv label: 0, L2: 1040.53, Queries: 201
# Attacking sample 51/100 (True: 0, Index: 487)...
#   Success! Adv label: 6, L2: 661.70, Queries: 61
# Attacking sample 52/100 (True: 0, Index: 489)...
#   Success! Adv label: 9, L2: 721.84, Queries: 69
# Attacking sample 53/100 (True: 0, Index: 492)...
#   Success! Adv label: 9, L2: 738.09, Queries: 69
# Attacking sample 54/100 (True: 0, Index: 506)...
#   Success! Adv label: 2, L2: 919.60, Queries: 81
# Attacking sample 55/100 (True: 0, Index: 513)...
#   Failed! Adv label: 0, L2: 1111.80, Queries: 201
# Attacking sample 56/100 (True: 0, Index: 518)...
#   Success! Adv label: 5, L2: 1021.29, Queries: 127
# Attacking sample 57/100 (True: 0, Index: 521)...
#   Failed! Adv label: 0, L2: 1126.42, Queries: 201
# Attacking sample 58/100 (True: 0, Index: 527)...
#   Success! Adv label: 2, L2: 740.70, Queries: 71
# Attacking sample 59/100 (True: 0, Index: 529)...
#   Success! Adv label: 5, L2: 872.71, Queries: 105
# Attacking sample 60/100 (True: 0, Index: 531)...
#   Failed! Adv label: 0, L2: 1084.99, Queries: 201
# Attacking sample 61/100 (True: 0, Index: 546)...
#   Success! Adv label: 9, L2: 662.51, Queries: 67
# Attacking sample 62/100 (True: 0, Index: 551)...
#   Success! Adv label: 6, L2: 409.06, Queries: 33
# Attacking sample 63/100 (True: 0, Index: 555)...
#   Success! Adv label: 8, L2: 990.48, Queries: 87
# Attacking sample 64/100 (True: 0, Index: 587)...
#   Success! Adv label: 2, L2: 902.32, Queries: 91
# Attacking sample 65/100 (True: 0, Index: 604)...
#   Success! Adv label: 8, L2: 711.86, Queries: 61
# Attacking sample 66/100 (True: 0, Index: 614)...
#   Success! Adv label: 8, L2: 863.54, Queries: 83
# Attacking sample 67/100 (True: 0, Index: 615)...
#   Success! Adv label: 9, L2: 460.65, Queries: 39
# Attacking sample 68/100 (True: 0, Index: 618)...
#   Success! Adv label: 6, L2: 340.09, Queries: 29
# Attacking sample 69/100 (True: 0, Index: 638)...
#   Success! Adv label: 8, L2: 447.32, Queries: 37
# Attacking sample 70/100 (True: 0, Index: 642)...
#   Success! Adv label: 9, L2: 904.89, Queries: 95
# Attacking sample 71/100 (True: 0, Index: 655)...
#   Success! Adv label: 6, L2: 814.63, Queries: 71
# Attacking sample 72/100 (True: 0, Index: 658)...
#   Success! Adv label: 6, L2: 712.17, Queries: 63
# Attacking sample 73/100 (True: 0, Index: 665)...
#   Success! Adv label: 2, L2: 699.83, Queries: 65
# Attacking sample 74/100 (True: 0, Index: 671)...
#   Success! Adv label: 6, L2: 747.27, Queries: 67
# Attacking sample 75/100 (True: 0, Index: 681)...
#   Success! Adv label: 9, L2: 937.99, Queries: 93
# Attacking sample 76/100 (True: 0, Index: 691)...
#   Success! Adv label: 2, L2: 739.61, Queries: 65
# Attacking sample 77/100 (True: 0, Index: 700)...
#   Success! Adv label: 5, L2: 594.40, Queries: 55
# Attacking sample 78/100 (True: 0, Index: 706)...
#   Failed! Adv label: 0, L2: 926.85, Queries: 201
# Attacking sample 79/100 (True: 0, Index: 712)...
#   Failed! Adv label: 0, L2: 1058.00, Queries: 201
# Attacking sample 80/100 (True: 0, Index: 713)...
#   Success! Adv label: 9, L2: 762.30, Queries: 69
# Attacking sample 81/100 (True: 0, Index: 736)...
#   Success! Adv label: 5, L2: 694.81, Queries: 73
# Attacking sample 82/100 (True: 0, Index: 742)...
#   Success! Adv label: 8, L2: 731.05, Queries: 73
# Attacking sample 83/100 (True: 0, Index: 744)...
#   Success! Adv label: 2, L2: 597.22, Queries: 57
# Attacking sample 84/100 (True: 0, Index: 760)...
#   Success! Adv label: 9, L2: 645.03, Queries: 63
# Attacking sample 85/100 (True: 0, Index: 772)...
#   Success! Adv label: 9, L2: 321.69, Queries: 27
# Attacking sample 86/100 (True: 0, Index: 781)...
#   Success! Adv label: 6, L2: 504.19, Queries: 45
# Attacking sample 87/100 (True: 0, Index: 809)...
#   Success! Adv label: 5, L2: 785.96, Queries: 85
# Attacking sample 88/100 (True: 0, Index: 813)...
#   Success! Adv label: 9, L2: 519.29, Queries: 49
# Attacking sample 89/100 (True: 0, Index: 820)...
#   Success! Adv label: 9, L2: 745.40, Queries: 77
# Attacking sample 90/100 (True: 0, Index: 823)...
#   Success! Adv label: 5, L2: 741.20, Queries: 77
# Attacking sample 91/100 (True: 0, Index: 844)...
#   Success! Adv label: 6, L2: 928.05, Queries: 123
# Attacking sample 92/100 (True: 0, Index: 848)...
#   Success! Adv label: 9, L2: 314.46, Queries: 27
# Attacking sample 93/100 (True: 0, Index: 861)...
#   Success! Adv label: 6, L2: 1016.82, Queries: 85
# Attacking sample 94/100 (True: 0, Index: 865)...
#   Success! Adv label: 6, L2: 1261.29, Queries: 167
# Attacking sample 95/100 (True: 0, Index: 869)...
#   Success! Adv label: 6, L2: 1054.42, Queries: 101
# Attacking sample 96/100 (True: 0, Index: 876)...
#   Success! Adv label: 9, L2: 703.65, Queries: 63
# Attacking sample 97/100 (True: 0, Index: 885)...
#   Failed! Adv label: 0, L2: 1082.27, Queries: 201
# Attacking sample 98/100 (True: 0, Index: 906)...
#   Success! Adv label: 3, L2: 1003.12, Queries: 105
# Attacking sample 99/100 (True: 0, Index: 907)...
#   Success! Adv label: 9, L2: 947.23, Queries: 93
# Attacking sample 100/100 (True: 0, Index: 918)...
#   Success! Adv label: 9, L2: 1065.67, Queries: 121
# Attacking sample 1/100 (True: 1, Index: 2)...
#   Success! Adv label: 7, L2: 322.54, Queries: 25
# Attacking sample 2/100 (True: 1, Index: 3)...
#   Success! Adv label: 7, L2: 375.22, Queries: 29
# Attacking sample 3/100 (True: 1, Index: 9)...
#   Success! Adv label: 2, L2: 356.88, Queries: 31
# Attacking sample 4/100 (True: 1, Index: 25)...
#   Success! Adv label: 4, L2: 360.30, Queries: 27
# Attacking sample 5/100 (True: 1, Index: 36)...
#   Success! Adv label: 2, L2: 318.90, Queries: 25
# Attacking sample 6/100 (True: 1, Index: 63)...
#   Success! Adv label: 8, L2: 303.90, Queries: 25
# Attacking sample 7/100 (True: 1, Index: 65)...
#   Success! Adv label: 8, L2: 355.80, Queries: 27
# Attacking sample 8/100 (True: 1, Index: 68)...
#   Success! Adv label: 4, L2: 407.54, Queries: 31
# Attacking sample 9/100 (True: 1, Index: 76)...
#   Success! Adv label: 8, L2: 232.45, Queries: 19
# Attacking sample 10/100 (True: 1, Index: 83)...
#   Success! Adv label: 4, L2: 384.37, Queries: 31
# Attacking sample 11/100 (True: 1, Index: 90)...
#   Success! Adv label: 9, L2: 30.72, Queries: 3
# Attacking sample 12/100 (True: 1, Index: 94)...
#   Success! Adv label: 8, L2: 211.68, Queries: 17
# Attacking sample 13/100 (True: 1, Index: 100)...
#   Success! Adv label: 8, L2: 261.68, Queries: 21
# Attacking sample 14/100 (True: 1, Index: 123)...
#   Success! Adv label: 8, L2: 206.24, Queries: 17
# Attacking sample 15/100 (True: 1, Index: 150)...
#   Success! Adv label: 8, L2: 360.94, Queries: 27
# Attacking sample 16/100 (True: 1, Index: 152)...
#   Success! Adv label: 9, L2: 363.52, Queries: 29
# Attacking sample 17/100 (True: 1, Index: 178)...
#   Success! Adv label: 4, L2: 350.60, Queries: 27
# Attacking sample 18/100 (True: 1, Index: 185)...
#   Success! Adv label: 8, L2: 379.31, Queries: 33
# Attacking sample 19/100 (True: 1, Index: 191)...
#   Success! Adv label: 4, L2: 447.85, Queries: 33
# Attacking sample 20/100 (True: 1, Index: 201)...
#   Success! Adv label: 8, L2: 332.02, Queries: 25
# Attacking sample 21/100 (True: 1, Index: 203)...
#   Success! Adv label: 8, L2: 306.18, Queries: 23
# Attacking sample 22/100 (True: 1, Index: 213)...
#   Success! Adv label: 8, L2: 318.80, Queries: 25
# Attacking sample 23/100 (True: 1, Index: 220)...
#   Success! Adv label: 8, L2: 268.95, Queries: 21
# Attacking sample 24/100 (True: 1, Index: 223)...
#   Success! Adv label: 4, L2: 377.22, Queries: 29
# Attacking sample 25/100 (True: 1, Index: 226)...
#   Success! Adv label: 4, L2: 352.59, Queries: 27
# Attacking sample 26/100 (True: 1, Index: 232)...
#   Success! Adv label: 4, L2: 442.07, Queries: 33
# Attacking sample 27/100 (True: 1, Index: 241)...
#   Success! Adv label: 4, L2: 290.33, Queries: 23
# Attacking sample 28/100 (True: 1, Index: 254)...
#   Success! Adv label: 8, L2: 334.28, Queries: 25
# Attacking sample 29/100 (True: 1, Index: 281)...
#   Success! Adv label: 8, L2: 284.81, Queries: 23
# Attacking sample 30/100 (True: 1, Index: 284)...
#   Success! Adv label: 8, L2: 326.40, Queries: 27
# Attacking sample 31/100 (True: 1, Index: 285)...
#   Success! Adv label: 9, L2: 236.52, Queries: 19
# Attacking sample 32/100 (True: 1, Index: 286)...
#   Success! Adv label: 4, L2: 328.56, Queries: 25
# Attacking sample 33/100 (True: 1, Index: 287)...
#   Success! Adv label: 4, L2: 333.27, Queries: 27
# Attacking sample 34/100 (True: 1, Index: 294)...
#   Success! Adv label: 4, L2: 377.79, Queries: 29
# Attacking sample 35/100 (True: 1, Index: 298)...
#   Success! Adv label: 9, L2: 495.54, Queries: 37
# Attacking sample 36/100 (True: 1, Index: 306)...
#   Success! Adv label: 4, L2: 403.84, Queries: 31
# Attacking sample 37/100 (True: 1, Index: 312)...
#   Success! Adv label: 8, L2: 364.82, Queries: 31
# Attacking sample 38/100 (True: 1, Index: 317)...
#   Success! Adv label: 4, L2: 362.12, Queries: 29
# Attacking sample 39/100 (True: 1, Index: 334)...
#   Success! Adv label: 4, L2: 389.61, Queries: 29
# Attacking sample 40/100 (True: 1, Index: 337)...
#   Success! Adv label: 8, L2: 408.19, Queries: 31
# Attacking sample 41/100 (True: 1, Index: 338)...
#   Success! Adv label: 8, L2: 498.29, Queries: 37
# Attacking sample 42/100 (True: 1, Index: 348)...
#   Success! Adv label: 2, L2: 493.77, Queries: 39
# Attacking sample 43/100 (True: 1, Index: 361)...
#   Success! Adv label: 9, L2: 297.71, Queries: 23
# Attacking sample 44/100 (True: 1, Index: 363)...
#   Success! Adv label: 8, L2: 387.70, Queries: 29
# Attacking sample 45/100 (True: 1, Index: 367)...
#   Success! Adv label: 8, L2: 212.94, Queries: 17
# Attacking sample 46/100 (True: 1, Index: 375)...
#   Success! Adv label: 7, L2: 444.23, Queries: 35
# Attacking sample 47/100 (True: 1, Index: 384)...
#   Success! Adv label: 8, L2: 296.16, Queries: 23
# Attacking sample 48/100 (True: 1, Index: 412)...
#   Success! Adv label: 8, L2: 450.52, Queries: 33
# Attacking sample 49/100 (True: 1, Index: 425)...
#   Success! Adv label: 7, L2: 405.23, Queries: 31
# Attacking sample 50/100 (True: 1, Index: 428)...
#   Success! Adv label: 4, L2: 360.84, Queries: 27
# Attacking sample 51/100 (True: 1, Index: 463)...
#   Success! Adv label: 4, L2: 286.68, Queries: 23
# Attacking sample 52/100 (True: 1, Index: 499)...
#   Success! Adv label: 4, L2: 438.96, Queries: 33
# Attacking sample 53/100 (True: 1, Index: 502)...
#   Success! Adv label: 4, L2: 430.73, Queries: 33
# Attacking sample 54/100 (True: 1, Index: 526)...
#   Success! Adv label: 8, L2: 295.94, Queries: 23
# Attacking sample 55/100 (True: 1, Index: 532)...
#   Success! Adv label: 4, L2: 355.79, Queries: 27
# Attacking sample 56/100 (True: 1, Index: 536)...
#   Success! Adv label: 9, L2: 259.40, Queries: 21
# Attacking sample 57/100 (True: 1, Index: 537)...
#   Success! Adv label: 8, L2: 359.62, Queries: 29
# Attacking sample 58/100 (True: 1, Index: 539)...
#   Success! Adv label: 4, L2: 379.57, Queries: 29
# Attacking sample 60/100 (True: 1, Index: 560)...
#   Success! Adv label: 4, L2: 348.58, Queries: 27
# Attacking sample 61/100 (True: 1, Index: 561)...
#   Success! Adv label: 8, L2: 294.08, Queries: 23
# Attacking sample 62/100 (True: 1, Index: 570)...
#   Success! Adv label: 8, L2: 337.74, Queries: 27
# Attacking sample 63/100 (True: 1, Index: 573)...
#   Success! Adv label: 2, L2: 34.37, Queries: 3
# Attacking sample 64/100 (True: 1, Index: 576)...
#   Success! Adv label: 7, L2: 325.27, Queries: 27
# Attacking sample 65/100 (True: 1, Index: 580)...
#   Success! Adv label: 4, L2: 329.13, Queries: 25
# Attacking sample 66/100 (True: 1, Index: 588)...
#   Success! Adv label: 7, L2: 434.18, Queries: 35
# Attacking sample 67/100 (True: 1, Index: 620)...
#   Success! Adv label: 4, L2: 383.51, Queries: 29
# Attacking sample 68/100 (True: 1, Index: 621)...
#   Success! Adv label: 4, L2: 372.90, Queries: 29
# Attacking sample 69/100 (True: 1, Index: 622)...
#   Success! Adv label: 2, L2: 137.54, Queries: 11
# Attacking sample 70/100 (True: 1, Index: 627)...
#   Success! Adv label: 8, L2: 282.94, Queries: 23
# Attacking sample 71/100 (True: 1, Index: 630)...
#   Success! Adv label: 8, L2: 251.39, Queries: 19
# Attacking sample 72/100 (True: 1, Index: 632)...
#   Success! Adv label: 4, L2: 273.86, Queries: 21
# Attacking sample 73/100 (True: 1, Index: 644)...
#   Success! Adv label: 4, L2: 296.74, Queries: 23
# Attacking sample 74/100 (True: 1, Index: 646)...
#   Success! Adv label: 7, L2: 316.31, Queries: 27
# Attacking sample 75/100 (True: 1, Index: 649)...
#   Success! Adv label: 4, L2: 407.55, Queries: 31
# Attacking sample 76/100 (True: 1, Index: 662)...
#   Success! Adv label: 4, L2: 435.24, Queries: 33
# Attacking sample 77/100 (True: 1, Index: 663)...
#   Success! Adv label: 8, L2: 274.91, Queries: 21
# Attacking sample 78/100 (True: 1, Index: 669)...
#   Success! Adv label: 9, L2: 451.17, Queries: 35
# Attacking sample 79/100 (True: 1, Index: 677)...
#   Success! Adv label: 4, L2: 290.77, Queries: 23
# Attacking sample 80/100 (True: 1, Index: 686)...
#   Success! Adv label: 8, L2: 355.96, Queries: 29
# Attacking sample 81/100 (True: 1, Index: 689)...
#   Success! Adv label: 4, L2: 372.23, Queries: 27
# Attacking sample 82/100 (True: 1, Index: 703)...
#   Success! Adv label: 8, L2: 378.75, Queries: 29
# Attacking sample 83/100 (True: 1, Index: 705)...
#   Success! Adv label: 7, L2: 514.52, Queries: 41
# Attacking sample 84/100 (True: 1, Index: 709)...
#   Success! Adv label: 4, L2: 311.63, Queries: 25
# Attacking sample 85/100 (True: 1, Index: 724)...
#   Success! Adv label: 4, L2: 245.19, Queries: 19
# Attacking sample 86/100 (True: 1, Index: 727)...
#   Success! Adv label: 8, L2: 338.39, Queries: 25
# Attacking sample 87/100 (True: 1, Index: 734)...
#   Success! Adv label: 8, L2: 229.92, Queries: 19
# Attacking sample 88/100 (True: 1, Index: 740)...
#   Success! Adv label: 4, L2: 354.99, Queries: 27
# Attacking sample 89/100 (True: 1, Index: 741)...
#   Success! Adv label: 8, L2: 241.81, Queries: 19
# Attacking sample 90/100 (True: 1, Index: 743)...
#   Success! Adv label: 8, L2: 343.74, Queries: 25
# Attacking sample 91/100 (True: 1, Index: 759)...
#   Success! Adv label: 4, L2: 388.66, Queries: 31
# Attacking sample 92/100 (True: 1, Index: 768)...
#   Success! Adv label: 8, L2: 322.17, Queries: 25
# Attacking sample 93/100 (True: 1, Index: 775)...
#   Success! Adv label: 4, L2: 256.69, Queries: 21
# Attacking sample 94/100 (True: 1, Index: 782)...
#   Success! Adv label: 4, L2: 385.99, Queries: 29
# Attacking sample 95/100 (True: 1, Index: 798)...
#   Success! Adv label: 9, L2: 315.27, Queries: 25
# Attacking sample 96/100 (True: 1, Index: 799)...
#   Success! Adv label: 8, L2: 436.91, Queries: 33
# Attacking sample 97/100 (True: 1, Index: 808)...
#   Success! Adv label: 7, L2: 375.69, Queries: 29
# Attacking sample 98/100 (True: 1, Index: 819)...
#   Success! Adv label: 4, L2: 467.28, Queries: 35
# Attacking sample 99/100 (True: 1, Index: 843)...
#   Success! Adv label: 4, L2: 436.60, Queries: 33
# Attacking sample 100/100 (True: 1, Index: 853)...
#   Success! Adv label: 4, L2: 393.07, Queries: 31
# Attacking sample 1/100 (True: 2, Index: 4)...
#   Success! Adv label: 3, L2: 591.63, Queries: 51
# Attacking sample 2/100 (True: 2, Index: 22)...
#   Success! Adv label: 6, L2: 722.81, Queries: 81
# Attacking sample 3/100 (True: 2, Index: 32)...
#   Success! Adv label: 3, L2: 921.80, Queries: 85
# Attacking sample 4/100 (True: 2, Index: 34)...
#   Success! Adv label: 4, L2: 30.66, Queries: 3
# Attacking sample 5/100 (True: 2, Index: 42)...
#   Success! Adv label: 3, L2: 251.14, Queries: 21
# Attacking sample 6/100 (True: 2, Index: 49)...
#   Success! Adv label: 3, L2: 905.22, Queries: 125
# Attacking sample 7/100 (True: 2, Index: 52)...
#   Success! Adv label: 3, L2: 982.44, Queries: 99
# Attacking sample 8/100 (True: 2, Index: 69)...
#   Success! Adv label: 8, L2: 792.22, Queries: 65
# Attacking sample 9/100 (True: 2, Index: 70)...
#   Success! Adv label: 3, L2: 654.57, Queries: 73
# Attacking sample 10/100 (True: 2, Index: 81)...
#   Success! Adv label: 8, L2: 928.99, Queries: 73
# Attacking sample 11/100 (True: 2, Index: 110)...
#   Success! Adv label: 7, L2: 1018.74, Queries: 95
# Attacking sample 12/100 (True: 2, Index: 118)...
#   Success! Adv label: 3, L2: 587.65, Queries: 51
# Attacking sample 13/100 (True: 2, Index: 121)...
#   Success! Adv label: 3, L2: 670.33, Queries: 57
# Attacking sample 14/100 (True: 2, Index: 138)...
#   Success! Adv label: 3, L2: 684.51, Queries: 61
# Attacking sample 15/100 (True: 2, Index: 144)...
#   Success! Adv label: 0, L2: 731.06, Queries: 63
# Attacking sample 16/100 (True: 2, Index: 155)...
#   Success! Adv label: 8, L2: 813.44, Queries: 63
# Attacking sample 17/100 (True: 2, Index: 160)...
#   Success! Adv label: 6, L2: 434.13, Queries: 41
# Attacking sample 18/100 (True: 2, Index: 161)...
#   Success! Adv label: 3, L2: 635.22, Queries: 55
# Attacking sample 19/100 (True: 2, Index: 176)...
#   Success! Adv label: 3, L2: 661.08, Queries: 57
# Attacking sample 21/100 (True: 2, Index: 186)...
#   Success! Adv label: 7, L2: 726.16, Queries: 77
# Attacking sample 22/100 (True: 2, Index: 197)...
#   Success! Adv label: 8, L2: 829.41, Queries: 77
# Attacking sample 23/100 (True: 2, Index: 208)...
#   Success! Adv label: 3, L2: 937.22, Queries: 83
# Attacking sample 25/100 (True: 2, Index: 216)...
#   Success! Adv label: 3, L2: 837.06, Queries: 79
# Attacking sample 26/100 (True: 2, Index: 219)...
#   Success! Adv label: 3, L2: 406.34, Queries: 37
# Attacking sample 27/100 (True: 2, Index: 235)...
#   Success! Adv label: 3, L2: 756.02, Queries: 69
# Attacking sample 28/100 (True: 2, Index: 260)...
#   Success! Adv label: 0, L2: 589.59, Queries: 53
# Attacking sample 29/100 (True: 2, Index: 276)...
#   Success! Adv label: 4, L2: 531.69, Queries: 53
# Attacking sample 30/100 (True: 2, Index: 293)...
#   Success! Adv label: 3, L2: 730.30, Queries: 81
# Attacking sample 31/100 (True: 2, Index: 295)...
#   Success! Adv label: 3, L2: 585.59, Queries: 53
# Attacking sample 32/100 (True: 2, Index: 311)...
#   Success! Adv label: 3, L2: 525.61, Queries: 47
# Attacking sample 33/100 (True: 2, Index: 313)...
#   Success! Adv label: 3, L2: 163.18, Queries: 15
# Attacking sample 34/100 (True: 2, Index: 322)...
#   Success! Adv label: 0, L2: 675.52, Queries: 61
# Attacking sample 35/100 (True: 2, Index: 328)...
#   Success! Adv label: 8, L2: 719.94, Queries: 63
# Attacking sample 36/100 (True: 2, Index: 357)...
#   Success! Adv label: 7, L2: 507.44, Queries: 47
# Attacking sample 37/100 (True: 2, Index: 374)...
#   Success! Adv label: 8, L2: 452.50, Queries: 39
# Attacking sample 38/100 (True: 2, Index: 395)...
#   Success! Adv label: 8, L2: 446.85, Queries: 43
# Attacking sample 39/100 (True: 2, Index: 396)...
#   Success! Adv label: 8, L2: 590.87, Queries: 49
# Attacking sample 40/100 (True: 2, Index: 398)...
#   Success! Adv label: 3, L2: 787.62, Queries: 73
# Attacking sample 41/100 (True: 2, Index: 433)...
#   Success! Adv label: 3, L2: 618.48, Queries: 51
# Attacking sample 42/100 (True: 2, Index: 439)...
#   Success! Adv label: 9, L2: 705.81, Queries: 59
# Attacking sample 43/100 (True: 2, Index: 441)...
#   Success! Adv label: 8, L2: 339.47, Queries: 27
# Attacking sample 44/100 (True: 2, Index: 442)...
#   Success! Adv label: 9, L2: 755.03, Queries: 65
# Attacking sample 45/100 (True: 2, Index: 451)...
#   Success! Adv label: 0, L2: 1101.31, Queries: 97
# Attacking sample 46/100 (True: 2, Index: 462)...
#   Success! Adv label: 3, L2: 673.20, Queries: 55
# Attacking sample 47/100 (True: 2, Index: 470)...
#   Success! Adv label: 3, L2: 648.46, Queries: 55
# Attacking sample 48/100 (True: 2, Index: 477)...
#   Success! Adv label: 3, L2: 916.66, Queries: 81
# Attacking sample 49/100 (True: 2, Index: 485)...
#   Success! Adv label: 7, L2: 234.20, Queries: 21
# Attacking sample 50/100 (True: 2, Index: 491)...
#   Success! Adv label: 8, L2: 740.63, Queries: 59
# Attacking sample 51/100 (True: 2, Index: 493)...
#   Success! Adv label: 7, L2: 806.41, Queries: 87
# Attacking sample 52/100 (True: 2, Index: 495)...
#   Success! Adv label: 3, L2: 658.71, Queries: 61
# Attacking sample 53/100 (True: 2, Index: 519)...
#   Success! Adv label: 3, L2: 782.29, Queries: 69
# Attacking sample 54/100 (True: 2, Index: 523)...
#   Success! Adv label: 6, L2: 696.26, Queries: 69
# Attacking sample 55/100 (True: 2, Index: 557)...
#   Success! Adv label: 8, L2: 700.22, Queries: 55
# Attacking sample 56/100 (True: 2, Index: 567)...
#   Success! Adv label: 0, L2: 513.07, Queries: 43
# Attacking sample 57/100 (True: 2, Index: 571)...
#   Success! Adv label: 7, L2: 674.25, Queries: 63
# Attacking sample 58/100 (True: 2, Index: 584)...
#   Success! Adv label: 3, L2: 1116.14, Queries: 97
# Attacking sample 59/100 (True: 2, Index: 591)...
#   Success! Adv label: 8, L2: 991.09, Queries: 91
# Attacking sample 60/100 (True: 2, Index: 592)...
#   Success! Adv label: 8, L2: 826.43, Queries: 87
# Attacking sample 61/100 (True: 2, Index: 610)...
#   Success! Adv label: 3, L2: 997.71, Queries: 91
# Attacking sample 62/100 (True: 2, Index: 612)...
#   Success! Adv label: 8, L2: 685.04, Queries: 53
# Attacking sample 63/100 (True: 2, Index: 616)...
#   Success! Adv label: 3, L2: 810.79, Queries: 73
# Attacking sample 64/100 (True: 2, Index: 624)...
#   Success! Adv label: 3, L2: 710.16, Queries: 59
# Attacking sample 65/100 (True: 2, Index: 631)...
#   Success! Adv label: 3, L2: 512.17, Queries: 47
# Attacking sample 66/100 (True: 2, Index: 636)...
#   Success! Adv label: 3, L2: 869.77, Queries: 73
# Attacking sample 67/100 (True: 2, Index: 647)...
#   Success! Adv label: 1, L2: 127.09, Queries: 13
# Attacking sample 68/100 (True: 2, Index: 650)...
#   Success! Adv label: 3, L2: 217.65, Queries: 19
# Attacking sample 69/100 (True: 2, Index: 664)...
#   Success! Adv label: 3, L2: 975.18, Queries: 85
# Attacking sample 70/100 (True: 2, Index: 704)...
#   Success! Adv label: 3, L2: 670.37, Queries: 59
# Attacking sample 71/100 (True: 2, Index: 720)...
#   Success! Adv label: 4, L2: 239.26, Queries: 21
# Attacking sample 72/100 (True: 2, Index: 725)...
#   Success! Adv label: 3, L2: 502.71, Queries: 43
# Attacking sample 73/100 (True: 2, Index: 750)...
#   Success! Adv label: 3, L2: 943.43, Queries: 145
# Attacking sample 74/100 (True: 2, Index: 764)...
#   Success! Adv label: 3, L2: 685.77, Queries: 77
# Attacking sample 75/100 (True: 2, Index: 780)...
#   Success! Adv label: 8, L2: 770.60, Queries: 63
# Attacking sample 76/100 (True: 2, Index: 784)...
#   Success! Adv label: 8, L2: 894.26, Queries: 77
# Attacking sample 77/100 (True: 2, Index: 788)...
#   Success! Adv label: 1, L2: 580.16, Queries: 51
# Attacking sample 78/100 (True: 2, Index: 790)...
#   Success! Adv label: 3, L2: 912.94, Queries: 91
# Attacking sample 79/100 (True: 2, Index: 797)...
#   Success! Adv label: 8, L2: 593.81, Queries: 49
# Attacking sample 80/100 (True: 2, Index: 803)...
#   Success! Adv label: 0, L2: 938.64, Queries: 81
# Attacking sample 81/100 (True: 2, Index: 807)...
#   Success! Adv label: 1, L2: 1008.32, Queries: 129
# Attacking sample 82/100 (True: 2, Index: 828)...
#   Success! Adv label: 3, L2: 456.02, Queries: 39
# Attacking sample 83/100 (True: 2, Index: 842)...
#   Success! Adv label: 3, L2: 717.72, Queries: 67
# Attacking sample 84/100 (True: 2, Index: 845)...
#   Success! Adv label: 3, L2: 939.24, Queries: 77
# Attacking sample 85/100 (True: 2, Index: 859)...
#   Success! Adv label: 3, L2: 485.86, Queries: 41
# Attacking sample 86/100 (True: 2, Index: 871)...
#   Success! Adv label: 1, L2: 733.16, Queries: 69
# Attacking sample 87/100 (True: 2, Index: 881)...
#   Success! Adv label: 1, L2: 637.22, Queries: 75
# Attacking sample 88/100 (True: 2, Index: 883)...
#   Success! Adv label: 8, L2: 391.32, Queries: 33
# Attacking sample 89/100 (True: 2, Index: 896)...
#   Success! Adv label: 3, L2: 548.39, Queries: 47
# Attacking sample 90/100 (True: 2, Index: 897)...
#   Success! Adv label: 3, L2: 522.25, Queries: 55
# Attacking sample 92/100 (True: 2, Index: 922)...
#   Success! Adv label: 7, L2: 560.20, Queries: 53
# Attacking sample 93/100 (True: 2, Index: 932)...
#   Success! Adv label: 8, L2: 723.20, Queries: 61
# Attacking sample 94/100 (True: 2, Index: 944)...
#   Success! Adv label: 3, L2: 541.61, Queries: 47
# Attacking sample 95/100 (True: 2, Index: 949)...
#   Success! Adv label: 3, L2: 782.93, Queries: 67
# Attacking sample 96/100 (True: 2, Index: 952)...
#   Failed! Adv label: 2, L2: 1014.98, Queries: 201
# Attacking sample 97/100 (True: 2, Index: 959)...
#   Success! Adv label: 3, L2: 593.01, Queries: 49
# Attacking sample 98/100 (True: 2, Index: 966)...
#   Success! Adv label: 7, L2: 204.70, Queries: 19
# Attacking sample 99/100 (True: 2, Index: 967)...
#   Success! Adv label: 7, L2: 788.64, Queries: 79
# Attacking sample 100/100 (True: 2, Index: 985)...
#   Success! Adv label: 3, L2: 627.75, Queries: 61
# Attacking sample 1/100 (True: 3, Index: 1)...
#   Success! Adv label: 5, L2: 348.77, Queries: 29
# Attacking sample 2/100 (True: 3, Index: 12)...
#   Success! Adv label: 5, L2: 365.99, Queries: 33
# Attacking sample 3/100 (True: 3, Index: 20)...
#   Success! Adv label: 8, L2: 721.24, Queries: 59
# Attacking sample 4/100 (True: 3, Index: 27)...
#   Success! Adv label: 5, L2: 961.66, Queries: 101
# Attacking sample 5/100 (True: 3, Index: 37)...
#   Success! Adv label: 0, L2: 955.24, Queries: 93
# Attacking sample 6/100 (True: 3, Index: 43)...
#   Success! Adv label: 2, L2: 884.32, Queries: 95
# Attacking sample 7/100 (True: 3, Index: 53)...
#   Success! Adv label: 8, L2: 545.22, Queries: 45
# Attacking sample 8/100 (True: 3, Index: 61)...
#   Success! Adv label: 8, L2: 572.24, Queries: 47
# Attacking sample 9/100 (True: 3, Index: 73)...
#   Success! Adv label: 8, L2: 618.06, Queries: 57
# Attacking sample 10/100 (True: 3, Index: 102)...
#   Success! Adv label: 2, L2: 417.32, Queries: 37
# Attacking sample 11/100 (True: 3, Index: 108)...
#   Success! Adv label: 2, L2: 80.40, Queries: 7
# Attacking sample 12/100 (True: 3, Index: 109)...
#   Success! Adv label: 8, L2: 544.88, Queries: 43
# Attacking sample 13/100 (True: 3, Index: 117)...
#   Success! Adv label: 5, L2: 882.30, Queries: 109
# Attacking sample 14/100 (True: 3, Index: 131)...
#   Success! Adv label: 8, L2: 163.84, Queries: 13
# Attacking sample 15/100 (True: 3, Index: 159)...
#   Success! Adv label: 2, L2: 867.41, Queries: 85
# Attacking sample 16/100 (True: 3, Index: 162)...
#   Success! Adv label: 2, L2: 1003.72, Queries: 163
# Attacking sample 17/100 (True: 3, Index: 166)...
#   Success! Adv label: 7, L2: 827.25, Queries: 95
# Attacking sample 18/100 (True: 3, Index: 177)...
#   Success! Adv label: 8, L2: 525.70, Queries: 41
# Attacking sample 19/100 (True: 3, Index: 181)...
#   Success! Adv label: 5, L2: 565.44, Queries: 55
# Attacking sample 20/100 (True: 3, Index: 187)...
#   Success! Adv label: 8, L2: 659.51, Queries: 51
# Attacking sample 21/100 (True: 3, Index: 196)...
#   Success! Adv label: 2, L2: 481.98, Queries: 39
# Attacking sample 22/100 (True: 3, Index: 204)...
#   Success! Adv label: 5, L2: 925.37, Queries: 97
# Attacking sample 23/100 (True: 3, Index: 227)...
#   Failed! Adv label: 3, L2: 961.58, Queries: 201
# Attacking sample 24/100 (True: 3, Index: 231)...
#   Success! Adv label: 5, L2: 675.20, Queries: 59
# Attacking sample 25/100 (True: 3, Index: 237)...
#   Success! Adv label: 5, L2: 971.80, Queries: 97
# Attacking sample 26/100 (True: 3, Index: 244)...
#   Success! Adv label: 7, L2: 845.29, Queries: 87
# Attacking sample 27/100 (True: 3, Index: 257)...
#   Success! Adv label: 8, L2: 535.36, Queries: 43
# Attacking sample 28/100 (True: 3, Index: 259)...
#   Success! Adv label: 5, L2: 843.11, Queries: 83
# Attacking sample 29/100 (True: 3, Index: 265)...
#   Success! Adv label: 5, L2: 490.51, Queries: 41
# Attacking sample 30/100 (True: 3, Index: 270)...
#   Success! Adv label: 5, L2: 230.16, Queries: 19
# Attacking sample 31/100 (True: 3, Index: 288)...
#   Success! Adv label: 8, L2: 957.28, Queries: 77
# Attacking sample 32/100 (True: 3, Index: 308)...
#   Success! Adv label: 8, L2: 559.22, Queries: 47
# Attacking sample 33/100 (True: 3, Index: 309)...
#   Success! Adv label: 8, L2: 539.02, Queries: 45
# Attacking sample 34/100 (True: 3, Index: 327)...
#   Success! Adv label: 1, L2: 363.41, Queries: 37
# Attacking sample 35/100 (True: 3, Index: 331)...
#   Success! Adv label: 8, L2: 808.92, Queries: 75
# Attacking sample 36/100 (True: 3, Index: 340)...
#   Success! Adv label: 2, L2: 997.30, Queries: 93
# Attacking sample 37/100 (True: 3, Index: 341)...
#   Success! Adv label: 5, L2: 687.24, Queries: 63
# Attacking sample 38/100 (True: 3, Index: 342)...
#   Success! Adv label: 5, L2: 473.77, Queries: 41
# Attacking sample 39/100 (True: 3, Index: 362)...
#   Success! Adv label: 2, L2: 524.14, Queries: 45
# Attacking sample 40/100 (True: 3, Index: 383)...
#   Success! Adv label: 2, L2: 526.95, Queries: 47
# Attacking sample 41/100 (True: 3, Index: 394)...
#   Success! Adv label: 8, L2: 476.79, Queries: 39
# Attacking sample 42/100 (True: 3, Index: 406)...
#   Failed! Adv label: 3, L2: 957.24, Queries: 201
# Attacking sample 43/100 (True: 3, Index: 409)...
#   Success! Adv label: 2, L2: 839.03, Queries: 81
# Attacking sample 44/100 (True: 3, Index: 445)...
#   Success! Adv label: 2, L2: 375.78, Queries: 31
# Attacking sample 45/100 (True: 3, Index: 456)...
#   Success! Adv label: 8, L2: 540.91, Queries: 43
# Attacking sample 46/100 (True: 3, Index: 459)...
#   Success! Adv label: 4, L2: 1001.23, Queries: 151
# Attacking sample 47/100 (True: 3, Index: 461)...
#   Failed! Adv label: 3, L2: 1099.45, Queries: 201
# Attacking sample 48/100 (True: 3, Index: 471)...
#   Success! Adv label: 8, L2: 873.40, Queries: 73
# Attacking sample 49/100 (True: 3, Index: 474)...
#   Success! Adv label: 5, L2: 477.72, Queries: 43
# Attacking sample 50/100 (True: 3, Index: 481)...
#   Success! Adv label: 5, L2: 828.53, Queries: 85
# Attacking sample 51/100 (True: 3, Index: 504)...
#   Success! Adv label: 5, L2: 691.85, Queries: 63
# Attacking sample 52/100 (True: 3, Index: 510)...
#   Success! Adv label: 5, L2: 317.39, Queries: 27
# Attacking sample 53/100 (True: 3, Index: 512)...
#   Failed! Adv label: 3, L2: 918.56, Queries: 201
# Attacking sample 54/100 (True: 3, Index: 524)...
#   Success! Adv label: 8, L2: 605.34, Queries: 47
# Attacking sample 55/100 (True: 3, Index: 549)...
#   Success! Adv label: 2, L2: 506.53, Queries: 47
# Attacking sample 56/100 (True: 3, Index: 556)...
#   Success! Adv label: 9, L2: 615.94, Queries: 57
# Attacking sample 57/100 (True: 3, Index: 564)...
#   Success! Adv label: 8, L2: 479.49, Queries: 39
# Attacking sample 58/100 (True: 3, Index: 586)...
#   Failed! Adv label: 3, L2: 979.89, Queries: 201
# Attacking sample 59/100 (True: 3, Index: 589)...
#   Success! Adv label: 0, L2: 1114.19, Queries: 117
# Attacking sample 60/100 (True: 3, Index: 609)...
#   Success! Adv label: 9, L2: 733.04, Queries: 65
# Attacking sample 61/100 (True: 3, Index: 613)...
#   Success! Adv label: 2, L2: 694.70, Queries: 57
# Attacking sample 62/100 (True: 3, Index: 623)...
#   Success! Adv label: 9, L2: 424.85, Queries: 35
# Attacking sample 63/100 (True: 3, Index: 639)...
#   Success! Adv label: 5, L2: 661.10, Queries: 61
# Attacking sample 64/100 (True: 3, Index: 648)...
#   Success! Adv label: 8, L2: 431.10, Queries: 35
# Attacking sample 65/100 (True: 3, Index: 651)...
#   Success! Adv label: 8, L2: 413.13, Queries: 33
# Attacking sample 66/100 (True: 3, Index: 659)...
#   Success! Adv label: 9, L2: 645.38, Queries: 61
# Attacking sample 67/100 (True: 3, Index: 661)...
#   Success! Adv label: 5, L2: 1029.48, Queries: 91
# Attacking sample 68/100 (True: 3, Index: 667)...
#   Failed! Adv label: 3, L2: 926.68, Queries: 201
# Attacking sample 69/100 (True: 3, Index: 678)...
#   Success! Adv label: 2, L2: 869.04, Queries: 125
# Attacking sample 70/100 (True: 3, Index: 690)...
#   Success! Adv label: 8, L2: 887.00, Queries: 69
# Attacking sample 71/100 (True: 3, Index: 693)...
#   Failed! Adv label: 3, L2: 917.48, Queries: 201
# Attacking sample 72/100 (True: 3, Index: 694)...
#   Success! Adv label: 8, L2: 738.87, Queries: 61
# Attacking sample 73/100 (True: 3, Index: 695)...
#   Success! Adv label: 0, L2: 278.04, Queries: 23
# Attacking sample 74/100 (True: 3, Index: 702)...
#   Success! Adv label: 8, L2: 400.81, Queries: 31
# Attacking sample 75/100 (True: 3, Index: 718)...
#   Success! Adv label: 2, L2: 1018.09, Queries: 107
# Attacking sample 76/100 (True: 3, Index: 749)...
#   Success! Adv label: 9, L2: 875.04, Queries: 89
# Attacking sample 77/100 (True: 3, Index: 769)...
#   Success! Adv label: 9, L2: 792.38, Queries: 65
# Attacking sample 79/100 (True: 3, Index: 779)...
#   Success! Adv label: 8, L2: 430.80, Queries: 37
# Attacking sample 80/100 (True: 3, Index: 800)...
#   Success! Adv label: 8, L2: 881.34, Queries: 67
# Attacking sample 81/100 (True: 3, Index: 816)...
#   Success! Adv label: 5, L2: 284.83, Queries: 25
# Attacking sample 82/100 (True: 3, Index: 829)...
#   Success! Adv label: 2, L2: 500.10, Queries: 43
# Attacking sample 83/100 (True: 3, Index: 833)...
#   Failed! Adv label: 3, L2: 963.93, Queries: 201
# Attacking sample 84/100 (True: 3, Index: 839)...
#   Success! Adv label: 8, L2: 668.10, Queries: 57
# Attacking sample 85/100 (True: 3, Index: 854)...
#   Success! Adv label: 5, L2: 334.27, Queries: 29
# Attacking sample 86/100 (True: 3, Index: 856)...
#   Success! Adv label: 2, L2: 444.42, Queries: 41
# Attacking sample 87/100 (True: 3, Index: 858)...
#   Success! Adv label: 5, L2: 121.45, Queries: 11
# Attacking sample 89/100 (True: 3, Index: 886)...
#   Success! Adv label: 8, L2: 868.22, Queries: 73
# Attacking sample 90/100 (True: 3, Index: 900)...
#   Success! Adv label: 8, L2: 700.85, Queries: 59
# Attacking sample 91/100 (True: 3, Index: 916)...
#   Success! Adv label: 5, L2: 455.28, Queries: 45
# Attacking sample 92/100 (True: 3, Index: 921)...
#   Success! Adv label: 2, L2: 444.80, Queries: 41
# Attacking sample 93/100 (True: 3, Index: 937)...
#   Success! Adv label: 8, L2: 885.84, Queries: 73
# Attacking sample 94/100 (True: 3, Index: 938)...
#   Success! Adv label: 8, L2: 702.48, Queries: 53
# Attacking sample 95/100 (True: 3, Index: 939)...
#   Success! Adv label: 8, L2: 362.64, Queries: 29
# Attacking sample 96/100 (True: 3, Index: 942)...
#   Success! Adv label: 5, L2: 940.29, Queries: 93
# Attacking sample 97/100 (True: 3, Index: 951)...
#   Success! Adv label: 8, L2: 595.73, Queries: 51
# Attacking sample 98/100 (True: 3, Index: 953)...
#   Failed! Adv label: 3, L2: 1060.93, Queries: 201
# Attacking sample 99/100 (True: 3, Index: 975)...
#   Success! Adv label: 5, L2: 1094.91, Queries: 187
# Attacking sample 1/100 (True: 4, Index: 16)...
#   Success! Adv label: 9, L2: 313.69, Queries: 27
# Attacking sample 2/100 (True: 4, Index: 17)...
#   Success! Adv label: 6, L2: 427.26, Queries: 37
# Attacking sample 3/100 (True: 4, Index: 30)...
#   Success! Adv label: 8, L2: 764.62, Queries: 65
# Attacking sample 4/100 (True: 4, Index: 33)...
#   Success! Adv label: 9, L2: 515.88, Queries: 45
# Attacking sample 5/100 (True: 4, Index: 45)...
#   Success! Adv label: 8, L2: 139.32, Queries: 11
# Attacking sample 6/100 (True: 4, Index: 48)...
#   Success! Adv label: 9, L2: 744.42, Queries: 63
# Attacking sample 7/100 (True: 4, Index: 58)...
#   Success! Adv label: 9, L2: 712.72, Queries: 59
# Attacking sample 8/100 (True: 4, Index: 66)...
#   Success! Adv label: 6, L2: 602.17, Queries: 55
# Attacking sample 9/100 (True: 4, Index: 89)...
#   Success! Adv label: 9, L2: 334.50, Queries: 27
# Attacking sample 10/100 (True: 4, Index: 92)...
#   Success! Adv label: 6, L2: 838.83, Queries: 75
# Attacking sample 11/100 (True: 4, Index: 113)...
#   Success! Adv label: 9, L2: 658.18, Queries: 55
# Attacking sample 12/100 (True: 4, Index: 116)...
#   Success! Adv label: 9, L2: 616.42, Queries: 49
# Attacking sample 13/100 (True: 4, Index: 126)...
#   Success! Adv label: 9, L2: 437.58, Queries: 35
# Attacking sample 14/100 (True: 4, Index: 130)...
#   Success! Adv label: 9, L2: 334.43, Queries: 27
# Attacking sample 15/100 (True: 4, Index: 139)...
#   Success! Adv label: 9, L2: 540.55, Queries: 43
# Attacking sample 16/100 (True: 4, Index: 149)...
#   Success! Adv label: 2, L2: 1043.50, Queries: 99
# Attacking sample 17/100 (True: 4, Index: 153)...
#   Success! Adv label: 8, L2: 487.02, Queries: 41
# Attacking sample 18/100 (True: 4, Index: 154)...
#   Success! Adv label: 7, L2: 845.49, Queries: 73
# Attacking sample 19/100 (True: 4, Index: 163)...
#   Success! Adv label: 9, L2: 523.69, Queries: 43
# Attacking sample 20/100 (True: 4, Index: 167)...
#   Success! Adv label: 9, L2: 657.67, Queries: 55
# Attacking sample 21/100 (True: 4, Index: 183)...
#   Success! Adv label: 9, L2: 395.75, Queries: 35
# Attacking sample 22/100 (True: 4, Index: 184)...
#   Success! Adv label: 9, L2: 579.74, Queries: 49
# Attacking sample 23/100 (True: 4, Index: 192)...
#   Success! Adv label: 9, L2: 279.74, Queries: 23
# Attacking sample 24/100 (True: 4, Index: 194)...
#   Success! Adv label: 9, L2: 478.37, Queries: 41
# Attacking sample 25/100 (True: 4, Index: 233)...
#   Success! Adv label: 9, L2: 685.44, Queries: 59
# Attacking sample 26/100 (True: 4, Index: 240)...
#   Success! Adv label: 8, L2: 596.62, Queries: 47
# Attacking sample 27/100 (True: 4, Index: 263)...
#   Success! Adv label: 9, L2: 256.73, Queries: 21
# Attacking sample 28/100 (True: 4, Index: 269)...
#   Success! Adv label: 9, L2: 374.46, Queries: 31
# Attacking sample 29/100 (True: 4, Index: 280)...
#   Success! Adv label: 9, L2: 361.12, Queries: 29
# Attacking sample 30/100 (True: 4, Index: 290)...
#   Success! Adv label: 9, L2: 656.25, Queries: 51
# Attacking sample 31/100 (True: 4, Index: 297)...
#   Success! Adv label: 6, L2: 425.91, Queries: 37
# Attacking sample 32/100 (True: 4, Index: 299)...
#   Success! Adv label: 9, L2: 377.70, Queries: 31
# Attacking sample 33/100 (True: 4, Index: 310)...
#   Success! Adv label: 9, L2: 308.54, Queries: 25
# Attacking sample 34/100 (True: 4, Index: 316)...
#   Success! Adv label: 9, L2: 479.23, Queries: 39
# Attacking sample 35/100 (True: 4, Index: 320)...
#   Success! Adv label: 9, L2: 441.30, Queries: 37
# Attacking sample 36/100 (True: 4, Index: 324)...
#   Success! Adv label: 9, L2: 485.28, Queries: 41
# Attacking sample 37/100 (True: 4, Index: 326)...
#   Success! Adv label: 9, L2: 542.56, Queries: 47
# Attacking sample 38/100 (True: 4, Index: 332)...
#   Success! Adv label: 9, L2: 31.38, Queries: 3
# Attacking sample 39/100 (True: 4, Index: 335)...
#   Success! Adv label: 9, L2: 683.71, Queries: 57
# Attacking sample 40/100 (True: 4, Index: 344)...
#   Success! Adv label: 7, L2: 510.63, Queries: 45
# Attacking sample 42/100 (True: 4, Index: 359)...
#   Success! Adv label: 9, L2: 422.94, Queries: 33
# Attacking sample 43/100 (True: 4, Index: 376)...
#   Success! Adv label: 9, L2: 574.05, Queries: 49
# Attacking sample 44/100 (True: 4, Index: 393)...
#   Success! Adv label: 9, L2: 548.02, Queries: 43
# Attacking sample 45/100 (True: 4, Index: 401)...
#   Success! Adv label: 2, L2: 712.53, Queries: 61
# Attacking sample 46/100 (True: 4, Index: 402)...
#   Success! Adv label: 9, L2: 520.06, Queries: 43
# Attacking sample 47/100 (True: 4, Index: 422)...
#   Success! Adv label: 9, L2: 348.98, Queries: 27
# Attacking sample 48/100 (True: 4, Index: 423)...
#   Success! Adv label: 9, L2: 173.67, Queries: 15
# Attacking sample 49/100 (True: 4, Index: 427)...
#   Success! Adv label: 1, L2: 547.96, Queries: 51
# Attacking sample 50/100 (True: 4, Index: 432)...
#   Success! Adv label: 9, L2: 392.96, Queries: 33
# Attacking sample 51/100 (True: 4, Index: 434)...
#   Success! Adv label: 9, L2: 292.33, Queries: 23
# Attacking sample 52/100 (True: 4, Index: 454)...
#   Success! Adv label: 9, L2: 551.13, Queries: 47
# Attacking sample 53/100 (True: 4, Index: 467)...
#   Success! Adv label: 8, L2: 357.94, Queries: 29
# Attacking sample 54/100 (True: 4, Index: 501)...
#   Success! Adv label: 9, L2: 269.37, Queries: 23
# Attacking sample 55/100 (True: 4, Index: 515)...
#   Success! Adv label: 9, L2: 362.43, Queries: 29
# Attacking sample 56/100 (True: 4, Index: 540)...
#   Success! Adv label: 9, L2: 608.61, Queries: 53
# Attacking sample 57/100 (True: 4, Index: 544)...
#   Success! Adv label: 0, L2: 448.60, Queries: 41
# Attacking sample 58/100 (True: 4, Index: 545)...
#   Success! Adv label: 9, L2: 392.17, Queries: 33
# Attacking sample 59/100 (True: 4, Index: 547)...
#   Success! Adv label: 7, L2: 820.36, Queries: 83
# Attacking sample 60/100 (True: 4, Index: 566)...
#   Success! Adv label: 9, L2: 394.87, Queries: 31
# Attacking sample 61/100 (True: 4, Index: 590)...
#   Success! Adv label: 0, L2: 460.57, Queries: 39
# Attacking sample 62/100 (True: 4, Index: 593)...
#   Success! Adv label: 9, L2: 360.53, Queries: 29
# Attacking sample 63/100 (True: 4, Index: 599)...
#   Success! Adv label: 9, L2: 696.10, Queries: 65
# Attacking sample 64/100 (True: 4, Index: 602)...
#   Success! Adv label: 9, L2: 525.55, Queries: 43
# Attacking sample 65/100 (True: 4, Index: 607)...
#   Success! Adv label: 7, L2: 592.35, Queries: 59
# Attacking sample 66/100 (True: 4, Index: 611)...
#   Success! Adv label: 9, L2: 657.28, Queries: 55
# Attacking sample 67/100 (True: 4, Index: 617)...
#   Success! Adv label: 9, L2: 533.63, Queries: 41
# Attacking sample 68/100 (True: 4, Index: 657)...
#   Success! Adv label: 9, L2: 330.57, Queries: 29
# Attacking sample 69/100 (True: 4, Index: 680)...
#   Success! Adv label: 9, L2: 384.08, Queries: 31
# Attacking sample 70/100 (True: 4, Index: 684)...
#   Success! Adv label: 9, L2: 638.73, Queries: 59
# Attacking sample 71/100 (True: 4, Index: 687)...
#   Success! Adv label: 9, L2: 515.08, Queries: 41
# Attacking sample 72/100 (True: 4, Index: 692)...
#   Success! Adv label: 9, L2: 760.04, Queries: 65
# Attacking sample 73/100 (True: 4, Index: 696)...
#   Success! Adv label: 9, L2: 181.64, Queries: 15
# Attacking sample 74/100 (True: 4, Index: 697)...
#   Success! Adv label: 9, L2: 851.28, Queries: 69
# Attacking sample 75/100 (True: 4, Index: 708)...
#   Success! Adv label: 9, L2: 552.18, Queries: 45
# Attacking sample 76/100 (True: 4, Index: 717)...
#   Success! Adv label: 9, L2: 355.41, Queries: 29
# Attacking sample 77/100 (True: 4, Index: 746)...
#   Success! Adv label: 9, L2: 459.78, Queries: 39
# Attacking sample 78/100 (True: 4, Index: 752)...
#   Success! Adv label: 9, L2: 995.10, Queries: 85
# Attacking sample 79/100 (True: 4, Index: 755)...
#   Success! Adv label: 7, L2: 810.90, Queries: 87
# Attacking sample 80/100 (True: 4, Index: 757)...
#   Success! Adv label: 9, L2: 427.40, Queries: 35
# Attacking sample 81/100 (True: 4, Index: 766)...
#   Success! Adv label: 7, L2: 487.46, Queries: 45
# Attacking sample 82/100 (True: 4, Index: 771)...
#   Success! Adv label: 9, L2: 311.70, Queries: 25
# Attacking sample 83/100 (True: 4, Index: 776)...
#   Success! Adv label: 2, L2: 627.53, Queries: 55
# Attacking sample 84/100 (True: 4, Index: 777)...
#   Success! Adv label: 1, L2: 963.22, Queries: 99
# Attacking sample 85/100 (True: 4, Index: 786)...
#   Success! Adv label: 9, L2: 187.89, Queries: 15
# Attacking sample 86/100 (True: 4, Index: 811)...
#   Success! Adv label: 9, L2: 252.38, Queries: 21
# Attacking sample 87/100 (True: 4, Index: 815)...
#   Success! Adv label: 6, L2: 686.68, Queries: 59
# Attacking sample 88/100 (True: 4, Index: 817)...
#   Success! Adv label: 8, L2: 841.89, Queries: 79
# Attacking sample 89/100 (True: 4, Index: 840)...
#   Success! Adv label: 6, L2: 718.81, Queries: 61
# Attacking sample 91/100 (True: 4, Index: 849)...
#   Success! Adv label: 8, L2: 696.16, Queries: 57
# Attacking sample 92/100 (True: 4, Index: 857)...
#   Success! Adv label: 9, L2: 539.45, Queries: 45
# Attacking sample 93/100 (True: 4, Index: 872)...
#   Success! Adv label: 9, L2: 708.63, Queries: 63
# Attacking sample 94/100 (True: 4, Index: 877)...
#   Success! Adv label: 9, L2: 426.60, Queries: 37
# Attacking sample 95/100 (True: 4, Index: 894)...
#   Success! Adv label: 9, L2: 276.22, Queries: 23
# Attacking sample 96/100 (True: 4, Index: 902)...
#   Success! Adv label: 9, L2: 413.13, Queries: 33
# Attacking sample 97/100 (True: 4, Index: 911)...
#   Success! Adv label: 9, L2: 567.50, Queries: 49
# ...
#   Success! Adv label: 3, L2: 544.55, Queries: 49
# Attacking sample 40/100 (True: 8, Index: 505)...
#   Success! Adv label: 2, L2: 743.13, Queries: 69
# Attacking sample 41/100 (True: 8, Index: 509)...
#   Success! Adv label: 3, L2: 678.46, Queries: 73
# Attacking sample 42/100 (True: 8, Index: 525)...
#   Success! Adv label: 3, L2: 593.98, Queries: 57
# Attacking sample 43/100 (True: 8, Index: 528)...
#   Success! Adv label: 3, L2: 726.73, Queries: 77
# Attacking sample 44/100 (True: 8, Index: 541)...
#   Success! Adv label: 3, L2: 864.67, Queries: 81
# Attacking sample 45/100 (True: 8, Index: 543)...
#   Success! Adv label: 6, L2: 380.36, Queries: 35
# Attacking sample 46/100 (True: 8, Index: 550)...
#   Success! Adv label: 5, L2: 510.85, Queries: 47
# Attacking sample 47/100 (True: 8, Index: 558)...
#   Success! Adv label: 2, L2: 822.15, Queries: 77
# Attacking sample 48/100 (True: 8, Index: 575)...
#   Success! Adv label: 9, L2: 469.69, Queries: 43
# Attacking sample 49/100 (True: 8, Index: 594)...
#   Success! Adv label: 2, L2: 390.52, Queries: 37
# Attacking sample 50/100 (True: 8, Index: 600)...
#   Success! Adv label: 3, L2: 1030.34, Queries: 95
# Attacking sample 51/100 (True: 8, Index: 605)...
#   Success! Adv label: 2, L2: 625.69, Queries: 57
# Attacking sample 52/100 (True: 8, Index: 619)...
#   Success! Adv label: 3, L2: 547.44, Queries: 53
# Attacking sample 53/100 (True: 8, Index: 625)...
#   Success! Adv label: 3, L2: 779.16, Queries: 69
# Attacking sample 54/100 (True: 8, Index: 629)...
#   Success! Adv label: 2, L2: 543.30, Queries: 47
# Attacking sample 55/100 (True: 8, Index: 645)...
#   Success! Adv label: 9, L2: 1008.81, Queries: 97
# Attacking sample 56/100 (True: 8, Index: 652)...
#   Success! Adv label: 2, L2: 625.38, Queries: 61
# Attacking sample 57/100 (True: 8, Index: 672)...
#   Success! Adv label: 3, L2: 575.07, Queries: 61
# Attacking sample 58/100 (True: 8, Index: 683)...
#   Success! Adv label: 3, L2: 367.47, Queries: 39
# Attacking sample 59/100 (True: 8, Index: 701)...
#   Success! Adv label: 5, L2: 760.64, Queries: 77
# Attacking sample 60/100 (True: 8, Index: 714)...
#   Success! Adv label: 3, L2: 665.73, Queries: 67
# Attacking sample 61/100 (True: 8, Index: 721)...
#   Success! Adv label: 3, L2: 502.49, Queries: 47
# Attacking sample 62/100 (True: 8, Index: 730)...
#   Success! Adv label: 2, L2: 622.32, Queries: 55
# Attacking sample 63/100 (True: 8, Index: 731)...
#   Failed! Adv label: 8, L2: 1138.49, Queries: 201
# Attacking sample 64/100 (True: 8, Index: 738)...
#   Success! Adv label: 3, L2: 747.20, Queries: 77
# Attacking sample 65/100 (True: 8, Index: 791)...
#   Success! Adv label: 5, L2: 785.25, Queries: 75
# Attacking sample 66/100 (True: 8, Index: 832)...
#   Success! Adv label: 6, L2: 572.60, Queries: 53
# Attacking sample 67/100 (True: 8, Index: 838)...
#   Success! Adv label: 5, L2: 566.19, Queries: 55
# Attacking sample 68/100 (True: 8, Index: 860)...
#   Success! Adv label: 3, L2: 742.86, Queries: 75
# Attacking sample 69/100 (True: 8, Index: 864)...
#   Success! Adv label: 9, L2: 818.39, Queries: 83
# Attacking sample 70/100 (True: 8, Index: 889)...
#   Success! Adv label: 3, L2: 642.15, Queries: 63
# Attacking sample 71/100 (True: 8, Index: 905)...
#   Success! Adv label: 9, L2: 766.33, Queries: 77
# Attacking sample 73/100 (True: 8, Index: 919)...
#   Success! Adv label: 3, L2: 577.49, Queries: 55
# Attacking sample 74/100 (True: 8, Index: 923)...
#   Success! Adv label: 3, L2: 697.06, Queries: 67
# Attacking sample 75/100 (True: 8, Index: 926)...
#   Success! Adv label: 5, L2: 708.31, Queries: 67
# Attacking sample 76/100 (True: 8, Index: 933)...
#   Success! Adv label: 3, L2: 647.24, Queries: 63
# Attacking sample 78/100 (True: 8, Index: 971)...
#   Success! Adv label: 2, L2: 771.13, Queries: 73
# Attacking sample 79/100 (True: 8, Index: 1014)...
#   Success! Adv label: 3, L2: 599.60, Queries: 59
# Attacking sample 80/100 (True: 8, Index: 1034)...
#   Success! Adv label: 6, L2: 801.90, Queries: 81
# Attacking sample 81/100 (True: 8, Index: 1053)...
#   Success! Adv label: 6, L2: 592.01, Queries: 57
# Attacking sample 82/100 (True: 8, Index: 1057)...
#   Success! Adv label: 6, L2: 469.66, Queries: 39
# Attacking sample 83/100 (True: 8, Index: 1061)...
#   Success! Adv label: 1, L2: 883.44, Queries: 111
# Attacking sample 84/100 (True: 8, Index: 1062)...
#   Success! Adv label: 3, L2: 632.98, Queries: 63
# Attacking sample 85/100 (True: 8, Index: 1063)...
#   Success! Adv label: 3, L2: 654.87, Queries: 61
# Attacking sample 86/100 (True: 8, Index: 1078)...
#   Success! Adv label: 9, L2: 359.46, Queries: 29
# Attacking sample 87/100 (True: 8, Index: 1088)...
#   Success! Adv label: 2, L2: 771.28, Queries: 75
# Attacking sample 88/100 (True: 8, Index: 1100)...
#   Success! Adv label: 4, L2: 1068.28, Queries: 121
# Attacking sample 89/100 (True: 8, Index: 1106)...
#   Success! Adv label: 2, L2: 1041.35, Queries: 101
# Attacking sample 90/100 (True: 8, Index: 1120)...
#   Success! Adv label: 3, L2: 564.56, Queries: 55
# Attacking sample 91/100 (True: 8, Index: 1132)...
#   Success! Adv label: 2, L2: 672.03, Queries: 63
# Attacking sample 92/100 (True: 8, Index: 1134)...
#   Failed! Adv label: 8, L2: 1153.59, Queries: 201
# Attacking sample 93/100 (True: 8, Index: 1140)...
#   Success! Adv label: 5, L2: 329.35, Queries: 31
# Attacking sample 94/100 (True: 8, Index: 1150)...
#   Success! Adv label: 9, L2: 600.79, Queries: 55
# Attacking sample 95/100 (True: 8, Index: 1165)...
#   Success! Adv label: 3, L2: 774.52, Queries: 73
# Attacking sample 96/100 (True: 8, Index: 1179)...
#   Success! Adv label: 3, L2: 624.46, Queries: 59
# Attacking sample 97/100 (True: 8, Index: 1182)...
#   Success! Adv label: 9, L2: 555.59, Queries: 51
# Attacking sample 98/100 (True: 8, Index: 1186)...
#   Success! Adv label: 2, L2: 813.20, Queries: 73
# Attacking sample 99/100 (True: 8, Index: 1189)...
#   Success! Adv label: 3, L2: 275.53, Queries: 27
# Attacking sample 100/100 (True: 8, Index: 1207)...
#   Success! Adv label: 9, L2: 718.68, Queries: 63
# Attacking sample 1/100 (True: 9, Index: 6)...
#   Success! Adv label: 7, L2: 340.77, Queries: 31
# Attacking sample 2/100 (True: 9, Index: 38)...
#   Success! Adv label: 7, L2: 76.92, Queries: 7
# Attacking sample 3/100 (True: 9, Index: 55)...
#   Success! Adv label: 0, L2: 168.53, Queries: 15
# Attacking sample 4/100 (True: 9, Index: 56)...
#   Success! Adv label: 4, L2: 455.46, Queries: 41
# Attacking sample 5/100 (True: 9, Index: 91)...
#   Success! Adv label: 3, L2: 299.51, Queries: 25
# Attacking sample 6/100 (True: 9, Index: 99)...
#   Success! Adv label: 7, L2: 474.87, Queries: 45
# Attacking sample 7/100 (True: 9, Index: 101)...
#   Success! Adv label: 5, L2: 732.97, Queries: 69
# Attacking sample 8/100 (True: 9, Index: 114)...
#   Success! Adv label: 8, L2: 706.16, Queries: 59
# Attacking sample 9/100 (True: 9, Index: 133)...
#   Success! Adv label: 8, L2: 674.82, Queries: 57
# Attacking sample 10/100 (True: 9, Index: 171)...
#   Success! Adv label: 8, L2: 105.74, Queries: 9
# Attacking sample 11/100 (True: 9, Index: 179)...
#   Success! Adv label: 7, L2: 669.84, Queries: 69
# Attacking sample 12/100 (True: 9, Index: 195)...
#   Success! Adv label: 1, L2: 239.17, Queries: 21
# Attacking sample 13/100 (True: 9, Index: 214)...
#   Success! Adv label: 4, L2: 505.33, Queries: 49
# Attacking sample 14/100 (True: 9, Index: 218)...
#   Success! Adv label: 4, L2: 382.87, Queries: 35
# Attacking sample 15/100 (True: 9, Index: 222)...
#   Success! Adv label: 8, L2: 418.63, Queries: 37
# Attacking sample 16/100 (True: 9, Index: 224)...
#   Success! Adv label: 6, L2: 539.22, Queries: 47
# Attacking sample 17/100 (True: 9, Index: 238)...
#   Success! Adv label: 4, L2: 503.78, Queries: 43
# Attacking sample 18/100 (True: 9, Index: 243)...
#   Success! Adv label: 8, L2: 697.58, Queries: 61
# Attacking sample 19/100 (True: 9, Index: 245)...
#   Success! Adv label: 4, L2: 501.56, Queries: 49
# Attacking sample 20/100 (True: 9, Index: 246)...
#   Success! Adv label: 8, L2: 652.23, Queries: 51
# Attacking sample 21/100 (True: 9, Index: 251)...
#   Success! Adv label: 7, L2: 281.65, Queries: 25
# Attacking sample 22/100 (True: 9, Index: 303)...
#   Success! Adv label: 4, L2: 290.95, Queries: 27
# Attacking sample 23/100 (True: 9, Index: 305)...
#   Success! Adv label: 8, L2: 264.70, Queries: 23
# Attacking sample 24/100 (True: 9, Index: 307)...
#   Success! Adv label: 5, L2: 670.05, Queries: 65
# Attacking sample 25/100 (True: 9, Index: 315)...
#   Success! Adv label: 8, L2: 736.80, Queries: 65
# Attacking sample 26/100 (True: 9, Index: 354)...
#   Success! Adv label: 4, L2: 585.13, Queries: 55
# Attacking sample 27/100 (True: 9, Index: 364)...
#   Success! Adv label: 8, L2: 717.87, Queries: 65
# Attacking sample 28/100 (True: 9, Index: 389)...
#   Success! Adv label: 4, L2: 344.41, Queries: 31
# Attacking sample 29/100 (True: 9, Index: 407)...
#   Success! Adv label: 8, L2: 282.50, Queries: 23
# Attacking sample 30/100 (True: 9, Index: 411)...
#   Success! Adv label: 4, L2: 228.95, Queries: 19
# Attacking sample 31/100 (True: 9, Index: 417)...
#   Success! Adv label: 7, L2: 412.07, Queries: 43
# Attacking sample 32/100 (True: 9, Index: 421)...
#   Success! Adv label: 4, L2: 440.80, Queries: 39
# Attacking sample 33/100 (True: 9, Index: 438)...
#   Success! Adv label: 4, L2: 486.79, Queries: 43
# Attacking sample 34/100 (True: 9, Index: 443)...
#   Success! Adv label: 8, L2: 691.54, Queries: 63
# Attacking sample 35/100 (True: 9, Index: 444)...
#   Success! Adv label: 4, L2: 321.25, Queries: 31
# Attacking sample 36/100 (True: 9, Index: 446)...
#   Success! Adv label: 4, L2: 633.46, Queries: 65
# Attacking sample 37/100 (True: 9, Index: 455)...
#   Success! Adv label: 7, L2: 326.29, Queries: 31
# Attacking sample 38/100 (True: 9, Index: 469)...
#   Success! Adv label: 4, L2: 953.11, Queries: 89
# Attacking sample 39/100 (True: 9, Index: 472)...
#   Success! Adv label: 3, L2: 789.89, Queries: 69
# Attacking sample 40/100 (True: 9, Index: 473)...
#   Success! Adv label: 4, L2: 749.86, Queries: 67
# Attacking sample 41/100 (True: 9, Index: 482)...
#   Success! Adv label: 4, L2: 482.77, Queries: 41
# Attacking sample 42/100 (True: 9, Index: 490)...
#   Success! Adv label: 8, L2: 880.68, Queries: 79
# Attacking sample 43/100 (True: 9, Index: 496)...
#   Success! Adv label: 4, L2: 475.43, Queries: 43
# Attacking sample 44/100 (True: 9, Index: 507)...
#   Success! Adv label: 8, L2: 452.64, Queries: 37
# Attacking sample 45/100 (True: 9, Index: 508)...
#   Success! Adv label: 7, L2: 520.75, Queries: 47
# Attacking sample 46/100 (True: 9, Index: 514)...
#   Success! Adv label: 4, L2: 205.93, Queries: 17
# Attacking sample 47/100 (True: 9, Index: 522)...
#   Success! Adv label: 4, L2: 80.49, Queries: 7
# Attacking sample 48/100 (True: 9, Index: 535)...
#   Success! Adv label: 4, L2: 496.59, Queries: 47
# Attacking sample 49/100 (True: 9, Index: 542)...
#   Success! Adv label: 8, L2: 434.78, Queries: 41
# Attacking sample 50/100 (True: 9, Index: 553)...
#   Success! Adv label: 4, L2: 684.90, Queries: 65
# Attacking sample 51/100 (True: 9, Index: 554)...
#   Success! Adv label: 4, L2: 840.60, Queries: 77
# Attacking sample 52/100 (True: 9, Index: 565)...
#   Success! Adv label: 0, L2: 449.14, Queries: 41
# Attacking sample 53/100 (True: 9, Index: 569)...
#   Success! Adv label: 4, L2: 508.45, Queries: 47
# Attacking sample 54/100 (True: 9, Index: 572)...
#   Success! Adv label: 5, L2: 376.77, Queries: 33
# Attacking sample 55/100 (True: 9, Index: 574)...
#   Success! Adv label: 8, L2: 432.75, Queries: 39
# Attacking sample 56/100 (True: 9, Index: 601)...
#   Success! Adv label: 8, L2: 405.17, Queries: 33
# Attacking sample 57/100 (True: 9, Index: 634)...
#   Success! Adv label: 5, L2: 456.97, Queries: 39
# Attacking sample 58/100 (True: 9, Index: 635)...
#   Success! Adv label: 4, L2: 656.51, Queries: 69
# Attacking sample 59/100 (True: 9, Index: 637)...
#   Success! Adv label: 4, L2: 587.31, Queries: 53
# Attacking sample 60/100 (True: 9, Index: 640)...
#   Success! Adv label: 4, L2: 564.46, Queries: 51
# Attacking sample 61/100 (True: 9, Index: 653)...
#   Success! Adv label: 3, L2: 630.30, Queries: 53
# Attacking sample 62/100 (True: 9, Index: 654)...
#   Success! Adv label: 4, L2: 569.25, Queries: 51
# Attacking sample 63/100 (True: 9, Index: 656)...
#   Success! Adv label: 4, L2: 645.94, Queries: 59
# Attacking sample 64/100 (True: 9, Index: 666)...
#   Success! Adv label: 4, L2: 463.50, Queries: 45
# Attacking sample 65/100 (True: 9, Index: 685)...
#   Success! Adv label: 7, L2: 685.95, Queries: 71
# Attacking sample 66/100 (True: 9, Index: 711)...
#   Success! Adv label: 4, L2: 240.47, Queries: 21
# Attacking sample 67/100 (True: 9, Index: 729)...
#   Success! Adv label: 8, L2: 524.33, Queries: 45
# Attacking sample 68/100 (True: 9, Index: 739)...
#   Success! Adv label: 4, L2: 453.92, Queries: 41
# Attacking sample 69/100 (True: 9, Index: 747)...
#   Success! Adv label: 8, L2: 426.49, Queries: 37
# Attacking sample 70/100 (True: 9, Index: 767)...
#   Success! Adv label: 8, L2: 476.36, Queries: 41
# Attacking sample 71/100 (True: 9, Index: 783)...
#   Success! Adv label: 5, L2: 606.98, Queries: 59
# Attacking sample 72/100 (True: 9, Index: 787)...
#   Success! Adv label: 8, L2: 618.03, Queries: 49
# Attacking sample 73/100 (True: 9, Index: 796)...
#   Success! Adv label: 7, L2: 455.14, Queries: 41
# Attacking sample 74/100 (True: 9, Index: 804)...
#   Success! Adv label: 7, L2: 685.72, Queries: 73
# Attacking sample 75/100 (True: 9, Index: 818)...
#   Success! Adv label: 4, L2: 649.25, Queries: 65
# Attacking sample 76/100 (True: 9, Index: 825)...
#   Success! Adv label: 8, L2: 381.85, Queries: 33
# Attacking sample 77/100 (True: 9, Index: 826)...
#   Success! Adv label: 1, L2: 181.58, Queries: 17
# Attacking sample 78/100 (True: 9, Index: 831)...
#   Success! Adv label: 4, L2: 543.65, Queries: 47
# Attacking sample 79/100 (True: 9, Index: 880)...
#   Success! Adv label: 5, L2: 606.85, Queries: 51
# Attacking sample 80/100 (True: 9, Index: 884)...
#   Success! Adv label: 4, L2: 498.79, Queries: 45
# Attacking sample 81/100 (True: 9, Index: 891)...
#   Success! Adv label: 4, L2: 121.39, Queries: 11
# Attacking sample 82/100 (True: 9, Index: 893)...
#   Success! Adv label: 2, L2: 697.64, Queries: 71
# Attacking sample 83/100 (True: 9, Index: 899)...
#   Success! Adv label: 4, L2: 496.85, Queries: 47
# Attacking sample 84/100 (True: 9, Index: 912)...
#   Success! Adv label: 5, L2: 578.92, Queries: 49
# Attacking sample 85/100 (True: 9, Index: 920)...
#   Success! Adv label: 4, L2: 646.31, Queries: 59
# Attacking sample 86/100 (True: 9, Index: 925)...
#   Success! Adv label: 8, L2: 379.13, Queries: 31
# Attacking sample 87/100 (True: 9, Index: 940)...
#   Success! Adv label: 4, L2: 353.12, Queries: 35
# Attacking sample 88/100 (True: 9, Index: 958)...
#   Success! Adv label: 4, L2: 516.72, Queries: 45
# Attacking sample 89/100 (True: 9, Index: 969)...
#   Success! Adv label: 8, L2: 409.29, Queries: 33
# Attacking sample 90/100 (True: 9, Index: 978)...
#   Success! Adv label: 4, L2: 523.40, Queries: 51
# Attacking sample 91/100 (True: 9, Index: 979)...
#   Success! Adv label: 4, L2: 406.29, Queries: 35
# Attacking sample 92/100 (True: 9, Index: 980)...
#   Success! Adv label: 8, L2: 364.71, Queries: 33
# Attacking sample 93/100 (True: 9, Index: 991)...
#   Success! Adv label: 7, L2: 545.65, Queries: 57
# Attacking sample 94/100 (True: 9, Index: 997)...
#   Success! Adv label: 4, L2: 243.29, Queries: 23
# Attacking sample 95/100 (True: 9, Index: 1006)...
#   Success! Adv label: 7, L2: 560.32, Queries: 57
# Attacking sample 96/100 (True: 9, Index: 1011)...
#   Success! Adv label: 4, L2: 822.45, Queries: 81
# Attacking sample 97/100 (True: 9, Index: 1020)...
#   Success! Adv label: 8, L2: 529.45, Queries: 49
# Attacking sample 98/100 (True: 9, Index: 1023)...
#   Success! Adv label: 4, L2: 838.53, Queries: 81
# Attacking sample 99/100 (True: 9, Index: 1042)...
#   Success! Adv label: 4, L2: 355.00, Queries: 29
# Attacking sample 100/100 (True: 9, Index: 1046)...
#   Success! Adv label: 4, L2: 397.21, Queries: 37
# Time taken to generate adversarial samples: 118.1115 seconds
#
# Stats saved to: adversarial_8bit_K150_test_images\per_sample_stats.csv
#
# ===== Attack Summary =====
# Total trials: 986
# Misclassified before attack: 14
# Success rate: 957/986 (97.1%)
# Mean L2 (successful): 576.37
# Mean queries (successful): 52.13
#
# Showing successful adversarial examples...

# %% [markdown]
# ### Untargeted Attack on test set; k=160

# %%
import os
import warnings
import numpy as np
import torch
import joblib
import pandas as pd
from PIL import Image
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import torch.nn.functional as F
import time


# Set seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# ─────────────── PATHS ────────────────────────────────────────────────────
LENET_MODEL_PATH = os.path.normpath("Models and Data splits/lenet.pt")  # TorchScript model
DATA_PKL = os.path.normpath("Models and Data splits/data_[SCALED] Train_Test_Splits.pkl")
RF_ALL_CLASSES_PATH = os.path.normpath("Models and Data splits/random_forest.pkl")
OUT_DIR = "adversarial_8bit_K160_test_images"
os.makedirs(OUT_DIR, exist_ok=True)

if not os.path.exists(RF_ALL_CLASSES_PATH):
    raise FileNotFoundError(f"Random Forest model not found at {RF_ALL_CLASSES_PATH}")

# ─────────── HYPER-PARAMETERS ─────────────────────────────────────────────
EPSILON_STEP = 0.01
ITERATIONS = 100
TOTAL_EPSILON = 0.5
TOP_K_FEATURES = 160
SAMPLES_PER_DIGIT = 100
MAX_L2 = 10000

def plot_adversarial_example(original_img, adv_img, true_label, adv_label, l2_mag, sample_idx, queries, title_suffix=""):
    if original_img.size == 784:
        original_img = original_img.reshape(28, 28)
    if adv_img.size == 784:
        adv_img = adv_img.reshape(28, 28)
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(original_img, cmap='gray')
    axes[0].set_title(f"Original\nTrue: {true_label}")
    axes[0].axis('off')
    axes[1].imshow(adv_img, cmap='gray')
    axes[1].set_title(f"Adversarial\nPred: {adv_label}")
    axes[1].axis('off')
    fig.suptitle(f"Sample {sample_idx} | L2: {l2_mag:.2f} | Queries: {queries} {title_suffix}")
    plt.show()
    plt.close(fig)  # <-- added here


# ─────────── Load Data ─────────────────────────────────────────────────────
try:
    data = joblib.load(DATA_PKL)
    _, X_samples , _, y_samples = data
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PKL}. Please check the path.")
    exit()

if X_samples.max() > 1.0:
    X_samples = X_samples.astype(np.float32) / 255.0
    warnings.warn("Data appeared in [0,255]; normalized to [0,1].")

# ─────────── Load TorchScripted LeNet ──────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
try:
    model = torch.jit.load(LENET_MODEL_PATH, map_location=device)
    model.eval()
    print(f"LeNet TorchScript model loaded from: {LENET_MODEL_PATH}")
except Exception as e:
    print(f"Error loading TorchScript LeNet model: {e}")
    exit()

def to_model(x01_batch):
    if x01_batch.ndim == 2 and x01_batch.shape == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)
    elif x01_batch.ndim == 3 and x01_batch.shape[1:] == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(1)
    elif x01_batch.ndim == 4 and x01_batch.shape[1] == 1:
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device)
    elif x01_batch.ndim == 1 and x01_batch.size == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(1, 1, 28, 28), dtype=torch.float32, device=device)
    elif x01_batch.ndim == 2 and x01_batch.shape[1] == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(x01_batch.shape[0], 1, 28, 28), dtype=torch.float32, device=device)
    else:
        raise ValueError(f"Unsupported input shape for to_model: {x01_batch.shape}")
    return tensor_batch


def model_query(x_tensor_batch):
    with torch.no_grad():
        return model(x_tensor_batch)

# ─────────── Load Random Forest Model ──────────────────────────────────────
rf_all_classes = None
top_feature_indices = None
print("Loading Random Forest Classifier for all classes...")
try:
    rf_all_classes = joblib.load(RF_ALL_CLASSES_PATH)
    feature_importances = rf_all_classes.feature_importances_
    #top_feature_indices = np.argsort(feature_importances)[:TOP_K_FEATURES]
    
    top_feature_indices = np.argsort(-feature_importances)[:TOP_K_FEATURES]
    print(f"Random Forest loaded. Using top {TOP_K_FEATURES} features.")
except Exception as e:
    print(f"Error loading Random Forest: {e}")
    top_feature_indices = np.arange(28 * 28)

# ─────────── I-FGSM Attack ─────────────────────────────────────────────────
def ifgsm_attack(original_image_np, true_label, model_target, epsilon_step, iterations,
                 total_epsilon_budget, features_to_perturb, query_count_tracker):
    if original_image_np.ndim == 1 and original_image_np.size == 784:
        original_image_np = original_image_np.reshape(28, 28)

    perturbed_image_np = original_image_np.copy()
    final_pred_label = true_label

    for i in range(iterations):
        image_tensor = to_model(perturbed_image_np)
        image_tensor.requires_grad = True
        output = model_target(image_tensor)
        query_count_tracker[0] += 1
        loss = F.cross_entropy(output, torch.tensor([true_label], device=device))
        model_target.zero_grad()
        loss.backward()
        data_grad_sign = torch.sign(image_tensor.grad.data).cpu().numpy()

        gradient_mask = np.zeros_like(data_grad_sign, dtype=np.float32)
        h, w = perturbed_image_np.shape
        rows, cols = np.unravel_index(features_to_perturb, (h, w))
        gradient_mask[0, 0, rows, cols] = data_grad_sign[0, 0, rows, cols]
        gradient_mask_for_update = gradient_mask.reshape(perturbed_image_np.shape)

        perturbed_image_np += epsilon_step * gradient_mask_for_update
        perturbation = perturbed_image_np - original_image_np
        perturbation = np.clip(perturbation, -total_epsilon_budget, total_epsilon_budget)
        perturbed_image_np = original_image_np + perturbation
        perturbed_image_np = np.clip(perturbed_image_np, 0, 1)

        # Discretize and check prediction on discretized image
        adv_uint8_temp = np.round(perturbed_image_np * 255).astype(np.uint8)
        adv_float_temp = adv_uint8_temp.astype(np.float32) / 255.0
        with torch.no_grad():
            output_temp = model_target(to_model(adv_float_temp))
            pred_temp = output_temp.argmax(dim=1).item()
            query_count_tracker[0] += 1

        if pred_temp != true_label:
            final_pred_label = pred_temp
            break

    # Final adversarial image (discretized)
    adv_uint8 = np.round(perturbed_image_np * 255).astype(np.uint8)
    adv_float = adv_uint8.astype(np.float32) / 255.0
    with torch.no_grad():
        output_final = model_target(to_model(adv_float))
        final_pred_label = output_final.argmax(dim=1).item()

    l2_norm = np.linalg.norm(adv_uint8.astype(np.float32) - (original_image_np * 255).astype(np.float32))
    success = (final_pred_label != true_label) and (l2_norm <= MAX_L2)

    return adv_uint8, final_pred_label, l2_norm, success


# ─────────── Attack Execution ──────────────────────────────────────────────
print(f"\n===== Starting Adversarial Attack =====")
total_trials, succ_total, misclassified = 0, 0, 0
records = []


start_time = time.time()


for digit in range(10):
    idxs = np.where(y_samples == digit)[0][:SAMPLES_PER_DIGIT]
    for rank, idx in enumerate(idxs, 1):
        x0 = X_samples[idx].copy()
        y0 = int(y_samples[idx])
        query_count_tracker = [0]
        pred0 = model_query(to_model(x0)).argmax(dim=1).item()
        query_count_tracker[0] += 1

        if pred0 != y0:
            misclassified += 1
            records.append({
                'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
                'adv_label': None, 'success': False, 'queries': query_count_tracker[0],
                'l2_mag': np.nan, 'note': 'Already misclassified'
            })
            continue

        total_trials += 1
        print(f"Attacking sample {rank}/{SAMPLES_PER_DIGIT} (True: {y0}, Index: {idx})...")
        adv_img_uint8, adv_label, l2_mag, success = ifgsm_attack(
            x0, y0, model, EPSILON_STEP, ITERATIONS, TOTAL_EPSILON,
            top_feature_indices, query_count_tracker
        )

        if success:
            succ_total += 1
            fname = f"true{y0}_adv{adv_label}_mag{l2_mag:.1f}_sample{idx}.png"
            Image.fromarray(adv_img_uint8, mode="L").save(os.path.join(OUT_DIR, fname))

        records.append({
            'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
            'adv_label': adv_label, 'success': success, 'queries': query_count_tracker[0],
            'l2_mag': l2_mag if success else np.nan, 'note': 'I-FGSM' + (' successful' if success else ' failed')
        })

        print(f"  {'Success' if success else 'Failed'}! Adv label: {adv_label}, L2: {l2_mag:.2f}, Queries: {query_count_tracker[0]}")


end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to generate adversarial samples: {elapsed_time:.4f} seconds")


# ─────────── Save Results ──────────────────────────────────────────────────
df = pd.DataFrame(records)
csv_path = os.path.join(OUT_DIR, "per_sample_stats.csv")
df.to_csv(csv_path, index=False)
print(f"\nStats saved to: {csv_path}")

# ─────────── Summary ───────────────────────────────────────────────────────
print(f"\n===== Attack Summary =====")
print(f"Total trials: {total_trials}")
print(f"Misclassified before attack: {misclassified}")
if total_trials > 0:
    success_rate = succ_total / total_trials * 100
    print(f"Success rate: {succ_total}/{total_trials} ({success_rate:.1f}%)")
    if succ_total > 0:
        print(f"Mean L2 (successful): {df[df['success']]['l2_mag'].mean():.2f}")
        print(f"Mean queries (successful): {df[df['success']]['queries'].mean():.2f}")

# ─────────── Display Examples ──────────────────────────────────────────────
success_df = df[df['success']]
if not success_df.empty:
    print("\nShowing successful adversarial examples...")
    show_ids = success_df.sample(min(3, len(success_df))).index.tolist()
    for record_idx in show_ids:
        r = df.loc[record_idx]
        fname_prefix = f"true{r['true_label']}_adv{r['adv_label']}_mag{r['l2_mag']:.1f}_sample{r['sample_idx']}"
        match_files = [f for f in os.listdir(OUT_DIR) if f.startswith(fname_prefix)]
        if match_files:
            adv_img_path = os.path.join(OUT_DIR, match_files[0])
            plot_adversarial_example(X_samples[r['sample_idx']], np.array(Image.open(adv_img_path)),
                                     r['true_label'], r['adv_label'], r['l2_mag'],
                                     r['sample_idx'], r['queries'], "(I-FGSM)")
else:
    print("No successful attacks to display. Showing original samples instead.")
    for i in range(min(3, len(df))):
        r = df.iloc[i]
        plot_adversarial_example(X_samples[r['sample_idx']], X_samples[r['sample_idx']],
                                 r['true_label'], r['initial_pred'], 0.0,
                                 r['sample_idx'], r['queries'], "(Original)")
# Out:
# LeNet TorchScript model loaded from: Models and Data splits\lenet.pt
# Loading Random Forest Classifier for all classes...
# Random Forest loaded. Using top 160 features.
#
# ===== Starting Adversarial Attack =====
# Attacking sample 1/100 (True: 0, Index: 29)...
#   Success! Adv label: 6, L2: 957.32, Queries: 91
# Attacking sample 2/100 (True: 0, Index: 40)...
#   Success! Adv label: 6, L2: 1085.89, Queries: 103
# Attacking sample 3/100 (True: 0, Index: 44)...
#   Success! Adv label: 5, L2: 601.66, Queries: 55
# Attacking sample 4/100 (True: 0, Index: 59)...
#   Success! Adv label: 6, L2: 664.21, Queries: 61
# Attacking sample 5/100 (True: 0, Index: 64)...
#   Failed! Adv label: 0, L2: 1252.24, Queries: 201
# Attacking sample 6/100 (True: 0, Index: 75)...
#   Success! Adv label: 8, L2: 718.30, Queries: 67
# Attacking sample 7/100 (True: 0, Index: 80)...
#   Success! Adv label: 9, L2: 622.99, Queries: 57
# Attacking sample 8/100 (True: 0, Index: 97)...
#   Success! Adv label: 6, L2: 737.75, Queries: 69
# Attacking sample 9/100 (True: 0, Index: 115)...
#   Success! Adv label: 6, L2: 841.73, Queries: 77
# Attacking sample 10/100 (True: 0, Index: 141)...
#   Success! Adv label: 7, L2: 209.62, Queries: 19
# Attacking sample 11/100 (True: 0, Index: 146)...
#   Success! Adv label: 9, L2: 731.37, Queries: 71
# Attacking sample 12/100 (True: 0, Index: 156)...
#   Failed! Adv label: 0, L2: 1060.44, Queries: 201
# Attacking sample 13/100 (True: 0, Index: 173)...
#   Success! Adv label: 6, L2: 682.19, Queries: 73
# Attacking sample 14/100 (True: 0, Index: 175)...
#   Success! Adv label: 8, L2: 538.23, Queries: 47
# Attacking sample 15/100 (True: 0, Index: 193)...
#   Success! Adv label: 9, L2: 929.48, Queries: 97
# Attacking sample 16/100 (True: 0, Index: 200)...
#   Success! Adv label: 9, L2: 719.67, Queries: 69
# Attacking sample 17/100 (True: 0, Index: 205)...
#   Success! Adv label: 9, L2: 843.28, Queries: 81
# Attacking sample 18/100 (True: 0, Index: 210)...
#   Success! Adv label: 8, L2: 805.33, Queries: 75
# Attacking sample 19/100 (True: 0, Index: 221)...
#   Success! Adv label: 3, L2: 850.03, Queries: 73
# Attacking sample 20/100 (True: 0, Index: 229)...
#   Failed! Adv label: 0, L2: 990.67, Queries: 201
# Attacking sample 21/100 (True: 0, Index: 249)...
#   Success! Adv label: 5, L2: 822.68, Queries: 91
# Attacking sample 22/100 (True: 0, Index: 258)...
#   Success! Adv label: 2, L2: 885.98, Queries: 83
# Attacking sample 23/100 (True: 0, Index: 275)...
#   Success! Adv label: 8, L2: 1119.25, Queries: 163
# Attacking sample 24/100 (True: 0, Index: 292)...
#   Failed! Adv label: 0, L2: 981.61, Queries: 201
# Attacking sample 25/100 (True: 0, Index: 296)...
#   Success! Adv label: 9, L2: 667.03, Queries: 61
# Attacking sample 26/100 (True: 0, Index: 301)...
#   Success! Adv label: 9, L2: 624.55, Queries: 55
# Attacking sample 27/100 (True: 0, Index: 314)...
#   Success! Adv label: 9, L2: 702.86, Queries: 59
# Attacking sample 28/100 (True: 0, Index: 325)...
#   Success! Adv label: 9, L2: 1038.58, Queries: 99
# Attacking sample 29/100 (True: 0, Index: 333)...
#   Success! Adv label: 9, L2: 827.32, Queries: 83
# Attacking sample 30/100 (True: 0, Index: 345)...
#   Success! Adv label: 6, L2: 668.28, Queries: 59
# Attacking sample 31/100 (True: 0, Index: 349)...
#   Success! Adv label: 9, L2: 669.41, Queries: 59
# Attacking sample 32/100 (True: 0, Index: 360)...
#   Failed! Adv label: 0, L2: 1153.91, Queries: 201
# Attacking sample 33/100 (True: 0, Index: 365)...
#   Success! Adv label: 9, L2: 1047.66, Queries: 111
# Attacking sample 34/100 (True: 0, Index: 366)...
#   Success! Adv label: 9, L2: 817.79, Queries: 75
# Attacking sample 35/100 (True: 0, Index: 379)...
#   Success! Adv label: 9, L2: 953.10, Queries: 85
# Attacking sample 36/100 (True: 0, Index: 385)...
#   Failed! Adv label: 0, L2: 1031.51, Queries: 201
# Attacking sample 37/100 (True: 0, Index: 397)...
#   Failed! Adv label: 0, L2: 1002.71, Queries: 201
# Attacking sample 38/100 (True: 0, Index: 400)...
#   Failed! Adv label: 0, L2: 1236.50, Queries: 201
# Attacking sample 39/100 (True: 0, Index: 405)...
#   Success! Adv label: 2, L2: 793.77, Queries: 69
# Attacking sample 40/100 (True: 0, Index: 410)...
#   Success! Adv label: 9, L2: 819.02, Queries: 75
# Attacking sample 41/100 (True: 0, Index: 420)...
#   Success! Adv label: 2, L2: 808.87, Queries: 85
# Attacking sample 42/100 (True: 0, Index: 424)...
#   Success! Adv label: 9, L2: 1002.54, Queries: 97
# Attacking sample 43/100 (True: 0, Index: 447)...
#   Success! Adv label: 2, L2: 693.28, Queries: 65
# Attacking sample 44/100 (True: 0, Index: 453)...
#   Success! Adv label: 6, L2: 813.37, Queries: 77
# Attacking sample 45/100 (True: 0, Index: 457)...
#   Success! Adv label: 6, L2: 1008.52, Queries: 93
# Attacking sample 46/100 (True: 0, Index: 466)...
#   Success! Adv label: 2, L2: 823.13, Queries: 81
# Attacking sample 47/100 (True: 0, Index: 475)...
#   Success! Adv label: 9, L2: 257.95, Queries: 23
# Attacking sample 48/100 (True: 0, Index: 483)...
#   Success! Adv label: 2, L2: 882.00, Queries: 87
# Attacking sample 49/100 (True: 0, Index: 484)...
#   Success! Adv label: 8, L2: 480.86, Queries: 37
# Attacking sample 50/100 (True: 0, Index: 486)...
#   Success! Adv label: 9, L2: 982.51, Queries: 113
# Attacking sample 51/100 (True: 0, Index: 487)...
#   Success! Adv label: 6, L2: 665.48, Queries: 59
# Attacking sample 52/100 (True: 0, Index: 489)...
#   Success! Adv label: 9, L2: 711.58, Queries: 65
# Attacking sample 53/100 (True: 0, Index: 492)...
#   Success! Adv label: 9, L2: 691.68, Queries: 61
# Attacking sample 54/100 (True: 0, Index: 506)...
#   Success! Adv label: 2, L2: 929.14, Queries: 81
# Attacking sample 55/100 (True: 0, Index: 513)...
#   Failed! Adv label: 0, L2: 1126.30, Queries: 201
# Attacking sample 56/100 (True: 0, Index: 518)...
#   Success! Adv label: 5, L2: 957.20, Queries: 93
# Attacking sample 57/100 (True: 0, Index: 521)...
#   Failed! Adv label: 0, L2: 1168.46, Queries: 201
# Attacking sample 58/100 (True: 0, Index: 527)...
#   Success! Adv label: 2, L2: 762.53, Queries: 69
# Attacking sample 59/100 (True: 0, Index: 529)...
#   Success! Adv label: 5, L2: 768.53, Queries: 83
# Attacking sample 60/100 (True: 0, Index: 531)...
#   Success! Adv label: 9, L2: 976.72, Queries: 125
# Attacking sample 61/100 (True: 0, Index: 546)...
#   Success! Adv label: 9, L2: 677.32, Queries: 65
# Attacking sample 62/100 (True: 0, Index: 551)...
#   Success! Adv label: 6, L2: 395.51, Queries: 31
# Attacking sample 63/100 (True: 0, Index: 555)...
#   Success! Adv label: 6, L2: 943.39, Queries: 83
# Attacking sample 64/100 (True: 0, Index: 587)...
#   Success! Adv label: 2, L2: 869.99, Queries: 85
# Attacking sample 65/100 (True: 0, Index: 604)...
#   Success! Adv label: 8, L2: 727.43, Queries: 61
# Attacking sample 66/100 (True: 0, Index: 614)...
#   Success! Adv label: 8, L2: 875.88, Queries: 81
# Attacking sample 67/100 (True: 0, Index: 615)...
#   Success! Adv label: 9, L2: 455.34, Queries: 37
# Attacking sample 68/100 (True: 0, Index: 618)...
#   Success! Adv label: 6, L2: 342.40, Queries: 29
# Attacking sample 69/100 (True: 0, Index: 638)...
#   Success! Adv label: 8, L2: 436.55, Queries: 35
# Attacking sample 70/100 (True: 0, Index: 642)...
#   Success! Adv label: 9, L2: 886.04, Queries: 89
# Attacking sample 71/100 (True: 0, Index: 655)...
#   Success! Adv label: 6, L2: 810.76, Queries: 69
# Attacking sample 72/100 (True: 0, Index: 658)...
#   Success! Adv label: 6, L2: 708.50, Queries: 61
# Attacking sample 73/100 (True: 0, Index: 665)...
#   Success! Adv label: 2, L2: 702.61, Queries: 63
# Attacking sample 74/100 (True: 0, Index: 671)...
#   Success! Adv label: 6, L2: 755.80, Queries: 65
# Attacking sample 75/100 (True: 0, Index: 681)...
#   Success! Adv label: 9, L2: 907.20, Queries: 87
# Attacking sample 76/100 (True: 0, Index: 691)...
#   Success! Adv label: 2, L2: 737.59, Queries: 63
# Attacking sample 77/100 (True: 0, Index: 700)...
#   Success! Adv label: 5, L2: 566.23, Queries: 51
# Attacking sample 78/100 (True: 0, Index: 706)...
#   Failed! Adv label: 0, L2: 957.71, Queries: 201
# Attacking sample 79/100 (True: 0, Index: 712)...
#   Failed! Adv label: 0, L2: 1128.84, Queries: 201
# Attacking sample 80/100 (True: 0, Index: 713)...
#   Success! Adv label: 9, L2: 753.87, Queries: 65
# Attacking sample 81/100 (True: 0, Index: 736)...
#   Success! Adv label: 5, L2: 694.62, Queries: 69
# Attacking sample 82/100 (True: 0, Index: 742)...
#   Success! Adv label: 8, L2: 739.26, Queries: 71
# Attacking sample 83/100 (True: 0, Index: 744)...
#   Success! Adv label: 2, L2: 624.32, Queries: 57
# Attacking sample 84/100 (True: 0, Index: 760)...
#   Success! Adv label: 9, L2: 644.90, Queries: 61
# Attacking sample 85/100 (True: 0, Index: 772)...
#   Success! Adv label: 9, L2: 329.23, Queries: 27
# Attacking sample 86/100 (True: 0, Index: 781)...
#   Success! Adv label: 6, L2: 512.99, Queries: 45
# Attacking sample 87/100 (True: 0, Index: 809)...
#   Success! Adv label: 5, L2: 777.78, Queries: 81
# Attacking sample 88/100 (True: 0, Index: 813)...
#   Success! Adv label: 9, L2: 515.44, Queries: 47
# Attacking sample 89/100 (True: 0, Index: 820)...
#   Success! Adv label: 9, L2: 678.44, Queries: 67
# Attacking sample 90/100 (True: 0, Index: 823)...
#   Success! Adv label: 5, L2: 736.13, Queries: 73
# Attacking sample 91/100 (True: 0, Index: 844)...
#   Success! Adv label: 9, L2: 1009.17, Queries: 139
# Attacking sample 92/100 (True: 0, Index: 848)...
#   Success! Adv label: 9, L2: 304.53, Queries: 25
# Attacking sample 93/100 (True: 0, Index: 861)...
#   Success! Adv label: 6, L2: 1017.11, Queries: 83
# Attacking sample 94/100 (True: 0, Index: 865)...
#   Success! Adv label: 6, L2: 1244.04, Queries: 119
# Attacking sample 95/100 (True: 0, Index: 869)...
#   Success! Adv label: 6, L2: 1046.11, Queries: 99
# Attacking sample 96/100 (True: 0, Index: 876)...
#   Success! Adv label: 9, L2: 654.75, Queries: 57
# Attacking sample 97/100 (True: 0, Index: 885)...
#   Success! Adv label: 9, L2: 1092.84, Queries: 181
# Attacking sample 98/100 (True: 0, Index: 906)...
#   Success! Adv label: 3, L2: 1022.54, Queries: 101
# Attacking sample 99/100 (True: 0, Index: 907)...
#   Success! Adv label: 9, L2: 927.20, Queries: 87
# Attacking sample 100/100 (True: 0, Index: 918)...
#   Success! Adv label: 9, L2: 989.20, Queries: 93
# Attacking sample 1/100 (True: 1, Index: 2)...
#   Success! Adv label: 7, L2: 299.86, Queries: 23
# Attacking sample 2/100 (True: 1, Index: 3)...
#   Success! Adv label: 7, L2: 353.46, Queries: 27
# Attacking sample 3/100 (True: 1, Index: 9)...
#   Success! Adv label: 2, L2: 348.70, Queries: 29
# Attacking sample 4/100 (True: 1, Index: 25)...
#   Success! Adv label: 4, L2: 371.09, Queries: 27
# Attacking sample 5/100 (True: 1, Index: 36)...
#   Success! Adv label: 2, L2: 296.44, Queries: 23
# Attacking sample 6/100 (True: 1, Index: 63)...
#   Success! Adv label: 8, L2: 285.60, Queries: 23
# Attacking sample 7/100 (True: 1, Index: 65)...
#   Success! Adv label: 8, L2: 365.24, Queries: 27
# Attacking sample 8/100 (True: 1, Index: 68)...
#   Success! Adv label: 8, L2: 407.46, Queries: 29
# Attacking sample 9/100 (True: 1, Index: 76)...
#   Success! Adv label: 8, L2: 240.75, Queries: 19
# Attacking sample 10/100 (True: 1, Index: 83)...
#   Success! Adv label: 4, L2: 372.73, Queries: 29
# Attacking sample 11/100 (True: 1, Index: 90)...
#   Success! Adv label: 9, L2: 31.30, Queries: 3
# Attacking sample 12/100 (True: 1, Index: 94)...
#   Success! Adv label: 8, L2: 196.97, Queries: 15
# Attacking sample 13/100 (True: 1, Index: 100)...
#   Success! Adv label: 8, L2: 269.79, Queries: 21
# Attacking sample 14/100 (True: 1, Index: 123)...
#   Success! Adv label: 8, L2: 212.62, Queries: 17
# Attacking sample 15/100 (True: 1, Index: 150)...
#   Success! Adv label: 8, L2: 349.96, Queries: 25
# Attacking sample 16/100 (True: 1, Index: 152)...
#   Success! Adv label: 9, L2: 341.72, Queries: 27
# Attacking sample 17/100 (True: 1, Index: 178)...
#   Success! Adv label: 4, L2: 364.45, Queries: 27
# Attacking sample 18/100 (True: 1, Index: 185)...
#   Success! Adv label: 8, L2: 361.01, Queries: 31
# Attacking sample 19/100 (True: 1, Index: 191)...
#   Success! Adv label: 4, L2: 458.19, Queries: 33
# Attacking sample 20/100 (True: 1, Index: 201)...
#   Success! Adv label: 8, L2: 309.19, Queries: 23
# Attacking sample 21/100 (True: 1, Index: 203)...
#   Success! Adv label: 8, L2: 282.10, Queries: 21
# Attacking sample 22/100 (True: 1, Index: 213)...
#   Success! Adv label: 8, L2: 300.82, Queries: 23
# Attacking sample 23/100 (True: 1, Index: 220)...
#   Success! Adv label: 8, L2: 256.64, Queries: 19
# Attacking sample 24/100 (True: 1, Index: 223)...
#   Success! Adv label: 4, L2: 353.96, Queries: 27
# Attacking sample 25/100 (True: 1, Index: 226)...
#   Success! Adv label: 4, L2: 344.96, Queries: 25
# Attacking sample 26/100 (True: 1, Index: 232)...
#   Success! Adv label: 4, L2: 453.58, Queries: 33
# Attacking sample 27/100 (True: 1, Index: 241)...
#   Success! Adv label: 4, L2: 296.83, Queries: 23
# Attacking sample 28/100 (True: 1, Index: 254)...
#   Success! Adv label: 8, L2: 312.81, Queries: 23
# Attacking sample 29/100 (True: 1, Index: 281)...
#   Success! Adv label: 8, L2: 292.68, Queries: 23
# Attacking sample 30/100 (True: 1, Index: 284)...
#   Success! Adv label: 8, L2: 333.38, Queries: 27
# Attacking sample 31/100 (True: 1, Index: 285)...
#   Success! Adv label: 9, L2: 242.26, Queries: 19
# Attacking sample 32/100 (True: 1, Index: 286)...
#   Success! Adv label: 4, L2: 336.80, Queries: 25
# Attacking sample 33/100 (True: 1, Index: 287)...
#   Success! Adv label: 4, L2: 318.63, Queries: 25
# Attacking sample 34/100 (True: 1, Index: 294)...
#   Success! Adv label: 4, L2: 390.04, Queries: 29
# Attacking sample 35/100 (True: 1, Index: 298)...
#   Success! Adv label: 7, L2: 472.64, Queries: 35
# Attacking sample 36/100 (True: 1, Index: 306)...
#   Success! Adv label: 4, L2: 392.92, Queries: 29
# Attacking sample 37/100 (True: 1, Index: 312)...
#   Success! Adv label: 8, L2: 354.56, Queries: 29
# Attacking sample 38/100 (True: 1, Index: 317)...
#   Success! Adv label: 4, L2: 376.67, Queries: 29
# Attacking sample 39/100 (True: 1, Index: 334)...
#   Success! Adv label: 4, L2: 401.90, Queries: 29
# Attacking sample 40/100 (True: 1, Index: 337)...
#   Success! Adv label: 8, L2: 398.37, Queries: 29
# Attacking sample 41/100 (True: 1, Index: 338)...
#   Success! Adv label: 8, L2: 477.41, Queries: 35
# Attacking sample 42/100 (True: 1, Index: 348)...
#   Success! Adv label: 2, L2: 489.50, Queries: 37
# Attacking sample 43/100 (True: 1, Index: 361)...
#   Success! Adv label: 9, L2: 305.65, Queries: 23
# Attacking sample 44/100 (True: 1, Index: 363)...
#   Success! Adv label: 8, L2: 366.56, Queries: 27
# Attacking sample 45/100 (True: 1, Index: 367)...
#   Success! Adv label: 8, L2: 198.72, Queries: 15
# Attacking sample 46/100 (True: 1, Index: 375)...
#   Success! Adv label: 7, L2: 435.17, Queries: 33
# Attacking sample 47/100 (True: 1, Index: 384)...
#   Success! Adv label: 8, L2: 274.14, Queries: 21
# Attacking sample 48/100 (True: 1, Index: 412)...
#   Success! Adv label: 8, L2: 404.16, Queries: 29
# Attacking sample 49/100 (True: 1, Index: 425)...
#   Success! Adv label: 7, L2: 391.92, Queries: 29
# Attacking sample 50/100 (True: 1, Index: 428)...
#   Success! Adv label: 4, L2: 350.67, Queries: 25
# Attacking sample 51/100 (True: 1, Index: 463)...
#   Success! Adv label: 4, L2: 291.90, Queries: 23
# Attacking sample 52/100 (True: 1, Index: 499)...
#   Success! Adv label: 4, L2: 418.98, Queries: 31
# Attacking sample 53/100 (True: 1, Index: 502)...
#   Success! Adv label: 4, L2: 412.88, Queries: 31
# Attacking sample 54/100 (True: 1, Index: 526)...
#   Success! Adv label: 8, L2: 269.09, Queries: 21
# Attacking sample 55/100 (True: 1, Index: 532)...
#   Success! Adv label: 4, L2: 343.04, Queries: 25
# Attacking sample 56/100 (True: 1, Index: 536)...
#   Success! Adv label: 9, L2: 245.33, Queries: 19
# Attacking sample 57/100 (True: 1, Index: 537)...
#   Success! Adv label: 8, L2: 325.73, Queries: 25
# Attacking sample 58/100 (True: 1, Index: 539)...
#   Success! Adv label: 4, L2: 392.23, Queries: 29
# Attacking sample 60/100 (True: 1, Index: 560)...
#   Success! Adv label: 4, L2: 360.87, Queries: 27
# Attacking sample 61/100 (True: 1, Index: 561)...
#   Success! Adv label: 8, L2: 272.16, Queries: 21
# Attacking sample 62/100 (True: 1, Index: 570)...
#   Success! Adv label: 8, L2: 325.84, Queries: 25
# Attacking sample 63/100 (True: 1, Index: 573)...
#   Success! Adv label: 2, L2: 35.01, Queries: 3
# Attacking sample 64/100 (True: 1, Index: 576)...
#   Success! Adv label: 7, L2: 313.68, Queries: 25
# Attacking sample 65/100 (True: 1, Index: 580)...
#   Success! Adv label: 4, L2: 304.96, Queries: 23
# Attacking sample 66/100 (True: 1, Index: 588)...
#   Success! Adv label: 7, L2: 423.87, Queries: 33
# Attacking sample 67/100 (True: 1, Index: 620)...
#   Success! Adv label: 4, L2: 400.05, Queries: 29
# Attacking sample 68/100 (True: 1, Index: 621)...
#   Success! Adv label: 4, L2: 356.71, Queries: 27
# Attacking sample 69/100 (True: 1, Index: 622)...
#   Success! Adv label: 2, L2: 141.52, Queries: 11
# Attacking sample 70/100 (True: 1, Index: 627)...
#   Success! Adv label: 8, L2: 264.13, Queries: 21
# Attacking sample 71/100 (True: 1, Index: 630)...
#   Success! Adv label: 8, L2: 259.95, Queries: 19
# Attacking sample 72/100 (True: 1, Index: 632)...
#   Success! Adv label: 4, L2: 259.51, Queries: 19
# Attacking sample 73/100 (True: 1, Index: 644)...
#   Success! Adv label: 4, L2: 303.82, Queries: 23
# Attacking sample 74/100 (True: 1, Index: 646)...
#   Success! Adv label: 7, L2: 307.68, Queries: 25
# Attacking sample 75/100 (True: 1, Index: 649)...
#   Success! Adv label: 4, L2: 397.18, Queries: 29
# Attacking sample 76/100 (True: 1, Index: 662)...
#   Success! Adv label: 4, L2: 415.46, Queries: 31
# Attacking sample 77/100 (True: 1, Index: 663)...
#   Success! Adv label: 8, L2: 283.04, Queries: 21
# Attacking sample 78/100 (True: 1, Index: 669)...
#   Success! Adv label: 9, L2: 458.03, Queries: 35
# Attacking sample 79/100 (True: 1, Index: 677)...
#   Success! Adv label: 4, L2: 267.70, Queries: 21
# Attacking sample 80/100 (True: 1, Index: 686)...
#   Success! Adv label: 8, L2: 339.79, Queries: 27
# Attacking sample 81/100 (True: 1, Index: 689)...
#   Success! Adv label: 4, L2: 359.14, Queries: 25
# Attacking sample 82/100 (True: 1, Index: 703)...
#   Success! Adv label: 8, L2: 337.29, Queries: 25
# Attacking sample 83/100 (True: 1, Index: 705)...
#   Success! Adv label: 7, L2: 524.16, Queries: 41
# Attacking sample 84/100 (True: 1, Index: 709)...
#   Success! Adv label: 4, L2: 317.13, Queries: 25
# Attacking sample 85/100 (True: 1, Index: 724)...
#   Success! Adv label: 4, L2: 252.57, Queries: 19
# Attacking sample 86/100 (True: 1, Index: 727)...
#   Success! Adv label: 8, L2: 318.34, Queries: 23
# Attacking sample 87/100 (True: 1, Index: 734)...
#   Success! Adv label: 2, L2: 207.52, Queries: 17
# Attacking sample 88/100 (True: 1, Index: 740)...
#   Success! Adv label: 4, L2: 341.85, Queries: 25
# Attacking sample 89/100 (True: 1, Index: 741)...
#   Success! Adv label: 8, L2: 219.01, Queries: 17
# Attacking sample 90/100 (True: 1, Index: 743)...
#   Success! Adv label: 8, L2: 320.19, Queries: 23
# Attacking sample 91/100 (True: 1, Index: 759)...
#   Success! Adv label: 4, L2: 376.84, Queries: 29
# Attacking sample 92/100 (True: 1, Index: 768)...
#   Success! Adv label: 8, L2: 304.23, Queries: 23
# Attacking sample 93/100 (True: 1, Index: 775)...
#   Success! Adv label: 4, L2: 263.90, Queries: 21
# Attacking sample 94/100 (True: 1, Index: 782)...
#   Success! Adv label: 4, L2: 396.02, Queries: 29
# Attacking sample 95/100 (True: 1, Index: 798)...
#   Success! Adv label: 9, L2: 322.41, Queries: 25
# Attacking sample 96/100 (True: 1, Index: 799)...
#   Success! Adv label: 8, L2: 420.21, Queries: 31
# Attacking sample 97/100 (True: 1, Index: 808)...
#   Success! Adv label: 7, L2: 357.23, Queries: 27
# Attacking sample 98/100 (True: 1, Index: 819)...
#   Success! Adv label: 4, L2: 458.13, Queries: 33
# Attacking sample 99/100 (True: 1, Index: 843)...
#   Success! Adv label: 4, L2: 422.98, Queries: 31
# Attacking sample 100/100 (True: 1, Index: 853)...
#   Success! Adv label: 4, L2: 383.95, Queries: 29
# Attacking sample 1/100 (True: 2, Index: 4)...
#   Success! Adv label: 3, L2: 582.56, Queries: 49
# Attacking sample 2/100 (True: 2, Index: 22)...
#   Success! Adv label: 6, L2: 699.07, Queries: 73
# Attacking sample 3/100 (True: 2, Index: 32)...
#   Success! Adv label: 3, L2: 924.18, Queries: 81
# Attacking sample 4/100 (True: 2, Index: 34)...
#   Success! Adv label: 4, L2: 31.67, Queries: 3
# Attacking sample 5/100 (True: 2, Index: 42)...
#   Success! Adv label: 3, L2: 237.08, Queries: 19
# Attacking sample 6/100 (True: 2, Index: 49)...
#   Success! Adv label: 3, L2: 950.44, Queries: 135
# Attacking sample 7/100 (True: 2, Index: 52)...
#   Success! Adv label: 8, L2: 956.44, Queries: 93
# Attacking sample 8/100 (True: 2, Index: 69)...
#   Success! Adv label: 8, L2: 750.61, Queries: 59
# Attacking sample 9/100 (True: 2, Index: 70)...
#   Success! Adv label: 3, L2: 668.54, Queries: 71
# Attacking sample 10/100 (True: 2, Index: 81)...
#   Success! Adv label: 8, L2: 906.52, Queries: 69
# Attacking sample 11/100 (True: 2, Index: 110)...
#   Success! Adv label: 7, L2: 977.70, Queries: 89
# Attacking sample 12/100 (True: 2, Index: 118)...
#   Success! Adv label: 3, L2: 580.56, Queries: 49
# Attacking sample 13/100 (True: 2, Index: 121)...
#   Success! Adv label: 3, L2: 663.75, Queries: 55
# Attacking sample 14/100 (True: 2, Index: 138)...
#   Success! Adv label: 3, L2: 655.29, Queries: 57
# Attacking sample 15/100 (True: 2, Index: 144)...
#   Success! Adv label: 9, L2: 770.78, Queries: 67
# Attacking sample 16/100 (True: 2, Index: 155)...
#   Success! Adv label: 8, L2: 835.24, Queries: 63
# Attacking sample 17/100 (True: 2, Index: 160)...
#   Success! Adv label: 6, L2: 384.10, Queries: 35
# Attacking sample 18/100 (True: 2, Index: 161)...
#   Success! Adv label: 3, L2: 611.13, Queries: 51
# Attacking sample 19/100 (True: 2, Index: 176)...
#   Success! Adv label: 3, L2: 633.27, Queries: 53
# Attacking sample 21/100 (True: 2, Index: 186)...
#   Success! Adv label: 7, L2: 691.46, Queries: 71
# Attacking sample 22/100 (True: 2, Index: 197)...
#   Success! Adv label: 8, L2: 826.85, Queries: 77
# Attacking sample 23/100 (True: 2, Index: 208)...
#   Success! Adv label: 8, L2: 931.93, Queries: 81
# Attacking sample 25/100 (True: 2, Index: 216)...
#   Success! Adv label: 3, L2: 812.13, Queries: 73
# Attacking sample 26/100 (True: 2, Index: 219)...
#   Success! Adv label: 3, L2: 413.73, Queries: 37
# Attacking sample 27/100 (True: 2, Index: 235)...
#   Success! Adv label: 3, L2: 714.18, Queries: 63
# Attacking sample 28/100 (True: 2, Index: 260)...
#   Success! Adv label: 0, L2: 578.34, Queries: 51
# Attacking sample 29/100 (True: 2, Index: 276)...
#   Success! Adv label: 4, L2: 530.65, Queries: 51
# Attacking sample 30/100 (True: 2, Index: 293)...
#   Success! Adv label: 3, L2: 761.13, Queries: 79
# Attacking sample 31/100 (True: 2, Index: 295)...
#   Success! Adv label: 3, L2: 560.14, Queries: 49
# Attacking sample 32/100 (True: 2, Index: 311)...
#   Success! Adv label: 3, L2: 523.44, Queries: 45
# Attacking sample 33/100 (True: 2, Index: 313)...
#   Success! Adv label: 3, L2: 167.96, Queries: 15
# Attacking sample 34/100 (True: 2, Index: 322)...
#   Success! Adv label: 0, L2: 649.94, Queries: 57
# Attacking sample 35/100 (True: 2, Index: 328)...
#   Success! Adv label: 8, L2: 715.26, Queries: 61
# Attacking sample 36/100 (True: 2, Index: 357)...
#   Success! Adv label: 7, L2: 505.37, Queries: 45
# Attacking sample 37/100 (True: 2, Index: 374)...
#   Success! Adv label: 8, L2: 446.17, Queries: 37
# Attacking sample 38/100 (True: 2, Index: 395)...
#   Success! Adv label: 8, L2: 456.22, Queries: 43
# Attacking sample 39/100 (True: 2, Index: 396)...
#   Success! Adv label: 8, L2: 559.47, Queries: 45
# Attacking sample 40/100 (True: 2, Index: 398)...
#   Success! Adv label: 3, L2: 775.88, Queries: 69
# Attacking sample 41/100 (True: 2, Index: 433)...
#   Success! Adv label: 3, L2: 610.06, Queries: 49
# Attacking sample 42/100 (True: 2, Index: 439)...
#   Success! Adv label: 8, L2: 688.62, Queries: 55
# Attacking sample 43/100 (True: 2, Index: 441)...
#   Success! Adv label: 8, L2: 346.16, Queries: 27
# Attacking sample 44/100 (True: 2, Index: 442)...
#   Success! Adv label: 9, L2: 747.98, Queries: 63
# Attacking sample 45/100 (True: 2, Index: 451)...
#   Success! Adv label: 0, L2: 1071.29, Queries: 91
# Attacking sample 46/100 (True: 2, Index: 462)...
#   Success! Adv label: 3, L2: 664.19, Queries: 53
# Attacking sample 47/100 (True: 2, Index: 470)...
#   Success! Adv label: 3, L2: 656.35, Queries: 55
# Attacking sample 48/100 (True: 2, Index: 477)...
#   Success! Adv label: 3, L2: 860.55, Queries: 75
# Attacking sample 49/100 (True: 2, Index: 485)...
#   Success! Adv label: 7, L2: 240.27, Queries: 21
# Attacking sample 50/100 (True: 2, Index: 491)...
#   Success! Adv label: 8, L2: 732.81, Queries: 57
# Attacking sample 51/100 (True: 2, Index: 493)...
#   Success! Adv label: 7, L2: 790.90, Queries: 83
# Attacking sample 52/100 (True: 2, Index: 495)...
#   Success! Adv label: 3, L2: 644.82, Queries: 57
# Attacking sample 53/100 (True: 2, Index: 519)...
#   Success! Adv label: 3, L2: 789.38, Queries: 67
# Attacking sample 54/100 (True: 2, Index: 523)...
#   Success! Adv label: 6, L2: 657.95, Queries: 63
# Attacking sample 55/100 (True: 2, Index: 557)...
#   Success! Adv label: 8, L2: 666.09, Queries: 51
# Attacking sample 56/100 (True: 2, Index: 567)...
#   Success! Adv label: 0, L2: 501.86, Queries: 41
# Attacking sample 57/100 (True: 2, Index: 571)...
#   Success! Adv label: 7, L2: 633.47, Queries: 57
# Attacking sample 58/100 (True: 2, Index: 584)...
#   Success! Adv label: 8, L2: 1175.07, Queries: 95
# Attacking sample 59/100 (True: 2, Index: 591)...
#   Success! Adv label: 8, L2: 986.67, Queries: 89
# Attacking sample 60/100 (True: 2, Index: 592)...
#   Success! Adv label: 8, L2: 791.70, Queries: 79
# Attacking sample 61/100 (True: 2, Index: 610)...
#   Success! Adv label: 3, L2: 995.52, Queries: 89
# Attacking sample 62/100 (True: 2, Index: 612)...
#   Success! Adv label: 8, L2: 675.27, Queries: 51
# Attacking sample 63/100 (True: 2, Index: 616)...
#   Success! Adv label: 3, L2: 806.91, Queries: 69
# Attacking sample 64/100 (True: 2, Index: 624)...
#   Success! Adv label: 3, L2: 723.39, Queries: 59
# Attacking sample 65/100 (True: 2, Index: 631)...
#   Success! Adv label: 3, L2: 490.16, Queries: 43
# Attacking sample 66/100 (True: 2, Index: 636)...
#   Success! Adv label: 3, L2: 860.48, Queries: 71
# Attacking sample 67/100 (True: 2, Index: 647)...
#   Success! Adv label: 1, L2: 132.43, Queries: 13
# Attacking sample 68/100 (True: 2, Index: 650)...
#   Success! Adv label: 3, L2: 223.22, Queries: 19
# Attacking sample 69/100 (True: 2, Index: 664)...
#   Success! Adv label: 8, L2: 979.40, Queries: 83
# Attacking sample 70/100 (True: 2, Index: 704)...
#   Success! Adv label: 3, L2: 667.97, Queries: 57
# Attacking sample 71/100 (True: 2, Index: 720)...
#   Success! Adv label: 4, L2: 228.80, Queries: 19
# Attacking sample 72/100 (True: 2, Index: 725)...
#   Success! Adv label: 3, L2: 485.51, Queries: 41
# Attacking sample 73/100 (True: 2, Index: 750)...
#   Success! Adv label: 7, L2: 938.12, Queries: 101
# Attacking sample 74/100 (True: 2, Index: 764)...
#   Success! Adv label: 3, L2: 681.81, Queries: 75
# Attacking sample 75/100 (True: 2, Index: 780)...
#   Success! Adv label: 8, L2: 766.13, Queries: 61
# Attacking sample 76/100 (True: 2, Index: 784)...
#   Success! Adv label: 8, L2: 899.03, Queries: 75
# Attacking sample 77/100 (True: 2, Index: 788)...
#   Success! Adv label: 1, L2: 567.70, Queries: 49
# Attacking sample 78/100 (True: 2, Index: 790)...
#   Success! Adv label: 3, L2: 891.62, Queries: 85
# Attacking sample 79/100 (True: 2, Index: 797)...
#   Success! Adv label: 8, L2: 588.44, Queries: 47
# Attacking sample 80/100 (True: 2, Index: 803)...
#   Success! Adv label: 0, L2: 904.69, Queries: 77
# Attacking sample 81/100 (True: 2, Index: 807)...
#   Success! Adv label: 1, L2: 983.74, Queries: 99
# Attacking sample 82/100 (True: 2, Index: 828)...
#   Success! Adv label: 3, L2: 442.88, Queries: 37
# Attacking sample 83/100 (True: 2, Index: 842)...
#   Success! Adv label: 3, L2: 711.88, Queries: 65
# Attacking sample 84/100 (True: 2, Index: 845)...
#   Success! Adv label: 3, L2: 925.92, Queries: 75
# Attacking sample 85/100 (True: 2, Index: 859)...
#   Success! Adv label: 3, L2: 470.20, Queries: 39
# Attacking sample 86/100 (True: 2, Index: 871)...
#   Success! Adv label: 1, L2: 707.91, Queries: 65
# Attacking sample 87/100 (True: 2, Index: 881)...
#   Success! Adv label: 3, L2: 659.60, Queries: 69
# Attacking sample 88/100 (True: 2, Index: 883)...
#   Success! Adv label: 8, L2: 372.36, Queries: 31
# Attacking sample 89/100 (True: 2, Index: 896)...
#   Success! Adv label: 3, L2: 556.52, Queries: 47
# Attacking sample 90/100 (True: 2, Index: 897)...
#   Success! Adv label: 3, L2: 547.11, Queries: 55
# Attacking sample 92/100 (True: 2, Index: 922)...
#   Success! Adv label: 7, L2: 539.90, Queries: 49
# Attacking sample 93/100 (True: 2, Index: 932)...
#   Success! Adv label: 8, L2: 721.46, Queries: 59
# Attacking sample 94/100 (True: 2, Index: 944)...
#   Success! Adv label: 3, L2: 545.74, Queries: 45
# Attacking sample 95/100 (True: 2, Index: 949)...
#   Success! Adv label: 3, L2: 757.34, Queries: 63
# Attacking sample 96/100 (True: 2, Index: 952)...
#   Failed! Adv label: 2, L2: 1081.93, Queries: 201
# Attacking sample 97/100 (True: 2, Index: 959)...
#   Success! Adv label: 3, L2: 584.96, Queries: 47
# Attacking sample 98/100 (True: 2, Index: 966)...
#   Success! Adv label: 7, L2: 186.13, Queries: 17
# Attacking sample 99/100 (True: 2, Index: 967)...
#   Success! Adv label: 7, L2: 748.77, Queries: 69
# Attacking sample 100/100 (True: 2, Index: 985)...
#   Success! Adv label: 3, L2: 634.78, Queries: 59
# Attacking sample 1/100 (True: 3, Index: 1)...
#   Success! Adv label: 5, L2: 332.23, Queries: 27
# Attacking sample 2/100 (True: 3, Index: 12)...
#   Success! Adv label: 5, L2: 337.54, Queries: 29
# Attacking sample 3/100 (True: 3, Index: 20)...
#   Success! Adv label: 9, L2: 671.03, Queries: 53
# Attacking sample 4/100 (True: 3, Index: 27)...
#   Success! Adv label: 5, L2: 936.45, Queries: 93
# Attacking sample 5/100 (True: 3, Index: 37)...
#   Success! Adv label: 0, L2: 916.97, Queries: 87
# Attacking sample 6/100 (True: 3, Index: 43)...
#   Failed! Adv label: 3, L2: 1002.83, Queries: 201
# Attacking sample 7/100 (True: 3, Index: 53)...
#   Success! Adv label: 8, L2: 547.35, Queries: 43
# Attacking sample 8/100 (True: 3, Index: 61)...
#   Success! Adv label: 8, L2: 589.11, Queries: 47
# Attacking sample 9/100 (True: 3, Index: 73)...
#   Success! Adv label: 8, L2: 590.62, Queries: 53
# Attacking sample 10/100 (True: 3, Index: 102)...
#   Success! Adv label: 2, L2: 409.89, Queries: 35
# Attacking sample 11/100 (True: 3, Index: 108)...
#   Success! Adv label: 2, L2: 83.58, Queries: 7
# Attacking sample 12/100 (True: 3, Index: 109)...
#   Success! Adv label: 8, L2: 531.69, Queries: 41
# Attacking sample 13/100 (True: 3, Index: 117)...
#   Success! Adv label: 5, L2: 890.26, Queries: 103
# Attacking sample 14/100 (True: 3, Index: 131)...
#   Success! Adv label: 8, L2: 144.90, Queries: 11
# Attacking sample 15/100 (True: 3, Index: 159)...
#   Success! Adv label: 2, L2: 858.67, Queries: 81
# Attacking sample 16/100 (True: 3, Index: 162)...
#   Success! Adv label: 2, L2: 1023.72, Queries: 183
# Attacking sample 17/100 (True: 3, Index: 166)...
#   Success! Adv label: 7, L2: 800.66, Queries: 87
# Attacking sample 18/100 (True: 3, Index: 177)...
#   Success! Adv label: 8, L2: 541.75, Queries: 41
# Attacking sample 19/100 (True: 3, Index: 181)...
#   Success! Adv label: 5, L2: 511.31, Queries: 47
# Attacking sample 20/100 (True: 3, Index: 187)...
#   Success! Adv label: 8, L2: 626.00, Queries: 47
# Attacking sample 21/100 (True: 3, Index: 196)...
#   Success! Adv label: 2, L2: 481.15, Queries: 37
# Attacking sample 22/100 (True: 3, Index: 204)...
#   Success! Adv label: 5, L2: 911.97, Queries: 89
# Attacking sample 23/100 (True: 3, Index: 227)...
#   Failed! Adv label: 3, L2: 1016.89, Queries: 201
# Attacking sample 24/100 (True: 3, Index: 231)...
#   Success! Adv label: 5, L2: 650.47, Queries: 55
# Attacking sample 25/100 (True: 3, Index: 237)...
#   Success! Adv label: 5, L2: 940.59, Queries: 91
# Attacking sample 26/100 (True: 3, Index: 244)...
#   Success! Adv label: 7, L2: 816.98, Queries: 81
# Attacking sample 27/100 (True: 3, Index: 257)...
#   Success! Adv label: 8, L2: 549.89, Queries: 43
# Attacking sample 28/100 (True: 3, Index: 259)...
#   Success! Adv label: 5, L2: 823.92, Queries: 79
# Attacking sample 29/100 (True: 3, Index: 265)...
#   Success! Adv label: 5, L2: 501.23, Queries: 41
# Attacking sample 30/100 (True: 3, Index: 270)...
#   Success! Adv label: 5, L2: 236.38, Queries: 19
# Attacking sample 31/100 (True: 3, Index: 288)...
#   Success! Adv label: 8, L2: 963.24, Queries: 75
# Attacking sample 32/100 (True: 3, Index: 308)...
#   Success! Adv label: 8, L2: 533.04, Queries: 43
# Attacking sample 33/100 (True: 3, Index: 309)...
#   Success! Adv label: 8, L2: 535.58, Queries: 43
# Attacking sample 34/100 (True: 3, Index: 327)...
#   Success! Adv label: 1, L2: 360.20, Queries: 35
# Attacking sample 35/100 (True: 3, Index: 331)...
#   Success! Adv label: 8, L2: 787.75, Queries: 69
# Attacking sample 36/100 (True: 3, Index: 340)...
#   Success! Adv label: 2, L2: 965.58, Queries: 87
# Attacking sample 37/100 (True: 3, Index: 341)...
#   Success! Adv label: 5, L2: 634.27, Queries: 55
# Attacking sample 38/100 (True: 3, Index: 342)...
#   Success! Adv label: 5, L2: 460.43, Queries: 39
# Attacking sample 39/100 (True: 3, Index: 362)...
#   Success! Adv label: 2, L2: 531.46, Queries: 45
# Attacking sample 40/100 (True: 3, Index: 383)...
#   Success! Adv label: 2, L2: 508.53, Queries: 43
# Attacking sample 41/100 (True: 3, Index: 394)...
#   Success! Adv label: 8, L2: 468.95, Queries: 37
# Attacking sample 42/100 (True: 3, Index: 406)...
#   Success! Adv label: 2, L2: 986.30, Queries: 175
# Attacking sample 43/100 (True: 3, Index: 409)...
#   Success! Adv label: 2, L2: 819.60, Queries: 75
# Attacking sample 44/100 (True: 3, Index: 445)...
#   Success! Adv label: 2, L2: 386.63, Queries: 31
# Attacking sample 45/100 (True: 3, Index: 456)...
#   Success! Adv label: 8, L2: 531.91, Queries: 41
# Attacking sample 46/100 (True: 3, Index: 459)...
#   Success! Adv label: 4, L2: 980.34, Queries: 107
# Attacking sample 47/100 (True: 3, Index: 461)...
#   Failed! Adv label: 3, L2: 1138.68, Queries: 201
# Attacking sample 48/100 (True: 3, Index: 471)...
#   Success! Adv label: 8, L2: 863.13, Queries: 69
# Attacking sample 49/100 (True: 3, Index: 474)...
#   Success! Adv label: 5, L2: 499.03, Queries: 43
# Attacking sample 50/100 (True: 3, Index: 481)...
#   Success! Adv label: 5, L2: 792.55, Queries: 77
# Attacking sample 51/100 (True: 3, Index: 504)...
#   Success! Adv label: 5, L2: 634.08, Queries: 55
# Attacking sample 52/100 (True: 3, Index: 510)...
#   Success! Adv label: 5, L2: 305.40, Queries: 25
# Attacking sample 53/100 (True: 3, Index: 512)...
#   Failed! Adv label: 3, L2: 913.11, Queries: 201
# Attacking sample 54/100 (True: 3, Index: 524)...
#   Success! Adv label: 8, L2: 594.77, Queries: 45
# Attacking sample 55/100 (True: 3, Index: 549)...
#   Success! Adv label: 8, L2: 480.65, Queries: 43
# Attacking sample 56/100 (True: 3, Index: 556)...
#   Success! Adv label: 9, L2: 580.85, Queries: 51
# Attacking sample 57/100 (True: 3, Index: 564)...
#   Success! Adv label: 8, L2: 451.84, Queries: 35
# Attacking sample 58/100 (True: 3, Index: 586)...
#   Failed! Adv label: 3, L2: 1048.69, Queries: 201
# Attacking sample 59/100 (True: 3, Index: 589)...
#   Success! Adv label: 8, L2: 1156.32, Queries: 113
# Attacking sample 60/100 (True: 3, Index: 609)...
#   Success! Adv label: 9, L2: 704.65, Queries: 61
# Attacking sample 61/100 (True: 3, Index: 613)...
#   Success! Adv label: 2, L2: 695.77, Queries: 55
# Attacking sample 62/100 (True: 3, Index: 623)...
#   Success! Adv label: 9, L2: 422.84, Queries: 33
# Attacking sample 63/100 (True: 3, Index: 639)...
#   Success! Adv label: 5, L2: 597.48, Queries: 53
# Attacking sample 64/100 (True: 3, Index: 648)...
#   Success! Adv label: 8, L2: 422.70, Queries: 33
# Attacking sample 65/100 (True: 3, Index: 651)...
#   Success! Adv label: 8, L2: 396.59, Queries: 31
# Attacking sample 66/100 (True: 3, Index: 659)...
#   Success! Adv label: 9, L2: 650.34, Queries: 59
# Attacking sample 67/100 (True: 3, Index: 661)...
#   Success! Adv label: 5, L2: 1046.92, Queries: 87
# Attacking sample 68/100 (True: 3, Index: 667)...
#   Failed! Adv label: 3, L2: 993.32, Queries: 201
# Attacking sample 69/100 (True: 3, Index: 678)...
#   Success! Adv label: 4, L2: 865.83, Queries: 113
# Attacking sample 70/100 (True: 3, Index: 690)...
#   Success! Adv label: 8, L2: 886.27, Queries: 67
# Attacking sample 71/100 (True: 3, Index: 693)...
#   Failed! Adv label: 3, L2: 952.76, Queries: 201
# Attacking sample 72/100 (True: 3, Index: 694)...
#   Success! Adv label: 8, L2: 747.83, Queries: 59
# Attacking sample 73/100 (True: 3, Index: 695)...
#   Success! Adv label: 2, L2: 255.70, Queries: 21
# Attacking sample 74/100 (True: 3, Index: 702)...
#   Success! Adv label: 8, L2: 392.64, Queries: 29
# Attacking sample 75/100 (True: 3, Index: 718)...
#   Success! Adv label: 2, L2: 974.42, Queries: 91
# Attacking sample 76/100 (True: 3, Index: 749)...
#   Success! Adv label: 9, L2: 806.97, Queries: 77
# Attacking sample 77/100 (True: 3, Index: 769)...
#   Success! Adv label: 9, L2: 749.38, Queries: 59
# Attacking sample 79/100 (True: 3, Index: 779)...
#   Success! Adv label: 8, L2: 446.07, Queries: 37
# Attacking sample 80/100 (True: 3, Index: 800)...
#   Success! Adv label: 8, L2: 842.71, Queries: 63
# Attacking sample 81/100 (True: 3, Index: 816)...
#   Success! Adv label: 5, L2: 265.60, Queries: 23
# Attacking sample 82/100 (True: 3, Index: 829)...
#   Success! Adv label: 2, L2: 511.52, Queries: 43
# Attacking sample 83/100 (True: 3, Index: 833)...
#   Success! Adv label: 7, L2: 959.06, Queries: 165
# Attacking sample 84/100 (True: 3, Index: 839)...
#   Success! Adv label: 8, L2: 662.81, Queries: 55
# Attacking sample 85/100 (True: 3, Index: 854)...
#   Success! Adv label: 5, L2: 301.45, Queries: 25
# Attacking sample 86/100 (True: 3, Index: 856)...
#   Success! Adv label: 2, L2: 396.61, Queries: 35
# Attacking sample 87/100 (True: 3, Index: 858)...
#   Success! Adv label: 5, L2: 96.73, Queries: 9
# Attacking sample 89/100 (True: 3, Index: 886)...
#   Success! Adv label: 8, L2: 851.56, Queries: 69
# Attacking sample 90/100 (True: 3, Index: 900)...
#   Success! Adv label: 8, L2: 688.27, Queries: 55
# Attacking sample 91/100 (True: 3, Index: 916)...
#   Success! Adv label: 5, L2: 435.45, Queries: 41
# Attacking sample 92/100 (True: 3, Index: 921)...
#   Success! Adv label: 2, L2: 433.06, Queries: 39
# Attacking sample 93/100 (True: 3, Index: 937)...
#   Success! Adv label: 8, L2: 822.62, Queries: 65
# Attacking sample 94/100 (True: 3, Index: 938)...
#   Success! Adv label: 8, L2: 700.19, Queries: 51
# Attacking sample 95/100 (True: 3, Index: 939)...
#   Success! Adv label: 8, L2: 327.80, Queries: 25
# Attacking sample 96/100 (True: 3, Index: 942)...
#   Success! Adv label: 5, L2: 942.54, Queries: 91
# Attacking sample 97/100 (True: 3, Index: 951)...
#   Success! Adv label: 8, L2: 593.16, Queries: 49
# Attacking sample 98/100 (True: 3, Index: 953)...
#   Success! Adv label: 4, L2: 1029.78, Queries: 155
# Attacking sample 99/100 (True: 3, Index: 975)...
#   Success! Adv label: 5, L2: 1095.41, Queries: 157
# Attacking sample 1/100 (True: 4, Index: 16)...
#   Success! Adv label: 9, L2: 310.47, Queries: 25
# Attacking sample 2/100 (True: 4, Index: 17)...
#   Success! Adv label: 6, L2: 407.58, Queries: 35
# Attacking sample 3/100 (True: 4, Index: 30)...
#   Success! Adv label: 8, L2: 731.07, Queries: 59
# Attacking sample 4/100 (True: 4, Index: 33)...
#   Success! Adv label: 9, L2: 507.21, Queries: 43
# Attacking sample 5/100 (True: 4, Index: 45)...
#   Success! Adv label: 8, L2: 144.90, Queries: 11
# Attacking sample 6/100 (True: 4, Index: 48)...
#   Success! Adv label: 9, L2: 735.21, Queries: 61
# Attacking sample 7/100 (True: 4, Index: 58)...
#   Success! Adv label: 9, L2: 698.61, Queries: 55
# Attacking sample 8/100 (True: 4, Index: 66)...
#   Success! Adv label: 6, L2: 578.73, Queries: 51
# Attacking sample 9/100 (True: 4, Index: 89)...
#   Success! Adv label: 9, L2: 346.78, Queries: 27
# Attacking sample 10/100 (True: 4, Index: 92)...
#   Success! Adv label: 6, L2: 811.24, Queries: 69
# Attacking sample 11/100 (True: 4, Index: 113)...
#   Success! Adv label: 9, L2: 637.28, Queries: 51
# Attacking sample 12/100 (True: 4, Index: 116)...
#   Success! Adv label: 9, L2: 583.78, Queries: 45
# Attacking sample 13/100 (True: 4, Index: 126)...
#   Success! Adv label: 9, L2: 434.23, Queries: 33
# Attacking sample 14/100 (True: 4, Index: 130)...
#   Success! Adv label: 9, L2: 326.12, Queries: 25
# Attacking sample 15/100 (True: 4, Index: 139)...
#   Success! Adv label: 9, L2: 501.44, Queries: 39
# Attacking sample 16/100 (True: 4, Index: 149)...
#   Success! Adv label: 2, L2: 1000.66, Queries: 89
# Attacking sample 17/100 (True: 4, Index: 153)...
#   Success! Adv label: 8, L2: 472.36, Queries: 39
# Attacking sample 18/100 (True: 4, Index: 154)...
#   Success! Adv label: 7, L2: 829.32, Queries: 69
# Attacking sample 19/100 (True: 4, Index: 163)...
#   Success! Adv label: 9, L2: 515.94, Queries: 41
# Attacking sample 20/100 (True: 4, Index: 167)...
#   Success! Adv label: 9, L2: 633.35, Queries: 51
# Attacking sample 21/100 (True: 4, Index: 183)...
#   Success! Adv label: 9, L2: 386.92, Queries: 33
# Attacking sample 22/100 (True: 4, Index: 184)...
#   Success! Adv label: 9, L2: 536.81, Queries: 43
# Attacking sample 23/100 (True: 4, Index: 192)...
#   Success! Adv label: 9, L2: 287.13, Queries: 23
# Attacking sample 24/100 (True: 4, Index: 194)...
#   Success! Adv label: 9, L2: 485.65, Queries: 41
# Attacking sample 25/100 (True: 4, Index: 233)...
#   Success! Adv label: 9, L2: 657.76, Queries: 55
# Attacking sample 26/100 (True: 4, Index: 240)...
#   Success! Adv label: 8, L2: 572.17, Queries: 43
# Attacking sample 27/100 (True: 4, Index: 263)...
#   Success! Adv label: 9, L2: 245.18, Queries: 19
# Attacking sample 28/100 (True: 4, Index: 269)...
#   Success! Adv label: 9, L2: 384.93, Queries: 31
# Attacking sample 29/100 (True: 4, Index: 280)...
#   Success! Adv label: 9, L2: 375.02, Queries: 29
# Attacking sample 30/100 (True: 4, Index: 290)...
#   Success! Adv label: 9, L2: 599.05, Queries: 45
# Attacking sample 31/100 (True: 4, Index: 297)...
#   Success! Adv label: 6, L2: 408.56, Queries: 35
# Attacking sample 32/100 (True: 4, Index: 299)...
#   Success! Adv label: 9, L2: 372.99, Queries: 29
# Attacking sample 33/100 (True: 4, Index: 310)...
#   Success! Adv label: 9, L2: 320.01, Queries: 25
# Attacking sample 34/100 (True: 4, Index: 316)...
#   Success! Adv label: 9, L2: 449.48, Queries: 35
# Attacking sample 35/100 (True: 4, Index: 320)...
#   Success! Adv label: 9, L2: 427.94, Queries: 35
# Attacking sample 36/100 (True: 4, Index: 324)...
#   Success! Adv label: 9, L2: 456.27, Queries: 37
# Attacking sample 37/100 (True: 4, Index: 326)...
#   Success! Adv label: 9, L2: 516.11, Queries: 43
# Attacking sample 38/100 (True: 4, Index: 332)...
#   Success! Adv label: 9, L2: 32.16, Queries: 3
# Attacking sample 39/100 (True: 4, Index: 335)...
#   Success! Adv label: 9, L2: 669.62, Queries: 53
# Attacking sample 40/100 (True: 4, Index: 344)...
#   Success! Adv label: 7, L2: 510.25, Queries: 43
# Attacking sample 42/100 (True: 4, Index: 359)...
#   Success! Adv label: 9, L2: 421.83, Queries: 33
# Attacking sample 43/100 (True: 4, Index: 376)...
#   Success! Adv label: 9, L2: 577.87, Queries: 47
# Attacking sample 44/100 (True: 4, Index: 393)...
#   Success! Adv label: 9, L2: 508.36, Queries: 39
# Attacking sample 45/100 (True: 4, Index: 401)...
#   Success! Adv label: 2, L2: 656.84, Queries: 55
# Attacking sample 46/100 (True: 4, Index: 402)...
#   Success! Adv label: 9, L2: 482.06, Queries: 39
# Attacking sample 47/100 (True: 4, Index: 422)...
#   Success! Adv label: 9, L2: 358.14, Queries: 27
# Attacking sample 48/100 (True: 4, Index: 423)...
#   Success! Adv label: 9, L2: 180.84, Queries: 15
# Attacking sample 49/100 (True: 4, Index: 427)...
#   Success! Adv label: 1, L2: 516.86, Queries: 47
# Attacking sample 50/100 (True: 4, Index: 432)...
#   Success! Adv label: 9, L2: 381.90, Queries: 31
# Attacking sample 51/100 (True: 4, Index: 434)...
#   Success! Adv label: 9, L2: 301.92, Queries: 23
# Attacking sample 52/100 (True: 4, Index: 454)...
#   Success! Adv label: 9, L2: 551.58, Queries: 45
# Attacking sample 53/100 (True: 4, Index: 467)...
#   Success! Adv label: 8, L2: 342.50, Queries: 27
# Attacking sample 54/100 (True: 4, Index: 501)...
#   Success! Adv label: 9, L2: 282.33, Queries: 23
# Attacking sample 55/100 (True: 4, Index: 515)...
#   Success! Adv label: 9, L2: 346.69, Queries: 27
# Attacking sample 56/100 (True: 4, Index: 540)...
#   Success! Adv label: 9, L2: 597.79, Queries: 49
# Attacking sample 57/100 (True: 4, Index: 544)...
#   Success! Adv label: 0, L2: 428.59, Queries: 37
# Attacking sample 58/100 (True: 4, Index: 545)...
#   Success! Adv label: 9, L2: 360.68, Queries: 29
# Attacking sample 59/100 (True: 4, Index: 547)...
#   Success! Adv label: 7, L2: 823.83, Queries: 81
# Attacking sample 60/100 (True: 4, Index: 566)...
#   Success! Adv label: 9, L2: 404.89, Queries: 31
# Attacking sample 61/100 (True: 4, Index: 590)...
#   Success! Adv label: 0, L2: 453.73, Queries: 37
# Attacking sample 62/100 (True: 4, Index: 593)...
#   Success! Adv label: 9, L2: 343.39, Queries: 27
# Attacking sample 63/100 (True: 4, Index: 599)...
#   Success! Adv label: 9, L2: 674.72, Queries: 61
# Attacking sample 64/100 (True: 4, Index: 602)...
#   Success! Adv label: 9, L2: 521.22, Queries: 41
# Attacking sample 65/100 (True: 4, Index: 607)...
#   Success! Adv label: 7, L2: 585.73, Queries: 57
# Attacking sample 66/100 (True: 4, Index: 611)...
#   Success! Adv label: 9, L2: 635.95, Queries: 51
# Attacking sample 67/100 (True: 4, Index: 617)...
#   Success! Adv label: 9, L2: 518.52, Queries: 39
# Attacking sample 68/100 (True: 4, Index: 657)...
#   Success! Adv label: 9, L2: 335.02, Queries: 29
# Attacking sample 69/100 (True: 4, Index: 680)...
#   Success! Adv label: 9, L2: 376.46, Queries: 29
# Attacking sample 70/100 (True: 4, Index: 684)...
#   Success! Adv label: 9, L2: 620.18, Queries: 55
# Attacking sample 71/100 (True: 4, Index: 687)...
#   Success! Adv label: 9, L2: 536.17, Queries: 41
# Attacking sample 72/100 (True: 4, Index: 692)...
#   Success! Adv label: 9, L2: 822.17, Queries: 67
# Attacking sample 73/100 (True: 4, Index: 696)...
#   Success! Adv label: 9, L2: 186.06, Queries: 15
# Attacking sample 74/100 (True: 4, Index: 697)...
#   Success! Adv label: 9, L2: 805.26, Queries: 63
# Attacking sample 75/100 (True: 4, Index: 708)...
#   Success! Adv label: 9, L2: 551.36, Queries: 43
# Attacking sample 76/100 (True: 4, Index: 717)...
#   Success! Adv label: 9, L2: 361.15, Queries: 29
# Attacking sample 77/100 (True: 4, Index: 746)...
#   Success! Adv label: 9, L2: 457.11, Queries: 37
# Attacking sample 78/100 (True: 4, Index: 752)...
#   Success! Adv label: 9, L2: 991.40, Queries: 81
# Attacking sample 79/100 (True: 4, Index: 755)...
#   Success! Adv label: 7, L2: 865.15, Queries: 89
# Attacking sample 80/100 (True: 4, Index: 757)...
#   Success! Adv label: 9, L2: 418.11, Queries: 33
# Attacking sample 81/100 (True: 4, Index: 766)...
#   Success! Adv label: 7, L2: 496.38, Queries: 45
# Attacking sample 82/100 (True: 4, Index: 771)...
#   Success! Adv label: 9, L2: 288.03, Queries: 23
# Attacking sample 83/100 (True: 4, Index: 776)...
#   Success! Adv label: 2, L2: 581.07, Queries: 49
# Attacking sample 84/100 (True: 4, Index: 777)...
#   Success! Adv label: 1, L2: 949.17, Queries: 95
# Attacking sample 85/100 (True: 4, Index: 786)...
#   Success! Adv label: 9, L2: 194.26, Queries: 15
# Attacking sample 86/100 (True: 4, Index: 811)...
#   Success! Adv label: 9, L2: 262.04, Queries: 21
# Attacking sample 87/100 (True: 4, Index: 815)...
#   Success! Adv label: 6, L2: 659.88, Queries: 55
# Attacking sample 88/100 (True: 4, Index: 817)...
#   Success! Adv label: 8, L2: 777.24, Queries: 71
# Attacking sample 89/100 (True: 4, Index: 840)...
#   Success! Adv label: 6, L2: 689.82, Queries: 57
# Attacking sample 91/100 (True: 4, Index: 849)...
#   Success! Adv label: 8, L2: 664.05, Queries: 53
# Attacking sample 92/100 (True: 4, Index: 857)...
#   Success! Adv label: 9, L2: 516.84, Queries: 41
# Attacking sample 93/100 (True: 4, Index: 872)...
#   Success! Adv label: 9, L2: 679.53, Queries: 59
# Attacking sample 94/100 (True: 4, Index: 877)...
#   Success! Adv label: 9, L2: 414.07, Queries: 35
# Attacking sample 95/100 (True: 4, Index: 894)...
#   Success! Adv label: 9, L2: 257.23, Queries: 21
# Attacking sample 96/100 (True: 4, Index: 902)...
#   Success! Adv label: 9, L2: 398.45, Queries: 31
# Attacking sample 97/100 (True: 4, Index: 911)...
#   Success! Adv label: 9, L2: 563.21, Queries: 47
# ...
#   Success! Adv label: 3, L2: 545.26, Queries: 47
# Attacking sample 40/100 (True: 8, Index: 505)...
#   Success! Adv label: 2, L2: 711.68, Queries: 63
# Attacking sample 41/100 (True: 8, Index: 509)...
#   Success! Adv label: 3, L2: 678.66, Queries: 71
# Attacking sample 42/100 (True: 8, Index: 525)...
#   Success! Adv label: 3, L2: 591.94, Queries: 55
# Attacking sample 43/100 (True: 8, Index: 528)...
#   Success! Adv label: 3, L2: 731.01, Queries: 73
# Attacking sample 44/100 (True: 8, Index: 541)...
#   Success! Adv label: 3, L2: 847.07, Queries: 77
# Attacking sample 45/100 (True: 8, Index: 543)...
#   Success! Adv label: 6, L2: 374.84, Queries: 33
# Attacking sample 46/100 (True: 8, Index: 550)...
#   Success! Adv label: 5, L2: 508.52, Queries: 45
# Attacking sample 47/100 (True: 8, Index: 558)...
#   Success! Adv label: 2, L2: 783.63, Queries: 71
# Attacking sample 48/100 (True: 8, Index: 575)...
#   Success! Adv label: 9, L2: 461.93, Queries: 41
# Attacking sample 49/100 (True: 8, Index: 594)...
#   Success! Adv label: 2, L2: 403.35, Queries: 37
# Attacking sample 50/100 (True: 8, Index: 600)...
#   Success! Adv label: 3, L2: 1039.98, Queries: 93
# Attacking sample 51/100 (True: 8, Index: 605)...
#   Success! Adv label: 2, L2: 624.69, Queries: 55
# Attacking sample 52/100 (True: 8, Index: 619)...
#   Success! Adv label: 3, L2: 551.07, Queries: 51
# Attacking sample 53/100 (True: 8, Index: 625)...
#   Success! Adv label: 3, L2: 763.96, Queries: 65
# Attacking sample 54/100 (True: 8, Index: 629)...
#   Success! Adv label: 2, L2: 519.86, Queries: 43
# Attacking sample 55/100 (True: 8, Index: 645)...
#   Success! Adv label: 9, L2: 997.06, Queries: 93
# Attacking sample 56/100 (True: 8, Index: 652)...
#   Success! Adv label: 2, L2: 637.55, Queries: 61
# Attacking sample 57/100 (True: 8, Index: 672)...
#   Success! Adv label: 3, L2: 581.89, Queries: 59
# Attacking sample 58/100 (True: 8, Index: 683)...
#   Success! Adv label: 3, L2: 363.06, Queries: 37
# Attacking sample 59/100 (True: 8, Index: 701)...
#   Success! Adv label: 5, L2: 746.89, Queries: 73
# Attacking sample 60/100 (True: 8, Index: 714)...
#   Success! Adv label: 3, L2: 642.96, Queries: 63
# Attacking sample 61/100 (True: 8, Index: 721)...
#   Success! Adv label: 3, L2: 487.49, Queries: 45
# Attacking sample 62/100 (True: 8, Index: 730)...
#   Success! Adv label: 2, L2: 612.62, Queries: 53
# Attacking sample 63/100 (True: 8, Index: 731)...
#   Failed! Adv label: 8, L2: 1151.40, Queries: 201
# Attacking sample 64/100 (True: 8, Index: 738)...
#   Success! Adv label: 3, L2: 707.50, Queries: 71
# Attacking sample 65/100 (True: 8, Index: 791)...
#   Success! Adv label: 5, L2: 733.15, Queries: 69
# Attacking sample 66/100 (True: 8, Index: 832)...
#   Success! Adv label: 6, L2: 566.96, Queries: 51
# Attacking sample 67/100 (True: 8, Index: 838)...
#   Success! Adv label: 5, L2: 546.97, Queries: 51
# Attacking sample 68/100 (True: 8, Index: 860)...
#   Success! Adv label: 3, L2: 689.59, Queries: 67
# Attacking sample 69/100 (True: 8, Index: 864)...
#   Success! Adv label: 9, L2: 790.85, Queries: 77
# Attacking sample 70/100 (True: 8, Index: 889)...
#   Success! Adv label: 3, L2: 631.65, Queries: 61
# Attacking sample 71/100 (True: 8, Index: 905)...
#   Success! Adv label: 9, L2: 755.17, Queries: 73
# Attacking sample 73/100 (True: 8, Index: 919)...
#   Success! Adv label: 3, L2: 577.23, Queries: 53
# Attacking sample 74/100 (True: 8, Index: 923)...
#   Success! Adv label: 3, L2: 683.91, Queries: 63
# Attacking sample 75/100 (True: 8, Index: 926)...
#   Success! Adv label: 5, L2: 666.02, Queries: 61
# Attacking sample 76/100 (True: 8, Index: 933)...
#   Success! Adv label: 3, L2: 647.68, Queries: 61
# Attacking sample 78/100 (True: 8, Index: 971)...
#   Success! Adv label: 2, L2: 765.56, Queries: 69
# Attacking sample 79/100 (True: 8, Index: 1014)...
#   Success! Adv label: 3, L2: 603.04, Queries: 59
# Attacking sample 80/100 (True: 8, Index: 1034)...
#   Success! Adv label: 6, L2: 761.30, Queries: 73
# Attacking sample 81/100 (True: 8, Index: 1053)...
#   Success! Adv label: 6, L2: 590.08, Queries: 55
# Attacking sample 82/100 (True: 8, Index: 1057)...
#   Success! Adv label: 6, L2: 468.10, Queries: 37
# Attacking sample 83/100 (True: 8, Index: 1061)...
#   Success! Adv label: 1, L2: 849.71, Queries: 93
# Attacking sample 84/100 (True: 8, Index: 1062)...
#   Success! Adv label: 3, L2: 619.56, Queries: 61
# Attacking sample 85/100 (True: 8, Index: 1063)...
#   Success! Adv label: 3, L2: 660.26, Queries: 59
# Attacking sample 86/100 (True: 8, Index: 1078)...
#   Success! Adv label: 9, L2: 368.15, Queries: 29
# Attacking sample 87/100 (True: 8, Index: 1088)...
#   Success! Adv label: 2, L2: 762.63, Queries: 71
# Attacking sample 88/100 (True: 8, Index: 1100)...
#   Success! Adv label: 0, L2: 1079.05, Queries: 99
# Attacking sample 89/100 (True: 8, Index: 1106)...
#   Success! Adv label: 2, L2: 1033.31, Queries: 97
# Attacking sample 90/100 (True: 8, Index: 1120)...
#   Success! Adv label: 3, L2: 549.58, Queries: 51
# Attacking sample 91/100 (True: 8, Index: 1132)...
#   Success! Adv label: 2, L2: 663.46, Queries: 59
# Attacking sample 92/100 (True: 8, Index: 1134)...
#   Success! Adv label: 6, L2: 1099.61, Queries: 127
# Attacking sample 93/100 (True: 8, Index: 1140)...
#   Success! Adv label: 5, L2: 320.82, Queries: 29
# Attacking sample 94/100 (True: 8, Index: 1150)...
#   Success! Adv label: 9, L2: 598.49, Queries: 53
# Attacking sample 95/100 (True: 8, Index: 1165)...
#   Success! Adv label: 3, L2: 774.53, Queries: 71
# Attacking sample 96/100 (True: 8, Index: 1179)...
#   Success! Adv label: 3, L2: 638.60, Queries: 59
# Attacking sample 97/100 (True: 8, Index: 1182)...
#   Success! Adv label: 9, L2: 555.62, Queries: 49
# Attacking sample 98/100 (True: 8, Index: 1186)...
#   Success! Adv label: 2, L2: 802.96, Queries: 69
# Attacking sample 99/100 (True: 8, Index: 1189)...
#   Success! Adv label: 3, L2: 267.19, Queries: 25
# Attacking sample 100/100 (True: 8, Index: 1207)...
#   Success! Adv label: 9, L2: 712.30, Queries: 61
# Attacking sample 1/100 (True: 9, Index: 6)...
#   Success! Adv label: 7, L2: 346.32, Queries: 31
# Attacking sample 2/100 (True: 9, Index: 38)...
#   Success! Adv label: 7, L2: 77.74, Queries: 7
# Attacking sample 3/100 (True: 9, Index: 55)...
#   Success! Adv label: 0, L2: 147.15, Queries: 13
# Attacking sample 4/100 (True: 9, Index: 56)...
#   Success! Adv label: 4, L2: 435.78, Queries: 39
# Attacking sample 5/100 (True: 9, Index: 91)...
#   Success! Adv label: 3, L2: 306.40, Queries: 25
# Attacking sample 6/100 (True: 9, Index: 99)...
#   Success! Adv label: 7, L2: 475.47, Queries: 45
# Attacking sample 7/100 (True: 9, Index: 101)...
#   Success! Adv label: 5, L2: 694.73, Queries: 63
# Attacking sample 8/100 (True: 9, Index: 114)...
#   Success! Adv label: 8, L2: 706.34, Queries: 57
# Attacking sample 9/100 (True: 9, Index: 133)...
#   Success! Adv label: 8, L2: 661.57, Queries: 53
# Attacking sample 10/100 (True: 9, Index: 171)...
#   Success! Adv label: 8, L2: 107.98, Queries: 9
# Attacking sample 11/100 (True: 9, Index: 179)...
#   Success! Adv label: 7, L2: 666.20, Queries: 67
# Attacking sample 12/100 (True: 9, Index: 195)...
#   Success! Adv label: 1, L2: 227.06, Queries: 19
# Attacking sample 13/100 (True: 9, Index: 214)...
#   Success! Adv label: 4, L2: 501.68, Queries: 47
# Attacking sample 14/100 (True: 9, Index: 218)...
#   Success! Adv label: 4, L2: 369.97, Queries: 33
# Attacking sample 15/100 (True: 9, Index: 222)...
#   Success! Adv label: 8, L2: 389.96, Queries: 33
# Attacking sample 16/100 (True: 9, Index: 224)...
#   Success! Adv label: 6, L2: 513.35, Queries: 43
# Attacking sample 17/100 (True: 9, Index: 238)...
#   Success! Adv label: 4, L2: 491.09, Queries: 41
# Attacking sample 18/100 (True: 9, Index: 243)...
#   Success! Adv label: 8, L2: 675.86, Queries: 57
# Attacking sample 19/100 (True: 9, Index: 245)...
#   Success! Adv label: 4, L2: 506.41, Queries: 47
# Attacking sample 20/100 (True: 9, Index: 246)...
#   Success! Adv label: 8, L2: 633.93, Queries: 49
# Attacking sample 21/100 (True: 9, Index: 251)...
#   Success! Adv label: 7, L2: 285.00, Queries: 25
# Attacking sample 22/100 (True: 9, Index: 303)...
#   Success! Adv label: 4, L2: 299.28, Queries: 27
# Attacking sample 23/100 (True: 9, Index: 305)...
#   Success! Adv label: 8, L2: 276.14, Queries: 23
# Attacking sample 24/100 (True: 9, Index: 307)...
#   Success! Adv label: 4, L2: 591.09, Queries: 59
# Attacking sample 25/100 (True: 9, Index: 315)...
#   Success! Adv label: 8, L2: 721.08, Queries: 61
# Attacking sample 26/100 (True: 9, Index: 354)...
#   Success! Adv label: 4, L2: 553.32, Queries: 51
# Attacking sample 27/100 (True: 9, Index: 364)...
#   Success! Adv label: 8, L2: 668.60, Queries: 59
# Attacking sample 28/100 (True: 9, Index: 389)...
#   Success! Adv label: 4, L2: 352.34, Queries: 31
# Attacking sample 29/100 (True: 9, Index: 407)...
#   Success! Adv label: 8, L2: 291.39, Queries: 23
# Attacking sample 30/100 (True: 9, Index: 411)...
#   Success! Adv label: 4, L2: 234.68, Queries: 19
# Attacking sample 31/100 (True: 9, Index: 417)...
#   Success! Adv label: 7, L2: 387.88, Queries: 39
# Attacking sample 32/100 (True: 9, Index: 421)...
#   Success! Adv label: 4, L2: 431.28, Queries: 37
# Attacking sample 33/100 (True: 9, Index: 438)...
#   Success! Adv label: 4, L2: 469.24, Queries: 41
# Attacking sample 34/100 (True: 9, Index: 443)...
#   Success! Adv label: 8, L2: 607.28, Queries: 53
# Attacking sample 35/100 (True: 9, Index: 444)...
#   Success! Adv label: 4, L2: 313.80, Queries: 29
# Attacking sample 36/100 (True: 9, Index: 446)...
#   Success! Adv label: 4, L2: 638.91, Queries: 65
# Attacking sample 37/100 (True: 9, Index: 455)...
#   Success! Adv label: 7, L2: 326.30, Queries: 31
# Attacking sample 38/100 (True: 9, Index: 469)...
#   Success! Adv label: 4, L2: 914.21, Queries: 83
# Attacking sample 39/100 (True: 9, Index: 472)...
#   Success! Adv label: 3, L2: 725.00, Queries: 61
# Attacking sample 40/100 (True: 9, Index: 473)...
#   Success! Adv label: 4, L2: 698.72, Queries: 61
# Attacking sample 41/100 (True: 9, Index: 482)...
#   Success! Adv label: 4, L2: 490.93, Queries: 41
# Attacking sample 42/100 (True: 9, Index: 490)...
#   Success! Adv label: 8, L2: 856.87, Queries: 75
# Attacking sample 43/100 (True: 9, Index: 496)...
#   Success! Adv label: 4, L2: 433.22, Queries: 39
# Attacking sample 44/100 (True: 9, Index: 507)...
#   Success! Adv label: 8, L2: 434.92, Queries: 35
# Attacking sample 45/100 (True: 9, Index: 508)...
#   Success! Adv label: 7, L2: 504.50, Queries: 45
# Attacking sample 46/100 (True: 9, Index: 514)...
#   Success! Adv label: 4, L2: 210.18, Queries: 17
# Attacking sample 47/100 (True: 9, Index: 522)...
#   Success! Adv label: 4, L2: 82.84, Queries: 7
# Attacking sample 48/100 (True: 9, Index: 535)...
#   Success! Adv label: 4, L2: 487.30, Queries: 45
# Attacking sample 49/100 (True: 9, Index: 542)...
#   Success! Adv label: 8, L2: 389.14, Queries: 35
# Attacking sample 50/100 (True: 9, Index: 553)...
#   Success! Adv label: 4, L2: 650.19, Queries: 61
# Attacking sample 51/100 (True: 9, Index: 554)...
#   Success! Adv label: 4, L2: 816.26, Queries: 73
# Attacking sample 52/100 (True: 9, Index: 565)...
#   Success! Adv label: 0, L2: 422.62, Queries: 37
# Attacking sample 53/100 (True: 9, Index: 569)...
#   Success! Adv label: 4, L2: 497.78, Queries: 45
# Attacking sample 54/100 (True: 9, Index: 572)...
#   Success! Adv label: 5, L2: 364.82, Queries: 31
# Attacking sample 55/100 (True: 9, Index: 574)...
#   Success! Adv label: 8, L2: 428.05, Queries: 37
# Attacking sample 56/100 (True: 9, Index: 601)...
#   Success! Adv label: 8, L2: 394.00, Queries: 31
# Attacking sample 57/100 (True: 9, Index: 634)...
#   Success! Adv label: 5, L2: 454.37, Queries: 37
# Attacking sample 58/100 (True: 9, Index: 635)...
#   Success! Adv label: 4, L2: 630.50, Queries: 65
# Attacking sample 59/100 (True: 9, Index: 637)...
#   Success! Adv label: 4, L2: 581.19, Queries: 51
# Attacking sample 60/100 (True: 9, Index: 640)...
#   Success! Adv label: 4, L2: 553.96, Queries: 49
# Attacking sample 61/100 (True: 9, Index: 653)...
#   Success! Adv label: 8, L2: 634.85, Queries: 51
# Attacking sample 62/100 (True: 9, Index: 654)...
#   Success! Adv label: 4, L2: 579.37, Queries: 51
# Attacking sample 63/100 (True: 9, Index: 656)...
#   Success! Adv label: 4, L2: 624.57, Queries: 55
# Attacking sample 64/100 (True: 9, Index: 666)...
#   Success! Adv label: 4, L2: 455.19, Queries: 43
# Attacking sample 65/100 (True: 9, Index: 685)...
#   Success! Adv label: 7, L2: 702.34, Queries: 71
# Attacking sample 66/100 (True: 9, Index: 711)...
#   Success! Adv label: 4, L2: 229.60, Queries: 19
# Attacking sample 67/100 (True: 9, Index: 729)...
#   Success! Adv label: 8, L2: 523.14, Queries: 43
# Attacking sample 68/100 (True: 9, Index: 739)...
#   Success! Adv label: 4, L2: 466.55, Queries: 41
# Attacking sample 69/100 (True: 9, Index: 747)...
#   Success! Adv label: 8, L2: 414.20, Queries: 35
# Attacking sample 70/100 (True: 9, Index: 767)...
#   Success! Adv label: 8, L2: 486.50, Queries: 41
# Attacking sample 71/100 (True: 9, Index: 783)...
#   Success! Adv label: 5, L2: 561.74, Queries: 51
# Attacking sample 72/100 (True: 9, Index: 787)...
#   Success! Adv label: 8, L2: 605.61, Queries: 47
# Attacking sample 73/100 (True: 9, Index: 796)...
#   Success! Adv label: 7, L2: 441.99, Queries: 39
# Attacking sample 74/100 (True: 9, Index: 804)...
#   Success! Adv label: 7, L2: 684.07, Queries: 73
# Attacking sample 75/100 (True: 9, Index: 818)...
#   Success! Adv label: 4, L2: 632.63, Queries: 63
# Attacking sample 76/100 (True: 9, Index: 825)...
#   Success! Adv label: 8, L2: 369.12, Queries: 31
# Attacking sample 77/100 (True: 9, Index: 826)...
#   Success! Adv label: 1, L2: 168.73, Queries: 15
# Attacking sample 78/100 (True: 9, Index: 831)...
#   Success! Adv label: 4, L2: 538.88, Queries: 45
# Attacking sample 79/100 (True: 9, Index: 880)...
#   Success! Adv label: 5, L2: 536.56, Queries: 43
# Attacking sample 80/100 (True: 9, Index: 884)...
#   Success! Adv label: 4, L2: 499.00, Queries: 43
# Attacking sample 81/100 (True: 9, Index: 891)...
#   Success! Adv label: 4, L2: 127.91, Queries: 11
# Attacking sample 82/100 (True: 9, Index: 893)...
#   Success! Adv label: 2, L2: 678.73, Queries: 67
# Attacking sample 83/100 (True: 9, Index: 899)...
#   Success! Adv label: 4, L2: 473.68, Queries: 43
# Attacking sample 84/100 (True: 9, Index: 912)...
#   Success! Adv label: 5, L2: 556.77, Queries: 45
# Attacking sample 85/100 (True: 9, Index: 920)...
#   Success! Adv label: 4, L2: 630.21, Queries: 57
# Attacking sample 86/100 (True: 9, Index: 925)...
#   Success! Adv label: 8, L2: 372.82, Queries: 29
# Attacking sample 87/100 (True: 9, Index: 940)...
#   Success! Adv label: 4, L2: 345.91, Queries: 33
# Attacking sample 88/100 (True: 9, Index: 958)...
#   Success! Adv label: 4, L2: 511.53, Queries: 43
# Attacking sample 89/100 (True: 9, Index: 969)...
#   Success! Adv label: 8, L2: 420.02, Queries: 33
# Attacking sample 90/100 (True: 9, Index: 978)...
#   Success! Adv label: 4, L2: 497.69, Queries: 47
# Attacking sample 91/100 (True: 9, Index: 979)...
#   Success! Adv label: 4, L2: 399.57, Queries: 33
# Attacking sample 92/100 (True: 9, Index: 980)...
#   Success! Adv label: 8, L2: 373.67, Queries: 33
# Attacking sample 93/100 (True: 9, Index: 991)...
#   Success! Adv label: 7, L2: 556.85, Queries: 57
# Attacking sample 94/100 (True: 9, Index: 997)...
#   Success! Adv label: 4, L2: 246.99, Queries: 23
# Attacking sample 95/100 (True: 9, Index: 1006)...
#   Success! Adv label: 7, L2: 540.67, Queries: 53
# Attacking sample 96/100 (True: 9, Index: 1011)...
#   Success! Adv label: 4, L2: 835.06, Queries: 81
# Attacking sample 97/100 (True: 9, Index: 1020)...
#   Success! Adv label: 8, L2: 511.67, Queries: 45
# Attacking sample 98/100 (True: 9, Index: 1023)...
#   Success! Adv label: 4, L2: 822.91, Queries: 77
# Attacking sample 99/100 (True: 9, Index: 1042)...
#   Success! Adv label: 4, L2: 333.15, Queries: 27
# Attacking sample 100/100 (True: 9, Index: 1046)...
#   Success! Adv label: 4, L2: 380.63, Queries: 35
# Time taken to generate adversarial samples: 110.3214 seconds
#
# Stats saved to: adversarial_8bit_K160_test_images\per_sample_stats.csv
#
# ===== Attack Summary =====
# Total trials: 986
# Misclassified before attack: 14
# Success rate: 965/986 (97.9%)
# Mean L2 (successful): 568.28
# Mean queries (successful): 49.81
#
# Showing successful adversarial examples...

# %% [markdown]
# ### Untargeted Attack on test set; k=170

# %%
import os
import warnings
import numpy as np
import torch
import joblib
import pandas as pd
from PIL import Image
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import torch.nn.functional as F
import time


# Set seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# ─────────────── PATHS ────────────────────────────────────────────────────
LENET_MODEL_PATH = os.path.normpath("Models and Data splits/lenet.pt")  # TorchScript model
DATA_PKL = os.path.normpath("Models and Data splits/data_[SCALED] Train_Test_Splits.pkl")
RF_ALL_CLASSES_PATH = os.path.normpath("Models and Data splits/random_forest.pkl")
OUT_DIR = "adversarial_8bit_K170_test_images"
os.makedirs(OUT_DIR, exist_ok=True)

if not os.path.exists(RF_ALL_CLASSES_PATH):
    raise FileNotFoundError(f"Random Forest model not found at {RF_ALL_CLASSES_PATH}")

# ─────────── HYPER-PARAMETERS ─────────────────────────────────────────────
EPSILON_STEP = 0.01
ITERATIONS = 100
TOTAL_EPSILON = 0.5
TOP_K_FEATURES = 170
SAMPLES_PER_DIGIT = 100
MAX_L2 = 10000

def plot_adversarial_example(original_img, adv_img, true_label, adv_label, l2_mag, sample_idx, queries, title_suffix=""):
    if original_img.size == 784:
        original_img = original_img.reshape(28, 28)
    if adv_img.size == 784:
        adv_img = adv_img.reshape(28, 28)
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(original_img, cmap='gray')
    axes[0].set_title(f"Original\nTrue: {true_label}")
    axes[0].axis('off')
    axes[1].imshow(adv_img, cmap='gray')
    axes[1].set_title(f"Adversarial\nPred: {adv_label}")
    axes[1].axis('off')
    fig.suptitle(f"Sample {sample_idx} | L2: {l2_mag:.2f} | Queries: {queries} {title_suffix}")
    plt.show()
    plt.close(fig)  # <-- added here


# ─────────── Load Data ─────────────────────────────────────────────────────
try:
    data = joblib.load(DATA_PKL)
    _, X_samples , _, y_samples = data
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PKL}. Please check the path.")
    exit()

if X_samples.max() > 1.0:
    X_samples = X_samples.astype(np.float32) / 255.0
    warnings.warn("Data appeared in [0,255]; normalized to [0,1].")

# ─────────── Load TorchScripted LeNet ──────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
try:
    model = torch.jit.load(LENET_MODEL_PATH, map_location=device)
    model.eval()
    print(f"LeNet TorchScript model loaded from: {LENET_MODEL_PATH}")
except Exception as e:
    print(f"Error loading TorchScript LeNet model: {e}")
    exit()

def to_model(x01_batch):
    if x01_batch.ndim == 2 and x01_batch.shape == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)
    elif x01_batch.ndim == 3 and x01_batch.shape[1:] == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(1)
    elif x01_batch.ndim == 4 and x01_batch.shape[1] == 1:
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device)
    elif x01_batch.ndim == 1 and x01_batch.size == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(1, 1, 28, 28), dtype=torch.float32, device=device)
    elif x01_batch.ndim == 2 and x01_batch.shape[1] == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(x01_batch.shape[0], 1, 28, 28), dtype=torch.float32, device=device)
    else:
        raise ValueError(f"Unsupported input shape for to_model: {x01_batch.shape}")
    return tensor_batch


def model_query(x_tensor_batch):
    with torch.no_grad():
        return model(x_tensor_batch)

# ─────────── Load Random Forest Model ──────────────────────────────────────
rf_all_classes = None
top_feature_indices = None
print("Loading Random Forest Classifier for all classes...")
try:
    rf_all_classes = joblib.load(RF_ALL_CLASSES_PATH)
    feature_importances = rf_all_classes.feature_importances_
    #top_feature_indices = np.argsort(feature_importances)[:TOP_K_FEATURES]
    
    top_feature_indices = np.argsort(-feature_importances)[:TOP_K_FEATURES]
    print(f"Random Forest loaded. Using top {TOP_K_FEATURES} features.")
except Exception as e:
    print(f"Error loading Random Forest: {e}")
    top_feature_indices = np.arange(28 * 28)

# ─────────── I-FGSM Attack ─────────────────────────────────────────────────
def ifgsm_attack(original_image_np, true_label, model_target, epsilon_step, iterations,
                 total_epsilon_budget, features_to_perturb, query_count_tracker):
    if original_image_np.ndim == 1 and original_image_np.size == 784:
        original_image_np = original_image_np.reshape(28, 28)

    perturbed_image_np = original_image_np.copy()
    final_pred_label = true_label

    for i in range(iterations):
        image_tensor = to_model(perturbed_image_np)
        image_tensor.requires_grad = True
        output = model_target(image_tensor)
        query_count_tracker[0] += 1
        loss = F.cross_entropy(output, torch.tensor([true_label], device=device))
        model_target.zero_grad()
        loss.backward()
        data_grad_sign = torch.sign(image_tensor.grad.data).cpu().numpy()

        gradient_mask = np.zeros_like(data_grad_sign, dtype=np.float32)
        h, w = perturbed_image_np.shape
        rows, cols = np.unravel_index(features_to_perturb, (h, w))
        gradient_mask[0, 0, rows, cols] = data_grad_sign[0, 0, rows, cols]
        gradient_mask_for_update = gradient_mask.reshape(perturbed_image_np.shape)

        perturbed_image_np += epsilon_step * gradient_mask_for_update
        perturbation = perturbed_image_np - original_image_np
        perturbation = np.clip(perturbation, -total_epsilon_budget, total_epsilon_budget)
        perturbed_image_np = original_image_np + perturbation
        perturbed_image_np = np.clip(perturbed_image_np, 0, 1)

        # Discretize and check prediction on discretized image
        adv_uint8_temp = np.round(perturbed_image_np * 255).astype(np.uint8)
        adv_float_temp = adv_uint8_temp.astype(np.float32) / 255.0
        with torch.no_grad():
            output_temp = model_target(to_model(adv_float_temp))
            pred_temp = output_temp.argmax(dim=1).item()
            query_count_tracker[0] += 1

        if pred_temp != true_label:
            final_pred_label = pred_temp
            break

    # Final adversarial image (discretized)
    adv_uint8 = np.round(perturbed_image_np * 255).astype(np.uint8)
    adv_float = adv_uint8.astype(np.float32) / 255.0
    with torch.no_grad():
        output_final = model_target(to_model(adv_float))
        final_pred_label = output_final.argmax(dim=1).item()

    l2_norm = np.linalg.norm(adv_uint8.astype(np.float32) - (original_image_np * 255).astype(np.float32))
    success = (final_pred_label != true_label) and (l2_norm <= MAX_L2)

    return adv_uint8, final_pred_label, l2_norm, success


# ─────────── Attack Execution ──────────────────────────────────────────────
print(f"\n===== Starting Adversarial Attack =====")
total_trials, succ_total, misclassified = 0, 0, 0
records = []


start_time = time.time()


for digit in range(10):
    idxs = np.where(y_samples == digit)[0][:SAMPLES_PER_DIGIT]
    for rank, idx in enumerate(idxs, 1):
        x0 = X_samples[idx].copy()
        y0 = int(y_samples[idx])
        query_count_tracker = [0]
        pred0 = model_query(to_model(x0)).argmax(dim=1).item()
        query_count_tracker[0] += 1

        if pred0 != y0:
            misclassified += 1
            records.append({
                'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
                'adv_label': None, 'success': False, 'queries': query_count_tracker[0],
                'l2_mag': np.nan, 'note': 'Already misclassified'
            })
            continue

        total_trials += 1
        print(f"Attacking sample {rank}/{SAMPLES_PER_DIGIT} (True: {y0}, Index: {idx})...")
        adv_img_uint8, adv_label, l2_mag, success = ifgsm_attack(
            x0, y0, model, EPSILON_STEP, ITERATIONS, TOTAL_EPSILON,
            top_feature_indices, query_count_tracker
        )

        if success:
            succ_total += 1
            fname = f"true{y0}_adv{adv_label}_mag{l2_mag:.1f}_sample{idx}.png"
            Image.fromarray(adv_img_uint8, mode="L").save(os.path.join(OUT_DIR, fname))

        records.append({
            'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
            'adv_label': adv_label, 'success': success, 'queries': query_count_tracker[0],
            'l2_mag': l2_mag if success else np.nan, 'note': 'I-FGSM' + (' successful' if success else ' failed')
        })

        print(f"  {'Success' if success else 'Failed'}! Adv label: {adv_label}, L2: {l2_mag:.2f}, Queries: {query_count_tracker[0]}")


end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to generate adversarial samples: {elapsed_time:.4f} seconds")


# ─────────── Save Results ──────────────────────────────────────────────────
df = pd.DataFrame(records)
csv_path = os.path.join(OUT_DIR, "per_sample_stats.csv")
df.to_csv(csv_path, index=False)
print(f"\nStats saved to: {csv_path}")

# ─────────── Summary ───────────────────────────────────────────────────────
print(f"\n===== Attack Summary =====")
print(f"Total trials: {total_trials}")
print(f"Misclassified before attack: {misclassified}")
if total_trials > 0:
    success_rate = succ_total / total_trials * 100
    print(f"Success rate: {succ_total}/{total_trials} ({success_rate:.1f}%)")
    if succ_total > 0:
        print(f"Mean L2 (successful): {df[df['success']]['l2_mag'].mean():.2f}")
        print(f"Mean queries (successful): {df[df['success']]['queries'].mean():.2f}")

# ─────────── Display Examples ──────────────────────────────────────────────
success_df = df[df['success']]
if not success_df.empty:
    print("\nShowing successful adversarial examples...")
    show_ids = success_df.sample(min(3, len(success_df))).index.tolist()
    for record_idx in show_ids:
        r = df.loc[record_idx]
        fname_prefix = f"true{r['true_label']}_adv{r['adv_label']}_mag{r['l2_mag']:.1f}_sample{r['sample_idx']}"
        match_files = [f for f in os.listdir(OUT_DIR) if f.startswith(fname_prefix)]
        if match_files:
            adv_img_path = os.path.join(OUT_DIR, match_files[0])
            plot_adversarial_example(X_samples[r['sample_idx']], np.array(Image.open(adv_img_path)),
                                     r['true_label'], r['adv_label'], r['l2_mag'],
                                     r['sample_idx'], r['queries'], "(I-FGSM)")
else:
    print("No successful attacks to display. Showing original samples instead.")
    for i in range(min(3, len(df))):
        r = df.iloc[i]
        plot_adversarial_example(X_samples[r['sample_idx']], X_samples[r['sample_idx']],
                                 r['true_label'], r['initial_pred'], 0.0,
                                 r['sample_idx'], r['queries'], "(Original)")
# Out:
# LeNet TorchScript model loaded from: Models and Data splits\lenet.pt
# Loading Random Forest Classifier for all classes...
# Random Forest loaded. Using top 170 features.
#
# ===== Starting Adversarial Attack =====
# Attacking sample 1/100 (True: 0, Index: 29)...
#   Success! Adv label: 6, L2: 892.43, Queries: 83
# Attacking sample 2/100 (True: 0, Index: 40)...
#   Success! Adv label: 6, L2: 1085.21, Queries: 99
# Attacking sample 3/100 (True: 0, Index: 44)...
#   Success! Adv label: 5, L2: 603.73, Queries: 53
# Attacking sample 4/100 (True: 0, Index: 59)...
#   Success! Adv label: 6, L2: 683.28, Queries: 61
# Attacking sample 5/100 (True: 0, Index: 64)...
#   Success! Adv label: 9, L2: 1201.28, Queries: 123
# Attacking sample 6/100 (True: 0, Index: 75)...
#   Success! Adv label: 8, L2: 727.84, Queries: 65
# Attacking sample 7/100 (True: 0, Index: 80)...
#   Success! Adv label: 9, L2: 613.50, Queries: 55
# Attacking sample 8/100 (True: 0, Index: 97)...
#   Success! Adv label: 6, L2: 725.59, Queries: 65
# Attacking sample 9/100 (True: 0, Index: 115)...
#   Success! Adv label: 6, L2: 851.62, Queries: 75
# Attacking sample 10/100 (True: 0, Index: 141)...
#   Success! Adv label: 7, L2: 214.56, Queries: 19
# Attacking sample 11/100 (True: 0, Index: 146)...
#   Success! Adv label: 9, L2: 754.93, Queries: 69
# Attacking sample 12/100 (True: 0, Index: 156)...
#   Success! Adv label: 9, L2: 1107.23, Queries: 193
# Attacking sample 13/100 (True: 0, Index: 173)...
#   Success! Adv label: 6, L2: 635.05, Queries: 65
# Attacking sample 14/100 (True: 0, Index: 175)...
#   Success! Adv label: 8, L2: 523.70, Queries: 43
# Attacking sample 15/100 (True: 0, Index: 193)...
#   Success! Adv label: 9, L2: 913.79, Queries: 93
# Attacking sample 16/100 (True: 0, Index: 200)...
#   Success! Adv label: 9, L2: 741.31, Queries: 67
# Attacking sample 17/100 (True: 0, Index: 205)...
#   Success! Adv label: 9, L2: 850.71, Queries: 79
# Attacking sample 18/100 (True: 0, Index: 210)...
#   Success! Adv label: 9, L2: 823.60, Queries: 73
# Attacking sample 19/100 (True: 0, Index: 221)...
#   Success! Adv label: 9, L2: 883.21, Queries: 73
# Attacking sample 20/100 (True: 0, Index: 229)...
#   Success! Adv label: 5, L2: 1024.71, Queries: 149
# Attacking sample 21/100 (True: 0, Index: 249)...
#   Success! Adv label: 5, L2: 789.56, Queries: 83
# Attacking sample 22/100 (True: 0, Index: 258)...
#   Success! Adv label: 2, L2: 884.22, Queries: 81
# Attacking sample 23/100 (True: 0, Index: 275)...
#   Success! Adv label: 9, L2: 1152.26, Queries: 163
# Attacking sample 24/100 (True: 0, Index: 292)...
#   Success! Adv label: 2, L2: 998.64, Queries: 149
# Attacking sample 25/100 (True: 0, Index: 296)...
#   Success! Adv label: 9, L2: 679.21, Queries: 59
# Attacking sample 26/100 (True: 0, Index: 301)...
#   Success! Adv label: 9, L2: 606.22, Queries: 51
# Attacking sample 27/100 (True: 0, Index: 314)...
#   Success! Adv label: 9, L2: 729.91, Queries: 61
# Attacking sample 28/100 (True: 0, Index: 325)...
#   Success! Adv label: 9, L2: 1036.01, Queries: 97
# Attacking sample 29/100 (True: 0, Index: 333)...
#   Success! Adv label: 9, L2: 846.31, Queries: 81
# Attacking sample 30/100 (True: 0, Index: 345)...
#   Success! Adv label: 6, L2: 661.74, Queries: 57
# Attacking sample 31/100 (True: 0, Index: 349)...
#   Success! Adv label: 9, L2: 674.95, Queries: 57
# Attacking sample 32/100 (True: 0, Index: 360)...
#   Failed! Adv label: 0, L2: 1173.95, Queries: 201
# Attacking sample 33/100 (True: 0, Index: 365)...
#   Success! Adv label: 9, L2: 1046.89, Queries: 99
# Attacking sample 34/100 (True: 0, Index: 366)...
#   Success! Adv label: 9, L2: 828.58, Queries: 73
# Attacking sample 35/100 (True: 0, Index: 379)...
#   Success! Adv label: 9, L2: 959.28, Queries: 83
# Attacking sample 36/100 (True: 0, Index: 385)...
#   Failed! Adv label: 0, L2: 1057.34, Queries: 201
# Attacking sample 37/100 (True: 0, Index: 397)...
#   Success! Adv label: 2, L2: 1038.76, Queries: 163
# Attacking sample 38/100 (True: 0, Index: 400)...
#   Failed! Adv label: 0, L2: 1264.79, Queries: 201
# Attacking sample 39/100 (True: 0, Index: 405)...
#   Success! Adv label: 2, L2: 760.01, Queries: 63
# Attacking sample 40/100 (True: 0, Index: 410)...
#   Success! Adv label: 9, L2: 825.73, Queries: 73
# Attacking sample 41/100 (True: 0, Index: 420)...
#   Success! Adv label: 2, L2: 777.77, Queries: 77
# Attacking sample 42/100 (True: 0, Index: 424)...
#   Success! Adv label: 9, L2: 930.80, Queries: 87
# Attacking sample 43/100 (True: 0, Index: 447)...
#   Success! Adv label: 2, L2: 696.15, Queries: 63
# Attacking sample 44/100 (True: 0, Index: 453)...
#   Success! Adv label: 6, L2: 807.74, Queries: 73
# Attacking sample 45/100 (True: 0, Index: 457)...
#   Success! Adv label: 6, L2: 1005.19, Queries: 91
# Attacking sample 46/100 (True: 0, Index: 466)...
#   Success! Adv label: 2, L2: 838.54, Queries: 77
# Attacking sample 47/100 (True: 0, Index: 475)...
#   Success! Adv label: 9, L2: 265.85, Queries: 23
# Attacking sample 48/100 (True: 0, Index: 483)...
#   Success! Adv label: 2, L2: 882.25, Queries: 83
# Attacking sample 49/100 (True: 0, Index: 484)...
#   Success! Adv label: 8, L2: 467.31, Queries: 35
# Attacking sample 50/100 (True: 0, Index: 486)...
#   Success! Adv label: 9, L2: 966.24, Queries: 99
# Attacking sample 51/100 (True: 0, Index: 487)...
#   Success! Adv label: 6, L2: 664.41, Queries: 57
# Attacking sample 52/100 (True: 0, Index: 489)...
#   Success! Adv label: 9, L2: 717.89, Queries: 65
# Attacking sample 53/100 (True: 0, Index: 492)...
#   Success! Adv label: 9, L2: 666.81, Queries: 57
# Attacking sample 54/100 (True: 0, Index: 506)...
#   Success! Adv label: 2, L2: 886.88, Queries: 73
# Attacking sample 55/100 (True: 0, Index: 513)...
#   Failed! Adv label: 0, L2: 1085.15, Queries: 201
# Attacking sample 56/100 (True: 0, Index: 518)...
#   Success! Adv label: 5, L2: 935.87, Queries: 89
# Attacking sample 57/100 (True: 0, Index: 521)...
#   Failed! Adv label: 0, L2: 1221.62, Queries: 201
# Attacking sample 58/100 (True: 0, Index: 527)...
#   Success! Adv label: 2, L2: 763.23, Queries: 67
# Attacking sample 59/100 (True: 0, Index: 529)...
#   Success! Adv label: 5, L2: 724.68, Queries: 75
# Attacking sample 60/100 (True: 0, Index: 531)...
#   Success! Adv label: 9, L2: 1005.19, Queries: 107
# Attacking sample 61/100 (True: 0, Index: 546)...
#   Success! Adv label: 9, L2: 701.20, Queries: 65
# Attacking sample 62/100 (True: 0, Index: 551)...
#   Success! Adv label: 6, L2: 387.45, Queries: 29
# Attacking sample 63/100 (True: 0, Index: 555)...
#   Success! Adv label: 6, L2: 959.51, Queries: 83
# Attacking sample 64/100 (True: 0, Index: 587)...
#   Success! Adv label: 2, L2: 867.31, Queries: 81
# Attacking sample 65/100 (True: 0, Index: 604)...
#   Success! Adv label: 8, L2: 729.50, Queries: 59
# Attacking sample 66/100 (True: 0, Index: 614)...
#   Success! Adv label: 8, L2: 864.23, Queries: 79
# Attacking sample 67/100 (True: 0, Index: 615)...
#   Success! Adv label: 9, L2: 465.06, Queries: 37
# Attacking sample 68/100 (True: 0, Index: 618)...
#   Success! Adv label: 6, L2: 348.50, Queries: 29
# Attacking sample 69/100 (True: 0, Index: 638)...
#   Success! Adv label: 8, L2: 430.27, Queries: 33
# Attacking sample 70/100 (True: 0, Index: 642)...
#   Success! Adv label: 9, L2: 898.20, Queries: 89
# Attacking sample 71/100 (True: 0, Index: 655)...
#   Success! Adv label: 6, L2: 806.19, Queries: 67
# Attacking sample 72/100 (True: 0, Index: 658)...
#   Success! Adv label: 6, L2: 724.13, Queries: 61
# Attacking sample 73/100 (True: 0, Index: 665)...
#   Success! Adv label: 2, L2: 689.31, Queries: 59
# Attacking sample 74/100 (True: 0, Index: 671)...
#   Success! Adv label: 6, L2: 761.27, Queries: 63
# Attacking sample 75/100 (True: 0, Index: 681)...
#   Success! Adv label: 9, L2: 939.78, Queries: 87
# Attacking sample 76/100 (True: 0, Index: 691)...
#   Success! Adv label: 2, L2: 690.02, Queries: 57
# Attacking sample 77/100 (True: 0, Index: 700)...
#   Success! Adv label: 5, L2: 547.45, Queries: 47
# Attacking sample 78/100 (True: 0, Index: 706)...
#   Success! Adv label: 2, L2: 979.30, Queries: 193
# Attacking sample 79/100 (True: 0, Index: 712)...
#   Success! Adv label: 3, L2: 1120.29, Queries: 195
# Attacking sample 80/100 (True: 0, Index: 713)...
#   Success! Adv label: 9, L2: 748.61, Queries: 63
# Attacking sample 81/100 (True: 0, Index: 736)...
#   Success! Adv label: 5, L2: 698.35, Queries: 65
# Attacking sample 82/100 (True: 0, Index: 742)...
#   Success! Adv label: 6, L2: 745.77, Queries: 69
# Attacking sample 83/100 (True: 0, Index: 744)...
#   Success! Adv label: 2, L2: 604.12, Queries: 53
# Attacking sample 84/100 (True: 0, Index: 760)...
#   Success! Adv label: 9, L2: 644.32, Queries: 59
# Attacking sample 85/100 (True: 0, Index: 772)...
#   Success! Adv label: 9, L2: 320.04, Queries: 25
# Attacking sample 86/100 (True: 0, Index: 781)...
#   Success! Adv label: 6, L2: 499.17, Queries: 43
# Attacking sample 87/100 (True: 0, Index: 809)...
#   Success! Adv label: 5, L2: 717.18, Queries: 69
# Attacking sample 88/100 (True: 0, Index: 813)...
#   Success! Adv label: 9, L2: 528.41, Queries: 47
# Attacking sample 89/100 (True: 0, Index: 820)...
#   Success! Adv label: 9, L2: 664.16, Queries: 63
# Attacking sample 90/100 (True: 0, Index: 823)...
#   Success! Adv label: 5, L2: 732.48, Queries: 71
# Attacking sample 91/100 (True: 0, Index: 844)...
#   Success! Adv label: 9, L2: 1032.02, Queries: 123
# Attacking sample 92/100 (True: 0, Index: 848)...
#   Success! Adv label: 9, L2: 311.53, Queries: 25
# Attacking sample 93/100 (True: 0, Index: 861)...
#   Success! Adv label: 6, L2: 1013.08, Queries: 81
# Attacking sample 94/100 (True: 0, Index: 865)...
#   Success! Adv label: 6, L2: 1250.06, Queries: 109
# Attacking sample 95/100 (True: 0, Index: 869)...
#   Success! Adv label: 6, L2: 1051.30, Queries: 97
# Attacking sample 96/100 (True: 0, Index: 876)...
#   Success! Adv label: 9, L2: 659.83, Queries: 55
# Attacking sample 97/100 (True: 0, Index: 885)...
#   Success! Adv label: 9, L2: 1091.33, Queries: 169
# Attacking sample 98/100 (True: 0, Index: 906)...
#   Success! Adv label: 3, L2: 958.86, Queries: 89
# Attacking sample 99/100 (True: 0, Index: 907)...
#   Success! Adv label: 9, L2: 916.77, Queries: 85
# Attacking sample 100/100 (True: 0, Index: 918)...
#   Success! Adv label: 9, L2: 993.34, Queries: 89
# Attacking sample 1/100 (True: 1, Index: 2)...
#   Success! Adv label: 7, L2: 277.36, Queries: 21
# Attacking sample 2/100 (True: 1, Index: 3)...
#   Success! Adv label: 7, L2: 363.56, Queries: 27
# Attacking sample 3/100 (True: 1, Index: 9)...
#   Success! Adv label: 2, L2: 361.54, Queries: 29
# Attacking sample 4/100 (True: 1, Index: 25)...
#   Success! Adv label: 4, L2: 358.24, Queries: 25
# Attacking sample 5/100 (True: 1, Index: 36)...
#   Success! Adv label: 2, L2: 274.45, Queries: 21
# Attacking sample 6/100 (True: 1, Index: 63)...
#   Success! Adv label: 8, L2: 265.70, Queries: 21
# Attacking sample 7/100 (True: 1, Index: 65)...
#   Success! Adv label: 8, L2: 349.45, Queries: 25
# Attacking sample 8/100 (True: 1, Index: 68)...
#   Success! Adv label: 8, L2: 385.13, Queries: 27
# Attacking sample 9/100 (True: 1, Index: 76)...
#   Success! Adv label: 8, L2: 217.80, Queries: 17
# Attacking sample 10/100 (True: 1, Index: 83)...
#   Success! Adv label: 4, L2: 382.04, Queries: 29
# Attacking sample 11/100 (True: 1, Index: 90)...
#   Success! Adv label: 9, L2: 32.43, Queries: 3
# Attacking sample 12/100 (True: 1, Index: 94)...
#   Success! Adv label: 8, L2: 204.19, Queries: 15
# Attacking sample 13/100 (True: 1, Index: 100)...
#   Success! Adv label: 8, L2: 256.95, Queries: 19
# Attacking sample 14/100 (True: 1, Index: 123)...
#   Success! Adv label: 8, L2: 198.77, Queries: 15
# Attacking sample 15/100 (True: 1, Index: 150)...
#   Success! Adv label: 8, L2: 361.39, Queries: 25
# Attacking sample 16/100 (True: 1, Index: 152)...
#   Success! Adv label: 9, L2: 354.18, Queries: 27
# Attacking sample 17/100 (True: 1, Index: 178)...
#   Success! Adv label: 4, L2: 355.05, Queries: 25
# Attacking sample 18/100 (True: 1, Index: 185)...
#   Success! Adv label: 8, L2: 352.53, Queries: 29
# Attacking sample 19/100 (True: 1, Index: 191)...
#   Success! Adv label: 4, L2: 411.78, Queries: 29
# Attacking sample 20/100 (True: 1, Index: 201)...
#   Success! Adv label: 8, L2: 317.77, Queries: 23
# Attacking sample 21/100 (True: 1, Index: 203)...
#   Success! Adv label: 8, L2: 267.24, Queries: 19
# Attacking sample 22/100 (True: 1, Index: 213)...
#   Success! Adv label: 8, L2: 277.32, Queries: 21
# Attacking sample 23/100 (True: 1, Index: 220)...
#   Success! Adv label: 8, L2: 261.77, Queries: 19
# Attacking sample 24/100 (True: 1, Index: 223)...
#   Success! Adv label: 4, L2: 344.90, Queries: 25
# Attacking sample 25/100 (True: 1, Index: 226)...
#   Success! Adv label: 4, L2: 321.75, Queries: 23
# Attacking sample 26/100 (True: 1, Index: 232)...
#   Success! Adv label: 4, L2: 434.08, Queries: 31
# Attacking sample 27/100 (True: 1, Index: 241)...
#   Success! Adv label: 4, L2: 276.73, Queries: 21
# Attacking sample 28/100 (True: 1, Index: 254)...
#   Success! Adv label: 8, L2: 321.86, Queries: 23
# Attacking sample 29/100 (True: 1, Index: 281)...
#   Success! Adv label: 8, L2: 300.30, Queries: 23
# Attacking sample 30/100 (True: 1, Index: 284)...
#   Success! Adv label: 8, L2: 320.77, Queries: 25
# Attacking sample 31/100 (True: 1, Index: 285)...
#   Success! Adv label: 9, L2: 219.07, Queries: 17
# Attacking sample 32/100 (True: 1, Index: 286)...
#   Success! Adv label: 4, L2: 311.43, Queries: 23
# Attacking sample 33/100 (True: 1, Index: 287)...
#   Success! Adv label: 4, L2: 326.30, Queries: 25
# Attacking sample 34/100 (True: 1, Index: 294)...
#   Success! Adv label: 4, L2: 367.73, Queries: 27
# Attacking sample 35/100 (True: 1, Index: 298)...
#   Success! Adv label: 7, L2: 465.54, Queries: 33
# Attacking sample 36/100 (True: 1, Index: 306)...
#   Success! Adv label: 4, L2: 407.20, Queries: 29
# Attacking sample 37/100 (True: 1, Index: 312)...
#   Success! Adv label: 8, L2: 341.67, Queries: 27
# Attacking sample 38/100 (True: 1, Index: 317)...
#   Success! Adv label: 4, L2: 354.29, Queries: 27
# Attacking sample 39/100 (True: 1, Index: 334)...
#   Success! Adv label: 4, L2: 377.70, Queries: 27
# Attacking sample 40/100 (True: 1, Index: 337)...
#   Success! Adv label: 8, L2: 350.57, Queries: 25
# Attacking sample 41/100 (True: 1, Index: 338)...
#   Success! Adv label: 8, L2: 493.92, Queries: 35
# Attacking sample 42/100 (True: 1, Index: 348)...
#   Success! Adv label: 4, L2: 471.35, Queries: 35
# Attacking sample 43/100 (True: 1, Index: 361)...
#   Success! Adv label: 8, L2: 260.44, Queries: 19
# Attacking sample 44/100 (True: 1, Index: 363)...
#   Success! Adv label: 8, L2: 355.56, Queries: 25
# Attacking sample 45/100 (True: 1, Index: 367)...
#   Success! Adv label: 8, L2: 205.68, Queries: 15
# Attacking sample 46/100 (True: 1, Index: 375)...
#   Success! Adv label: 7, L2: 417.85, Queries: 31
# Attacking sample 47/100 (True: 1, Index: 384)...
#   Success! Adv label: 8, L2: 261.74, Queries: 19
# Attacking sample 48/100 (True: 1, Index: 412)...
#   Success! Adv label: 8, L2: 410.37, Queries: 29
# Attacking sample 49/100 (True: 1, Index: 425)...
#   Success! Adv label: 7, L2: 371.48, Queries: 27
# Attacking sample 50/100 (True: 1, Index: 428)...
#   Success! Adv label: 4, L2: 362.31, Queries: 25
# Attacking sample 51/100 (True: 1, Index: 463)...
#   Success! Adv label: 4, L2: 270.16, Queries: 21
# Attacking sample 52/100 (True: 1, Index: 499)...
#   Success! Adv label: 4, L2: 409.43, Queries: 29
# Attacking sample 53/100 (True: 1, Index: 502)...
#   Success! Adv label: 4, L2: 398.06, Queries: 29
# Attacking sample 54/100 (True: 1, Index: 526)...
#   Success! Adv label: 8, L2: 260.68, Queries: 19
# Attacking sample 55/100 (True: 1, Index: 532)...
#   Success! Adv label: 4, L2: 321.65, Queries: 23
# Attacking sample 56/100 (True: 1, Index: 536)...
#   Success! Adv label: 9, L2: 246.17, Queries: 19
# Attacking sample 57/100 (True: 1, Index: 537)...
#   Success! Adv label: 8, L2: 308.00, Queries: 23
# Attacking sample 58/100 (True: 1, Index: 539)...
#   Success! Adv label: 4, L2: 375.00, Queries: 27
# Attacking sample 60/100 (True: 1, Index: 560)...
#   Success! Adv label: 4, L2: 349.02, Queries: 25
# Attacking sample 61/100 (True: 1, Index: 561)...
#   Success! Adv label: 8, L2: 260.26, Queries: 19
# Attacking sample 62/100 (True: 1, Index: 570)...
#   Success! Adv label: 8, L2: 340.56, Queries: 25
# Attacking sample 63/100 (True: 1, Index: 573)...
#   Success! Adv label: 2, L2: 35.67, Queries: 3
# Attacking sample 64/100 (True: 1, Index: 576)...
#   Success! Adv label: 7, L2: 298.14, Queries: 23
# Attacking sample 65/100 (True: 1, Index: 580)...
#   Success! Adv label: 4, L2: 316.34, Queries: 23
# Attacking sample 66/100 (True: 1, Index: 588)...
#   Success! Adv label: 7, L2: 410.07, Queries: 31
# Attacking sample 67/100 (True: 1, Index: 620)...
#   Success! Adv label: 4, L2: 378.30, Queries: 27
# Attacking sample 68/100 (True: 1, Index: 621)...
#   Success! Adv label: 4, L2: 345.93, Queries: 25
# Attacking sample 69/100 (True: 1, Index: 622)...
#   Success! Adv label: 2, L2: 144.51, Queries: 11
# Attacking sample 70/100 (True: 1, Index: 627)...
#   Success! Adv label: 8, L2: 251.03, Queries: 19
# Attacking sample 71/100 (True: 1, Index: 630)...
#   Success! Adv label: 8, L2: 234.12, Queries: 17
# Attacking sample 72/100 (True: 1, Index: 632)...
#   Success! Adv label: 4, L2: 267.91, Queries: 19
# Attacking sample 73/100 (True: 1, Index: 644)...
#   Success! Adv label: 4, L2: 282.31, Queries: 21
# Attacking sample 74/100 (True: 1, Index: 646)...
#   Success! Adv label: 7, L2: 321.15, Queries: 25
# Attacking sample 75/100 (True: 1, Index: 649)...
#   Success! Adv label: 4, L2: 411.63, Queries: 29
# Attacking sample 76/100 (True: 1, Index: 662)...
#   Success! Adv label: 4, L2: 404.10, Queries: 29
# Attacking sample 77/100 (True: 1, Index: 663)...
#   Success! Adv label: 8, L2: 269.69, Queries: 19
# Attacking sample 78/100 (True: 1, Index: 669)...
#   Success! Adv label: 9, L2: 453.35, Queries: 33
# Attacking sample 79/100 (True: 1, Index: 677)...
#   Success! Adv label: 4, L2: 254.89, Queries: 19
# Attacking sample 80/100 (True: 1, Index: 686)...
#   Success! Adv label: 8, L2: 330.38, Queries: 25
# Attacking sample 81/100 (True: 1, Index: 689)...
#   Success! Adv label: 4, L2: 335.19, Queries: 23
# Attacking sample 82/100 (True: 1, Index: 703)...
#   Success! Adv label: 8, L2: 349.17, Queries: 25
# Attacking sample 83/100 (True: 1, Index: 705)...
#   Success! Adv label: 7, L2: 495.47, Queries: 37
# Attacking sample 84/100 (True: 1, Index: 709)...
#   Success! Adv label: 4, L2: 329.57, Queries: 25
# Attacking sample 85/100 (True: 1, Index: 724)...
#   Success! Adv label: 4, L2: 229.05, Queries: 17
# Attacking sample 86/100 (True: 1, Index: 727)...
#   Success! Adv label: 8, L2: 295.01, Queries: 21
# Attacking sample 87/100 (True: 1, Index: 734)...
#   Success! Adv label: 8, L2: 211.76, Queries: 17
# Attacking sample 88/100 (True: 1, Index: 740)...
#   Success! Adv label: 4, L2: 322.38, Queries: 23
# Attacking sample 89/100 (True: 1, Index: 741)...
#   Success! Adv label: 8, L2: 225.76, Queries: 17
# Attacking sample 90/100 (True: 1, Index: 743)...
#   Success! Adv label: 8, L2: 296.20, Queries: 21
# Attacking sample 91/100 (True: 1, Index: 759)...
#   Success! Adv label: 4, L2: 357.38, Queries: 27
# Attacking sample 92/100 (True: 1, Index: 768)...
#   Success! Adv label: 8, L2: 313.08, Queries: 23
# Attacking sample 93/100 (True: 1, Index: 775)...
#   Success! Adv label: 4, L2: 251.78, Queries: 19
# Attacking sample 94/100 (True: 1, Index: 782)...
#   Success! Adv label: 4, L2: 372.00, Queries: 27
# Attacking sample 95/100 (True: 1, Index: 798)...
#   Success! Adv label: 9, L2: 333.93, Queries: 25
# Attacking sample 96/100 (True: 1, Index: 799)...
#   Success! Adv label: 8, L2: 409.56, Queries: 29
# Attacking sample 97/100 (True: 1, Index: 808)...
#   Success! Adv label: 7, L2: 350.04, Queries: 25
# Attacking sample 98/100 (True: 1, Index: 819)...
#   Success! Adv label: 4, L2: 416.91, Queries: 29
# Attacking sample 99/100 (True: 1, Index: 843)...
#   Success! Adv label: 4, L2: 413.31, Queries: 29
# Attacking sample 100/100 (True: 1, Index: 853)...
#   Success! Adv label: 4, L2: 362.51, Queries: 27
# Attacking sample 1/100 (True: 2, Index: 4)...
#   Success! Adv label: 3, L2: 587.70, Queries: 47
# Attacking sample 2/100 (True: 2, Index: 22)...
#   Success! Adv label: 6, L2: 597.79, Queries: 59
# Attacking sample 3/100 (True: 2, Index: 32)...
#   Success! Adv label: 3, L2: 1020.27, Queries: 85
# Attacking sample 4/100 (True: 2, Index: 34)...
#   Success! Adv label: 4, L2: 32.92, Queries: 3
# Attacking sample 5/100 (True: 2, Index: 42)...
#   Success! Adv label: 3, L2: 245.61, Queries: 19
# Attacking sample 6/100 (True: 2, Index: 49)...
#   Success! Adv label: 3, L2: 1001.07, Queries: 147
# Attacking sample 7/100 (True: 2, Index: 52)...
#   Success! Adv label: 8, L2: 959.55, Queries: 91
# Attacking sample 8/100 (True: 2, Index: 69)...
#   Success! Adv label: 8, L2: 718.09, Queries: 55
# Attacking sample 9/100 (True: 2, Index: 70)...
#   Success! Adv label: 3, L2: 702.41, Queries: 71
# Attacking sample 10/100 (True: 2, Index: 81)...
#   Success! Adv label: 8, L2: 889.63, Queries: 65
# Attacking sample 11/100 (True: 2, Index: 110)...
#   Success! Adv label: 7, L2: 959.66, Queries: 83
# Attacking sample 12/100 (True: 2, Index: 118)...
#   Success! Adv label: 3, L2: 580.28, Queries: 47
# Attacking sample 13/100 (True: 2, Index: 121)...
#   Success! Adv label: 3, L2: 652.54, Queries: 53
# Attacking sample 14/100 (True: 2, Index: 138)...
#   Success! Adv label: 3, L2: 662.63, Queries: 55
# Attacking sample 15/100 (True: 2, Index: 144)...
#   Success! Adv label: 0, L2: 674.89, Queries: 55
# Attacking sample 16/100 (True: 2, Index: 155)...
#   Success! Adv label: 8, L2: 815.99, Queries: 61
# Attacking sample 17/100 (True: 2, Index: 160)...
#   Success! Adv label: 6, L2: 382.57, Queries: 33
# Attacking sample 18/100 (True: 2, Index: 161)...
#   Success! Adv label: 3, L2: 614.34, Queries: 49
# Attacking sample 19/100 (True: 2, Index: 176)...
#   Success! Adv label: 3, L2: 635.82, Queries: 51
# Attacking sample 21/100 (True: 2, Index: 186)...
#   Success! Adv label: 7, L2: 655.24, Queries: 63
# Attacking sample 22/100 (True: 2, Index: 197)...
#   Success! Adv label: 8, L2: 841.99, Queries: 77
# Attacking sample 23/100 (True: 2, Index: 208)...
#   Success! Adv label: 8, L2: 857.62, Queries: 73
# Attacking sample 25/100 (True: 2, Index: 216)...
#   Success! Adv label: 3, L2: 812.03, Queries: 71
# Attacking sample 26/100 (True: 2, Index: 219)...
#   Success! Adv label: 3, L2: 401.36, Queries: 35
# Attacking sample 27/100 (True: 2, Index: 235)...
#   Success! Adv label: 3, L2: 708.04, Queries: 61
# Attacking sample 28/100 (True: 2, Index: 260)...
#   Success! Adv label: 0, L2: 554.33, Queries: 47
# Attacking sample 29/100 (True: 2, Index: 276)...
#   Success! Adv label: 4, L2: 514.38, Queries: 47
# Attacking sample 30/100 (True: 2, Index: 293)...
#   Success! Adv label: 3, L2: 768.96, Queries: 77
# Attacking sample 31/100 (True: 2, Index: 295)...
#   Success! Adv label: 3, L2: 537.54, Queries: 45
# Attacking sample 32/100 (True: 2, Index: 311)...
#   Success! Adv label: 3, L2: 536.02, Queries: 45
# Attacking sample 33/100 (True: 2, Index: 313)...
#   Success! Adv label: 3, L2: 173.45, Queries: 15
# Attacking sample 34/100 (True: 2, Index: 322)...
#   Success! Adv label: 0, L2: 654.80, Queries: 55
# Attacking sample 35/100 (True: 2, Index: 328)...
#   Success! Adv label: 8, L2: 700.71, Queries: 57
# Attacking sample 36/100 (True: 2, Index: 357)...
#   Success! Adv label: 7, L2: 502.25, Queries: 43
# Attacking sample 37/100 (True: 2, Index: 374)...
#   Success! Adv label: 8, L2: 409.21, Queries: 33
# Attacking sample 38/100 (True: 2, Index: 395)...
#   Success! Adv label: 8, L2: 474.65, Queries: 43
# Attacking sample 39/100 (True: 2, Index: 396)...
#   Success! Adv label: 8, L2: 528.12, Queries: 41
# Attacking sample 40/100 (True: 2, Index: 398)...
#   Success! Adv label: 3, L2: 757.08, Queries: 65
# Attacking sample 41/100 (True: 2, Index: 433)...
#   Success! Adv label: 3, L2: 613.71, Queries: 47
# Attacking sample 42/100 (True: 2, Index: 439)...
#   Success! Adv label: 8, L2: 662.24, Queries: 51
# Attacking sample 43/100 (True: 2, Index: 441)...
#   Success! Adv label: 8, L2: 336.96, Queries: 25
# Attacking sample 44/100 (True: 2, Index: 442)...
#   Success! Adv label: 9, L2: 709.91, Queries: 57
# Attacking sample 45/100 (True: 2, Index: 451)...
#   Success! Adv label: 0, L2: 1041.89, Queries: 87
# Attacking sample 46/100 (True: 2, Index: 462)...
#   Success! Adv label: 3, L2: 669.50, Queries: 51
# Attacking sample 47/100 (True: 2, Index: 470)...
#   Success! Adv label: 3, L2: 638.15, Queries: 53
# Attacking sample 48/100 (True: 2, Index: 477)...
#   Success! Adv label: 8, L2: 866.65, Queries: 73
# Attacking sample 49/100 (True: 2, Index: 485)...
#   Success! Adv label: 7, L2: 229.62, Queries: 19
# Attacking sample 50/100 (True: 2, Index: 491)...
#   Success! Adv label: 8, L2: 727.61, Queries: 55
# Attacking sample 51/100 (True: 2, Index: 493)...
#   Success! Adv label: 7, L2: 761.42, Queries: 77
# Attacking sample 52/100 (True: 2, Index: 495)...
#   Success! Adv label: 3, L2: 648.72, Queries: 55
# Attacking sample 53/100 (True: 2, Index: 519)...
#   Success! Adv label: 3, L2: 790.31, Queries: 65
# Attacking sample 54/100 (True: 2, Index: 523)...
#   Success! Adv label: 6, L2: 576.24, Queries: 51
# Attacking sample 55/100 (True: 2, Index: 557)...
#   Success! Adv label: 8, L2: 640.75, Queries: 47
# Attacking sample 56/100 (True: 2, Index: 567)...
#   Success! Adv label: 0, L2: 462.89, Queries: 37
# Attacking sample 57/100 (True: 2, Index: 571)...
#   Success! Adv label: 7, L2: 619.60, Queries: 53
# Attacking sample 58/100 (True: 2, Index: 584)...
#   Success! Adv label: 3, L2: 1073.87, Queries: 85
# Attacking sample 59/100 (True: 2, Index: 591)...
#   Success! Adv label: 8, L2: 920.21, Queries: 81
# Attacking sample 60/100 (True: 2, Index: 592)...
#   Success! Adv label: 8, L2: 740.13, Queries: 69
# Attacking sample 61/100 (True: 2, Index: 610)...
#   Success! Adv label: 3, L2: 1017.98, Queries: 87
# Attacking sample 62/100 (True: 2, Index: 612)...
#   Success! Adv label: 8, L2: 642.51, Queries: 47
# Attacking sample 63/100 (True: 2, Index: 616)...
#   Success! Adv label: 3, L2: 795.45, Queries: 65
# Attacking sample 64/100 (True: 2, Index: 624)...
#   Success! Adv label: 3, L2: 704.14, Queries: 55
# Attacking sample 65/100 (True: 2, Index: 631)...
#   Success! Adv label: 3, L2: 485.59, Queries: 41
# Attacking sample 66/100 (True: 2, Index: 636)...
#   Success! Adv label: 3, L2: 850.78, Queries: 67
# Attacking sample 67/100 (True: 2, Index: 647)...
#   Success! Adv label: 1, L2: 119.19, Queries: 11
# Attacking sample 68/100 (True: 2, Index: 650)...
#   Success! Adv label: 3, L2: 202.16, Queries: 17
# Attacking sample 69/100 (True: 2, Index: 664)...
#   Success! Adv label: 8, L2: 872.35, Queries: 71
# Attacking sample 70/100 (True: 2, Index: 704)...
#   Success! Adv label: 3, L2: 666.90, Queries: 55
# Attacking sample 71/100 (True: 2, Index: 720)...
#   Success! Adv label: 4, L2: 207.88, Queries: 17
# Attacking sample 72/100 (True: 2, Index: 725)...
#   Success! Adv label: 3, L2: 476.63, Queries: 39
# Attacking sample 73/100 (True: 2, Index: 750)...
#   Success! Adv label: 7, L2: 952.35, Queries: 99
# Attacking sample 74/100 (True: 2, Index: 764)...
#   Success! Adv label: 1, L2: 667.57, Queries: 71
# Attacking sample 75/100 (True: 2, Index: 780)...
#   Success! Adv label: 8, L2: 765.59, Queries: 59
# Attacking sample 76/100 (True: 2, Index: 784)...
#   Success! Adv label: 8, L2: 871.40, Queries: 71
# Attacking sample 77/100 (True: 2, Index: 788)...
#   Success! Adv label: 1, L2: 562.12, Queries: 47
# Attacking sample 78/100 (True: 2, Index: 790)...
#   Success! Adv label: 3, L2: 890.48, Queries: 81
# Attacking sample 79/100 (True: 2, Index: 797)...
#   Success! Adv label: 8, L2: 577.32, Queries: 45
# Attacking sample 80/100 (True: 2, Index: 803)...
#   Success! Adv label: 0, L2: 941.95, Queries: 77
# Attacking sample 81/100 (True: 2, Index: 807)...
#   Success! Adv label: 1, L2: 1020.80, Queries: 97
# Attacking sample 82/100 (True: 2, Index: 828)...
#   Success! Adv label: 3, L2: 455.77, Queries: 37
# Attacking sample 83/100 (True: 2, Index: 842)...
#   Success! Adv label: 3, L2: 707.19, Queries: 63
# Attacking sample 84/100 (True: 2, Index: 845)...
#   Success! Adv label: 3, L2: 935.49, Queries: 73
# Attacking sample 85/100 (True: 2, Index: 859)...
#   Success! Adv label: 3, L2: 480.99, Queries: 39
# Attacking sample 86/100 (True: 2, Index: 871)...
#   Success! Adv label: 1, L2: 693.27, Queries: 61
# Attacking sample 87/100 (True: 2, Index: 881)...
#   Success! Adv label: 3, L2: 604.33, Queries: 59
# Attacking sample 88/100 (True: 2, Index: 883)...
#   Success! Adv label: 8, L2: 336.39, Queries: 27
# Attacking sample 89/100 (True: 2, Index: 896)...
#   Success! Adv label: 3, L2: 550.92, Queries: 45
# Attacking sample 90/100 (True: 2, Index: 897)...
#   Success! Adv label: 3, L2: 543.02, Queries: 53
# Attacking sample 92/100 (True: 2, Index: 922)...
#   Success! Adv label: 7, L2: 550.05, Queries: 47
# Attacking sample 93/100 (True: 2, Index: 932)...
#   Success! Adv label: 8, L2: 704.55, Queries: 55
# Attacking sample 94/100 (True: 2, Index: 944)...
#   Success! Adv label: 3, L2: 585.43, Queries: 47
# Attacking sample 95/100 (True: 2, Index: 949)...
#   Success! Adv label: 3, L2: 742.89, Queries: 61
# Attacking sample 96/100 (True: 2, Index: 952)...
#   Failed! Adv label: 2, L2: 1119.29, Queries: 201
# Attacking sample 97/100 (True: 2, Index: 959)...
#   Success! Adv label: 3, L2: 569.05, Queries: 45
# Attacking sample 98/100 (True: 2, Index: 966)...
#   Success! Adv label: 7, L2: 174.79, Queries: 15
# Attacking sample 99/100 (True: 2, Index: 967)...
#   Success! Adv label: 7, L2: 734.77, Queries: 67
# Attacking sample 100/100 (True: 2, Index: 985)...
#   Success! Adv label: 3, L2: 643.17, Queries: 57
# Attacking sample 1/100 (True: 3, Index: 1)...
#   Success! Adv label: 5, L2: 336.57, Queries: 27
# Attacking sample 2/100 (True: 3, Index: 12)...
#   Success! Adv label: 5, L2: 321.90, Queries: 27
# Attacking sample 3/100 (True: 3, Index: 20)...
#   Success! Adv label: 9, L2: 635.70, Queries: 49
# Attacking sample 4/100 (True: 3, Index: 27)...
#   Success! Adv label: 5, L2: 916.78, Queries: 89
# Attacking sample 5/100 (True: 3, Index: 37)...
#   Success! Adv label: 0, L2: 900.25, Queries: 83
# Attacking sample 6/100 (True: 3, Index: 43)...
#   Failed! Adv label: 3, L2: 1033.66, Queries: 201
# Attacking sample 7/100 (True: 3, Index: 53)...
#   Success! Adv label: 8, L2: 555.30, Queries: 43
# Attacking sample 8/100 (True: 3, Index: 61)...
#   Success! Adv label: 8, L2: 575.48, Queries: 45
# Attacking sample 9/100 (True: 3, Index: 73)...
#   Success! Adv label: 8, L2: 638.79, Queries: 55
# Attacking sample 10/100 (True: 3, Index: 102)...
#   Success! Adv label: 2, L2: 407.71, Queries: 33
# Attacking sample 11/100 (True: 3, Index: 108)...
#   Success! Adv label: 2, L2: 86.54, Queries: 7
# Attacking sample 12/100 (True: 3, Index: 109)...
#   Success! Adv label: 8, L2: 497.93, Queries: 37
# Attacking sample 13/100 (True: 3, Index: 117)...
#   Success! Adv label: 5, L2: 878.28, Queries: 93
# Attacking sample 14/100 (True: 3, Index: 131)...
#   Success! Adv label: 8, L2: 148.23, Queries: 11
# Attacking sample 15/100 (True: 3, Index: 159)...
#   Success! Adv label: 2, L2: 855.22, Queries: 79
# Attacking sample 16/100 (True: 3, Index: 162)...
#   Success! Adv label: 2, L2: 1042.76, Queries: 171
# Attacking sample 17/100 (True: 3, Index: 166)...
#   Success! Adv label: 7, L2: 810.90, Queries: 87
# Attacking sample 18/100 (True: 3, Index: 177)...
#   Success! Adv label: 8, L2: 529.07, Queries: 39
# Attacking sample 19/100 (True: 3, Index: 181)...
#   Success! Adv label: 5, L2: 447.15, Queries: 39
# Attacking sample 20/100 (True: 3, Index: 187)...
#   Success! Adv label: 8, L2: 608.77, Queries: 45
# Attacking sample 21/100 (True: 3, Index: 196)...
#   Success! Adv label: 2, L2: 493.94, Queries: 37
# Attacking sample 22/100 (True: 3, Index: 204)...
#   Success! Adv label: 5, L2: 889.18, Queries: 81
# Attacking sample 23/100 (True: 3, Index: 227)...
#   Failed! Adv label: 3, L2: 1031.53, Queries: 201
# Attacking sample 24/100 (True: 3, Index: 231)...
#   Success! Adv label: 5, L2: 603.96, Queries: 49
# Attacking sample 25/100 (True: 3, Index: 237)...
#   Success! Adv label: 5, L2: 909.34, Queries: 83
# Attacking sample 26/100 (True: 3, Index: 244)...
#   Success! Adv label: 7, L2: 813.21, Queries: 77
# Attacking sample 27/100 (True: 3, Index: 257)...
#   Success! Adv label: 8, L2: 536.95, Queries: 41
# Attacking sample 28/100 (True: 3, Index: 259)...
#   Success! Adv label: 5, L2: 805.20, Queries: 75
# Attacking sample 29/100 (True: 3, Index: 265)...
#   Success! Adv label: 5, L2: 480.83, Queries: 39
# Attacking sample 30/100 (True: 3, Index: 270)...
#   Success! Adv label: 5, L2: 239.39, Queries: 19
# Attacking sample 31/100 (True: 3, Index: 288)...
#   Success! Adv label: 8, L2: 968.59, Queries: 73
# Attacking sample 32/100 (True: 3, Index: 308)...
#   Success! Adv label: 8, L2: 521.44, Queries: 41
# Attacking sample 33/100 (True: 3, Index: 309)...
#   Success! Adv label: 8, L2: 529.87, Queries: 41
# Attacking sample 34/100 (True: 3, Index: 327)...
#   Success! Adv label: 1, L2: 347.03, Queries: 33
# Attacking sample 35/100 (True: 3, Index: 331)...
#   Success! Adv label: 8, L2: 794.69, Queries: 69
# Attacking sample 36/100 (True: 3, Index: 340)...
#   Success! Adv label: 2, L2: 991.74, Queries: 85
# Attacking sample 37/100 (True: 3, Index: 341)...
#   Success! Adv label: 5, L2: 557.05, Queries: 47
# Attacking sample 38/100 (True: 3, Index: 342)...
#   Success! Adv label: 5, L2: 454.54, Queries: 37
# Attacking sample 39/100 (True: 3, Index: 362)...
#   Success! Adv label: 2, L2: 534.67, Queries: 45
# Attacking sample 40/100 (True: 3, Index: 383)...
#   Success! Adv label: 2, L2: 523.08, Queries: 43
# Attacking sample 41/100 (True: 3, Index: 394)...
#   Success! Adv label: 8, L2: 484.70, Queries: 37
# Attacking sample 42/100 (True: 3, Index: 406)...
#   Success! Adv label: 2, L2: 1004.04, Queries: 163
# Attacking sample 43/100 (True: 3, Index: 409)...
#   Success! Adv label: 2, L2: 818.72, Queries: 73
# Attacking sample 44/100 (True: 3, Index: 445)...
#   Success! Adv label: 2, L2: 391.10, Queries: 31
# Attacking sample 45/100 (True: 3, Index: 456)...
#   Success! Adv label: 8, L2: 513.05, Queries: 39
# Attacking sample 46/100 (True: 3, Index: 459)...
#   Success! Adv label: 4, L2: 981.39, Queries: 99
# Attacking sample 47/100 (True: 3, Index: 461)...
#   Success! Adv label: 5, L2: 1084.69, Queries: 135
# Attacking sample 48/100 (True: 3, Index: 471)...
#   Success! Adv label: 8, L2: 837.88, Queries: 65
# Attacking sample 49/100 (True: 3, Index: 474)...
#   Success! Adv label: 5, L2: 459.63, Queries: 39
# Attacking sample 50/100 (True: 3, Index: 481)...
#   Success! Adv label: 5, L2: 747.48, Queries: 69
# Attacking sample 51/100 (True: 3, Index: 504)...
#   Success! Adv label: 5, L2: 586.05, Queries: 49
# Attacking sample 52/100 (True: 3, Index: 510)...
#   Success! Adv label: 5, L2: 309.46, Queries: 25
# Attacking sample 53/100 (True: 3, Index: 512)...
#   Failed! Adv label: 3, L2: 949.54, Queries: 201
# Attacking sample 54/100 (True: 3, Index: 524)...
#   Success! Adv label: 8, L2: 578.94, Queries: 43
# Attacking sample 55/100 (True: 3, Index: 549)...
#   Success! Adv label: 8, L2: 463.81, Queries: 41
# Attacking sample 56/100 (True: 3, Index: 556)...
#   Success! Adv label: 9, L2: 528.75, Queries: 45
# Attacking sample 57/100 (True: 3, Index: 564)...
#   Success! Adv label: 8, L2: 439.85, Queries: 33
# Attacking sample 58/100 (True: 3, Index: 586)...
#   Failed! Adv label: 3, L2: 1077.52, Queries: 201
# Attacking sample 59/100 (True: 3, Index: 589)...
#   Success! Adv label: 8, L2: 1094.43, Queries: 97
# Attacking sample 60/100 (True: 3, Index: 609)...
#   Success! Adv label: 9, L2: 661.84, Queries: 55
# Attacking sample 61/100 (True: 3, Index: 613)...
#   Success! Adv label: 8, L2: 687.00, Queries: 53
# Attacking sample 62/100 (True: 3, Index: 623)...
#   Success! Adv label: 9, L2: 387.07, Queries: 29
# Attacking sample 63/100 (True: 3, Index: 639)...
#   Success! Adv label: 5, L2: 533.82, Queries: 45
# Attacking sample 64/100 (True: 3, Index: 648)...
#   Success! Adv label: 8, L2: 403.82, Queries: 31
# Attacking sample 65/100 (True: 3, Index: 651)...
#   Success! Adv label: 8, L2: 381.19, Queries: 29
# Attacking sample 66/100 (True: 3, Index: 659)...
#   Success! Adv label: 9, L2: 605.24, Queries: 53
# Attacking sample 67/100 (True: 3, Index: 661)...
#   Success! Adv label: 5, L2: 904.04, Queries: 77
# Attacking sample 68/100 (True: 3, Index: 667)...
#   Failed! Adv label: 3, L2: 1030.93, Queries: 201
# Attacking sample 69/100 (True: 3, Index: 678)...
#   Success! Adv label: 4, L2: 873.59, Queries: 107
# Attacking sample 70/100 (True: 3, Index: 690)...
#   Success! Adv label: 8, L2: 855.82, Queries: 63
# Attacking sample 71/100 (True: 3, Index: 693)...
#   Failed! Adv label: 3, L2: 997.29, Queries: 201
# Attacking sample 72/100 (True: 3, Index: 694)...
#   Success! Adv label: 8, L2: 713.85, Queries: 55
# Attacking sample 73/100 (True: 3, Index: 695)...
#   Success! Adv label: 2, L2: 262.13, Queries: 21
# Attacking sample 74/100 (True: 3, Index: 702)...
#   Success! Adv label: 8, L2: 371.08, Queries: 27
# Attacking sample 75/100 (True: 3, Index: 718)...
#   Success! Adv label: 2, L2: 968.54, Queries: 89
# Attacking sample 76/100 (True: 3, Index: 749)...
#   Success! Adv label: 9, L2: 775.47, Queries: 71
# Attacking sample 77/100 (True: 3, Index: 769)...
#   Success! Adv label: 9, L2: 717.09, Queries: 55
# Attacking sample 79/100 (True: 3, Index: 779)...
#   Success! Adv label: 8, L2: 427.45, Queries: 35
# Attacking sample 80/100 (True: 3, Index: 800)...
#   Success! Adv label: 8, L2: 866.75, Queries: 63
# Attacking sample 81/100 (True: 3, Index: 816)...
#   Success! Adv label: 5, L2: 243.43, Queries: 21
# Attacking sample 82/100 (True: 3, Index: 829)...
#   Success! Adv label: 2, L2: 497.18, Queries: 41
# Attacking sample 83/100 (True: 3, Index: 833)...
#   Success! Adv label: 7, L2: 935.27, Queries: 139
# Attacking sample 84/100 (True: 3, Index: 839)...
#   Success! Adv label: 8, L2: 652.11, Queries: 53
# Attacking sample 85/100 (True: 3, Index: 854)...
#   Success! Adv label: 5, L2: 311.02, Queries: 25
# Attacking sample 86/100 (True: 3, Index: 856)...
#   Success! Adv label: 2, L2: 402.88, Queries: 35
# Attacking sample 87/100 (True: 3, Index: 858)...
#   Success! Adv label: 5, L2: 99.15, Queries: 9
# Attacking sample 89/100 (True: 3, Index: 886)...
#   Success! Adv label: 8, L2: 818.98, Queries: 65
# Attacking sample 90/100 (True: 3, Index: 900)...
#   Success! Adv label: 8, L2: 659.22, Queries: 51
# Attacking sample 91/100 (True: 3, Index: 916)...
#   Success! Adv label: 5, L2: 395.19, Queries: 35
# Attacking sample 92/100 (True: 3, Index: 921)...
#   Success! Adv label: 2, L2: 447.96, Queries: 39
# Attacking sample 93/100 (True: 3, Index: 937)...
#   Success! Adv label: 9, L2: 782.08, Queries: 61
# Attacking sample 94/100 (True: 3, Index: 938)...
#   Success! Adv label: 8, L2: 665.02, Queries: 47
# Attacking sample 95/100 (True: 3, Index: 939)...
#   Success! Adv label: 8, L2: 330.85, Queries: 25
# Attacking sample 96/100 (True: 3, Index: 942)...
#   Success! Adv label: 5, L2: 889.95, Queries: 83
# Attacking sample 97/100 (True: 3, Index: 951)...
#   Success! Adv label: 8, L2: 590.39, Queries: 47
# Attacking sample 98/100 (True: 3, Index: 953)...
#   Success! Adv label: 4, L2: 1052.07, Queries: 155
# Attacking sample 99/100 (True: 3, Index: 975)...
#   Success! Adv label: 5, L2: 1098.51, Queries: 139
# Attacking sample 1/100 (True: 4, Index: 16)...
#   Success! Adv label: 9, L2: 292.23, Queries: 23
# Attacking sample 2/100 (True: 4, Index: 17)...
#   Success! Adv label: 6, L2: 404.48, Queries: 33
# Attacking sample 3/100 (True: 4, Index: 30)...
#   Success! Adv label: 8, L2: 704.38, Queries: 55
# Attacking sample 4/100 (True: 4, Index: 33)...
#   Success! Adv label: 9, L2: 500.01, Queries: 41
# Attacking sample 5/100 (True: 4, Index: 45)...
#   Success! Adv label: 8, L2: 115.47, Queries: 9
# Attacking sample 6/100 (True: 4, Index: 48)...
#   Success! Adv label: 9, L2: 733.37, Queries: 59
# Attacking sample 7/100 (True: 4, Index: 58)...
#   Success! Adv label: 9, L2: 664.12, Queries: 51
# Attacking sample 8/100 (True: 4, Index: 66)...
#   Success! Adv label: 6, L2: 551.12, Queries: 47
# Attacking sample 9/100 (True: 4, Index: 89)...
#   Success! Adv label: 9, L2: 333.78, Queries: 25
# Attacking sample 10/100 (True: 4, Index: 92)...
#   Success! Adv label: 6, L2: 812.14, Queries: 67
# Attacking sample 11/100 (True: 4, Index: 113)...
#   Success! Adv label: 9, L2: 627.26, Queries: 49
# Attacking sample 12/100 (True: 4, Index: 116)...
#   Success! Adv label: 9, L2: 573.60, Queries: 43
# Attacking sample 13/100 (True: 4, Index: 126)...
#   Success! Adv label: 9, L2: 448.50, Queries: 33
# Attacking sample 14/100 (True: 4, Index: 130)...
#   Success! Adv label: 9, L2: 333.86, Queries: 25
# Attacking sample 15/100 (True: 4, Index: 139)...
#   Success! Adv label: 9, L2: 488.77, Queries: 37
# Attacking sample 16/100 (True: 4, Index: 149)...
#   Success! Adv label: 2, L2: 974.48, Queries: 83
# Attacking sample 17/100 (True: 4, Index: 153)...
#   Success! Adv label: 8, L2: 471.41, Queries: 37
# Attacking sample 18/100 (True: 4, Index: 154)...
#   Success! Adv label: 7, L2: 823.50, Queries: 67
# Attacking sample 19/100 (True: 4, Index: 163)...
#   Success! Adv label: 9, L2: 503.96, Queries: 39
# Attacking sample 20/100 (True: 4, Index: 167)...
#   Success! Adv label: 9, L2: 610.54, Queries: 47
# Attacking sample 21/100 (True: 4, Index: 183)...
#   Success! Adv label: 9, L2: 375.21, Queries: 31
# Attacking sample 22/100 (True: 4, Index: 184)...
#   Success! Adv label: 9, L2: 549.77, Queries: 43
# Attacking sample 23/100 (True: 4, Index: 192)...
#   Success! Adv label: 9, L2: 264.77, Queries: 21
# Attacking sample 24/100 (True: 4, Index: 194)...
#   Success! Adv label: 9, L2: 497.71, Queries: 41
# Attacking sample 25/100 (True: 4, Index: 233)...
#   Success! Adv label: 9, L2: 649.93, Queries: 53
# Attacking sample 26/100 (True: 4, Index: 240)...
#   Success! Adv label: 8, L2: 557.39, Queries: 41
# Attacking sample 27/100 (True: 4, Index: 263)...
#   Success! Adv label: 9, L2: 252.21, Queries: 19
# Attacking sample 28/100 (True: 4, Index: 269)...
#   Success! Adv label: 9, L2: 346.69, Queries: 27
# Attacking sample 29/100 (True: 4, Index: 280)...
#   Success! Adv label: 9, L2: 352.95, Queries: 27
# Attacking sample 30/100 (True: 4, Index: 290)...
#   Success! Adv label: 9, L2: 589.97, Queries: 43
# Attacking sample 31/100 (True: 4, Index: 297)...
#   Success! Adv label: 6, L2: 400.18, Queries: 33
# Attacking sample 32/100 (True: 4, Index: 299)...
#   Success! Adv label: 9, L2: 353.25, Queries: 27
# Attacking sample 33/100 (True: 4, Index: 310)...
#   Success! Adv label: 9, L2: 327.65, Queries: 25
# Attacking sample 34/100 (True: 4, Index: 316)...
#   Success! Adv label: 9, L2: 445.03, Queries: 33
# Attacking sample 35/100 (True: 4, Index: 320)...
#   Success! Adv label: 9, L2: 420.43, Queries: 33
# Attacking sample 36/100 (True: 4, Index: 324)...
#   Success! Adv label: 9, L2: 446.16, Queries: 35
# Attacking sample 37/100 (True: 4, Index: 326)...
#   Success! Adv label: 9, L2: 507.26, Queries: 41
# Attacking sample 38/100 (True: 4, Index: 332)...
#   Success! Adv label: 9, L2: 32.85, Queries: 3
# Attacking sample 39/100 (True: 4, Index: 335)...
#   Success! Adv label: 9, L2: 633.71, Queries: 49
# Attacking sample 40/100 (True: 4, Index: 344)...
#   Success! Adv label: 7, L2: 492.74, Queries: 41
# Attacking sample 42/100 (True: 4, Index: 359)...
#   Success! Adv label: 9, L2: 428.50, Queries: 33
# Attacking sample 43/100 (True: 4, Index: 376)...
#   Success! Adv label: 9, L2: 548.50, Queries: 43
# Attacking sample 44/100 (True: 4, Index: 393)...
#   Success! Adv label: 9, L2: 519.20, Queries: 39
# Attacking sample 45/100 (True: 4, Index: 401)...
#   Success! Adv label: 2, L2: 659.86, Queries: 55
# Attacking sample 46/100 (True: 4, Index: 402)...
#   Success! Adv label: 9, L2: 474.12, Queries: 37
# Attacking sample 47/100 (True: 4, Index: 422)...
#   Success! Adv label: 9, L2: 344.25, Queries: 25
# Attacking sample 48/100 (True: 4, Index: 423)...
#   Success! Adv label: 9, L2: 185.73, Queries: 15
# Attacking sample 49/100 (True: 4, Index: 427)...
#   Success! Adv label: 1, L2: 525.84, Queries: 47
# Attacking sample 50/100 (True: 4, Index: 432)...
#   Success! Adv label: 9, L2: 372.38, Queries: 29
# Attacking sample 51/100 (True: 4, Index: 434)...
#   Success! Adv label: 9, L2: 277.06, Queries: 21
# Attacking sample 52/100 (True: 4, Index: 454)...
#   Success! Adv label: 9, L2: 548.14, Queries: 43
# Attacking sample 53/100 (True: 4, Index: 467)...
#   Success! Adv label: 8, L2: 327.26, Queries: 25
# Attacking sample 54/100 (True: 4, Index: 501)...
#   Success! Adv label: 9, L2: 262.10, Queries: 21
# Attacking sample 55/100 (True: 4, Index: 515)...
#   Success! Adv label: 9, L2: 335.21, Queries: 25
# Attacking sample 56/100 (True: 4, Index: 540)...
#   Success! Adv label: 9, L2: 569.38, Queries: 45
# Attacking sample 57/100 (True: 4, Index: 544)...
#   Success! Adv label: 0, L2: 400.60, Queries: 33
# Attacking sample 58/100 (True: 4, Index: 545)...
#   Success! Adv label: 9, L2: 370.92, Queries: 29
# Attacking sample 59/100 (True: 4, Index: 547)...
#   Success! Adv label: 8, L2: 816.37, Queries: 75
# Attacking sample 60/100 (True: 4, Index: 566)...
#   Success! Adv label: 9, L2: 390.17, Queries: 29
# Attacking sample 61/100 (True: 4, Index: 590)...
#   Success! Adv label: 0, L2: 432.77, Queries: 35
# Attacking sample 62/100 (True: 4, Index: 593)...
#   Success! Adv label: 9, L2: 333.28, Queries: 25
# Attacking sample 63/100 (True: 4, Index: 599)...
#   Success! Adv label: 9, L2: 640.97, Queries: 55
# Attacking sample 64/100 (True: 4, Index: 602)...
#   Success! Adv label: 9, L2: 484.47, Queries: 37
# Attacking sample 65/100 (True: 4, Index: 607)...
#   Success! Adv label: 7, L2: 565.75, Queries: 53
# Attacking sample 66/100 (True: 4, Index: 611)...
#   Success! Adv label: 9, L2: 604.21, Queries: 47
# Attacking sample 67/100 (True: 4, Index: 617)...
#   Success! Adv label: 9, L2: 506.26, Queries: 37
# Attacking sample 68/100 (True: 4, Index: 657)...
#   Success! Adv label: 9, L2: 319.09, Queries: 27
# Attacking sample 69/100 (True: 4, Index: 680)...
#   Success! Adv label: 9, L2: 383.89, Queries: 29
# Attacking sample 70/100 (True: 4, Index: 684)...
#   Success! Adv label: 9, L2: 595.45, Queries: 51
# Attacking sample 71/100 (True: 4, Index: 687)...
#   Success! Adv label: 9, L2: 520.47, Queries: 39
# Attacking sample 72/100 (True: 4, Index: 692)...
#   Success! Adv label: 9, L2: 751.75, Queries: 59
# Attacking sample 73/100 (True: 4, Index: 696)...
#   Success! Adv label: 9, L2: 159.25, Queries: 13
# Attacking sample 74/100 (True: 4, Index: 697)...
#   Success! Adv label: 9, L2: 768.12, Queries: 59
# Attacking sample 75/100 (True: 4, Index: 708)...
#   Success! Adv label: 9, L2: 566.97, Queries: 43
# Attacking sample 76/100 (True: 4, Index: 717)...
#   Success! Adv label: 9, L2: 341.11, Queries: 27
# Attacking sample 77/100 (True: 4, Index: 746)...
#   Success! Adv label: 9, L2: 443.64, Queries: 35
# Attacking sample 78/100 (True: 4, Index: 752)...
#   Success! Adv label: 9, L2: 939.50, Queries: 73
# Attacking sample 79/100 (True: 4, Index: 755)...
#   Success! Adv label: 2, L2: 930.96, Queries: 87
# Attacking sample 80/100 (True: 4, Index: 757)...
#   Success! Adv label: 9, L2: 403.52, Queries: 31
# Attacking sample 81/100 (True: 4, Index: 766)...
#   Success! Adv label: 7, L2: 489.99, Queries: 43
# Attacking sample 82/100 (True: 4, Index: 771)...
#   Success! Adv label: 9, L2: 296.90, Queries: 23
# Attacking sample 83/100 (True: 4, Index: 776)...
#   Success! Adv label: 2, L2: 572.66, Queries: 47
# Attacking sample 84/100 (True: 4, Index: 777)...
#   Success! Adv label: 1, L2: 942.54, Queries: 93
# Attacking sample 85/100 (True: 4, Index: 786)...
#   Success! Adv label: 9, L2: 200.38, Queries: 15
# Attacking sample 86/100 (True: 4, Index: 811)...
#   Success! Adv label: 9, L2: 249.40, Queries: 19
# Attacking sample 87/100 (True: 4, Index: 815)...
#   Success! Adv label: 6, L2: 652.65, Queries: 53
# Attacking sample 88/100 (True: 4, Index: 817)...
#   Success! Adv label: 8, L2: 736.31, Queries: 65
# Attacking sample 89/100 (True: 4, Index: 840)...
#   Success! Adv label: 6, L2: 665.00, Queries: 53
# Attacking sample 91/100 (True: 4, Index: 849)...
#   Success! Adv label: 8, L2: 664.69, Queries: 51
# Attacking sample 92/100 (True: 4, Index: 857)...
#   Success! Adv label: 9, L2: 531.94, Queries: 41
# Attacking sample 93/100 (True: 4, Index: 872)...
#   Success! Adv label: 9, L2: 663.25, Queries: 55
# Attacking sample 94/100 (True: 4, Index: 877)...
#   Success! Adv label: 9, L2: 405.85, Queries: 33
# Attacking sample 95/100 (True: 4, Index: 894)...
#   Success! Adv label: 9, L2: 260.22, Queries: 21
# Attacking sample 96/100 (True: 4, Index: 902)...
#   Success! Adv label: 9, L2: 382.37, Queries: 29
# Attacking sample 97/100 (True: 4, Index: 911)...
#   Success! Adv label: 9, L2: 550.80, Queries: 45
# ...
#   Success! Adv label: 3, L2: 551.98, Queries: 47
# Attacking sample 40/100 (True: 8, Index: 505)...
#   Success! Adv label: 2, L2: 733.94, Queries: 63
# Attacking sample 41/100 (True: 8, Index: 509)...
#   Success! Adv label: 3, L2: 643.16, Queries: 65
# Attacking sample 42/100 (True: 8, Index: 525)...
#   Success! Adv label: 3, L2: 578.17, Queries: 53
# Attacking sample 43/100 (True: 8, Index: 528)...
#   Success! Adv label: 3, L2: 747.31, Queries: 71
# Attacking sample 44/100 (True: 8, Index: 541)...
#   Success! Adv label: 3, L2: 816.16, Queries: 71
# Attacking sample 45/100 (True: 8, Index: 543)...
#   Success! Adv label: 6, L2: 361.42, Queries: 31
# Attacking sample 46/100 (True: 8, Index: 550)...
#   Success! Adv label: 5, L2: 514.91, Queries: 45
# Attacking sample 47/100 (True: 8, Index: 558)...
#   Success! Adv label: 2, L2: 786.19, Queries: 69
# Attacking sample 48/100 (True: 8, Index: 575)...
#   Success! Adv label: 9, L2: 454.91, Queries: 39
# Attacking sample 49/100 (True: 8, Index: 594)...
#   Success! Adv label: 2, L2: 389.56, Queries: 35
# Attacking sample 50/100 (True: 8, Index: 600)...
#   Success! Adv label: 3, L2: 1029.69, Queries: 89
# Attacking sample 51/100 (True: 8, Index: 605)...
#   Success! Adv label: 2, L2: 612.95, Queries: 53
# Attacking sample 52/100 (True: 8, Index: 619)...
#   Success! Adv label: 3, L2: 550.00, Queries: 49
# Attacking sample 53/100 (True: 8, Index: 625)...
#   Success! Adv label: 3, L2: 758.60, Queries: 63
# Attacking sample 54/100 (True: 8, Index: 629)...
#   Success! Adv label: 2, L2: 528.98, Queries: 43
# Attacking sample 55/100 (True: 8, Index: 645)...
#   Success! Adv label: 9, L2: 1009.17, Queries: 91
# Attacking sample 56/100 (True: 8, Index: 652)...
#   Success! Adv label: 2, L2: 635.82, Queries: 59
# Attacking sample 57/100 (True: 8, Index: 672)...
#   Success! Adv label: 3, L2: 579.91, Queries: 57
# Attacking sample 58/100 (True: 8, Index: 683)...
#   Success! Adv label: 3, L2: 380.80, Queries: 37
# Attacking sample 59/100 (True: 8, Index: 701)...
#   Success! Adv label: 5, L2: 745.24, Queries: 71
# Attacking sample 60/100 (True: 8, Index: 714)...
#   Success! Adv label: 3, L2: 643.42, Queries: 61
# Attacking sample 61/100 (True: 8, Index: 721)...
#   Success! Adv label: 3, L2: 485.28, Queries: 43
# Attacking sample 62/100 (True: 8, Index: 730)...
#   Success! Adv label: 2, L2: 614.66, Queries: 51
# Attacking sample 63/100 (True: 8, Index: 731)...
#   Failed! Adv label: 8, L2: 1203.06, Queries: 201
# Attacking sample 64/100 (True: 8, Index: 738)...
#   Success! Adv label: 3, L2: 724.23, Queries: 71
# Attacking sample 65/100 (True: 8, Index: 791)...
#   Success! Adv label: 5, L2: 716.65, Queries: 65
# Attacking sample 66/100 (True: 8, Index: 832)...
#   Success! Adv label: 6, L2: 552.08, Queries: 49
# Attacking sample 67/100 (True: 8, Index: 838)...
#   Success! Adv label: 5, L2: 538.84, Queries: 49
# Attacking sample 68/100 (True: 8, Index: 860)...
#   Success! Adv label: 3, L2: 685.18, Queries: 65
# Attacking sample 69/100 (True: 8, Index: 864)...
#   Success! Adv label: 9, L2: 781.00, Queries: 73
# Attacking sample 70/100 (True: 8, Index: 889)...
#   Success! Adv label: 3, L2: 609.31, Queries: 55
# Attacking sample 71/100 (True: 8, Index: 905)...
#   Success! Adv label: 9, L2: 765.20, Queries: 71
# Attacking sample 73/100 (True: 8, Index: 919)...
#   Success! Adv label: 3, L2: 578.22, Queries: 51
# Attacking sample 74/100 (True: 8, Index: 923)...
#   Success! Adv label: 3, L2: 707.81, Queries: 63
# Attacking sample 75/100 (True: 8, Index: 926)...
#   Success! Adv label: 5, L2: 671.10, Queries: 59
# Attacking sample 76/100 (True: 8, Index: 933)...
#   Success! Adv label: 3, L2: 632.05, Queries: 57
# Attacking sample 78/100 (True: 8, Index: 971)...
#   Success! Adv label: 2, L2: 787.49, Queries: 69
# Attacking sample 79/100 (True: 8, Index: 1014)...
#   Success! Adv label: 3, L2: 591.81, Queries: 57
# Attacking sample 80/100 (True: 8, Index: 1034)...
#   Success! Adv label: 6, L2: 748.72, Queries: 71
# Attacking sample 81/100 (True: 8, Index: 1053)...
#   Success! Adv label: 6, L2: 583.92, Queries: 53
# Attacking sample 82/100 (True: 8, Index: 1057)...
#   Success! Adv label: 6, L2: 454.44, Queries: 35
# Attacking sample 83/100 (True: 8, Index: 1061)...
#   Success! Adv label: 1, L2: 866.95, Queries: 91
# Attacking sample 84/100 (True: 8, Index: 1062)...
#   Success! Adv label: 3, L2: 636.44, Queries: 61
# Attacking sample 85/100 (True: 8, Index: 1063)...
#   Success! Adv label: 3, L2: 652.27, Queries: 57
# Attacking sample 86/100 (True: 8, Index: 1078)...
#   Success! Adv label: 9, L2: 377.79, Queries: 29
# Attacking sample 87/100 (True: 8, Index: 1088)...
#   Success! Adv label: 2, L2: 746.97, Queries: 65
# Attacking sample 88/100 (True: 8, Index: 1100)...
#   Success! Adv label: 0, L2: 1058.76, Queries: 95
# Attacking sample 89/100 (True: 8, Index: 1106)...
#   Success! Adv label: 2, L2: 1009.38, Queries: 91
# Attacking sample 90/100 (True: 8, Index: 1120)...
#   Success! Adv label: 3, L2: 569.26, Queries: 51
# Attacking sample 91/100 (True: 8, Index: 1132)...
#   Success! Adv label: 2, L2: 643.47, Queries: 55
# Attacking sample 92/100 (True: 8, Index: 1134)...
#   Success! Adv label: 6, L2: 1074.83, Queries: 101
# Attacking sample 93/100 (True: 8, Index: 1140)...
#   Success! Adv label: 5, L2: 330.39, Queries: 29
# Attacking sample 94/100 (True: 8, Index: 1150)...
#   Success! Adv label: 9, L2: 602.88, Queries: 51
# Attacking sample 95/100 (True: 8, Index: 1165)...
#   Success! Adv label: 3, L2: 773.30, Queries: 69
# Attacking sample 96/100 (True: 8, Index: 1179)...
#   Success! Adv label: 3, L2: 609.24, Queries: 55
# Attacking sample 97/100 (True: 8, Index: 1182)...
#   Success! Adv label: 9, L2: 557.81, Queries: 49
# Attacking sample 98/100 (True: 8, Index: 1186)...
#   Success! Adv label: 2, L2: 786.52, Queries: 65
# Attacking sample 99/100 (True: 8, Index: 1189)...
#   Success! Adv label: 3, L2: 253.37, Queries: 23
# Attacking sample 100/100 (True: 8, Index: 1207)...
#   Success! Adv label: 9, L2: 681.55, Queries: 57
# Attacking sample 1/100 (True: 9, Index: 6)...
#   Success! Adv label: 7, L2: 336.50, Queries: 29
# Attacking sample 2/100 (True: 9, Index: 38)...
#   Success! Adv label: 7, L2: 80.99, Queries: 7
# Attacking sample 3/100 (True: 9, Index: 55)...
#   Success! Adv label: 0, L2: 151.51, Queries: 13
# Attacking sample 4/100 (True: 9, Index: 56)...
#   Success! Adv label: 4, L2: 431.54, Queries: 37
# Attacking sample 5/100 (True: 9, Index: 91)...
#   Success! Adv label: 3, L2: 284.71, Queries: 23
# Attacking sample 6/100 (True: 9, Index: 99)...
#   Success! Adv label: 7, L2: 480.38, Queries: 43
# Attacking sample 7/100 (True: 9, Index: 101)...
#   Success! Adv label: 4, L2: 620.22, Queries: 55
# Attacking sample 8/100 (True: 9, Index: 114)...
#   Success! Adv label: 8, L2: 700.55, Queries: 55
# Attacking sample 9/100 (True: 9, Index: 133)...
#   Success! Adv label: 8, L2: 660.62, Queries: 51
# Attacking sample 10/100 (True: 9, Index: 171)...
#   Success! Adv label: 8, L2: 89.81, Queries: 7
# Attacking sample 11/100 (True: 9, Index: 179)...
#   Success! Adv label: 7, L2: 660.26, Queries: 63
# Attacking sample 12/100 (True: 9, Index: 195)...
#   Success! Adv label: 4, L2: 233.17, Queries: 19
# Attacking sample 13/100 (True: 9, Index: 214)...
#   Success! Adv label: 4, L2: 481.56, Queries: 43
# Attacking sample 14/100 (True: 9, Index: 218)...
#   Success! Adv label: 4, L2: 381.33, Queries: 33
# Attacking sample 15/100 (True: 9, Index: 222)...
#   Success! Adv label: 8, L2: 397.38, Queries: 33
# Attacking sample 16/100 (True: 9, Index: 224)...
#   Success! Adv label: 6, L2: 507.78, Queries: 41
# Attacking sample 17/100 (True: 9, Index: 238)...
#   Success! Adv label: 4, L2: 461.40, Queries: 37
# Attacking sample 18/100 (True: 9, Index: 243)...
#   Success! Adv label: 8, L2: 683.26, Queries: 57
# Attacking sample 19/100 (True: 9, Index: 245)...
#   Success! Adv label: 4, L2: 522.24, Queries: 47
# Attacking sample 20/100 (True: 9, Index: 246)...
#   Success! Adv label: 8, L2: 631.69, Queries: 47
# Attacking sample 21/100 (True: 9, Index: 251)...
#   Success! Adv label: 7, L2: 269.36, Queries: 23
# Attacking sample 22/100 (True: 9, Index: 303)...
#   Success! Adv label: 4, L2: 298.48, Queries: 25
# Attacking sample 23/100 (True: 9, Index: 305)...
#   Success! Adv label: 8, L2: 255.69, Queries: 21
# Attacking sample 24/100 (True: 9, Index: 307)...
#   Success! Adv label: 4, L2: 561.35, Queries: 53
# Attacking sample 25/100 (True: 9, Index: 315)...
#   Success! Adv label: 8, L2: 728.72, Queries: 59
# Attacking sample 26/100 (True: 9, Index: 354)...
#   Success! Adv label: 4, L2: 536.77, Queries: 47
# Attacking sample 27/100 (True: 9, Index: 364)...
#   Success! Adv label: 4, L2: 798.80, Queries: 67
# Attacking sample 28/100 (True: 9, Index: 389)...
#   Success! Adv label: 4, L2: 325.01, Queries: 27
# Attacking sample 29/100 (True: 9, Index: 407)...
#   Success! Adv label: 8, L2: 270.83, Queries: 21
# Attacking sample 30/100 (True: 9, Index: 411)...
#   Success! Adv label: 4, L2: 190.70, Queries: 15
# Attacking sample 31/100 (True: 9, Index: 417)...
#   Success! Adv label: 7, L2: 391.10, Queries: 39
# Attacking sample 32/100 (True: 9, Index: 421)...
#   Success! Adv label: 4, L2: 400.16, Queries: 33
# Attacking sample 33/100 (True: 9, Index: 438)...
#   Success! Adv label: 4, L2: 446.63, Queries: 37
# Attacking sample 34/100 (True: 9, Index: 443)...
#   Success! Adv label: 3, L2: 609.56, Queries: 53
# Attacking sample 35/100 (True: 9, Index: 444)...
#   Success! Adv label: 4, L2: 326.39, Queries: 29
# Attacking sample 36/100 (True: 9, Index: 446)...
#   Success! Adv label: 7, L2: 583.70, Queries: 57
# Attacking sample 37/100 (True: 9, Index: 455)...
#   Success! Adv label: 7, L2: 319.20, Queries: 29
# Attacking sample 38/100 (True: 9, Index: 469)...
#   Success! Adv label: 4, L2: 809.48, Queries: 71
# Attacking sample 39/100 (True: 9, Index: 472)...
#   Success! Adv label: 3, L2: 730.54, Queries: 59
# Attacking sample 40/100 (True: 9, Index: 473)...
#   Success! Adv label: 4, L2: 647.71, Queries: 53
# Attacking sample 41/100 (True: 9, Index: 482)...
#   Success! Adv label: 4, L2: 460.30, Queries: 37
# Attacking sample 42/100 (True: 9, Index: 490)...
#   Success! Adv label: 8, L2: 853.51, Queries: 71
# Attacking sample 43/100 (True: 9, Index: 496)...
#   Success! Adv label: 4, L2: 401.10, Queries: 35
# Attacking sample 44/100 (True: 9, Index: 507)...
#   Success! Adv label: 8, L2: 450.59, Queries: 35
# Attacking sample 45/100 (True: 9, Index: 508)...
#   Success! Adv label: 7, L2: 511.38, Queries: 43
# Attacking sample 46/100 (True: 9, Index: 514)...
#   Success! Adv label: 4, L2: 196.23, Queries: 15
# Attacking sample 47/100 (True: 9, Index: 522)...
#   Success! Adv label: 4, L2: 54.31, Queries: 5
# Attacking sample 48/100 (True: 9, Index: 535)...
#   Success! Adv label: 4, L2: 465.02, Queries: 41
# Attacking sample 49/100 (True: 9, Index: 542)...
#   Success! Adv label: 8, L2: 400.35, Queries: 35
# Attacking sample 50/100 (True: 9, Index: 553)...
#   Success! Adv label: 4, L2: 596.23, Queries: 53
# Attacking sample 51/100 (True: 9, Index: 554)...
#   Success! Adv label: 4, L2: 802.36, Queries: 69
# Attacking sample 52/100 (True: 9, Index: 565)...
#   Success! Adv label: 0, L2: 429.43, Queries: 37
# Attacking sample 53/100 (True: 9, Index: 569)...
#   Success! Adv label: 4, L2: 477.63, Queries: 41
# Attacking sample 54/100 (True: 9, Index: 572)...
#   Success! Adv label: 5, L2: 354.19, Queries: 29
# Attacking sample 55/100 (True: 9, Index: 574)...
#   Success! Adv label: 8, L2: 420.25, Queries: 35
# Attacking sample 56/100 (True: 9, Index: 601)...
#   Success! Adv label: 8, L2: 388.63, Queries: 29
# Attacking sample 57/100 (True: 9, Index: 634)...
#   Success! Adv label: 5, L2: 437.41, Queries: 35
# Attacking sample 58/100 (True: 9, Index: 635)...
#   Success! Adv label: 4, L2: 599.58, Queries: 59
# Attacking sample 59/100 (True: 9, Index: 637)...
#   Success! Adv label: 4, L2: 567.47, Queries: 47
# Attacking sample 60/100 (True: 9, Index: 640)...
#   Success! Adv label: 4, L2: 536.15, Queries: 45
# Attacking sample 61/100 (True: 9, Index: 653)...
#   Success! Adv label: 3, L2: 620.51, Queries: 49
# Attacking sample 62/100 (True: 9, Index: 654)...
#   Success! Adv label: 4, L2: 530.92, Queries: 45
# Attacking sample 63/100 (True: 9, Index: 656)...
#   Success! Adv label: 4, L2: 624.41, Queries: 53
# Attacking sample 64/100 (True: 9, Index: 666)...
#   Success! Adv label: 4, L2: 459.49, Queries: 41
# Attacking sample 65/100 (True: 9, Index: 685)...
#   Success! Adv label: 7, L2: 669.05, Queries: 65
# Attacking sample 66/100 (True: 9, Index: 711)...
#   Success! Adv label: 4, L2: 207.72, Queries: 17
# Attacking sample 67/100 (True: 9, Index: 729)...
#   Success! Adv label: 8, L2: 517.08, Queries: 41
# Attacking sample 68/100 (True: 9, Index: 739)...
#   Success! Adv label: 4, L2: 438.81, Queries: 37
# Attacking sample 69/100 (True: 9, Index: 747)...
#   Success! Adv label: 8, L2: 413.81, Queries: 33
# Attacking sample 70/100 (True: 9, Index: 767)...
#   Success! Adv label: 8, L2: 476.52, Queries: 39
# Attacking sample 71/100 (True: 9, Index: 783)...
#   Success! Adv label: 5, L2: 582.37, Queries: 53
# Attacking sample 72/100 (True: 9, Index: 787)...
#   Success! Adv label: 8, L2: 633.26, Queries: 47
# Attacking sample 73/100 (True: 9, Index: 796)...
#   Success! Adv label: 7, L2: 445.64, Queries: 37
# Attacking sample 74/100 (True: 9, Index: 804)...
#   Success! Adv label: 7, L2: 685.55, Queries: 67
# Attacking sample 75/100 (True: 9, Index: 818)...
#   Success! Adv label: 4, L2: 639.49, Queries: 61
# Attacking sample 76/100 (True: 9, Index: 825)...
#   Success! Adv label: 8, L2: 384.17, Queries: 31
# Attacking sample 77/100 (True: 9, Index: 826)...
#   Success! Adv label: 1, L2: 172.29, Queries: 15
# Attacking sample 78/100 (True: 9, Index: 831)...
#   Success! Adv label: 4, L2: 517.48, Queries: 41
# Attacking sample 79/100 (True: 9, Index: 880)...
#   Success! Adv label: 5, L2: 525.25, Queries: 41
# Attacking sample 80/100 (True: 9, Index: 884)...
#   Success! Adv label: 4, L2: 481.80, Queries: 41
# Attacking sample 81/100 (True: 9, Index: 891)...
#   Success! Adv label: 4, L2: 130.66, Queries: 11
# Attacking sample 82/100 (True: 9, Index: 893)...
#   Success! Adv label: 2, L2: 674.03, Queries: 65
# Attacking sample 83/100 (True: 9, Index: 899)...
#   Success! Adv label: 4, L2: 464.97, Queries: 41
# Attacking sample 84/100 (True: 9, Index: 912)...
#   Success! Adv label: 5, L2: 556.61, Queries: 43
# Attacking sample 85/100 (True: 9, Index: 920)...
#   Success! Adv label: 4, L2: 599.71, Queries: 51
# Attacking sample 86/100 (True: 9, Index: 925)...
#   Success! Adv label: 8, L2: 356.23, Queries: 27
# Attacking sample 87/100 (True: 9, Index: 940)...
#   Success! Adv label: 4, L2: 338.29, Queries: 31
# Attacking sample 88/100 (True: 9, Index: 958)...
#   Success! Adv label: 4, L2: 480.58, Queries: 39
# Attacking sample 89/100 (True: 9, Index: 969)...
#   Success! Adv label: 8, L2: 407.36, Queries: 31
# Attacking sample 90/100 (True: 9, Index: 978)...
#   Success! Adv label: 4, L2: 451.72, Queries: 41
# Attacking sample 91/100 (True: 9, Index: 979)...
#   Success! Adv label: 4, L2: 370.21, Queries: 29
# Attacking sample 92/100 (True: 9, Index: 980)...
#   Success! Adv label: 8, L2: 368.25, Queries: 31
# Attacking sample 93/100 (True: 9, Index: 991)...
#   Success! Adv label: 7, L2: 583.14, Queries: 55
# Attacking sample 94/100 (True: 9, Index: 997)...
#   Success! Adv label: 4, L2: 232.16, Queries: 21
# Attacking sample 95/100 (True: 9, Index: 1006)...
#   Success! Adv label: 7, L2: 526.43, Queries: 49
# Attacking sample 96/100 (True: 9, Index: 1011)...
#   Success! Adv label: 4, L2: 805.00, Queries: 73
# Attacking sample 97/100 (True: 9, Index: 1020)...
#   Success! Adv label: 8, L2: 530.53, Queries: 45
# Attacking sample 98/100 (True: 9, Index: 1023)...
#   Success! Adv label: 4, L2: 824.36, Queries: 73
# Attacking sample 99/100 (True: 9, Index: 1042)...
#   Success! Adv label: 4, L2: 324.98, Queries: 25
# Attacking sample 100/100 (True: 9, Index: 1046)...
#   Success! Adv label: 4, L2: 379.84, Queries: 33
# Time taken to generate adversarial samples: 105.5235 seconds
#
# Stats saved to: adversarial_8bit_K170_test_images\per_sample_stats.csv
#
# ===== Attack Summary =====
# Total trials: 986
# Misclassified before attack: 14
# Success rate: 973/986 (98.7%)
# Mean L2 (successful): 562.17
# Mean queries (successful): 48.14
#
# Showing successful adversarial examples...

# %% [markdown]
# ### Untargeted Attack on test set; k=180

# %%
import os
import warnings
import numpy as np
import torch
import joblib
import pandas as pd
from PIL import Image
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import torch.nn.functional as F
import time


# Set seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# ─────────────── PATHS ────────────────────────────────────────────────────
LENET_MODEL_PATH = os.path.normpath("Models and Data splits/lenet.pt")  # TorchScript model
DATA_PKL = os.path.normpath("Models and Data splits/data_[SCALED] Train_Test_Splits.pkl")
RF_ALL_CLASSES_PATH = os.path.normpath("Models and Data splits/random_forest.pkl")
OUT_DIR = "adversarial_8bit_K180_test_images"
os.makedirs(OUT_DIR, exist_ok=True)

if not os.path.exists(RF_ALL_CLASSES_PATH):
    raise FileNotFoundError(f"Random Forest model not found at {RF_ALL_CLASSES_PATH}")

# ─────────── HYPER-PARAMETERS ─────────────────────────────────────────────
EPSILON_STEP = 0.01
ITERATIONS = 100
TOTAL_EPSILON = 0.5
TOP_K_FEATURES = 180
SAMPLES_PER_DIGIT = 100
MAX_L2 = 10000

def plot_adversarial_example(original_img, adv_img, true_label, adv_label, l2_mag, sample_idx, queries, title_suffix=""):
    if original_img.size == 784:
        original_img = original_img.reshape(28, 28)
    if adv_img.size == 784:
        adv_img = adv_img.reshape(28, 28)
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(original_img, cmap='gray')
    axes[0].set_title(f"Original\nTrue: {true_label}")
    axes[0].axis('off')
    axes[1].imshow(adv_img, cmap='gray')
    axes[1].set_title(f"Adversarial\nPred: {adv_label}")
    axes[1].axis('off')
    fig.suptitle(f"Sample {sample_idx} | L2: {l2_mag:.2f} | Queries: {queries} {title_suffix}")
    plt.show()
    plt.close(fig)  # <-- added here


# ─────────── Load Data ─────────────────────────────────────────────────────
try:
    data = joblib.load(DATA_PKL)
    _, X_samples , _, y_samples = data
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PKL}. Please check the path.")
    exit()

if X_samples.max() > 1.0:
    X_samples = X_samples.astype(np.float32) / 255.0
    warnings.warn("Data appeared in [0,255]; normalized to [0,1].")

# ─────────── Load TorchScripted LeNet ──────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
try:
    model = torch.jit.load(LENET_MODEL_PATH, map_location=device)
    model.eval()
    print(f"LeNet TorchScript model loaded from: {LENET_MODEL_PATH}")
except Exception as e:
    print(f"Error loading TorchScript LeNet model: {e}")
    exit()

def to_model(x01_batch):
    if x01_batch.ndim == 2 and x01_batch.shape == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)
    elif x01_batch.ndim == 3 and x01_batch.shape[1:] == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(1)
    elif x01_batch.ndim == 4 and x01_batch.shape[1] == 1:
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device)
    elif x01_batch.ndim == 1 and x01_batch.size == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(1, 1, 28, 28), dtype=torch.float32, device=device)
    elif x01_batch.ndim == 2 and x01_batch.shape[1] == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(x01_batch.shape[0], 1, 28, 28), dtype=torch.float32, device=device)
    else:
        raise ValueError(f"Unsupported input shape for to_model: {x01_batch.shape}")
    return tensor_batch


def model_query(x_tensor_batch):
    with torch.no_grad():
        return model(x_tensor_batch)

# ─────────── Load Random Forest Model ──────────────────────────────────────
rf_all_classes = None
top_feature_indices = None
print("Loading Random Forest Classifier for all classes...")
try:
    rf_all_classes = joblib.load(RF_ALL_CLASSES_PATH)
    feature_importances = rf_all_classes.feature_importances_
    #top_feature_indices = np.argsort(feature_importances)[:TOP_K_FEATURES]
    
    top_feature_indices = np.argsort(-feature_importances)[:TOP_K_FEATURES]
    print(f"Random Forest loaded. Using top {TOP_K_FEATURES} features.")
except Exception as e:
    print(f"Error loading Random Forest: {e}")
    top_feature_indices = np.arange(28 * 28)

# ─────────── I-FGSM Attack ─────────────────────────────────────────────────
def ifgsm_attack(original_image_np, true_label, model_target, epsilon_step, iterations,
                 total_epsilon_budget, features_to_perturb, query_count_tracker):
    if original_image_np.ndim == 1 and original_image_np.size == 784:
        original_image_np = original_image_np.reshape(28, 28)

    perturbed_image_np = original_image_np.copy()
    final_pred_label = true_label

    for i in range(iterations):
        image_tensor = to_model(perturbed_image_np)
        image_tensor.requires_grad = True
        output = model_target(image_tensor)
        query_count_tracker[0] += 1
        loss = F.cross_entropy(output, torch.tensor([true_label], device=device))
        model_target.zero_grad()
        loss.backward()
        data_grad_sign = torch.sign(image_tensor.grad.data).cpu().numpy()

        gradient_mask = np.zeros_like(data_grad_sign, dtype=np.float32)
        h, w = perturbed_image_np.shape
        rows, cols = np.unravel_index(features_to_perturb, (h, w))
        gradient_mask[0, 0, rows, cols] = data_grad_sign[0, 0, rows, cols]
        gradient_mask_for_update = gradient_mask.reshape(perturbed_image_np.shape)

        perturbed_image_np += epsilon_step * gradient_mask_for_update
        perturbation = perturbed_image_np - original_image_np
        perturbation = np.clip(perturbation, -total_epsilon_budget, total_epsilon_budget)
        perturbed_image_np = original_image_np + perturbation
        perturbed_image_np = np.clip(perturbed_image_np, 0, 1)

        # Discretize and check prediction on discretized image
        adv_uint8_temp = np.round(perturbed_image_np * 255).astype(np.uint8)
        adv_float_temp = adv_uint8_temp.astype(np.float32) / 255.0
        with torch.no_grad():
            output_temp = model_target(to_model(adv_float_temp))
            pred_temp = output_temp.argmax(dim=1).item()
            query_count_tracker[0] += 1

        if pred_temp != true_label:
            final_pred_label = pred_temp
            break

    # Final adversarial image (discretized)
    adv_uint8 = np.round(perturbed_image_np * 255).astype(np.uint8)
    adv_float = adv_uint8.astype(np.float32) / 255.0
    with torch.no_grad():
        output_final = model_target(to_model(adv_float))
        final_pred_label = output_final.argmax(dim=1).item()

    l2_norm = np.linalg.norm(adv_uint8.astype(np.float32) - (original_image_np * 255).astype(np.float32))
    success = (final_pred_label != true_label) and (l2_norm <= MAX_L2)

    return adv_uint8, final_pred_label, l2_norm, success


# ─────────── Attack Execution ──────────────────────────────────────────────
print(f"\n===== Starting Adversarial Attack =====")
total_trials, succ_total, misclassified = 0, 0, 0
records = []


start_time = time.time()


for digit in range(10):
    idxs = np.where(y_samples == digit)[0][:SAMPLES_PER_DIGIT]
    for rank, idx in enumerate(idxs, 1):
        x0 = X_samples[idx].copy()
        y0 = int(y_samples[idx])
        query_count_tracker = [0]
        pred0 = model_query(to_model(x0)).argmax(dim=1).item()
        query_count_tracker[0] += 1

        if pred0 != y0:
            misclassified += 1
            records.append({
                'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
                'adv_label': None, 'success': False, 'queries': query_count_tracker[0],
                'l2_mag': np.nan, 'note': 'Already misclassified'
            })
            continue

        total_trials += 1
        print(f"Attacking sample {rank}/{SAMPLES_PER_DIGIT} (True: {y0}, Index: {idx})...")
        adv_img_uint8, adv_label, l2_mag, success = ifgsm_attack(
            x0, y0, model, EPSILON_STEP, ITERATIONS, TOTAL_EPSILON,
            top_feature_indices, query_count_tracker
        )

        if success:
            succ_total += 1
            fname = f"true{y0}_adv{adv_label}_mag{l2_mag:.1f}_sample{idx}.png"
            Image.fromarray(adv_img_uint8, mode="L").save(os.path.join(OUT_DIR, fname))

        records.append({
            'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
            'adv_label': adv_label, 'success': success, 'queries': query_count_tracker[0],
            'l2_mag': l2_mag if success else np.nan, 'note': 'I-FGSM' + (' successful' if success else ' failed')
        })

        print(f"  {'Success' if success else 'Failed'}! Adv label: {adv_label}, L2: {l2_mag:.2f}, Queries: {query_count_tracker[0]}")


end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to generate adversarial samples: {elapsed_time:.4f} seconds")


# ─────────── Save Results ──────────────────────────────────────────────────
df = pd.DataFrame(records)
csv_path = os.path.join(OUT_DIR, "per_sample_stats.csv")
df.to_csv(csv_path, index=False)
print(f"\nStats saved to: {csv_path}")

# ─────────── Summary ───────────────────────────────────────────────────────
print(f"\n===== Attack Summary =====")
print(f"Total trials: {total_trials}")
print(f"Misclassified before attack: {misclassified}")
if total_trials > 0:
    success_rate = succ_total / total_trials * 100
    print(f"Success rate: {succ_total}/{total_trials} ({success_rate:.1f}%)")
    if succ_total > 0:
        print(f"Mean L2 (successful): {df[df['success']]['l2_mag'].mean():.2f}")
        print(f"Mean queries (successful): {df[df['success']]['queries'].mean():.2f}")

# ─────────── Display Examples ──────────────────────────────────────────────
success_df = df[df['success']]
if not success_df.empty:
    print("\nShowing successful adversarial examples...")
    show_ids = success_df.sample(min(3, len(success_df))).index.tolist()
    for record_idx in show_ids:
        r = df.loc[record_idx]
        fname_prefix = f"true{r['true_label']}_adv{r['adv_label']}_mag{r['l2_mag']:.1f}_sample{r['sample_idx']}"
        match_files = [f for f in os.listdir(OUT_DIR) if f.startswith(fname_prefix)]
        if match_files:
            adv_img_path = os.path.join(OUT_DIR, match_files[0])
            plot_adversarial_example(X_samples[r['sample_idx']], np.array(Image.open(adv_img_path)),
                                     r['true_label'], r['adv_label'], r['l2_mag'],
                                     r['sample_idx'], r['queries'], "(I-FGSM)")
else:
    print("No successful attacks to display. Showing original samples instead.")
    for i in range(min(3, len(df))):
        r = df.iloc[i]
        plot_adversarial_example(X_samples[r['sample_idx']], X_samples[r['sample_idx']],
                                 r['true_label'], r['initial_pred'], 0.0,
                                 r['sample_idx'], r['queries'], "(Original)")
# Out:
# LeNet TorchScript model loaded from: Models and Data splits\lenet.pt
# Loading Random Forest Classifier for all classes...
# Random Forest loaded. Using top 180 features.
#
# ===== Starting Adversarial Attack =====
# Attacking sample 1/100 (True: 0, Index: 29)...
#   Success! Adv label: 6, L2: 882.21, Queries: 79
# Attacking sample 2/100 (True: 0, Index: 40)...
#   Success! Adv label: 6, L2: 1066.75, Queries: 93
# Attacking sample 3/100 (True: 0, Index: 44)...
#   Success! Adv label: 5, L2: 581.63, Queries: 49
# Attacking sample 4/100 (True: 0, Index: 59)...
#   Success! Adv label: 6, L2: 682.08, Queries: 59
# Attacking sample 5/100 (True: 0, Index: 64)...
#   Success! Adv label: 9, L2: 1156.90, Queries: 97
# Attacking sample 6/100 (True: 0, Index: 75)...
#   Success! Adv label: 8, L2: 738.77, Queries: 65
# Attacking sample 7/100 (True: 0, Index: 80)...
#   Success! Adv label: 9, L2: 603.27, Queries: 53
# Attacking sample 8/100 (True: 0, Index: 97)...
#   Success! Adv label: 6, L2: 703.48, Queries: 61
# Attacking sample 9/100 (True: 0, Index: 115)...
#   Success! Adv label: 6, L2: 838.38, Queries: 71
# Attacking sample 10/100 (True: 0, Index: 141)...
#   Success! Adv label: 7, L2: 190.93, Queries: 17
# Attacking sample 11/100 (True: 0, Index: 146)...
#   Success! Adv label: 9, L2: 771.63, Queries: 69
# Attacking sample 12/100 (True: 0, Index: 156)...
#   Success! Adv label: 9, L2: 1107.37, Queries: 137
# Attacking sample 13/100 (True: 0, Index: 173)...
#   Success! Adv label: 6, L2: 693.01, Queries: 67
# Attacking sample 14/100 (True: 0, Index: 175)...
#   Success! Adv label: 8, L2: 472.93, Queries: 39
# Attacking sample 15/100 (True: 0, Index: 193)...
#   Success! Adv label: 9, L2: 852.20, Queries: 81
# Attacking sample 16/100 (True: 0, Index: 200)...
#   Success! Adv label: 9, L2: 745.44, Queries: 65
# Attacking sample 17/100 (True: 0, Index: 205)...
#   Success! Adv label: 9, L2: 892.68, Queries: 79
# Attacking sample 18/100 (True: 0, Index: 210)...
#   Success! Adv label: 9, L2: 818.35, Queries: 71
# Attacking sample 19/100 (True: 0, Index: 221)...
#   Success! Adv label: 9, L2: 830.78, Queries: 65
# Attacking sample 20/100 (True: 0, Index: 229)...
#   Success! Adv label: 5, L2: 1006.33, Queries: 95
# Attacking sample 21/100 (True: 0, Index: 249)...
#   Success! Adv label: 5, L2: 787.88, Queries: 81
# Attacking sample 22/100 (True: 0, Index: 258)...
#   Success! Adv label: 2, L2: 826.21, Queries: 71
# Attacking sample 23/100 (True: 0, Index: 275)...
#   Success! Adv label: 9, L2: 1179.60, Queries: 155
# Attacking sample 24/100 (True: 0, Index: 292)...
#   Success! Adv label: 2, L2: 938.62, Queries: 93
# Attacking sample 25/100 (True: 0, Index: 296)...
#   Success! Adv label: 9, L2: 667.02, Queries: 55
# Attacking sample 26/100 (True: 0, Index: 301)...
#   Success! Adv label: 9, L2: 590.32, Queries: 47
# Attacking sample 27/100 (True: 0, Index: 314)...
#   Success! Adv label: 9, L2: 727.46, Queries: 59
# Attacking sample 28/100 (True: 0, Index: 325)...
#   Success! Adv label: 9, L2: 1019.11, Queries: 91
# Attacking sample 29/100 (True: 0, Index: 333)...
#   Success! Adv label: 9, L2: 828.18, Queries: 77
# Attacking sample 30/100 (True: 0, Index: 345)...
#   Success! Adv label: 6, L2: 674.44, Queries: 55
# Attacking sample 31/100 (True: 0, Index: 349)...
#   Success! Adv label: 9, L2: 657.61, Queries: 53
# Attacking sample 32/100 (True: 0, Index: 360)...
#   Success! Adv label: 6, L2: 1160.62, Queries: 137
# Attacking sample 33/100 (True: 0, Index: 365)...
#   Success! Adv label: 5, L2: 1020.78, Queries: 95
# Attacking sample 34/100 (True: 0, Index: 366)...
#   Success! Adv label: 9, L2: 850.77, Queries: 73
# Attacking sample 35/100 (True: 0, Index: 379)...
#   Success! Adv label: 9, L2: 975.07, Queries: 83
# Attacking sample 36/100 (True: 0, Index: 385)...
#   Failed! Adv label: 0, L2: 1145.75, Queries: 201
# Attacking sample 37/100 (True: 0, Index: 397)...
#   Success! Adv label: 2, L2: 1011.54, Queries: 99
# Attacking sample 38/100 (True: 0, Index: 400)...
#   Success! Adv label: 9, L2: 1182.77, Queries: 101
# Attacking sample 39/100 (True: 0, Index: 405)...
#   Success! Adv label: 2, L2: 726.52, Queries: 57
# Attacking sample 40/100 (True: 0, Index: 410)...
#   Success! Adv label: 9, L2: 808.59, Queries: 69
# Attacking sample 41/100 (True: 0, Index: 420)...
#   Success! Adv label: 2, L2: 761.31, Queries: 71
# Attacking sample 42/100 (True: 0, Index: 424)...
#   Success! Adv label: 9, L2: 789.94, Queries: 69
# Attacking sample 43/100 (True: 0, Index: 447)...
#   Success! Adv label: 2, L2: 687.12, Queries: 59
# Attacking sample 44/100 (True: 0, Index: 453)...
#   Success! Adv label: 6, L2: 804.11, Queries: 71
# Attacking sample 45/100 (True: 0, Index: 457)...
#   Success! Adv label: 6, L2: 1004.52, Queries: 87
# Attacking sample 46/100 (True: 0, Index: 466)...
#   Success! Adv label: 2, L2: 786.65, Queries: 69
# Attacking sample 47/100 (True: 0, Index: 475)...
#   Success! Adv label: 9, L2: 273.36, Queries: 23
# Attacking sample 48/100 (True: 0, Index: 483)...
#   Success! Adv label: 2, L2: 814.44, Queries: 73
# Attacking sample 49/100 (True: 0, Index: 484)...
#   Success! Adv label: 8, L2: 475.61, Queries: 35
# Attacking sample 50/100 (True: 0, Index: 486)...
#   Success! Adv label: 9, L2: 924.51, Queries: 89
# Attacking sample 51/100 (True: 0, Index: 487)...
#   Success! Adv label: 6, L2: 669.73, Queries: 57
# Attacking sample 52/100 (True: 0, Index: 489)...
#   Success! Adv label: 9, L2: 750.84, Queries: 65
# Attacking sample 53/100 (True: 0, Index: 492)...
#   Success! Adv label: 9, L2: 673.03, Queries: 55
# Attacking sample 54/100 (True: 0, Index: 506)...
#   Success! Adv label: 2, L2: 876.28, Queries: 69
# Attacking sample 55/100 (True: 0, Index: 513)...
#   Failed! Adv label: 0, L2: 1221.86, Queries: 201
# Attacking sample 56/100 (True: 0, Index: 518)...
#   Success! Adv label: 5, L2: 978.08, Queries: 89
# Attacking sample 57/100 (True: 0, Index: 521)...
#   Success! Adv label: 9, L2: 1234.98, Queries: 139
# Attacking sample 58/100 (True: 0, Index: 527)...
#   Success! Adv label: 2, L2: 748.65, Queries: 63
# Attacking sample 59/100 (True: 0, Index: 529)...
#   Success! Adv label: 5, L2: 707.07, Queries: 69
# Attacking sample 60/100 (True: 0, Index: 531)...
#   Success! Adv label: 2, L2: 1061.09, Queries: 125
# Attacking sample 61/100 (True: 0, Index: 546)...
#   Success! Adv label: 9, L2: 710.33, Queries: 65
# Attacking sample 62/100 (True: 0, Index: 551)...
#   Success! Adv label: 6, L2: 368.08, Queries: 27
# Attacking sample 63/100 (True: 0, Index: 555)...
#   Success! Adv label: 6, L2: 913.70, Queries: 77
# Attacking sample 64/100 (True: 0, Index: 587)...
#   Success! Adv label: 2, L2: 840.91, Queries: 75
# Attacking sample 65/100 (True: 0, Index: 604)...
#   Success! Adv label: 8, L2: 761.44, Queries: 59
# Attacking sample 66/100 (True: 0, Index: 614)...
#   Success! Adv label: 8, L2: 1073.39, Queries: 91
# Attacking sample 67/100 (True: 0, Index: 615)...
#   Success! Adv label: 9, L2: 469.70, Queries: 37
# Attacking sample 68/100 (True: 0, Index: 618)...
#   Success! Adv label: 6, L2: 314.63, Queries: 25
# Attacking sample 69/100 (True: 0, Index: 638)...
#   Success! Adv label: 8, L2: 438.17, Queries: 33
# Attacking sample 70/100 (True: 0, Index: 642)...
#   Success! Adv label: 9, L2: 878.09, Queries: 83
# Attacking sample 71/100 (True: 0, Index: 655)...
#   Success! Adv label: 6, L2: 821.02, Queries: 65
# Attacking sample 72/100 (True: 0, Index: 658)...
#   Success! Adv label: 6, L2: 691.99, Queries: 55
# Attacking sample 73/100 (True: 0, Index: 665)...
#   Success! Adv label: 2, L2: 674.59, Queries: 55
# Attacking sample 74/100 (True: 0, Index: 671)...
#   Success! Adv label: 6, L2: 704.38, Queries: 55
# Attacking sample 75/100 (True: 0, Index: 681)...
#   Success! Adv label: 9, L2: 951.33, Queries: 87
# Attacking sample 76/100 (True: 0, Index: 691)...
#   Success! Adv label: 2, L2: 701.72, Queries: 55
# Attacking sample 77/100 (True: 0, Index: 700)...
#   Success! Adv label: 5, L2: 567.01, Queries: 49
# Attacking sample 78/100 (True: 0, Index: 706)...
#   Success! Adv label: 2, L2: 894.98, Queries: 121
# Attacking sample 79/100 (True: 0, Index: 712)...
#   Success! Adv label: 3, L2: 1087.16, Queries: 149
# Attacking sample 80/100 (True: 0, Index: 713)...
#   Success! Adv label: 9, L2: 772.68, Queries: 63
# Attacking sample 81/100 (True: 0, Index: 736)...
#   Success! Adv label: 5, L2: 667.59, Queries: 59
# Attacking sample 82/100 (True: 0, Index: 742)...
#   Success! Adv label: 6, L2: 709.28, Queries: 63
# Attacking sample 83/100 (True: 0, Index: 744)...
#   Success! Adv label: 2, L2: 593.09, Queries: 49
# Attacking sample 84/100 (True: 0, Index: 760)...
#   Success! Adv label: 9, L2: 676.71, Queries: 59
# Attacking sample 85/100 (True: 0, Index: 772)...
#   Success! Adv label: 9, L2: 329.13, Queries: 25
# Attacking sample 86/100 (True: 0, Index: 781)...
#   Success! Adv label: 6, L2: 490.16, Queries: 41
# Attacking sample 87/100 (True: 0, Index: 809)...
#   Success! Adv label: 5, L2: 665.61, Queries: 61
# Attacking sample 88/100 (True: 0, Index: 813)...
#   Success! Adv label: 9, L2: 541.23, Queries: 47
# Attacking sample 89/100 (True: 0, Index: 820)...
#   Success! Adv label: 9, L2: 635.08, Queries: 57
# Attacking sample 90/100 (True: 0, Index: 823)...
#   Success! Adv label: 5, L2: 726.28, Queries: 69
# Attacking sample 91/100 (True: 0, Index: 844)...
#   Success! Adv label: 9, L2: 1094.88, Queries: 143
# Attacking sample 92/100 (True: 0, Index: 848)...
#   Success! Adv label: 9, L2: 322.91, Queries: 25
# Attacking sample 93/100 (True: 0, Index: 861)...
#   Success! Adv label: 6, L2: 953.79, Queries: 73
# Attacking sample 94/100 (True: 0, Index: 865)...
#   Success! Adv label: 6, L2: 1231.80, Queries: 97
# Attacking sample 95/100 (True: 0, Index: 869)...
#   Success! Adv label: 6, L2: 1011.25, Queries: 87
# Attacking sample 96/100 (True: 0, Index: 876)...
#   Success! Adv label: 9, L2: 679.79, Queries: 55
# Attacking sample 97/100 (True: 0, Index: 885)...
#   Success! Adv label: 9, L2: 1100.28, Queries: 147
# Attacking sample 98/100 (True: 0, Index: 906)...
#   Success! Adv label: 2, L2: 926.07, Queries: 81
# Attacking sample 99/100 (True: 0, Index: 907)...
#   Success! Adv label: 9, L2: 820.49, Queries: 71
# Attacking sample 100/100 (True: 0, Index: 918)...
#   Success! Adv label: 9, L2: 941.82, Queries: 81
# Attacking sample 1/100 (True: 1, Index: 2)...
#   Success! Adv label: 7, L2: 285.20, Queries: 21
# Attacking sample 2/100 (True: 1, Index: 3)...
#   Success! Adv label: 7, L2: 350.77, Queries: 25
# Attacking sample 3/100 (True: 1, Index: 9)...
#   Success! Adv label: 2, L2: 343.87, Queries: 27
# Attacking sample 4/100 (True: 1, Index: 25)...
#   Success! Adv label: 4, L2: 332.84, Queries: 23
# Attacking sample 5/100 (True: 1, Index: 36)...
#   Success! Adv label: 2, L2: 280.58, Queries: 21
# Attacking sample 6/100 (True: 1, Index: 63)...
#   Success! Adv label: 8, L2: 272.38, Queries: 21
# Attacking sample 7/100 (True: 1, Index: 65)...
#   Success! Adv label: 8, L2: 358.06, Queries: 25
# Attacking sample 8/100 (True: 1, Index: 68)...
#   Success! Adv label: 8, L2: 369.48, Queries: 25
# Attacking sample 9/100 (True: 1, Index: 76)...
#   Success! Adv label: 8, L2: 224.47, Queries: 17
# Attacking sample 10/100 (True: 1, Index: 83)...
#   Success! Adv label: 4, L2: 364.65, Queries: 27
# Attacking sample 11/100 (True: 1, Index: 90)...
#   Success! Adv label: 9, L2: 33.12, Queries: 3
# Attacking sample 12/100 (True: 1, Index: 94)...
#   Success! Adv label: 8, L2: 210.41, Queries: 15
# Attacking sample 13/100 (True: 1, Index: 100)...
#   Success! Adv label: 8, L2: 230.12, Queries: 17
# Attacking sample 14/100 (True: 1, Index: 123)...
#   Success! Adv label: 8, L2: 203.40, Queries: 15
# Attacking sample 15/100 (True: 1, Index: 150)...
#   Success! Adv label: 8, L2: 335.60, Queries: 23
# Attacking sample 16/100 (True: 1, Index: 152)...
#   Success! Adv label: 9, L2: 340.73, Queries: 25
# Attacking sample 17/100 (True: 1, Index: 178)...
#   Success! Adv label: 4, L2: 328.53, Queries: 23
# Attacking sample 18/100 (True: 1, Index: 185)...
#   Success! Adv label: 8, L2: 364.16, Queries: 29
# Attacking sample 19/100 (True: 1, Index: 191)...
#   Success! Adv label: 4, L2: 419.30, Queries: 29
# Attacking sample 20/100 (True: 1, Index: 201)...
#   Success! Adv label: 8, L2: 328.81, Queries: 23
# Attacking sample 21/100 (True: 1, Index: 203)...
#   Success! Adv label: 8, L2: 274.05, Queries: 19
# Attacking sample 22/100 (True: 1, Index: 213)...
#   Success! Adv label: 8, L2: 283.01, Queries: 21
# Attacking sample 23/100 (True: 1, Index: 220)...
#   Success! Adv label: 8, L2: 234.37, Queries: 17
# Attacking sample 24/100 (True: 1, Index: 223)...
#   Success! Adv label: 4, L2: 350.43, Queries: 25
# Attacking sample 25/100 (True: 1, Index: 226)...
#   Success! Adv label: 4, L2: 331.62, Queries: 23
# Attacking sample 26/100 (True: 1, Index: 232)...
#   Success! Adv label: 4, L2: 417.72, Queries: 29
# Attacking sample 27/100 (True: 1, Index: 241)...
#   Success! Adv label: 4, L2: 287.45, Queries: 21
# Attacking sample 28/100 (True: 1, Index: 254)...
#   Success! Adv label: 8, L2: 295.86, Queries: 21
# Attacking sample 29/100 (True: 1, Index: 281)...
#   Success! Adv label: 8, L2: 276.95, Queries: 21
# Attacking sample 30/100 (True: 1, Index: 284)...
#   Success! Adv label: 8, L2: 327.58, Queries: 25
# Attacking sample 31/100 (True: 1, Index: 285)...
#   Success! Adv label: 9, L2: 223.28, Queries: 17
# Attacking sample 32/100 (True: 1, Index: 286)...
#   Success! Adv label: 4, L2: 287.70, Queries: 21
# Attacking sample 33/100 (True: 1, Index: 287)...
#   Success! Adv label: 4, L2: 309.31, Queries: 23
# Attacking sample 34/100 (True: 1, Index: 294)...
#   Success! Adv label: 4, L2: 357.46, Queries: 25
# Attacking sample 35/100 (True: 1, Index: 298)...
#   Success! Adv label: 7, L2: 445.36, Queries: 31
# Attacking sample 36/100 (True: 1, Index: 306)...
#   Success! Adv label: 4, L2: 380.84, Queries: 27
# Attacking sample 37/100 (True: 1, Index: 312)...
#   Success! Adv label: 8, L2: 330.33, Queries: 25
# Attacking sample 38/100 (True: 1, Index: 317)...
#   Success! Adv label: 4, L2: 343.58, Queries: 25
# Attacking sample 39/100 (True: 1, Index: 334)...
#   Success! Adv label: 4, L2: 364.21, Queries: 25
# Attacking sample 40/100 (True: 1, Index: 337)...
#   Success! Adv label: 8, L2: 362.32, Queries: 25
# Attacking sample 41/100 (True: 1, Index: 338)...
#   Success! Adv label: 4, L2: 482.24, Queries: 33
# Attacking sample 42/100 (True: 1, Index: 348)...
#   Success! Adv label: 2, L2: 431.07, Queries: 31
# Attacking sample 43/100 (True: 1, Index: 361)...
#   Success! Adv label: 8, L2: 266.32, Queries: 19
# Attacking sample 44/100 (True: 1, Index: 363)...
#   Success! Adv label: 8, L2: 328.91, Queries: 23
# Attacking sample 45/100 (True: 1, Index: 367)...
#   Success! Adv label: 8, L2: 176.28, Queries: 13
# Attacking sample 46/100 (True: 1, Index: 375)...
#   Success! Adv label: 7, L2: 410.41, Queries: 29
# Attacking sample 47/100 (True: 1, Index: 384)...
#   Success! Adv label: 8, L2: 268.82, Queries: 19
# Attacking sample 48/100 (True: 1, Index: 412)...
#   Success! Adv label: 8, L2: 389.83, Queries: 27
# Attacking sample 49/100 (True: 1, Index: 425)...
#   Success! Adv label: 7, L2: 380.06, Queries: 27
# Attacking sample 50/100 (True: 1, Index: 428)...
#   Success! Adv label: 4, L2: 334.50, Queries: 23
# Attacking sample 51/100 (True: 1, Index: 463)...
#   Success! Adv label: 4, L2: 281.14, Queries: 21
# Attacking sample 52/100 (True: 1, Index: 499)...
#   Success! Adv label: 4, L2: 386.01, Queries: 27
# Attacking sample 53/100 (True: 1, Index: 502)...
#   Success! Adv label: 4, L2: 377.04, Queries: 27
# Attacking sample 54/100 (True: 1, Index: 526)...
#   Success! Adv label: 8, L2: 268.63, Queries: 19
# Attacking sample 55/100 (True: 1, Index: 532)...
#   Success! Adv label: 4, L2: 331.19, Queries: 23
# Attacking sample 56/100 (True: 1, Index: 536)...
#   Success! Adv label: 9, L2: 250.04, Queries: 19
# Attacking sample 57/100 (True: 1, Index: 537)...
#   Success! Adv label: 8, L2: 317.16, Queries: 23
# Attacking sample 58/100 (True: 1, Index: 539)...
#   Success! Adv label: 4, L2: 360.03, Queries: 25
# Attacking sample 60/100 (True: 1, Index: 560)...
#   Success! Adv label: 4, L2: 325.80, Queries: 23
# Attacking sample 61/100 (True: 1, Index: 561)...
#   Success! Adv label: 8, L2: 266.26, Queries: 19
# Attacking sample 62/100 (True: 1, Index: 570)...
#   Success! Adv label: 8, L2: 319.65, Queries: 23
# Attacking sample 63/100 (True: 1, Index: 573)...
#   Success! Adv label: 2, L2: 36.67, Queries: 3
# Attacking sample 64/100 (True: 1, Index: 576)...
#   Success! Adv label: 7, L2: 306.14, Queries: 23
# Attacking sample 65/100 (True: 1, Index: 580)...
#   Success! Adv label: 4, L2: 292.70, Queries: 21
# Attacking sample 66/100 (True: 1, Index: 588)...
#   Success! Adv label: 7, L2: 418.78, Queries: 31
# Attacking sample 67/100 (True: 1, Index: 620)...
#   Success! Adv label: 8, L2: 368.10, Queries: 25
# Attacking sample 68/100 (True: 1, Index: 621)...
#   Success! Adv label: 4, L2: 359.62, Queries: 25
# Attacking sample 69/100 (True: 1, Index: 622)...
#   Success! Adv label: 2, L2: 116.17, Queries: 9
# Attacking sample 70/100 (True: 1, Index: 627)...
#   Success! Adv label: 8, L2: 257.81, Queries: 19
# Attacking sample 71/100 (True: 1, Index: 630)...
#   Success! Adv label: 8, L2: 217.00, Queries: 15
# Attacking sample 72/100 (True: 1, Index: 632)...
#   Success! Adv label: 4, L2: 274.69, Queries: 19
# Attacking sample 73/100 (True: 1, Index: 644)...
#   Success! Adv label: 4, L2: 267.60, Queries: 19
# Attacking sample 74/100 (True: 1, Index: 646)...
#   Success! Adv label: 7, L2: 297.99, Queries: 23
# Attacking sample 75/100 (True: 1, Index: 649)...
#   Success! Adv label: 8, L2: 422.09, Queries: 29
# Attacking sample 76/100 (True: 1, Index: 662)...
#   Success! Adv label: 4, L2: 359.08, Queries: 25
# Attacking sample 77/100 (True: 1, Index: 663)...
#   Success! Adv label: 8, L2: 274.03, Queries: 19
# Attacking sample 78/100 (True: 1, Index: 669)...
#   Success! Adv label: 9, L2: 464.11, Queries: 33
# Attacking sample 79/100 (True: 1, Index: 677)...
#   Success! Adv label: 9, L2: 262.04, Queries: 19
# Attacking sample 80/100 (True: 1, Index: 686)...
#   Success! Adv label: 8, L2: 305.24, Queries: 23
# Attacking sample 81/100 (True: 1, Index: 689)...
#   Success! Adv label: 8, L2: 344.33, Queries: 23
# Attacking sample 82/100 (True: 1, Index: 703)...
#   Success! Adv label: 8, L2: 325.55, Queries: 23
# Attacking sample 83/100 (True: 1, Index: 705)...
#   Success! Adv label: 7, L2: 509.84, Queries: 37
# Attacking sample 84/100 (True: 1, Index: 709)...
#   Success! Adv label: 4, L2: 307.32, Queries: 23
# Attacking sample 85/100 (True: 1, Index: 724)...
#   Success! Adv label: 4, L2: 214.02, Queries: 15
# Attacking sample 86/100 (True: 1, Index: 727)...
#   Success! Adv label: 8, L2: 277.48, Queries: 19
# Attacking sample 87/100 (True: 1, Index: 734)...
#   Success! Adv label: 8, L2: 198.31, Queries: 15
# Attacking sample 88/100 (True: 1, Index: 740)...
#   Success! Adv label: 4, L2: 330.95, Queries: 23
# Attacking sample 89/100 (True: 1, Index: 741)...
#   Success! Adv label: 8, L2: 233.28, Queries: 17
# Attacking sample 90/100 (True: 1, Index: 743)...
#   Success! Adv label: 8, L2: 303.72, Queries: 21
# Attacking sample 91/100 (True: 1, Index: 759)...
#   Success! Adv label: 4, L2: 349.35, Queries: 25
# Attacking sample 92/100 (True: 1, Index: 768)...
#   Success! Adv label: 8, L2: 287.47, Queries: 21
# Attacking sample 93/100 (True: 1, Index: 775)...
#   Success! Adv label: 4, L2: 257.85, Queries: 19
# Attacking sample 94/100 (True: 1, Index: 782)...
#   Success! Adv label: 4, L2: 360.59, Queries: 25
# Attacking sample 95/100 (True: 1, Index: 798)...
#   Success! Adv label: 9, L2: 311.99, Queries: 23
# Attacking sample 96/100 (True: 1, Index: 799)...
#   Success! Adv label: 8, L2: 421.72, Queries: 29
# Attacking sample 97/100 (True: 1, Index: 808)...
#   Success! Adv label: 7, L2: 360.95, Queries: 25
# Attacking sample 98/100 (True: 1, Index: 819)...
#   Success! Adv label: 4, L2: 425.72, Queries: 29
# Attacking sample 99/100 (True: 1, Index: 843)...
#   Success! Adv label: 4, L2: 418.56, Queries: 29
# Attacking sample 100/100 (True: 1, Index: 853)...
#   Success! Adv label: 4, L2: 350.52, Queries: 25
# Attacking sample 1/100 (True: 2, Index: 4)...
#   Success! Adv label: 3, L2: 567.39, Queries: 45
# Attacking sample 2/100 (True: 2, Index: 22)...
#   Success! Adv label: 6, L2: 558.32, Queries: 53
# Attacking sample 3/100 (True: 2, Index: 32)...
#   Success! Adv label: 9, L2: 994.26, Queries: 81
# Attacking sample 4/100 (True: 2, Index: 34)...
#   Success! Adv label: 4, L2: 33.66, Queries: 3
# Attacking sample 5/100 (True: 2, Index: 42)...
#   Success! Adv label: 3, L2: 252.66, Queries: 19
# Attacking sample 6/100 (True: 2, Index: 49)...
#   Success! Adv label: 3, L2: 1048.18, Queries: 157
# Attacking sample 7/100 (True: 2, Index: 52)...
#   Success! Adv label: 8, L2: 985.85, Queries: 91
# Attacking sample 8/100 (True: 2, Index: 69)...
#   Success! Adv label: 8, L2: 695.58, Queries: 53
# Attacking sample 9/100 (True: 2, Index: 70)...
#   Success! Adv label: 3, L2: 692.24, Queries: 69
# Attacking sample 10/100 (True: 2, Index: 81)...
#   Success! Adv label: 8, L2: 858.40, Queries: 61
# Attacking sample 11/100 (True: 2, Index: 110)...
#   Success! Adv label: 7, L2: 951.64, Queries: 81
# Attacking sample 12/100 (True: 2, Index: 118)...
#   Success! Adv label: 3, L2: 565.02, Queries: 45
# Attacking sample 13/100 (True: 2, Index: 121)...
#   Success! Adv label: 3, L2: 623.14, Queries: 49
# Attacking sample 14/100 (True: 2, Index: 138)...
#   Success! Adv label: 3, L2: 646.63, Queries: 51
# Attacking sample 15/100 (True: 2, Index: 144)...
#   Success! Adv label: 0, L2: 670.52, Queries: 53
# Attacking sample 16/100 (True: 2, Index: 155)...
#   Success! Adv label: 8, L2: 826.92, Queries: 59
# Attacking sample 17/100 (True: 2, Index: 160)...
#   Success! Adv label: 6, L2: 367.69, Queries: 31
# Attacking sample 18/100 (True: 2, Index: 161)...
#   Success! Adv label: 3, L2: 614.45, Queries: 49
# Attacking sample 19/100 (True: 2, Index: 176)...
#   Success! Adv label: 3, L2: 626.95, Queries: 49
# Attacking sample 21/100 (True: 2, Index: 186)...
#   Success! Adv label: 7, L2: 649.19, Queries: 61
# Attacking sample 22/100 (True: 2, Index: 197)...
#   Success! Adv label: 8, L2: 920.14, Queries: 83
# Attacking sample 23/100 (True: 2, Index: 208)...
#   Success! Adv label: 8, L2: 828.24, Queries: 69
# Attacking sample 25/100 (True: 2, Index: 216)...
#   Success! Adv label: 3, L2: 790.37, Queries: 67
# Attacking sample 26/100 (True: 2, Index: 219)...
#   Success! Adv label: 3, L2: 391.00, Queries: 33
# Attacking sample 27/100 (True: 2, Index: 235)...
#   Success! Adv label: 3, L2: 727.06, Queries: 61
# Attacking sample 28/100 (True: 2, Index: 260)...
#   Success! Adv label: 0, L2: 519.36, Queries: 43
# Attacking sample 29/100 (True: 2, Index: 276)...
#   Success! Adv label: 4, L2: 508.96, Queries: 45
# Attacking sample 30/100 (True: 2, Index: 293)...
#   Success! Adv label: 3, L2: 760.78, Queries: 73
# Attacking sample 31/100 (True: 2, Index: 295)...
#   Success! Adv label: 3, L2: 525.20, Queries: 43
# Attacking sample 32/100 (True: 2, Index: 311)...
#   Success! Adv label: 3, L2: 546.55, Queries: 45
# Attacking sample 33/100 (True: 2, Index: 313)...
#   Success! Adv label: 3, L2: 176.85, Queries: 15
# Attacking sample 34/100 (True: 2, Index: 322)...
#   Success! Adv label: 7, L2: 667.93, Queries: 55
# Attacking sample 35/100 (True: 2, Index: 328)...
#   Success! Adv label: 8, L2: 679.42, Queries: 53
# Attacking sample 36/100 (True: 2, Index: 357)...
#   Success! Adv label: 7, L2: 501.77, Queries: 43
# Attacking sample 37/100 (True: 2, Index: 374)...
#   Success! Adv label: 8, L2: 414.50, Queries: 33
# Attacking sample 38/100 (True: 2, Index: 395)...
#   Success! Adv label: 8, L2: 459.55, Queries: 41
# Attacking sample 39/100 (True: 2, Index: 396)...
#   Success! Adv label: 8, L2: 540.72, Queries: 41
# Attacking sample 40/100 (True: 2, Index: 398)...
#   Success! Adv label: 3, L2: 778.01, Queries: 65
# Attacking sample 41/100 (True: 2, Index: 433)...
#   Success! Adv label: 3, L2: 596.87, Queries: 45
# Attacking sample 42/100 (True: 2, Index: 439)...
#   Success! Adv label: 8, L2: 630.60, Queries: 47
# Attacking sample 43/100 (True: 2, Index: 441)...
#   Success! Adv label: 8, L2: 314.07, Queries: 23
# Attacking sample 44/100 (True: 2, Index: 442)...
#   Success! Adv label: 9, L2: 704.37, Queries: 55
# Attacking sample 45/100 (True: 2, Index: 451)...
#   Success! Adv label: 0, L2: 1046.20, Queries: 83
# Attacking sample 46/100 (True: 2, Index: 462)...
#   Success! Adv label: 3, L2: 713.01, Queries: 53
# Attacking sample 47/100 (True: 2, Index: 470)...
#   Success! Adv label: 3, L2: 638.98, Queries: 51
# Attacking sample 48/100 (True: 2, Index: 477)...
#   Success! Adv label: 3, L2: 877.03, Queries: 73
# Attacking sample 49/100 (True: 2, Index: 485)...
#   Success! Adv label: 7, L2: 235.94, Queries: 19
# Attacking sample 50/100 (True: 2, Index: 491)...
#   Success! Adv label: 8, L2: 749.45, Queries: 55
# Attacking sample 51/100 (True: 2, Index: 493)...
#   Success! Adv label: 7, L2: 757.29, Queries: 73
# Attacking sample 52/100 (True: 2, Index: 495)...
#   Success! Adv label: 3, L2: 637.01, Queries: 53
# Attacking sample 53/100 (True: 2, Index: 519)...
#   Success! Adv label: 3, L2: 800.86, Queries: 65
# Attacking sample 54/100 (True: 2, Index: 523)...
#   Success! Adv label: 6, L2: 578.02, Queries: 49
# Attacking sample 55/100 (True: 2, Index: 557)...
#   Success! Adv label: 8, L2: 604.40, Queries: 43
# Attacking sample 56/100 (True: 2, Index: 567)...
#   Success! Adv label: 0, L2: 442.78, Queries: 35
# Attacking sample 57/100 (True: 2, Index: 571)...
#   Success! Adv label: 7, L2: 623.10, Queries: 53
# Attacking sample 58/100 (True: 2, Index: 584)...
#   Success! Adv label: 3, L2: 1061.18, Queries: 83
# Attacking sample 59/100 (True: 2, Index: 591)...
#   Success! Adv label: 8, L2: 918.10, Queries: 79
# Attacking sample 60/100 (True: 2, Index: 592)...
#   Success! Adv label: 8, L2: 787.92, Queries: 71
# Attacking sample 61/100 (True: 2, Index: 610)...
#   Success! Adv label: 3, L2: 1034.09, Queries: 85
# Attacking sample 62/100 (True: 2, Index: 612)...
#   Success! Adv label: 8, L2: 636.51, Queries: 45
# Attacking sample 63/100 (True: 2, Index: 616)...
#   Success! Adv label: 3, L2: 790.00, Queries: 63
# Attacking sample 64/100 (True: 2, Index: 624)...
#   Success! Adv label: 3, L2: 723.14, Queries: 55
# Attacking sample 65/100 (True: 2, Index: 631)...
#   Success! Adv label: 3, L2: 478.48, Queries: 39
# Attacking sample 66/100 (True: 2, Index: 636)...
#   Success! Adv label: 3, L2: 820.65, Queries: 63
# Attacking sample 67/100 (True: 2, Index: 647)...
#   Success! Adv label: 1, L2: 121.70, Queries: 11
# Attacking sample 68/100 (True: 2, Index: 650)...
#   Success! Adv label: 3, L2: 189.00, Queries: 15
# Attacking sample 69/100 (True: 2, Index: 664)...
#   Success! Adv label: 8, L2: 866.83, Queries: 69
# Attacking sample 70/100 (True: 2, Index: 704)...
#   Success! Adv label: 3, L2: 649.04, Queries: 53
# Attacking sample 71/100 (True: 2, Index: 720)...
#   Success! Adv label: 4, L2: 216.04, Queries: 17
# Attacking sample 72/100 (True: 2, Index: 725)...
#   Success! Adv label: 3, L2: 488.87, Queries: 39
# Attacking sample 73/100 (True: 2, Index: 750)...
#   Success! Adv label: 7, L2: 944.24, Queries: 95
# Attacking sample 74/100 (True: 2, Index: 764)...
#   Success! Adv label: 1, L2: 614.85, Queries: 63
# Attacking sample 75/100 (True: 2, Index: 780)...
#   Success! Adv label: 8, L2: 741.25, Queries: 55
# Attacking sample 76/100 (True: 2, Index: 784)...
#   Success! Adv label: 8, L2: 906.67, Queries: 71
# Attacking sample 77/100 (True: 2, Index: 788)...
#   Success! Adv label: 1, L2: 577.47, Queries: 47
# Attacking sample 78/100 (True: 2, Index: 790)...
#   Success! Adv label: 3, L2: 891.13, Queries: 79
# Attacking sample 79/100 (True: 2, Index: 797)...
#   Success! Adv label: 8, L2: 595.12, Queries: 45
# Attacking sample 80/100 (True: 2, Index: 803)...
#   Success! Adv label: 0, L2: 919.94, Queries: 73
# Attacking sample 81/100 (True: 2, Index: 807)...
#   Success! Adv label: 1, L2: 1007.62, Queries: 93
# Attacking sample 82/100 (True: 2, Index: 828)...
#   Success! Adv label: 3, L2: 438.62, Queries: 35
# Attacking sample 83/100 (True: 2, Index: 842)...
#   Success! Adv label: 3, L2: 704.38, Queries: 59
# Attacking sample 84/100 (True: 2, Index: 845)...
#   Success! Adv label: 3, L2: 911.88, Queries: 69
# Attacking sample 85/100 (True: 2, Index: 859)...
#   Success! Adv label: 3, L2: 478.67, Queries: 37
# Attacking sample 86/100 (True: 2, Index: 871)...
#   Success! Adv label: 1, L2: 693.84, Queries: 59
# Attacking sample 87/100 (True: 2, Index: 881)...
#   Success! Adv label: 1, L2: 597.99, Queries: 57
# Attacking sample 88/100 (True: 2, Index: 883)...
#   Success! Adv label: 8, L2: 342.87, Queries: 27
# Attacking sample 89/100 (True: 2, Index: 896)...
#   Success! Adv label: 3, L2: 554.29, Queries: 43
# Attacking sample 90/100 (True: 2, Index: 897)...
#   Success! Adv label: 3, L2: 552.53, Queries: 51
# Attacking sample 92/100 (True: 2, Index: 922)...
#   Success! Adv label: 7, L2: 542.08, Queries: 45
# Attacking sample 93/100 (True: 2, Index: 932)...
#   Success! Adv label: 8, L2: 654.37, Queries: 49
# Attacking sample 94/100 (True: 2, Index: 944)...
#   Success! Adv label: 7, L2: 586.25, Queries: 47
# Attacking sample 95/100 (True: 2, Index: 949)...
#   Success! Adv label: 3, L2: 701.07, Queries: 55
# Attacking sample 96/100 (True: 2, Index: 952)...
#   Failed! Adv label: 2, L2: 1122.10, Queries: 201
# Attacking sample 97/100 (True: 2, Index: 959)...
#   Success! Adv label: 3, L2: 561.01, Queries: 43
# Attacking sample 98/100 (True: 2, Index: 966)...
#   Success! Adv label: 7, L2: 179.34, Queries: 15
# Attacking sample 99/100 (True: 2, Index: 967)...
#   Success! Adv label: 7, L2: 721.27, Queries: 63
# Attacking sample 100/100 (True: 2, Index: 985)...
#   Success! Adv label: 3, L2: 639.71, Queries: 55
# Attacking sample 1/100 (True: 3, Index: 1)...
#   Success! Adv label: 5, L2: 322.13, Queries: 25
# Attacking sample 2/100 (True: 3, Index: 12)...
#   Success! Adv label: 5, L2: 310.86, Queries: 25
# Attacking sample 3/100 (True: 3, Index: 20)...
#   Success! Adv label: 9, L2: 625.75, Queries: 47
# Attacking sample 4/100 (True: 3, Index: 27)...
#   Success! Adv label: 5, L2: 901.18, Queries: 87
# Attacking sample 5/100 (True: 3, Index: 37)...
#   Success! Adv label: 0, L2: 924.59, Queries: 83
# Attacking sample 6/100 (True: 3, Index: 43)...
#   Success! Adv label: 2, L2: 840.54, Queries: 85
# Attacking sample 7/100 (True: 3, Index: 53)...
#   Success! Adv label: 8, L2: 535.96, Queries: 41
# Attacking sample 8/100 (True: 3, Index: 61)...
#   Success! Adv label: 8, L2: 576.22, Queries: 43
# Attacking sample 9/100 (True: 3, Index: 73)...
#   Success! Adv label: 8, L2: 626.51, Queries: 53
# Attacking sample 10/100 (True: 3, Index: 102)...
#   Success! Adv label: 2, L2: 422.72, Queries: 33
# Attacking sample 11/100 (True: 3, Index: 108)...
#   Success! Adv label: 2, L2: 89.94, Queries: 7
# Attacking sample 12/100 (True: 3, Index: 109)...
#   Success! Adv label: 8, L2: 515.30, Queries: 37
# Attacking sample 13/100 (True: 3, Index: 117)...
#   Success! Adv label: 5, L2: 876.49, Queries: 89
# Attacking sample 14/100 (True: 3, Index: 131)...
#   Success! Adv label: 8, L2: 152.17, Queries: 11
# Attacking sample 15/100 (True: 3, Index: 159)...
#   Success! Adv label: 2, L2: 867.19, Queries: 77
# Attacking sample 16/100 (True: 3, Index: 162)...
#   Success! Adv label: 2, L2: 1057.56, Queries: 171
# Attacking sample 17/100 (True: 3, Index: 166)...
#   Success! Adv label: 7, L2: 747.84, Queries: 75
# Attacking sample 18/100 (True: 3, Index: 177)...
#   Success! Adv label: 8, L2: 534.46, Queries: 39
# Attacking sample 19/100 (True: 3, Index: 181)...
#   Success! Adv label: 5, L2: 405.21, Queries: 33
# Attacking sample 20/100 (True: 3, Index: 187)...
#   Success! Adv label: 8, L2: 617.97, Queries: 45
# Attacking sample 21/100 (True: 3, Index: 196)...
#   Success! Adv label: 2, L2: 478.10, Queries: 35
# Attacking sample 22/100 (True: 3, Index: 204)...
#   Success! Adv label: 5, L2: 865.31, Queries: 77
# Attacking sample 23/100 (True: 3, Index: 227)...
#   Failed! Adv label: 3, L2: 1089.97, Queries: 201
# Attacking sample 24/100 (True: 3, Index: 231)...
#   Success! Adv label: 5, L2: 597.22, Queries: 47
# Attacking sample 25/100 (True: 3, Index: 237)...
#   Success! Adv label: 5, L2: 913.66, Queries: 81
# Attacking sample 26/100 (True: 3, Index: 244)...
#   Success! Adv label: 7, L2: 797.66, Queries: 73
# Attacking sample 27/100 (True: 3, Index: 257)...
#   Success! Adv label: 8, L2: 546.72, Queries: 41
# Attacking sample 28/100 (True: 3, Index: 259)...
#   Success! Adv label: 5, L2: 803.99, Queries: 73
# Attacking sample 29/100 (True: 3, Index: 265)...
#   Success! Adv label: 5, L2: 485.57, Queries: 39
# Attacking sample 30/100 (True: 3, Index: 270)...
#   Success! Adv label: 5, L2: 241.72, Queries: 19
# Attacking sample 31/100 (True: 3, Index: 288)...
#   Success! Adv label: 8, L2: 982.10, Queries: 73
# Attacking sample 32/100 (True: 3, Index: 308)...
#   Success! Adv label: 8, L2: 532.86, Queries: 41
# Attacking sample 33/100 (True: 3, Index: 309)...
#   Success! Adv label: 8, L2: 538.34, Queries: 41
# Attacking sample 34/100 (True: 3, Index: 327)...
#   Success! Adv label: 1, L2: 321.96, Queries: 29
# Attacking sample 35/100 (True: 3, Index: 331)...
#   Success! Adv label: 8, L2: 777.83, Queries: 67
# Attacking sample 36/100 (True: 3, Index: 340)...
#   Success! Adv label: 8, L2: 887.59, Queries: 75
# Attacking sample 37/100 (True: 3, Index: 341)...
#   Success! Adv label: 5, L2: 563.32, Queries: 47
# Attacking sample 38/100 (True: 3, Index: 342)...
#   Success! Adv label: 5, L2: 434.18, Queries: 35
# Attacking sample 39/100 (True: 3, Index: 362)...
#   Success! Adv label: 2, L2: 507.05, Queries: 41
# Attacking sample 40/100 (True: 3, Index: 383)...
#   Success! Adv label: 2, L2: 530.87, Queries: 43
# Attacking sample 41/100 (True: 3, Index: 394)...
#   Success! Adv label: 8, L2: 464.49, Queries: 35
# Attacking sample 42/100 (True: 3, Index: 406)...
#   Success! Adv label: 2, L2: 1076.60, Queries: 161
# Attacking sample 43/100 (True: 3, Index: 409)...
#   Success! Adv label: 2, L2: 818.96, Queries: 71
# Attacking sample 44/100 (True: 3, Index: 445)...
#   Success! Adv label: 2, L2: 380.40, Queries: 29
# Attacking sample 45/100 (True: 3, Index: 456)...
#   Success! Adv label: 8, L2: 508.28, Queries: 37
# Attacking sample 46/100 (True: 3, Index: 459)...
#   Success! Adv label: 4, L2: 925.37, Queries: 93
# Attacking sample 47/100 (True: 3, Index: 461)...
#   Success! Adv label: 5, L2: 1061.37, Queries: 121
# Attacking sample 48/100 (True: 3, Index: 471)...
#   Success! Adv label: 8, L2: 833.99, Queries: 63
# Attacking sample 49/100 (True: 3, Index: 474)...
#   Success! Adv label: 5, L2: 448.54, Queries: 37
# Attacking sample 50/100 (True: 3, Index: 481)...
#   Success! Adv label: 5, L2: 743.93, Queries: 67
# Attacking sample 51/100 (True: 3, Index: 504)...
#   Success! Adv label: 5, L2: 586.29, Queries: 47
# Attacking sample 52/100 (True: 3, Index: 510)...
#   Success! Adv label: 5, L2: 320.62, Queries: 25
# Attacking sample 53/100 (True: 3, Index: 512)...
#   Failed! Adv label: 3, L2: 1022.63, Queries: 201
# Attacking sample 54/100 (True: 3, Index: 524)...
#   Success! Adv label: 8, L2: 589.66, Queries: 43
# Attacking sample 55/100 (True: 3, Index: 549)...
#   Success! Adv label: 2, L2: 477.25, Queries: 41
# Attacking sample 56/100 (True: 3, Index: 556)...
#   Success! Adv label: 9, L2: 520.02, Queries: 43
# Attacking sample 57/100 (True: 3, Index: 564)...
#   Success! Adv label: 8, L2: 449.91, Queries: 33
# Attacking sample 58/100 (True: 3, Index: 586)...
#   Failed! Adv label: 3, L2: 1139.96, Queries: 201
# Attacking sample 59/100 (True: 3, Index: 589)...
#   Success! Adv label: 5, L2: 1103.01, Queries: 95
# Attacking sample 60/100 (True: 3, Index: 609)...
#   Success! Adv label: 9, L2: 630.01, Queries: 51
# Attacking sample 61/100 (True: 3, Index: 613)...
#   Success! Adv label: 2, L2: 693.84, Queries: 51
# Attacking sample 62/100 (True: 3, Index: 623)...
#   Success! Adv label: 9, L2: 398.50, Queries: 29
# Attacking sample 63/100 (True: 3, Index: 639)...
#   Success! Adv label: 5, L2: 534.32, Queries: 43
# Attacking sample 64/100 (True: 3, Index: 648)...
#   Success! Adv label: 8, L2: 411.13, Queries: 31
# Attacking sample 65/100 (True: 3, Index: 651)...
#   Success! Adv label: 8, L2: 384.59, Queries: 29
# Attacking sample 66/100 (True: 3, Index: 659)...
#   Success! Adv label: 9, L2: 604.05, Queries: 51
# Attacking sample 67/100 (True: 3, Index: 661)...
#   Success! Adv label: 5, L2: 888.78, Queries: 75
# Attacking sample 68/100 (True: 3, Index: 667)...
#   Failed! Adv label: 3, L2: 1049.15, Queries: 201
# Attacking sample 69/100 (True: 3, Index: 678)...
#   Success! Adv label: 2, L2: 815.11, Queries: 91
# Attacking sample 70/100 (True: 3, Index: 690)...
#   Success! Adv label: 8, L2: 843.35, Queries: 61
# Attacking sample 71/100 (True: 3, Index: 693)...
#   Failed! Adv label: 3, L2: 1021.53, Queries: 201
# Attacking sample 72/100 (True: 3, Index: 694)...
#   Success! Adv label: 9, L2: 707.73, Queries: 53
# Attacking sample 73/100 (True: 3, Index: 695)...
#   Success! Adv label: 2, L2: 251.72, Queries: 19
# Attacking sample 74/100 (True: 3, Index: 702)...
#   Success! Adv label: 8, L2: 378.89, Queries: 27
# Attacking sample 75/100 (True: 3, Index: 718)...
#   Success! Adv label: 2, L2: 988.56, Queries: 87
# Attacking sample 76/100 (True: 3, Index: 749)...
#   Success! Adv label: 9, L2: 749.55, Queries: 67
# Attacking sample 77/100 (True: 3, Index: 769)...
#   Success! Adv label: 9, L2: 741.18, Queries: 55
# Attacking sample 79/100 (True: 3, Index: 779)...
#   Success! Adv label: 8, L2: 419.42, Queries: 33
# Attacking sample 80/100 (True: 3, Index: 800)...
#   Success! Adv label: 8, L2: 886.51, Queries: 63
# Attacking sample 81/100 (True: 3, Index: 816)...
#   Success! Adv label: 5, L2: 251.41, Queries: 21
# Attacking sample 82/100 (True: 3, Index: 829)...
#   Success! Adv label: 2, L2: 514.60, Queries: 41
# Attacking sample 83/100 (True: 3, Index: 833)...
#   Success! Adv label: 7, L2: 906.62, Queries: 97
# Attacking sample 84/100 (True: 3, Index: 839)...
#   Success! Adv label: 8, L2: 643.06, Queries: 51
# Attacking sample 85/100 (True: 3, Index: 854)...
#   Success! Adv label: 5, L2: 288.36, Queries: 23
# Attacking sample 86/100 (True: 3, Index: 856)...
#   Success! Adv label: 2, L2: 401.26, Queries: 33
# Attacking sample 87/100 (True: 3, Index: 858)...
#   Success! Adv label: 5, L2: 102.21, Queries: 9
# Attacking sample 89/100 (True: 3, Index: 886)...
#   Success! Adv label: 8, L2: 817.58, Queries: 63
# Attacking sample 90/100 (True: 3, Index: 900)...
#   Success! Adv label: 8, L2: 671.77, Queries: 51
# Attacking sample 91/100 (True: 3, Index: 916)...
#   Success! Adv label: 5, L2: 382.82, Queries: 33
# Attacking sample 92/100 (True: 3, Index: 921)...
#   Success! Adv label: 2, L2: 445.22, Queries: 37
# Attacking sample 93/100 (True: 3, Index: 937)...
#   Success! Adv label: 9, L2: 717.23, Queries: 57
# Attacking sample 94/100 (True: 3, Index: 938)...
#   Success! Adv label: 8, L2: 681.21, Queries: 47
# Attacking sample 95/100 (True: 3, Index: 939)...
#   Success! Adv label: 8, L2: 308.17, Queries: 23
# Attacking sample 96/100 (True: 3, Index: 942)...
#   Success! Adv label: 5, L2: 890.27, Queries: 81
# Attacking sample 97/100 (True: 3, Index: 951)...
#   Success! Adv label: 8, L2: 600.06, Queries: 47
# Attacking sample 98/100 (True: 3, Index: 953)...
#   Success! Adv label: 7, L2: 1061.36, Queries: 125
# Attacking sample 99/100 (True: 3, Index: 975)...
#   Success! Adv label: 5, L2: 1090.41, Queries: 125
# Attacking sample 1/100 (True: 4, Index: 16)...
#   Success! Adv label: 9, L2: 297.54, Queries: 23
# Attacking sample 2/100 (True: 4, Index: 17)...
#   Success! Adv label: 6, L2: 422.02, Queries: 33
# Attacking sample 3/100 (True: 4, Index: 30)...
#   Success! Adv label: 8, L2: 723.51, Queries: 55
# Attacking sample 4/100 (True: 4, Index: 33)...
#   Success! Adv label: 9, L2: 512.48, Queries: 41
# Attacking sample 5/100 (True: 4, Index: 45)...
#   Success! Adv label: 8, L2: 118.15, Queries: 9
# Attacking sample 6/100 (True: 4, Index: 48)...
#   Success! Adv label: 9, L2: 707.82, Queries: 55
# Attacking sample 7/100 (True: 4, Index: 58)...
#   Success! Adv label: 9, L2: 676.02, Queries: 51
# Attacking sample 8/100 (True: 4, Index: 66)...
#   Success! Adv label: 6, L2: 565.49, Queries: 47
# Attacking sample 9/100 (True: 4, Index: 89)...
#   Success! Adv label: 9, L2: 343.20, Queries: 25
# Attacking sample 10/100 (True: 4, Index: 92)...
#   Success! Adv label: 6, L2: 793.60, Queries: 63
# Attacking sample 11/100 (True: 4, Index: 113)...
#   Success! Adv label: 9, L2: 639.76, Queries: 49
# Attacking sample 12/100 (True: 4, Index: 116)...
#   Success! Adv label: 9, L2: 585.85, Queries: 43
# Attacking sample 13/100 (True: 4, Index: 126)...
#   Success! Adv label: 9, L2: 430.51, Queries: 31
# Attacking sample 14/100 (True: 4, Index: 130)...
#   Success! Adv label: 9, L2: 341.09, Queries: 25
# Attacking sample 15/100 (True: 4, Index: 139)...
#   Success! Adv label: 9, L2: 503.08, Queries: 37
# Attacking sample 16/100 (True: 4, Index: 149)...
#   Success! Adv label: 2, L2: 961.38, Queries: 79
# Attacking sample 17/100 (True: 4, Index: 153)...
#   Success! Adv label: 8, L2: 489.95, Queries: 37
# Attacking sample 18/100 (True: 4, Index: 154)...
#   Success! Adv label: 7, L2: 854.48, Queries: 67
# Attacking sample 19/100 (True: 4, Index: 163)...
#   Success! Adv label: 9, L2: 517.75, Queries: 39
# Attacking sample 20/100 (True: 4, Index: 167)...
#   Success! Adv label: 9, L2: 635.19, Queries: 47
# Attacking sample 21/100 (True: 4, Index: 183)...
#   Success! Adv label: 9, L2: 388.70, Queries: 31
# Attacking sample 22/100 (True: 4, Index: 184)...
#   Success! Adv label: 9, L2: 532.92, Queries: 41
# Attacking sample 23/100 (True: 4, Index: 192)...
#   Success! Adv label: 9, L2: 273.64, Queries: 21
# Attacking sample 24/100 (True: 4, Index: 194)...
#   Success! Adv label: 9, L2: 489.67, Queries: 39
# Attacking sample 25/100 (True: 4, Index: 233)...
#   Success! Adv label: 9, L2: 649.99, Queries: 51
# Attacking sample 26/100 (True: 4, Index: 240)...
#   Success! Adv label: 8, L2: 537.78, Queries: 39
# Attacking sample 27/100 (True: 4, Index: 263)...
#   Success! Adv label: 9, L2: 259.08, Queries: 19
# Attacking sample 28/100 (True: 4, Index: 269)...
#   Success! Adv label: 9, L2: 336.99, Queries: 25
# Attacking sample 29/100 (True: 4, Index: 280)...
#   Success! Adv label: 9, L2: 363.83, Queries: 27
# Attacking sample 30/100 (True: 4, Index: 290)...
#   Success! Adv label: 9, L2: 575.80, Queries: 41
# Attacking sample 31/100 (True: 4, Index: 297)...
#   Success! Adv label: 6, L2: 416.44, Queries: 33
# Attacking sample 32/100 (True: 4, Index: 299)...
#   Success! Adv label: 9, L2: 364.88, Queries: 27
# Attacking sample 33/100 (True: 4, Index: 310)...
#   Success! Adv label: 9, L2: 302.85, Queries: 23
# Attacking sample 34/100 (True: 4, Index: 316)...
#   Success! Adv label: 9, L2: 461.85, Queries: 33
# Attacking sample 35/100 (True: 4, Index: 320)...
#   Success! Adv label: 9, L2: 432.37, Queries: 33
# Attacking sample 36/100 (True: 4, Index: 324)...
#   Success! Adv label: 9, L2: 441.23, Queries: 33
# Attacking sample 37/100 (True: 4, Index: 326)...
#   Success! Adv label: 9, L2: 488.80, Queries: 39
# Attacking sample 38/100 (True: 4, Index: 332)...
#   Success! Adv label: 9, L2: 33.66, Queries: 3
# Attacking sample 39/100 (True: 4, Index: 335)...
#   Success! Adv label: 9, L2: 635.64, Queries: 47
# Attacking sample 40/100 (True: 4, Index: 344)...
#   Success! Adv label: 7, L2: 511.15, Queries: 41
# Attacking sample 42/100 (True: 4, Index: 359)...
#   Success! Adv label: 9, L2: 406.05, Queries: 31
# Attacking sample 43/100 (True: 4, Index: 376)...
#   Success! Adv label: 9, L2: 535.78, Queries: 41
# Attacking sample 44/100 (True: 4, Index: 393)...
#   Success! Adv label: 9, L2: 515.22, Queries: 37
# Attacking sample 45/100 (True: 4, Index: 401)...
#   Success! Adv label: 2, L2: 682.43, Queries: 55
# Attacking sample 46/100 (True: 4, Index: 402)...
#   Success! Adv label: 9, L2: 479.06, Queries: 37
# Attacking sample 47/100 (True: 4, Index: 422)...
#   Success! Adv label: 9, L2: 351.82, Queries: 25
# Attacking sample 48/100 (True: 4, Index: 423)...
#   Success! Adv label: 9, L2: 190.18, Queries: 15
# Attacking sample 49/100 (True: 4, Index: 427)...
#   Success! Adv label: 1, L2: 507.64, Queries: 43
# Attacking sample 50/100 (True: 4, Index: 432)...
#   Success! Adv label: 9, L2: 380.93, Queries: 29
# Attacking sample 51/100 (True: 4, Index: 434)...
#   Success! Adv label: 9, L2: 285.15, Queries: 21
# Attacking sample 52/100 (True: 4, Index: 454)...
#   Success! Adv label: 9, L2: 559.86, Queries: 43
# Attacking sample 53/100 (True: 4, Index: 467)...
#   Success! Adv label: 8, L2: 334.49, Queries: 25
# Attacking sample 54/100 (True: 4, Index: 501)...
#   Success! Adv label: 9, L2: 272.30, Queries: 21
# Attacking sample 55/100 (True: 4, Index: 515)...
#   Success! Adv label: 9, L2: 348.26, Queries: 25
# Attacking sample 56/100 (True: 4, Index: 540)...
#   Success! Adv label: 9, L2: 567.41, Queries: 43
# Attacking sample 57/100 (True: 4, Index: 544)...
#   Success! Adv label: 0, L2: 419.86, Queries: 33
# Attacking sample 58/100 (True: 4, Index: 545)...
#   Success! Adv label: 9, L2: 376.79, Queries: 29
# Attacking sample 59/100 (True: 4, Index: 547)...
#   Success! Adv label: 8, L2: 783.81, Queries: 67
# Attacking sample 60/100 (True: 4, Index: 566)...
#   Success! Adv label: 9, L2: 403.12, Queries: 29
# Attacking sample 61/100 (True: 4, Index: 590)...
#   Success! Adv label: 0, L2: 426.19, Queries: 33
# Attacking sample 62/100 (True: 4, Index: 593)...
#   Success! Adv label: 9, L2: 341.21, Queries: 25
# Attacking sample 63/100 (True: 4, Index: 599)...
#   Success! Adv label: 9, L2: 636.82, Queries: 53
# Attacking sample 64/100 (True: 4, Index: 602)...
#   Success! Adv label: 9, L2: 494.84, Queries: 37
# Attacking sample 65/100 (True: 4, Index: 607)...
#   Success! Adv label: 7, L2: 569.86, Queries: 53
# Attacking sample 66/100 (True: 4, Index: 611)...
#   Success! Adv label: 9, L2: 618.30, Queries: 47
# Attacking sample 67/100 (True: 4, Index: 617)...
#   Success! Adv label: 9, L2: 519.87, Queries: 37
# Attacking sample 68/100 (True: 4, Index: 657)...
#   Success! Adv label: 9, L2: 308.23, Queries: 25
# Attacking sample 69/100 (True: 4, Index: 680)...
#   Success! Adv label: 9, L2: 395.91, Queries: 29
# Attacking sample 70/100 (True: 4, Index: 684)...
#   Success! Adv label: 9, L2: 592.04, Queries: 49
# Attacking sample 71/100 (True: 4, Index: 687)...
#   Success! Adv label: 9, L2: 514.12, Queries: 37
# Attacking sample 72/100 (True: 4, Index: 692)...
#   Success! Adv label: 9, L2: 776.94, Queries: 59
# Attacking sample 73/100 (True: 4, Index: 696)...
#   Success! Adv label: 9, L2: 163.53, Queries: 13
# Attacking sample 74/100 (True: 4, Index: 697)...
#   Success! Adv label: 9, L2: 714.63, Queries: 53
# Attacking sample 75/100 (True: 4, Index: 708)...
#   Success! Adv label: 9, L2: 553.38, Queries: 41
# Attacking sample 76/100 (True: 4, Index: 717)...
#   Success! Adv label: 9, L2: 348.27, Queries: 27
# Attacking sample 77/100 (True: 4, Index: 746)...
#   Success! Adv label: 9, L2: 456.07, Queries: 35
# Attacking sample 78/100 (True: 4, Index: 752)...
#   Success! Adv label: 9, L2: 940.89, Queries: 71
# Attacking sample 79/100 (True: 4, Index: 755)...
#   Success! Adv label: 2, L2: 897.17, Queries: 81
# Attacking sample 80/100 (True: 4, Index: 757)...
#   Success! Adv label: 9, L2: 396.44, Queries: 29
# Attacking sample 81/100 (True: 4, Index: 766)...
#   Success! Adv label: 7, L2: 512.62, Queries: 43
# Attacking sample 82/100 (True: 4, Index: 771)...
#   Success! Adv label: 9, L2: 308.55, Queries: 23
# Attacking sample 83/100 (True: 4, Index: 776)...
#   Success! Adv label: 2, L2: 570.40, Queries: 45
# Attacking sample 84/100 (True: 4, Index: 777)...
#   Success! Adv label: 1, L2: 872.05, Queries: 81
# Attacking sample 85/100 (True: 4, Index: 786)...
#   Success! Adv label: 9, L2: 206.51, Queries: 15
# Attacking sample 86/100 (True: 4, Index: 811)...
#   Success! Adv label: 9, L2: 255.67, Queries: 19
# Attacking sample 87/100 (True: 4, Index: 815)...
#   Success! Adv label: 6, L2: 649.51, Queries: 51
# Attacking sample 88/100 (True: 4, Index: 817)...
#   Success! Adv label: 8, L2: 809.12, Queries: 71
# Attacking sample 89/100 (True: 4, Index: 840)...
#   Success! Adv label: 6, L2: 665.92, Queries: 51
# Attacking sample 91/100 (True: 4, Index: 849)...
#   Success! Adv label: 8, L2: 683.62, Queries: 51
# Attacking sample 92/100 (True: 4, Index: 857)...
#   Success! Adv label: 9, L2: 546.70, Queries: 41
# Attacking sample 93/100 (True: 4, Index: 872)...
#   Success! Adv label: 9, L2: 657.63, Queries: 53
# Attacking sample 94/100 (True: 4, Index: 877)...
#   Success! Adv label: 9, L2: 412.75, Queries: 33
# Attacking sample 95/100 (True: 4, Index: 894)...
#   Success! Adv label: 9, L2: 266.04, Queries: 21
# Attacking sample 96/100 (True: 4, Index: 902)...
#   Success! Adv label: 9, L2: 391.46, Queries: 29
# Attacking sample 97/100 (True: 4, Index: 911)...
#   Success! Adv label: 9, L2: 540.05, Queries: 43
# ...
#   Success! Adv label: 3, L2: 512.36, Queries: 43
# Attacking sample 40/100 (True: 8, Index: 505)...
#   Success! Adv label: 2, L2: 720.63, Queries: 61
# Attacking sample 41/100 (True: 8, Index: 509)...
#   Success! Adv label: 3, L2: 636.64, Queries: 63
# Attacking sample 42/100 (True: 8, Index: 525)...
#   Success! Adv label: 3, L2: 577.29, Queries: 51
# Attacking sample 43/100 (True: 8, Index: 528)...
#   Success! Adv label: 3, L2: 727.87, Queries: 67
# Attacking sample 44/100 (True: 8, Index: 541)...
#   Success! Adv label: 3, L2: 783.37, Queries: 65
# Attacking sample 45/100 (True: 8, Index: 543)...
#   Success! Adv label: 6, L2: 355.75, Queries: 29
# Attacking sample 46/100 (True: 8, Index: 550)...
#   Success! Adv label: 5, L2: 504.64, Queries: 43
# Attacking sample 47/100 (True: 8, Index: 558)...
#   Success! Adv label: 2, L2: 748.33, Queries: 63
# Attacking sample 48/100 (True: 8, Index: 575)...
#   Success! Adv label: 9, L2: 458.35, Queries: 39
# Attacking sample 49/100 (True: 8, Index: 594)...
#   Success! Adv label: 2, L2: 379.21, Queries: 33
# Attacking sample 50/100 (True: 8, Index: 600)...
#   Success! Adv label: 3, L2: 994.94, Queries: 83
# Attacking sample 51/100 (True: 8, Index: 605)...
#   Success! Adv label: 2, L2: 614.86, Queries: 51
# Attacking sample 52/100 (True: 8, Index: 619)...
#   Success! Adv label: 3, L2: 542.84, Queries: 47
# Attacking sample 53/100 (True: 8, Index: 625)...
#   Success! Adv label: 3, L2: 731.64, Queries: 61
# Attacking sample 54/100 (True: 8, Index: 629)...
#   Success! Adv label: 2, L2: 506.66, Queries: 41
# Attacking sample 55/100 (True: 8, Index: 645)...
#   Success! Adv label: 9, L2: 966.52, Queries: 83
# Attacking sample 56/100 (True: 8, Index: 652)...
#   Success! Adv label: 2, L2: 593.84, Queries: 53
# Attacking sample 57/100 (True: 8, Index: 672)...
#   Success! Adv label: 3, L2: 592.60, Queries: 55
# Attacking sample 58/100 (True: 8, Index: 683)...
#   Success! Adv label: 3, L2: 394.16, Queries: 37
# Attacking sample 59/100 (True: 8, Index: 701)...
#   Success! Adv label: 5, L2: 747.12, Queries: 69
# Attacking sample 60/100 (True: 8, Index: 714)...
#   Success! Adv label: 3, L2: 650.22, Queries: 61
# Attacking sample 61/100 (True: 8, Index: 721)...
#   Success! Adv label: 3, L2: 495.56, Queries: 43
# Attacking sample 62/100 (True: 8, Index: 730)...
#   Success! Adv label: 2, L2: 605.61, Queries: 49
# Attacking sample 63/100 (True: 8, Index: 731)...
#   Success! Adv label: 9, L2: 1214.13, Queries: 157
# Attacking sample 64/100 (True: 8, Index: 738)...
#   Success! Adv label: 3, L2: 835.88, Queries: 77
# Attacking sample 65/100 (True: 8, Index: 791)...
#   Success! Adv label: 5, L2: 719.67, Queries: 63
# Attacking sample 66/100 (True: 8, Index: 832)...
#   Success! Adv label: 6, L2: 566.17, Queries: 49
# Attacking sample 67/100 (True: 8, Index: 838)...
#   Success! Adv label: 5, L2: 532.47, Queries: 47
# Attacking sample 68/100 (True: 8, Index: 860)...
#   Success! Adv label: 3, L2: 709.29, Queries: 65
# Attacking sample 69/100 (True: 8, Index: 864)...
#   Success! Adv label: 9, L2: 756.33, Queries: 67
# Attacking sample 70/100 (True: 8, Index: 889)...
#   Success! Adv label: 3, L2: 619.80, Queries: 55
# Attacking sample 71/100 (True: 8, Index: 905)...
#   Success! Adv label: 9, L2: 762.42, Queries: 69
# Attacking sample 73/100 (True: 8, Index: 919)...
#   Success! Adv label: 3, L2: 592.62, Queries: 51
# Attacking sample 74/100 (True: 8, Index: 923)...
#   Success! Adv label: 3, L2: 707.74, Queries: 63
# Attacking sample 75/100 (True: 8, Index: 926)...
#   Success! Adv label: 5, L2: 665.89, Queries: 57
# Attacking sample 76/100 (True: 8, Index: 933)...
#   Success! Adv label: 3, L2: 627.56, Queries: 55
# Attacking sample 78/100 (True: 8, Index: 971)...
#   Success! Adv label: 2, L2: 763.37, Queries: 65
# Attacking sample 79/100 (True: 8, Index: 1014)...
#   Success! Adv label: 3, L2: 615.93, Queries: 57
# Attacking sample 80/100 (True: 8, Index: 1034)...
#   Success! Adv label: 6, L2: 735.75, Queries: 67
# Attacking sample 81/100 (True: 8, Index: 1053)...
#   Success! Adv label: 6, L2: 586.14, Queries: 51
# Attacking sample 82/100 (True: 8, Index: 1057)...
#   Success! Adv label: 6, L2: 452.62, Queries: 33
# Attacking sample 83/100 (True: 8, Index: 1061)...
#   Success! Adv label: 1, L2: 821.07, Queries: 83
# Attacking sample 84/100 (True: 8, Index: 1062)...
#   Success! Adv label: 3, L2: 645.61, Queries: 59
# Attacking sample 85/100 (True: 8, Index: 1063)...
#   Success! Adv label: 3, L2: 658.44, Queries: 57
# Attacking sample 86/100 (True: 8, Index: 1078)...
#   Success! Adv label: 9, L2: 353.77, Queries: 27
# Attacking sample 87/100 (True: 8, Index: 1088)...
#   Success! Adv label: 2, L2: 721.88, Queries: 61
# Attacking sample 88/100 (True: 8, Index: 1100)...
#   Success! Adv label: 0, L2: 1059.41, Queries: 93
# Attacking sample 89/100 (True: 8, Index: 1106)...
#   Success! Adv label: 2, L2: 990.02, Queries: 87
# Attacking sample 90/100 (True: 8, Index: 1120)...
#   Success! Adv label: 3, L2: 550.77, Queries: 49
# Attacking sample 91/100 (True: 8, Index: 1132)...
#   Success! Adv label: 2, L2: 636.68, Queries: 53
# Attacking sample 92/100 (True: 8, Index: 1134)...
#   Success! Adv label: 6, L2: 1077.40, Queries: 99
# Attacking sample 93/100 (True: 8, Index: 1140)...
#   Success! Adv label: 5, L2: 317.60, Queries: 27
# Attacking sample 94/100 (True: 8, Index: 1150)...
#   Success! Adv label: 9, L2: 587.74, Queries: 49
# Attacking sample 95/100 (True: 8, Index: 1165)...
#   Success! Adv label: 3, L2: 810.60, Queries: 71
# Attacking sample 96/100 (True: 8, Index: 1179)...
#   Success! Adv label: 3, L2: 607.59, Queries: 53
# Attacking sample 97/100 (True: 8, Index: 1182)...
#   Success! Adv label: 9, L2: 533.21, Queries: 45
# Attacking sample 98/100 (True: 8, Index: 1186)...
#   Success! Adv label: 2, L2: 760.87, Queries: 61
# Attacking sample 99/100 (True: 8, Index: 1189)...
#   Success! Adv label: 3, L2: 264.84, Queries: 23
# Attacking sample 100/100 (True: 8, Index: 1207)...
#   Success! Adv label: 9, L2: 656.12, Queries: 53
# Attacking sample 1/100 (True: 9, Index: 6)...
#   Success! Adv label: 7, L2: 347.57, Queries: 29
# Attacking sample 2/100 (True: 9, Index: 38)...
#   Success! Adv label: 7, L2: 84.22, Queries: 7
# Attacking sample 3/100 (True: 9, Index: 55)...
#   Success! Adv label: 0, L2: 137.27, Queries: 11
# Attacking sample 4/100 (True: 9, Index: 56)...
#   Success! Adv label: 4, L2: 419.12, Queries: 35
# Attacking sample 5/100 (True: 9, Index: 91)...
#   Success! Adv label: 3, L2: 298.21, Queries: 23
# Attacking sample 6/100 (True: 9, Index: 99)...
#   Success! Adv label: 7, L2: 474.52, Queries: 41
# Attacking sample 7/100 (True: 9, Index: 101)...
#   Success! Adv label: 5, L2: 605.68, Queries: 53
# Attacking sample 8/100 (True: 9, Index: 114)...
#   Success! Adv label: 8, L2: 676.64, Queries: 51
# Attacking sample 9/100 (True: 9, Index: 133)...
#   Success! Adv label: 8, L2: 635.29, Queries: 47
# Attacking sample 10/100 (True: 9, Index: 171)...
#   Success! Adv label: 8, L2: 92.96, Queries: 7
# Attacking sample 11/100 (True: 9, Index: 179)...
#   Success! Adv label: 7, L2: 625.21, Queries: 57
# Attacking sample 12/100 (True: 9, Index: 195)...
#   Success! Adv label: 4, L2: 208.82, Queries: 17
# Attacking sample 13/100 (True: 9, Index: 214)...
#   Success! Adv label: 4, L2: 495.34, Queries: 43
# Attacking sample 14/100 (True: 9, Index: 218)...
#   Success! Adv label: 4, L2: 364.38, Queries: 31
# Attacking sample 15/100 (True: 9, Index: 222)...
#   Success! Adv label: 8, L2: 366.27, Queries: 29
# Attacking sample 16/100 (True: 9, Index: 224)...
#   Success! Adv label: 6, L2: 479.20, Queries: 37
# Attacking sample 17/100 (True: 9, Index: 238)...
#   Success! Adv label: 4, L2: 448.59, Queries: 35
# Attacking sample 18/100 (True: 9, Index: 243)...
#   Success! Adv label: 8, L2: 681.55, Queries: 55
# Attacking sample 19/100 (True: 9, Index: 245)...
#   Success! Adv label: 4, L2: 510.86, Queries: 45
# Attacking sample 20/100 (True: 9, Index: 246)...
#   Success! Adv label: 8, L2: 597.63, Queries: 43
# Attacking sample 21/100 (True: 9, Index: 251)...
#   Success! Adv label: 7, L2: 274.17, Queries: 23
# Attacking sample 22/100 (True: 9, Index: 303)...
#   Success! Adv label: 4, L2: 281.68, Queries: 23
# Attacking sample 23/100 (True: 9, Index: 305)...
#   Success! Adv label: 8, L2: 245.78, Queries: 19
# Attacking sample 24/100 (True: 9, Index: 307)...
#   Success! Adv label: 4, L2: 543.11, Queries: 49
# Attacking sample 25/100 (True: 9, Index: 315)...
#   Success! Adv label: 8, L2: 683.54, Queries: 53
# Attacking sample 26/100 (True: 9, Index: 354)...
#   Success! Adv label: 4, L2: 528.16, Queries: 45
# Attacking sample 27/100 (True: 9, Index: 364)...
#   Success! Adv label: 8, L2: 724.77, Queries: 59
# Attacking sample 28/100 (True: 9, Index: 389)...
#   Success! Adv label: 4, L2: 318.62, Queries: 25
# Attacking sample 29/100 (True: 9, Index: 407)...
#   Success! Adv label: 8, L2: 256.67, Queries: 19
# Attacking sample 30/100 (True: 9, Index: 411)...
#   Success! Adv label: 4, L2: 198.40, Queries: 15
# Attacking sample 31/100 (True: 9, Index: 417)...
#   Success! Adv label: 7, L2: 386.21, Queries: 37
# Attacking sample 32/100 (True: 9, Index: 421)...
#   Success! Adv label: 4, L2: 413.43, Queries: 33
# Attacking sample 33/100 (True: 9, Index: 438)...
#   Success! Adv label: 4, L2: 433.24, Queries: 35
# Attacking sample 34/100 (True: 9, Index: 443)...
#   Success! Adv label: 8, L2: 590.54, Queries: 49
# Attacking sample 35/100 (True: 9, Index: 444)...
#   Success! Adv label: 4, L2: 309.81, Queries: 27
# Attacking sample 36/100 (True: 9, Index: 446)...
#   Success! Adv label: 7, L2: 551.01, Queries: 51
# Attacking sample 37/100 (True: 9, Index: 455)...
#   Success! Adv label: 7, L2: 304.10, Queries: 27
# Attacking sample 38/100 (True: 9, Index: 469)...
#   Success! Adv label: 4, L2: 767.96, Queries: 65
# Attacking sample 39/100 (True: 9, Index: 472)...
#   Success! Adv label: 3, L2: 703.77, Queries: 55
# Attacking sample 40/100 (True: 9, Index: 473)...
#   Success! Adv label: 4, L2: 641.39, Queries: 51
# Attacking sample 41/100 (True: 9, Index: 482)...
#   Success! Adv label: 4, L2: 445.21, Queries: 35
# Attacking sample 42/100 (True: 9, Index: 490)...
#   Success! Adv label: 8, L2: 776.73, Queries: 61
# Attacking sample 43/100 (True: 9, Index: 496)...
#   Success! Adv label: 4, L2: 393.94, Queries: 33
# Attacking sample 44/100 (True: 9, Index: 507)...
#   Success! Adv label: 8, L2: 444.40, Queries: 33
# Attacking sample 45/100 (True: 9, Index: 508)...
#   Success! Adv label: 7, L2: 491.71, Queries: 41
# Attacking sample 46/100 (True: 9, Index: 514)...
#   Success! Adv label: 4, L2: 202.89, Queries: 15
# Attacking sample 47/100 (True: 9, Index: 522)...
#   Success! Adv label: 4, L2: 55.70, Queries: 5
# Attacking sample 48/100 (True: 9, Index: 535)...
#   Success! Adv label: 4, L2: 440.28, Queries: 37
# Attacking sample 49/100 (True: 9, Index: 542)...
#   Success! Adv label: 8, L2: 372.68, Queries: 31
# Attacking sample 50/100 (True: 9, Index: 553)...
#   Success! Adv label: 4, L2: 595.94, Queries: 51
# Attacking sample 51/100 (True: 9, Index: 554)...
#   Success! Adv label: 4, L2: 784.89, Queries: 65
# Attacking sample 52/100 (True: 9, Index: 565)...
#   Success! Adv label: 0, L2: 419.63, Queries: 35
# Attacking sample 53/100 (True: 9, Index: 569)...
#   Success! Adv label: 4, L2: 491.49, Queries: 41
# Attacking sample 54/100 (True: 9, Index: 572)...
#   Success! Adv label: 5, L2: 337.07, Queries: 27
# Attacking sample 55/100 (True: 9, Index: 574)...
#   Success! Adv label: 8, L2: 365.63, Queries: 29
# Attacking sample 56/100 (True: 9, Index: 601)...
#   Success! Adv label: 8, L2: 397.59, Queries: 29
# Attacking sample 57/100 (True: 9, Index: 634)...
#   Success! Adv label: 5, L2: 430.16, Queries: 33
# Attacking sample 58/100 (True: 9, Index: 635)...
#   Success! Adv label: 4, L2: 594.73, Queries: 57
# Attacking sample 59/100 (True: 9, Index: 637)...
#   Success! Adv label: 4, L2: 534.34, Queries: 43
# Attacking sample 60/100 (True: 9, Index: 640)...
#   Success! Adv label: 4, L2: 533.35, Queries: 43
# Attacking sample 61/100 (True: 9, Index: 653)...
#   Success! Adv label: 3, L2: 618.24, Queries: 47
# Attacking sample 62/100 (True: 9, Index: 654)...
#   Success! Adv label: 4, L2: 527.38, Queries: 43
# Attacking sample 63/100 (True: 9, Index: 656)...
#   Success! Adv label: 4, L2: 635.80, Queries: 51
# Attacking sample 64/100 (True: 9, Index: 666)...
#   Success! Adv label: 4, L2: 450.83, Queries: 39
# Attacking sample 65/100 (True: 9, Index: 685)...
#   Success! Adv label: 7, L2: 630.98, Queries: 59
# Attacking sample 66/100 (True: 9, Index: 711)...
#   Success! Adv label: 4, L2: 211.77, Queries: 17
# Attacking sample 67/100 (True: 9, Index: 729)...
#   Success! Adv label: 8, L2: 482.51, Queries: 37
# Attacking sample 68/100 (True: 9, Index: 739)...
#   Success! Adv label: 4, L2: 425.80, Queries: 35
# Attacking sample 69/100 (True: 9, Index: 747)...
#   Success! Adv label: 8, L2: 381.80, Queries: 29
# Attacking sample 70/100 (True: 9, Index: 767)...
#   Success! Adv label: 8, L2: 468.27, Queries: 37
# Attacking sample 71/100 (True: 9, Index: 783)...
#   Success! Adv label: 5, L2: 528.18, Queries: 45
# Attacking sample 72/100 (True: 9, Index: 787)...
#   Success! Adv label: 8, L2: 595.50, Queries: 43
# Attacking sample 73/100 (True: 9, Index: 796)...
#   Success! Adv label: 7, L2: 411.32, Queries: 33
# Attacking sample 74/100 (True: 9, Index: 804)...
#   Success! Adv label: 7, L2: 669.97, Queries: 63
# Attacking sample 75/100 (True: 9, Index: 818)...
#   Success! Adv label: 4, L2: 644.38, Queries: 59
# Attacking sample 76/100 (True: 9, Index: 825)...
#   Success! Adv label: 8, L2: 348.20, Queries: 27
# Attacking sample 77/100 (True: 9, Index: 826)...
#   Success! Adv label: 1, L2: 176.57, Queries: 15
# Attacking sample 78/100 (True: 9, Index: 831)...
#   Success! Adv label: 4, L2: 502.60, Queries: 39
# Attacking sample 79/100 (True: 9, Index: 880)...
#   Success! Adv label: 5, L2: 459.99, Queries: 35
# Attacking sample 80/100 (True: 9, Index: 884)...
#   Success! Adv label: 4, L2: 473.59, Queries: 39
# Attacking sample 81/100 (True: 9, Index: 891)...
#   Success! Adv label: 4, L2: 134.72, Queries: 11
# Attacking sample 82/100 (True: 9, Index: 893)...
#   Success! Adv label: 2, L2: 630.54, Queries: 59
# Attacking sample 83/100 (True: 9, Index: 899)...
#   Success! Adv label: 4, L2: 451.19, Queries: 39
# Attacking sample 84/100 (True: 9, Index: 912)...
#   Success! Adv label: 5, L2: 494.53, Queries: 37
# Attacking sample 85/100 (True: 9, Index: 920)...
#   Success! Adv label: 4, L2: 591.56, Queries: 49
# Attacking sample 86/100 (True: 9, Index: 925)...
#   Success! Adv label: 8, L2: 347.19, Queries: 25
# Attacking sample 87/100 (True: 9, Index: 940)...
#   Success! Adv label: 4, L2: 353.93, Queries: 31
# Attacking sample 88/100 (True: 9, Index: 958)...
#   Success! Adv label: 4, L2: 481.81, Queries: 37
# Attacking sample 89/100 (True: 9, Index: 969)...
#   Success! Adv label: 8, L2: 368.48, Queries: 27
# Attacking sample 90/100 (True: 9, Index: 978)...
#   Success! Adv label: 4, L2: 432.02, Queries: 37
# Attacking sample 91/100 (True: 9, Index: 979)...
#   Success! Adv label: 4, L2: 377.78, Queries: 29
# Attacking sample 92/100 (True: 9, Index: 980)...
#   Success! Adv label: 8, L2: 361.95, Queries: 29
# Attacking sample 93/100 (True: 9, Index: 991)...
#   Success! Adv label: 7, L2: 565.44, Queries: 51
# Attacking sample 94/100 (True: 9, Index: 997)...
#   Success! Adv label: 4, L2: 240.73, Queries: 21
# Attacking sample 95/100 (True: 9, Index: 1006)...
#   Success! Adv label: 7, L2: 524.60, Queries: 47
# Attacking sample 96/100 (True: 9, Index: 1011)...
#   Success! Adv label: 4, L2: 795.57, Queries: 69
# Attacking sample 97/100 (True: 9, Index: 1020)...
#   Success! Adv label: 2, L2: 540.82, Queries: 45
# Attacking sample 98/100 (True: 9, Index: 1023)...
#   Success! Adv label: 4, L2: 801.14, Queries: 69
# Attacking sample 99/100 (True: 9, Index: 1042)...
#   Success! Adv label: 4, L2: 301.66, Queries: 23
# Attacking sample 100/100 (True: 9, Index: 1046)...
#   Success! Adv label: 4, L2: 370.90, Queries: 31
# Time taken to generate adversarial samples: 109.0591 seconds
#
# Stats saved to: adversarial_8bit_K180_test_images\per_sample_stats.csv
#
# ===== Attack Summary =====
# Total trials: 986
# Misclassified before attack: 14
# Success rate: 978/986 (99.2%)
# Mean L2 (successful): 558.57
# Mean queries (successful): 46.16
#
# Showing successful adversarial examples...

# %% [markdown]
# ### Untargeted Attack on test set; k=190

# %%
import os
import warnings
import numpy as np
import torch
import joblib
import pandas as pd
from PIL import Image
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import torch.nn.functional as F
import time


# Set seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# ─────────────── PATHS ────────────────────────────────────────────────────
LENET_MODEL_PATH = os.path.normpath("Models and Data splits/lenet.pt")  # TorchScript model
DATA_PKL = os.path.normpath("Models and Data splits/data_[SCALED] Train_Test_Splits.pkl")
RF_ALL_CLASSES_PATH = os.path.normpath("Models and Data splits/random_forest.pkl")
OUT_DIR = "adversarial_8bit_K190_test_images"
os.makedirs(OUT_DIR, exist_ok=True)

if not os.path.exists(RF_ALL_CLASSES_PATH):
    raise FileNotFoundError(f"Random Forest model not found at {RF_ALL_CLASSES_PATH}")

# ─────────── HYPER-PARAMETERS ─────────────────────────────────────────────
EPSILON_STEP = 0.01
ITERATIONS = 100
TOTAL_EPSILON = 0.5
TOP_K_FEATURES = 190
SAMPLES_PER_DIGIT = 100
MAX_L2 = 10000

def plot_adversarial_example(original_img, adv_img, true_label, adv_label, l2_mag, sample_idx, queries, title_suffix=""):
    if original_img.size == 784:
        original_img = original_img.reshape(28, 28)
    if adv_img.size == 784:
        adv_img = adv_img.reshape(28, 28)
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(original_img, cmap='gray')
    axes[0].set_title(f"Original\nTrue: {true_label}")
    axes[0].axis('off')
    axes[1].imshow(adv_img, cmap='gray')
    axes[1].set_title(f"Adversarial\nPred: {adv_label}")
    axes[1].axis('off')
    fig.suptitle(f"Sample {sample_idx} | L2: {l2_mag:.2f} | Queries: {queries} {title_suffix}")
    plt.show()
    plt.close(fig)  # <-- added here


# ─────────── Load Data ─────────────────────────────────────────────────────
try:
    data = joblib.load(DATA_PKL)
    _, X_samples , _, y_samples = data
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PKL}. Please check the path.")
    exit()

if X_samples.max() > 1.0:
    X_samples = X_samples.astype(np.float32) / 255.0
    warnings.warn("Data appeared in [0,255]; normalized to [0,1].")

# ─────────── Load TorchScripted LeNet ──────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
try:
    model = torch.jit.load(LENET_MODEL_PATH, map_location=device)
    model.eval()
    print(f"LeNet TorchScript model loaded from: {LENET_MODEL_PATH}")
except Exception as e:
    print(f"Error loading TorchScript LeNet model: {e}")
    exit()

def to_model(x01_batch):
    if x01_batch.ndim == 2 and x01_batch.shape == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)
    elif x01_batch.ndim == 3 and x01_batch.shape[1:] == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(1)
    elif x01_batch.ndim == 4 and x01_batch.shape[1] == 1:
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device)
    elif x01_batch.ndim == 1 and x01_batch.size == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(1, 1, 28, 28), dtype=torch.float32, device=device)
    elif x01_batch.ndim == 2 and x01_batch.shape[1] == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(x01_batch.shape[0], 1, 28, 28), dtype=torch.float32, device=device)
    else:
        raise ValueError(f"Unsupported input shape for to_model: {x01_batch.shape}")
    return tensor_batch


def model_query(x_tensor_batch):
    with torch.no_grad():
        return model(x_tensor_batch)

# ─────────── Load Random Forest Model ──────────────────────────────────────
rf_all_classes = None
top_feature_indices = None
print("Loading Random Forest Classifier for all classes...")
try:
    rf_all_classes = joblib.load(RF_ALL_CLASSES_PATH)
    feature_importances = rf_all_classes.feature_importances_
    #top_feature_indices = np.argsort(feature_importances)[:TOP_K_FEATURES]
    
    top_feature_indices = np.argsort(-feature_importances)[:TOP_K_FEATURES]
    print(f"Random Forest loaded. Using top {TOP_K_FEATURES} features.")
except Exception as e:
    print(f"Error loading Random Forest: {e}")
    top_feature_indices = np.arange(28 * 28)

# ─────────── I-FGSM Attack ─────────────────────────────────────────────────
def ifgsm_attack(original_image_np, true_label, model_target, epsilon_step, iterations,
                 total_epsilon_budget, features_to_perturb, query_count_tracker):
    if original_image_np.ndim == 1 and original_image_np.size == 784:
        original_image_np = original_image_np.reshape(28, 28)

    perturbed_image_np = original_image_np.copy()
    final_pred_label = true_label

    for i in range(iterations):
        image_tensor = to_model(perturbed_image_np)
        image_tensor.requires_grad = True
        output = model_target(image_tensor)
        query_count_tracker[0] += 1
        loss = F.cross_entropy(output, torch.tensor([true_label], device=device))
        model_target.zero_grad()
        loss.backward()
        data_grad_sign = torch.sign(image_tensor.grad.data).cpu().numpy()

        gradient_mask = np.zeros_like(data_grad_sign, dtype=np.float32)
        h, w = perturbed_image_np.shape
        rows, cols = np.unravel_index(features_to_perturb, (h, w))
        gradient_mask[0, 0, rows, cols] = data_grad_sign[0, 0, rows, cols]
        gradient_mask_for_update = gradient_mask.reshape(perturbed_image_np.shape)

        perturbed_image_np += epsilon_step * gradient_mask_for_update
        perturbation = perturbed_image_np - original_image_np
        perturbation = np.clip(perturbation, -total_epsilon_budget, total_epsilon_budget)
        perturbed_image_np = original_image_np + perturbation
        perturbed_image_np = np.clip(perturbed_image_np, 0, 1)

        # Discretize and check prediction on discretized image
        adv_uint8_temp = np.round(perturbed_image_np * 255).astype(np.uint8)
        adv_float_temp = adv_uint8_temp.astype(np.float32) / 255.0
        with torch.no_grad():
            output_temp = model_target(to_model(adv_float_temp))
            pred_temp = output_temp.argmax(dim=1).item()
            query_count_tracker[0] += 1

        if pred_temp != true_label:
            final_pred_label = pred_temp
            break

    # Final adversarial image (discretized)
    adv_uint8 = np.round(perturbed_image_np * 255).astype(np.uint8)
    adv_float = adv_uint8.astype(np.float32) / 255.0
    with torch.no_grad():
        output_final = model_target(to_model(adv_float))
        final_pred_label = output_final.argmax(dim=1).item()

    l2_norm = np.linalg.norm(adv_uint8.astype(np.float32) - (original_image_np * 255).astype(np.float32))
    success = (final_pred_label != true_label) and (l2_norm <= MAX_L2)

    return adv_uint8, final_pred_label, l2_norm, success


# ─────────── Attack Execution ──────────────────────────────────────────────
print(f"\n===== Starting Adversarial Attack =====")
total_trials, succ_total, misclassified = 0, 0, 0
records = []


start_time = time.time()


for digit in range(10):
    idxs = np.where(y_samples == digit)[0][:SAMPLES_PER_DIGIT]
    for rank, idx in enumerate(idxs, 1):
        x0 = X_samples[idx].copy()
        y0 = int(y_samples[idx])
        query_count_tracker = [0]
        pred0 = model_query(to_model(x0)).argmax(dim=1).item()
        query_count_tracker[0] += 1

        if pred0 != y0:
            misclassified += 1
            records.append({
                'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
                'adv_label': None, 'success': False, 'queries': query_count_tracker[0],
                'l2_mag': np.nan, 'note': 'Already misclassified'
            })
            continue

        total_trials += 1
        print(f"Attacking sample {rank}/{SAMPLES_PER_DIGIT} (True: {y0}, Index: {idx})...")
        adv_img_uint8, adv_label, l2_mag, success = ifgsm_attack(
            x0, y0, model, EPSILON_STEP, ITERATIONS, TOTAL_EPSILON,
            top_feature_indices, query_count_tracker
        )

        if success:
            succ_total += 1
            fname = f"true{y0}_adv{adv_label}_mag{l2_mag:.1f}_sample{idx}.png"
            Image.fromarray(adv_img_uint8, mode="L").save(os.path.join(OUT_DIR, fname))

        records.append({
            'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
            'adv_label': adv_label, 'success': success, 'queries': query_count_tracker[0],
            'l2_mag': l2_mag if success else np.nan, 'note': 'I-FGSM' + (' successful' if success else ' failed')
        })

        print(f"  {'Success' if success else 'Failed'}! Adv label: {adv_label}, L2: {l2_mag:.2f}, Queries: {query_count_tracker[0]}")


end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to generate adversarial samples: {elapsed_time:.4f} seconds")


# ─────────── Save Results ──────────────────────────────────────────────────
df = pd.DataFrame(records)
csv_path = os.path.join(OUT_DIR, "per_sample_stats.csv")
df.to_csv(csv_path, index=False)
print(f"\nStats saved to: {csv_path}")

# ─────────── Summary ───────────────────────────────────────────────────────
print(f"\n===== Attack Summary =====")
print(f"Total trials: {total_trials}")
print(f"Misclassified before attack: {misclassified}")
if total_trials > 0:
    success_rate = succ_total / total_trials * 100
    print(f"Success rate: {succ_total}/{total_trials} ({success_rate:.1f}%)")
    if succ_total > 0:
        print(f"Mean L2 (successful): {df[df['success']]['l2_mag'].mean():.2f}")
        print(f"Mean queries (successful): {df[df['success']]['queries'].mean():.2f}")

# ─────────── Display Examples ──────────────────────────────────────────────
success_df = df[df['success']]
if not success_df.empty:
    print("\nShowing successful adversarial examples...")
    show_ids = success_df.sample(min(3, len(success_df))).index.tolist()
    for record_idx in show_ids:
        r = df.loc[record_idx]
        fname_prefix = f"true{r['true_label']}_adv{r['adv_label']}_mag{r['l2_mag']:.1f}_sample{r['sample_idx']}"
        match_files = [f for f in os.listdir(OUT_DIR) if f.startswith(fname_prefix)]
        if match_files:
            adv_img_path = os.path.join(OUT_DIR, match_files[0])
            plot_adversarial_example(X_samples[r['sample_idx']], np.array(Image.open(adv_img_path)),
                                     r['true_label'], r['adv_label'], r['l2_mag'],
                                     r['sample_idx'], r['queries'], "(I-FGSM)")
else:
    print("No successful attacks to display. Showing original samples instead.")
    for i in range(min(3, len(df))):
        r = df.iloc[i]
        plot_adversarial_example(X_samples[r['sample_idx']], X_samples[r['sample_idx']],
                                 r['true_label'], r['initial_pred'], 0.0,
                                 r['sample_idx'], r['queries'], "(Original)")
# Out:
# LeNet TorchScript model loaded from: Models and Data splits\lenet.pt
# Loading Random Forest Classifier for all classes...
# Random Forest loaded. Using top 190 features.
#
# ===== Starting Adversarial Attack =====
# Attacking sample 1/100 (True: 0, Index: 29)...
#   Success! Adv label: 6, L2: 864.78, Queries: 75
# Attacking sample 2/100 (True: 0, Index: 40)...
#   Success! Adv label: 6, L2: 1066.12, Queries: 91
# Attacking sample 3/100 (True: 0, Index: 44)...
#   Success! Adv label: 5, L2: 573.32, Queries: 47
# Attacking sample 4/100 (True: 0, Index: 59)...
#   Success! Adv label: 6, L2: 695.55, Queries: 59
# Attacking sample 5/100 (True: 0, Index: 64)...
#   Success! Adv label: 9, L2: 1142.81, Queries: 93
# Attacking sample 6/100 (True: 0, Index: 75)...
#   Success! Adv label: 8, L2: 715.32, Queries: 61
# Attacking sample 7/100 (True: 0, Index: 80)...
#   Success! Adv label: 9, L2: 604.07, Queries: 51
# Attacking sample 8/100 (True: 0, Index: 97)...
#   Success! Adv label: 6, L2: 663.53, Queries: 55
# Attacking sample 9/100 (True: 0, Index: 115)...
#   Success! Adv label: 6, L2: 833.27, Queries: 69
# Attacking sample 10/100 (True: 0, Index: 141)...
#   Success! Adv label: 7, L2: 194.06, Queries: 17
# Attacking sample 11/100 (True: 0, Index: 146)...
#   Success! Adv label: 9, L2: 798.35, Queries: 67
# Attacking sample 12/100 (True: 0, Index: 156)...
#   Success! Adv label: 9, L2: 1118.07, Queries: 133
# Attacking sample 13/100 (True: 0, Index: 173)...
#   Success! Adv label: 6, L2: 692.12, Queries: 65
# Attacking sample 14/100 (True: 0, Index: 175)...
#   Success! Adv label: 8, L2: 468.93, Queries: 37
# Attacking sample 15/100 (True: 0, Index: 193)...
#   Success! Adv label: 9, L2: 840.23, Queries: 79
# Attacking sample 16/100 (True: 0, Index: 200)...
#   Success! Adv label: 9, L2: 746.82, Queries: 63
# Attacking sample 17/100 (True: 0, Index: 205)...
#   Success! Adv label: 9, L2: 898.41, Queries: 77
# Attacking sample 18/100 (True: 0, Index: 210)...
#   Success! Adv label: 9, L2: 820.63, Queries: 69
# Attacking sample 19/100 (True: 0, Index: 221)...
#   Success! Adv label: 9, L2: 850.02, Queries: 65
# Attacking sample 20/100 (True: 0, Index: 229)...
#   Success! Adv label: 5, L2: 971.89, Queries: 89
# Attacking sample 21/100 (True: 0, Index: 249)...
#   Success! Adv label: 5, L2: 744.37, Queries: 71
# Attacking sample 22/100 (True: 0, Index: 258)...
#   Success! Adv label: 2, L2: 853.86, Queries: 71
# Attacking sample 23/100 (True: 0, Index: 275)...
#   Success! Adv label: 9, L2: 1176.00, Queries: 135
# Attacking sample 24/100 (True: 0, Index: 292)...
#   Success! Adv label: 2, L2: 948.76, Queries: 89
# Attacking sample 25/100 (True: 0, Index: 296)...
#   Success! Adv label: 9, L2: 662.53, Queries: 53
# Attacking sample 26/100 (True: 0, Index: 301)...
#   Success! Adv label: 9, L2: 594.77, Queries: 47
# Attacking sample 27/100 (True: 0, Index: 314)...
#   Success! Adv label: 9, L2: 744.59, Queries: 59
# Attacking sample 28/100 (True: 0, Index: 325)...
#   Success! Adv label: 9, L2: 998.51, Queries: 87
# Attacking sample 29/100 (True: 0, Index: 333)...
#   Success! Adv label: 9, L2: 815.62, Queries: 73
# Attacking sample 30/100 (True: 0, Index: 345)...
#   Success! Adv label: 6, L2: 662.65, Queries: 53
# Attacking sample 31/100 (True: 0, Index: 349)...
#   Success! Adv label: 9, L2: 666.61, Queries: 53
# Attacking sample 32/100 (True: 0, Index: 360)...
#   Success! Adv label: 6, L2: 1130.25, Queries: 109
# Attacking sample 33/100 (True: 0, Index: 365)...
#   Success! Adv label: 5, L2: 985.91, Queries: 89
# Attacking sample 34/100 (True: 0, Index: 366)...
#   Success! Adv label: 9, L2: 849.53, Queries: 71
# Attacking sample 35/100 (True: 0, Index: 379)...
#   Success! Adv label: 9, L2: 976.67, Queries: 81
# Attacking sample 36/100 (True: 0, Index: 385)...
#   Failed! Adv label: 0, L2: 1155.52, Queries: 201
# Attacking sample 37/100 (True: 0, Index: 397)...
#   Success! Adv label: 2, L2: 961.86, Queries: 91
# Attacking sample 38/100 (True: 0, Index: 400)...
#   Success! Adv label: 9, L2: 1191.93, Queries: 101
# Attacking sample 39/100 (True: 0, Index: 405)...
#   Success! Adv label: 2, L2: 724.82, Queries: 55
# Attacking sample 40/100 (True: 0, Index: 410)...
#   Success! Adv label: 9, L2: 820.95, Queries: 69
# Attacking sample 41/100 (True: 0, Index: 420)...
#   Success! Adv label: 2, L2: 753.43, Queries: 67
# Attacking sample 42/100 (True: 0, Index: 424)...
#   Success! Adv label: 9, L2: 798.50, Queries: 67
# Attacking sample 43/100 (True: 0, Index: 447)...
#   Success! Adv label: 2, L2: 682.17, Queries: 57
# Attacking sample 44/100 (True: 0, Index: 453)...
#   Success! Adv label: 6, L2: 815.38, Queries: 69
# Attacking sample 45/100 (True: 0, Index: 457)...
#   Success! Adv label: 6, L2: 979.42, Queries: 83
# Attacking sample 46/100 (True: 0, Index: 466)...
#   Success! Adv label: 2, L2: 795.11, Queries: 67
# Attacking sample 47/100 (True: 0, Index: 475)...
#   Success! Adv label: 9, L2: 253.58, Queries: 21
# Attacking sample 48/100 (True: 0, Index: 483)...
#   Success! Adv label: 2, L2: 821.42, Queries: 71
# Attacking sample 49/100 (True: 0, Index: 484)...
#   Success! Adv label: 8, L2: 466.07, Queries: 33
# Attacking sample 50/100 (True: 0, Index: 486)...
#   Success! Adv label: 9, L2: 935.38, Queries: 87
# Attacking sample 51/100 (True: 0, Index: 487)...
#   Success! Adv label: 8, L2: 645.56, Queries: 53
# Attacking sample 52/100 (True: 0, Index: 489)...
#   Success! Adv label: 9, L2: 766.28, Queries: 65
# Attacking sample 53/100 (True: 0, Index: 492)...
#   Success! Adv label: 9, L2: 660.59, Queries: 53
# Attacking sample 54/100 (True: 0, Index: 506)...
#   Success! Adv label: 2, L2: 829.82, Queries: 63
# Attacking sample 55/100 (True: 0, Index: 513)...
#   Failed! Adv label: 0, L2: 1230.94, Queries: 201
# Attacking sample 56/100 (True: 0, Index: 518)...
#   Success! Adv label: 5, L2: 960.26, Queries: 87
# Attacking sample 57/100 (True: 0, Index: 521)...
#   Success! Adv label: 9, L2: 1315.27, Queries: 179
# Attacking sample 58/100 (True: 0, Index: 527)...
#   Success! Adv label: 2, L2: 739.58, Queries: 61
# Attacking sample 59/100 (True: 0, Index: 529)...
#   Success! Adv label: 5, L2: 652.72, Queries: 61
# Attacking sample 60/100 (True: 0, Index: 531)...
#   Success! Adv label: 2, L2: 1049.17, Queries: 119
# Attacking sample 61/100 (True: 0, Index: 546)...
#   Success! Adv label: 9, L2: 735.41, Queries: 65
# Attacking sample 62/100 (True: 0, Index: 551)...
#   Success! Adv label: 6, L2: 374.87, Queries: 27
# Attacking sample 63/100 (True: 0, Index: 555)...
#   Success! Adv label: 6, L2: 861.58, Queries: 71
# Attacking sample 64/100 (True: 0, Index: 587)...
#   Success! Adv label: 2, L2: 845.42, Queries: 73
# Attacking sample 65/100 (True: 0, Index: 604)...
#   Success! Adv label: 8, L2: 776.11, Queries: 59
# Attacking sample 66/100 (True: 0, Index: 614)...
#   Success! Adv label: 2, L2: 1084.06, Queries: 95
# Attacking sample 67/100 (True: 0, Index: 615)...
#   Success! Adv label: 9, L2: 448.07, Queries: 35
# Attacking sample 68/100 (True: 0, Index: 618)...
#   Success! Adv label: 6, L2: 323.35, Queries: 25
# Attacking sample 69/100 (True: 0, Index: 638)...
#   Success! Adv label: 8, L2: 420.86, Queries: 31
# Attacking sample 70/100 (True: 0, Index: 642)...
#   Success! Adv label: 9, L2: 888.34, Queries: 83
# Attacking sample 71/100 (True: 0, Index: 655)...
#   Success! Adv label: 6, L2: 783.05, Queries: 61
# Attacking sample 72/100 (True: 0, Index: 658)...
#   Success! Adv label: 6, L2: 682.37, Queries: 53
# Attacking sample 73/100 (True: 0, Index: 665)...
#   Success! Adv label: 2, L2: 663.23, Queries: 53
# Attacking sample 74/100 (True: 0, Index: 671)...
#   Success! Adv label: 6, L2: 690.38, Queries: 53
# Attacking sample 75/100 (True: 0, Index: 681)...
#   Success! Adv label: 9, L2: 986.11, Queries: 87
# Attacking sample 76/100 (True: 0, Index: 691)...
#   Success! Adv label: 2, L2: 649.23, Queries: 49
# Attacking sample 77/100 (True: 0, Index: 700)...
#   Success! Adv label: 5, L2: 562.06, Queries: 47
# Attacking sample 78/100 (True: 0, Index: 706)...
#   Success! Adv label: 2, L2: 880.63, Queries: 99
# Attacking sample 79/100 (True: 0, Index: 712)...
#   Success! Adv label: 3, L2: 1073.74, Queries: 107
# Attacking sample 80/100 (True: 0, Index: 713)...
#   Success! Adv label: 9, L2: 758.88, Queries: 61
# Attacking sample 81/100 (True: 0, Index: 736)...
#   Success! Adv label: 5, L2: 654.05, Queries: 55
# Attacking sample 82/100 (True: 0, Index: 742)...
#   Success! Adv label: 6, L2: 678.54, Queries: 59
# Attacking sample 83/100 (True: 0, Index: 744)...
#   Success! Adv label: 2, L2: 588.67, Queries: 47
# Attacking sample 84/100 (True: 0, Index: 760)...
#   Success! Adv label: 9, L2: 660.93, Queries: 57
# Attacking sample 85/100 (True: 0, Index: 772)...
#   Success! Adv label: 9, L2: 338.91, Queries: 25
# Attacking sample 86/100 (True: 0, Index: 781)...
#   Success! Adv label: 6, L2: 469.86, Queries: 39
# Attacking sample 87/100 (True: 0, Index: 809)...
#   Success! Adv label: 5, L2: 637.90, Queries: 55
# Attacking sample 88/100 (True: 0, Index: 813)...
#   Success! Adv label: 9, L2: 560.49, Queries: 47
# Attacking sample 89/100 (True: 0, Index: 820)...
#   Success! Adv label: 9, L2: 626.32, Queries: 55
# Attacking sample 90/100 (True: 0, Index: 823)...
#   Success! Adv label: 5, L2: 715.43, Queries: 65
# Attacking sample 91/100 (True: 0, Index: 844)...
#   Success! Adv label: 9, L2: 1104.27, Queries: 135
# Attacking sample 92/100 (True: 0, Index: 848)...
#   Success! Adv label: 9, L2: 329.48, Queries: 25
# Attacking sample 93/100 (True: 0, Index: 861)...
#   Success! Adv label: 6, L2: 938.69, Queries: 71
# Attacking sample 94/100 (True: 0, Index: 865)...
#   Success! Adv label: 6, L2: 1234.86, Queries: 95
# Attacking sample 95/100 (True: 0, Index: 869)...
#   Success! Adv label: 6, L2: 1006.78, Queries: 85
# Attacking sample 96/100 (True: 0, Index: 876)...
#   Success! Adv label: 9, L2: 664.03, Queries: 53
# Attacking sample 97/100 (True: 0, Index: 885)...
#   Success! Adv label: 9, L2: 1095.42, Queries: 143
# Attacking sample 98/100 (True: 0, Index: 906)...
#   Success! Adv label: 2, L2: 892.09, Queries: 75
# Attacking sample 99/100 (True: 0, Index: 907)...
#   Success! Adv label: 9, L2: 812.11, Queries: 67
# Attacking sample 100/100 (True: 0, Index: 918)...
#   Success! Adv label: 9, L2: 942.00, Queries: 79
# Attacking sample 1/100 (True: 1, Index: 2)...
#   Success! Adv label: 7, L2: 293.04, Queries: 21
# Attacking sample 2/100 (True: 1, Index: 3)...
#   Success! Adv label: 7, L2: 360.67, Queries: 25
# Attacking sample 3/100 (True: 1, Index: 9)...
#   Success! Adv label: 8, L2: 353.61, Queries: 27
# Attacking sample 4/100 (True: 1, Index: 25)...
#   Success! Adv label: 4, L2: 338.75, Queries: 23
# Attacking sample 5/100 (True: 1, Index: 36)...
#   Success! Adv label: 2, L2: 267.36, Queries: 19
# Attacking sample 6/100 (True: 1, Index: 63)...
#   Success! Adv label: 8, L2: 257.80, Queries: 19
# Attacking sample 7/100 (True: 1, Index: 65)...
#   Success! Adv label: 8, L2: 329.40, Queries: 23
# Attacking sample 8/100 (True: 1, Index: 68)...
#   Success! Adv label: 8, L2: 373.72, Queries: 25
# Attacking sample 9/100 (True: 1, Index: 76)...
#   Success! Adv label: 8, L2: 207.58, Queries: 15
# Attacking sample 10/100 (True: 1, Index: 83)...
#   Success! Adv label: 4, L2: 373.10, Queries: 27
# Attacking sample 11/100 (True: 1, Index: 90)...
#   Success! Adv label: 9, L2: 34.06, Queries: 3
# Attacking sample 12/100 (True: 1, Index: 94)...
#   Success! Adv label: 8, L2: 181.02, Queries: 13
# Attacking sample 13/100 (True: 1, Index: 100)...
#   Success! Adv label: 8, L2: 238.05, Queries: 17
# Attacking sample 14/100 (True: 1, Index: 123)...
#   Success! Adv label: 8, L2: 209.95, Queries: 15
# Attacking sample 15/100 (True: 1, Index: 150)...
#   Success! Adv label: 8, L2: 343.50, Queries: 23
# Attacking sample 16/100 (True: 1, Index: 152)...
#   Success! Adv label: 9, L2: 346.84, Queries: 25
# Attacking sample 17/100 (True: 1, Index: 178)...
#   Success! Adv label: 4, L2: 338.81, Queries: 23
# Attacking sample 18/100 (True: 1, Index: 185)...
#   Success! Adv label: 8, L2: 376.57, Queries: 29
# Attacking sample 19/100 (True: 1, Index: 191)...
#   Success! Adv label: 4, L2: 399.30, Queries: 27
# Attacking sample 20/100 (True: 1, Index: 201)...
#   Success! Adv label: 8, L2: 301.55, Queries: 21
# Attacking sample 21/100 (True: 1, Index: 203)...
#   Success! Adv label: 8, L2: 242.66, Queries: 17
# Attacking sample 22/100 (True: 1, Index: 213)...
#   Success! Adv label: 8, L2: 266.31, Queries: 19
# Attacking sample 23/100 (True: 1, Index: 220)...
#   Success! Adv label: 8, L2: 214.79, Queries: 15
# Attacking sample 24/100 (True: 1, Index: 223)...
#   Success! Adv label: 4, L2: 359.58, Queries: 25
# Attacking sample 25/100 (True: 1, Index: 226)...
#   Success! Adv label: 4, L2: 344.51, Queries: 23
# Attacking sample 26/100 (True: 1, Index: 232)...
#   Success! Adv label: 4, L2: 426.39, Queries: 29
# Attacking sample 27/100 (True: 1, Index: 241)...
#   Success! Adv label: 4, L2: 274.54, Queries: 19
# Attacking sample 28/100 (True: 1, Index: 254)...
#   Success! Adv label: 8, L2: 279.60, Queries: 19
# Attacking sample 29/100 (True: 1, Index: 281)...
#   Success! Adv label: 8, L2: 284.00, Queries: 21
# Attacking sample 30/100 (True: 1, Index: 284)...
#   Success! Adv label: 8, L2: 304.80, Queries: 23
# Attacking sample 31/100 (True: 1, Index: 285)...
#   Success! Adv label: 9, L2: 228.73, Queries: 17
# Attacking sample 32/100 (True: 1, Index: 286)...
#   Success! Adv label: 4, L2: 295.32, Queries: 21
# Attacking sample 33/100 (True: 1, Index: 287)...
#   Success! Adv label: 4, L2: 317.04, Queries: 23
# Attacking sample 34/100 (True: 1, Index: 294)...
#   Success! Adv label: 4, L2: 362.50, Queries: 25
# Attacking sample 35/100 (True: 1, Index: 298)...
#   Success! Adv label: 7, L2: 431.81, Queries: 29
# Attacking sample 36/100 (True: 1, Index: 306)...
#   Success! Adv label: 4, L2: 389.48, Queries: 27
# Attacking sample 37/100 (True: 1, Index: 312)...
#   Success! Adv label: 8, L2: 340.97, Queries: 25
# Attacking sample 38/100 (True: 1, Index: 317)...
#   Success! Adv label: 4, L2: 350.30, Queries: 25
# Attacking sample 39/100 (True: 1, Index: 334)...
#   Success! Adv label: 4, L2: 372.94, Queries: 25
# Attacking sample 40/100 (True: 1, Index: 337)...
#   Success! Adv label: 8, L2: 333.11, Queries: 23
# Attacking sample 41/100 (True: 1, Index: 338)...
#   Success! Adv label: 4, L2: 457.06, Queries: 31
# Attacking sample 42/100 (True: 1, Index: 348)...
#   Success! Adv label: 2, L2: 419.39, Queries: 29
# Attacking sample 43/100 (True: 1, Index: 361)...
#   Success! Adv label: 8, L2: 271.18, Queries: 19
# Attacking sample 44/100 (True: 1, Index: 363)...
#   Success! Adv label: 8, L2: 332.90, Queries: 23
# Attacking sample 45/100 (True: 1, Index: 367)...
#   Success! Adv label: 8, L2: 181.73, Queries: 13
# Attacking sample 46/100 (True: 1, Index: 375)...
#   Success! Adv label: 7, L2: 420.64, Queries: 29
# Attacking sample 47/100 (True: 1, Index: 384)...
#   Success! Adv label: 8, L2: 279.28, Queries: 19
# Attacking sample 48/100 (True: 1, Index: 412)...
#   Success! Adv label: 8, L2: 369.08, Queries: 25
# Attacking sample 49/100 (True: 1, Index: 425)...
#   Success! Adv label: 7, L2: 370.43, Queries: 25
# Attacking sample 50/100 (True: 1, Index: 428)...
#   Success! Adv label: 4, L2: 342.30, Queries: 23
# Attacking sample 51/100 (True: 1, Index: 463)...
#   Success! Adv label: 4, L2: 291.68, Queries: 21
# Attacking sample 52/100 (True: 1, Index: 499)...
#   Success! Adv label: 4, L2: 394.45, Queries: 27
# Attacking sample 53/100 (True: 1, Index: 502)...
#   Success! Adv label: 4, L2: 382.98, Queries: 27
# Attacking sample 54/100 (True: 1, Index: 526)...
#   Success! Adv label: 8, L2: 239.72, Queries: 17
# Attacking sample 55/100 (True: 1, Index: 532)...
#   Success! Adv label: 4, L2: 340.75, Queries: 23
# Attacking sample 56/100 (True: 1, Index: 536)...
#   Success! Adv label: 9, L2: 253.11, Queries: 19
# Attacking sample 57/100 (True: 1, Index: 537)...
#   Success! Adv label: 8, L2: 293.46, Queries: 21
# Attacking sample 58/100 (True: 1, Index: 539)...
#   Success! Adv label: 4, L2: 371.41, Queries: 25
# Attacking sample 60/100 (True: 1, Index: 560)...
#   Success! Adv label: 4, L2: 335.04, Queries: 23
# Attacking sample 61/100 (True: 1, Index: 561)...
#   Success! Adv label: 8, L2: 275.35, Queries: 19
# Attacking sample 62/100 (True: 1, Index: 570)...
#   Success! Adv label: 8, L2: 325.80, Queries: 23
# Attacking sample 63/100 (True: 1, Index: 573)...
#   Success! Adv label: 2, L2: 37.52, Queries: 3
# Attacking sample 64/100 (True: 1, Index: 576)...
#   Success! Adv label: 7, L2: 315.15, Queries: 23
# Attacking sample 65/100 (True: 1, Index: 580)...
#   Success! Adv label: 4, L2: 300.19, Queries: 21
# Attacking sample 66/100 (True: 1, Index: 588)...
#   Success! Adv label: 7, L2: 410.82, Queries: 29
# Attacking sample 67/100 (True: 1, Index: 620)...
#   Success! Adv label: 8, L2: 337.96, Queries: 23
# Attacking sample 68/100 (True: 1, Index: 621)...
#   Success! Adv label: 4, L2: 365.29, Queries: 25
# Attacking sample 69/100 (True: 1, Index: 622)...
#   Success! Adv label: 2, L2: 118.62, Queries: 9
# Attacking sample 70/100 (True: 1, Index: 627)...
#   Success! Adv label: 8, L2: 264.89, Queries: 19
# Attacking sample 71/100 (True: 1, Index: 630)...
#   Success! Adv label: 8, L2: 220.46, Queries: 15
# Attacking sample 72/100 (True: 1, Index: 632)...
#   Success! Adv label: 4, L2: 245.66, Queries: 17
# Attacking sample 73/100 (True: 1, Index: 644)...
#   Success! Adv label: 4, L2: 274.03, Queries: 19
# Attacking sample 74/100 (True: 1, Index: 646)...
#   Success! Adv label: 7, L2: 309.60, Queries: 23
# Attacking sample 75/100 (True: 1, Index: 649)...
#   Success! Adv label: 8, L2: 366.35, Queries: 25
# Attacking sample 76/100 (True: 1, Index: 662)...
#   Success! Adv label: 4, L2: 365.04, Queries: 25
# Attacking sample 77/100 (True: 1, Index: 663)...
#   Success! Adv label: 8, L2: 245.67, Queries: 17
# Attacking sample 78/100 (True: 1, Index: 669)...
#   Success! Adv label: 7, L2: 444.36, Queries: 31
# Attacking sample 79/100 (True: 1, Index: 677)...
#   Success! Adv label: 9, L2: 265.97, Queries: 19
# Attacking sample 80/100 (True: 1, Index: 686)...
#   Success! Adv label: 8, L2: 314.72, Queries: 23
# Attacking sample 81/100 (True: 1, Index: 689)...
#   Success! Adv label: 8, L2: 314.67, Queries: 21
# Attacking sample 82/100 (True: 1, Index: 703)...
#   Success! Adv label: 8, L2: 335.57, Queries: 23
# Attacking sample 83/100 (True: 1, Index: 705)...
#   Success! Adv label: 7, L2: 467.69, Queries: 33
# Attacking sample 84/100 (True: 1, Index: 709)...
#   Success! Adv label: 4, L2: 315.54, Queries: 23
# Attacking sample 85/100 (True: 1, Index: 724)...
#   Success! Adv label: 4, L2: 219.70, Queries: 15
# Attacking sample 86/100 (True: 1, Index: 727)...
#   Success! Adv label: 8, L2: 283.37, Queries: 19
# Attacking sample 87/100 (True: 1, Index: 734)...
#   Success! Adv label: 8, L2: 201.71, Queries: 15
# Attacking sample 88/100 (True: 1, Index: 740)...
#   Success! Adv label: 4, L2: 341.23, Queries: 23
# Attacking sample 89/100 (True: 1, Index: 741)...
#   Success! Adv label: 8, L2: 217.58, Queries: 15
# Attacking sample 90/100 (True: 1, Index: 743)...
#   Success! Adv label: 8, L2: 284.22, Queries: 19
# Attacking sample 91/100 (True: 1, Index: 759)...
#   Success! Adv label: 4, L2: 356.22, Queries: 25
# Attacking sample 92/100 (True: 1, Index: 768)...
#   Success! Adv label: 8, L2: 293.54, Queries: 21
# Attacking sample 93/100 (True: 1, Index: 775)...
#   Success! Adv label: 4, L2: 265.27, Queries: 19
# Attacking sample 94/100 (True: 1, Index: 782)...
#   Success! Adv label: 4, L2: 369.51, Queries: 25
# Attacking sample 95/100 (True: 1, Index: 798)...
#   Success! Adv label: 9, L2: 319.39, Queries: 23
# Attacking sample 96/100 (True: 1, Index: 799)...
#   Success! Adv label: 8, L2: 393.19, Queries: 27
# Attacking sample 97/100 (True: 1, Index: 808)...
#   Success! Adv label: 7, L2: 336.46, Queries: 23
# Attacking sample 98/100 (True: 1, Index: 819)...
#   Success! Adv label: 4, L2: 435.01, Queries: 29
# Attacking sample 99/100 (True: 1, Index: 843)...
#   Success! Adv label: 4, L2: 393.56, Queries: 27
# Attacking sample 100/100 (True: 1, Index: 853)...
#   Success! Adv label: 4, L2: 359.29, Queries: 25
# Attacking sample 1/100 (True: 2, Index: 4)...
#   Success! Adv label: 3, L2: 565.65, Queries: 43
# Attacking sample 2/100 (True: 2, Index: 22)...
#   Success! Adv label: 6, L2: 516.66, Queries: 47
# Attacking sample 3/100 (True: 2, Index: 32)...
#   Success! Adv label: 9, L2: 894.60, Queries: 71
# Attacking sample 4/100 (True: 2, Index: 34)...
#   Success! Adv label: 4, L2: 34.45, Queries: 3
# Attacking sample 5/100 (True: 2, Index: 42)...
#   Success! Adv label: 3, L2: 229.48, Queries: 17
# Attacking sample 6/100 (True: 2, Index: 49)...
#   Success! Adv label: 3, L2: 1076.84, Queries: 153
# Attacking sample 7/100 (True: 2, Index: 52)...
#   Success! Adv label: 8, L2: 1009.30, Queries: 91
# Attacking sample 8/100 (True: 2, Index: 69)...
#   Success! Adv label: 8, L2: 658.22, Queries: 49
# Attacking sample 9/100 (True: 2, Index: 70)...
#   Success! Adv label: 3, L2: 709.53, Queries: 69
# Attacking sample 10/100 (True: 2, Index: 81)...
#   Success! Adv label: 8, L2: 854.35, Queries: 59
# Attacking sample 11/100 (True: 2, Index: 110)...
#   Success! Adv label: 7, L2: 938.73, Queries: 79
# Attacking sample 12/100 (True: 2, Index: 118)...
#   Success! Adv label: 3, L2: 583.89, Queries: 45
# Attacking sample 13/100 (True: 2, Index: 121)...
#   Success! Adv label: 3, L2: 638.30, Queries: 49
# Attacking sample 14/100 (True: 2, Index: 138)...
#   Success! Adv label: 3, L2: 643.98, Queries: 49
# Attacking sample 15/100 (True: 2, Index: 144)...
#   Success! Adv label: 9, L2: 666.84, Queries: 51
# Attacking sample 16/100 (True: 2, Index: 155)...
#   Success! Adv label: 8, L2: 815.85, Queries: 57
# Attacking sample 17/100 (True: 2, Index: 160)...
#   Success! Adv label: 6, L2: 357.89, Queries: 29
# Attacking sample 18/100 (True: 2, Index: 161)...
#   Success! Adv label: 3, L2: 618.71, Queries: 47
# Attacking sample 19/100 (True: 2, Index: 176)...
#   Success! Adv label: 3, L2: 619.67, Queries: 47
# Attacking sample 21/100 (True: 2, Index: 186)...
#   Success! Adv label: 7, L2: 650.89, Queries: 59
# Attacking sample 22/100 (True: 2, Index: 197)...
#   Success! Adv label: 8, L2: 966.36, Queries: 87
# Attacking sample 23/100 (True: 2, Index: 208)...
#   Success! Adv label: 8, L2: 825.76, Queries: 67
# Attacking sample 25/100 (True: 2, Index: 216)...
#   Success! Adv label: 3, L2: 798.29, Queries: 65
# Attacking sample 26/100 (True: 2, Index: 219)...
#   Success! Adv label: 3, L2: 378.24, Queries: 31
# Attacking sample 27/100 (True: 2, Index: 235)...
#   Success! Adv label: 3, L2: 733.98, Queries: 59
# Attacking sample 28/100 (True: 2, Index: 260)...
#   Success! Adv label: 0, L2: 508.69, Queries: 41
# Attacking sample 29/100 (True: 2, Index: 276)...
#   Success! Adv label: 4, L2: 490.26, Queries: 41
# Attacking sample 30/100 (True: 2, Index: 293)...
#   Success! Adv label: 3, L2: 748.19, Queries: 71
# Attacking sample 31/100 (True: 2, Index: 295)...
#   Success! Adv label: 3, L2: 509.01, Queries: 41
# Attacking sample 32/100 (True: 2, Index: 311)...
#   Success! Adv label: 3, L2: 535.41, Queries: 43
# Attacking sample 33/100 (True: 2, Index: 313)...
#   Success! Adv label: 3, L2: 154.28, Queries: 13
# Attacking sample 34/100 (True: 2, Index: 322)...
#   Success! Adv label: 7, L2: 658.71, Queries: 53
# Attacking sample 35/100 (True: 2, Index: 328)...
#   Success! Adv label: 8, L2: 677.26, Queries: 51
# Attacking sample 36/100 (True: 2, Index: 357)...
#   Success! Adv label: 7, L2: 493.12, Queries: 41
# Attacking sample 37/100 (True: 2, Index: 374)...
#   Success! Adv label: 8, L2: 401.55, Queries: 31
# Attacking sample 38/100 (True: 2, Index: 395)...
#   Success! Adv label: 8, L2: 478.10, Queries: 41
# Attacking sample 39/100 (True: 2, Index: 396)...
#   Success! Adv label: 8, L2: 510.17, Queries: 37
# Attacking sample 40/100 (True: 2, Index: 398)...
#   Success! Adv label: 3, L2: 776.07, Queries: 63
# Attacking sample 41/100 (True: 2, Index: 433)...
#   Success! Adv label: 3, L2: 592.82, Queries: 43
# Attacking sample 42/100 (True: 2, Index: 439)...
#   Success! Adv label: 8, L2: 601.19, Queries: 43
# Attacking sample 43/100 (True: 2, Index: 441)...
#   Success! Adv label: 8, L2: 322.47, Queries: 23
# Attacking sample 44/100 (True: 2, Index: 442)...
#   Success! Adv label: 9, L2: 670.46, Queries: 51
# Attacking sample 45/100 (True: 2, Index: 451)...
#   Success! Adv label: 0, L2: 1034.64, Queries: 81
# Attacking sample 46/100 (True: 2, Index: 462)...
#   Success! Adv label: 3, L2: 711.85, Queries: 51
# Attacking sample 47/100 (True: 2, Index: 470)...
#   Success! Adv label: 3, L2: 630.60, Queries: 49
# Attacking sample 48/100 (True: 2, Index: 477)...
#   Success! Adv label: 3, L2: 836.43, Queries: 67
# Attacking sample 49/100 (True: 2, Index: 485)...
#   Success! Adv label: 7, L2: 244.02, Queries: 19
# Attacking sample 50/100 (True: 2, Index: 491)...
#   Success! Adv label: 8, L2: 738.01, Queries: 53
# Attacking sample 51/100 (True: 2, Index: 493)...
#   Success! Adv label: 7, L2: 723.80, Queries: 67
# Attacking sample 52/100 (True: 2, Index: 495)...
#   Success! Adv label: 3, L2: 644.08, Queries: 51
# Attacking sample 53/100 (True: 2, Index: 519)...
#   Success! Adv label: 3, L2: 820.48, Queries: 65
# Attacking sample 54/100 (True: 2, Index: 523)...
#   Success! Adv label: 6, L2: 539.33, Queries: 45
# Attacking sample 55/100 (True: 2, Index: 557)...
#   Success! Adv label: 8, L2: 590.57, Queries: 41
# Attacking sample 56/100 (True: 2, Index: 567)...
#   Success! Adv label: 0, L2: 435.12, Queries: 33
# Attacking sample 57/100 (True: 2, Index: 571)...
#   Success! Adv label: 7, L2: 623.85, Queries: 51
# Attacking sample 58/100 (True: 2, Index: 584)...
#   Success! Adv label: 3, L2: 1023.23, Queries: 79
# Attacking sample 59/100 (True: 2, Index: 591)...
#   Success! Adv label: 8, L2: 889.38, Queries: 73
# Attacking sample 60/100 (True: 2, Index: 592)...
#   Success! Adv label: 8, L2: 760.16, Queries: 65
# Attacking sample 61/100 (True: 2, Index: 610)...
#   Success! Adv label: 8, L2: 1048.33, Queries: 83
# Attacking sample 62/100 (True: 2, Index: 612)...
#   Success! Adv label: 8, L2: 626.64, Queries: 43
# Attacking sample 63/100 (True: 2, Index: 616)...
#   Success! Adv label: 3, L2: 784.58, Queries: 61
# Attacking sample 64/100 (True: 2, Index: 624)...
#   Success! Adv label: 3, L2: 719.21, Queries: 53
# Attacking sample 65/100 (True: 2, Index: 631)...
#   Success! Adv label: 3, L2: 477.73, Queries: 37
# Attacking sample 66/100 (True: 2, Index: 636)...
#   Success! Adv label: 3, L2: 817.79, Queries: 61
# Attacking sample 67/100 (True: 2, Index: 647)...
#   Success! Adv label: 1, L2: 126.60, Queries: 11
# Attacking sample 68/100 (True: 2, Index: 650)...
#   Success! Adv label: 3, L2: 194.12, Queries: 15
# Attacking sample 69/100 (True: 2, Index: 664)...
#   Success! Adv label: 8, L2: 848.98, Queries: 65
# Attacking sample 70/100 (True: 2, Index: 704)...
#   Success! Adv label: 3, L2: 645.26, Queries: 51
# Attacking sample 71/100 (True: 2, Index: 720)...
#   Success! Adv label: 4, L2: 202.98, Queries: 15
# Attacking sample 72/100 (True: 2, Index: 725)...
#   Success! Adv label: 3, L2: 493.58, Queries: 37
# Attacking sample 73/100 (True: 2, Index: 750)...
#   Success! Adv label: 7, L2: 919.79, Queries: 89
# Attacking sample 74/100 (True: 2, Index: 764)...
#   Success! Adv label: 1, L2: 611.96, Queries: 59
# Attacking sample 75/100 (True: 2, Index: 780)...
#   Success! Adv label: 8, L2: 732.29, Queries: 53
# Attacking sample 76/100 (True: 2, Index: 784)...
#   Success! Adv label: 8, L2: 883.22, Queries: 67
# Attacking sample 77/100 (True: 2, Index: 788)...
#   Success! Adv label: 1, L2: 573.15, Queries: 45
# Attacking sample 78/100 (True: 2, Index: 790)...
#   Success! Adv label: 3, L2: 908.49, Queries: 79
# Attacking sample 79/100 (True: 2, Index: 797)...
#   Success! Adv label: 8, L2: 592.82, Queries: 43
# Attacking sample 80/100 (True: 2, Index: 803)...
#   Success! Adv label: 8, L2: 867.30, Queries: 67
# Attacking sample 81/100 (True: 2, Index: 807)...
#   Success! Adv label: 1, L2: 1011.10, Queries: 91
# Attacking sample 82/100 (True: 2, Index: 828)...
#   Success! Adv label: 3, L2: 448.20, Queries: 35
# Attacking sample 83/100 (True: 2, Index: 842)...
#   Success! Adv label: 3, L2: 691.78, Queries: 57
# Attacking sample 84/100 (True: 2, Index: 845)...
#   Success! Adv label: 3, L2: 937.58, Queries: 69
# Attacking sample 85/100 (True: 2, Index: 859)...
#   Success! Adv label: 3, L2: 495.21, Queries: 37
# Attacking sample 86/100 (True: 2, Index: 871)...
#   Success! Adv label: 1, L2: 678.18, Queries: 55
# Attacking sample 87/100 (True: 2, Index: 881)...
#   Success! Adv label: 1, L2: 567.39, Queries: 51
# Attacking sample 88/100 (True: 2, Index: 883)...
#   Success! Adv label: 8, L2: 334.79, Queries: 25
# Attacking sample 89/100 (True: 2, Index: 896)...
#   Success! Adv label: 3, L2: 576.05, Queries: 43
# Attacking sample 90/100 (True: 2, Index: 897)...
#   Success! Adv label: 3, L2: 557.49, Queries: 51
# Attacking sample 92/100 (True: 2, Index: 922)...
#   Success! Adv label: 7, L2: 544.52, Queries: 43
# Attacking sample 93/100 (True: 2, Index: 932)...
#   Success! Adv label: 8, L2: 657.00, Queries: 47
# Attacking sample 94/100 (True: 2, Index: 944)...
#   Success! Adv label: 3, L2: 576.58, Queries: 45
# Attacking sample 95/100 (True: 2, Index: 949)...
#   Success! Adv label: 3, L2: 711.41, Queries: 55
# Attacking sample 96/100 (True: 2, Index: 952)...
#   Failed! Adv label: 2, L2: 1159.11, Queries: 201
# Attacking sample 97/100 (True: 2, Index: 959)...
#   Success! Adv label: 3, L2: 573.57, Queries: 43
# Attacking sample 98/100 (True: 2, Index: 966)...
#   Success! Adv label: 7, L2: 185.62, Queries: 15
# Attacking sample 99/100 (True: 2, Index: 967)...
#   Success! Adv label: 7, L2: 743.47, Queries: 63
# Attacking sample 100/100 (True: 2, Index: 985)...
#   Success! Adv label: 3, L2: 660.41, Queries: 55
# Attacking sample 1/100 (True: 3, Index: 1)...
#   Success! Adv label: 5, L2: 324.27, Queries: 25
# Attacking sample 2/100 (True: 3, Index: 12)...
#   Success! Adv label: 5, L2: 291.79, Queries: 23
# Attacking sample 3/100 (True: 3, Index: 20)...
#   Success! Adv label: 9, L2: 600.65, Queries: 45
# Attacking sample 4/100 (True: 3, Index: 27)...
#   Success! Adv label: 5, L2: 894.96, Queries: 85
# Attacking sample 5/100 (True: 3, Index: 37)...
#   Success! Adv label: 0, L2: 919.71, Queries: 81
# Attacking sample 6/100 (True: 3, Index: 43)...
#   Success! Adv label: 2, L2: 820.19, Queries: 81
# Attacking sample 7/100 (True: 3, Index: 53)...
#   Success! Adv label: 8, L2: 544.87, Queries: 41
# Attacking sample 8/100 (True: 3, Index: 61)...
#   Success! Adv label: 8, L2: 560.47, Queries: 41
# Attacking sample 9/100 (True: 3, Index: 73)...
#   Success! Adv label: 8, L2: 621.89, Queries: 51
# Attacking sample 10/100 (True: 3, Index: 102)...
#   Success! Adv label: 2, L2: 434.42, Queries: 33
# Attacking sample 11/100 (True: 3, Index: 108)...
#   Success! Adv label: 2, L2: 91.72, Queries: 7
# Attacking sample 12/100 (True: 3, Index: 109)...
#   Success! Adv label: 8, L2: 493.49, Queries: 35
# Attacking sample 13/100 (True: 3, Index: 117)...
#   Success! Adv label: 5, L2: 865.13, Queries: 83
# Attacking sample 14/100 (True: 3, Index: 131)...
#   Success! Adv label: 8, L2: 155.13, Queries: 11
# Attacking sample 15/100 (True: 3, Index: 159)...
#   Success! Adv label: 2, L2: 850.02, Queries: 73
# Attacking sample 16/100 (True: 3, Index: 162)...
#   Success! Adv label: 2, L2: 1102.01, Queries: 169
# Attacking sample 17/100 (True: 3, Index: 166)...
#   Success! Adv label: 7, L2: 745.51, Queries: 73
# Attacking sample 18/100 (True: 3, Index: 177)...
#   Success! Adv label: 8, L2: 539.35, Queries: 39
# Attacking sample 19/100 (True: 3, Index: 181)...
#   Success! Adv label: 5, L2: 390.66, Queries: 31
# Attacking sample 20/100 (True: 3, Index: 187)...
#   Success! Adv label: 8, L2: 625.83, Queries: 45
# Attacking sample 21/100 (True: 3, Index: 196)...
#   Success! Adv label: 2, L2: 491.02, Queries: 35
# Attacking sample 22/100 (True: 3, Index: 204)...
#   Success! Adv label: 5, L2: 807.47, Queries: 69
# Attacking sample 23/100 (True: 3, Index: 227)...
#   Success! Adv label: 7, L2: 1105.19, Queries: 195
# Attacking sample 24/100 (True: 3, Index: 231)...
#   Success! Adv label: 5, L2: 584.40, Queries: 45
# Attacking sample 25/100 (True: 3, Index: 237)...
#   Success! Adv label: 5, L2: 904.33, Queries: 79
# Attacking sample 26/100 (True: 3, Index: 244)...
#   Success! Adv label: 7, L2: 797.88, Queries: 73
# Attacking sample 27/100 (True: 3, Index: 257)...
#   Success! Adv label: 8, L2: 551.13, Queries: 41
# Attacking sample 28/100 (True: 3, Index: 259)...
#   Success! Adv label: 5, L2: 769.36, Queries: 69
# Attacking sample 29/100 (True: 3, Index: 265)...
#   Success! Adv label: 5, L2: 471.19, Queries: 37
# Attacking sample 30/100 (True: 3, Index: 270)...
#   Success! Adv label: 5, L2: 244.54, Queries: 19
# Attacking sample 31/100 (True: 3, Index: 288)...
#   Success! Adv label: 8, L2: 1007.83, Queries: 73
# Attacking sample 32/100 (True: 3, Index: 308)...
#   Success! Adv label: 8, L2: 498.87, Queries: 37
# Attacking sample 33/100 (True: 3, Index: 309)...
#   Success! Adv label: 8, L2: 548.23, Queries: 41
# Attacking sample 34/100 (True: 3, Index: 327)...
#   Success! Adv label: 1, L2: 329.99, Queries: 29
# Attacking sample 35/100 (True: 3, Index: 331)...
#   Success! Adv label: 8, L2: 813.55, Queries: 69
# Attacking sample 36/100 (True: 3, Index: 340)...
#   Success! Adv label: 9, L2: 842.38, Queries: 71
# Attacking sample 37/100 (True: 3, Index: 341)...
#   Success! Adv label: 5, L2: 533.81, Queries: 43
# Attacking sample 38/100 (True: 3, Index: 342)...
#   Success! Adv label: 5, L2: 422.12, Queries: 33
# Attacking sample 39/100 (True: 3, Index: 362)...
#   Success! Adv label: 2, L2: 520.34, Queries: 41
# Attacking sample 40/100 (True: 3, Index: 383)...
#   Success! Adv label: 2, L2: 543.80, Queries: 43
# Attacking sample 41/100 (True: 3, Index: 394)...
#   Success! Adv label: 8, L2: 478.10, Queries: 35
# Attacking sample 42/100 (True: 3, Index: 406)...
#   Success! Adv label: 2, L2: 1098.97, Queries: 157
# Attacking sample 43/100 (True: 3, Index: 409)...
#   Success! Adv label: 2, L2: 820.58, Queries: 69
# Attacking sample 44/100 (True: 3, Index: 445)...
#   Success! Adv label: 2, L2: 389.30, Queries: 29
# Attacking sample 45/100 (True: 3, Index: 456)...
#   Success! Adv label: 8, L2: 519.89, Queries: 37
# Attacking sample 46/100 (True: 3, Index: 459)...
#   Success! Adv label: 4, L2: 894.08, Queries: 89
# Attacking sample 47/100 (True: 3, Index: 461)...
#   Success! Adv label: 5, L2: 1046.17, Queries: 99
# Attacking sample 48/100 (True: 3, Index: 471)...
#   Success! Adv label: 8, L2: 827.37, Queries: 61
# Attacking sample 49/100 (True: 3, Index: 474)...
#   Success! Adv label: 5, L2: 459.62, Queries: 37
# Attacking sample 50/100 (True: 3, Index: 481)...
#   Success! Adv label: 5, L2: 703.34, Queries: 61
# Attacking sample 51/100 (True: 3, Index: 504)...
#   Success! Adv label: 5, L2: 550.26, Queries: 43
# Attacking sample 52/100 (True: 3, Index: 510)...
#   Success! Adv label: 5, L2: 296.06, Queries: 23
# Attacking sample 53/100 (True: 3, Index: 512)...
#   Failed! Adv label: 3, L2: 1082.16, Queries: 201
# Attacking sample 54/100 (True: 3, Index: 524)...
#   Success! Adv label: 8, L2: 604.68, Queries: 43
# Attacking sample 55/100 (True: 3, Index: 549)...
#   Success! Adv label: 2, L2: 474.73, Queries: 41
# Attacking sample 56/100 (True: 3, Index: 556)...
#   Success! Adv label: 9, L2: 504.96, Queries: 41
# Attacking sample 57/100 (True: 3, Index: 564)...
#   Success! Adv label: 8, L2: 455.09, Queries: 33
# Attacking sample 58/100 (True: 3, Index: 586)...
#   Failed! Adv label: 3, L2: 1159.10, Queries: 201
# Attacking sample 59/100 (True: 3, Index: 589)...
#   Success! Adv label: 5, L2: 1073.83, Queries: 91
# Attacking sample 60/100 (True: 3, Index: 609)...
#   Success! Adv label: 9, L2: 617.78, Queries: 49
# Attacking sample 61/100 (True: 3, Index: 613)...
#   Success! Adv label: 8, L2: 715.24, Queries: 51
# Attacking sample 62/100 (True: 3, Index: 623)...
#   Success! Adv label: 9, L2: 370.06, Queries: 27
# Attacking sample 63/100 (True: 3, Index: 639)...
#   Success! Adv label: 5, L2: 518.93, Queries: 41
# Attacking sample 64/100 (True: 3, Index: 648)...
#   Success! Adv label: 8, L2: 396.47, Queries: 29
# Attacking sample 65/100 (True: 3, Index: 651)...
#   Success! Adv label: 8, L2: 388.55, Queries: 29
# Attacking sample 66/100 (True: 3, Index: 659)...
#   Success! Adv label: 9, L2: 611.23, Queries: 51
# Attacking sample 67/100 (True: 3, Index: 661)...
#   Success! Adv label: 5, L2: 875.49, Queries: 73
# Attacking sample 68/100 (True: 3, Index: 667)...
#   Failed! Adv label: 3, L2: 1097.21, Queries: 201
# Attacking sample 69/100 (True: 3, Index: 678)...
#   Success! Adv label: 2, L2: 796.22, Queries: 87
# Attacking sample 70/100 (True: 3, Index: 690)...
#   Success! Adv label: 8, L2: 842.88, Queries: 59
# Attacking sample 71/100 (True: 3, Index: 693)...
#   Failed! Adv label: 3, L2: 1073.87, Queries: 201
# Attacking sample 72/100 (True: 3, Index: 694)...
#   Success! Adv label: 9, L2: 714.02, Queries: 53
# Attacking sample 73/100 (True: 3, Index: 695)...
#   Success! Adv label: 2, L2: 255.71, Queries: 19
# Attacking sample 74/100 (True: 3, Index: 702)...
#   Success! Adv label: 8, L2: 384.70, Queries: 27
# Attacking sample 75/100 (True: 3, Index: 718)...
#   Success! Adv label: 2, L2: 981.68, Queries: 83
# Attacking sample 76/100 (True: 3, Index: 749)...
#   Success! Adv label: 9, L2: 738.03, Queries: 63
# Attacking sample 77/100 (True: 3, Index: 769)...
#   Success! Adv label: 9, L2: 760.59, Queries: 55
# Attacking sample 79/100 (True: 3, Index: 779)...
#   Success! Adv label: 8, L2: 426.57, Queries: 33
# Attacking sample 80/100 (True: 3, Index: 800)...
#   Success! Adv label: 8, L2: 871.84, Queries: 61
# Attacking sample 81/100 (True: 3, Index: 816)...
#   Success! Adv label: 5, L2: 238.24, Queries: 19
# Attacking sample 82/100 (True: 3, Index: 829)...
#   Success! Adv label: 2, L2: 497.82, Queries: 39
# Attacking sample 83/100 (True: 3, Index: 833)...
#   Success! Adv label: 7, L2: 902.00, Queries: 93
# Attacking sample 84/100 (True: 3, Index: 839)...
#   Success! Adv label: 8, L2: 659.57, Queries: 51
# Attacking sample 85/100 (True: 3, Index: 854)...
#   Success! Adv label: 5, L2: 292.72, Queries: 23
# Attacking sample 86/100 (True: 3, Index: 856)...
#   Success! Adv label: 2, L2: 404.47, Queries: 33
# Attacking sample 87/100 (True: 3, Index: 858)...
#   Success! Adv label: 5, L2: 104.20, Queries: 9
# Attacking sample 89/100 (True: 3, Index: 886)...
#   Success! Adv label: 8, L2: 803.47, Queries: 61
# Attacking sample 90/100 (True: 3, Index: 900)...
#   Success! Adv label: 8, L2: 664.10, Queries: 49
# Attacking sample 91/100 (True: 3, Index: 916)...
#   Success! Adv label: 5, L2: 366.40, Queries: 31
# Attacking sample 92/100 (True: 3, Index: 921)...
#   Success! Adv label: 2, L2: 450.58, Queries: 37
# Attacking sample 93/100 (True: 3, Index: 937)...
#   Success! Adv label: 9, L2: 662.64, Queries: 51
# Attacking sample 94/100 (True: 3, Index: 938)...
#   Success! Adv label: 8, L2: 644.03, Queries: 43
# Attacking sample 95/100 (True: 3, Index: 939)...
#   Success! Adv label: 8, L2: 311.83, Queries: 23
# Attacking sample 96/100 (True: 3, Index: 942)...
#   Success! Adv label: 5, L2: 858.39, Queries: 77
# Attacking sample 97/100 (True: 3, Index: 951)...
#   Success! Adv label: 8, L2: 585.92, Queries: 45
# Attacking sample 98/100 (True: 3, Index: 953)...
#   Success! Adv label: 7, L2: 1052.93, Queries: 107
# Attacking sample 99/100 (True: 3, Index: 975)...
#   Success! Adv label: 5, L2: 1098.85, Queries: 123
# Attacking sample 1/100 (True: 4, Index: 16)...
#   Success! Adv label: 9, L2: 307.50, Queries: 23
# Attacking sample 2/100 (True: 4, Index: 17)...
#   Success! Adv label: 6, L2: 400.94, Queries: 31
# Attacking sample 3/100 (True: 4, Index: 30)...
#   Success! Adv label: 8, L2: 713.69, Queries: 53
# Attacking sample 4/100 (True: 4, Index: 33)...
#   Success! Adv label: 9, L2: 498.15, Queries: 39
# Attacking sample 5/100 (True: 4, Index: 45)...
#   Success! Adv label: 8, L2: 120.66, Queries: 9
# Attacking sample 6/100 (True: 4, Index: 48)...
#   Success! Adv label: 9, L2: 697.12, Queries: 53
# Attacking sample 7/100 (True: 4, Index: 58)...
#   Success! Adv label: 9, L2: 667.71, Queries: 49
# Attacking sample 8/100 (True: 4, Index: 66)...
#   Success! Adv label: 6, L2: 544.07, Queries: 45
# Attacking sample 9/100 (True: 4, Index: 89)...
#   Success! Adv label: 9, L2: 317.21, Queries: 23
# Attacking sample 10/100 (True: 4, Index: 92)...
#   Success! Adv label: 6, L2: 790.70, Queries: 61
# Attacking sample 11/100 (True: 4, Index: 113)...
#   Success! Adv label: 9, L2: 613.00, Queries: 45
# Attacking sample 12/100 (True: 4, Index: 116)...
#   Success! Adv label: 9, L2: 599.45, Queries: 43
# Attacking sample 13/100 (True: 4, Index: 126)...
#   Success! Adv label: 9, L2: 419.58, Queries: 29
# Attacking sample 14/100 (True: 4, Index: 130)...
#   Success! Adv label: 9, L2: 319.03, Queries: 23
# Attacking sample 15/100 (True: 4, Index: 139)...
#   Success! Adv label: 9, L2: 513.88, Queries: 37
# Attacking sample 16/100 (True: 4, Index: 149)...
#   Success! Adv label: 2, L2: 926.91, Queries: 73
# Attacking sample 17/100 (True: 4, Index: 153)...
#   Success! Adv label: 8, L2: 472.22, Queries: 35
# Attacking sample 18/100 (True: 4, Index: 154)...
#   Success! Adv label: 7, L2: 856.99, Queries: 65
# Attacking sample 19/100 (True: 4, Index: 163)...
#   Success! Adv label: 9, L2: 509.80, Queries: 37
# Attacking sample 20/100 (True: 4, Index: 167)...
#   Success! Adv label: 9, L2: 600.46, Queries: 43
# Attacking sample 21/100 (True: 4, Index: 183)...
#   Success! Adv label: 9, L2: 382.22, Queries: 29
# Attacking sample 22/100 (True: 4, Index: 184)...
#   Success! Adv label: 9, L2: 548.21, Queries: 41
# Attacking sample 23/100 (True: 4, Index: 192)...
#   Success! Adv label: 9, L2: 256.86, Queries: 19
# Attacking sample 24/100 (True: 4, Index: 194)...
#   Success! Adv label: 9, L2: 499.54, Queries: 39
# Attacking sample 25/100 (True: 4, Index: 233)...
#   Success! Adv label: 9, L2: 632.10, Queries: 49
# Attacking sample 26/100 (True: 4, Index: 240)...
#   Success! Adv label: 8, L2: 535.46, Queries: 37
# Attacking sample 27/100 (True: 4, Index: 263)...
#   Success! Adv label: 9, L2: 229.12, Queries: 17
# Attacking sample 28/100 (True: 4, Index: 269)...
#   Success! Adv label: 9, L2: 313.80, Queries: 23
# Attacking sample 29/100 (True: 4, Index: 280)...
#   Success! Adv label: 9, L2: 350.37, Queries: 25
# Attacking sample 30/100 (True: 4, Index: 290)...
#   Success! Adv label: 9, L2: 561.14, Queries: 39
# Attacking sample 31/100 (True: 4, Index: 297)...
#   Success! Adv label: 6, L2: 398.17, Queries: 31
# Attacking sample 32/100 (True: 4, Index: 299)...
#   Success! Adv label: 9, L2: 350.80, Queries: 25
# Attacking sample 33/100 (True: 4, Index: 310)...
#   Success! Adv label: 9, L2: 308.29, Queries: 23
# Attacking sample 34/100 (True: 4, Index: 316)...
#   Success! Adv label: 9, L2: 441.32, Queries: 31
# Attacking sample 35/100 (True: 4, Index: 320)...
#   Success! Adv label: 9, L2: 441.01, Queries: 33
# Attacking sample 36/100 (True: 4, Index: 324)...
#   Success! Adv label: 9, L2: 455.96, Queries: 33
# Attacking sample 37/100 (True: 4, Index: 326)...
#   Success! Adv label: 9, L2: 485.90, Queries: 37
# Attacking sample 38/100 (True: 4, Index: 332)...
#   Success! Adv label: 9, L2: 34.45, Queries: 3
# Attacking sample 39/100 (True: 4, Index: 335)...
#   Success! Adv label: 9, L2: 620.13, Queries: 45
# Attacking sample 40/100 (True: 4, Index: 344)...
#   Success! Adv label: 7, L2: 500.35, Queries: 39
# Attacking sample 42/100 (True: 4, Index: 359)...
#   Success! Adv label: 9, L2: 396.07, Queries: 29
# Attacking sample 43/100 (True: 4, Index: 376)...
#   Success! Adv label: 9, L2: 525.32, Queries: 39
# Attacking sample 44/100 (True: 4, Index: 393)...
#   Success! Adv label: 9, L2: 496.69, Queries: 35
# Attacking sample 45/100 (True: 4, Index: 401)...
#   Success! Adv label: 2, L2: 665.39, Queries: 53
# Attacking sample 46/100 (True: 4, Index: 402)...
#   Success! Adv label: 9, L2: 443.09, Queries: 33
# Attacking sample 47/100 (True: 4, Index: 422)...
#   Success! Adv label: 9, L2: 360.63, Queries: 25
# Attacking sample 48/100 (True: 4, Index: 423)...
#   Success! Adv label: 9, L2: 163.19, Queries: 13
# Attacking sample 49/100 (True: 4, Index: 427)...
#   Success! Adv label: 1, L2: 489.45, Queries: 41
# Attacking sample 50/100 (True: 4, Index: 432)...
#   Success! Adv label: 9, L2: 393.98, Queries: 29
# Attacking sample 51/100 (True: 4, Index: 434)...
#   Success! Adv label: 9, L2: 291.06, Queries: 21
# Attacking sample 52/100 (True: 4, Index: 454)...
#   Success! Adv label: 9, L2: 542.72, Queries: 41
# Attacking sample 53/100 (True: 4, Index: 467)...
#   Success! Adv label: 8, L2: 345.03, Queries: 25
# Attacking sample 54/100 (True: 4, Index: 501)...
#   Success! Adv label: 9, L2: 256.54, Queries: 19
# Attacking sample 55/100 (True: 4, Index: 515)...
#   Success! Adv label: 9, L2: 356.58, Queries: 25
# Attacking sample 56/100 (True: 4, Index: 540)...
#   Success! Adv label: 9, L2: 575.81, Queries: 43
# Attacking sample 57/100 (True: 4, Index: 544)...
#   Success! Adv label: 0, L2: 428.41, Queries: 33
# Attacking sample 58/100 (True: 4, Index: 545)...
#   Success! Adv label: 9, L2: 356.33, Queries: 27
# Attacking sample 59/100 (True: 4, Index: 547)...
#   Success! Adv label: 8, L2: 743.12, Queries: 61
# Attacking sample 60/100 (True: 4, Index: 566)...
#   Success! Adv label: 9, L2: 376.71, Queries: 27
# Attacking sample 61/100 (True: 4, Index: 590)...
#   Success! Adv label: 0, L2: 440.20, Queries: 33
# Attacking sample 62/100 (True: 4, Index: 593)...
#   Success! Adv label: 9, L2: 345.49, Queries: 25
# Attacking sample 63/100 (True: 4, Index: 599)...
#   Success! Adv label: 9, L2: 602.61, Queries: 49
# Attacking sample 64/100 (True: 4, Index: 602)...
#   Success! Adv label: 9, L2: 475.50, Queries: 35
# Attacking sample 65/100 (True: 4, Index: 607)...
#   Success! Adv label: 7, L2: 571.81, Queries: 51
# Attacking sample 66/100 (True: 4, Index: 611)...
#   Success! Adv label: 9, L2: 586.13, Queries: 43
# Attacking sample 67/100 (True: 4, Index: 617)...
#   Success! Adv label: 9, L2: 497.61, Queries: 35
# Attacking sample 68/100 (True: 4, Index: 657)...
#   Success! Adv label: 9, L2: 312.98, Queries: 25
# Attacking sample 69/100 (True: 4, Index: 680)...
#   Success! Adv label: 9, L2: 370.97, Queries: 27
# Attacking sample 70/100 (True: 4, Index: 684)...
#   Success! Adv label: 9, L2: 590.04, Queries: 47
# Attacking sample 71/100 (True: 4, Index: 687)...
#   Success! Adv label: 9, L2: 524.97, Queries: 37
# Attacking sample 72/100 (True: 4, Index: 692)...
#   Success! Adv label: 9, L2: 663.02, Queries: 49
# Attacking sample 73/100 (True: 4, Index: 696)...
#   Success! Adv label: 9, L2: 167.46, Queries: 13
# Attacking sample 74/100 (True: 4, Index: 697)...
#   Success! Adv label: 9, L2: 708.62, Queries: 51
# Attacking sample 75/100 (True: 4, Index: 708)...
#   Success! Adv label: 9, L2: 571.38, Queries: 41
# Attacking sample 76/100 (True: 4, Index: 717)...
#   Success! Adv label: 9, L2: 333.77, Queries: 25
# Attacking sample 77/100 (True: 4, Index: 746)...
#   Success! Adv label: 9, L2: 441.94, Queries: 33
# Attacking sample 78/100 (True: 4, Index: 752)...
#   Success! Adv label: 9, L2: 913.70, Queries: 67
# Attacking sample 79/100 (True: 4, Index: 755)...
#   Success! Adv label: 2, L2: 830.86, Queries: 75
# Attacking sample 80/100 (True: 4, Index: 757)...
#   Success! Adv label: 9, L2: 404.01, Queries: 29
# Attacking sample 81/100 (True: 4, Index: 766)...
#   Success! Adv label: 7, L2: 501.33, Queries: 41
# Attacking sample 82/100 (True: 4, Index: 771)...
#   Success! Adv label: 9, L2: 313.99, Queries: 23
# Attacking sample 83/100 (True: 4, Index: 776)...
#   Success! Adv label: 2, L2: 562.73, Queries: 43
# Attacking sample 84/100 (True: 4, Index: 777)...
#   Success! Adv label: 1, L2: 830.33, Queries: 75
# Attacking sample 85/100 (True: 4, Index: 786)...
#   Success! Adv label: 9, L2: 176.11, Queries: 13
# Attacking sample 86/100 (True: 4, Index: 811)...
#   Success! Adv label: 9, L2: 262.82, Queries: 19
# Attacking sample 87/100 (True: 4, Index: 815)...
#   Success! Adv label: 6, L2: 637.71, Queries: 49
# Attacking sample 88/100 (True: 4, Index: 817)...
#   Success! Adv label: 8, L2: 869.77, Queries: 75
# Attacking sample 89/100 (True: 4, Index: 840)...
#   Success! Adv label: 6, L2: 646.37, Queries: 49
# Attacking sample 91/100 (True: 4, Index: 849)...
#   Success! Adv label: 8, L2: 673.80, Queries: 49
# Attacking sample 92/100 (True: 4, Index: 857)...
#   Success! Adv label: 9, L2: 530.54, Queries: 39
# Attacking sample 93/100 (True: 4, Index: 872)...
#   Success! Adv label: 9, L2: 669.88, Queries: 53
# Attacking sample 94/100 (True: 4, Index: 877)...
#   Success! Adv label: 9, L2: 399.10, Queries: 31
# Attacking sample 95/100 (True: 4, Index: 894)...
#   Success! Adv label: 9, L2: 254.32, Queries: 19
# Attacking sample 96/100 (True: 4, Index: 902)...
#   Success! Adv label: 9, L2: 401.81, Queries: 29
# Attacking sample 97/100 (True: 4, Index: 911)...
#   Success! Adv label: 9, L2: 552.36, Queries: 43
# ...
#   Success! Adv label: 3, L2: 529.73, Queries: 43
# Attacking sample 40/100 (True: 8, Index: 505)...
#   Success! Adv label: 2, L2: 718.23, Queries: 59
# Attacking sample 41/100 (True: 8, Index: 509)...
#   Success! Adv label: 3, L2: 658.57, Queries: 61
# Attacking sample 42/100 (True: 8, Index: 525)...
#   Success! Adv label: 3, L2: 572.92, Queries: 49
# Attacking sample 43/100 (True: 8, Index: 528)...
#   Success! Adv label: 3, L2: 727.61, Queries: 65
# Attacking sample 44/100 (True: 8, Index: 541)...
#   Success! Adv label: 3, L2: 778.81, Queries: 63
# Attacking sample 45/100 (True: 8, Index: 543)...
#   Success! Adv label: 6, L2: 361.04, Queries: 29
# Attacking sample 46/100 (True: 8, Index: 550)...
#   Success! Adv label: 5, L2: 514.41, Queries: 43
# Attacking sample 47/100 (True: 8, Index: 558)...
#   Success! Adv label: 2, L2: 689.12, Queries: 55
# Attacking sample 48/100 (True: 8, Index: 575)...
#   Success! Adv label: 9, L2: 453.24, Queries: 37
# Attacking sample 49/100 (True: 8, Index: 594)...
#   Success! Adv label: 2, L2: 383.27, Queries: 33
# Attacking sample 50/100 (True: 8, Index: 600)...
#   Success! Adv label: 3, L2: 1001.42, Queries: 81
# Attacking sample 51/100 (True: 8, Index: 605)...
#   Success! Adv label: 2, L2: 625.66, Queries: 51
# Attacking sample 52/100 (True: 8, Index: 619)...
#   Success! Adv label: 3, L2: 536.55, Queries: 45
# Attacking sample 53/100 (True: 8, Index: 625)...
#   Success! Adv label: 3, L2: 729.41, Queries: 59
# Attacking sample 54/100 (True: 8, Index: 629)...
#   Success! Adv label: 2, L2: 518.00, Queries: 41
# Attacking sample 55/100 (True: 8, Index: 645)...
#   Success! Adv label: 9, L2: 983.53, Queries: 83
# Attacking sample 56/100 (True: 8, Index: 652)...
#   Success! Adv label: 2, L2: 588.35, Queries: 51
# Attacking sample 57/100 (True: 8, Index: 672)...
#   Success! Adv label: 3, L2: 591.27, Queries: 53
# Attacking sample 58/100 (True: 8, Index: 683)...
#   Success! Adv label: 3, L2: 384.86, Queries: 35
# Attacking sample 59/100 (True: 8, Index: 701)...
#   Success! Adv label: 3, L2: 716.85, Queries: 65
# Attacking sample 60/100 (True: 8, Index: 714)...
#   Success! Adv label: 3, L2: 644.33, Queries: 59
# Attacking sample 61/100 (True: 8, Index: 721)...
#   Success! Adv label: 3, L2: 487.98, Queries: 41
# Attacking sample 62/100 (True: 8, Index: 730)...
#   Success! Adv label: 2, L2: 607.23, Queries: 47
# Attacking sample 63/100 (True: 8, Index: 731)...
#   Success! Adv label: 9, L2: 1256.71, Queries: 147
# Attacking sample 64/100 (True: 8, Index: 738)...
#   Success! Adv label: 3, L2: 833.60, Queries: 75
# Attacking sample 65/100 (True: 8, Index: 791)...
#   Success! Adv label: 5, L2: 688.73, Queries: 59
# Attacking sample 66/100 (True: 8, Index: 832)...
#   Success! Adv label: 6, L2: 573.21, Queries: 49
# Attacking sample 67/100 (True: 8, Index: 838)...
#   Success! Adv label: 5, L2: 544.42, Queries: 47
# Attacking sample 68/100 (True: 8, Index: 860)...
#   Success! Adv label: 3, L2: 722.73, Queries: 65
# Attacking sample 69/100 (True: 8, Index: 864)...
#   Success! Adv label: 9, L2: 750.16, Queries: 65
# Attacking sample 70/100 (True: 8, Index: 889)...
#   Success! Adv label: 3, L2: 598.18, Queries: 51
# Attacking sample 71/100 (True: 8, Index: 905)...
#   Success! Adv label: 9, L2: 780.64, Queries: 69
# Attacking sample 73/100 (True: 8, Index: 919)...
#   Success! Adv label: 3, L2: 575.66, Queries: 49
# Attacking sample 74/100 (True: 8, Index: 923)...
#   Success! Adv label: 3, L2: 696.44, Queries: 61
# Attacking sample 75/100 (True: 8, Index: 926)...
#   Success! Adv label: 5, L2: 659.13, Queries: 55
# Attacking sample 76/100 (True: 8, Index: 933)...
#   Success! Adv label: 3, L2: 626.70, Queries: 53
# Attacking sample 78/100 (True: 8, Index: 971)...
#   Success! Adv label: 2, L2: 754.73, Queries: 63
# Attacking sample 79/100 (True: 8, Index: 1014)...
#   Success! Adv label: 3, L2: 590.65, Queries: 53
# Attacking sample 80/100 (True: 8, Index: 1034)...
#   Success! Adv label: 6, L2: 723.81, Queries: 65
# Attacking sample 81/100 (True: 8, Index: 1053)...
#   Success! Adv label: 6, L2: 608.56, Queries: 51
# Attacking sample 82/100 (True: 8, Index: 1057)...
#   Success! Adv label: 6, L2: 458.99, Queries: 33
# Attacking sample 83/100 (True: 8, Index: 1061)...
#   Success! Adv label: 1, L2: 800.50, Queries: 79
# Attacking sample 84/100 (True: 8, Index: 1062)...
#   Success! Adv label: 3, L2: 636.20, Queries: 57
# Attacking sample 85/100 (True: 8, Index: 1063)...
#   Success! Adv label: 3, L2: 659.03, Queries: 55
# Attacking sample 86/100 (True: 8, Index: 1078)...
#   Success! Adv label: 9, L2: 360.05, Queries: 27
# Attacking sample 87/100 (True: 8, Index: 1088)...
#   Success! Adv label: 2, L2: 715.11, Queries: 59
# Attacking sample 88/100 (True: 8, Index: 1100)...
#   Success! Adv label: 0, L2: 1070.47, Queries: 91
# Attacking sample 89/100 (True: 8, Index: 1106)...
#   Success! Adv label: 2, L2: 1015.81, Queries: 87
# Attacking sample 90/100 (True: 8, Index: 1120)...
#   Success! Adv label: 3, L2: 566.85, Queries: 49
# Attacking sample 91/100 (True: 8, Index: 1132)...
#   Success! Adv label: 2, L2: 603.52, Queries: 49
# Attacking sample 92/100 (True: 8, Index: 1134)...
#   Success! Adv label: 6, L2: 1052.99, Queries: 95
# Attacking sample 93/100 (True: 8, Index: 1140)...
#   Success! Adv label: 5, L2: 323.26, Queries: 27
# Attacking sample 94/100 (True: 8, Index: 1150)...
#   Success! Adv label: 9, L2: 583.54, Queries: 47
# Attacking sample 95/100 (True: 8, Index: 1165)...
#   Success! Adv label: 3, L2: 791.86, Queries: 67
# Attacking sample 96/100 (True: 8, Index: 1179)...
#   Success! Adv label: 3, L2: 601.09, Queries: 51
# Attacking sample 97/100 (True: 8, Index: 1182)...
#   Success! Adv label: 9, L2: 546.83, Queries: 45
# Attacking sample 98/100 (True: 8, Index: 1186)...
#   Success! Adv label: 2, L2: 753.93, Queries: 59
# Attacking sample 99/100 (True: 8, Index: 1189)...
#   Success! Adv label: 3, L2: 244.16, Queries: 21
# Attacking sample 100/100 (True: 8, Index: 1207)...
#   Success! Adv label: 9, L2: 664.10, Queries: 53
# Attacking sample 1/100 (True: 9, Index: 6)...
#   Success! Adv label: 7, L2: 330.02, Queries: 27
# Attacking sample 2/100 (True: 9, Index: 38)...
#   Success! Adv label: 7, L2: 86.47, Queries: 7
# Attacking sample 3/100 (True: 9, Index: 55)...
#   Success! Adv label: 0, L2: 141.49, Queries: 11
# Attacking sample 4/100 (True: 9, Index: 56)...
#   Success! Adv label: 4, L2: 412.11, Queries: 33
# Attacking sample 5/100 (True: 9, Index: 91)...
#   Success! Adv label: 3, L2: 272.29, Queries: 21
# Attacking sample 6/100 (True: 9, Index: 99)...
#   Success! Adv label: 7, L2: 446.72, Queries: 37
# Attacking sample 7/100 (True: 9, Index: 101)...
#   Success! Adv label: 5, L2: 610.51, Queries: 51
# Attacking sample 8/100 (True: 9, Index: 114)...
#   Success! Adv label: 8, L2: 665.60, Queries: 49
# Attacking sample 9/100 (True: 9, Index: 133)...
#   Success! Adv label: 8, L2: 625.57, Queries: 45
# Attacking sample 10/100 (True: 9, Index: 171)...
#   Success! Adv label: 8, L2: 95.05, Queries: 7
# Attacking sample 11/100 (True: 9, Index: 179)...
#   Success! Adv label: 7, L2: 606.49, Queries: 53
# Attacking sample 12/100 (True: 9, Index: 195)...
#   Success! Adv label: 4, L2: 194.80, Queries: 15
# Attacking sample 13/100 (True: 9, Index: 214)...
#   Success! Adv label: 4, L2: 488.40, Queries: 41
# Attacking sample 14/100 (True: 9, Index: 218)...
#   Success! Adv label: 4, L2: 372.36, Queries: 31
# Attacking sample 15/100 (True: 9, Index: 222)...
#   Success! Adv label: 8, L2: 352.17, Queries: 27
# Attacking sample 16/100 (True: 9, Index: 224)...
#   Success! Adv label: 6, L2: 458.15, Queries: 35
# Attacking sample 17/100 (True: 9, Index: 238)...
#   Success! Adv label: 4, L2: 415.19, Queries: 31
# Attacking sample 18/100 (True: 9, Index: 243)...
#   Success! Adv label: 8, L2: 700.88, Queries: 55
# Attacking sample 19/100 (True: 9, Index: 245)...
#   Success! Adv label: 4, L2: 513.49, Queries: 43
# Attacking sample 20/100 (True: 9, Index: 246)...
#   Success! Adv label: 8, L2: 608.11, Queries: 43
# Attacking sample 21/100 (True: 9, Index: 251)...
#   Success! Adv label: 7, L2: 253.44, Queries: 21
# Attacking sample 22/100 (True: 9, Index: 303)...
#   Success! Adv label: 4, L2: 289.33, Queries: 23
# Attacking sample 23/100 (True: 9, Index: 305)...
#   Success! Adv label: 8, L2: 256.33, Queries: 19
# Attacking sample 24/100 (True: 9, Index: 307)...
#   Success! Adv label: 4, L2: 540.04, Queries: 47
# Attacking sample 25/100 (True: 9, Index: 315)...
#   Success! Adv label: 8, L2: 690.74, Queries: 51
# Attacking sample 26/100 (True: 9, Index: 354)...
#   Success! Adv label: 4, L2: 529.88, Queries: 43
# Attacking sample 27/100 (True: 9, Index: 364)...
#   Success! Adv label: 8, L2: 693.99, Queries: 55
# Attacking sample 28/100 (True: 9, Index: 389)...
#   Success! Adv label: 4, L2: 324.05, Queries: 25
# Attacking sample 29/100 (True: 9, Index: 407)...
#   Success! Adv label: 8, L2: 230.90, Queries: 17
# Attacking sample 30/100 (True: 9, Index: 411)...
#   Success! Adv label: 4, L2: 204.82, Queries: 15
# Attacking sample 31/100 (True: 9, Index: 417)...
#   Success! Adv label: 7, L2: 373.83, Queries: 35
# Attacking sample 32/100 (True: 9, Index: 421)...
#   Success! Adv label: 4, L2: 375.82, Queries: 29
# Attacking sample 33/100 (True: 9, Index: 438)...
#   Success! Adv label: 4, L2: 424.68, Queries: 33
# Attacking sample 34/100 (True: 9, Index: 443)...
#   Success! Adv label: 3, L2: 581.46, Queries: 47
# Attacking sample 35/100 (True: 9, Index: 444)...
#   Success! Adv label: 4, L2: 304.48, Queries: 25
# Attacking sample 36/100 (True: 9, Index: 446)...
#   Success! Adv label: 7, L2: 526.24, Queries: 47
# Attacking sample 37/100 (True: 9, Index: 455)...
#   Success! Adv label: 7, L2: 294.00, Queries: 25
# Attacking sample 38/100 (True: 9, Index: 469)...
#   Success! Adv label: 4, L2: 726.72, Queries: 59
# Attacking sample 39/100 (True: 9, Index: 472)...
#   Success! Adv label: 3, L2: 688.28, Queries: 53
# Attacking sample 40/100 (True: 9, Index: 473)...
#   Success! Adv label: 4, L2: 622.48, Queries: 47
# Attacking sample 41/100 (True: 9, Index: 482)...
#   Success! Adv label: 4, L2: 433.97, Queries: 33
# Attacking sample 42/100 (True: 9, Index: 490)...
#   Success! Adv label: 8, L2: 777.29, Queries: 59
# Attacking sample 43/100 (True: 9, Index: 496)...
#   Success! Adv label: 4, L2: 377.54, Queries: 31
# Attacking sample 44/100 (True: 9, Index: 507)...
#   Success! Adv label: 8, L2: 408.49, Queries: 29
# Attacking sample 45/100 (True: 9, Index: 508)...
#   Success! Adv label: 7, L2: 463.09, Queries: 37
# Attacking sample 46/100 (True: 9, Index: 514)...
#   Success! Adv label: 4, L2: 174.17, Queries: 13
# Attacking sample 47/100 (True: 9, Index: 522)...
#   Success! Adv label: 4, L2: 57.04, Queries: 5
# Attacking sample 48/100 (True: 9, Index: 535)...
#   Success! Adv label: 4, L2: 424.74, Queries: 35
# Attacking sample 49/100 (True: 9, Index: 542)...
#   Success! Adv label: 8, L2: 387.79, Queries: 31
# Attacking sample 50/100 (True: 9, Index: 553)...
#   Success! Adv label: 4, L2: 568.26, Queries: 47
# Attacking sample 51/100 (True: 9, Index: 554)...
#   Success! Adv label: 4, L2: 764.20, Queries: 61
# Attacking sample 52/100 (True: 9, Index: 565)...
#   Success! Adv label: 0, L2: 414.32, Queries: 33
# Attacking sample 53/100 (True: 9, Index: 569)...
#   Success! Adv label: 4, L2: 476.57, Queries: 39
# Attacking sample 54/100 (True: 9, Index: 572)...
#   Success! Adv label: 5, L2: 322.98, Queries: 25
# Attacking sample 55/100 (True: 9, Index: 574)...
#   Success! Adv label: 8, L2: 348.40, Queries: 27
# Attacking sample 56/100 (True: 9, Index: 601)...
#   Success! Adv label: 8, L2: 380.47, Queries: 27
# Attacking sample 57/100 (True: 9, Index: 634)...
#   Success! Adv label: 5, L2: 406.68, Queries: 31
# Attacking sample 58/100 (True: 9, Index: 635)...
#   Success! Adv label: 4, L2: 598.33, Queries: 55
# Attacking sample 59/100 (True: 9, Index: 637)...
#   Success! Adv label: 4, L2: 551.79, Queries: 43
# Attacking sample 60/100 (True: 9, Index: 640)...
#   Success! Adv label: 4, L2: 522.60, Queries: 41
# Attacking sample 61/100 (True: 9, Index: 653)...
#   Success! Adv label: 3, L2: 582.30, Queries: 43
# Attacking sample 62/100 (True: 9, Index: 654)...
#   Success! Adv label: 4, L2: 517.88, Queries: 41
# Attacking sample 63/100 (True: 9, Index: 656)...
#   Success! Adv label: 8, L2: 669.68, Queries: 51
# Attacking sample 64/100 (True: 9, Index: 666)...
#   Success! Adv label: 4, L2: 443.67, Queries: 37
# Attacking sample 65/100 (True: 9, Index: 685)...
#   Success! Adv label: 7, L2: 617.02, Queries: 55
# Attacking sample 66/100 (True: 9, Index: 711)...
#   Success! Adv label: 4, L2: 196.62, Queries: 15
# Attacking sample 67/100 (True: 9, Index: 729)...
#   Success! Adv label: 8, L2: 462.18, Queries: 35
# Attacking sample 68/100 (True: 9, Index: 739)...
#   Success! Adv label: 4, L2: 416.75, Queries: 33
# Attacking sample 69/100 (True: 9, Index: 747)...
#   Success! Adv label: 8, L2: 364.22, Queries: 27
# Attacking sample 70/100 (True: 9, Index: 767)...
#   Success! Adv label: 8, L2: 455.59, Queries: 35
# Attacking sample 71/100 (True: 9, Index: 783)...
#   Success! Adv label: 5, L2: 497.57, Queries: 41
# Attacking sample 72/100 (True: 9, Index: 787)...
#   Success! Adv label: 8, L2: 571.32, Queries: 41
# Attacking sample 73/100 (True: 9, Index: 796)...
#   Success! Adv label: 7, L2: 375.11, Queries: 29
# Attacking sample 74/100 (True: 9, Index: 804)...
#   Success! Adv label: 7, L2: 668.83, Queries: 61
# Attacking sample 75/100 (True: 9, Index: 818)...
#   Success! Adv label: 4, L2: 633.20, Queries: 55
# Attacking sample 76/100 (True: 9, Index: 825)...
#   Success! Adv label: 8, L2: 362.10, Queries: 27
# Attacking sample 77/100 (True: 9, Index: 826)...
#   Success! Adv label: 1, L2: 150.80, Queries: 13
# Attacking sample 78/100 (True: 9, Index: 831)...
#   Success! Adv label: 4, L2: 466.76, Queries: 35
# Attacking sample 79/100 (True: 9, Index: 880)...
#   Success! Adv label: 5, L2: 469.12, Queries: 35
# Attacking sample 80/100 (True: 9, Index: 884)...
#   Success! Adv label: 4, L2: 464.94, Queries: 37
# Attacking sample 81/100 (True: 9, Index: 891)...
#   Success! Adv label: 4, L2: 137.79, Queries: 11
# Attacking sample 82/100 (True: 9, Index: 893)...
#   Success! Adv label: 2, L2: 616.67, Queries: 55
# Attacking sample 83/100 (True: 9, Index: 899)...
#   Success! Adv label: 4, L2: 446.01, Queries: 37
# Attacking sample 84/100 (True: 9, Index: 912)...
#   Success! Adv label: 5, L2: 455.21, Queries: 33
# Attacking sample 85/100 (True: 9, Index: 920)...
#   Success! Adv label: 4, L2: 543.21, Queries: 43
# Attacking sample 86/100 (True: 9, Index: 925)...
#   Success! Adv label: 8, L2: 357.07, Queries: 25
# Attacking sample 87/100 (True: 9, Index: 940)...
#   Success! Adv label: 4, L2: 345.09, Queries: 29
# Attacking sample 88/100 (True: 9, Index: 958)...
#   Success! Adv label: 4, L2: 462.34, Queries: 35
# Attacking sample 89/100 (True: 9, Index: 969)...
#   Success! Adv label: 8, L2: 360.21, Queries: 25
# Attacking sample 90/100 (True: 9, Index: 978)...
#   Success! Adv label: 4, L2: 424.87, Queries: 35
# Attacking sample 91/100 (True: 9, Index: 979)...
#   Success! Adv label: 4, L2: 334.50, Queries: 25
# Attacking sample 92/100 (True: 9, Index: 980)...
#   Success! Adv label: 8, L2: 347.75, Queries: 27
# Attacking sample 93/100 (True: 9, Index: 991)...
#   Success! Adv label: 7, L2: 538.19, Queries: 47
# Attacking sample 94/100 (True: 9, Index: 997)...
#   Success! Adv label: 4, L2: 244.98, Queries: 21
# Attacking sample 95/100 (True: 9, Index: 1006)...
#   Success! Adv label: 7, L2: 513.07, Queries: 45
# Attacking sample 96/100 (True: 9, Index: 1011)...
#   Success! Adv label: 4, L2: 783.03, Queries: 65
# Attacking sample 97/100 (True: 9, Index: 1020)...
#   Success! Adv label: 3, L2: 550.90, Queries: 43
# Attacking sample 98/100 (True: 9, Index: 1023)...
#   Success! Adv label: 4, L2: 760.81, Queries: 63
# Attacking sample 99/100 (True: 9, Index: 1042)...
#   Success! Adv label: 4, L2: 308.76, Queries: 23
# Attacking sample 100/100 (True: 9, Index: 1046)...
#   Success! Adv label: 4, L2: 363.85, Queries: 29
# Time taken to generate adversarial samples: 96.7399 seconds
#
# Stats saved to: adversarial_8bit_K190_test_images\per_sample_stats.csv
#
# ===== Attack Summary =====
# Total trials: 986
# Misclassified before attack: 14
# Success rate: 979/986 (99.3%)
# Mean L2 (successful): 552.22
# Mean queries (successful): 44.42
#
# Showing successful adversarial examples...
