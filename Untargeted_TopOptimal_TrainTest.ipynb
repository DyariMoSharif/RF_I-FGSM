# %% [markdown]
# ### Display the versions of the libraries used for reference purposes.

# %%
import sys
import numpy as np
import tensorflow as tf
import sklearn
import torch
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import notebook
import os

# Print Python version
print(f'Python version: {sys.version}')

# Print Jupyter Notebook version
print(f'Jupyter Notebook version: {notebook.__version__}')

# Print library versions
print(f'NumPy version: {np.__version__}')
print(f'TensorFlow version: {tf.__version__}')
print(f'Torch version: {torch.__version__}')
print(f'Scikit-learn version: {sklearn.__version__}')

os.makedirs("Models and Data splits", exist_ok=True)
# Out:
# Python version: 3.12.9 | packaged by Anaconda, Inc. | (main, Feb  6 2025, 18:49:16) [MSC v.1929 64 bit (AMD64)]
# Jupyter Notebook version: 7.3.2
# NumPy version: 2.0.1
# TensorFlow version: 2.19.0
# Torch version: 2.6.0+cu126
# Scikit-learn version: 1.6.1

# %% [markdown]
# ### Untargeted Attack on train set

# %%
import os
import warnings
import numpy as np
import torch
import joblib
import pandas as pd
from PIL import Image
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import torch.nn.functional as F
import time


# Set seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# ─────────────── PATHS ────────────────────────────────────────────────────
LENET_MODEL_PATH = os.path.normpath("Models and Data splits/lenet.pt")  # TorchScript model
DATA_PKL = os.path.normpath("Models and Data splits/data_[SCALED] Train_Test_Splits.pkl")
RF_ALL_CLASSES_PATH = os.path.normpath("Models and Data splits/random_forest.pkl")
OUT_DIR = "adversarial_8bit_train_images"
os.makedirs(OUT_DIR, exist_ok=True)

if not os.path.exists(RF_ALL_CLASSES_PATH):
    raise FileNotFoundError(f"Random Forest model not found at {RF_ALL_CLASSES_PATH}")

# ─────────── HYPER-PARAMETERS ─────────────────────────────────────────────
EPSILON_STEP = 0.01
ITERATIONS = 100
TOTAL_EPSILON = 0.5
TOP_K_FEATURES = 196
SAMPLES_PER_DIGIT = 100
MAX_L2 = 10000

def plot_adversarial_example(original_img, adv_img, true_label, adv_label, l2_mag, sample_idx, queries, title_suffix=""):
    if original_img.size == 784:
        original_img = original_img.reshape(28, 28)
    if adv_img.size == 784:
        adv_img = adv_img.reshape(28, 28)
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(original_img, cmap='gray')
    axes[0].set_title(f"Original\nTrue: {true_label}")
    axes[0].axis('off')
    axes[1].imshow(adv_img, cmap='gray')
    axes[1].set_title(f"Adversarial\nPred: {adv_label}")
    axes[1].axis('off')
    fig.suptitle(f"Sample {sample_idx} | L2: {l2_mag:.2f} | Queries: {queries} {title_suffix}")
    plt.show()
    plt.close(fig)  # <-- added here


# ─────────── Load Data ─────────────────────────────────────────────────────
try:
    data = joblib.load(DATA_PKL)
    X_samples , _, y_samples , _ = data
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PKL}. Please check the path.")
    exit()

if X_samples.max() > 1.0:
    X_samples = X_samples.astype(np.float32) / 255.0
    warnings.warn("Data appeared in [0,255]; normalized to [0,1].")

# ─────────── Load TorchScripted LeNet ──────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
try:
    model = torch.jit.load(LENET_MODEL_PATH, map_location=device)
    model.eval()
    print(f"LeNet TorchScript model loaded from: {LENET_MODEL_PATH}")
except Exception as e:
    print(f"Error loading TorchScript LeNet model: {e}")
    exit()

def to_model(x01_batch):
    if x01_batch.ndim == 2 and x01_batch.shape == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)
    elif x01_batch.ndim == 3 and x01_batch.shape[1:] == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(1)
    elif x01_batch.ndim == 4 and x01_batch.shape[1] == 1:
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device)
    elif x01_batch.ndim == 1 and x01_batch.size == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(1, 1, 28, 28), dtype=torch.float32, device=device)
    elif x01_batch.ndim == 2 and x01_batch.shape[1] == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(x01_batch.shape[0], 1, 28, 28), dtype=torch.float32, device=device)
    else:
        raise ValueError(f"Unsupported input shape for to_model: {x01_batch.shape}")
    return tensor_batch


def model_query(x_tensor_batch):
    with torch.no_grad():
        return model(x_tensor_batch)

# ─────────── Load Random Forest Model ──────────────────────────────────────
rf_all_classes = None
top_feature_indices = None
print("Loading Random Forest Classifier for all classes...")
try:
    rf_all_classes = joblib.load(RF_ALL_CLASSES_PATH)
    feature_importances = rf_all_classes.feature_importances_
    #top_feature_indices = np.argsort(feature_importances)[:TOP_K_FEATURES]
    
    top_feature_indices = np.argsort(-feature_importances)[:TOP_K_FEATURES]
    print(f"Random Forest loaded. Using top {TOP_K_FEATURES} features.")
except Exception as e:
    print(f"Error loading Random Forest: {e}")
    top_feature_indices = np.arange(28 * 28)

# ─────────── I-FGSM Attack ─────────────────────────────────────────────────
def ifgsm_attack(original_image_np, true_label, model_target, epsilon_step, iterations,
                 total_epsilon_budget, features_to_perturb, query_count_tracker):
    if original_image_np.ndim == 1 and original_image_np.size == 784:
        original_image_np = original_image_np.reshape(28, 28)

    perturbed_image_np = original_image_np.copy()
    final_pred_label = true_label

    for i in range(iterations):
        image_tensor = to_model(perturbed_image_np)
        image_tensor.requires_grad = True
        output = model_target(image_tensor)
        query_count_tracker[0] += 1
        loss = F.cross_entropy(output, torch.tensor([true_label], device=device))
        model_target.zero_grad()
        loss.backward()
        data_grad_sign = torch.sign(image_tensor.grad.data).cpu().numpy()

        gradient_mask = np.zeros_like(data_grad_sign, dtype=np.float32)
        h, w = perturbed_image_np.shape
        rows, cols = np.unravel_index(features_to_perturb, (h, w))
        gradient_mask[0, 0, rows, cols] = data_grad_sign[0, 0, rows, cols]
        gradient_mask_for_update = gradient_mask.reshape(perturbed_image_np.shape)

        perturbed_image_np += epsilon_step * gradient_mask_for_update
        perturbation = perturbed_image_np - original_image_np
        perturbation = np.clip(perturbation, -total_epsilon_budget, total_epsilon_budget)
        perturbed_image_np = original_image_np + perturbation
        perturbed_image_np = np.clip(perturbed_image_np, 0, 1)

        # Discretize and check prediction on discretized image
        adv_uint8_temp = np.round(perturbed_image_np * 255).astype(np.uint8)
        adv_float_temp = adv_uint8_temp.astype(np.float32) / 255.0
        with torch.no_grad():
            output_temp = model_target(to_model(adv_float_temp))
            pred_temp = output_temp.argmax(dim=1).item()
            query_count_tracker[0] += 1

        if pred_temp != true_label:
            final_pred_label = pred_temp
            break

    # Final adversarial image (discretized)
    adv_uint8 = np.round(perturbed_image_np * 255).astype(np.uint8)
    adv_float = adv_uint8.astype(np.float32) / 255.0
    with torch.no_grad():
        output_final = model_target(to_model(adv_float))
        final_pred_label = output_final.argmax(dim=1).item()

    l2_norm = np.linalg.norm(adv_uint8.astype(np.float32) - (original_image_np * 255).astype(np.float32))
    success = (final_pred_label != true_label) and (l2_norm <= MAX_L2)

    return adv_uint8, final_pred_label, l2_norm, success


# ─────────── Attack Execution ──────────────────────────────────────────────
print(f"\n===== Starting Adversarial Attack =====")
total_trials, succ_total, misclassified = 0, 0, 0
records = []


start_time = time.time()


for digit in range(10):
    idxs = np.where(y_samples == digit)[0][:SAMPLES_PER_DIGIT]
    for rank, idx in enumerate(idxs, 1):
        x0 = X_samples[idx].copy()
        y0 = int(y_samples[idx])
        query_count_tracker = [0]
        pred0 = model_query(to_model(x0)).argmax(dim=1).item()
        query_count_tracker[0] += 1

        if pred0 != y0:
            misclassified += 1
            records.append({
                'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
                'adv_label': None, 'success': False, 'queries': query_count_tracker[0],
                'l2_mag': np.nan, 'note': 'Already misclassified'
            })
            continue

        total_trials += 1
        print(f"Attacking sample {rank}/{SAMPLES_PER_DIGIT} (True: {y0}, Index: {idx})...")
        adv_img_uint8, adv_label, l2_mag, success = ifgsm_attack(
            x0, y0, model, EPSILON_STEP, ITERATIONS, TOTAL_EPSILON,
            top_feature_indices, query_count_tracker
        )

        if success:
            succ_total += 1
            fname = f"true{y0}_adv{adv_label}_mag{l2_mag:.1f}_sample{idx}.png"
            Image.fromarray(adv_img_uint8, mode="L").save(os.path.join(OUT_DIR, fname))

        records.append({
            'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
            'adv_label': adv_label, 'success': success, 'queries': query_count_tracker[0],
            'l2_mag': l2_mag if success else np.nan, 'note': 'I-FGSM' + (' successful' if success else ' failed')
        })

        print(f"  {'Success' if success else 'Failed'}! Adv label: {adv_label}, L2: {l2_mag:.2f}, Queries: {query_count_tracker[0]}")


end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to generate adversarial samples: {elapsed_time:.4f} seconds")


# ─────────── Save Results ──────────────────────────────────────────────────
df = pd.DataFrame(records)
csv_path = os.path.join(OUT_DIR, "per_sample_stats.csv")
df.to_csv(csv_path, index=False)
print(f"\nStats saved to: {csv_path}")

# ─────────── Summary ───────────────────────────────────────────────────────
print(f"\n===== Attack Summary =====")
print(f"Total trials: {total_trials}")
print(f"Misclassified before attack: {misclassified}")
if total_trials > 0:
    success_rate = succ_total / total_trials * 100
    print(f"Success rate: {succ_total}/{total_trials} ({success_rate:.1f}%)")
    if succ_total > 0:
        print(f"Mean L2 (successful): {df[df['success']]['l2_mag'].mean():.2f}")
        print(f"Mean queries (successful): {df[df['success']]['queries'].mean():.2f}")

# ─────────── Display Examples ──────────────────────────────────────────────
success_df = df[df['success']]
if not success_df.empty:
    print("\nShowing successful adversarial examples...")
    show_ids = success_df.sample(min(3, len(success_df))).index.tolist()
    for record_idx in show_ids:
        r = df.loc[record_idx]
        fname_prefix = f"true{r['true_label']}_adv{r['adv_label']}_mag{r['l2_mag']:.1f}_sample{r['sample_idx']}"
        match_files = [f for f in os.listdir(OUT_DIR) if f.startswith(fname_prefix)]
        if match_files:
            adv_img_path = os.path.join(OUT_DIR, match_files[0])
            plot_adversarial_example(X_samples[r['sample_idx']], np.array(Image.open(adv_img_path)),
                                     r['true_label'], r['adv_label'], r['l2_mag'],
                                     r['sample_idx'], r['queries'], "(I-FGSM)")
else:
    print("No successful attacks to display. Showing original samples instead.")
    for i in range(min(3, len(df))):
        r = df.iloc[i]
        plot_adversarial_example(X_samples[r['sample_idx']], X_samples[r['sample_idx']],
                                 r['true_label'], r['initial_pred'], 0.0,
                                 r['sample_idx'], r['queries'], "(Original)")
# Out:
# LeNet TorchScript model loaded from: Models and Data splits\lenet.pt
# Loading Random Forest Classifier for all classes...
# Random Forest loaded. Using top 196 features.
#
# ===== Starting Adversarial Attack =====
# Attacking sample 1/100 (True: 0, Index: 0)...
#   Success! Adv label: 2, L2: 900.31, Queries: 75
# Attacking sample 2/100 (True: 0, Index: 2)...
#   Success! Adv label: 9, L2: 663.58, Queries: 55
# Attacking sample 3/100 (True: 0, Index: 7)...
#   Success! Adv label: 9, L2: 996.01, Queries: 81
# Attacking sample 4/100 (True: 0, Index: 16)...
#   Success! Adv label: 5, L2: 693.67, Queries: 59
# Attacking sample 5/100 (True: 0, Index: 35)...
#   Success! Adv label: 6, L2: 329.67, Queries: 25
# Attacking sample 6/100 (True: 0, Index: 44)...
#   Success! Adv label: 5, L2: 526.71, Queries: 43
# Attacking sample 7/100 (True: 0, Index: 49)...
#   Success! Adv label: 5, L2: 661.66, Queries: 55
# Attacking sample 8/100 (True: 0, Index: 58)...
#   Success! Adv label: 3, L2: 835.42, Queries: 67
# Attacking sample 9/100 (True: 0, Index: 63)...
#   Success! Adv label: 5, L2: 884.98, Queries: 77
# Attacking sample 10/100 (True: 0, Index: 67)...
#   Success! Adv label: 2, L2: 610.60, Queries: 49
# Attacking sample 11/100 (True: 0, Index: 72)...
#   Success! Adv label: 9, L2: 886.94, Queries: 81
# Attacking sample 12/100 (True: 0, Index: 73)...
#   Success! Adv label: 9, L2: 1115.69, Queries: 95
# Attacking sample 13/100 (True: 0, Index: 75)...
#   Success! Adv label: 8, L2: 950.25, Queries: 77
# Attacking sample 14/100 (True: 0, Index: 97)...
#   Success! Adv label: 2, L2: 672.38, Queries: 55
# Attacking sample 15/100 (True: 0, Index: 112)...
#   Success! Adv label: 9, L2: 831.02, Queries: 77
# Attacking sample 16/100 (True: 0, Index: 113)...
#   Success! Adv label: 2, L2: 747.21, Queries: 59
# Attacking sample 17/100 (True: 0, Index: 118)...
#   Success! Adv label: 6, L2: 515.53, Queries: 43
# Attacking sample 18/100 (True: 0, Index: 135)...
#   Success! Adv label: 2, L2: 479.85, Queries: 37
# Attacking sample 19/100 (True: 0, Index: 155)...
#   Success! Adv label: 2, L2: 1108.99, Queries: 145
# Attacking sample 20/100 (True: 0, Index: 174)...
#   Success! Adv label: 9, L2: 447.64, Queries: 37
# Attacking sample 21/100 (True: 0, Index: 182)...
#   Success! Adv label: 2, L2: 1087.97, Queries: 89
# Attacking sample 22/100 (True: 0, Index: 186)...
#   Success! Adv label: 9, L2: 724.94, Queries: 65
# Attacking sample 23/100 (True: 0, Index: 187)...
#   Success! Adv label: 6, L2: 218.65, Queries: 15
# Attacking sample 24/100 (True: 0, Index: 196)...
#   Success! Adv label: 6, L2: 791.19, Queries: 69
# Attacking sample 25/100 (True: 0, Index: 200)...
#   Success! Adv label: 6, L2: 404.60, Queries: 33
# Attacking sample 26/100 (True: 0, Index: 203)...
#   Success! Adv label: 6, L2: 675.29, Queries: 53
# Attacking sample 27/100 (True: 0, Index: 218)...
#   Success! Adv label: 2, L2: 254.90, Queries: 19
# Attacking sample 28/100 (True: 0, Index: 219)...
#   Success! Adv label: 6, L2: 542.48, Queries: 41
# Attacking sample 29/100 (True: 0, Index: 239)...
#   Success! Adv label: 5, L2: 678.71, Queries: 57
# Attacking sample 30/100 (True: 0, Index: 246)...
#   Success! Adv label: 5, L2: 993.02, Queries: 89
# Attacking sample 31/100 (True: 0, Index: 251)...
#   Success! Adv label: 2, L2: 1002.70, Queries: 87
# Attacking sample 32/100 (True: 0, Index: 252)...
#   Success! Adv label: 2, L2: 721.36, Queries: 57
# Attacking sample 33/100 (True: 0, Index: 261)...
#   Success! Adv label: 9, L2: 696.79, Queries: 53
# Attacking sample 34/100 (True: 0, Index: 273)...
#   Success! Adv label: 3, L2: 878.39, Queries: 69
# Attacking sample 35/100 (True: 0, Index: 282)...
#   Success! Adv label: 9, L2: 1068.59, Queries: 135
# Attacking sample 36/100 (True: 0, Index: 295)...
#   Success! Adv label: 6, L2: 630.48, Queries: 47
# Attacking sample 37/100 (True: 0, Index: 297)...
#   Success! Adv label: 6, L2: 1085.82, Queries: 89
# Attacking sample 38/100 (True: 0, Index: 315)...
#   Success! Adv label: 9, L2: 971.23, Queries: 91
# Attacking sample 39/100 (True: 0, Index: 322)...
#   Success! Adv label: 9, L2: 989.71, Queries: 75
# Attacking sample 40/100 (True: 0, Index: 338)...
#   Success! Adv label: 6, L2: 827.17, Queries: 71
# Attacking sample 41/100 (True: 0, Index: 339)...
#   Success! Adv label: 5, L2: 540.06, Queries: 43
# Attacking sample 42/100 (True: 0, Index: 354)...
#   Success! Adv label: 9, L2: 499.77, Queries: 37
# Attacking sample 43/100 (True: 0, Index: 356)...
#   Success! Adv label: 2, L2: 645.42, Queries: 49
# Attacking sample 44/100 (True: 0, Index: 357)...
#   Success! Adv label: 2, L2: 213.57, Queries: 17
# Attacking sample 45/100 (True: 0, Index: 359)...
#   Success! Adv label: 8, L2: 311.94, Queries: 23
# Attacking sample 46/100 (True: 0, Index: 377)...
#   Success! Adv label: 8, L2: 863.03, Queries: 75
# Attacking sample 47/100 (True: 0, Index: 379)...
#   Success! Adv label: 9, L2: 728.65, Queries: 63
# Attacking sample 48/100 (True: 0, Index: 387)...
#   Success! Adv label: 6, L2: 460.44, Queries: 35
# Attacking sample 49/100 (True: 0, Index: 390)...
#   Success! Adv label: 6, L2: 784.41, Queries: 61
# Attacking sample 50/100 (True: 0, Index: 394)...
#   Success! Adv label: 9, L2: 790.51, Queries: 67
# Attacking sample 51/100 (True: 0, Index: 408)...
#   Success! Adv label: 6, L2: 36.58, Queries: 3
# Attacking sample 52/100 (True: 0, Index: 423)...
#   Success! Adv label: 2, L2: 818.78, Queries: 67
# Attacking sample 53/100 (True: 0, Index: 434)...
#   Success! Adv label: 2, L2: 686.07, Queries: 55
# Attacking sample 54/100 (True: 0, Index: 436)...
#   Success! Adv label: 2, L2: 774.55, Queries: 65
# Attacking sample 55/100 (True: 0, Index: 454)...
#   Success! Adv label: 2, L2: 595.55, Queries: 43
# Attacking sample 56/100 (True: 0, Index: 462)...
#   Success! Adv label: 9, L2: 688.58, Queries: 67
# Attacking sample 57/100 (True: 0, Index: 476)...
#   Success! Adv label: 2, L2: 477.58, Queries: 37
# Attacking sample 58/100 (True: 0, Index: 497)...
#   Success! Adv label: 2, L2: 828.32, Queries: 69
# Attacking sample 59/100 (True: 0, Index: 509)...
#   Success! Adv label: 6, L2: 356.81, Queries: 27
# Attacking sample 60/100 (True: 0, Index: 511)...
#   Success! Adv label: 2, L2: 834.65, Queries: 69
# Attacking sample 61/100 (True: 0, Index: 521)...
#   Success! Adv label: 2, L2: 309.49, Queries: 23
# Attacking sample 62/100 (True: 0, Index: 523)...
#   Success! Adv label: 2, L2: 817.99, Queries: 63
# Attacking sample 63/100 (True: 0, Index: 524)...
#   Success! Adv label: 9, L2: 842.75, Queries: 75
# Attacking sample 64/100 (True: 0, Index: 534)...
#   Success! Adv label: 9, L2: 783.18, Queries: 63
# Attacking sample 65/100 (True: 0, Index: 543)...
#   Success! Adv label: 5, L2: 942.74, Queries: 95
# Attacking sample 66/100 (True: 0, Index: 550)...
#   Success! Adv label: 9, L2: 610.12, Queries: 53
# Attacking sample 67/100 (True: 0, Index: 555)...
#   Success! Adv label: 2, L2: 548.37, Queries: 41
# Attacking sample 68/100 (True: 0, Index: 559)...
#   Success! Adv label: 2, L2: 912.28, Queries: 81
# Attacking sample 69/100 (True: 0, Index: 564)...
#   Success! Adv label: 2, L2: 969.00, Queries: 75
# Attacking sample 70/100 (True: 0, Index: 575)...
#   Success! Adv label: 5, L2: 609.31, Queries: 49
# Attacking sample 71/100 (True: 0, Index: 577)...
#   Success! Adv label: 9, L2: 808.10, Queries: 65
# Attacking sample 72/100 (True: 0, Index: 595)...
#   Success! Adv label: 9, L2: 615.30, Queries: 51
# Attacking sample 73/100 (True: 0, Index: 600)...
#   Success! Adv label: 6, L2: 708.30, Queries: 59
# Attacking sample 74/100 (True: 0, Index: 630)...
#   Success! Adv label: 9, L2: 869.04, Queries: 69
# Attacking sample 75/100 (True: 0, Index: 643)...
#   Success! Adv label: 6, L2: 710.28, Queries: 61
# Attacking sample 76/100 (True: 0, Index: 667)...
#   Success! Adv label: 5, L2: 997.75, Queries: 93
# Attacking sample 77/100 (True: 0, Index: 685)...
#   Success! Adv label: 9, L2: 1004.07, Queries: 91
# Attacking sample 78/100 (True: 0, Index: 687)...
#   Success! Adv label: 9, L2: 1152.75, Queries: 119
# Attacking sample 79/100 (True: 0, Index: 701)...
#   Success! Adv label: 6, L2: 743.82, Queries: 57
# Attacking sample 80/100 (True: 0, Index: 703)...
#   Success! Adv label: 5, L2: 775.20, Queries: 59
# Attacking sample 81/100 (True: 0, Index: 710)...
#   Success! Adv label: 6, L2: 318.40, Queries: 23
# Attacking sample 82/100 (True: 0, Index: 716)...
#   Success! Adv label: 6, L2: 89.45, Queries: 7
# Attacking sample 83/100 (True: 0, Index: 719)...
#   Success! Adv label: 5, L2: 659.66, Queries: 59
# Attacking sample 84/100 (True: 0, Index: 725)...
#   Success! Adv label: 6, L2: 922.16, Queries: 85
# Attacking sample 85/100 (True: 0, Index: 727)...
#   Success! Adv label: 9, L2: 522.36, Queries: 43
# Attacking sample 86/100 (True: 0, Index: 728)...
#   Success! Adv label: 5, L2: 781.30, Queries: 63
# Attacking sample 87/100 (True: 0, Index: 732)...
#   Success! Adv label: 2, L2: 1078.50, Queries: 87
# Attacking sample 88/100 (True: 0, Index: 744)...
#   Success! Adv label: 6, L2: 618.02, Queries: 49
# Attacking sample 89/100 (True: 0, Index: 757)...
#   Success! Adv label: 5, L2: 732.39, Queries: 63
# Attacking sample 90/100 (True: 0, Index: 764)...
#   Success! Adv label: 6, L2: 750.99, Queries: 63
# Attacking sample 91/100 (True: 0, Index: 784)...
#   Success! Adv label: 5, L2: 908.08, Queries: 83
# Attacking sample 92/100 (True: 0, Index: 789)...
#   Success! Adv label: 8, L2: 1144.15, Queries: 97
# Attacking sample 93/100 (True: 0, Index: 803)...
#   Success! Adv label: 5, L2: 1038.95, Queries: 91
# Attacking sample 94/100 (True: 0, Index: 805)...
#   Success! Adv label: 9, L2: 954.82, Queries: 91
# Attacking sample 95/100 (True: 0, Index: 813)...
#   Success! Adv label: 9, L2: 900.10, Queries: 77
# Attacking sample 96/100 (True: 0, Index: 822)...
#   Success! Adv label: 4, L2: 338.65, Queries: 27
# Attacking sample 97/100 (True: 0, Index: 823)...
#   Success! Adv label: 2, L2: 458.04, Queries: 37
# Attacking sample 98/100 (True: 0, Index: 828)...
#   Success! Adv label: 8, L2: 785.72, Queries: 61
# Attacking sample 99/100 (True: 0, Index: 856)...
#   Success! Adv label: 8, L2: 455.65, Queries: 33
# Attacking sample 100/100 (True: 0, Index: 861)...
#   Success! Adv label: 6, L2: 1284.29, Queries: 143
# Attacking sample 1/100 (True: 1, Index: 4)...
#   Success! Adv label: 8, L2: 271.18, Queries: 19
# Attacking sample 2/100 (True: 1, Index: 6)...
#   Success! Adv label: 8, L2: 393.48, Queries: 27
# Attacking sample 3/100 (True: 1, Index: 26)...
#   Success! Adv label: 8, L2: 286.26, Queries: 21
# Attacking sample 4/100 (True: 1, Index: 34)...
#   Success! Adv label: 4, L2: 352.43, Queries: 23
# Attacking sample 5/100 (True: 1, Index: 43)...
#   Success! Adv label: 4, L2: 265.48, Queries: 19
# Attacking sample 6/100 (True: 1, Index: 50)...
#   Success! Adv label: 7, L2: 283.90, Queries: 21
# Attacking sample 7/100 (True: 1, Index: 52)...
#   Success! Adv label: 4, L2: 296.71, Queries: 21
# Attacking sample 8/100 (True: 1, Index: 57)...
#   Success! Adv label: 4, L2: 397.81, Queries: 27
# Attacking sample 9/100 (True: 1, Index: 64)...
#   Success! Adv label: 8, L2: 379.33, Queries: 25
# Attacking sample 10/100 (True: 1, Index: 86)...
#   Success! Adv label: 8, L2: 285.54, Queries: 19
# Attacking sample 11/100 (True: 1, Index: 96)...
#   Success! Adv label: 4, L2: 363.76, Queries: 25
# Attacking sample 12/100 (True: 1, Index: 121)...
#   Success! Adv label: 4, L2: 387.06, Queries: 25
# Attacking sample 13/100 (True: 1, Index: 125)...
#   Success! Adv label: 8, L2: 431.97, Queries: 31
# Attacking sample 14/100 (True: 1, Index: 126)...
#   Success! Adv label: 4, L2: 337.33, Queries: 23
# Attacking sample 15/100 (True: 1, Index: 127)...
#   Success! Adv label: 8, L2: 450.71, Queries: 31
# Attacking sample 16/100 (True: 1, Index: 130)...
#   Success! Adv label: 8, L2: 249.70, Queries: 17
# Attacking sample 17/100 (True: 1, Index: 136)...
#   Success! Adv label: 4, L2: 226.57, Queries: 15
# Attacking sample 18/100 (True: 1, Index: 141)...
#   Success! Adv label: 8, L2: 294.54, Queries: 21
# Attacking sample 19/100 (True: 1, Index: 151)...
#   Success! Adv label: 8, L2: 300.70, Queries: 21
# Attacking sample 20/100 (True: 1, Index: 159)...
#   Success! Adv label: 8, L2: 305.44, Queries: 21
# Attacking sample 21/100 (True: 1, Index: 172)...
#   Success! Adv label: 8, L2: 386.59, Queries: 25
# Attacking sample 22/100 (True: 1, Index: 183)...
#   Success! Adv label: 8, L2: 291.58, Queries: 21
# Attacking sample 23/100 (True: 1, Index: 191)...
#   Success! Adv label: 8, L2: 406.92, Queries: 27
# Attacking sample 24/100 (True: 1, Index: 208)...
#   Success! Adv label: 8, L2: 237.79, Queries: 17
# Attacking sample 26/100 (True: 1, Index: 243)...
#   Success! Adv label: 4, L2: 344.90, Queries: 23
# Attacking sample 27/100 (True: 1, Index: 256)...
#   Success! Adv label: 6, L2: 59.27, Queries: 5
# Attacking sample 28/100 (True: 1, Index: 257)...
#   Success! Adv label: 8, L2: 214.08, Queries: 15
# Attacking sample 29/100 (True: 1, Index: 272)...
#   Success! Adv label: 4, L2: 276.11, Queries: 19
# Attacking sample 30/100 (True: 1, Index: 298)...
#   Success! Adv label: 4, L2: 363.05, Queries: 25
# Attacking sample 31/100 (True: 1, Index: 312)...
#   Success! Adv label: 8, L2: 368.33, Queries: 25
# Attacking sample 32/100 (True: 1, Index: 328)...
#   Success! Adv label: 8, L2: 363.41, Queries: 25
# Attacking sample 33/100 (True: 1, Index: 348)...
#   Success! Adv label: 8, L2: 263.85, Queries: 19
# Attacking sample 34/100 (True: 1, Index: 368)...
#   Success! Adv label: 8, L2: 247.47, Queries: 17
# Attacking sample 35/100 (True: 1, Index: 384)...
#   Success! Adv label: 8, L2: 208.31, Queries: 15
# Attacking sample 36/100 (True: 1, Index: 393)...
#   Success! Adv label: 8, L2: 275.34, Queries: 19
# Attacking sample 37/100 (True: 1, Index: 407)...
#   Success! Adv label: 2, L2: 217.24, Queries: 15
# Attacking sample 38/100 (True: 1, Index: 416)...
#   Success! Adv label: 4, L2: 406.62, Queries: 27
# Attacking sample 39/100 (True: 1, Index: 429)...
#   Success! Adv label: 9, L2: 349.50, Queries: 25
# Attacking sample 40/100 (True: 1, Index: 430)...
#   Success! Adv label: 8, L2: 291.91, Queries: 21
# Attacking sample 41/100 (True: 1, Index: 432)...
#   Success! Adv label: 4, L2: 380.57, Queries: 25
# Attacking sample 42/100 (True: 1, Index: 448)...
#   Success! Adv label: 4, L2: 399.87, Queries: 27
# Attacking sample 43/100 (True: 1, Index: 452)...
#   Success! Adv label: 4, L2: 283.68, Queries: 21
# Attacking sample 44/100 (True: 1, Index: 455)...
#   Success! Adv label: 4, L2: 342.30, Queries: 23
# Attacking sample 45/100 (True: 1, Index: 456)...
#   Success! Adv label: 9, L2: 264.04, Queries: 19
# Attacking sample 46/100 (True: 1, Index: 467)...
#   Success! Adv label: 4, L2: 341.08, Queries: 23
# Attacking sample 47/100 (True: 1, Index: 469)...
#   Success! Adv label: 4, L2: 224.99, Queries: 15
# Attacking sample 48/100 (True: 1, Index: 477)...
#   Success! Adv label: 9, L2: 340.96, Queries: 23
# Attacking sample 49/100 (True: 1, Index: 487)...
#   Success! Adv label: 8, L2: 123.81, Queries: 9
# Attacking sample 50/100 (True: 1, Index: 495)...
#   Success! Adv label: 6, L2: 324.40, Queries: 23
# Attacking sample 51/100 (True: 1, Index: 499)...
#   Success! Adv label: 8, L2: 305.20, Queries: 21
# Attacking sample 52/100 (True: 1, Index: 504)...
#   Success! Adv label: 8, L2: 287.31, Queries: 19
# Attacking sample 53/100 (True: 1, Index: 505)...
#   Success! Adv label: 8, L2: 337.79, Queries: 23
# Attacking sample 54/100 (True: 1, Index: 525)...
#   Success! Adv label: 8, L2: 281.42, Queries: 19
# Attacking sample 55/100 (True: 1, Index: 531)...
#   Success! Adv label: 4, L2: 278.25, Queries: 19
# Attacking sample 56/100 (True: 1, Index: 551)...
#   Success! Adv label: 8, L2: 378.16, Queries: 25
# Attacking sample 57/100 (True: 1, Index: 561)...
#   Success! Adv label: 7, L2: 386.12, Queries: 25
# Attacking sample 58/100 (True: 1, Index: 566)...
#   Success! Adv label: 8, L2: 125.79, Queries: 9
# Attacking sample 59/100 (True: 1, Index: 573)...
#   Success! Adv label: 8, L2: 279.61, Queries: 19
# Attacking sample 60/100 (True: 1, Index: 580)...
#   Success! Adv label: 8, L2: 296.69, Queries: 21
# Attacking sample 61/100 (True: 1, Index: 608)...
#   Success! Adv label: 4, L2: 58.48, Queries: 5
# Attacking sample 62/100 (True: 1, Index: 609)...
#   Success! Adv label: 4, L2: 194.24, Queries: 15
# Attacking sample 63/100 (True: 1, Index: 613)...
#   Success! Adv label: 8, L2: 239.47, Queries: 17
# Attacking sample 64/100 (True: 1, Index: 615)...
#   Success! Adv label: 7, L2: 334.15, Queries: 23
# Attacking sample 65/100 (True: 1, Index: 627)...
#   Success! Adv label: 8, L2: 250.49, Queries: 17
# Attacking sample 66/100 (True: 1, Index: 648)...
#   Success! Adv label: 8, L2: 237.42, Queries: 17
# Attacking sample 67/100 (True: 1, Index: 655)...
#   Success! Adv label: 4, L2: 367.23, Queries: 25
# Attacking sample 68/100 (True: 1, Index: 661)...
#   Success! Adv label: 8, L2: 344.00, Queries: 23
# Attacking sample 69/100 (True: 1, Index: 664)...
#   Success! Adv label: 4, L2: 292.31, Queries: 19
# Attacking sample 70/100 (True: 1, Index: 665)...
#   Success! Adv label: 4, L2: 333.06, Queries: 23
# Attacking sample 71/100 (True: 1, Index: 680)...
#   Success! Adv label: 8, L2: 377.94, Queries: 25
# Attacking sample 72/100 (True: 1, Index: 689)...
#   Success! Adv label: 8, L2: 338.70, Queries: 23
# Attacking sample 73/100 (True: 1, Index: 697)...
#   Success! Adv label: 8, L2: 299.32, Queries: 21
# Attacking sample 74/100 (True: 1, Index: 704)...
#   Success! Adv label: 7, L2: 363.37, Queries: 25
# Attacking sample 75/100 (True: 1, Index: 707)...
#   Success! Adv label: 4, L2: 341.49, Queries: 23
# Attacking sample 76/100 (True: 1, Index: 722)...
#   Success! Adv label: 8, L2: 153.72, Queries: 11
# Attacking sample 77/100 (True: 1, Index: 723)...
#   Success! Adv label: 4, L2: 340.29, Queries: 23
# Attacking sample 78/100 (True: 1, Index: 743)...
#   Success! Adv label: 8, L2: 345.37, Queries: 23
# Attacking sample 79/100 (True: 1, Index: 754)...
#   Success! Adv label: 8, L2: 301.54, Queries: 21
# Attacking sample 80/100 (True: 1, Index: 755)...
#   Success! Adv label: 8, L2: 184.13, Queries: 13
# Attacking sample 81/100 (True: 1, Index: 758)...
#   Success! Adv label: 9, L2: 332.69, Queries: 23
# Attacking sample 82/100 (True: 1, Index: 759)...
#   Success! Adv label: 2, L2: 296.68, Queries: 21
# Attacking sample 83/100 (True: 1, Index: 766)...
#   Success! Adv label: 8, L2: 159.70, Queries: 11
# Attacking sample 84/100 (True: 1, Index: 770)...
#   Success! Adv label: 8, L2: 38.13, Queries: 3
# Attacking sample 85/100 (True: 1, Index: 779)...
#   Success! Adv label: 8, L2: 365.86, Queries: 25
# Attacking sample 86/100 (True: 1, Index: 788)...
#   Success! Adv label: 4, L2: 248.71, Queries: 17
# Attacking sample 87/100 (True: 1, Index: 799)...
#   Success! Adv label: 4, L2: 276.73, Queries: 19
# Attacking sample 88/100 (True: 1, Index: 820)...
#   Success! Adv label: 8, L2: 276.53, Queries: 19
# Attacking sample 89/100 (True: 1, Index: 835)...
#   Success! Adv label: 8, L2: 342.68, Queries: 23
# Attacking sample 90/100 (True: 1, Index: 860)...
#   Success! Adv label: 8, L2: 237.44, Queries: 17
# Attacking sample 91/100 (True: 1, Index: 865)...
#   Success! Adv label: 8, L2: 177.79, Queries: 13
# Attacking sample 92/100 (True: 1, Index: 891)...
#   Success! Adv label: 4, L2: 343.26, Queries: 23
# Attacking sample 93/100 (True: 1, Index: 901)...
#   Success! Adv label: 4, L2: 396.04, Queries: 27
# Attacking sample 94/100 (True: 1, Index: 903)...
#   Success! Adv label: 8, L2: 281.30, Queries: 19
# Attacking sample 95/100 (True: 1, Index: 909)...
#   Success! Adv label: 4, L2: 230.25, Queries: 17
# Attacking sample 96/100 (True: 1, Index: 927)...
#   Success! Adv label: 8, L2: 213.09, Queries: 15
# Attacking sample 97/100 (True: 1, Index: 929)...
#   Success! Adv label: 4, L2: 343.69, Queries: 23
# Attacking sample 98/100 (True: 1, Index: 931)...
#   Success! Adv label: 8, L2: 302.45, Queries: 21
# Attacking sample 99/100 (True: 1, Index: 950)...
#   Success! Adv label: 8, L2: 219.93, Queries: 15
# Attacking sample 100/100 (True: 1, Index: 971)...
#   Success! Adv label: 4, L2: 384.94, Queries: 25
# Attacking sample 1/100 (True: 2, Index: 5)...
#   Success! Adv label: 3, L2: 717.42, Queries: 53
# Attacking sample 2/100 (True: 2, Index: 8)...
#   Success! Adv label: 8, L2: 392.96, Queries: 27
# Attacking sample 3/100 (True: 2, Index: 10)...
#   Success! Adv label: 9, L2: 159.71, Queries: 13
# Attacking sample 4/100 (True: 2, Index: 18)...
#   Success! Adv label: 3, L2: 1108.05, Queries: 101
# Attacking sample 5/100 (True: 2, Index: 21)...
#   Success! Adv label: 7, L2: 725.89, Queries: 61
# Attacking sample 6/100 (True: 2, Index: 78)...
#   Success! Adv label: 0, L2: 503.46, Queries: 39
# Attacking sample 7/100 (True: 2, Index: 87)...
#   Success! Adv label: 8, L2: 748.27, Queries: 51
# Attacking sample 8/100 (True: 2, Index: 98)...
#   Success! Adv label: 8, L2: 907.66, Queries: 71
# Attacking sample 9/100 (True: 2, Index: 111)...
#   Success! Adv label: 8, L2: 268.51, Queries: 19
# Attacking sample 10/100 (True: 2, Index: 117)...
#   Success! Adv label: 1, L2: 971.57, Queries: 85
# Attacking sample 11/100 (True: 2, Index: 134)...
#   Success! Adv label: 3, L2: 430.49, Queries: 31
# Attacking sample 12/100 (True: 2, Index: 143)...
#   Success! Adv label: 8, L2: 847.54, Queries: 63
# Attacking sample 13/100 (True: 2, Index: 161)...
#   Success! Adv label: 8, L2: 422.95, Queries: 29
# Attacking sample 14/100 (True: 2, Index: 164)...
#   Success! Adv label: 1, L2: 185.22, Queries: 15
# Attacking sample 15/100 (True: 2, Index: 165)...
#   Success! Adv label: 3, L2: 792.04, Queries: 61
# Attacking sample 16/100 (True: 2, Index: 166)...
#   Success! Adv label: 3, L2: 879.91, Queries: 79
# Attacking sample 17/100 (True: 2, Index: 170)...
#   Success! Adv label: 8, L2: 904.05, Queries: 65
# Attacking sample 18/100 (True: 2, Index: 175)...
#   Success! Adv label: 3, L2: 413.25, Queries: 31
# Attacking sample 19/100 (True: 2, Index: 176)...
#   Failed! Adv label: 2, L2: 1179.77, Queries: 201
# Attacking sample 20/100 (True: 2, Index: 202)...
#   Success! Adv label: 1, L2: 952.71, Queries: 81
# Attacking sample 21/100 (True: 2, Index: 204)...
#   Success! Adv label: 3, L2: 1015.56, Queries: 75
# Attacking sample 22/100 (True: 2, Index: 209)...
#   Success! Adv label: 8, L2: 442.26, Queries: 31
# Attacking sample 23/100 (True: 2, Index: 224)...
#   Success! Adv label: 3, L2: 820.01, Queries: 79
# Attacking sample 24/100 (True: 2, Index: 240)...
#   Success! Adv label: 0, L2: 425.90, Queries: 29
# Attacking sample 25/100 (True: 2, Index: 245)...
#   Success! Adv label: 3, L2: 846.43, Queries: 65
# Attacking sample 26/100 (True: 2, Index: 258)...
#   Success! Adv label: 3, L2: 464.02, Queries: 35
# Attacking sample 27/100 (True: 2, Index: 259)...
#   Success! Adv label: 3, L2: 594.87, Queries: 43
# Attacking sample 28/100 (True: 2, Index: 269)...
#   Success! Adv label: 3, L2: 264.33, Queries: 19
# Attacking sample 29/100 (True: 2, Index: 275)...
#   Success! Adv label: 8, L2: 764.65, Queries: 55
# Attacking sample 30/100 (True: 2, Index: 276)...
#   Success! Adv label: 3, L2: 558.20, Queries: 51
# Attacking sample 31/100 (True: 2, Index: 281)...
#   Success! Adv label: 3, L2: 599.26, Queries: 43
# Attacking sample 32/100 (True: 2, Index: 288)...
#   Success! Adv label: 3, L2: 662.61, Queries: 49
# Attacking sample 33/100 (True: 2, Index: 289)...
#   Success! Adv label: 8, L2: 359.77, Queries: 25
# Attacking sample 34/100 (True: 2, Index: 308)...
#   Success! Adv label: 8, L2: 520.44, Queries: 37
# Attacking sample 35/100 (True: 2, Index: 313)...
#   Success! Adv label: 3, L2: 281.09, Queries: 23
# Attacking sample 36/100 (True: 2, Index: 317)...
#   Success! Adv label: 8, L2: 920.25, Queries: 69
# Attacking sample 37/100 (True: 2, Index: 327)...
#   Success! Adv label: 1, L2: 684.56, Queries: 63
# Attacking sample 38/100 (True: 2, Index: 333)...
#   Success! Adv label: 3, L2: 985.34, Queries: 85
# Attacking sample 39/100 (True: 2, Index: 344)...
#   Success! Adv label: 3, L2: 857.38, Queries: 65
# Attacking sample 40/100 (True: 2, Index: 349)...
#   Success! Adv label: 7, L2: 543.02, Queries: 47
# Attacking sample 41/100 (True: 2, Index: 352)...
#   Success! Adv label: 3, L2: 626.36, Queries: 49
# Attacking sample 42/100 (True: 2, Index: 386)...
#   Success! Adv label: 8, L2: 604.67, Queries: 41
# Attacking sample 43/100 (True: 2, Index: 391)...
#   Success! Adv label: 8, L2: 801.11, Queries: 55
# Attacking sample 44/100 (True: 2, Index: 418)...
#   Success! Adv label: 3, L2: 806.99, Queries: 63
# Attacking sample 45/100 (True: 2, Index: 422)...
#   Success! Adv label: 3, L2: 585.11, Queries: 45
# Attacking sample 46/100 (True: 2, Index: 435)...
#   Success! Adv label: 3, L2: 808.00, Queries: 63
# Attacking sample 47/100 (True: 2, Index: 441)...
#   Success! Adv label: 8, L2: 837.96, Queries: 59
# Attacking sample 48/100 (True: 2, Index: 442)...
#   Success! Adv label: 7, L2: 604.52, Queries: 47
# Attacking sample 49/100 (True: 2, Index: 444)...
#   Success! Adv label: 8, L2: 918.00, Queries: 73
# Attacking sample 50/100 (True: 2, Index: 447)...
#   Success! Adv label: 3, L2: 690.49, Queries: 55
# Attacking sample 51/100 (True: 2, Index: 458)...
#   Success! Adv label: 3, L2: 386.63, Queries: 33
# Attacking sample 52/100 (True: 2, Index: 463)...
#   Success! Adv label: 3, L2: 747.60, Queries: 59
# Attacking sample 53/100 (True: 2, Index: 471)...
#   Success! Adv label: 3, L2: 919.07, Queries: 77
# Attacking sample 54/100 (True: 2, Index: 475)...
#   Success! Adv label: 3, L2: 1122.93, Queries: 89
# Attacking sample 55/100 (True: 2, Index: 482)...
#   Success! Adv label: 4, L2: 309.15, Queries: 23
# Attacking sample 56/100 (True: 2, Index: 490)...
#   Success! Adv label: 3, L2: 470.29, Queries: 37
# Attacking sample 57/100 (True: 2, Index: 491)...
#   Success! Adv label: 8, L2: 420.60, Queries: 29
# Attacking sample 58/100 (True: 2, Index: 494)...
#   Success! Adv label: 7, L2: 704.78, Queries: 59
# Attacking sample 59/100 (True: 2, Index: 514)...
#   Success! Adv label: 3, L2: 567.02, Queries: 45
# Attacking sample 60/100 (True: 2, Index: 542)...
#   Success! Adv label: 4, L2: 207.05, Queries: 17
# Attacking sample 61/100 (True: 2, Index: 558)...
#   Success! Adv label: 3, L2: 696.62, Queries: 55
# Attacking sample 62/100 (True: 2, Index: 587)...
#   Success! Adv label: 8, L2: 896.07, Queries: 65
# Attacking sample 63/100 (True: 2, Index: 597)...
#   Success! Adv label: 3, L2: 806.70, Queries: 65
# Attacking sample 64/100 (True: 2, Index: 626)...
#   Success! Adv label: 3, L2: 449.69, Queries: 37
# Attacking sample 65/100 (True: 2, Index: 663)...
#   Success! Adv label: 3, L2: 202.45, Queries: 15
# Attacking sample 66/100 (True: 2, Index: 679)...
#   Success! Adv label: 3, L2: 1274.70, Queries: 99
# Attacking sample 67/100 (True: 2, Index: 712)...
#   Success! Adv label: 3, L2: 55.44, Queries: 5
# Attacking sample 68/100 (True: 2, Index: 729)...
#   Success! Adv label: 8, L2: 606.11, Queries: 41
# Attacking sample 69/100 (True: 2, Index: 738)...
#   Success! Adv label: 8, L2: 360.21, Queries: 25
# Attacking sample 70/100 (True: 2, Index: 742)...
#   Success! Adv label: 4, L2: 465.35, Queries: 37
# Attacking sample 71/100 (True: 2, Index: 745)...
#   Success! Adv label: 1, L2: 815.03, Queries: 73
# Attacking sample 72/100 (True: 2, Index: 756)...
#   Success! Adv label: 7, L2: 455.30, Queries: 37
# Attacking sample 73/100 (True: 2, Index: 760)...
#   Success! Adv label: 8, L2: 640.20, Queries: 43
# Attacking sample 74/100 (True: 2, Index: 768)...
#   Failed! Adv label: 2, L2: 1258.73, Queries: 201
# Attacking sample 75/100 (True: 2, Index: 775)...
#   Success! Adv label: 3, L2: 781.19, Queries: 57
# Attacking sample 76/100 (True: 2, Index: 781)...
#   Success! Adv label: 3, L2: 467.16, Queries: 35
# Attacking sample 77/100 (True: 2, Index: 787)...
#   Success! Adv label: 3, L2: 821.04, Queries: 63
# Attacking sample 78/100 (True: 2, Index: 794)...
#   Success! Adv label: 3, L2: 646.66, Queries: 47
# Attacking sample 79/100 (True: 2, Index: 806)...
#   Success! Adv label: 3, L2: 486.54, Queries: 37
# Attacking sample 80/100 (True: 2, Index: 808)...
#   Success! Adv label: 3, L2: 1014.18, Queries: 79
# Attacking sample 81/100 (True: 2, Index: 809)...
#   Success! Adv label: 8, L2: 800.61, Queries: 55
# Attacking sample 82/100 (True: 2, Index: 824)...
#   Success! Adv label: 3, L2: 952.45, Queries: 81
# Attacking sample 83/100 (True: 2, Index: 830)...
#   Success! Adv label: 3, L2: 977.41, Queries: 71
# Attacking sample 84/100 (True: 2, Index: 836)...
#   Success! Adv label: 8, L2: 493.39, Queries: 35
# Attacking sample 85/100 (True: 2, Index: 839)...
#   Success! Adv label: 3, L2: 597.98, Queries: 45
# Attacking sample 86/100 (True: 2, Index: 843)...
#   Success! Adv label: 1, L2: 913.96, Queries: 87
# Attacking sample 87/100 (True: 2, Index: 848)...
#   Success! Adv label: 1, L2: 655.34, Queries: 59
# Attacking sample 88/100 (True: 2, Index: 863)...
#   Success! Adv label: 3, L2: 513.54, Queries: 39
# Attacking sample 89/100 (True: 2, Index: 869)...
#   Success! Adv label: 8, L2: 284.88, Queries: 21
# Attacking sample 90/100 (True: 2, Index: 871)...
#   Success! Adv label: 3, L2: 860.56, Queries: 75
# Attacking sample 91/100 (True: 2, Index: 878)...
#   Success! Adv label: 9, L2: 444.00, Queries: 33
# Attacking sample 92/100 (True: 2, Index: 886)...
#   Success! Adv label: 1, L2: 886.72, Queries: 83
# Attacking sample 93/100 (True: 2, Index: 888)...
#   Success! Adv label: 8, L2: 794.57, Queries: 59
# Attacking sample 94/100 (True: 2, Index: 893)...
#   Success! Adv label: 4, L2: 150.68, Queries: 11
# Attacking sample 95/100 (True: 2, Index: 913)...
#   Success! Adv label: 1, L2: 956.78, Queries: 89
# Attacking sample 96/100 (True: 2, Index: 916)...
#   Success! Adv label: 3, L2: 375.82, Queries: 27
# Attacking sample 97/100 (True: 2, Index: 922)...
#   Success! Adv label: 8, L2: 870.17, Queries: 69
# Attacking sample 98/100 (True: 2, Index: 933)...
#   Success! Adv label: 3, L2: 978.45, Queries: 81
# Attacking sample 99/100 (True: 2, Index: 958)...
#   Success! Adv label: 3, L2: 918.71, Queries: 75
# Attacking sample 100/100 (True: 2, Index: 965)...
#   Success! Adv label: 8, L2: 406.06, Queries: 29
# Attacking sample 1/100 (True: 3, Index: 32)...
#   Success! Adv label: 8, L2: 884.53, Queries: 69
# Attacking sample 2/100 (True: 3, Index: 33)...
#   Success! Adv label: 9, L2: 628.49, Queries: 49
# Attacking sample 3/100 (True: 3, Index: 51)...
#   Success! Adv label: 2, L2: 799.51, Queries: 63
# Attacking sample 4/100 (True: 3, Index: 66)...
#   Success! Adv label: 5, L2: 390.48, Queries: 31
# Attacking sample 5/100 (True: 3, Index: 74)...
#   Success! Adv label: 8, L2: 273.24, Queries: 19
# Attacking sample 6/100 (True: 3, Index: 76)...
#   Success! Adv label: 8, L2: 263.38, Queries: 21
# Attacking sample 7/100 (True: 3, Index: 81)...
#   Success! Adv label: 2, L2: 563.56, Queries: 55
# Attacking sample 8/100 (True: 3, Index: 82)...
#   Success! Adv label: 8, L2: 532.56, Queries: 37
# Attacking sample 9/100 (True: 3, Index: 85)...
#   Success! Adv label: 8, L2: 472.47, Queries: 43
# Attacking sample 10/100 (True: 3, Index: 91)...
#   Success! Adv label: 8, L2: 461.87, Queries: 35
# Attacking sample 12/100 (True: 3, Index: 122)...
#   Success! Adv label: 7, L2: 1061.80, Queries: 103
# Attacking sample 13/100 (True: 3, Index: 133)...
#   Success! Adv label: 8, L2: 682.78, Queries: 55
# Attacking sample 14/100 (True: 3, Index: 137)...
#   Success! Adv label: 2, L2: 656.41, Queries: 47
# Attacking sample 15/100 (True: 3, Index: 147)...
#   Success! Adv label: 2, L2: 442.76, Queries: 33
# Attacking sample 16/100 (True: 3, Index: 152)...
#   Success! Adv label: 8, L2: 98.34, Queries: 7
# Attacking sample 17/100 (True: 3, Index: 162)...
#   Success! Adv label: 9, L2: 771.67, Queries: 63
# Attacking sample 18/100 (True: 3, Index: 167)...
#   Success! Adv label: 9, L2: 413.78, Queries: 35
# Attacking sample 19/100 (True: 3, Index: 211)...
#   Success! Adv label: 5, L2: 527.92, Queries: 41
# Attacking sample 20/100 (True: 3, Index: 215)...
#   Success! Adv label: 9, L2: 804.65, Queries: 65
# Attacking sample 21/100 (True: 3, Index: 216)...
#   Success! Adv label: 9, L2: 477.41, Queries: 35
# Attacking sample 22/100 (True: 3, Index: 247)...
#   Success! Adv label: 8, L2: 103.74, Queries: 7
# Attacking sample 23/100 (True: 3, Index: 248)...
#   Success! Adv label: 2, L2: 391.59, Queries: 29
# Attacking sample 24/100 (True: 3, Index: 255)...
#   Success! Adv label: 8, L2: 484.11, Queries: 35
# Attacking sample 25/100 (True: 3, Index: 262)...
#   Success! Adv label: 8, L2: 801.08, Queries: 63
# Attacking sample 26/100 (True: 3, Index: 270)...
#   Success! Adv label: 9, L2: 587.17, Queries: 41
# Attacking sample 27/100 (True: 3, Index: 279)...
#   Success! Adv label: 8, L2: 615.31, Queries: 47
# Attacking sample 28/100 (True: 3, Index: 285)...
#   Success! Adv label: 5, L2: 635.88, Queries: 53
# Attacking sample 29/100 (True: 3, Index: 286)...
#   Success! Adv label: 7, L2: 931.29, Queries: 95
# Attacking sample 30/100 (True: 3, Index: 303)...
#   Success! Adv label: 7, L2: 470.06, Queries: 39
# Attacking sample 31/100 (True: 3, Index: 310)...
#   Success! Adv label: 9, L2: 506.73, Queries: 45
# Attacking sample 32/100 (True: 3, Index: 311)...
#   Success! Adv label: 9, L2: 445.24, Queries: 35
# Attacking sample 33/100 (True: 3, Index: 314)...
#   Success! Adv label: 8, L2: 855.26, Queries: 77
# Attacking sample 35/100 (True: 3, Index: 337)...
#   Success! Adv label: 8, L2: 710.29, Queries: 51
# Attacking sample 36/100 (True: 3, Index: 340)...
#   Success! Adv label: 8, L2: 703.92, Queries: 51
# Attacking sample 37/100 (True: 3, Index: 343)...
#   Success! Adv label: 8, L2: 393.50, Queries: 27
# Attacking sample 38/100 (True: 3, Index: 347)...
#   Success! Adv label: 5, L2: 434.00, Queries: 35
# Attacking sample 39/100 (True: 3, Index: 361)...
#   Success! Adv label: 8, L2: 536.71, Queries: 37
# Attacking sample 40/100 (True: 3, Index: 364)...
#   Success! Adv label: 9, L2: 836.67, Queries: 65
# Attacking sample 41/100 (True: 3, Index: 366)...
#   Success! Adv label: 8, L2: 476.89, Queries: 33
# Attacking sample 42/100 (True: 3, Index: 383)...
#   Success! Adv label: 0, L2: 910.90, Queries: 69
# Attacking sample 43/100 (True: 3, Index: 385)...
#   Success! Adv label: 5, L2: 622.80, Queries: 51
# Attacking sample 44/100 (True: 3, Index: 400)...
#   Success! Adv label: 9, L2: 643.23, Queries: 51
# Attacking sample 45/100 (True: 3, Index: 401)...
#   Success! Adv label: 8, L2: 472.80, Queries: 35
# Attacking sample 46/100 (True: 3, Index: 403)...
#   Success! Adv label: 5, L2: 605.20, Queries: 47
# Attacking sample 47/100 (True: 3, Index: 405)...
#   Success! Adv label: 9, L2: 366.44, Queries: 27
# Attacking sample 48/100 (True: 3, Index: 412)...
#   Success! Adv label: 7, L2: 1082.07, Queries: 143
# Attacking sample 49/100 (True: 3, Index: 424)...
#   Success! Adv label: 2, L2: 577.91, Queries: 41
# Attacking sample 50/100 (True: 3, Index: 433)...
#   Failed! Adv label: 3, L2: 1124.46, Queries: 201
# Attacking sample 51/100 (True: 3, Index: 438)...
#   Success! Adv label: 8, L2: 670.45, Queries: 51
# Attacking sample 52/100 (True: 3, Index: 459)...
#   Success! Adv label: 8, L2: 278.31, Queries: 23
# Attacking sample 53/100 (True: 3, Index: 464)...
#   Success! Adv label: 2, L2: 538.33, Queries: 41
# Attacking sample 54/100 (True: 3, Index: 481)...
#   Success! Adv label: 7, L2: 718.47, Queries: 69
# Attacking sample 55/100 (True: 3, Index: 500)...
#   Success! Adv label: 7, L2: 237.75, Queries: 21
# Attacking sample 56/100 (True: 3, Index: 507)...
#   Success! Adv label: 5, L2: 579.82, Queries: 45
# Attacking sample 57/100 (True: 3, Index: 510)...
#   Failed! Adv label: 3, L2: 1197.82, Queries: 201
# Attacking sample 58/100 (True: 3, Index: 517)...
#   Success! Adv label: 5, L2: 713.01, Queries: 63
# Attacking sample 59/100 (True: 3, Index: 530)...
#   Success! Adv label: 9, L2: 401.50, Queries: 31
# Attacking sample 60/100 (True: 3, Index: 544)...
#   Success! Adv label: 5, L2: 713.20, Queries: 61
# Attacking sample 61/100 (True: 3, Index: 556)...
#   Success! Adv label: 5, L2: 1001.96, Queries: 83
# Attacking sample 62/100 (True: 3, Index: 567)...
#   Success! Adv label: 7, L2: 585.18, Queries: 53
# Attacking sample 63/100 (True: 3, Index: 576)...
#   Failed! Adv label: 3, L2: 1149.03, Queries: 201
# Attacking sample 64/100 (True: 3, Index: 586)...
#   Success! Adv label: 8, L2: 579.53, Queries: 43
# Attacking sample 65/100 (True: 3, Index: 618)...
#   Success! Adv label: 8, L2: 280.29, Queries: 21
# Attacking sample 66/100 (True: 3, Index: 625)...
#   Success! Adv label: 2, L2: 490.03, Queries: 37
# Attacking sample 67/100 (True: 3, Index: 635)...
#   Success! Adv label: 8, L2: 379.87, Queries: 27
# Attacking sample 68/100 (True: 3, Index: 642)...
#   Success! Adv label: 7, L2: 877.09, Queries: 73
# Attacking sample 69/100 (True: 3, Index: 650)...
#   Success! Adv label: 2, L2: 538.79, Queries: 41
# Attacking sample 70/100 (True: 3, Index: 670)...
#   Success! Adv label: 5, L2: 533.71, Queries: 47
# Attacking sample 71/100 (True: 3, Index: 677)...
#   Success! Adv label: 8, L2: 433.97, Queries: 33
# Attacking sample 72/100 (True: 3, Index: 681)...
#   Success! Adv label: 7, L2: 1050.78, Queries: 143
# Attacking sample 73/100 (True: 3, Index: 691)...
#   Success! Adv label: 7, L2: 999.59, Queries: 129
# Attacking sample 74/100 (True: 3, Index: 695)...
#   Success! Adv label: 9, L2: 505.54, Queries: 41
# Attacking sample 75/100 (True: 3, Index: 709)...
#   Success! Adv label: 9, L2: 609.85, Queries: 49
# Attacking sample 76/100 (True: 3, Index: 714)...
#   Failed! Adv label: 3, L2: 1107.98, Queries: 201
# Attacking sample 77/100 (True: 3, Index: 718)...
#   Success! Adv label: 2, L2: 709.10, Queries: 59
# Attacking sample 78/100 (True: 3, Index: 741)...
#   Success! Adv label: 8, L2: 564.99, Queries: 43
# Attacking sample 79/100 (True: 3, Index: 746)...
#   Success! Adv label: 5, L2: 787.20, Queries: 65
# Attacking sample 80/100 (True: 3, Index: 769)...
#   Failed! Adv label: 3, L2: 1088.30, Queries: 201
# Attacking sample 81/100 (True: 3, Index: 777)...
#   Success! Adv label: 5, L2: 1217.10, Queries: 157
# Attacking sample 82/100 (True: 3, Index: 793)...
#   Success! Adv label: 5, L2: 616.47, Queries: 49
# Attacking sample 83/100 (True: 3, Index: 837)...
#   Success! Adv label: 2, L2: 951.28, Queries: 83
# Attacking sample 84/100 (True: 3, Index: 850)...
#   Success! Adv label: 8, L2: 674.39, Queries: 47
# Attacking sample 85/100 (True: 3, Index: 851)...
#   Success! Adv label: 8, L2: 728.54, Queries: 55
# Attacking sample 86/100 (True: 3, Index: 854)...
#   Success! Adv label: 7, L2: 195.36, Queries: 15
# Attacking sample 87/100 (True: 3, Index: 859)...
#   Success! Adv label: 8, L2: 562.77, Queries: 43
# Attacking sample 88/100 (True: 3, Index: 867)...
#   Success! Adv label: 8, L2: 454.81, Queries: 31
# Attacking sample 89/100 (True: 3, Index: 874)...
#   Success! Adv label: 9, L2: 554.45, Queries: 43
# Attacking sample 90/100 (True: 3, Index: 885)...
#   Success! Adv label: 2, L2: 555.73, Queries: 41
# Attacking sample 91/100 (True: 3, Index: 906)...
#   Success! Adv label: 5, L2: 416.49, Queries: 31
# Attacking sample 92/100 (True: 3, Index: 915)...
#   Success! Adv label: 9, L2: 490.03, Queries: 37
# Attacking sample 93/100 (True: 3, Index: 942)...
#   Failed! Adv label: 3, L2: 1133.30, Queries: 201
# Attacking sample 94/100 (True: 3, Index: 951)...
#   Success! Adv label: 8, L2: 940.50, Queries: 79
# Attacking sample 95/100 (True: 3, Index: 952)...
#   Success! Adv label: 5, L2: 254.44, Queries: 21
# Attacking sample 96/100 (True: 3, Index: 976)...
#   Success! Adv label: 8, L2: 822.32, Queries: 59
# Attacking sample 97/100 (True: 3, Index: 982)...
#   Success! Adv label: 8, L2: 470.04, Queries: 33
# Attacking sample 98/100 (True: 3, Index: 991)...
#   Success! Adv label: 5, L2: 524.66, Queries: 39
# Attacking sample 99/100 (True: 3, Index: 998)...
#   Failed! Adv label: 3, L2: 1148.66, Queries: 201
# Attacking sample 100/100 (True: 3, Index: 1004)...
#   Success! Adv label: 5, L2: 596.01, Queries: 49
# Attacking sample 1/100 (True: 4, Index: 55)...
#   Success! Adv label: 9, L2: 470.50, Queries: 33
# Attacking sample 2/100 (True: 4, Index: 62)...
#   Success! Adv label: 9, L2: 201.80, Queries: 15
# Attacking sample 3/100 (True: 4, Index: 68)...
#   Success! Adv label: 9, L2: 356.63, Queries: 25
# Attacking sample 4/100 (True: 4, Index: 69)...
#   Success! Adv label: 9, L2: 237.50, Queries: 17
# Attacking sample 5/100 (True: 4, Index: 83)...
#   Success! Adv label: 9, L2: 313.17, Queries: 23
# Attacking sample 6/100 (True: 4, Index: 103)...
#   Success! Adv label: 9, L2: 450.78, Queries: 33
# Attacking sample 7/100 (True: 4, Index: 107)...
#   Success! Adv label: 7, L2: 1054.13, Queries: 97
# Attacking sample 8/100 (True: 4, Index: 108)...
#   Success! Adv label: 6, L2: 698.96, Queries: 51
# Attacking sample 9/100 (True: 4, Index: 109)...
#   Success! Adv label: 9, L2: 478.19, Queries: 33
# Attacking sample 10/100 (True: 4, Index: 116)...
#   Success! Adv label: 9, L2: 177.63, Queries: 13
# Attacking sample 11/100 (True: 4, Index: 129)...
#   Success! Adv label: 8, L2: 447.02, Queries: 31
# Attacking sample 12/100 (True: 4, Index: 144)...
#   Success! Adv label: 9, L2: 319.69, Queries: 23
# Attacking sample 13/100 (True: 4, Index: 145)...
#   Success! Adv label: 9, L2: 209.00, Queries: 15
# Attacking sample 14/100 (True: 4, Index: 171)...
#   Success! Adv label: 9, L2: 538.44, Queries: 39
# Attacking sample 15/100 (True: 4, Index: 197)...
#   Success! Adv label: 9, L2: 352.02, Queries: 25
# Attacking sample 16/100 (True: 4, Index: 199)...
#   Success! Adv label: 9, L2: 993.32, Queries: 71
# Attacking sample 17/100 (True: 4, Index: 205)...
#   Success! Adv label: 9, L2: 478.97, Queries: 35
# Attacking sample 18/100 (True: 4, Index: 221)...
#   Success! Adv label: 9, L2: 655.57, Queries: 47
# Attacking sample 19/100 (True: 4, Index: 227)...
#   Success! Adv label: 9, L2: 560.25, Queries: 39
# Attacking sample 20/100 (True: 4, Index: 228)...
#   Success! Adv label: 7, L2: 299.49, Queries: 23
# Attacking sample 21/100 (True: 4, Index: 237)...
#   Success! Adv label: 9, L2: 599.23, Queries: 45
# Attacking sample 23/100 (True: 4, Index: 271)...
#   Success! Adv label: 7, L2: 588.37, Queries: 43
# Attacking sample 24/100 (True: 4, Index: 283)...
#   Success! Adv label: 8, L2: 468.63, Queries: 35
# Attacking sample 25/100 (True: 4, Index: 300)...
#   Success! Adv label: 8, L2: 884.84, Queries: 63
# Attacking sample 26/100 (True: 4, Index: 302)...
#   Success! Adv label: 9, L2: 590.68, Queries: 41
# Attacking sample 27/100 (True: 4, Index: 323)...
#   Success! Adv label: 7, L2: 621.78, Queries: 51
# Attacking sample 28/100 (True: 4, Index: 325)...
#   Success! Adv label: 9, L2: 495.57, Queries: 37
# Attacking sample 29/100 (True: 4, Index: 332)...
#   Success! Adv label: 3, L2: 643.56, Queries: 53
# Attacking sample 30/100 (True: 4, Index: 346)...
#   Success! Adv label: 9, L2: 659.76, Queries: 49
# Attacking sample 31/100 (True: 4, Index: 355)...
#   Success! Adv label: 9, L2: 703.21, Queries: 51
# Attacking sample 32/100 (True: 4, Index: 373)...
#   Success! Adv label: 9, L2: 34.34, Queries: 3
# Attacking sample 33/100 (True: 4, Index: 389)...
#   Success! Adv label: 9, L2: 403.10, Queries: 27
# Attacking sample 34/100 (True: 4, Index: 399)...
#   Success! Adv label: 9, L2: 728.42, Queries: 51
# Attacking sample 35/100 (True: 4, Index: 419)...
#   Success! Adv label: 9, L2: 394.24, Queries: 27
# Attacking sample 36/100 (True: 4, Index: 431)...
#   Success! Adv label: 7, L2: 445.56, Queries: 37
# Attacking sample 37/100 (True: 4, Index: 443)...
#   Success! Adv label: 9, L2: 394.72, Queries: 29
# Attacking sample 38/100 (True: 4, Index: 457)...
#   Success! Adv label: 8, L2: 350.40, Queries: 25
# Attacking sample 39/100 (True: 4, Index: 465)...
#   Success! Adv label: 9, L2: 640.49, Queries: 43
# Attacking sample 40/100 (True: 4, Index: 484)...
#   Success! Adv label: 9, L2: 423.40, Queries: 29
# Attacking sample 41/100 (True: 4, Index: 496)...
#   Success! Adv label: 9, L2: 489.23, Queries: 37
# Attacking sample 42/100 (True: 4, Index: 516)...
#   Success! Adv label: 9, L2: 506.87, Queries: 39
# Attacking sample 43/100 (True: 4, Index: 547)...
#   Success! Adv label: 9, L2: 565.48, Queries: 41
# Attacking sample 44/100 (True: 4, Index: 552)...
#   Success! Adv label: 9, L2: 508.59, Queries: 37
# Attacking sample 45/100 (True: 4, Index: 554)...
#   Success! Adv label: 9, L2: 157.40, Queries: 11
# Attacking sample 46/100 (True: 4, Index: 560)...
#   Success! Adv label: 7, L2: 655.12, Queries: 55
# Attacking sample 47/100 (True: 4, Index: 572)...
#   Success! Adv label: 9, L2: 281.64, Queries: 21
# Attacking sample 48/100 (True: 4, Index: 584)...
#   Success! Adv label: 8, L2: 652.49, Queries: 47
# Attacking sample 49/100 (True: 4, Index: 589)...
#   Success! Adv label: 9, L2: 476.92, Queries: 33
# Attacking sample 50/100 (True: 4, Index: 591)...
#   Success! Adv label: 9, L2: 573.21, Queries: 43
# Attacking sample 51/100 (True: 4, Index: 599)...
#   Success! Adv label: 9, L2: 461.50, Queries: 33
# Attacking sample 52/100 (True: 4, Index: 603)...
#   Success! Adv label: 9, L2: 732.17, Queries: 55
# Attacking sample 53/100 (True: 4, Index: 622)...
#   Success! Adv label: 9, L2: 292.68, Queries: 21
# Attacking sample 54/100 (True: 4, Index: 624)...
#   Success! Adv label: 7, L2: 679.15, Queries: 51
# Attacking sample 55/100 (True: 4, Index: 644)...
#   Success! Adv label: 9, L2: 319.14, Queries: 23
# Attacking sample 56/100 (True: 4, Index: 652)...
#   Success! Adv label: 7, L2: 592.90, Queries: 51
# Attacking sample 57/100 (True: 4, Index: 653)...
#   Success! Adv label: 9, L2: 141.53, Queries: 11
# Attacking sample 58/100 (True: 4, Index: 671)...
#   Success! Adv label: 8, L2: 180.81, Queries: 13
# Attacking sample 59/100 (True: 4, Index: 675)...
#   Success! Adv label: 9, L2: 203.54, Queries: 15
# Attacking sample 60/100 (True: 4, Index: 693)...
#   Success! Adv label: 7, L2: 449.72, Queries: 37
# Attacking sample 61/100 (True: 4, Index: 713)...
#   Success! Adv label: 9, L2: 563.29, Queries: 43
# Attacking sample 62/100 (True: 4, Index: 720)...
#   Success! Adv label: 8, L2: 562.70, Queries: 41
# Attacking sample 63/100 (True: 4, Index: 739)...
#   Success! Adv label: 9, L2: 390.29, Queries: 29
# Attacking sample 64/100 (True: 4, Index: 747)...
#   Success! Adv label: 7, L2: 618.94, Queries: 47
# Attacking sample 65/100 (True: 4, Index: 761)...
#   Success! Adv label: 9, L2: 322.90, Queries: 23
# Attacking sample 66/100 (True: 4, Index: 774)...
#   Success! Adv label: 9, L2: 217.38, Queries: 17
# Attacking sample 67/100 (True: 4, Index: 780)...
#   Success! Adv label: 9, L2: 430.96, Queries: 31
# Attacking sample 68/100 (True: 4, Index: 790)...
#   Success! Adv label: 9, L2: 154.74, Queries: 11
# Attacking sample 69/100 (True: 4, Index: 797)...
#   Success! Adv label: 9, L2: 356.25, Queries: 25
# Attacking sample 70/100 (True: 4, Index: 833)...
#   Success! Adv label: 7, L2: 915.98, Queries: 73
# Attacking sample 71/100 (True: 4, Index: 844)...
#   Success! Adv label: 6, L2: 358.10, Queries: 27
# Attacking sample 72/100 (True: 4, Index: 864)...
#   Success! Adv label: 9, L2: 521.32, Queries: 41
# Attacking sample 73/100 (True: 4, Index: 872)...
#   Success! Adv label: 8, L2: 521.87, Queries: 39
# Attacking sample 74/100 (True: 4, Index: 875)...
#   Success! Adv label: 8, L2: 863.17, Queries: 63
# Attacking sample 75/100 (True: 4, Index: 881)...
#   Success! Adv label: 8, L2: 876.50, Queries: 65
# Attacking sample 76/100 (True: 4, Index: 905)...
#   Success! Adv label: 8, L2: 531.25, Queries: 39
# Attacking sample 77/100 (True: 4, Index: 907)...
#   Success! Adv label: 2, L2: 546.96, Queries: 43
# Attacking sample 78/100 (True: 4, Index: 910)...
#   Success! Adv label: 9, L2: 662.31, Queries: 47
# Attacking sample 79/100 (True: 4, Index: 932)...
#   Success! Adv label: 2, L2: 1092.48, Queries: 87
# Attacking sample 80/100 (True: 4, Index: 939)...
#   Success! Adv label: 9, L2: 563.23, Queries: 41
# Attacking sample 81/100 (True: 4, Index: 940)...
#   Success! Adv label: 9, L2: 557.73, Queries: 43
# Attacking sample 82/100 (True: 4, Index: 946)...
#   Success! Adv label: 9, L2: 205.29, Queries: 15
# Attacking sample 83/100 (True: 4, Index: 949)...
#   Success! Adv label: 9, L2: 270.26, Queries: 19
# Attacking sample 84/100 (True: 4, Index: 960)...
#   Success! Adv label: 7, L2: 1160.49, Queries: 113
# Attacking sample 85/100 (True: 4, Index: 983)...
#   Success! Adv label: 9, L2: 414.79, Queries: 29
# Attacking sample 86/100 (True: 4, Index: 986)...
#   Success! Adv label: 8, L2: 460.95, Queries: 35
# Attacking sample 87/100 (True: 4, Index: 996)...
#   Success! Adv label: 9, L2: 416.67, Queries: 31
# Attacking sample 88/100 (True: 4, Index: 1014)...
#   Success! Adv label: 6, L2: 753.49, Queries: 57
# Attacking sample 89/100 (True: 4, Index: 1017)...
#   Success! Adv label: 9, L2: 518.65, Queries: 37
# Attacking sample 90/100 (True: 4, Index: 1021)...
#   Success! Adv label: 9, L2: 93.71, Queries: 7
# Attacking sample 91/100 (True: 4, Index: 1043)...
#   Success! Adv label: 9, L2: 282.79, Queries: 21
# Attacking sample 92/100 (True: 4, Index: 1051)...
#   Success! Adv label: 3, L2: 879.86, Queries: 75
# ...
#   Success! Adv label: 3, L2: 631.91, Queries: 53
# Attacking sample 42/100 (True: 8, Index: 376)...
#   Success! Adv label: 3, L2: 546.56, Queries: 47
# Attacking sample 43/100 (True: 8, Index: 388)...
#   Success! Adv label: 2, L2: 989.41, Queries: 81
# Attacking sample 44/100 (True: 8, Index: 395)...
#   Success! Adv label: 5, L2: 396.67, Queries: 31
# Attacking sample 45/100 (True: 8, Index: 396)...
#   Success! Adv label: 9, L2: 1182.77, Queries: 99
# Attacking sample 46/100 (True: 8, Index: 413)...
#   Success! Adv label: 6, L2: 776.78, Queries: 65
# Attacking sample 47/100 (True: 8, Index: 417)...
#   Success! Adv label: 5, L2: 676.39, Queries: 57
# Attacking sample 48/100 (True: 8, Index: 420)...
#   Success! Adv label: 2, L2: 660.01, Queries: 51
# Attacking sample 49/100 (True: 8, Index: 427)...
#   Success! Adv label: 0, L2: 922.79, Queries: 79
# Attacking sample 50/100 (True: 8, Index: 474)...
#   Success! Adv label: 2, L2: 674.39, Queries: 59
# Attacking sample 51/100 (True: 8, Index: 486)...
#   Success! Adv label: 9, L2: 606.65, Queries: 49
# Attacking sample 52/100 (True: 8, Index: 498)...
#   Success! Adv label: 2, L2: 489.62, Queries: 41
# Attacking sample 53/100 (True: 8, Index: 501)...
#   Success! Adv label: 2, L2: 713.02, Queries: 61
# Attacking sample 54/100 (True: 8, Index: 515)...
#   Success! Adv label: 2, L2: 258.71, Queries: 21
# Attacking sample 55/100 (True: 8, Index: 527)...
#   Success! Adv label: 0, L2: 503.59, Queries: 43
# Attacking sample 56/100 (True: 8, Index: 536)...
#   Success! Adv label: 3, L2: 644.15, Queries: 59
# Attacking sample 57/100 (True: 8, Index: 538)...
#   Success! Adv label: 2, L2: 620.78, Queries: 49
# Attacking sample 58/100 (True: 8, Index: 546)...
#   Success! Adv label: 9, L2: 686.27, Queries: 55
# Attacking sample 59/100 (True: 8, Index: 557)...
#   Success! Adv label: 5, L2: 691.24, Queries: 55
# Attacking sample 60/100 (True: 8, Index: 570)...
#   Success! Adv label: 3, L2: 830.53, Queries: 67
# Attacking sample 61/100 (True: 8, Index: 571)...
#   Success! Adv label: 5, L2: 180.86, Queries: 15
# Attacking sample 62/100 (True: 8, Index: 592)...
#   Success! Adv label: 5, L2: 632.62, Queries: 55
# Attacking sample 63/100 (True: 8, Index: 594)...
#   Success! Adv label: 9, L2: 399.80, Queries: 29
# Attacking sample 64/100 (True: 8, Index: 611)...
#   Success! Adv label: 2, L2: 723.46, Queries: 63
# Attacking sample 65/100 (True: 8, Index: 621)...
#   Success! Adv label: 3, L2: 565.47, Queries: 45
# Attacking sample 66/100 (True: 8, Index: 628)...
#   Success! Adv label: 9, L2: 1073.65, Queries: 95
# Attacking sample 67/100 (True: 8, Index: 633)...
#   Success! Adv label: 2, L2: 976.66, Queries: 83
# Attacking sample 68/100 (True: 8, Index: 640)...
#   Success! Adv label: 3, L2: 738.29, Queries: 63
# Attacking sample 69/100 (True: 8, Index: 659)...
#   Success! Adv label: 2, L2: 576.54, Queries: 47
# Attacking sample 70/100 (True: 8, Index: 666)...
#   Success! Adv label: 2, L2: 577.60, Queries: 49
# Attacking sample 71/100 (True: 8, Index: 672)...
#   Success! Adv label: 3, L2: 824.63, Queries: 69
# Attacking sample 72/100 (True: 8, Index: 686)...
#   Success! Adv label: 5, L2: 546.70, Queries: 43
# Attacking sample 73/100 (True: 8, Index: 698)...
#   Success! Adv label: 6, L2: 238.68, Queries: 19
# Attacking sample 74/100 (True: 8, Index: 700)...
#   Success! Adv label: 9, L2: 507.85, Queries: 41
# Attacking sample 75/100 (True: 8, Index: 717)...
#   Success! Adv label: 3, L2: 581.40, Queries: 43
# Attacking sample 76/100 (True: 8, Index: 721)...
#   Success! Adv label: 3, L2: 311.86, Queries: 25
# Attacking sample 77/100 (True: 8, Index: 762)...
#   Success! Adv label: 2, L2: 730.61, Queries: 63
# Attacking sample 78/100 (True: 8, Index: 772)...
#   Success! Adv label: 1, L2: 576.81, Queries: 51
# Attacking sample 79/100 (True: 8, Index: 785)...
#   Success! Adv label: 2, L2: 598.70, Queries: 49
# Attacking sample 80/100 (True: 8, Index: 800)...
#   Success! Adv label: 2, L2: 621.38, Queries: 49
# Attacking sample 81/100 (True: 8, Index: 814)...
#   Success! Adv label: 3, L2: 840.23, Queries: 79
# Attacking sample 82/100 (True: 8, Index: 815)...
#   Success! Adv label: 3, L2: 655.34, Queries: 53
# Attacking sample 83/100 (True: 8, Index: 841)...
#   Success! Adv label: 3, L2: 804.94, Queries: 77
# Attacking sample 84/100 (True: 8, Index: 847)...
#   Success! Adv label: 2, L2: 853.22, Queries: 73
# Attacking sample 85/100 (True: 8, Index: 858)...
#   Success! Adv label: 6, L2: 492.76, Queries: 39
# Attacking sample 86/100 (True: 8, Index: 862)...
#   Success! Adv label: 9, L2: 492.98, Queries: 39
# Attacking sample 87/100 (True: 8, Index: 868)...
#   Success! Adv label: 9, L2: 514.93, Queries: 45
# Attacking sample 88/100 (True: 8, Index: 876)...
#   Success! Adv label: 2, L2: 791.03, Queries: 69
# Attacking sample 89/100 (True: 8, Index: 908)...
#   Success! Adv label: 2, L2: 611.45, Queries: 55
# Attacking sample 90/100 (True: 8, Index: 926)...
#   Success! Adv label: 2, L2: 1079.89, Queries: 93
# Attacking sample 91/100 (True: 8, Index: 934)...
#   Success! Adv label: 6, L2: 683.37, Queries: 57
# Attacking sample 92/100 (True: 8, Index: 943)...
#   Success! Adv label: 2, L2: 672.31, Queries: 57
# Attacking sample 93/100 (True: 8, Index: 947)...
#   Success! Adv label: 3, L2: 507.52, Queries: 43
# Attacking sample 94/100 (True: 8, Index: 948)...
#   Success! Adv label: 2, L2: 679.80, Queries: 59
# Attacking sample 95/100 (True: 8, Index: 953)...
#   Success! Adv label: 2, L2: 1052.44, Queries: 95
# Attacking sample 96/100 (True: 8, Index: 954)...
#   Success! Adv label: 3, L2: 505.97, Queries: 43
# Attacking sample 97/100 (True: 8, Index: 962)...
#   Success! Adv label: 3, L2: 426.73, Queries: 33
# Attacking sample 98/100 (True: 8, Index: 963)...
#   Success! Adv label: 3, L2: 556.73, Queries: 49
# Attacking sample 99/100 (True: 8, Index: 966)...
#   Success! Adv label: 9, L2: 531.81, Queries: 47
# Attacking sample 100/100 (True: 8, Index: 980)...
#   Success! Adv label: 2, L2: 545.54, Queries: 43
# Attacking sample 1/100 (True: 9, Index: 3)...
#   Success! Adv label: 7, L2: 706.10, Queries: 67
# Attacking sample 2/100 (True: 9, Index: 27)...
#   Success! Adv label: 3, L2: 836.67, Queries: 61
# Attacking sample 3/100 (True: 9, Index: 36)...
#   Success! Adv label: 8, L2: 405.51, Queries: 29
# Attacking sample 4/100 (True: 9, Index: 42)...
#   Success! Adv label: 4, L2: 617.88, Queries: 51
# Attacking sample 5/100 (True: 9, Index: 48)...
#   Success! Adv label: 4, L2: 438.69, Queries: 41
# Attacking sample 6/100 (True: 9, Index: 59)...
#   Success! Adv label: 3, L2: 372.12, Queries: 31
# Attacking sample 7/100 (True: 9, Index: 60)...
#   Success! Adv label: 3, L2: 88.82, Queries: 7
# Attacking sample 8/100 (True: 9, Index: 65)...
#   Success! Adv label: 3, L2: 522.33, Queries: 39
# Attacking sample 9/100 (True: 9, Index: 101)...
#   Success! Adv label: 7, L2: 160.65, Queries: 13
# Attacking sample 10/100 (True: 9, Index: 105)...
#   Success! Adv label: 0, L2: 403.07, Queries: 29
# Attacking sample 11/100 (True: 9, Index: 128)...
#   Success! Adv label: 4, L2: 784.75, Queries: 63
# Attacking sample 12/100 (True: 9, Index: 138)...
#   Success! Adv label: 8, L2: 437.14, Queries: 31
# Attacking sample 13/100 (True: 9, Index: 140)...
#   Success! Adv label: 8, L2: 619.63, Queries: 45
# Attacking sample 14/100 (True: 9, Index: 142)...
#   Success! Adv label: 5, L2: 611.82, Queries: 45
# Attacking sample 15/100 (True: 9, Index: 160)...
#   Success! Adv label: 4, L2: 408.12, Queries: 33
# Attacking sample 16/100 (True: 9, Index: 178)...
#   Success! Adv label: 7, L2: 424.99, Queries: 33
# Attacking sample 17/100 (True: 9, Index: 212)...
#   Success! Adv label: 8, L2: 615.38, Queries: 47
# Attacking sample 18/100 (True: 9, Index: 222)...
#   Success! Adv label: 8, L2: 241.47, Queries: 19
# Attacking sample 19/100 (True: 9, Index: 225)...
#   Success! Adv label: 5, L2: 633.39, Queries: 47
# Attacking sample 20/100 (True: 9, Index: 233)...
#   Success! Adv label: 8, L2: 752.44, Queries: 55
# Attacking sample 21/100 (True: 9, Index: 253)...
#   Success! Adv label: 7, L2: 581.62, Queries: 47
# Attacking sample 22/100 (True: 9, Index: 260)...
#   Success! Adv label: 8, L2: 546.11, Queries: 39
# Attacking sample 23/100 (True: 9, Index: 264)...
#   Success! Adv label: 8, L2: 643.15, Queries: 47
# Attacking sample 24/100 (True: 9, Index: 265)...
#   Success! Adv label: 4, L2: 702.45, Queries: 57
# Attacking sample 25/100 (True: 9, Index: 267)...
#   Success! Adv label: 3, L2: 328.51, Queries: 25
# Attacking sample 26/100 (True: 9, Index: 280)...
#   Success! Adv label: 5, L2: 585.14, Queries: 43
# Attacking sample 27/100 (True: 9, Index: 291)...
#   Success! Adv label: 8, L2: 359.74, Queries: 25
# Attacking sample 28/100 (True: 9, Index: 299)...
#   Success! Adv label: 4, L2: 394.28, Queries: 29
# Attacking sample 29/100 (True: 9, Index: 307)...
#   Success! Adv label: 4, L2: 317.88, Queries: 25
# Attacking sample 30/100 (True: 9, Index: 318)...
#   Success! Adv label: 8, L2: 439.69, Queries: 35
# Attacking sample 31/100 (True: 9, Index: 319)...
#   Success! Adv label: 7, L2: 424.54, Queries: 37
# Attacking sample 32/100 (True: 9, Index: 330)...
#   Success! Adv label: 7, L2: 56.96, Queries: 5
# Attacking sample 33/100 (True: 9, Index: 341)...
#   Success! Adv label: 4, L2: 688.99, Queries: 57
# Attacking sample 34/100 (True: 9, Index: 345)...
#   Success! Adv label: 5, L2: 565.33, Queries: 47
# Attacking sample 35/100 (True: 9, Index: 353)...
#   Success! Adv label: 8, L2: 714.25, Queries: 55
# Attacking sample 36/100 (True: 9, Index: 374)...
#   Success! Adv label: 8, L2: 446.54, Queries: 35
# Attacking sample 37/100 (True: 9, Index: 404)...
#   Success! Adv label: 4, L2: 445.07, Queries: 33
# Attacking sample 38/100 (True: 9, Index: 406)...
#   Success! Adv label: 8, L2: 370.40, Queries: 27
# Attacking sample 39/100 (True: 9, Index: 414)...
#   Success! Adv label: 4, L2: 149.31, Queries: 13
# Attacking sample 40/100 (True: 9, Index: 439)...
#   Success! Adv label: 4, L2: 595.18, Queries: 43
# Attacking sample 41/100 (True: 9, Index: 445)...
#   Success! Adv label: 7, L2: 311.72, Queries: 25
# Attacking sample 42/100 (True: 9, Index: 446)...
#   Success! Adv label: 4, L2: 320.21, Queries: 25
# Attacking sample 43/100 (True: 9, Index: 468)...
#   Success! Adv label: 8, L2: 554.57, Queries: 45
# Attacking sample 44/100 (True: 9, Index: 473)...
#   Success! Adv label: 4, L2: 391.85, Queries: 29
# Attacking sample 45/100 (True: 9, Index: 513)...
#   Success! Adv label: 7, L2: 452.85, Queries: 37
# Attacking sample 46/100 (True: 9, Index: 529)...
#   Success! Adv label: 4, L2: 340.07, Queries: 25
# Attacking sample 47/100 (True: 9, Index: 539)...
#   Success! Adv label: 4, L2: 553.50, Queries: 49
# Attacking sample 48/100 (True: 9, Index: 540)...
#   Success! Adv label: 4, L2: 527.37, Queries: 43
# Attacking sample 49/100 (True: 9, Index: 562)...
#   Success! Adv label: 7, L2: 629.65, Queries: 51
# Attacking sample 50/100 (True: 9, Index: 565)...
#   Success! Adv label: 8, L2: 301.35, Queries: 23
# Attacking sample 51/100 (True: 9, Index: 569)...
#   Success! Adv label: 3, L2: 453.61, Queries: 37
# Attacking sample 52/100 (True: 9, Index: 582)...
#   Success! Adv label: 0, L2: 438.87, Queries: 35
# Attacking sample 53/100 (True: 9, Index: 588)...
#   Success! Adv label: 4, L2: 400.26, Queries: 31
# Attacking sample 54/100 (True: 9, Index: 614)...
#   Success! Adv label: 8, L2: 672.69, Queries: 51
# Attacking sample 55/100 (True: 9, Index: 620)...
#   Success! Adv label: 8, L2: 444.66, Queries: 31
# Attacking sample 56/100 (True: 9, Index: 639)...
#   Success! Adv label: 4, L2: 835.55, Queries: 65
# Attacking sample 57/100 (True: 9, Index: 645)...
#   Success! Adv label: 7, L2: 428.84, Queries: 33
# Attacking sample 58/100 (True: 9, Index: 647)...
#   Success! Adv label: 7, L2: 373.21, Queries: 31
# Attacking sample 59/100 (True: 9, Index: 649)...
#   Success! Adv label: 7, L2: 213.06, Queries: 17
# Attacking sample 60/100 (True: 9, Index: 673)...
#   Success! Adv label: 7, L2: 794.26, Queries: 67
# Attacking sample 61/100 (True: 9, Index: 684)...
#   Success! Adv label: 3, L2: 210.96, Queries: 17
# Attacking sample 62/100 (True: 9, Index: 688)...
#   Success! Adv label: 2, L2: 275.10, Queries: 21
# Attacking sample 63/100 (True: 9, Index: 690)...
#   Success! Adv label: 5, L2: 636.06, Queries: 49
# Attacking sample 64/100 (True: 9, Index: 699)...
#   Success! Adv label: 7, L2: 247.72, Queries: 19
# Attacking sample 65/100 (True: 9, Index: 705)...
#   Success! Adv label: 8, L2: 466.46, Queries: 33
# Attacking sample 66/100 (True: 9, Index: 706)...
#   Success! Adv label: 7, L2: 578.39, Queries: 49
# Attacking sample 67/100 (True: 9, Index: 711)...
#   Success! Adv label: 4, L2: 381.79, Queries: 31
# Attacking sample 68/100 (True: 9, Index: 724)...
#   Success! Adv label: 4, L2: 667.36, Queries: 55
# Attacking sample 69/100 (True: 9, Index: 730)...
#   Success! Adv label: 0, L2: 35.71, Queries: 3
# Attacking sample 70/100 (True: 9, Index: 731)...
#   Success! Adv label: 4, L2: 244.83, Queries: 19
# Attacking sample 71/100 (True: 9, Index: 748)...
#   Success! Adv label: 7, L2: 402.45, Queries: 31
# Attacking sample 72/100 (True: 9, Index: 751)...
#   Success! Adv label: 8, L2: 837.12, Queries: 65
# Attacking sample 73/100 (True: 9, Index: 752)...
#   Success! Adv label: 4, L2: 445.18, Queries: 33
# Attacking sample 74/100 (True: 9, Index: 753)...
#   Success! Adv label: 3, L2: 451.16, Queries: 35
# Attacking sample 75/100 (True: 9, Index: 842)...
#   Success! Adv label: 0, L2: 535.17, Queries: 41
# Attacking sample 76/100 (True: 9, Index: 845)...
#   Success! Adv label: 8, L2: 631.14, Queries: 47
# Attacking sample 77/100 (True: 9, Index: 870)...
#   Success! Adv label: 3, L2: 277.41, Queries: 21
# Attacking sample 78/100 (True: 9, Index: 873)...
#   Success! Adv label: 4, L2: 641.80, Queries: 53
# Attacking sample 79/100 (True: 9, Index: 889)...
#   Success! Adv label: 3, L2: 256.75, Queries: 19
# Attacking sample 80/100 (True: 9, Index: 898)...
#   Success! Adv label: 8, L2: 398.04, Queries: 29
# Attacking sample 81/100 (True: 9, Index: 912)...
#   Success! Adv label: 8, L2: 565.28, Queries: 41
# Attacking sample 82/100 (True: 9, Index: 921)...
#   Success! Adv label: 5, L2: 650.20, Queries: 47
# Attacking sample 83/100 (True: 9, Index: 935)...
#   Success! Adv label: 4, L2: 536.42, Queries: 43
# Attacking sample 84/100 (True: 9, Index: 937)...
#   Success! Adv label: 4, L2: 542.25, Queries: 45
# Attacking sample 85/100 (True: 9, Index: 941)...
#   Success! Adv label: 4, L2: 595.29, Queries: 47
# Attacking sample 86/100 (True: 9, Index: 973)...
#   Success! Adv label: 4, L2: 783.03, Queries: 65
# Attacking sample 87/100 (True: 9, Index: 974)...
#   Success! Adv label: 4, L2: 762.07, Queries: 61
# Attacking sample 88/100 (True: 9, Index: 979)...
#   Success! Adv label: 8, L2: 650.86, Queries: 47
# Attacking sample 89/100 (True: 9, Index: 988)...
#   Success! Adv label: 7, L2: 632.71, Queries: 51
# Attacking sample 90/100 (True: 9, Index: 1003)...
#   Success! Adv label: 3, L2: 483.71, Queries: 37
# Attacking sample 91/100 (True: 9, Index: 1011)...
#   Success! Adv label: 4, L2: 399.11, Queries: 31
# Attacking sample 92/100 (True: 9, Index: 1018)...
#   Success! Adv label: 3, L2: 405.46, Queries: 31
# Attacking sample 93/100 (True: 9, Index: 1024)...
#   Success! Adv label: 3, L2: 390.01, Queries: 29
# Attacking sample 94/100 (True: 9, Index: 1029)...
#   Success! Adv label: 7, L2: 522.77, Queries: 41
# Attacking sample 95/100 (True: 9, Index: 1032)...
#   Success! Adv label: 8, L2: 367.22, Queries: 25
# Attacking sample 96/100 (True: 9, Index: 1040)...
#   Success! Adv label: 8, L2: 610.96, Queries: 49
# Attacking sample 97/100 (True: 9, Index: 1053)...
#   Success! Adv label: 8, L2: 468.34, Queries: 35
# Attacking sample 98/100 (True: 9, Index: 1062)...
#   Success! Adv label: 4, L2: 406.24, Queries: 31
# Attacking sample 99/100 (True: 9, Index: 1066)...
#   Success! Adv label: 4, L2: 399.64, Queries: 31
# Attacking sample 100/100 (True: 9, Index: 1092)...
#   Success! Adv label: 5, L2: 445.61, Queries: 35
# Time taken to generate adversarial samples: 120.6764 seconds
#
# Stats saved to: adversarial_8bit_train_images\per_sample_stats.csv
#
# ===== Attack Summary =====
# Total trials: 995
# Misclassified before attack: 5
# Success rate: 986/995 (99.1%)
# Mean L2 (successful): 547.09
# Mean queries (successful): 43.10
#
# Showing successful adversarial examples...

# %% [markdown]
# ### Untargeted Attack on test set

# %%
import os
import warnings
import numpy as np
import torch
import joblib
import pandas as pd
from PIL import Image
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import torch.nn.functional as F
import time


# Set seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# ─────────────── PATHS ────────────────────────────────────────────────────
LENET_MODEL_PATH = os.path.normpath("Models and Data splits/lenet.pt")  # TorchScript model
DATA_PKL = os.path.normpath("Models and Data splits/data_[SCALED] Train_Test_Splits.pkl")
RF_ALL_CLASSES_PATH = os.path.normpath("Models and Data splits/random_forest.pkl")
OUT_DIR = "adversarial_8bit_test_images"
os.makedirs(OUT_DIR, exist_ok=True)

if not os.path.exists(RF_ALL_CLASSES_PATH):
    raise FileNotFoundError(f"Random Forest model not found at {RF_ALL_CLASSES_PATH}")

# ─────────── HYPER-PARAMETERS ─────────────────────────────────────────────
EPSILON_STEP = 0.01
ITERATIONS = 100
TOTAL_EPSILON = 0.5
TOP_K_FEATURES = 196
SAMPLES_PER_DIGIT = 100
MAX_L2 = 10000

def plot_adversarial_example(original_img, adv_img, true_label, adv_label, l2_mag, sample_idx, queries, title_suffix=""):
    if original_img.size == 784:
        original_img = original_img.reshape(28, 28)
    if adv_img.size == 784:
        adv_img = adv_img.reshape(28, 28)
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(original_img, cmap='gray')
    axes[0].set_title(f"Original\nTrue: {true_label}")
    axes[0].axis('off')
    axes[1].imshow(adv_img, cmap='gray')
    axes[1].set_title(f"Adversarial\nPred: {adv_label}")
    axes[1].axis('off')
    fig.suptitle(f"Sample {sample_idx} | L2: {l2_mag:.2f} | Queries: {queries} {title_suffix}")
    plt.show()
    plt.close(fig)  # <-- added here


# ─────────── Load Data ─────────────────────────────────────────────────────
try:
    data = joblib.load(DATA_PKL)
    _, X_samples , _, y_samples = data
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PKL}. Please check the path.")
    exit()

if X_samples.max() > 1.0:
    X_samples = X_samples.astype(np.float32) / 255.0
    warnings.warn("Data appeared in [0,255]; normalized to [0,1].")

# ─────────── Load TorchScripted LeNet ──────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
try:
    model = torch.jit.load(LENET_MODEL_PATH, map_location=device)
    model.eval()
    print(f"LeNet TorchScript model loaded from: {LENET_MODEL_PATH}")
except Exception as e:
    print(f"Error loading TorchScript LeNet model: {e}")
    exit()

def to_model(x01_batch):
    if x01_batch.ndim == 2 and x01_batch.shape == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)
    elif x01_batch.ndim == 3 and x01_batch.shape[1:] == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(1)
    elif x01_batch.ndim == 4 and x01_batch.shape[1] == 1:
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device)
    elif x01_batch.ndim == 1 and x01_batch.size == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(1, 1, 28, 28), dtype=torch.float32, device=device)
    elif x01_batch.ndim == 2 and x01_batch.shape[1] == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(x01_batch.shape[0], 1, 28, 28), dtype=torch.float32, device=device)
    else:
        raise ValueError(f"Unsupported input shape for to_model: {x01_batch.shape}")
    return tensor_batch


def model_query(x_tensor_batch):
    with torch.no_grad():
        return model(x_tensor_batch)

# ─────────── Load Random Forest Model ──────────────────────────────────────
rf_all_classes = None
top_feature_indices = None
print("Loading Random Forest Classifier for all classes...")
try:
    rf_all_classes = joblib.load(RF_ALL_CLASSES_PATH)
    feature_importances = rf_all_classes.feature_importances_
    #top_feature_indices = np.argsort(feature_importances)[:TOP_K_FEATURES]
    
    top_feature_indices = np.argsort(-feature_importances)[:TOP_K_FEATURES]
    print(f"Random Forest loaded. Using top {TOP_K_FEATURES} features.")
except Exception as e:
    print(f"Error loading Random Forest: {e}")
    top_feature_indices = np.arange(28 * 28)

# ─────────── I-FGSM Attack ─────────────────────────────────────────────────
def ifgsm_attack(original_image_np, true_label, model_target, epsilon_step, iterations,
                 total_epsilon_budget, features_to_perturb, query_count_tracker):
    if original_image_np.ndim == 1 and original_image_np.size == 784:
        original_image_np = original_image_np.reshape(28, 28)

    perturbed_image_np = original_image_np.copy()
    final_pred_label = true_label

    for i in range(iterations):
        image_tensor = to_model(perturbed_image_np)
        image_tensor.requires_grad = True
        output = model_target(image_tensor)
        query_count_tracker[0] += 1
        loss = F.cross_entropy(output, torch.tensor([true_label], device=device))
        model_target.zero_grad()
        loss.backward()
        data_grad_sign = torch.sign(image_tensor.grad.data).cpu().numpy()

        gradient_mask = np.zeros_like(data_grad_sign, dtype=np.float32)
        h, w = perturbed_image_np.shape
        rows, cols = np.unravel_index(features_to_perturb, (h, w))
        gradient_mask[0, 0, rows, cols] = data_grad_sign[0, 0, rows, cols]
        gradient_mask_for_update = gradient_mask.reshape(perturbed_image_np.shape)

        perturbed_image_np += epsilon_step * gradient_mask_for_update
        perturbation = perturbed_image_np - original_image_np
        perturbation = np.clip(perturbation, -total_epsilon_budget, total_epsilon_budget)
        perturbed_image_np = original_image_np + perturbation
        perturbed_image_np = np.clip(perturbed_image_np, 0, 1)

        # Discretize and check prediction on discretized image
        adv_uint8_temp = np.round(perturbed_image_np * 255).astype(np.uint8)
        adv_float_temp = adv_uint8_temp.astype(np.float32) / 255.0
        with torch.no_grad():
            output_temp = model_target(to_model(adv_float_temp))
            pred_temp = output_temp.argmax(dim=1).item()
            query_count_tracker[0] += 1

        if pred_temp != true_label:
            final_pred_label = pred_temp
            break

    # Final adversarial image (discretized)
    adv_uint8 = np.round(perturbed_image_np * 255).astype(np.uint8)
    adv_float = adv_uint8.astype(np.float32) / 255.0
    with torch.no_grad():
        output_final = model_target(to_model(adv_float))
        final_pred_label = output_final.argmax(dim=1).item()

    l2_norm = np.linalg.norm(adv_uint8.astype(np.float32) - (original_image_np * 255).astype(np.float32))
    success = (final_pred_label != true_label) and (l2_norm <= MAX_L2)

    return adv_uint8, final_pred_label, l2_norm, success


# ─────────── Attack Execution ──────────────────────────────────────────────
print(f"\n===== Starting Adversarial Attack =====")
total_trials, succ_total, misclassified = 0, 0, 0
records = []


start_time = time.time()


for digit in range(10):
    idxs = np.where(y_samples == digit)[0][:SAMPLES_PER_DIGIT]
    for rank, idx in enumerate(idxs, 1):
        x0 = X_samples[idx].copy()
        y0 = int(y_samples[idx])
        query_count_tracker = [0]
        pred0 = model_query(to_model(x0)).argmax(dim=1).item()
        query_count_tracker[0] += 1

        if pred0 != y0:
            misclassified += 1
            records.append({
                'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
                'adv_label': None, 'success': False, 'queries': query_count_tracker[0],
                'l2_mag': np.nan, 'note': 'Already misclassified'
            })
            continue

        total_trials += 1
        print(f"Attacking sample {rank}/{SAMPLES_PER_DIGIT} (True: {y0}, Index: {idx})...")
        adv_img_uint8, adv_label, l2_mag, success = ifgsm_attack(
            x0, y0, model, EPSILON_STEP, ITERATIONS, TOTAL_EPSILON,
            top_feature_indices, query_count_tracker
        )

        if success:
            succ_total += 1
            fname = f"true{y0}_adv{adv_label}_mag{l2_mag:.1f}_sample{idx}.png"
            Image.fromarray(adv_img_uint8, mode="L").save(os.path.join(OUT_DIR, fname))

        records.append({
            'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
            'adv_label': adv_label, 'success': success, 'queries': query_count_tracker[0],
            'l2_mag': l2_mag if success else np.nan, 'note': 'I-FGSM' + (' successful' if success else ' failed')
        })

        print(f"  {'Success' if success else 'Failed'}! Adv label: {adv_label}, L2: {l2_mag:.2f}, Queries: {query_count_tracker[0]}")


end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to generate adversarial samples: {elapsed_time:.4f} seconds")


# ─────────── Save Results ──────────────────────────────────────────────────
df = pd.DataFrame(records)
csv_path = os.path.join(OUT_DIR, "per_sample_stats.csv")
df.to_csv(csv_path, index=False)
print(f"\nStats saved to: {csv_path}")

# ─────────── Summary ───────────────────────────────────────────────────────
print(f"\n===== Attack Summary =====")
print(f"Total trials: {total_trials}")
print(f"Misclassified before attack: {misclassified}")
if total_trials > 0:
    success_rate = succ_total / total_trials * 100
    print(f"Success rate: {succ_total}/{total_trials} ({success_rate:.1f}%)")
    if succ_total > 0:
        print(f"Mean L2 (successful): {df[df['success']]['l2_mag'].mean():.2f}")
        print(f"Mean queries (successful): {df[df['success']]['queries'].mean():.2f}")

# ─────────── Display Examples ──────────────────────────────────────────────
success_df = df[df['success']]
if not success_df.empty:
    print("\nShowing successful adversarial examples...")
    show_ids = success_df.sample(min(3, len(success_df))).index.tolist()
    for record_idx in show_ids:
        r = df.loc[record_idx]
        fname_prefix = f"true{r['true_label']}_adv{r['adv_label']}_mag{r['l2_mag']:.1f}_sample{r['sample_idx']}"
        match_files = [f for f in os.listdir(OUT_DIR) if f.startswith(fname_prefix)]
        if match_files:
            adv_img_path = os.path.join(OUT_DIR, match_files[0])
            plot_adversarial_example(X_samples[r['sample_idx']], np.array(Image.open(adv_img_path)),
                                     r['true_label'], r['adv_label'], r['l2_mag'],
                                     r['sample_idx'], r['queries'], "(I-FGSM)")
else:
    print("No successful attacks to display. Showing original samples instead.")
    for i in range(min(3, len(df))):
        r = df.iloc[i]
        plot_adversarial_example(X_samples[r['sample_idx']], X_samples[r['sample_idx']],
                                 r['true_label'], r['initial_pred'], 0.0,
                                 r['sample_idx'], r['queries'], "(Original)")
# Out:
# LeNet TorchScript model loaded from: Models and Data splits\lenet.pt
# Loading Random Forest Classifier for all classes...
# Random Forest loaded. Using top 196 features.
#
# ===== Starting Adversarial Attack =====
# Attacking sample 1/100 (True: 0, Index: 29)...
#   Success! Adv label: 6, L2: 855.04, Queries: 73
# Attacking sample 2/100 (True: 0, Index: 40)...
#   Success! Adv label: 6, L2: 1022.48, Queries: 85
# Attacking sample 3/100 (True: 0, Index: 44)...
#   Success! Adv label: 5, L2: 555.39, Queries: 45
# Attacking sample 4/100 (True: 0, Index: 59)...
#   Success! Adv label: 6, L2: 660.23, Queries: 55
# Attacking sample 5/100 (True: 0, Index: 64)...
#   Success! Adv label: 9, L2: 1150.88, Queries: 91
# Attacking sample 6/100 (True: 0, Index: 75)...
#   Success! Adv label: 8, L2: 717.72, Queries: 61
# Attacking sample 7/100 (True: 0, Index: 80)...
#   Success! Adv label: 9, L2: 592.91, Queries: 49
# Attacking sample 8/100 (True: 0, Index: 97)...
#   Success! Adv label: 6, L2: 628.93, Queries: 51
# Attacking sample 9/100 (True: 0, Index: 115)...
#   Success! Adv label: 6, L2: 843.45, Queries: 69
# Attacking sample 10/100 (True: 0, Index: 141)...
#   Success! Adv label: 7, L2: 196.63, Queries: 17
# Attacking sample 11/100 (True: 0, Index: 146)...
#   Success! Adv label: 5, L2: 810.05, Queries: 67
# Attacking sample 12/100 (True: 0, Index: 156)...
#   Success! Adv label: 9, L2: 1130.33, Queries: 127
# Attacking sample 13/100 (True: 0, Index: 173)...
#   Success! Adv label: 6, L2: 701.60, Queries: 65
# Attacking sample 14/100 (True: 0, Index: 175)...
#   Success! Adv label: 8, L2: 470.35, Queries: 37
# Attacking sample 15/100 (True: 0, Index: 193)...
#   Success! Adv label: 9, L2: 859.55, Queries: 81
# Attacking sample 16/100 (True: 0, Index: 200)...
#   Success! Adv label: 9, L2: 757.50, Queries: 63
# Attacking sample 17/100 (True: 0, Index: 205)...
#   Success! Adv label: 9, L2: 923.52, Queries: 79
# Attacking sample 18/100 (True: 0, Index: 210)...
#   Success! Adv label: 9, L2: 820.92, Queries: 69
# Attacking sample 19/100 (True: 0, Index: 221)...
#   Success! Adv label: 9, L2: 838.80, Queries: 63
# Attacking sample 20/100 (True: 0, Index: 229)...
#   Success! Adv label: 5, L2: 935.79, Queries: 83
# Attacking sample 21/100 (True: 0, Index: 249)...
#   Success! Adv label: 5, L2: 671.44, Queries: 61
# Attacking sample 22/100 (True: 0, Index: 258)...
#   Success! Adv label: 2, L2: 820.90, Queries: 67
# Attacking sample 23/100 (True: 0, Index: 275)...
#   Success! Adv label: 5, L2: 1115.92, Queries: 115
# Attacking sample 24/100 (True: 0, Index: 292)...
#   Success! Adv label: 2, L2: 944.11, Queries: 87
# Attacking sample 25/100 (True: 0, Index: 296)...
#   Success! Adv label: 9, L2: 676.96, Queries: 53
# Attacking sample 26/100 (True: 0, Index: 301)...
#   Success! Adv label: 9, L2: 575.64, Queries: 45
# Attacking sample 27/100 (True: 0, Index: 314)...
#   Success! Adv label: 6, L2: 746.86, Queries: 59
# Attacking sample 28/100 (True: 0, Index: 325)...
#   Success! Adv label: 9, L2: 1039.30, Queries: 89
# Attacking sample 29/100 (True: 0, Index: 333)...
#   Success! Adv label: 9, L2: 820.58, Queries: 73
# Attacking sample 30/100 (True: 0, Index: 345)...
#   Success! Adv label: 6, L2: 659.32, Queries: 51
# Attacking sample 31/100 (True: 0, Index: 349)...
#   Success! Adv label: 9, L2: 653.02, Queries: 51
# Attacking sample 32/100 (True: 0, Index: 360)...
#   Success! Adv label: 6, L2: 1065.84, Queries: 93
# Attacking sample 33/100 (True: 0, Index: 365)...
#   Success! Adv label: 5, L2: 931.42, Queries: 81
# Attacking sample 34/100 (True: 0, Index: 366)...
#   Success! Adv label: 9, L2: 857.38, Queries: 71
# Attacking sample 35/100 (True: 0, Index: 379)...
#   Success! Adv label: 9, L2: 959.79, Queries: 79
# Attacking sample 36/100 (True: 0, Index: 385)...
#   Failed! Adv label: 0, L2: 1212.08, Queries: 201
# Attacking sample 37/100 (True: 0, Index: 397)...
#   Success! Adv label: 2, L2: 953.49, Queries: 87
# Attacking sample 38/100 (True: 0, Index: 400)...
#   Success! Adv label: 9, L2: 1199.14, Queries: 99
# Attacking sample 39/100 (True: 0, Index: 405)...
#   Success! Adv label: 2, L2: 688.83, Queries: 51
# Attacking sample 40/100 (True: 0, Index: 410)...
#   Success! Adv label: 9, L2: 838.02, Queries: 69
# Attacking sample 41/100 (True: 0, Index: 420)...
#   Success! Adv label: 2, L2: 747.21, Queries: 65
# Attacking sample 42/100 (True: 0, Index: 424)...
#   Success! Adv label: 9, L2: 795.13, Queries: 65
# Attacking sample 43/100 (True: 0, Index: 447)...
#   Success! Adv label: 2, L2: 681.07, Queries: 55
# Attacking sample 44/100 (True: 0, Index: 453)...
#   Success! Adv label: 6, L2: 755.82, Queries: 63
# Attacking sample 45/100 (True: 0, Index: 457)...
#   Success! Adv label: 6, L2: 972.45, Queries: 81
# Attacking sample 46/100 (True: 0, Index: 466)...
#   Success! Adv label: 2, L2: 791.68, Queries: 65
# Attacking sample 47/100 (True: 0, Index: 475)...
#   Success! Adv label: 9, L2: 289.06, Queries: 23
# Attacking sample 48/100 (True: 0, Index: 483)...
#   Success! Adv label: 2, L2: 811.38, Queries: 69
# Attacking sample 49/100 (True: 0, Index: 484)...
#   Success! Adv label: 8, L2: 469.31, Queries: 33
# Attacking sample 50/100 (True: 0, Index: 486)...
#   Success! Adv label: 9, L2: 942.57, Queries: 87
# Attacking sample 51/100 (True: 0, Index: 487)...
#   Success! Adv label: 8, L2: 641.10, Queries: 51
# Attacking sample 52/100 (True: 0, Index: 489)...
#   Success! Adv label: 9, L2: 746.86, Queries: 63
# Attacking sample 53/100 (True: 0, Index: 492)...
#   Success! Adv label: 9, L2: 673.67, Queries: 53
# Attacking sample 54/100 (True: 0, Index: 506)...
#   Success! Adv label: 2, L2: 794.04, Queries: 59
# Attacking sample 55/100 (True: 0, Index: 513)...
#   Success! Adv label: 6, L2: 1282.57, Queries: 191
# Attacking sample 56/100 (True: 0, Index: 518)...
#   Success! Adv label: 5, L2: 940.92, Queries: 85
# Attacking sample 57/100 (True: 0, Index: 521)...
#   Success! Adv label: 5, L2: 1215.32, Queries: 111
# Attacking sample 58/100 (True: 0, Index: 527)...
#   Success! Adv label: 2, L2: 732.57, Queries: 59
# Attacking sample 59/100 (True: 0, Index: 529)...
#   Success! Adv label: 5, L2: 610.07, Queries: 55
# Attacking sample 60/100 (True: 0, Index: 531)...
#   Success! Adv label: 2, L2: 1060.70, Queries: 117
# Attacking sample 61/100 (True: 0, Index: 546)...
#   Success! Adv label: 9, L2: 749.88, Queries: 65
# Attacking sample 62/100 (True: 0, Index: 551)...
#   Success! Adv label: 6, L2: 377.59, Queries: 27
# Attacking sample 63/100 (True: 0, Index: 555)...
#   Success! Adv label: 6, L2: 828.65, Queries: 67
# Attacking sample 64/100 (True: 0, Index: 587)...
#   Success! Adv label: 2, L2: 856.23, Queries: 73
# Attacking sample 65/100 (True: 0, Index: 604)...
#   Success! Adv label: 2, L2: 791.92, Queries: 59
# Attacking sample 66/100 (True: 0, Index: 614)...
#   Success! Adv label: 2, L2: 1036.74, Queries: 91
# Attacking sample 67/100 (True: 0, Index: 615)...
#   Success! Adv label: 9, L2: 450.38, Queries: 35
# Attacking sample 68/100 (True: 0, Index: 618)...
#   Success! Adv label: 6, L2: 327.55, Queries: 25
# Attacking sample 69/100 (True: 0, Index: 638)...
#   Success! Adv label: 8, L2: 423.23, Queries: 31
# Attacking sample 70/100 (True: 0, Index: 642)...
#   Success! Adv label: 9, L2: 875.52, Queries: 81
# Attacking sample 71/100 (True: 0, Index: 655)...
#   Success! Adv label: 6, L2: 774.92, Queries: 59
# Attacking sample 72/100 (True: 0, Index: 658)...
#   Success! Adv label: 6, L2: 646.77, Queries: 49
# Attacking sample 73/100 (True: 0, Index: 665)...
#   Success! Adv label: 2, L2: 658.37, Queries: 51
# Attacking sample 74/100 (True: 0, Index: 671)...
#   Success! Adv label: 6, L2: 678.74, Queries: 51
# Attacking sample 75/100 (True: 0, Index: 681)...
#   Success! Adv label: 9, L2: 1066.37, Queries: 91
# Attacking sample 76/100 (True: 0, Index: 691)...
#   Success! Adv label: 2, L2: 641.32, Queries: 47
# Attacking sample 77/100 (True: 0, Index: 700)...
#   Success! Adv label: 5, L2: 536.05, Queries: 45
# Attacking sample 78/100 (True: 0, Index: 706)...
#   Success! Adv label: 2, L2: 826.43, Queries: 91
# Attacking sample 79/100 (True: 0, Index: 712)...
#   Success! Adv label: 3, L2: 1042.55, Queries: 97
# Attacking sample 80/100 (True: 0, Index: 713)...
#   Success! Adv label: 9, L2: 769.78, Queries: 61
# Attacking sample 81/100 (True: 0, Index: 736)...
#   Success! Adv label: 5, L2: 624.52, Queries: 51
# Attacking sample 82/100 (True: 0, Index: 742)...
#   Success! Adv label: 6, L2: 688.44, Queries: 59
# Attacking sample 83/100 (True: 0, Index: 744)...
#   Success! Adv label: 2, L2: 599.56, Queries: 47
# Attacking sample 84/100 (True: 0, Index: 760)...
#   Success! Adv label: 9, L2: 671.90, Queries: 57
# Attacking sample 85/100 (True: 0, Index: 772)...
#   Success! Adv label: 9, L2: 338.81, Queries: 25
# Attacking sample 86/100 (True: 0, Index: 781)...
#   Success! Adv label: 6, L2: 475.19, Queries: 39
# Attacking sample 87/100 (True: 0, Index: 809)...
#   Success! Adv label: 5, L2: 584.77, Queries: 49
# Attacking sample 88/100 (True: 0, Index: 813)...
#   Success! Adv label: 9, L2: 545.52, Queries: 45
# Attacking sample 89/100 (True: 0, Index: 820)...
#   Success! Adv label: 9, L2: 641.15, Queries: 55
# Attacking sample 90/100 (True: 0, Index: 823)...
#   Success! Adv label: 5, L2: 700.38, Queries: 63
# Attacking sample 91/100 (True: 0, Index: 844)...
#   Success! Adv label: 9, L2: 1123.17, Queries: 133
# Attacking sample 92/100 (True: 0, Index: 848)...
#   Success! Adv label: 9, L2: 332.87, Queries: 25
# Attacking sample 93/100 (True: 0, Index: 861)...
#   Success! Adv label: 6, L2: 939.56, Queries: 69
# Attacking sample 94/100 (True: 0, Index: 865)...
#   Success! Adv label: 6, L2: 1189.73, Queries: 89
# Attacking sample 95/100 (True: 0, Index: 869)...
#   Success! Adv label: 6, L2: 963.26, Queries: 81
# Attacking sample 96/100 (True: 0, Index: 876)...
#   Success! Adv label: 9, L2: 671.50, Queries: 53
# Attacking sample 97/100 (True: 0, Index: 885)...
#   Success! Adv label: 9, L2: 1087.87, Queries: 145
# Attacking sample 98/100 (True: 0, Index: 906)...
#   Success! Adv label: 2, L2: 890.77, Queries: 73
# Attacking sample 99/100 (True: 0, Index: 907)...
#   Success! Adv label: 9, L2: 757.31, Queries: 61
# Attacking sample 100/100 (True: 0, Index: 918)...
#   Success! Adv label: 9, L2: 930.68, Queries: 77
# Attacking sample 1/100 (True: 1, Index: 2)...
#   Success! Adv label: 7, L2: 277.05, Queries: 19
# Attacking sample 2/100 (True: 1, Index: 3)...
#   Success! Adv label: 7, L2: 334.21, Queries: 23
# Attacking sample 3/100 (True: 1, Index: 9)...
#   Success! Adv label: 8, L2: 357.36, Queries: 27
# Attacking sample 4/100 (True: 1, Index: 25)...
#   Success! Adv label: 8, L2: 344.89, Queries: 23
# Attacking sample 5/100 (True: 1, Index: 36)...
#   Success! Adv label: 2, L2: 270.44, Queries: 19
# Attacking sample 6/100 (True: 1, Index: 63)...
#   Success! Adv label: 8, L2: 261.97, Queries: 19
# Attacking sample 7/100 (True: 1, Index: 65)...
#   Success! Adv label: 8, L2: 335.11, Queries: 23
# Attacking sample 8/100 (True: 1, Index: 68)...
#   Success! Adv label: 8, L2: 344.58, Queries: 23
# Attacking sample 9/100 (True: 1, Index: 76)...
#   Success! Adv label: 8, L2: 211.19, Queries: 15
# Attacking sample 10/100 (True: 1, Index: 83)...
#   Success! Adv label: 4, L2: 381.09, Queries: 27
# Attacking sample 11/100 (True: 1, Index: 90)...
#   Success! Adv label: 9, L2: 34.84, Queries: 3
# Attacking sample 12/100 (True: 1, Index: 94)...
#   Success! Adv label: 8, L2: 184.77, Queries: 13
# Attacking sample 13/100 (True: 1, Index: 100)...
#   Success! Adv label: 8, L2: 242.89, Queries: 17
# Attacking sample 14/100 (True: 1, Index: 123)...
#   Success! Adv label: 8, L2: 179.77, Queries: 13
# Attacking sample 15/100 (True: 1, Index: 150)...
#   Success! Adv label: 8, L2: 312.50, Queries: 21
# Attacking sample 16/100 (True: 1, Index: 152)...
#   Success! Adv label: 9, L2: 351.96, Queries: 25
# Attacking sample 17/100 (True: 1, Index: 178)...
#   Success! Adv label: 4, L2: 343.76, Queries: 23
# Attacking sample 18/100 (True: 1, Index: 185)...
#   Success! Adv label: 8, L2: 355.18, Queries: 27
# Attacking sample 19/100 (True: 1, Index: 191)...
#   Success! Adv label: 4, L2: 408.64, Queries: 27
# Attacking sample 20/100 (True: 1, Index: 201)...
#   Success! Adv label: 8, L2: 305.17, Queries: 21
# Attacking sample 21/100 (True: 1, Index: 203)...
#   Success! Adv label: 8, L2: 243.39, Queries: 17
# Attacking sample 22/100 (True: 1, Index: 213)...
#   Success! Adv label: 8, L2: 271.07, Queries: 19
# Attacking sample 23/100 (True: 1, Index: 220)...
#   Success! Adv label: 8, L2: 217.41, Queries: 15
# Attacking sample 24/100 (True: 1, Index: 223)...
#   Success! Adv label: 4, L2: 330.00, Queries: 23
# Attacking sample 25/100 (True: 1, Index: 226)...
#   Success! Adv label: 4, L2: 349.70, Queries: 23
# Attacking sample 26/100 (True: 1, Index: 232)...
#   Success! Adv label: 8, L2: 433.10, Queries: 29
# Attacking sample 27/100 (True: 1, Index: 241)...
#   Success! Adv label: 4, L2: 283.75, Queries: 19
# Attacking sample 28/100 (True: 1, Index: 254)...
#   Success! Adv label: 8, L2: 282.38, Queries: 19
# Attacking sample 29/100 (True: 1, Index: 281)...
#   Success! Adv label: 8, L2: 266.32, Queries: 19
# Attacking sample 30/100 (True: 1, Index: 284)...
#   Success! Adv label: 8, L2: 310.63, Queries: 23
# Attacking sample 31/100 (True: 1, Index: 285)...
#   Success! Adv label: 9, L2: 210.93, Queries: 15
# Attacking sample 32/100 (True: 1, Index: 286)...
#   Success! Adv label: 4, L2: 306.29, Queries: 21
# Attacking sample 33/100 (True: 1, Index: 287)...
#   Success! Adv label: 4, L2: 322.32, Queries: 23
# Attacking sample 34/100 (True: 1, Index: 294)...
#   Success! Adv label: 4, L2: 369.14, Queries: 25
# Attacking sample 35/100 (True: 1, Index: 298)...
#   Success! Adv label: 7, L2: 439.54, Queries: 29
# Attacking sample 36/100 (True: 1, Index: 306)...
#   Success! Adv label: 4, L2: 367.41, Queries: 25
# Attacking sample 37/100 (True: 1, Index: 312)...
#   Success! Adv label: 8, L2: 320.16, Queries: 23
# Attacking sample 38/100 (True: 1, Index: 317)...
#   Success! Adv label: 4, L2: 355.76, Queries: 25
# Attacking sample 39/100 (True: 1, Index: 334)...
#   Success! Adv label: 4, L2: 374.79, Queries: 25
# Attacking sample 40/100 (True: 1, Index: 337)...
#   Success! Adv label: 8, L2: 337.92, Queries: 23
# Attacking sample 41/100 (True: 1, Index: 338)...
#   Success! Adv label: 8, L2: 462.76, Queries: 31
# Attacking sample 42/100 (True: 1, Index: 348)...
#   Success! Adv label: 2, L2: 424.56, Queries: 29
# Attacking sample 43/100 (True: 1, Index: 361)...
#   Success! Adv label: 8, L2: 241.82, Queries: 17
# Attacking sample 44/100 (True: 1, Index: 363)...
#   Success! Adv label: 8, L2: 337.75, Queries: 23
# Attacking sample 45/100 (True: 1, Index: 367)...
#   Success! Adv label: 8, L2: 185.40, Queries: 13
# Attacking sample 46/100 (True: 1, Index: 375)...
#   Success! Adv label: 7, L2: 395.03, Queries: 27
# Attacking sample 47/100 (True: 1, Index: 384)...
#   Success! Adv label: 8, L2: 247.86, Queries: 17
# Attacking sample 48/100 (True: 1, Index: 412)...
#   Success! Adv label: 8, L2: 371.29, Queries: 25
# Attacking sample 49/100 (True: 1, Index: 425)...
#   Success! Adv label: 7, L2: 376.60, Queries: 25
# Attacking sample 50/100 (True: 1, Index: 428)...
#   Success! Adv label: 4, L2: 346.65, Queries: 23
# Attacking sample 51/100 (True: 1, Index: 463)...
#   Success! Adv label: 8, L2: 273.84, Queries: 19
# Attacking sample 52/100 (True: 1, Index: 499)...
#   Success! Adv label: 4, L2: 407.59, Queries: 27
# Attacking sample 53/100 (True: 1, Index: 502)...
#   Success! Adv label: 4, L2: 387.63, Queries: 27
# Attacking sample 54/100 (True: 1, Index: 526)...
#   Success! Adv label: 8, L2: 243.03, Queries: 17
# Attacking sample 55/100 (True: 1, Index: 532)...
#   Success! Adv label: 4, L2: 346.11, Queries: 23
# Attacking sample 56/100 (True: 1, Index: 536)...
#   Success! Adv label: 9, L2: 256.01, Queries: 19
# Attacking sample 57/100 (True: 1, Index: 537)...
#   Success! Adv label: 8, L2: 301.28, Queries: 21
# Attacking sample 58/100 (True: 1, Index: 539)...
#   Success! Adv label: 4, L2: 374.83, Queries: 25
# Attacking sample 60/100 (True: 1, Index: 560)...
#   Success! Adv label: 4, L2: 340.26, Queries: 23
# Attacking sample 61/100 (True: 1, Index: 561)...
#   Success! Adv label: 8, L2: 243.52, Queries: 17
# Attacking sample 62/100 (True: 1, Index: 570)...
#   Success! Adv label: 8, L2: 297.28, Queries: 21
# Attacking sample 63/100 (True: 1, Index: 573)...
#   Success! Adv label: 2, L2: 38.01, Queries: 3
# Attacking sample 64/100 (True: 1, Index: 576)...
#   Success! Adv label: 7, L2: 286.85, Queries: 21
# Attacking sample 65/100 (True: 1, Index: 580)...
#   Success! Adv label: 4, L2: 305.26, Queries: 21
# Attacking sample 66/100 (True: 1, Index: 588)...
#   Success! Adv label: 7, L2: 385.88, Queries: 27
# Attacking sample 67/100 (True: 1, Index: 620)...
#   Success! Adv label: 8, L2: 342.07, Queries: 23
# Attacking sample 68/100 (True: 1, Index: 621)...
#   Success! Adv label: 4, L2: 370.57, Queries: 25
# Attacking sample 69/100 (True: 1, Index: 622)...
#   Success! Adv label: 2, L2: 121.12, Queries: 9
# Attacking sample 70/100 (True: 1, Index: 627)...
#   Success! Adv label: 8, L2: 234.56, Queries: 17
# Attacking sample 71/100 (True: 1, Index: 630)...
#   Success! Adv label: 8, L2: 220.17, Queries: 15
# Attacking sample 72/100 (True: 1, Index: 632)...
#   Success! Adv label: 4, L2: 250.34, Queries: 17
# Attacking sample 73/100 (True: 1, Index: 644)...
#   Success! Adv label: 4, L2: 278.94, Queries: 19
# Attacking sample 74/100 (True: 1, Index: 646)...
#   Success! Adv label: 7, L2: 283.64, Queries: 21
# Attacking sample 75/100 (True: 1, Index: 649)...
#   Success! Adv label: 8, L2: 365.61, Queries: 25
# Attacking sample 76/100 (True: 1, Index: 662)...
#   Success! Adv label: 8, L2: 373.16, Queries: 25
# Attacking sample 77/100 (True: 1, Index: 663)...
#   Success! Adv label: 8, L2: 248.06, Queries: 17
# Attacking sample 78/100 (True: 1, Index: 669)...
#   Success! Adv label: 7, L2: 428.13, Queries: 29
# Attacking sample 79/100 (True: 1, Index: 677)...
#   Success! Adv label: 9, L2: 237.99, Queries: 17
# Attacking sample 80/100 (True: 1, Index: 686)...
#   Success! Adv label: 8, L2: 286.63, Queries: 21
# Attacking sample 81/100 (True: 1, Index: 689)...
#   Success! Adv label: 8, L2: 316.15, Queries: 21
# Attacking sample 82/100 (True: 1, Index: 703)...
#   Success! Adv label: 8, L2: 342.21, Queries: 23
# Attacking sample 83/100 (True: 1, Index: 705)...
#   Success! Adv label: 7, L2: 474.54, Queries: 33
# Attacking sample 84/100 (True: 1, Index: 709)...
#   Success! Adv label: 4, L2: 288.68, Queries: 21
# Attacking sample 85/100 (True: 1, Index: 724)...
#   Success! Adv label: 4, L2: 222.74, Queries: 15
# Attacking sample 86/100 (True: 1, Index: 727)...
#   Success! Adv label: 8, L2: 287.12, Queries: 19
# Attacking sample 87/100 (True: 1, Index: 734)...
#   Success! Adv label: 8, L2: 205.66, Queries: 15
# Attacking sample 88/100 (True: 1, Index: 740)...
#   Success! Adv label: 4, L2: 344.85, Queries: 23
# Attacking sample 89/100 (True: 1, Index: 741)...
#   Success! Adv label: 8, L2: 222.36, Queries: 15
# Attacking sample 90/100 (True: 1, Index: 743)...
#   Success! Adv label: 8, L2: 288.12, Queries: 19
# Attacking sample 91/100 (True: 1, Index: 759)...
#   Success! Adv label: 4, L2: 363.89, Queries: 25
# Attacking sample 92/100 (True: 1, Index: 768)...
#   Success! Adv label: 8, L2: 272.57, Queries: 19
# Attacking sample 93/100 (True: 1, Index: 775)...
#   Success! Adv label: 4, L2: 234.51, Queries: 17
# Attacking sample 94/100 (True: 1, Index: 782)...
#   Success! Adv label: 4, L2: 376.37, Queries: 25
# Attacking sample 95/100 (True: 1, Index: 798)...
#   Success! Adv label: 9, L2: 325.42, Queries: 23
# Attacking sample 96/100 (True: 1, Index: 799)...
#   Success! Adv label: 8, L2: 375.84, Queries: 25
# Attacking sample 97/100 (True: 1, Index: 808)...
#   Success! Adv label: 7, L2: 342.02, Queries: 23
# Attacking sample 98/100 (True: 1, Index: 819)...
#   Success! Adv label: 8, L2: 441.51, Queries: 29
# Attacking sample 99/100 (True: 1, Index: 843)...
#   Success! Adv label: 4, L2: 397.75, Queries: 27
# Attacking sample 100/100 (True: 1, Index: 853)...
#   Success! Adv label: 4, L2: 363.53, Queries: 25
# Attacking sample 1/100 (True: 2, Index: 4)...
#   Success! Adv label: 3, L2: 575.40, Queries: 43
# Attacking sample 2/100 (True: 2, Index: 22)...
#   Success! Adv label: 6, L2: 500.40, Queries: 45
# Attacking sample 3/100 (True: 2, Index: 32)...
#   Success! Adv label: 9, L2: 889.96, Queries: 69
# Attacking sample 4/100 (True: 2, Index: 34)...
#   Success! Adv label: 4, L2: 34.97, Queries: 3
# Attacking sample 5/100 (True: 2, Index: 42)...
#   Success! Adv label: 3, L2: 233.30, Queries: 17
# Attacking sample 6/100 (True: 2, Index: 49)...
#   Success! Adv label: 3, L2: 1052.55, Queries: 137
# Attacking sample 7/100 (True: 2, Index: 52)...
#   Success! Adv label: 8, L2: 987.96, Queries: 89
# Attacking sample 8/100 (True: 2, Index: 69)...
#   Success! Adv label: 8, L2: 618.83, Queries: 45
# Attacking sample 9/100 (True: 2, Index: 70)...
#   Success! Adv label: 3, L2: 692.67, Queries: 67
# Attacking sample 10/100 (True: 2, Index: 81)...
#   Success! Adv label: 8, L2: 833.17, Queries: 57
# Attacking sample 11/100 (True: 2, Index: 110)...
#   Success! Adv label: 7, L2: 906.28, Queries: 75
# Attacking sample 12/100 (True: 2, Index: 118)...
#   Success! Adv label: 3, L2: 575.70, Queries: 43
# Attacking sample 13/100 (True: 2, Index: 121)...
#   Success! Adv label: 3, L2: 624.35, Queries: 47
# Attacking sample 14/100 (True: 2, Index: 138)...
#   Success! Adv label: 3, L2: 633.42, Queries: 47
# Attacking sample 15/100 (True: 2, Index: 144)...
#   Success! Adv label: 3, L2: 655.36, Queries: 51
# Attacking sample 16/100 (True: 2, Index: 155)...
#   Success! Adv label: 8, L2: 809.99, Queries: 55
# Attacking sample 17/100 (True: 2, Index: 160)...
#   Success! Adv label: 6, L2: 363.25, Queries: 29
# Attacking sample 18/100 (True: 2, Index: 161)...
#   Success! Adv label: 3, L2: 589.73, Queries: 45
# Attacking sample 19/100 (True: 2, Index: 176)...
#   Success! Adv label: 3, L2: 626.75, Queries: 47
# Attacking sample 21/100 (True: 2, Index: 186)...
#   Success! Adv label: 7, L2: 635.27, Queries: 57
# Attacking sample 22/100 (True: 2, Index: 197)...
#   Success! Adv label: 8, L2: 955.24, Queries: 85
# Attacking sample 23/100 (True: 2, Index: 208)...
#   Success! Adv label: 8, L2: 813.90, Queries: 65
# Attacking sample 25/100 (True: 2, Index: 216)...
#   Success! Adv label: 3, L2: 781.82, Queries: 63
# Attacking sample 26/100 (True: 2, Index: 219)...
#   Success! Adv label: 3, L2: 385.04, Queries: 31
# Attacking sample 27/100 (True: 2, Index: 235)...
#   Success! Adv label: 3, L2: 745.00, Queries: 59
# Attacking sample 28/100 (True: 2, Index: 260)...
#   Success! Adv label: 0, L2: 519.59, Queries: 41
# Attacking sample 29/100 (True: 2, Index: 276)...
#   Success! Adv label: 4, L2: 518.61, Queries: 43
# Attacking sample 30/100 (True: 2, Index: 293)...
#   Success! Adv label: 3, L2: 747.21, Queries: 69
# Attacking sample 31/100 (True: 2, Index: 295)...
#   Success! Adv label: 3, L2: 516.60, Queries: 41
# Attacking sample 32/100 (True: 2, Index: 311)...
#   Success! Adv label: 3, L2: 541.01, Queries: 43
# Attacking sample 33/100 (True: 2, Index: 313)...
#   Success! Adv label: 3, L2: 158.07, Queries: 13
# Attacking sample 34/100 (True: 2, Index: 322)...
#   Success! Adv label: 0, L2: 658.51, Queries: 51
# Attacking sample 35/100 (True: 2, Index: 328)...
#   Success! Adv label: 8, L2: 661.19, Queries: 49
# Attacking sample 36/100 (True: 2, Index: 357)...
#   Success! Adv label: 7, L2: 501.46, Queries: 41
# Attacking sample 37/100 (True: 2, Index: 374)...
#   Success! Adv label: 8, L2: 387.80, Queries: 29
# Attacking sample 38/100 (True: 2, Index: 395)...
#   Success! Adv label: 8, L2: 463.24, Queries: 39
# Attacking sample 39/100 (True: 2, Index: 396)...
#   Success! Adv label: 8, L2: 490.44, Queries: 35
# Attacking sample 40/100 (True: 2, Index: 398)...
#   Success! Adv label: 3, L2: 766.60, Queries: 61
# Attacking sample 41/100 (True: 2, Index: 433)...
#   Success! Adv label: 3, L2: 569.37, Queries: 41
# Attacking sample 42/100 (True: 2, Index: 439)...
#   Success! Adv label: 8, L2: 577.60, Queries: 41
# Attacking sample 43/100 (True: 2, Index: 441)...
#   Success! Adv label: 8, L2: 327.80, Queries: 23
# Attacking sample 44/100 (True: 2, Index: 442)...
#   Success! Adv label: 9, L2: 681.79, Queries: 51
# Attacking sample 45/100 (True: 2, Index: 451)...
#   Success! Adv label: 0, L2: 1025.92, Queries: 79
# Attacking sample 46/100 (True: 2, Index: 462)...
#   Success! Adv label: 3, L2: 728.85, Queries: 51
# Attacking sample 47/100 (True: 2, Index: 470)...
#   Success! Adv label: 3, L2: 646.07, Queries: 49
# Attacking sample 48/100 (True: 2, Index: 477)...
#   Success! Adv label: 8, L2: 804.89, Queries: 63
# Attacking sample 49/100 (True: 2, Index: 485)...
#   Success! Adv label: 7, L2: 244.07, Queries: 19
# Attacking sample 50/100 (True: 2, Index: 491)...
#   Success! Adv label: 8, L2: 730.80, Queries: 51
# Attacking sample 51/100 (True: 2, Index: 493)...
#   Success! Adv label: 7, L2: 725.67, Queries: 65
# Attacking sample 52/100 (True: 2, Index: 495)...
#   Success! Adv label: 3, L2: 655.47, Queries: 51
# Attacking sample 53/100 (True: 2, Index: 519)...
#   Success! Adv label: 3, L2: 829.13, Queries: 65
# Attacking sample 54/100 (True: 2, Index: 523)...
#   Success! Adv label: 6, L2: 569.50, Queries: 47
# Attacking sample 55/100 (True: 2, Index: 557)...
#   Success! Adv label: 8, L2: 594.80, Queries: 41
# Attacking sample 56/100 (True: 2, Index: 567)...
#   Success! Adv label: 0, L2: 443.56, Queries: 33
# Attacking sample 57/100 (True: 2, Index: 571)...
#   Success! Adv label: 7, L2: 630.51, Queries: 51
# Attacking sample 58/100 (True: 2, Index: 584)...
#   Success! Adv label: 8, L2: 1072.19, Queries: 79
# Attacking sample 59/100 (True: 2, Index: 591)...
#   Success! Adv label: 8, L2: 862.70, Queries: 69
# Attacking sample 60/100 (True: 2, Index: 592)...
#   Success! Adv label: 8, L2: 736.28, Queries: 63
# Attacking sample 61/100 (True: 2, Index: 610)...
#   Success! Adv label: 8, L2: 1014.27, Queries: 79
# Attacking sample 62/100 (True: 2, Index: 612)...
#   Success! Adv label: 8, L2: 605.86, Queries: 41
# Attacking sample 63/100 (True: 2, Index: 616)...
#   Success! Adv label: 3, L2: 772.33, Queries: 59
# Attacking sample 64/100 (True: 2, Index: 624)...
#   Success! Adv label: 3, L2: 709.28, Queries: 51
# Attacking sample 65/100 (True: 2, Index: 631)...
#   Success! Adv label: 3, L2: 456.80, Queries: 35
# Attacking sample 66/100 (True: 2, Index: 636)...
#   Success! Adv label: 3, L2: 810.14, Queries: 59
# Attacking sample 67/100 (True: 2, Index: 647)...
#   Success! Adv label: 1, L2: 127.33, Queries: 11
# Attacking sample 68/100 (True: 2, Index: 650)...
#   Success! Adv label: 3, L2: 197.74, Queries: 15
# Attacking sample 69/100 (True: 2, Index: 664)...
#   Success! Adv label: 8, L2: 807.12, Queries: 61
# Attacking sample 70/100 (True: 2, Index: 704)...
#   Success! Adv label: 3, L2: 628.85, Queries: 49
# Attacking sample 71/100 (True: 2, Index: 720)...
#   Success! Adv label: 4, L2: 205.73, Queries: 15
# Attacking sample 72/100 (True: 2, Index: 725)...
#   Success! Adv label: 3, L2: 470.10, Queries: 35
# Attacking sample 73/100 (True: 2, Index: 750)...
#   Success! Adv label: 7, L2: 917.50, Queries: 87
# Attacking sample 74/100 (True: 2, Index: 764)...
#   Success! Adv label: 1, L2: 611.26, Queries: 59
# Attacking sample 75/100 (True: 2, Index: 780)...
#   Success! Adv label: 8, L2: 723.73, Queries: 51
# Attacking sample 76/100 (True: 2, Index: 784)...
#   Success! Adv label: 8, L2: 856.54, Queries: 63
# Attacking sample 77/100 (True: 2, Index: 788)...
#   Success! Adv label: 1, L2: 560.91, Queries: 43
# Attacking sample 78/100 (True: 2, Index: 790)...
#   Success! Adv label: 3, L2: 916.80, Queries: 77
# Attacking sample 79/100 (True: 2, Index: 797)...
#   Success! Adv label: 8, L2: 601.38, Queries: 43
# Attacking sample 80/100 (True: 2, Index: 803)...
#   Success! Adv label: 8, L2: 825.23, Queries: 63
# Attacking sample 81/100 (True: 2, Index: 807)...
#   Success! Adv label: 1, L2: 990.54, Queries: 89
# Attacking sample 82/100 (True: 2, Index: 828)...
#   Success! Adv label: 3, L2: 435.98, Queries: 33
# Attacking sample 83/100 (True: 2, Index: 842)...
#   Success! Adv label: 3, L2: 700.39, Queries: 57
# Attacking sample 84/100 (True: 2, Index: 845)...
#   Success! Adv label: 3, L2: 925.82, Queries: 67
# Attacking sample 85/100 (True: 2, Index: 859)...
#   Success! Adv label: 3, L2: 469.18, Queries: 35
# Attacking sample 86/100 (True: 2, Index: 871)...
#   Success! Adv label: 1, L2: 682.14, Queries: 55
# Attacking sample 87/100 (True: 2, Index: 881)...
#   Success! Adv label: 1, L2: 571.31, Queries: 51
# Attacking sample 88/100 (True: 2, Index: 883)...
#   Success! Adv label: 8, L2: 308.25, Queries: 23
# Attacking sample 89/100 (True: 2, Index: 896)...
#   Success! Adv label: 3, L2: 585.86, Queries: 43
# Attacking sample 90/100 (True: 2, Index: 897)...
#   Success! Adv label: 3, L2: 563.30, Queries: 51
# Attacking sample 92/100 (True: 2, Index: 922)...
#   Success! Adv label: 7, L2: 548.93, Queries: 43
# Attacking sample 93/100 (True: 2, Index: 932)...
#   Success! Adv label: 8, L2: 636.51, Queries: 45
# Attacking sample 94/100 (True: 2, Index: 944)...
#   Success! Adv label: 3, L2: 560.77, Queries: 43
# Attacking sample 95/100 (True: 2, Index: 949)...
#   Success! Adv label: 3, L2: 691.61, Queries: 53
# Attacking sample 96/100 (True: 2, Index: 952)...
#   Failed! Adv label: 2, L2: 1161.92, Queries: 201
# Attacking sample 97/100 (True: 2, Index: 959)...
#   Success! Adv label: 3, L2: 550.73, Queries: 41
# Attacking sample 98/100 (True: 2, Index: 966)...
#   Success! Adv label: 7, L2: 189.42, Queries: 15
# Attacking sample 99/100 (True: 2, Index: 967)...
#   Success! Adv label: 7, L2: 718.61, Queries: 59
# Attacking sample 100/100 (True: 2, Index: 985)...
#   Success! Adv label: 3, L2: 637.86, Queries: 53
# Attacking sample 1/100 (True: 3, Index: 1)...
#   Success! Adv label: 5, L2: 329.35, Queries: 25
# Attacking sample 2/100 (True: 3, Index: 12)...
#   Success! Adv label: 5, L2: 293.54, Queries: 23
# Attacking sample 3/100 (True: 3, Index: 20)...
#   Success! Adv label: 9, L2: 610.24, Queries: 45
# Attacking sample 4/100 (True: 3, Index: 27)...
#   Success! Adv label: 5, L2: 861.85, Queries: 81
# Attacking sample 5/100 (True: 3, Index: 37)...
#   Success! Adv label: 0, L2: 925.76, Queries: 81
# Attacking sample 6/100 (True: 3, Index: 43)...
#   Success! Adv label: 2, L2: 795.23, Queries: 77
# Attacking sample 7/100 (True: 3, Index: 53)...
#   Success! Adv label: 8, L2: 551.90, Queries: 41
# Attacking sample 8/100 (True: 3, Index: 61)...
#   Success! Adv label: 8, L2: 573.69, Queries: 41
# Attacking sample 9/100 (True: 3, Index: 73)...
#   Success! Adv label: 8, L2: 626.35, Queries: 51
# Attacking sample 10/100 (True: 3, Index: 102)...
#   Success! Adv label: 2, L2: 410.26, Queries: 31
# Attacking sample 11/100 (True: 3, Index: 108)...
#   Success! Adv label: 2, L2: 93.79, Queries: 7
# Attacking sample 12/100 (True: 3, Index: 109)...
#   Success! Adv label: 8, L2: 499.78, Queries: 35
# Attacking sample 13/100 (True: 3, Index: 117)...
#   Success! Adv label: 5, L2: 857.52, Queries: 81
# Attacking sample 14/100 (True: 3, Index: 131)...
#   Success! Adv label: 8, L2: 156.09, Queries: 11
# Attacking sample 15/100 (True: 3, Index: 159)...
#   Success! Adv label: 2, L2: 825.82, Queries: 69
# Attacking sample 16/100 (True: 3, Index: 162)...
#   Failed! Adv label: 3, L2: 1172.88, Queries: 201
# Attacking sample 17/100 (True: 3, Index: 166)...
#   Success! Adv label: 7, L2: 724.81, Queries: 69
# Attacking sample 18/100 (True: 3, Index: 177)...
#   Success! Adv label: 8, L2: 527.26, Queries: 37
# Attacking sample 19/100 (True: 3, Index: 181)...
#   Success! Adv label: 5, L2: 395.89, Queries: 31
# Attacking sample 20/100 (True: 3, Index: 187)...
#   Success! Adv label: 8, L2: 605.22, Queries: 43
# Attacking sample 21/100 (True: 3, Index: 196)...
#   Success! Adv label: 2, L2: 480.67, Queries: 33
# Attacking sample 22/100 (True: 3, Index: 204)...
#   Success! Adv label: 5, L2: 821.05, Queries: 69
# Attacking sample 23/100 (True: 3, Index: 227)...
#   Success! Adv label: 7, L2: 1118.96, Queries: 171
# Attacking sample 24/100 (True: 3, Index: 231)...
#   Success! Adv label: 5, L2: 570.14, Queries: 43
# Attacking sample 25/100 (True: 3, Index: 237)...
#   Success! Adv label: 5, L2: 903.06, Queries: 77
# Attacking sample 26/100 (True: 3, Index: 244)...
#   Success! Adv label: 7, L2: 808.33, Queries: 73
# Attacking sample 27/100 (True: 3, Index: 257)...
#   Success! Adv label: 8, L2: 530.06, Queries: 39
# Attacking sample 28/100 (True: 3, Index: 259)...
#   Success! Adv label: 5, L2: 751.97, Queries: 67
# Attacking sample 29/100 (True: 3, Index: 265)...
#   Success! Adv label: 5, L2: 478.05, Queries: 37
# Attacking sample 30/100 (True: 3, Index: 270)...
#   Success! Adv label: 5, L2: 214.87, Queries: 17
# Attacking sample 31/100 (True: 3, Index: 288)...
#   Success! Adv label: 2, L2: 986.23, Queries: 71
# Attacking sample 32/100 (True: 3, Index: 308)...
#   Success! Adv label: 8, L2: 507.92, Queries: 37
# Attacking sample 33/100 (True: 3, Index: 309)...
#   Success! Adv label: 8, L2: 556.91, Queries: 41
# Attacking sample 34/100 (True: 3, Index: 327)...
#   Success! Adv label: 1, L2: 332.27, Queries: 29
# Attacking sample 35/100 (True: 3, Index: 331)...
#   Success! Adv label: 8, L2: 806.96, Queries: 67
# Attacking sample 36/100 (True: 3, Index: 340)...
#   Success! Adv label: 9, L2: 854.06, Queries: 71
# Attacking sample 37/100 (True: 3, Index: 341)...
#   Success! Adv label: 5, L2: 511.05, Queries: 41
# Attacking sample 38/100 (True: 3, Index: 342)...
#   Success! Adv label: 5, L2: 426.62, Queries: 33
# Attacking sample 39/100 (True: 3, Index: 362)...
#   Success! Adv label: 2, L2: 530.97, Queries: 41
# Attacking sample 40/100 (True: 3, Index: 383)...
#   Success! Adv label: 2, L2: 550.44, Queries: 43
# Attacking sample 41/100 (True: 3, Index: 394)...
#   Success! Adv label: 8, L2: 487.78, Queries: 35
# Attacking sample 42/100 (True: 3, Index: 406)...
#   Success! Adv label: 7, L2: 1078.81, Queries: 129
# Attacking sample 43/100 (True: 3, Index: 409)...
#   Success! Adv label: 2, L2: 810.68, Queries: 67
# Attacking sample 44/100 (True: 3, Index: 445)...
#   Success! Adv label: 2, L2: 396.21, Queries: 29
# Attacking sample 45/100 (True: 3, Index: 456)...
#   Success! Adv label: 8, L2: 496.31, Queries: 35
# Attacking sample 46/100 (True: 3, Index: 459)...
#   Success! Adv label: 4, L2: 884.60, Queries: 87
# Attacking sample 47/100 (True: 3, Index: 461)...
#   Success! Adv label: 5, L2: 1049.33, Queries: 97
# Attacking sample 48/100 (True: 3, Index: 471)...
#   Success! Adv label: 8, L2: 822.13, Queries: 59
# Attacking sample 49/100 (True: 3, Index: 474)...
#   Success! Adv label: 5, L2: 439.74, Queries: 35
# Attacking sample 50/100 (True: 3, Index: 481)...
#   Success! Adv label: 5, L2: 730.14, Queries: 63
# Attacking sample 51/100 (True: 3, Index: 504)...
#   Success! Adv label: 5, L2: 554.09, Queries: 43
# Attacking sample 52/100 (True: 3, Index: 510)...
#   Success! Adv label: 5, L2: 300.89, Queries: 23
# Attacking sample 53/100 (True: 3, Index: 512)...
#   Failed! Adv label: 3, L2: 1102.37, Queries: 201
# Attacking sample 54/100 (True: 3, Index: 524)...
#   Success! Adv label: 8, L2: 580.74, Queries: 41
# Attacking sample 55/100 (True: 3, Index: 549)...
#   Success! Adv label: 2, L2: 439.76, Queries: 37
# Attacking sample 56/100 (True: 3, Index: 556)...
#   Success! Adv label: 9, L2: 510.72, Queries: 41
# Attacking sample 57/100 (True: 3, Index: 564)...
#   Success! Adv label: 8, L2: 430.87, Queries: 31
# Attacking sample 58/100 (True: 3, Index: 586)...
#   Failed! Adv label: 3, L2: 1182.68, Queries: 201
# Attacking sample 59/100 (True: 3, Index: 589)...
#   Success! Adv label: 5, L2: 1038.10, Queries: 87
# Attacking sample 60/100 (True: 3, Index: 609)...
#   Success! Adv label: 9, L2: 609.47, Queries: 47
# Attacking sample 61/100 (True: 3, Index: 613)...
#   Success! Adv label: 8, L2: 720.82, Queries: 51
# Attacking sample 62/100 (True: 3, Index: 623)...
#   Success! Adv label: 9, L2: 377.38, Queries: 27
# Attacking sample 63/100 (True: 3, Index: 639)...
#   Success! Adv label: 5, L2: 494.14, Queries: 39
# Attacking sample 64/100 (True: 3, Index: 648)...
#   Success! Adv label: 8, L2: 403.27, Queries: 29
# Attacking sample 65/100 (True: 3, Index: 651)...
#   Success! Adv label: 8, L2: 391.32, Queries: 29
# Attacking sample 66/100 (True: 3, Index: 659)...
#   Success! Adv label: 9, L2: 595.84, Queries: 49
# Attacking sample 67/100 (True: 3, Index: 661)...
#   Success! Adv label: 5, L2: 855.96, Queries: 71
# Attacking sample 68/100 (True: 3, Index: 667)...
#   Success! Adv label: 7, L2: 1058.51, Queries: 101
# Attacking sample 69/100 (True: 3, Index: 678)...
#   Success! Adv label: 2, L2: 791.00, Queries: 85
# Attacking sample 70/100 (True: 3, Index: 690)...
#   Success! Adv label: 8, L2: 830.64, Queries: 57
# Attacking sample 71/100 (True: 3, Index: 693)...
#   Failed! Adv label: 3, L2: 1105.79, Queries: 201
# Attacking sample 72/100 (True: 3, Index: 694)...
#   Success! Adv label: 9, L2: 722.64, Queries: 53
# Attacking sample 73/100 (True: 3, Index: 695)...
#   Success! Adv label: 2, L2: 261.49, Queries: 19
# Attacking sample 74/100 (True: 3, Index: 702)...
#   Success! Adv label: 8, L2: 367.06, Queries: 25
# Attacking sample 75/100 (True: 3, Index: 718)...
#   Success! Adv label: 2, L2: 976.23, Queries: 81
# Attacking sample 76/100 (True: 3, Index: 749)...
#   Success! Adv label: 9, L2: 720.52, Queries: 61
# Attacking sample 77/100 (True: 3, Index: 769)...
#   Success! Adv label: 9, L2: 750.71, Queries: 53
# Attacking sample 79/100 (True: 3, Index: 779)...
#   Success! Adv label: 8, L2: 431.33, Queries: 33
# Attacking sample 80/100 (True: 3, Index: 800)...
#   Success! Adv label: 8, L2: 876.19, Queries: 61
# Attacking sample 81/100 (True: 3, Index: 816)...
#   Success! Adv label: 5, L2: 239.62, Queries: 19
# Attacking sample 82/100 (True: 3, Index: 829)...
#   Success! Adv label: 2, L2: 484.77, Queries: 37
# Attacking sample 83/100 (True: 3, Index: 833)...
#   Success! Adv label: 7, L2: 880.67, Queries: 85
# Attacking sample 84/100 (True: 3, Index: 839)...
#   Success! Adv label: 8, L2: 676.39, Queries: 51
# Attacking sample 85/100 (True: 3, Index: 854)...
#   Success! Adv label: 5, L2: 266.15, Queries: 21
# Attacking sample 86/100 (True: 3, Index: 856)...
#   Success! Adv label: 2, L2: 409.00, Queries: 33
# Attacking sample 87/100 (True: 3, Index: 858)...
#   Success! Adv label: 5, L2: 106.10, Queries: 9
# Attacking sample 89/100 (True: 3, Index: 886)...
#   Success! Adv label: 8, L2: 809.20, Queries: 61
# Attacking sample 90/100 (True: 3, Index: 900)...
#   Success! Adv label: 8, L2: 655.47, Queries: 47
# Attacking sample 91/100 (True: 3, Index: 916)...
#   Success! Adv label: 5, L2: 370.63, Queries: 31
# Attacking sample 92/100 (True: 3, Index: 921)...
#   Success! Adv label: 2, L2: 464.38, Queries: 37
# Attacking sample 93/100 (True: 3, Index: 937)...
#   Success! Adv label: 9, L2: 673.68, Queries: 51
# Attacking sample 94/100 (True: 3, Index: 938)...
#   Success! Adv label: 8, L2: 654.74, Queries: 43
# Attacking sample 95/100 (True: 3, Index: 939)...
#   Success! Adv label: 8, L2: 313.85, Queries: 23
# Attacking sample 96/100 (True: 3, Index: 942)...
#   Success! Adv label: 5, L2: 844.21, Queries: 75
# Attacking sample 97/100 (True: 3, Index: 951)...
#   Success! Adv label: 8, L2: 594.30, Queries: 45
# Attacking sample 98/100 (True: 3, Index: 953)...
#   Success! Adv label: 7, L2: 1038.26, Queries: 99
# Attacking sample 99/100 (True: 3, Index: 975)...
#   Success! Adv label: 5, L2: 1090.10, Queries: 119
# Attacking sample 1/100 (True: 4, Index: 16)...
#   Success! Adv label: 9, L2: 279.57, Queries: 21
# Attacking sample 2/100 (True: 4, Index: 17)...
#   Success! Adv label: 6, L2: 402.38, Queries: 31
# Attacking sample 3/100 (True: 4, Index: 30)...
#   Success! Adv label: 8, L2: 723.27, Queries: 53
# Attacking sample 4/100 (True: 4, Index: 33)...
#   Success! Adv label: 9, L2: 511.03, Queries: 39
# Attacking sample 5/100 (True: 4, Index: 45)...
#   Success! Adv label: 8, L2: 122.70, Queries: 9
# Attacking sample 6/100 (True: 4, Index: 48)...
#   Success! Adv label: 9, L2: 685.55, Queries: 51
# Attacking sample 7/100 (True: 4, Index: 58)...
#   Success! Adv label: 9, L2: 683.11, Queries: 49
# Attacking sample 8/100 (True: 4, Index: 66)...
#   Success! Adv label: 6, L2: 555.94, Queries: 45
# Attacking sample 9/100 (True: 4, Index: 89)...
#   Success! Adv label: 9, L2: 323.95, Queries: 23
# Attacking sample 10/100 (True: 4, Index: 92)...
#   Success! Adv label: 6, L2: 790.14, Queries: 59
# Attacking sample 11/100 (True: 4, Index: 113)...
#   Success! Adv label: 9, L2: 602.55, Queries: 43
# Attacking sample 12/100 (True: 4, Index: 116)...
#   Success! Adv label: 9, L2: 575.04, Queries: 41
# Attacking sample 13/100 (True: 4, Index: 126)...
#   Success! Adv label: 9, L2: 428.42, Queries: 29
# Attacking sample 14/100 (True: 4, Index: 130)...
#   Success! Adv label: 9, L2: 326.14, Queries: 23
# Attacking sample 15/100 (True: 4, Index: 139)...
#   Success! Adv label: 9, L2: 492.19, Queries: 35
# Attacking sample 16/100 (True: 4, Index: 149)...
#   Success! Adv label: 2, L2: 944.47, Queries: 73
# Attacking sample 17/100 (True: 4, Index: 153)...
#   Success! Adv label: 8, L2: 476.03, Queries: 35
# Attacking sample 18/100 (True: 4, Index: 154)...
#   Success! Adv label: 7, L2: 834.42, Queries: 63
# Attacking sample 19/100 (True: 4, Index: 163)...
#   Success! Adv label: 9, L2: 485.84, Queries: 35
# Attacking sample 20/100 (True: 4, Index: 167)...
#   Success! Adv label: 9, L2: 614.59, Queries: 43
# Attacking sample 21/100 (True: 4, Index: 183)...
#   Success! Adv label: 9, L2: 388.55, Queries: 29
# Attacking sample 22/100 (True: 4, Index: 184)...
#   Success! Adv label: 9, L2: 531.08, Queries: 39
# Attacking sample 23/100 (True: 4, Index: 192)...
#   Success! Adv label: 9, L2: 263.58, Queries: 19
# Attacking sample 24/100 (True: 4, Index: 194)...
#   Success! Adv label: 9, L2: 486.09, Queries: 37
# Attacking sample 25/100 (True: 4, Index: 233)...
#   Success! Adv label: 9, L2: 637.22, Queries: 49
# Attacking sample 26/100 (True: 4, Index: 240)...
#   Success! Adv label: 8, L2: 543.37, Queries: 37
# Attacking sample 27/100 (True: 4, Index: 263)...
#   Success! Adv label: 9, L2: 231.10, Queries: 17
# Attacking sample 28/100 (True: 4, Index: 269)...
#   Success! Adv label: 9, L2: 319.18, Queries: 23
# Attacking sample 29/100 (True: 4, Index: 280)...
#   Success! Adv label: 9, L2: 356.57, Queries: 25
# Attacking sample 30/100 (True: 4, Index: 290)...
#   Success! Adv label: 9, L2: 570.56, Queries: 39
# Attacking sample 31/100 (True: 4, Index: 297)...
#   Success! Adv label: 6, L2: 387.24, Queries: 29
# Attacking sample 32/100 (True: 4, Index: 299)...
#   Success! Adv label: 9, L2: 352.23, Queries: 25
# Attacking sample 33/100 (True: 4, Index: 310)...
#   Success! Adv label: 9, L2: 312.14, Queries: 23
# Attacking sample 34/100 (True: 4, Index: 316)...
#   Success! Adv label: 9, L2: 427.39, Queries: 29
# Attacking sample 35/100 (True: 4, Index: 320)...
#   Success! Adv label: 9, L2: 418.79, Queries: 31
# Attacking sample 36/100 (True: 4, Index: 324)...
#   Success! Adv label: 9, L2: 431.59, Queries: 31
# Attacking sample 37/100 (True: 4, Index: 326)...
#   Success! Adv label: 9, L2: 495.16, Queries: 37
# Attacking sample 38/100 (True: 4, Index: 332)...
#   Success! Adv label: 9, L2: 35.10, Queries: 3
# Attacking sample 39/100 (True: 4, Index: 335)...
#   Success! Adv label: 9, L2: 606.65, Queries: 43
# Attacking sample 40/100 (True: 4, Index: 344)...
#   Success! Adv label: 7, L2: 490.82, Queries: 37
# Attacking sample 42/100 (True: 4, Index: 359)...
#   Success! Adv label: 9, L2: 400.62, Queries: 29
# Attacking sample 43/100 (True: 4, Index: 376)...
#   Success! Adv label: 9, L2: 512.87, Queries: 37
# Attacking sample 44/100 (True: 4, Index: 393)...
#   Success! Adv label: 9, L2: 485.07, Queries: 33
# Attacking sample 45/100 (True: 4, Index: 401)...
#   Success! Adv label: 2, L2: 652.73, Queries: 51
# Attacking sample 46/100 (True: 4, Index: 402)...
#   Success! Adv label: 9, L2: 450.13, Queries: 33
# Attacking sample 47/100 (True: 4, Index: 422)...
#   Success! Adv label: 9, L2: 363.40, Queries: 25
# Attacking sample 48/100 (True: 4, Index: 423)...
#   Success! Adv label: 9, L2: 165.57, Queries: 13
# Attacking sample 49/100 (True: 4, Index: 427)...
#   Success! Adv label: 1, L2: 495.83, Queries: 41
# Attacking sample 50/100 (True: 4, Index: 432)...
#   Success! Adv label: 9, L2: 366.10, Queries: 27
# Attacking sample 51/100 (True: 4, Index: 434)...
#   Success! Adv label: 9, L2: 272.48, Queries: 19
# Attacking sample 52/100 (True: 4, Index: 454)...
#   Success! Adv label: 9, L2: 556.29, Queries: 41
# Attacking sample 53/100 (True: 4, Index: 467)...
#   Success! Adv label: 8, L2: 349.79, Queries: 25
# Attacking sample 54/100 (True: 4, Index: 501)...
#   Success! Adv label: 9, L2: 262.00, Queries: 19
# Attacking sample 55/100 (True: 4, Index: 515)...
#   Success! Adv label: 9, L2: 329.22, Queries: 23
# Attacking sample 56/100 (True: 4, Index: 540)...
#   Success! Adv label: 9, L2: 558.76, Queries: 41
# Attacking sample 57/100 (True: 4, Index: 544)...
#   Success! Adv label: 0, L2: 440.01, Queries: 33
# Attacking sample 58/100 (True: 4, Index: 545)...
#   Success! Adv label: 9, L2: 341.14, Queries: 25
# Attacking sample 59/100 (True: 4, Index: 547)...
#   Success! Adv label: 8, L2: 701.91, Queries: 55
# Attacking sample 60/100 (True: 4, Index: 566)...
#   Success! Adv label: 9, L2: 381.00, Queries: 27
# Attacking sample 61/100 (True: 4, Index: 590)...
#   Success! Adv label: 0, L2: 415.92, Queries: 31
# Attacking sample 62/100 (True: 4, Index: 593)...
#   Success! Adv label: 9, L2: 347.91, Queries: 25
# Attacking sample 63/100 (True: 4, Index: 599)...
#   Success! Adv label: 9, L2: 590.03, Queries: 47
# Attacking sample 64/100 (True: 4, Index: 602)...
#   Success! Adv label: 9, L2: 464.07, Queries: 33
# Attacking sample 65/100 (True: 4, Index: 607)...
#   Success! Adv label: 7, L2: 578.18, Queries: 51
# Attacking sample 66/100 (True: 4, Index: 611)...
#   Success! Adv label: 9, L2: 597.43, Queries: 43
# Attacking sample 67/100 (True: 4, Index: 617)...
#   Success! Adv label: 9, L2: 502.13, Queries: 35
# Attacking sample 68/100 (True: 4, Index: 657)...
#   Success! Adv label: 9, L2: 313.42, Queries: 25
# Attacking sample 69/100 (True: 4, Index: 680)...
#   Success! Adv label: 9, L2: 377.48, Queries: 27
# Attacking sample 70/100 (True: 4, Index: 684)...
#   Success! Adv label: 9, L2: 574.89, Queries: 45
# Attacking sample 71/100 (True: 4, Index: 687)...
#   Success! Adv label: 9, L2: 532.01, Queries: 37
# Attacking sample 72/100 (True: 4, Index: 692)...
#   Success! Adv label: 9, L2: 650.41, Queries: 47
# Attacking sample 73/100 (True: 4, Index: 696)...
#   Success! Adv label: 9, L2: 168.89, Queries: 13
# Attacking sample 74/100 (True: 4, Index: 697)...
#   Success! Adv label: 9, L2: 669.21, Queries: 47
# Attacking sample 75/100 (True: 4, Index: 708)...
#   Success! Adv label: 9, L2: 545.56, Queries: 39
# Attacking sample 76/100 (True: 4, Index: 717)...
#   Success! Adv label: 9, L2: 339.38, Queries: 25
# Attacking sample 77/100 (True: 4, Index: 746)...
#   Success! Adv label: 9, L2: 452.84, Queries: 33
# Attacking sample 78/100 (True: 4, Index: 752)...
#   Success! Adv label: 9, L2: 908.78, Queries: 65
# Attacking sample 79/100 (True: 4, Index: 755)...
#   Success! Adv label: 2, L2: 880.36, Queries: 75
# Attacking sample 80/100 (True: 4, Index: 757)...
#   Success! Adv label: 9, L2: 410.33, Queries: 29
# Attacking sample 81/100 (True: 4, Index: 766)...
#   Success! Adv label: 7, L2: 509.12, Queries: 41
# Attacking sample 82/100 (True: 4, Index: 771)...
#   Success! Adv label: 9, L2: 318.13, Queries: 23
# Attacking sample 83/100 (True: 4, Index: 776)...
#   Success! Adv label: 2, L2: 576.43, Queries: 43
# Attacking sample 84/100 (True: 4, Index: 777)...
#   Success! Adv label: 1, L2: 820.05, Queries: 73
# Attacking sample 85/100 (True: 4, Index: 786)...
#   Success! Adv label: 9, L2: 178.67, Queries: 13
# Attacking sample 86/100 (True: 4, Index: 811)...
#   Success! Adv label: 9, L2: 267.93, Queries: 19
# Attacking sample 87/100 (True: 4, Index: 815)...
#   Success! Adv label: 6, L2: 628.86, Queries: 47
# Attacking sample 88/100 (True: 4, Index: 817)...
#   Success! Adv label: 5, L2: 822.09, Queries: 69
# Attacking sample 89/100 (True: 4, Index: 840)...
#   Success! Adv label: 6, L2: 648.75, Queries: 49
# Attacking sample 91/100 (True: 4, Index: 849)...
#   Success! Adv label: 8, L2: 667.33, Queries: 47
# Attacking sample 92/100 (True: 4, Index: 857)...
#   Success! Adv label: 9, L2: 520.83, Queries: 37
# Attacking sample 93/100 (True: 4, Index: 872)...
#   Success! Adv label: 9, L2: 661.81, Queries: 51
# Attacking sample 94/100 (True: 4, Index: 877)...
#   Success! Adv label: 9, L2: 383.76, Queries: 29
# Attacking sample 95/100 (True: 4, Index: 894)...
#   Success! Adv label: 9, L2: 260.47, Queries: 19
# Attacking sample 96/100 (True: 4, Index: 902)...
#   Success! Adv label: 9, L2: 377.14, Queries: 27
# Attacking sample 97/100 (True: 4, Index: 911)...
#   Success! Adv label: 9, L2: 538.88, Queries: 41
# ...
#   Success! Adv label: 3, L2: 516.34, Queries: 41
# Attacking sample 40/100 (True: 8, Index: 505)...
#   Success! Adv label: 2, L2: 726.80, Queries: 59
# Attacking sample 41/100 (True: 8, Index: 509)...
#   Success! Adv label: 2, L2: 652.40, Queries: 59
# Attacking sample 42/100 (True: 8, Index: 525)...
#   Success! Adv label: 3, L2: 577.25, Queries: 49
# Attacking sample 43/100 (True: 8, Index: 528)...
#   Success! Adv label: 3, L2: 728.56, Queries: 65
# Attacking sample 44/100 (True: 8, Index: 541)...
#   Success! Adv label: 3, L2: 784.66, Queries: 63
# Attacking sample 45/100 (True: 8, Index: 543)...
#   Success! Adv label: 6, L2: 367.47, Queries: 29
# Attacking sample 46/100 (True: 8, Index: 550)...
#   Success! Adv label: 5, L2: 529.73, Queries: 43
# Attacking sample 47/100 (True: 8, Index: 558)...
#   Success! Adv label: 2, L2: 695.19, Queries: 55
# Attacking sample 48/100 (True: 8, Index: 575)...
#   Success! Adv label: 9, L2: 463.33, Queries: 37
# Attacking sample 49/100 (True: 8, Index: 594)...
#   Success! Adv label: 2, L2: 388.81, Queries: 33
# Attacking sample 50/100 (True: 8, Index: 600)...
#   Success! Adv label: 3, L2: 988.00, Queries: 79
# Attacking sample 51/100 (True: 8, Index: 605)...
#   Success! Adv label: 2, L2: 601.95, Queries: 49
# Attacking sample 52/100 (True: 8, Index: 619)...
#   Success! Adv label: 3, L2: 536.77, Queries: 45
# Attacking sample 53/100 (True: 8, Index: 625)...
#   Success! Adv label: 3, L2: 735.94, Queries: 59
# Attacking sample 54/100 (True: 8, Index: 629)...
#   Success! Adv label: 2, L2: 497.62, Queries: 39
# Attacking sample 55/100 (True: 8, Index: 645)...
#   Success! Adv label: 9, L2: 958.40, Queries: 79
# Attacking sample 56/100 (True: 8, Index: 652)...
#   Success! Adv label: 2, L2: 592.20, Queries: 51
# Attacking sample 57/100 (True: 8, Index: 672)...
#   Success! Adv label: 3, L2: 598.10, Queries: 53
# Attacking sample 58/100 (True: 8, Index: 683)...
#   Success! Adv label: 3, L2: 387.44, Queries: 35
# Attacking sample 59/100 (True: 8, Index: 701)...
#   Success! Adv label: 3, L2: 721.23, Queries: 65
# Attacking sample 60/100 (True: 8, Index: 714)...
#   Success! Adv label: 3, L2: 655.00, Queries: 59
# Attacking sample 61/100 (True: 8, Index: 721)...
#   Success! Adv label: 3, L2: 490.15, Queries: 41
# Attacking sample 62/100 (True: 8, Index: 730)...
#   Success! Adv label: 2, L2: 614.93, Queries: 47
# Attacking sample 63/100 (True: 8, Index: 731)...
#   Success! Adv label: 9, L2: 1266.15, Queries: 145
# Attacking sample 64/100 (True: 8, Index: 738)...
#   Success! Adv label: 3, L2: 826.77, Queries: 73
# Attacking sample 65/100 (True: 8, Index: 791)...
#   Success! Adv label: 5, L2: 673.09, Queries: 57
# Attacking sample 66/100 (True: 8, Index: 832)...
#   Success! Adv label: 6, L2: 580.07, Queries: 49
# Attacking sample 67/100 (True: 8, Index: 838)...
#   Success! Adv label: 5, L2: 528.69, Queries: 45
# Attacking sample 68/100 (True: 8, Index: 860)...
#   Success! Adv label: 3, L2: 710.38, Queries: 63
# Attacking sample 69/100 (True: 8, Index: 864)...
#   Success! Adv label: 9, L2: 744.76, Queries: 63
# Attacking sample 70/100 (True: 8, Index: 889)...
#   Success! Adv label: 3, L2: 599.12, Queries: 51
# Attacking sample 71/100 (True: 8, Index: 905)...
#   Success! Adv label: 9, L2: 787.54, Queries: 69
# Attacking sample 73/100 (True: 8, Index: 919)...
#   Success! Adv label: 3, L2: 583.64, Queries: 49
# Attacking sample 74/100 (True: 8, Index: 923)...
#   Success! Adv label: 3, L2: 693.31, Queries: 59
# Attacking sample 75/100 (True: 8, Index: 926)...
#   Success! Adv label: 5, L2: 659.18, Queries: 55
# Attacking sample 76/100 (True: 8, Index: 933)...
#   Success! Adv label: 3, L2: 616.96, Queries: 51
# Attacking sample 78/100 (True: 8, Index: 971)...
#   Success! Adv label: 2, L2: 764.93, Queries: 63
# Attacking sample 79/100 (True: 8, Index: 1014)...
#   Success! Adv label: 3, L2: 575.28, Queries: 51
# Attacking sample 80/100 (True: 8, Index: 1034)...
#   Success! Adv label: 6, L2: 730.07, Queries: 65
# Attacking sample 81/100 (True: 8, Index: 1053)...
#   Success! Adv label: 6, L2: 586.64, Queries: 49
# Attacking sample 82/100 (True: 8, Index: 1057)...
#   Success! Adv label: 6, L2: 432.08, Queries: 31
# Attacking sample 83/100 (True: 8, Index: 1061)...
#   Success! Adv label: 1, L2: 776.05, Queries: 75
# Attacking sample 84/100 (True: 8, Index: 1062)...
#   Success! Adv label: 3, L2: 640.30, Queries: 57
# Attacking sample 85/100 (True: 8, Index: 1063)...
#   Success! Adv label: 3, L2: 664.01, Queries: 55
# Attacking sample 86/100 (True: 8, Index: 1078)...
#   Success! Adv label: 9, L2: 364.90, Queries: 27
# Attacking sample 87/100 (True: 8, Index: 1088)...
#   Success! Adv label: 2, L2: 719.35, Queries: 59
# Attacking sample 88/100 (True: 8, Index: 1100)...
#   Success! Adv label: 0, L2: 1086.84, Queries: 91
# Attacking sample 89/100 (True: 8, Index: 1106)...
#   Success! Adv label: 2, L2: 1007.95, Queries: 85
# Attacking sample 90/100 (True: 8, Index: 1120)...
#   Success! Adv label: 3, L2: 577.65, Queries: 49
# Attacking sample 91/100 (True: 8, Index: 1132)...
#   Success! Adv label: 2, L2: 605.91, Queries: 49
# Attacking sample 92/100 (True: 8, Index: 1134)...
#   Success! Adv label: 6, L2: 1036.80, Queries: 93
# Attacking sample 93/100 (True: 8, Index: 1140)...
#   Success! Adv label: 5, L2: 308.62, Queries: 25
# Attacking sample 94/100 (True: 8, Index: 1150)...
#   Success! Adv label: 9, L2: 592.98, Queries: 47
# Attacking sample 95/100 (True: 8, Index: 1165)...
#   Success! Adv label: 3, L2: 785.39, Queries: 65
# Attacking sample 96/100 (True: 8, Index: 1179)...
#   Success! Adv label: 3, L2: 627.69, Queries: 53
# Attacking sample 97/100 (True: 8, Index: 1182)...
#   Success! Adv label: 9, L2: 548.38, Queries: 45
# Attacking sample 98/100 (True: 8, Index: 1186)...
#   Success! Adv label: 2, L2: 733.76, Queries: 57
# Attacking sample 99/100 (True: 8, Index: 1189)...
#   Success! Adv label: 3, L2: 249.90, Queries: 21
# Attacking sample 100/100 (True: 8, Index: 1207)...
#   Success! Adv label: 9, L2: 650.84, Queries: 51
# Attacking sample 1/100 (True: 9, Index: 6)...
#   Success! Adv label: 7, L2: 316.93, Queries: 25
# Attacking sample 2/100 (True: 9, Index: 38)...
#   Success! Adv label: 7, L2: 55.74, Queries: 5
# Attacking sample 3/100 (True: 9, Index: 55)...
#   Success! Adv label: 0, L2: 143.42, Queries: 11
# Attacking sample 4/100 (True: 9, Index: 56)...
#   Success! Adv label: 4, L2: 414.20, Queries: 33
# Attacking sample 5/100 (True: 9, Index: 91)...
#   Success! Adv label: 3, L2: 273.51, Queries: 21
# Attacking sample 6/100 (True: 9, Index: 99)...
#   Success! Adv label: 7, L2: 451.87, Queries: 37
# Attacking sample 7/100 (True: 9, Index: 101)...
#   Success! Adv label: 5, L2: 599.35, Queries: 49
# Attacking sample 8/100 (True: 9, Index: 114)...
#   Success! Adv label: 8, L2: 673.94, Queries: 49
# Attacking sample 9/100 (True: 9, Index: 133)...
#   Success! Adv label: 8, L2: 616.68, Queries: 43
# Attacking sample 10/100 (True: 9, Index: 171)...
#   Success! Adv label: 8, L2: 95.72, Queries: 7
# Attacking sample 11/100 (True: 9, Index: 179)...
#   Success! Adv label: 7, L2: 601.45, Queries: 51
# Attacking sample 12/100 (True: 9, Index: 195)...
#   Success! Adv label: 4, L2: 196.46, Queries: 15
# Attacking sample 13/100 (True: 9, Index: 214)...
#   Success! Adv label: 4, L2: 495.75, Queries: 41
# Attacking sample 14/100 (True: 9, Index: 218)...
#   Success! Adv label: 4, L2: 376.68, Queries: 31
# Attacking sample 15/100 (True: 9, Index: 222)...
#   Success! Adv label: 8, L2: 341.37, Queries: 25
# Attacking sample 16/100 (True: 9, Index: 224)...
#   Success! Adv label: 6, L2: 446.06, Queries: 33
# Attacking sample 17/100 (True: 9, Index: 238)...
#   Success! Adv label: 4, L2: 425.28, Queries: 31
# Attacking sample 18/100 (True: 9, Index: 243)...
#   Success! Adv label: 8, L2: 724.22, Queries: 57
# Attacking sample 19/100 (True: 9, Index: 245)...
#   Success! Adv label: 4, L2: 491.54, Queries: 41
# Attacking sample 20/100 (True: 9, Index: 246)...
#   Success! Adv label: 8, L2: 618.25, Queries: 43
# Attacking sample 21/100 (True: 9, Index: 251)...
#   Success! Adv label: 7, L2: 257.25, Queries: 21
# Attacking sample 22/100 (True: 9, Index: 303)...
#   Success! Adv label: 4, L2: 263.19, Queries: 21
# Attacking sample 23/100 (True: 9, Index: 305)...
#   Success! Adv label: 8, L2: 262.22, Queries: 19
# Attacking sample 24/100 (True: 9, Index: 307)...
#   Success! Adv label: 4, L2: 546.65, Queries: 47
# Attacking sample 25/100 (True: 9, Index: 315)...
#   Success! Adv label: 8, L2: 701.31, Queries: 51
# Attacking sample 26/100 (True: 9, Index: 354)...
#   Success! Adv label: 4, L2: 538.06, Queries: 43
# Attacking sample 27/100 (True: 9, Index: 364)...
#   Success! Adv label: 8, L2: 645.87, Queries: 51
# Attacking sample 28/100 (True: 9, Index: 389)...
#   Success! Adv label: 4, L2: 298.78, Queries: 23
# Attacking sample 29/100 (True: 9, Index: 407)...
#   Success! Adv label: 8, L2: 233.95, Queries: 17
# Attacking sample 30/100 (True: 9, Index: 411)...
#   Success! Adv label: 4, L2: 208.74, Queries: 15
# Attacking sample 31/100 (True: 9, Index: 417)...
#   Success! Adv label: 7, L2: 364.48, Queries: 33
# Attacking sample 32/100 (True: 9, Index: 421)...
#   Success! Adv label: 4, L2: 379.50, Queries: 29
# Attacking sample 33/100 (True: 9, Index: 438)...
#   Success! Adv label: 4, L2: 426.66, Queries: 33
# Attacking sample 34/100 (True: 9, Index: 443)...
#   Success! Adv label: 3, L2: 588.92, Queries: 47
# Attacking sample 35/100 (True: 9, Index: 444)...
#   Success! Adv label: 4, L2: 308.27, Queries: 25
# Attacking sample 36/100 (True: 9, Index: 446)...
#   Success! Adv label: 7, L2: 534.78, Queries: 47
# Attacking sample 37/100 (True: 9, Index: 455)...
#   Success! Adv label: 7, L2: 297.72, Queries: 25
# Attacking sample 38/100 (True: 9, Index: 469)...
#   Success! Adv label: 4, L2: 736.83, Queries: 59
# Attacking sample 39/100 (True: 9, Index: 472)...
#   Success! Adv label: 3, L2: 696.60, Queries: 53
# Attacking sample 40/100 (True: 9, Index: 473)...
#   Success! Adv label: 4, L2: 624.26, Queries: 47
# Attacking sample 41/100 (True: 9, Index: 482)...
#   Success! Adv label: 4, L2: 406.48, Queries: 31
# Attacking sample 42/100 (True: 9, Index: 490)...
#   Success! Adv label: 8, L2: 782.04, Queries: 59
# Attacking sample 43/100 (True: 9, Index: 496)...
#   Success! Adv label: 4, L2: 385.38, Queries: 31
# Attacking sample 44/100 (True: 9, Index: 507)...
#   Success! Adv label: 8, L2: 416.29, Queries: 29
# Attacking sample 45/100 (True: 9, Index: 508)...
#   Success! Adv label: 7, L2: 468.19, Queries: 37
# Attacking sample 46/100 (True: 9, Index: 514)...
#   Success! Adv label: 4, L2: 178.29, Queries: 13
# Attacking sample 47/100 (True: 9, Index: 522)...
#   Success! Adv label: 4, L2: 57.26, Queries: 5
# Attacking sample 48/100 (True: 9, Index: 535)...
#   Success! Adv label: 4, L2: 431.29, Queries: 35
# Attacking sample 49/100 (True: 9, Index: 542)...
#   Success! Adv label: 8, L2: 375.74, Queries: 29
# Attacking sample 50/100 (True: 9, Index: 553)...
#   Success! Adv label: 4, L2: 576.23, Queries: 47
# Attacking sample 51/100 (True: 9, Index: 554)...
#   Success! Adv label: 4, L2: 745.98, Queries: 59
# Attacking sample 52/100 (True: 9, Index: 565)...
#   Success! Adv label: 0, L2: 422.08, Queries: 33
# Attacking sample 53/100 (True: 9, Index: 569)...
#   Success! Adv label: 4, L2: 461.26, Queries: 37
# Attacking sample 54/100 (True: 9, Index: 572)...
#   Success! Adv label: 5, L2: 330.25, Queries: 25
# Attacking sample 55/100 (True: 9, Index: 574)...
#   Success! Adv label: 8, L2: 356.43, Queries: 27
# Attacking sample 56/100 (True: 9, Index: 601)...
#   Success! Adv label: 8, L2: 385.58, Queries: 27
# Attacking sample 57/100 (True: 9, Index: 634)...
#   Success! Adv label: 5, L2: 391.16, Queries: 29
# Attacking sample 58/100 (True: 9, Index: 635)...
#   Success! Adv label: 4, L2: 590.60, Queries: 53
# Attacking sample 59/100 (True: 9, Index: 637)...
#   Success! Adv label: 4, L2: 553.62, Queries: 43
# Attacking sample 60/100 (True: 9, Index: 640)...
#   Success! Adv label: 4, L2: 522.39, Queries: 41
# Attacking sample 61/100 (True: 9, Index: 653)...
#   Success! Adv label: 3, L2: 560.03, Queries: 41
# Attacking sample 62/100 (True: 9, Index: 654)...
#   Success! Adv label: 4, L2: 495.30, Queries: 39
# Attacking sample 63/100 (True: 9, Index: 656)...
#   Success! Adv label: 8, L2: 633.38, Queries: 47
# Attacking sample 64/100 (True: 9, Index: 666)...
#   Success! Adv label: 4, L2: 455.31, Queries: 37
# Attacking sample 65/100 (True: 9, Index: 685)...
#   Success! Adv label: 7, L2: 600.79, Queries: 53
# Attacking sample 66/100 (True: 9, Index: 711)...
#   Success! Adv label: 4, L2: 199.08, Queries: 15
# Attacking sample 67/100 (True: 9, Index: 729)...
#   Success! Adv label: 8, L2: 446.61, Queries: 33
# Attacking sample 68/100 (True: 9, Index: 739)...
#   Success! Adv label: 4, L2: 422.83, Queries: 33
# Attacking sample 69/100 (True: 9, Index: 747)...
#   Success! Adv label: 8, L2: 365.73, Queries: 27
# Attacking sample 70/100 (True: 9, Index: 767)...
#   Success! Adv label: 8, L2: 444.28, Queries: 33
# Attacking sample 71/100 (True: 9, Index: 783)...
#   Success! Adv label: 5, L2: 500.45, Queries: 41
# Attacking sample 72/100 (True: 9, Index: 787)...
#   Success! Adv label: 8, L2: 578.43, Queries: 41
# Attacking sample 73/100 (True: 9, Index: 796)...
#   Success! Adv label: 7, L2: 382.48, Queries: 29
# Attacking sample 74/100 (True: 9, Index: 804)...
#   Success! Adv label: 7, L2: 662.95, Queries: 59
# Attacking sample 75/100 (True: 9, Index: 818)...
#   Success! Adv label: 4, L2: 659.00, Queries: 57
# Attacking sample 76/100 (True: 9, Index: 825)...
#   Success! Adv label: 8, L2: 348.40, Queries: 25
# Attacking sample 77/100 (True: 9, Index: 826)...
#   Success! Adv label: 1, L2: 153.01, Queries: 13
# Attacking sample 78/100 (True: 9, Index: 831)...
#   Success! Adv label: 4, L2: 469.77, Queries: 35
# Attacking sample 79/100 (True: 9, Index: 880)...
#   Success! Adv label: 5, L2: 456.62, Queries: 33
# Attacking sample 80/100 (True: 9, Index: 884)...
#   Success! Adv label: 4, L2: 438.85, Queries: 35
# Attacking sample 81/100 (True: 9, Index: 891)...
#   Success! Adv label: 4, L2: 140.82, Queries: 11
# Attacking sample 82/100 (True: 9, Index: 893)...
#   Success! Adv label: 2, L2: 591.18, Queries: 53
# Attacking sample 83/100 (True: 9, Index: 899)...
#   Success! Adv label: 4, L2: 425.77, Queries: 35
# Attacking sample 84/100 (True: 9, Index: 912)...
#   Success! Adv label: 5, L2: 460.22, Queries: 33
# Attacking sample 85/100 (True: 9, Index: 920)...
#   Success! Adv label: 4, L2: 549.48, Queries: 43
# Attacking sample 86/100 (True: 9, Index: 925)...
#   Success! Adv label: 8, L2: 360.95, Queries: 25
# Attacking sample 87/100 (True: 9, Index: 940)...
#   Success! Adv label: 4, L2: 342.66, Queries: 29
# Attacking sample 88/100 (True: 9, Index: 958)...
#   Success! Adv label: 4, L2: 448.48, Queries: 33
# Attacking sample 89/100 (True: 9, Index: 969)...
#   Success! Adv label: 8, L2: 365.40, Queries: 25
# Attacking sample 90/100 (True: 9, Index: 978)...
#   Success! Adv label: 4, L2: 420.68, Queries: 33
# Attacking sample 91/100 (True: 9, Index: 979)...
#   Success! Adv label: 4, L2: 337.76, Queries: 25
# Attacking sample 92/100 (True: 9, Index: 980)...
#   Success! Adv label: 8, L2: 351.66, Queries: 27
# Attacking sample 93/100 (True: 9, Index: 991)...
#   Success! Adv label: 7, L2: 521.27, Queries: 45
# Attacking sample 94/100 (True: 9, Index: 997)...
#   Success! Adv label: 4, L2: 229.18, Queries: 19
# Attacking sample 95/100 (True: 9, Index: 1006)...
#   Success! Adv label: 7, L2: 505.75, Queries: 43
# Attacking sample 96/100 (True: 9, Index: 1011)...
#   Success! Adv label: 4, L2: 767.70, Queries: 63
# Attacking sample 97/100 (True: 9, Index: 1020)...
#   Success! Adv label: 3, L2: 555.42, Queries: 43
# Attacking sample 98/100 (True: 9, Index: 1023)...
#   Success! Adv label: 4, L2: 760.69, Queries: 63
# Attacking sample 99/100 (True: 9, Index: 1042)...
#   Success! Adv label: 4, L2: 309.63, Queries: 23
# Attacking sample 100/100 (True: 9, Index: 1046)...
#   Success! Adv label: 4, L2: 366.79, Queries: 29
# Time taken to generate adversarial samples: 99.6986 seconds
#
# Stats saved to: adversarial_8bit_test_images\per_sample_stats.csv
#
# ===== Attack Summary =====
# Total trials: 986
# Misclassified before attack: 14
# Success rate: 980/986 (99.4%)
# Mean L2 (successful): 546.95
# Mean queries (successful): 43.18
#
# Showing successful adversarial examples...

# %% [markdown]
# ### On Least feature importance features

# %%
import os
import warnings
import numpy as np
import torch
import joblib
import pandas as pd
from PIL import Image
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import torch.nn.functional as F
import time


# Set seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# ─────────────── PATHS ────────────────────────────────────────────────────
LENET_MODEL_PATH = os.path.normpath("Models and Data splits/lenet.pt")  # TorchScript model
DATA_PKL = os.path.normpath("Models and Data splits/data_[SCALED] Train_Test_Splits.pkl")
RF_ALL_CLASSES_PATH = os.path.normpath("Models and Data splits/random_forest.pkl")
OUT_DIR = "adversarial_8bit_LeastK_test_images"
os.makedirs(OUT_DIR, exist_ok=True)

if not os.path.exists(RF_ALL_CLASSES_PATH):
    raise FileNotFoundError(f"Random Forest model not found at {RF_ALL_CLASSES_PATH}")

# ─────────── HYPER-PARAMETERS ─────────────────────────────────────────────
EPSILON_STEP = 0.01
ITERATIONS = 100
TOTAL_EPSILON = 0.5
TOP_K_FEATURES = 196
SAMPLES_PER_DIGIT = 100
MAX_L2 = 10000

def plot_adversarial_example(original_img, adv_img, true_label, adv_label, l2_mag, sample_idx, queries, title_suffix=""):
    if original_img.size == 784:
        original_img = original_img.reshape(28, 28)
    if adv_img.size == 784:
        adv_img = adv_img.reshape(28, 28)
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(original_img, cmap='gray')
    axes[0].set_title(f"Original\nTrue: {true_label}")
    axes[0].axis('off')
    axes[1].imshow(adv_img, cmap='gray')
    axes[1].set_title(f"Adversarial\nPred: {adv_label}")
    axes[1].axis('off')
    fig.suptitle(f"Sample {sample_idx} | L2: {l2_mag:.2f} | Queries: {queries} {title_suffix}")
    plt.show()
    plt.close(fig)  # <-- added here


# ─────────── Load Data ─────────────────────────────────────────────────────
try:
    data = joblib.load(DATA_PKL)
    _, X_samples , _, y_samples = data
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PKL}. Please check the path.")
    exit()

if X_samples.max() > 1.0:
    X_samples = X_samples.astype(np.float32) / 255.0
    warnings.warn("Data appeared in [0,255]; normalized to [0,1].")

# ─────────── Load TorchScripted LeNet ──────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
try:
    model = torch.jit.load(LENET_MODEL_PATH, map_location=device)
    model.eval()
    print(f"LeNet TorchScript model loaded from: {LENET_MODEL_PATH}")
except Exception as e:
    print(f"Error loading TorchScript LeNet model: {e}")
    exit()

def to_model(x01_batch):
    if x01_batch.ndim == 2 and x01_batch.shape == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)
    elif x01_batch.ndim == 3 and x01_batch.shape[1:] == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(1)
    elif x01_batch.ndim == 4 and x01_batch.shape[1] == 1:
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device)
    elif x01_batch.ndim == 1 and x01_batch.size == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(1, 1, 28, 28), dtype=torch.float32, device=device)
    elif x01_batch.ndim == 2 and x01_batch.shape[1] == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(x01_batch.shape[0], 1, 28, 28), dtype=torch.float32, device=device)
    else:
        raise ValueError(f"Unsupported input shape for to_model: {x01_batch.shape}")
    return tensor_batch


def model_query(x_tensor_batch):
    with torch.no_grad():
        return model(x_tensor_batch)

# ─────────── Load Random Forest Model ──────────────────────────────────────
rf_all_classes = None
top_feature_indices = None
print("Loading Random Forest Classifier for all classes...")
try:
    rf_all_classes = joblib.load(RF_ALL_CLASSES_PATH)
    feature_importances = rf_all_classes.feature_importances_
    top_feature_indices = np.argsort(feature_importances)[:TOP_K_FEATURES]
    
    #top_feature_indices = np.argsort(-feature_importances)[:TOP_K_FEATURES]
    print(f"Random Forest loaded. Using top {TOP_K_FEATURES} features.")
except Exception as e:
    print(f"Error loading Random Forest: {e}")
    top_feature_indices = np.arange(28 * 28)

# ─────────── I-FGSM Attack ─────────────────────────────────────────────────
def ifgsm_attack(original_image_np, true_label, model_target, epsilon_step, iterations,
                 total_epsilon_budget, features_to_perturb, query_count_tracker):
    if original_image_np.ndim == 1 and original_image_np.size == 784:
        original_image_np = original_image_np.reshape(28, 28)

    perturbed_image_np = original_image_np.copy()
    final_pred_label = true_label

    for i in range(iterations):
        image_tensor = to_model(perturbed_image_np)
        image_tensor.requires_grad = True
        output = model_target(image_tensor)
        query_count_tracker[0] += 1
        loss = F.cross_entropy(output, torch.tensor([true_label], device=device))
        model_target.zero_grad()
        loss.backward()
        data_grad_sign = torch.sign(image_tensor.grad.data).cpu().numpy()

        gradient_mask = np.zeros_like(data_grad_sign, dtype=np.float32)
        h, w = perturbed_image_np.shape
        rows, cols = np.unravel_index(features_to_perturb, (h, w))
        gradient_mask[0, 0, rows, cols] = data_grad_sign[0, 0, rows, cols]
        gradient_mask_for_update = gradient_mask.reshape(perturbed_image_np.shape)

        perturbed_image_np += epsilon_step * gradient_mask_for_update
        perturbation = perturbed_image_np - original_image_np
        perturbation = np.clip(perturbation, -total_epsilon_budget, total_epsilon_budget)
        perturbed_image_np = original_image_np + perturbation
        perturbed_image_np = np.clip(perturbed_image_np, 0, 1)

        # Discretize and check prediction on discretized image
        adv_uint8_temp = np.round(perturbed_image_np * 255).astype(np.uint8)
        adv_float_temp = adv_uint8_temp.astype(np.float32) / 255.0
        with torch.no_grad():
            output_temp = model_target(to_model(adv_float_temp))
            pred_temp = output_temp.argmax(dim=1).item()
            query_count_tracker[0] += 1

        if pred_temp != true_label:
            final_pred_label = pred_temp
            break

    # Final adversarial image (discretized)
    adv_uint8 = np.round(perturbed_image_np * 255).astype(np.uint8)
    adv_float = adv_uint8.astype(np.float32) / 255.0
    with torch.no_grad():
        output_final = model_target(to_model(adv_float))
        final_pred_label = output_final.argmax(dim=1).item()

    l2_norm = np.linalg.norm(adv_uint8.astype(np.float32) - (original_image_np * 255).astype(np.float32))
    success = (final_pred_label != true_label) and (l2_norm <= MAX_L2)

    return adv_uint8, final_pred_label, l2_norm, success


# ─────────── Attack Execution ──────────────────────────────────────────────
print(f"\n===== Starting Adversarial Attack =====")
total_trials, succ_total, misclassified = 0, 0, 0
records = []


start_time = time.time()


for digit in range(10):
    idxs = np.where(y_samples == digit)[0][:SAMPLES_PER_DIGIT]
    for rank, idx in enumerate(idxs, 1):
        x0 = X_samples[idx].copy()
        y0 = int(y_samples[idx])
        query_count_tracker = [0]
        pred0 = model_query(to_model(x0)).argmax(dim=1).item()
        query_count_tracker[0] += 1

        if pred0 != y0:
            misclassified += 1
            records.append({
                'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
                'adv_label': None, 'success': False, 'queries': query_count_tracker[0],
                'l2_mag': np.nan, 'note': 'Already misclassified'
            })
            continue

        total_trials += 1
        print(f"Attacking sample {rank}/{SAMPLES_PER_DIGIT} (True: {y0}, Index: {idx})...")
        adv_img_uint8, adv_label, l2_mag, success = ifgsm_attack(
            x0, y0, model, EPSILON_STEP, ITERATIONS, TOTAL_EPSILON,
            top_feature_indices, query_count_tracker
        )

        if success:
            succ_total += 1
            fname = f"true{y0}_adv{adv_label}_mag{l2_mag:.1f}_sample{idx}.png"
            Image.fromarray(adv_img_uint8, mode="L").save(os.path.join(OUT_DIR, fname))

        records.append({
            'sample_idx': idx, 'true_label': y0, 'initial_pred': pred0,
            'adv_label': adv_label, 'success': success, 'queries': query_count_tracker[0],
            'l2_mag': l2_mag if success else np.nan, 'note': 'I-FGSM' + (' successful' if success else ' failed')
        })

        print(f"  {'Success' if success else 'Failed'}! Adv label: {adv_label}, L2: {l2_mag:.2f}, Queries: {query_count_tracker[0]}")


end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to generate adversarial samples: {elapsed_time:.4f} seconds")


# ─────────── Save Results ──────────────────────────────────────────────────
df = pd.DataFrame(records)
csv_path = os.path.join(OUT_DIR, "per_sample_stats.csv")
df.to_csv(csv_path, index=False)
print(f"\nStats saved to: {csv_path}")

# ─────────── Summary ───────────────────────────────────────────────────────
print(f"\n===== Attack Summary =====")
print(f"Total trials: {total_trials}")
print(f"Misclassified before attack: {misclassified}")
if total_trials > 0:
    success_rate = succ_total / total_trials * 100
    print(f"Success rate: {succ_total}/{total_trials} ({success_rate:.1f}%)")
    if succ_total > 0:
        print(f"Mean L2 (successful): {df[df['success']]['l2_mag'].mean():.2f}")
        print(f"Mean queries (successful): {df[df['success']]['queries'].mean():.2f}")

# ─────────── Display Examples ──────────────────────────────────────────────
success_df = df[df['success']]
if not success_df.empty:
    print("\nShowing successful adversarial examples...")
    show_ids = success_df.sample(min(3, len(success_df))).index.tolist()
    for record_idx in show_ids:
        r = df.loc[record_idx]
        fname_prefix = f"true{r['true_label']}_adv{r['adv_label']}_mag{r['l2_mag']:.1f}_sample{r['sample_idx']}"
        match_files = [f for f in os.listdir(OUT_DIR) if f.startswith(fname_prefix)]
        if match_files:
            adv_img_path = os.path.join(OUT_DIR, match_files[0])
            plot_adversarial_example(X_samples[r['sample_idx']], np.array(Image.open(adv_img_path)),
                                     r['true_label'], r['adv_label'], r['l2_mag'],
                                     r['sample_idx'], r['queries'], "(I-FGSM)")
else:
    print("No successful attacks to display. Showing original samples instead.")
    for i in range(min(3, len(df))):
        r = df.iloc[i]
        plot_adversarial_example(X_samples[r['sample_idx']], X_samples[r['sample_idx']],
                                 r['true_label'], r['initial_pred'], 0.0,
                                 r['sample_idx'], r['queries'], "(Original)")
# Out:
# LeNet TorchScript model loaded from: Models and Data splits\lenet.pt
# Loading Random Forest Classifier for all classes...
# Random Forest loaded. Using top 196 features.
#
# ===== Starting Adversarial Attack =====
# Attacking sample 1/100 (True: 0, Index: 29)...
#   Failed! Adv label: 0, L2: 1010.82, Queries: 201
# Attacking sample 2/100 (True: 0, Index: 40)...
#   Failed! Adv label: 0, L2: 1173.30, Queries: 201
# Attacking sample 3/100 (True: 0, Index: 44)...
#   Failed! Adv label: 0, L2: 1179.92, Queries: 201
# Attacking sample 4/100 (True: 0, Index: 59)...
#   Failed! Adv label: 0, L2: 1168.78, Queries: 201
# Attacking sample 5/100 (True: 0, Index: 64)...
#   Failed! Adv label: 0, L2: 1264.70, Queries: 201
# Attacking sample 6/100 (True: 0, Index: 75)...
#   Failed! Adv label: 0, L2: 1029.31, Queries: 201
# Attacking sample 7/100 (True: 0, Index: 80)...
#   Failed! Adv label: 0, L2: 1219.16, Queries: 201
# Attacking sample 8/100 (True: 0, Index: 97)...
#   Failed! Adv label: 0, L2: 900.81, Queries: 201
# Attacking sample 9/100 (True: 0, Index: 115)...
#   Failed! Adv label: 0, L2: 1006.05, Queries: 201
# Attacking sample 10/100 (True: 0, Index: 141)...
#   Failed! Adv label: 0, L2: 1216.63, Queries: 201
# Attacking sample 11/100 (True: 0, Index: 146)...
#   Failed! Adv label: 0, L2: 1294.86, Queries: 201
# Attacking sample 12/100 (True: 0, Index: 156)...
#   Failed! Adv label: 0, L2: 1241.36, Queries: 201
# Attacking sample 13/100 (True: 0, Index: 173)...
#   Failed! Adv label: 0, L2: 1038.64, Queries: 201
# Attacking sample 14/100 (True: 0, Index: 175)...
#   Failed! Adv label: 0, L2: 1091.68, Queries: 201
# Attacking sample 15/100 (True: 0, Index: 193)...
#   Failed! Adv label: 0, L2: 1186.30, Queries: 201
# Attacking sample 16/100 (True: 0, Index: 200)...
#   Failed! Adv label: 0, L2: 1185.79, Queries: 201
# Attacking sample 17/100 (True: 0, Index: 205)...
#   Failed! Adv label: 0, L2: 1222.40, Queries: 201
# Attacking sample 18/100 (True: 0, Index: 210)...
#   Failed! Adv label: 0, L2: 1317.12, Queries: 201
# Attacking sample 19/100 (True: 0, Index: 221)...
#   Failed! Adv label: 0, L2: 1120.60, Queries: 201
# Attacking sample 20/100 (True: 0, Index: 229)...
#   Failed! Adv label: 0, L2: 1222.57, Queries: 201
# Attacking sample 21/100 (True: 0, Index: 249)...
#   Failed! Adv label: 0, L2: 1251.96, Queries: 201
# Attacking sample 22/100 (True: 0, Index: 258)...
#   Failed! Adv label: 0, L2: 1185.76, Queries: 201
# Attacking sample 23/100 (True: 0, Index: 275)...
#   Failed! Adv label: 0, L2: 1295.25, Queries: 201
# Attacking sample 24/100 (True: 0, Index: 292)...
#   Failed! Adv label: 0, L2: 1194.64, Queries: 201
# Attacking sample 25/100 (True: 0, Index: 296)...
#   Failed! Adv label: 0, L2: 1242.37, Queries: 201
# Attacking sample 26/100 (True: 0, Index: 301)...
#   Failed! Adv label: 0, L2: 1111.23, Queries: 201
# Attacking sample 27/100 (True: 0, Index: 314)...
#   Failed! Adv label: 0, L2: 1166.30, Queries: 201
# Attacking sample 28/100 (True: 0, Index: 325)...
#   Failed! Adv label: 0, L2: 1179.38, Queries: 201
# Attacking sample 29/100 (True: 0, Index: 333)...
#   Failed! Adv label: 0, L2: 1207.22, Queries: 201
# Attacking sample 30/100 (True: 0, Index: 345)...
#   Failed! Adv label: 0, L2: 1107.83, Queries: 201
# Attacking sample 31/100 (True: 0, Index: 349)...
#   Failed! Adv label: 0, L2: 1228.87, Queries: 201
# Attacking sample 32/100 (True: 0, Index: 360)...
#   Failed! Adv label: 0, L2: 1193.21, Queries: 201
# Attacking sample 33/100 (True: 0, Index: 365)...
#   Failed! Adv label: 0, L2: 1227.03, Queries: 201
# Attacking sample 34/100 (True: 0, Index: 366)...
#   Failed! Adv label: 0, L2: 1373.52, Queries: 201
# Attacking sample 35/100 (True: 0, Index: 379)...
#   Failed! Adv label: 0, L2: 1258.56, Queries: 201
# Attacking sample 36/100 (True: 0, Index: 385)...
#   Failed! Adv label: 0, L2: 1215.18, Queries: 201
# Attacking sample 37/100 (True: 0, Index: 397)...
#   Failed! Adv label: 0, L2: 1222.39, Queries: 201
# Attacking sample 38/100 (True: 0, Index: 400)...
#   Failed! Adv label: 0, L2: 1121.66, Queries: 201
# Attacking sample 39/100 (True: 0, Index: 405)...
#   Failed! Adv label: 0, L2: 1194.83, Queries: 201
# Attacking sample 40/100 (True: 0, Index: 410)...
#   Failed! Adv label: 0, L2: 1282.36, Queries: 201
# Attacking sample 41/100 (True: 0, Index: 420)...
#   Failed! Adv label: 0, L2: 1209.74, Queries: 201
# Attacking sample 42/100 (True: 0, Index: 424)...
#   Failed! Adv label: 0, L2: 1127.44, Queries: 201
# Attacking sample 43/100 (True: 0, Index: 447)...
#   Failed! Adv label: 0, L2: 1108.72, Queries: 201
# Attacking sample 44/100 (True: 0, Index: 453)...
#   Failed! Adv label: 0, L2: 1078.11, Queries: 201
# Attacking sample 45/100 (True: 0, Index: 457)...
#   Failed! Adv label: 0, L2: 1172.45, Queries: 201
# Attacking sample 46/100 (True: 0, Index: 466)...
#   Failed! Adv label: 0, L2: 1113.70, Queries: 201
# Attacking sample 47/100 (True: 0, Index: 475)...
#   Failed! Adv label: 0, L2: 1291.29, Queries: 201
# Attacking sample 48/100 (True: 0, Index: 483)...
#   Failed! Adv label: 0, L2: 1123.28, Queries: 201
# Attacking sample 49/100 (True: 0, Index: 484)...
#   Failed! Adv label: 0, L2: 1146.29, Queries: 201
# Attacking sample 50/100 (True: 0, Index: 486)...
#   Failed! Adv label: 0, L2: 1252.27, Queries: 201
# Attacking sample 51/100 (True: 0, Index: 487)...
#   Failed! Adv label: 0, L2: 1069.78, Queries: 201
# Attacking sample 52/100 (True: 0, Index: 489)...
#   Failed! Adv label: 0, L2: 1187.37, Queries: 201
# Attacking sample 53/100 (True: 0, Index: 492)...
#   Failed! Adv label: 0, L2: 1206.79, Queries: 201
# Attacking sample 54/100 (True: 0, Index: 506)...
#   Failed! Adv label: 0, L2: 1034.99, Queries: 201
# Attacking sample 55/100 (True: 0, Index: 513)...
#   Failed! Adv label: 0, L2: 1217.79, Queries: 201
# Attacking sample 56/100 (True: 0, Index: 518)...
#   Failed! Adv label: 0, L2: 1259.13, Queries: 201
# Attacking sample 57/100 (True: 0, Index: 521)...
#   Failed! Adv label: 0, L2: 1146.15, Queries: 201
# Attacking sample 58/100 (True: 0, Index: 527)...
#   Failed! Adv label: 0, L2: 1140.95, Queries: 201
# Attacking sample 59/100 (True: 0, Index: 529)...
#   Failed! Adv label: 0, L2: 1187.88, Queries: 201
# Attacking sample 60/100 (True: 0, Index: 531)...
#   Failed! Adv label: 0, L2: 1235.88, Queries: 201
# Attacking sample 61/100 (True: 0, Index: 546)...
#   Failed! Adv label: 0, L2: 1201.00, Queries: 201
# Attacking sample 62/100 (True: 0, Index: 551)...
#   Failed! Adv label: 0, L2: 1025.70, Queries: 201
# Attacking sample 63/100 (True: 0, Index: 555)...
#   Failed! Adv label: 0, L2: 1080.78, Queries: 201
# Attacking sample 64/100 (True: 0, Index: 587)...
#   Failed! Adv label: 0, L2: 1124.81, Queries: 201
# Attacking sample 65/100 (True: 0, Index: 604)...
#   Failed! Adv label: 0, L2: 1225.97, Queries: 201
# Attacking sample 66/100 (True: 0, Index: 614)...
#   Failed! Adv label: 0, L2: 1226.72, Queries: 201
# Attacking sample 67/100 (True: 0, Index: 615)...
#   Failed! Adv label: 0, L2: 1349.58, Queries: 201
# Attacking sample 68/100 (True: 0, Index: 618)...
#   Failed! Adv label: 0, L2: 1057.33, Queries: 201
# Attacking sample 69/100 (True: 0, Index: 638)...
#   Failed! Adv label: 0, L2: 1140.48, Queries: 201
# Attacking sample 70/100 (True: 0, Index: 642)...
#   Failed! Adv label: 0, L2: 1273.15, Queries: 201
# Attacking sample 71/100 (True: 0, Index: 655)...
#   Failed! Adv label: 0, L2: 988.28, Queries: 201
# Attacking sample 72/100 (True: 0, Index: 658)...
#   Failed! Adv label: 0, L2: 1135.24, Queries: 201
# Attacking sample 73/100 (True: 0, Index: 665)...
#   Failed! Adv label: 0, L2: 1126.43, Queries: 201
# Attacking sample 74/100 (True: 0, Index: 671)...
#   Failed! Adv label: 0, L2: 1172.93, Queries: 201
# Attacking sample 75/100 (True: 0, Index: 681)...
#   Failed! Adv label: 0, L2: 1363.24, Queries: 201
# Attacking sample 76/100 (True: 0, Index: 691)...
#   Failed! Adv label: 0, L2: 1220.68, Queries: 201
# Attacking sample 77/100 (True: 0, Index: 700)...
#   Failed! Adv label: 0, L2: 1190.77, Queries: 201
# Attacking sample 78/100 (True: 0, Index: 706)...
#   Failed! Adv label: 0, L2: 1234.26, Queries: 201
# Attacking sample 79/100 (True: 0, Index: 712)...
#   Failed! Adv label: 0, L2: 1338.28, Queries: 201
# Attacking sample 80/100 (True: 0, Index: 713)...
#   Failed! Adv label: 0, L2: 1264.07, Queries: 201
# Attacking sample 81/100 (True: 0, Index: 736)...
#   Failed! Adv label: 0, L2: 1268.71, Queries: 201
# Attacking sample 82/100 (True: 0, Index: 742)...
#   Failed! Adv label: 0, L2: 1157.18, Queries: 201
# Attacking sample 83/100 (True: 0, Index: 744)...
#   Failed! Adv label: 0, L2: 1179.68, Queries: 201
# Attacking sample 84/100 (True: 0, Index: 760)...
#   Failed! Adv label: 0, L2: 1232.92, Queries: 201
# Attacking sample 85/100 (True: 0, Index: 772)...
#   Failed! Adv label: 0, L2: 1160.85, Queries: 201
# Attacking sample 86/100 (True: 0, Index: 781)...
#   Failed! Adv label: 0, L2: 1131.79, Queries: 201
# Attacking sample 87/100 (True: 0, Index: 809)...
#   Failed! Adv label: 0, L2: 1190.57, Queries: 201
# Attacking sample 88/100 (True: 0, Index: 813)...
#   Failed! Adv label: 0, L2: 1295.47, Queries: 201
# Attacking sample 89/100 (True: 0, Index: 820)...
#   Failed! Adv label: 0, L2: 1241.13, Queries: 201
# Attacking sample 90/100 (True: 0, Index: 823)...
#   Failed! Adv label: 0, L2: 1250.93, Queries: 201
# Attacking sample 91/100 (True: 0, Index: 844)...
#   Failed! Adv label: 0, L2: 1248.28, Queries: 201
# Attacking sample 92/100 (True: 0, Index: 848)...
#   Failed! Adv label: 0, L2: 1323.78, Queries: 201
# Attacking sample 93/100 (True: 0, Index: 861)...
#   Failed! Adv label: 0, L2: 1120.80, Queries: 201
# Attacking sample 94/100 (True: 0, Index: 865)...
#   Failed! Adv label: 0, L2: 1153.12, Queries: 201
# Attacking sample 95/100 (True: 0, Index: 869)...
#   Failed! Adv label: 0, L2: 1006.29, Queries: 201
# Attacking sample 96/100 (True: 0, Index: 876)...
#   Failed! Adv label: 0, L2: 1297.43, Queries: 201
# Attacking sample 97/100 (True: 0, Index: 885)...
#   Failed! Adv label: 0, L2: 1318.62, Queries: 201
# Attacking sample 98/100 (True: 0, Index: 906)...
#   Failed! Adv label: 0, L2: 1153.16, Queries: 201
# Attacking sample 99/100 (True: 0, Index: 907)...
#   Failed! Adv label: 0, L2: 1196.73, Queries: 201
# Attacking sample 100/100 (True: 0, Index: 918)...
#   Failed! Adv label: 0, L2: 1156.18, Queries: 201
# Attacking sample 1/100 (True: 1, Index: 2)...
#   Failed! Adv label: 1, L2: 1284.00, Queries: 201
# Attacking sample 2/100 (True: 1, Index: 3)...
#   Failed! Adv label: 1, L2: 1281.43, Queries: 201
# Attacking sample 3/100 (True: 1, Index: 9)...
#   Failed! Adv label: 1, L2: 1235.48, Queries: 201
# Attacking sample 4/100 (True: 1, Index: 25)...
#   Failed! Adv label: 1, L2: 1096.70, Queries: 201
# Attacking sample 5/100 (True: 1, Index: 36)...
#   Failed! Adv label: 1, L2: 1182.93, Queries: 201
# Attacking sample 6/100 (True: 1, Index: 63)...
#   Failed! Adv label: 1, L2: 1276.81, Queries: 201
# Attacking sample 7/100 (True: 1, Index: 65)...
#   Failed! Adv label: 1, L2: 1118.13, Queries: 201
# Attacking sample 8/100 (True: 1, Index: 68)...
#   Failed! Adv label: 1, L2: 1171.47, Queries: 201
# Attacking sample 9/100 (True: 1, Index: 76)...
#   Failed! Adv label: 1, L2: 1262.52, Queries: 201
# Attacking sample 10/100 (True: 1, Index: 83)...
#   Failed! Adv label: 1, L2: 1291.01, Queries: 201
# Attacking sample 11/100 (True: 1, Index: 90)...
#   Success! Adv label: 9, L2: 32.59, Queries: 3
# Attacking sample 12/100 (True: 1, Index: 94)...
#   Failed! Adv label: 1, L2: 1172.22, Queries: 201
# Attacking sample 13/100 (True: 1, Index: 100)...
#   Failed! Adv label: 1, L2: 1281.43, Queries: 201
# Attacking sample 14/100 (True: 1, Index: 123)...
#   Failed! Adv label: 1, L2: 1263.40, Queries: 201
# Attacking sample 15/100 (True: 1, Index: 150)...
#   Failed! Adv label: 1, L2: 1198.75, Queries: 201
# Attacking sample 16/100 (True: 1, Index: 152)...
#   Failed! Adv label: 1, L2: 1135.52, Queries: 201
# Attacking sample 17/100 (True: 1, Index: 178)...
#   Failed! Adv label: 1, L2: 1162.41, Queries: 201
# Attacking sample 18/100 (True: 1, Index: 185)...
#   Failed! Adv label: 1, L2: 1272.09, Queries: 201
# Attacking sample 19/100 (True: 1, Index: 191)...
#   Failed! Adv label: 1, L2: 1232.15, Queries: 201
# Attacking sample 20/100 (True: 1, Index: 201)...
#   Failed! Adv label: 1, L2: 1017.70, Queries: 201
# Attacking sample 21/100 (True: 1, Index: 203)...
#   Failed! Adv label: 1, L2: 1126.86, Queries: 201
# Attacking sample 22/100 (True: 1, Index: 213)...
#   Failed! Adv label: 1, L2: 1237.40, Queries: 201
# Attacking sample 23/100 (True: 1, Index: 220)...
#   Failed! Adv label: 1, L2: 1134.36, Queries: 201
# Attacking sample 24/100 (True: 1, Index: 223)...
#   Failed! Adv label: 1, L2: 1026.23, Queries: 201
# Attacking sample 25/100 (True: 1, Index: 226)...
#   Failed! Adv label: 1, L2: 1131.57, Queries: 201
# Attacking sample 26/100 (True: 1, Index: 232)...
#   Failed! Adv label: 1, L2: 1183.80, Queries: 201
# Attacking sample 27/100 (True: 1, Index: 241)...
#   Failed! Adv label: 1, L2: 1125.29, Queries: 201
# Attacking sample 28/100 (True: 1, Index: 254)...
#   Failed! Adv label: 1, L2: 1086.16, Queries: 201
# Attacking sample 29/100 (True: 1, Index: 281)...
#   Failed! Adv label: 1, L2: 1042.02, Queries: 201
# Attacking sample 30/100 (True: 1, Index: 284)...
#   Failed! Adv label: 1, L2: 1253.06, Queries: 201
# Attacking sample 31/100 (True: 1, Index: 285)...
#   Failed! Adv label: 1, L2: 1253.06, Queries: 201
# Attacking sample 32/100 (True: 1, Index: 286)...
#   Failed! Adv label: 1, L2: 1274.14, Queries: 201
# Attacking sample 33/100 (True: 1, Index: 287)...
#   Failed! Adv label: 1, L2: 1273.25, Queries: 201
# Attacking sample 34/100 (True: 1, Index: 294)...
#   Failed! Adv label: 1, L2: 1130.53, Queries: 201
# Attacking sample 35/100 (True: 1, Index: 298)...
#   Failed! Adv label: 1, L2: 1243.66, Queries: 201
# Attacking sample 36/100 (True: 1, Index: 306)...
#   Failed! Adv label: 1, L2: 995.06, Queries: 201
# Attacking sample 37/100 (True: 1, Index: 312)...
#   Failed! Adv label: 1, L2: 1276.44, Queries: 201
# Attacking sample 38/100 (True: 1, Index: 317)...
#   Failed! Adv label: 1, L2: 1259.10, Queries: 201
# Attacking sample 39/100 (True: 1, Index: 334)...
#   Failed! Adv label: 1, L2: 1227.60, Queries: 201
# Attacking sample 40/100 (True: 1, Index: 337)...
#   Failed! Adv label: 1, L2: 1229.37, Queries: 201
# Attacking sample 41/100 (True: 1, Index: 338)...
#   Failed! Adv label: 1, L2: 1275.06, Queries: 201
# Attacking sample 42/100 (True: 1, Index: 348)...
#   Failed! Adv label: 1, L2: 1227.16, Queries: 201
# Attacking sample 43/100 (True: 1, Index: 361)...
#   Failed! Adv label: 1, L2: 1215.20, Queries: 201
# Attacking sample 44/100 (True: 1, Index: 363)...
#   Failed! Adv label: 1, L2: 1158.32, Queries: 201
# Attacking sample 45/100 (True: 1, Index: 367)...
#   Failed! Adv label: 1, L2: 1172.68, Queries: 201
# Attacking sample 46/100 (True: 1, Index: 375)...
#   Failed! Adv label: 1, L2: 1293.16, Queries: 201
# Attacking sample 47/100 (True: 1, Index: 384)...
#   Failed! Adv label: 1, L2: 1253.16, Queries: 201
# Attacking sample 48/100 (True: 1, Index: 412)...
#   Failed! Adv label: 1, L2: 1226.00, Queries: 201
# Attacking sample 49/100 (True: 1, Index: 425)...
#   Failed! Adv label: 1, L2: 1258.36, Queries: 201
# Attacking sample 50/100 (True: 1, Index: 428)...
#   Failed! Adv label: 1, L2: 1115.05, Queries: 201
# Attacking sample 51/100 (True: 1, Index: 463)...
#   Failed! Adv label: 1, L2: 1269.14, Queries: 201
# Attacking sample 52/100 (True: 1, Index: 499)...
#   Failed! Adv label: 1, L2: 1192.31, Queries: 201
# Attacking sample 53/100 (True: 1, Index: 502)...
#   Failed! Adv label: 1, L2: 1153.00, Queries: 201
# Attacking sample 54/100 (True: 1, Index: 526)...
#   Failed! Adv label: 1, L2: 1318.68, Queries: 201
# Attacking sample 55/100 (True: 1, Index: 532)...
#   Failed! Adv label: 1, L2: 1143.77, Queries: 201
# Attacking sample 56/100 (True: 1, Index: 536)...
#   Failed! Adv label: 1, L2: 1272.35, Queries: 201
# Attacking sample 57/100 (True: 1, Index: 537)...
#   Failed! Adv label: 1, L2: 1232.66, Queries: 201
# Attacking sample 58/100 (True: 1, Index: 539)...
#   Failed! Adv label: 1, L2: 1178.38, Queries: 201
# Attacking sample 60/100 (True: 1, Index: 560)...
#   Failed! Adv label: 1, L2: 1185.88, Queries: 201
# Attacking sample 61/100 (True: 1, Index: 561)...
#   Failed! Adv label: 1, L2: 1189.43, Queries: 201
# Attacking sample 62/100 (True: 1, Index: 570)...
#   Failed! Adv label: 1, L2: 1295.08, Queries: 201
# Attacking sample 63/100 (True: 1, Index: 573)...
#   Success! Adv label: 2, L2: 168.20, Queries: 15
# Attacking sample 64/100 (True: 1, Index: 576)...
#   Failed! Adv label: 1, L2: 1303.41, Queries: 201
# Attacking sample 65/100 (True: 1, Index: 580)...
#   Failed! Adv label: 1, L2: 996.10, Queries: 201
# Attacking sample 66/100 (True: 1, Index: 588)...
#   Failed! Adv label: 1, L2: 1258.80, Queries: 201
# Attacking sample 67/100 (True: 1, Index: 620)...
#   Failed! Adv label: 1, L2: 1090.48, Queries: 201
# Attacking sample 68/100 (True: 1, Index: 621)...
#   Failed! Adv label: 1, L2: 1171.61, Queries: 201
# Attacking sample 69/100 (True: 1, Index: 622)...
#   Success! Adv label: 2, L2: 872.40, Queries: 69
# Attacking sample 70/100 (True: 1, Index: 627)...
#   Failed! Adv label: 1, L2: 1286.81, Queries: 201
# Attacking sample 71/100 (True: 1, Index: 630)...
#   Failed! Adv label: 1, L2: 1145.20, Queries: 201
# Attacking sample 72/100 (True: 1, Index: 632)...
#   Failed! Adv label: 1, L2: 1054.92, Queries: 201
# Attacking sample 73/100 (True: 1, Index: 644)...
#   Failed! Adv label: 1, L2: 1124.09, Queries: 201
# Attacking sample 74/100 (True: 1, Index: 646)...
#   Failed! Adv label: 1, L2: 1253.76, Queries: 201
# Attacking sample 75/100 (True: 1, Index: 649)...
#   Failed! Adv label: 1, L2: 1228.75, Queries: 201
# Attacking sample 76/100 (True: 1, Index: 662)...
#   Failed! Adv label: 1, L2: 1241.36, Queries: 201
# Attacking sample 77/100 (True: 1, Index: 663)...
#   Failed! Adv label: 1, L2: 1269.55, Queries: 201
# Attacking sample 78/100 (True: 1, Index: 669)...
#   Failed! Adv label: 1, L2: 1273.48, Queries: 201
# Attacking sample 79/100 (True: 1, Index: 677)...
#   Failed! Adv label: 1, L2: 1291.44, Queries: 201
# Attacking sample 80/100 (True: 1, Index: 686)...
#   Failed! Adv label: 1, L2: 1188.21, Queries: 201
# Attacking sample 81/100 (True: 1, Index: 689)...
#   Failed! Adv label: 1, L2: 1155.39, Queries: 201
# Attacking sample 82/100 (True: 1, Index: 703)...
#   Failed! Adv label: 1, L2: 1118.62, Queries: 201
# Attacking sample 83/100 (True: 1, Index: 705)...
#   Failed! Adv label: 1, L2: 1298.17, Queries: 201
# Attacking sample 84/100 (True: 1, Index: 709)...
#   Failed! Adv label: 1, L2: 1309.31, Queries: 201
# Attacking sample 85/100 (True: 1, Index: 724)...
#   Failed! Adv label: 1, L2: 1053.09, Queries: 201
# Attacking sample 86/100 (True: 1, Index: 727)...
#   Failed! Adv label: 1, L2: 978.83, Queries: 201
# Attacking sample 87/100 (True: 1, Index: 734)...
#   Failed! Adv label: 1, L2: 1190.23, Queries: 201
# Attacking sample 88/100 (True: 1, Index: 740)...
#   Failed! Adv label: 1, L2: 1150.90, Queries: 201
# Attacking sample 89/100 (True: 1, Index: 741)...
#   Failed! Adv label: 1, L2: 1174.78, Queries: 201
# Attacking sample 90/100 (True: 1, Index: 743)...
#   Failed! Adv label: 1, L2: 1182.35, Queries: 201
# Attacking sample 91/100 (True: 1, Index: 759)...
#   Failed! Adv label: 1, L2: 1159.97, Queries: 201
# Attacking sample 92/100 (True: 1, Index: 768)...
#   Failed! Adv label: 1, L2: 1226.53, Queries: 201
# Attacking sample 93/100 (True: 1, Index: 775)...
#   Failed! Adv label: 1, L2: 1029.68, Queries: 201
# Attacking sample 94/100 (True: 1, Index: 782)...
#   Failed! Adv label: 1, L2: 1201.70, Queries: 201
# Attacking sample 95/100 (True: 1, Index: 798)...
#   Failed! Adv label: 1, L2: 1277.48, Queries: 201
# Attacking sample 96/100 (True: 1, Index: 799)...
#   Failed! Adv label: 1, L2: 1049.55, Queries: 201
# Attacking sample 97/100 (True: 1, Index: 808)...
#   Failed! Adv label: 1, L2: 1281.09, Queries: 201
# Attacking sample 98/100 (True: 1, Index: 819)...
#   Failed! Adv label: 1, L2: 1165.23, Queries: 201
# Attacking sample 99/100 (True: 1, Index: 843)...
#   Failed! Adv label: 1, L2: 1205.72, Queries: 201
# Attacking sample 100/100 (True: 1, Index: 853)...
#   Failed! Adv label: 1, L2: 1063.36, Queries: 201
# Attacking sample 1/100 (True: 2, Index: 4)...
#   Failed! Adv label: 2, L2: 1217.76, Queries: 201
# Attacking sample 2/100 (True: 2, Index: 22)...
#   Failed! Adv label: 2, L2: 1218.44, Queries: 201
# Attacking sample 3/100 (True: 2, Index: 32)...
#   Failed! Adv label: 2, L2: 1264.24, Queries: 201
# Attacking sample 4/100 (True: 2, Index: 34)...
#   Success! Adv label: 4, L2: 188.83, Queries: 19
# Attacking sample 5/100 (True: 2, Index: 42)...
#   Failed! Adv label: 2, L2: 1180.85, Queries: 201
# Attacking sample 6/100 (True: 2, Index: 49)...
#   Failed! Adv label: 2, L2: 1202.61, Queries: 201
# Attacking sample 7/100 (True: 2, Index: 52)...
#   Failed! Adv label: 2, L2: 1277.00, Queries: 201
# Attacking sample 8/100 (True: 2, Index: 69)...
#   Failed! Adv label: 2, L2: 1305.33, Queries: 201
# Attacking sample 9/100 (True: 2, Index: 70)...
#   Failed! Adv label: 2, L2: 1161.30, Queries: 201
# Attacking sample 10/100 (True: 2, Index: 81)...
#   Failed! Adv label: 2, L2: 1146.62, Queries: 201
# Attacking sample 11/100 (True: 2, Index: 110)...
#   Failed! Adv label: 2, L2: 1232.14, Queries: 201
# Attacking sample 12/100 (True: 2, Index: 118)...
#   Failed! Adv label: 2, L2: 1241.28, Queries: 201
# Attacking sample 13/100 (True: 2, Index: 121)...
#   Failed! Adv label: 2, L2: 1235.74, Queries: 201
# Attacking sample 14/100 (True: 2, Index: 138)...
#   Failed! Adv label: 2, L2: 1169.44, Queries: 201
# Attacking sample 15/100 (True: 2, Index: 144)...
#   Failed! Adv label: 2, L2: 1301.00, Queries: 201
# Attacking sample 16/100 (True: 2, Index: 155)...
#   Failed! Adv label: 2, L2: 1130.76, Queries: 201
# Attacking sample 17/100 (True: 2, Index: 160)...
#   Failed! Adv label: 2, L2: 1223.85, Queries: 201
# Attacking sample 18/100 (True: 2, Index: 161)...
#   Failed! Adv label: 2, L2: 1103.31, Queries: 201
# Attacking sample 19/100 (True: 2, Index: 176)...
#   Failed! Adv label: 2, L2: 1271.75, Queries: 201
# Attacking sample 21/100 (True: 2, Index: 186)...
#   Failed! Adv label: 2, L2: 1183.05, Queries: 201
# Attacking sample 22/100 (True: 2, Index: 197)...
#   Failed! Adv label: 2, L2: 1250.16, Queries: 201
# Attacking sample 23/100 (True: 2, Index: 208)...
#   Failed! Adv label: 2, L2: 1291.74, Queries: 201
# Attacking sample 25/100 (True: 2, Index: 216)...
#   Failed! Adv label: 2, L2: 1374.78, Queries: 201
# Attacking sample 26/100 (True: 2, Index: 219)...
#   Failed! Adv label: 2, L2: 1188.33, Queries: 201
# Attacking sample 27/100 (True: 2, Index: 235)...
#   Failed! Adv label: 2, L2: 1244.50, Queries: 201
# Attacking sample 28/100 (True: 2, Index: 260)...
#   Failed! Adv label: 2, L2: 1255.31, Queries: 201
# Attacking sample 29/100 (True: 2, Index: 276)...
#   Failed! Adv label: 2, L2: 1328.33, Queries: 201
# Attacking sample 30/100 (True: 2, Index: 293)...
#   Failed! Adv label: 2, L2: 1241.34, Queries: 201
# Attacking sample 31/100 (True: 2, Index: 295)...
#   Failed! Adv label: 2, L2: 1127.53, Queries: 201
# Attacking sample 32/100 (True: 2, Index: 311)...
#   Failed! Adv label: 2, L2: 1205.72, Queries: 201
# Attacking sample 33/100 (True: 2, Index: 313)...
#   Success! Adv label: 5, L2: 796.83, Queries: 69
# Attacking sample 34/100 (True: 2, Index: 322)...
#   Failed! Adv label: 2, L2: 1331.24, Queries: 201
# Attacking sample 35/100 (True: 2, Index: 328)...
#   Failed! Adv label: 2, L2: 1130.90, Queries: 201
# Attacking sample 36/100 (True: 2, Index: 357)...
#   Failed! Adv label: 2, L2: 1257.30, Queries: 201
# Attacking sample 37/100 (True: 2, Index: 374)...
#   Failed! Adv label: 2, L2: 1312.24, Queries: 201
# Attacking sample 38/100 (True: 2, Index: 395)...
#   Failed! Adv label: 2, L2: 1385.99, Queries: 201
# Attacking sample 39/100 (True: 2, Index: 396)...
#   Failed! Adv label: 2, L2: 1293.43, Queries: 201
# Attacking sample 40/100 (True: 2, Index: 398)...
#   Failed! Adv label: 2, L2: 1225.33, Queries: 201
# Attacking sample 41/100 (True: 2, Index: 433)...
#   Failed! Adv label: 2, L2: 1324.34, Queries: 201
# Attacking sample 42/100 (True: 2, Index: 439)...
#   Failed! Adv label: 2, L2: 1187.55, Queries: 201
# Attacking sample 43/100 (True: 2, Index: 441)...
#   Failed! Adv label: 2, L2: 1278.32, Queries: 201
# Attacking sample 44/100 (True: 2, Index: 442)...
#   Failed! Adv label: 2, L2: 1166.88, Queries: 201
# Attacking sample 45/100 (True: 2, Index: 451)...
#   Failed! Adv label: 2, L2: 1359.31, Queries: 201
# Attacking sample 46/100 (True: 2, Index: 462)...
#   Failed! Adv label: 2, L2: 1351.87, Queries: 201
# Attacking sample 47/100 (True: 2, Index: 470)...
#   Failed! Adv label: 2, L2: 1327.11, Queries: 201
# Attacking sample 48/100 (True: 2, Index: 477)...
#   Failed! Adv label: 2, L2: 1133.37, Queries: 201
# Attacking sample 49/100 (True: 2, Index: 485)...
#   Failed! Adv label: 2, L2: 1351.48, Queries: 201
# Attacking sample 50/100 (True: 2, Index: 491)...
#   Failed! Adv label: 2, L2: 1262.32, Queries: 201
# Attacking sample 51/100 (True: 2, Index: 493)...
#   Failed! Adv label: 2, L2: 1426.10, Queries: 201
# Attacking sample 52/100 (True: 2, Index: 495)...
#   Failed! Adv label: 2, L2: 1336.09, Queries: 201
# Attacking sample 53/100 (True: 2, Index: 519)...
#   Failed! Adv label: 2, L2: 1289.81, Queries: 201
# Attacking sample 54/100 (True: 2, Index: 523)...
#   Failed! Adv label: 2, L2: 1321.04, Queries: 201
# Attacking sample 55/100 (True: 2, Index: 557)...
#   Failed! Adv label: 2, L2: 1264.38, Queries: 201
# Attacking sample 56/100 (True: 2, Index: 567)...
#   Failed! Adv label: 2, L2: 1264.60, Queries: 201
# Attacking sample 57/100 (True: 2, Index: 571)...
#   Failed! Adv label: 2, L2: 1273.13, Queries: 201
# Attacking sample 58/100 (True: 2, Index: 584)...
#   Failed! Adv label: 2, L2: 1182.10, Queries: 201
# Attacking sample 59/100 (True: 2, Index: 591)...
#   Failed! Adv label: 2, L2: 1218.88, Queries: 201
# Attacking sample 60/100 (True: 2, Index: 592)...
#   Failed! Adv label: 2, L2: 1227.32, Queries: 201
# Attacking sample 61/100 (True: 2, Index: 610)...
#   Failed! Adv label: 2, L2: 1190.64, Queries: 201
# Attacking sample 62/100 (True: 2, Index: 612)...
#   Failed! Adv label: 2, L2: 1304.94, Queries: 201
# Attacking sample 63/100 (True: 2, Index: 616)...
#   Failed! Adv label: 2, L2: 1137.94, Queries: 201
# Attacking sample 64/100 (True: 2, Index: 624)...
#   Failed! Adv label: 2, L2: 1262.03, Queries: 201
# Attacking sample 65/100 (True: 2, Index: 631)...
#   Failed! Adv label: 2, L2: 1189.12, Queries: 201
# Attacking sample 66/100 (True: 2, Index: 636)...
#   Failed! Adv label: 2, L2: 1202.11, Queries: 201
# Attacking sample 67/100 (True: 2, Index: 647)...
#   Success! Adv label: 1, L2: 943.65, Queries: 71
# Attacking sample 68/100 (True: 2, Index: 650)...
#   Success! Adv label: 3, L2: 1144.17, Queries: 93
# Attacking sample 69/100 (True: 2, Index: 664)...
#   Failed! Adv label: 2, L2: 1304.69, Queries: 201
# Attacking sample 70/100 (True: 2, Index: 704)...
#   Failed! Adv label: 2, L2: 1151.71, Queries: 201
# Attacking sample 71/100 (True: 2, Index: 720)...
#   Failed! Adv label: 2, L2: 1248.46, Queries: 201
# Attacking sample 72/100 (True: 2, Index: 725)...
#   Failed! Adv label: 2, L2: 1145.35, Queries: 201
# Attacking sample 73/100 (True: 2, Index: 750)...
#   Failed! Adv label: 2, L2: 1249.12, Queries: 201
# Attacking sample 74/100 (True: 2, Index: 764)...
#   Failed! Adv label: 2, L2: 1248.88, Queries: 201
# Attacking sample 75/100 (True: 2, Index: 780)...
#   Failed! Adv label: 2, L2: 1095.24, Queries: 201
# Attacking sample 76/100 (True: 2, Index: 784)...
#   Failed! Adv label: 2, L2: 1319.82, Queries: 201
# Attacking sample 77/100 (True: 2, Index: 788)...
#   Failed! Adv label: 2, L2: 1213.20, Queries: 201
# Attacking sample 78/100 (True: 2, Index: 790)...
#   Failed! Adv label: 2, L2: 1204.58, Queries: 201
# Attacking sample 79/100 (True: 2, Index: 797)...
#   Failed! Adv label: 2, L2: 1239.74, Queries: 201
# Attacking sample 80/100 (True: 2, Index: 803)...
#   Failed! Adv label: 2, L2: 1286.02, Queries: 201
# Attacking sample 81/100 (True: 2, Index: 807)...
#   Failed! Adv label: 2, L2: 1107.19, Queries: 201
# Attacking sample 82/100 (True: 2, Index: 828)...
#   Failed! Adv label: 2, L2: 1205.06, Queries: 201
# Attacking sample 83/100 (True: 2, Index: 842)...
#   Failed! Adv label: 2, L2: 1152.82, Queries: 201
# Attacking sample 84/100 (True: 2, Index: 845)...
#   Failed! Adv label: 2, L2: 1188.93, Queries: 201
# Attacking sample 85/100 (True: 2, Index: 859)...
#   Failed! Adv label: 2, L2: 1161.99, Queries: 201
# Attacking sample 86/100 (True: 2, Index: 871)...
#   Failed! Adv label: 2, L2: 1202.34, Queries: 201
# Attacking sample 87/100 (True: 2, Index: 881)...
#   Failed! Adv label: 2, L2: 1303.60, Queries: 201
# Attacking sample 88/100 (True: 2, Index: 883)...
#   Failed! Adv label: 2, L2: 1274.76, Queries: 201
# Attacking sample 89/100 (True: 2, Index: 896)...
#   Failed! Adv label: 2, L2: 1155.74, Queries: 201
# Attacking sample 90/100 (True: 2, Index: 897)...
#   Failed! Adv label: 2, L2: 1180.71, Queries: 201
# Attacking sample 92/100 (True: 2, Index: 922)...
#   Failed! Adv label: 2, L2: 1220.34, Queries: 201
# Attacking sample 93/100 (True: 2, Index: 932)...
#   Failed! Adv label: 2, L2: 1256.90, Queries: 201
# Attacking sample 94/100 (True: 2, Index: 944)...
#   Failed! Adv label: 2, L2: 1410.00, Queries: 201
# Attacking sample 95/100 (True: 2, Index: 949)...
#   Failed! Adv label: 2, L2: 1087.39, Queries: 201
# Attacking sample 96/100 (True: 2, Index: 952)...
#   Failed! Adv label: 2, L2: 1192.57, Queries: 201
# Attacking sample 97/100 (True: 2, Index: 959)...
#   Failed! Adv label: 2, L2: 1126.44, Queries: 201
# Attacking sample 98/100 (True: 2, Index: 966)...
#   Success! Adv label: 7, L2: 1276.44, Queries: 101
# Attacking sample 99/100 (True: 2, Index: 967)...
#   Failed! Adv label: 2, L2: 1374.71, Queries: 201
# Attacking sample 100/100 (True: 2, Index: 985)...
#   Failed! Adv label: 2, L2: 1256.43, Queries: 201
# Attacking sample 1/100 (True: 3, Index: 1)...
#   Failed! Adv label: 3, L2: 1213.91, Queries: 201
# Attacking sample 2/100 (True: 3, Index: 12)...
#   Failed! Adv label: 3, L2: 1357.42, Queries: 201
# Attacking sample 3/100 (True: 3, Index: 20)...
#   Failed! Adv label: 3, L2: 1290.67, Queries: 201
# Attacking sample 4/100 (True: 3, Index: 27)...
#   Failed! Adv label: 3, L2: 1479.35, Queries: 201
# Attacking sample 5/100 (True: 3, Index: 37)...
#   Failed! Adv label: 3, L2: 1308.20, Queries: 201
# Attacking sample 6/100 (True: 3, Index: 43)...
#   Failed! Adv label: 3, L2: 1227.36, Queries: 201
# Attacking sample 7/100 (True: 3, Index: 53)...
#   Failed! Adv label: 3, L2: 1297.85, Queries: 201
# Attacking sample 8/100 (True: 3, Index: 61)...
#   Failed! Adv label: 3, L2: 1314.00, Queries: 201
# Attacking sample 9/100 (True: 3, Index: 73)...
#   Failed! Adv label: 3, L2: 1326.63, Queries: 201
# Attacking sample 10/100 (True: 3, Index: 102)...
#   Failed! Adv label: 3, L2: 1101.06, Queries: 201
# Attacking sample 11/100 (True: 3, Index: 108)...
#   Success! Adv label: 2, L2: 878.59, Queries: 73
# Attacking sample 12/100 (True: 3, Index: 109)...
#   Failed! Adv label: 3, L2: 1121.19, Queries: 201
# Attacking sample 13/100 (True: 3, Index: 117)...
#   Failed! Adv label: 3, L2: 1367.76, Queries: 201
# Attacking sample 14/100 (True: 3, Index: 131)...
#   Success! Adv label: 8, L2: 1010.10, Queries: 85
# Attacking sample 15/100 (True: 3, Index: 159)...
#   Failed! Adv label: 3, L2: 1313.66, Queries: 201
# Attacking sample 16/100 (True: 3, Index: 162)...
#   Failed! Adv label: 3, L2: 1162.24, Queries: 201
# Attacking sample 17/100 (True: 3, Index: 166)...
#   Failed! Adv label: 3, L2: 1269.37, Queries: 201
# Attacking sample 18/100 (True: 3, Index: 177)...
#   Failed! Adv label: 3, L2: 1311.72, Queries: 201
# Attacking sample 19/100 (True: 3, Index: 181)...
#   Failed! Adv label: 3, L2: 1387.69, Queries: 201
# Attacking sample 20/100 (True: 3, Index: 187)...
#   Failed! Adv label: 3, L2: 1188.43, Queries: 201
# Attacking sample 21/100 (True: 3, Index: 196)...
#   Failed! Adv label: 3, L2: 1137.02, Queries: 201
# Attacking sample 22/100 (True: 3, Index: 204)...
#   Failed! Adv label: 3, L2: 1208.48, Queries: 201
# Attacking sample 23/100 (True: 3, Index: 227)...
#   Failed! Adv label: 3, L2: 1276.55, Queries: 201
# Attacking sample 24/100 (True: 3, Index: 231)...
#   Failed! Adv label: 3, L2: 1269.50, Queries: 201
# Attacking sample 25/100 (True: 3, Index: 237)...
#   Failed! Adv label: 3, L2: 1212.99, Queries: 201
# Attacking sample 26/100 (True: 3, Index: 244)...
#   Failed! Adv label: 3, L2: 1424.08, Queries: 201
# Attacking sample 27/100 (True: 3, Index: 257)...
#   Failed! Adv label: 3, L2: 1272.67, Queries: 201
# Attacking sample 28/100 (True: 3, Index: 259)...
#   Failed! Adv label: 3, L2: 1380.90, Queries: 201
# Attacking sample 29/100 (True: 3, Index: 265)...
#   Failed! Adv label: 3, L2: 1176.50, Queries: 201
# Attacking sample 30/100 (True: 3, Index: 270)...
#   Failed! Adv label: 3, L2: 1202.33, Queries: 201
# Attacking sample 31/100 (True: 3, Index: 288)...
#   Failed! Adv label: 3, L2: 1293.84, Queries: 201
# Attacking sample 32/100 (True: 3, Index: 308)...
#   Failed! Adv label: 3, L2: 983.94, Queries: 201
# Attacking sample 33/100 (True: 3, Index: 309)...
#   Failed! Adv label: 3, L2: 1320.77, Queries: 201
# Attacking sample 34/100 (True: 3, Index: 327)...
#   Failed! Adv label: 3, L2: 1181.19, Queries: 201
# Attacking sample 35/100 (True: 3, Index: 331)...
#   Failed! Adv label: 3, L2: 1480.25, Queries: 201
# Attacking sample 36/100 (True: 3, Index: 340)...
#   Failed! Adv label: 3, L2: 1413.51, Queries: 201
# Attacking sample 37/100 (True: 3, Index: 341)...
#   Failed! Adv label: 3, L2: 1314.82, Queries: 201
# Attacking sample 38/100 (True: 3, Index: 342)...
#   Failed! Adv label: 3, L2: 1210.33, Queries: 201
# Attacking sample 39/100 (True: 3, Index: 362)...
#   Failed! Adv label: 3, L2: 1302.12, Queries: 201
# Attacking sample 40/100 (True: 3, Index: 383)...
#   Failed! Adv label: 3, L2: 1243.56, Queries: 201
# Attacking sample 41/100 (True: 3, Index: 394)...
#   Failed! Adv label: 3, L2: 1198.03, Queries: 201
# Attacking sample 42/100 (True: 3, Index: 406)...
#   Failed! Adv label: 3, L2: 1196.83, Queries: 201
# Attacking sample 43/100 (True: 3, Index: 409)...
#   Failed! Adv label: 3, L2: 1162.95, Queries: 201
# Attacking sample 44/100 (True: 3, Index: 445)...
#   Failed! Adv label: 3, L2: 1305.00, Queries: 201
# Attacking sample 45/100 (True: 3, Index: 456)...
#   Failed! Adv label: 3, L2: 1327.58, Queries: 201
# Attacking sample 46/100 (True: 3, Index: 459)...
#   Failed! Adv label: 3, L2: 1347.62, Queries: 201
# Attacking sample 47/100 (True: 3, Index: 461)...
#   Failed! Adv label: 3, L2: 1288.03, Queries: 201
# Attacking sample 48/100 (True: 3, Index: 471)...
#   Failed! Adv label: 3, L2: 1281.79, Queries: 201
# Attacking sample 49/100 (True: 3, Index: 474)...
#   Failed! Adv label: 3, L2: 1295.58, Queries: 201
# Attacking sample 50/100 (True: 3, Index: 481)...
#   Failed! Adv label: 3, L2: 1248.74, Queries: 201
# Attacking sample 51/100 (True: 3, Index: 504)...
#   Failed! Adv label: 3, L2: 1317.13, Queries: 201
# Attacking sample 52/100 (True: 3, Index: 510)...
#   Failed! Adv label: 3, L2: 1275.61, Queries: 201
# Attacking sample 53/100 (True: 3, Index: 512)...
#   Failed! Adv label: 3, L2: 1365.67, Queries: 201
# Attacking sample 54/100 (True: 3, Index: 524)...
#   Failed! Adv label: 3, L2: 1391.24, Queries: 201
# Attacking sample 55/100 (True: 3, Index: 549)...
#   Failed! Adv label: 3, L2: 1361.15, Queries: 201
# Attacking sample 56/100 (True: 3, Index: 556)...
#   Failed! Adv label: 3, L2: 1318.01, Queries: 201
# Attacking sample 57/100 (True: 3, Index: 564)...
#   Failed! Adv label: 3, L2: 1286.37, Queries: 201
# Attacking sample 58/100 (True: 3, Index: 586)...
#   Failed! Adv label: 3, L2: 1258.69, Queries: 201
# Attacking sample 59/100 (True: 3, Index: 589)...
#   Failed! Adv label: 3, L2: 1422.86, Queries: 201
# Attacking sample 60/100 (True: 3, Index: 609)...
#   Failed! Adv label: 3, L2: 1336.65, Queries: 201
# Attacking sample 61/100 (True: 3, Index: 613)...
#   Failed! Adv label: 3, L2: 1316.01, Queries: 201
# Attacking sample 62/100 (True: 3, Index: 623)...
#   Failed! Adv label: 3, L2: 1350.15, Queries: 201
# Attacking sample 63/100 (True: 3, Index: 639)...
#   Failed! Adv label: 3, L2: 1317.71, Queries: 201
# Attacking sample 64/100 (True: 3, Index: 648)...
#   Failed! Adv label: 3, L2: 1219.65, Queries: 201
# Attacking sample 65/100 (True: 3, Index: 651)...
#   Failed! Adv label: 3, L2: 1319.67, Queries: 201
# Attacking sample 66/100 (True: 3, Index: 659)...
#   Failed! Adv label: 3, L2: 1482.92, Queries: 201
# Attacking sample 67/100 (True: 3, Index: 661)...
#   Failed! Adv label: 3, L2: 1281.81, Queries: 201
# Attacking sample 68/100 (True: 3, Index: 667)...
#   Failed! Adv label: 3, L2: 1241.41, Queries: 201
# Attacking sample 69/100 (True: 3, Index: 678)...
#   Failed! Adv label: 3, L2: 1404.56, Queries: 201
# Attacking sample 70/100 (True: 3, Index: 690)...
#   Failed! Adv label: 3, L2: 1278.19, Queries: 201
# Attacking sample 71/100 (True: 3, Index: 693)...
#   Failed! Adv label: 3, L2: 1305.73, Queries: 201
# Attacking sample 72/100 (True: 3, Index: 694)...
#   Failed! Adv label: 3, L2: 1488.61, Queries: 201
# Attacking sample 73/100 (True: 3, Index: 695)...
#   Failed! Adv label: 3, L2: 1247.87, Queries: 201
# Attacking sample 74/100 (True: 3, Index: 702)...
#   Failed! Adv label: 3, L2: 1289.19, Queries: 201
# Attacking sample 75/100 (True: 3, Index: 718)...
#   Failed! Adv label: 3, L2: 1240.06, Queries: 201
# Attacking sample 76/100 (True: 3, Index: 749)...
#   Failed! Adv label: 3, L2: 1381.99, Queries: 201
# Attacking sample 77/100 (True: 3, Index: 769)...
#   Failed! Adv label: 3, L2: 1284.85, Queries: 201
# Attacking sample 79/100 (True: 3, Index: 779)...
#   Failed! Adv label: 3, L2: 1139.21, Queries: 201
# Attacking sample 80/100 (True: 3, Index: 800)...
#   Failed! Adv label: 3, L2: 1252.89, Queries: 201
# Attacking sample 81/100 (True: 3, Index: 816)...
#   Failed! Adv label: 3, L2: 1273.00, Queries: 201
# Attacking sample 82/100 (True: 3, Index: 829)...
#   Failed! Adv label: 3, L2: 1181.15, Queries: 201
# Attacking sample 83/100 (True: 3, Index: 833)...
#   Failed! Adv label: 3, L2: 1407.68, Queries: 201
# Attacking sample 84/100 (True: 3, Index: 839)...
#   Failed! Adv label: 3, L2: 1223.02, Queries: 201
# Attacking sample 85/100 (True: 3, Index: 854)...
#   Failed! Adv label: 3, L2: 1235.87, Queries: 201
# Attacking sample 86/100 (True: 3, Index: 856)...
#   Failed! Adv label: 3, L2: 1281.04, Queries: 201
# Attacking sample 87/100 (True: 3, Index: 858)...
#   Success! Adv label: 5, L2: 413.18, Queries: 33
# Attacking sample 89/100 (True: 3, Index: 886)...
#   Failed! Adv label: 3, L2: 1292.49, Queries: 201
# Attacking sample 90/100 (True: 3, Index: 900)...
#   Failed! Adv label: 3, L2: 1136.65, Queries: 201
# Attacking sample 91/100 (True: 3, Index: 916)...
#   Failed! Adv label: 3, L2: 1257.62, Queries: 201
# Attacking sample 92/100 (True: 3, Index: 921)...
#   Failed! Adv label: 3, L2: 1290.04, Queries: 201
# Attacking sample 93/100 (True: 3, Index: 937)...
#   Failed! Adv label: 3, L2: 1322.87, Queries: 201
# Attacking sample 94/100 (True: 3, Index: 938)...
#   Failed! Adv label: 3, L2: 1308.46, Queries: 201
# Attacking sample 95/100 (True: 3, Index: 939)...
#   Failed! Adv label: 3, L2: 1099.45, Queries: 201
# Attacking sample 96/100 (True: 3, Index: 942)...
#   Failed! Adv label: 3, L2: 1293.57, Queries: 201
# Attacking sample 97/100 (True: 3, Index: 951)...
#   Failed! Adv label: 3, L2: 1256.30, Queries: 201
# Attacking sample 98/100 (True: 3, Index: 953)...
#   Failed! Adv label: 3, L2: 1485.73, Queries: 201
# Attacking sample 99/100 (True: 3, Index: 975)...
#   Failed! Adv label: 3, L2: 1392.83, Queries: 201
# Attacking sample 1/100 (True: 4, Index: 16)...
#   Failed! Adv label: 4, L2: 1350.29, Queries: 201
# Attacking sample 2/100 (True: 4, Index: 17)...
#   Failed! Adv label: 4, L2: 1338.10, Queries: 201
# Attacking sample 3/100 (True: 4, Index: 30)...
#   Failed! Adv label: 4, L2: 1379.04, Queries: 201
# Attacking sample 4/100 (True: 4, Index: 33)...
#   Failed! Adv label: 4, L2: 1412.09, Queries: 201
# Attacking sample 5/100 (True: 4, Index: 45)...
#   Failed! Adv label: 4, L2: 1365.46, Queries: 201
# Attacking sample 6/100 (True: 4, Index: 48)...
#   Failed! Adv label: 4, L2: 1397.18, Queries: 201
# Attacking sample 7/100 (True: 4, Index: 58)...
#   Failed! Adv label: 4, L2: 1374.95, Queries: 201
# Attacking sample 8/100 (True: 4, Index: 66)...
#   Failed! Adv label: 4, L2: 1422.59, Queries: 201
# Attacking sample 9/100 (True: 4, Index: 89)...
#   Failed! Adv label: 4, L2: 1412.29, Queries: 201
# Attacking sample 10/100 (True: 4, Index: 92)...
#   Failed! Adv label: 4, L2: 1178.26, Queries: 201
# Attacking sample 11/100 (True: 4, Index: 113)...
#   Failed! Adv label: 4, L2: 1376.60, Queries: 201
# Attacking sample 12/100 (True: 4, Index: 116)...
#   Failed! Adv label: 4, L2: 1461.15, Queries: 201
# Attacking sample 13/100 (True: 4, Index: 126)...
#   Failed! Adv label: 4, L2: 1359.23, Queries: 201
# Attacking sample 14/100 (True: 4, Index: 130)...
#   Failed! Adv label: 4, L2: 1440.46, Queries: 201
# Attacking sample 15/100 (True: 4, Index: 139)...
#   Failed! Adv label: 4, L2: 1435.28, Queries: 201
# Attacking sample 16/100 (True: 4, Index: 149)...
#   Failed! Adv label: 4, L2: 1376.41, Queries: 201
# Attacking sample 17/100 (True: 4, Index: 153)...
#   Failed! Adv label: 4, L2: 1389.71, Queries: 201
# Attacking sample 18/100 (True: 4, Index: 154)...
#   Failed! Adv label: 4, L2: 1419.99, Queries: 201
# Attacking sample 19/100 (True: 4, Index: 163)...
#   Failed! Adv label: 4, L2: 1435.27, Queries: 201
# Attacking sample 20/100 (True: 4, Index: 167)...
#   Failed! Adv label: 4, L2: 1335.04, Queries: 201
# Attacking sample 21/100 (True: 4, Index: 183)...
#   Failed! Adv label: 4, L2: 1435.46, Queries: 201
# Attacking sample 22/100 (True: 4, Index: 184)...
#   Failed! Adv label: 4, L2: 1376.58, Queries: 201
# Attacking sample 23/100 (True: 4, Index: 192)...
#   Failed! Adv label: 4, L2: 1446.77, Queries: 201
# Attacking sample 24/100 (True: 4, Index: 194)...
#   Failed! Adv label: 4, L2: 1390.76, Queries: 201
# Attacking sample 25/100 (True: 4, Index: 233)...
#   Failed! Adv label: 4, L2: 1359.68, Queries: 201
# Attacking sample 26/100 (True: 4, Index: 240)...
#   Failed! Adv label: 4, L2: 1369.44, Queries: 201
# Attacking sample 27/100 (True: 4, Index: 263)...
#   Failed! Adv label: 4, L2: 1258.29, Queries: 201
# Attacking sample 28/100 (True: 4, Index: 269)...
#   Failed! Adv label: 4, L2: 1355.59, Queries: 201
# Attacking sample 29/100 (True: 4, Index: 280)...
#   Failed! Adv label: 4, L2: 1415.45, Queries: 201
# Attacking sample 30/100 (True: 4, Index: 290)...
#   Failed! Adv label: 4, L2: 1437.56, Queries: 201
# Attacking sample 31/100 (True: 4, Index: 297)...
#   Failed! Adv label: 4, L2: 1231.13, Queries: 201
# Attacking sample 32/100 (True: 4, Index: 299)...
#   Failed! Adv label: 4, L2: 1456.41, Queries: 201
# Attacking sample 33/100 (True: 4, Index: 310)...
#   Failed! Adv label: 4, L2: 1474.58, Queries: 201
# Attacking sample 34/100 (True: 4, Index: 316)...
#   Failed! Adv label: 4, L2: 1412.94, Queries: 201
# Attacking sample 35/100 (True: 4, Index: 320)...
#   Failed! Adv label: 4, L2: 1392.71, Queries: 201
# Attacking sample 36/100 (True: 4, Index: 324)...
#   Failed! Adv label: 4, L2: 1385.97, Queries: 201
# Attacking sample 37/100 (True: 4, Index: 326)...
#   Failed! Adv label: 4, L2: 1393.54, Queries: 201
# Attacking sample 38/100 (True: 4, Index: 332)...
#   Success! Adv label: 9, L2: 111.47, Queries: 9
# Attacking sample 39/100 (True: 4, Index: 335)...
#   Failed! Adv label: 4, L2: 1396.78, Queries: 201
# Attacking sample 40/100 (True: 4, Index: 344)...
#   Failed! Adv label: 4, L2: 1434.63, Queries: 201
# Attacking sample 42/100 (True: 4, Index: 359)...
#   Failed! Adv label: 4, L2: 1449.18, Queries: 201
# Attacking sample 43/100 (True: 4, Index: 376)...
#   Failed! Adv label: 4, L2: 1397.69, Queries: 201
# Attacking sample 44/100 (True: 4, Index: 393)...
#   Failed! Adv label: 4, L2: 1371.02, Queries: 201
# Attacking sample 45/100 (True: 4, Index: 401)...
#   Failed! Adv label: 4, L2: 1337.19, Queries: 201
# Attacking sample 46/100 (True: 4, Index: 402)...
#   Failed! Adv label: 4, L2: 1398.46, Queries: 201
# Attacking sample 47/100 (True: 4, Index: 422)...
#   Failed! Adv label: 4, L2: 1473.62, Queries: 201
# Attacking sample 48/100 (True: 4, Index: 423)...
#   Failed! Adv label: 4, L2: 1353.47, Queries: 201
# Attacking sample 49/100 (True: 4, Index: 427)...
#   Failed! Adv label: 4, L2: 1287.51, Queries: 201
# Attacking sample 50/100 (True: 4, Index: 432)...
#   Failed! Adv label: 4, L2: 1356.87, Queries: 201
# Attacking sample 51/100 (True: 4, Index: 434)...
#   Failed! Adv label: 4, L2: 1452.93, Queries: 201
# Attacking sample 52/100 (True: 4, Index: 454)...
#   Failed! Adv label: 4, L2: 1375.43, Queries: 201
# Attacking sample 53/100 (True: 4, Index: 467)...
#   Failed! Adv label: 4, L2: 1452.77, Queries: 201
# Attacking sample 54/100 (True: 4, Index: 501)...
#   Failed! Adv label: 4, L2: 1285.01, Queries: 201
# Attacking sample 55/100 (True: 4, Index: 515)...
#   Failed! Adv label: 4, L2: 1347.07, Queries: 201
# Attacking sample 56/100 (True: 4, Index: 540)...
#   Failed! Adv label: 4, L2: 1323.27, Queries: 201
# Attacking sample 57/100 (True: 4, Index: 544)...
#   Failed! Adv label: 4, L2: 1356.35, Queries: 201
# Attacking sample 58/100 (True: 4, Index: 545)...
#   Failed! Adv label: 4, L2: 1355.63, Queries: 201
# Attacking sample 59/100 (True: 4, Index: 547)...
#   Failed! Adv label: 4, L2: 1365.41, Queries: 201
# Attacking sample 60/100 (True: 4, Index: 566)...
#   Failed! Adv label: 4, L2: 1411.10, Queries: 201
# Attacking sample 61/100 (True: 4, Index: 590)...
#   Failed! Adv label: 4, L2: 1345.50, Queries: 201
# Attacking sample 62/100 (True: 4, Index: 593)...
#   Failed! Adv label: 4, L2: 1445.05, Queries: 201
# Attacking sample 63/100 (True: 4, Index: 599)...
#   Failed! Adv label: 4, L2: 1408.91, Queries: 201
# Attacking sample 64/100 (True: 4, Index: 602)...
#   Failed! Adv label: 4, L2: 1462.08, Queries: 201
# Attacking sample 65/100 (True: 4, Index: 607)...
#   Failed! Adv label: 4, L2: 1413.51, Queries: 201
# Attacking sample 66/100 (True: 4, Index: 611)...
#   Failed! Adv label: 4, L2: 1421.20, Queries: 201
# Attacking sample 67/100 (True: 4, Index: 617)...
#   Failed! Adv label: 4, L2: 1396.90, Queries: 201
# Attacking sample 68/100 (True: 4, Index: 657)...
#   Failed! Adv label: 4, L2: 1380.33, Queries: 201
# Attacking sample 69/100 (True: 4, Index: 680)...
#   Failed! Adv label: 4, L2: 1451.10, Queries: 201
# Attacking sample 70/100 (True: 4, Index: 684)...
#   Failed! Adv label: 4, L2: 1359.32, Queries: 201
# Attacking sample 71/100 (True: 4, Index: 687)...
#   Failed! Adv label: 4, L2: 1402.55, Queries: 201
# Attacking sample 72/100 (True: 4, Index: 692)...
#   Failed! Adv label: 4, L2: 1310.22, Queries: 201
# Attacking sample 73/100 (True: 4, Index: 696)...
#   Success! Adv label: 9, L2: 1161.04, Queries: 85
# Attacking sample 74/100 (True: 4, Index: 697)...
#   Failed! Adv label: 4, L2: 1347.46, Queries: 201
# Attacking sample 75/100 (True: 4, Index: 708)...
#   Failed! Adv label: 4, L2: 1380.44, Queries: 201
# Attacking sample 76/100 (True: 4, Index: 717)...
#   Failed! Adv label: 4, L2: 1330.40, Queries: 201
# Attacking sample 77/100 (True: 4, Index: 746)...
#   Failed! Adv label: 4, L2: 1390.54, Queries: 201
# Attacking sample 78/100 (True: 4, Index: 752)...
#   Failed! Adv label: 4, L2: 1471.05, Queries: 201
# Attacking sample 79/100 (True: 4, Index: 755)...
#   Failed! Adv label: 4, L2: 1462.66, Queries: 201
# Attacking sample 80/100 (True: 4, Index: 757)...
#   Failed! Adv label: 4, L2: 1456.86, Queries: 201
# Attacking sample 81/100 (True: 4, Index: 766)...
#   Failed! Adv label: 4, L2: 1460.93, Queries: 201
# Attacking sample 82/100 (True: 4, Index: 771)...
#   Failed! Adv label: 4, L2: 1430.82, Queries: 201
# Attacking sample 83/100 (True: 4, Index: 776)...
#   Failed! Adv label: 4, L2: 1359.71, Queries: 201
# Attacking sample 84/100 (True: 4, Index: 777)...
#   Failed! Adv label: 4, L2: 1481.64, Queries: 201
# Attacking sample 85/100 (True: 4, Index: 786)...
#   Failed! Adv label: 4, L2: 1466.85, Queries: 201
# Attacking sample 86/100 (True: 4, Index: 811)...
#   Failed! Adv label: 4, L2: 1366.91, Queries: 201
# Attacking sample 87/100 (True: 4, Index: 815)...
#   Failed! Adv label: 4, L2: 1267.17, Queries: 201
# Attacking sample 88/100 (True: 4, Index: 817)...
#   Failed! Adv label: 4, L2: 1479.78, Queries: 201
# Attacking sample 89/100 (True: 4, Index: 840)...
#   Failed! Adv label: 4, L2: 1100.95, Queries: 201
# Attacking sample 91/100 (True: 4, Index: 849)...
#   Failed! Adv label: 4, L2: 1306.26, Queries: 201
# Attacking sample 92/100 (True: 4, Index: 857)...
#   Failed! Adv label: 4, L2: 1416.73, Queries: 201
# Attacking sample 93/100 (True: 4, Index: 872)...
# ...
# Attacking sample 41/100 (True: 8, Index: 509)...
#   Failed! Adv label: 8, L2: 1337.80, Queries: 201
# Attacking sample 42/100 (True: 8, Index: 525)...
#   Failed! Adv label: 8, L2: 1441.86, Queries: 201
# Attacking sample 43/100 (True: 8, Index: 528)...
#   Failed! Adv label: 8, L2: 1397.13, Queries: 201
# Attacking sample 44/100 (True: 8, Index: 541)...
#   Failed! Adv label: 8, L2: 1288.68, Queries: 201
# Attacking sample 45/100 (True: 8, Index: 543)...
#   Failed! Adv label: 8, L2: 1200.03, Queries: 201
# Attacking sample 46/100 (True: 8, Index: 550)...
#   Failed! Adv label: 8, L2: 1414.11, Queries: 201
# Attacking sample 47/100 (True: 8, Index: 558)...
#   Failed! Adv label: 8, L2: 1182.71, Queries: 201
# Attacking sample 48/100 (True: 8, Index: 575)...
#   Failed! Adv label: 8, L2: 1423.37, Queries: 201
# Attacking sample 49/100 (True: 8, Index: 594)...
#   Failed! Adv label: 8, L2: 1245.12, Queries: 201
# Attacking sample 50/100 (True: 8, Index: 600)...
#   Failed! Adv label: 8, L2: 1423.95, Queries: 201
# Attacking sample 51/100 (True: 8, Index: 605)...
#   Failed! Adv label: 8, L2: 1238.73, Queries: 201
# Attacking sample 52/100 (True: 8, Index: 619)...
#   Failed! Adv label: 8, L2: 1380.87, Queries: 201
# Attacking sample 53/100 (True: 8, Index: 625)...
#   Failed! Adv label: 8, L2: 1381.13, Queries: 201
# Attacking sample 54/100 (True: 8, Index: 629)...
#   Failed! Adv label: 8, L2: 1239.47, Queries: 201
# Attacking sample 55/100 (True: 8, Index: 645)...
#   Failed! Adv label: 8, L2: 1473.29, Queries: 201
# Attacking sample 56/100 (True: 8, Index: 652)...
#   Failed! Adv label: 8, L2: 1156.04, Queries: 201
# Attacking sample 57/100 (True: 8, Index: 672)...
#   Failed! Adv label: 8, L2: 1480.45, Queries: 201
# Attacking sample 58/100 (True: 8, Index: 683)...
#   Failed! Adv label: 8, L2: 1375.11, Queries: 201
# Attacking sample 59/100 (True: 8, Index: 701)...
#   Failed! Adv label: 8, L2: 1396.84, Queries: 201
# Attacking sample 60/100 (True: 8, Index: 714)...
#   Failed! Adv label: 8, L2: 1520.76, Queries: 201
# Attacking sample 61/100 (True: 8, Index: 721)...
#   Failed! Adv label: 8, L2: 1397.44, Queries: 201
# Attacking sample 62/100 (True: 8, Index: 730)...
#   Failed! Adv label: 8, L2: 1214.50, Queries: 201
# Attacking sample 63/100 (True: 8, Index: 731)...
#   Failed! Adv label: 8, L2: 1511.27, Queries: 201
# Attacking sample 64/100 (True: 8, Index: 738)...
#   Failed! Adv label: 8, L2: 1440.61, Queries: 201
# Attacking sample 65/100 (True: 8, Index: 791)...
#   Failed! Adv label: 8, L2: 1496.94, Queries: 201
# Attacking sample 66/100 (True: 8, Index: 832)...
#   Failed! Adv label: 8, L2: 1155.97, Queries: 201
# Attacking sample 67/100 (True: 8, Index: 838)...
#   Failed! Adv label: 8, L2: 1350.04, Queries: 201
# Attacking sample 68/100 (True: 8, Index: 860)...
#   Failed! Adv label: 8, L2: 1347.80, Queries: 201
# Attacking sample 69/100 (True: 8, Index: 864)...
#   Failed! Adv label: 8, L2: 1402.60, Queries: 201
# Attacking sample 70/100 (True: 8, Index: 889)...
#   Failed! Adv label: 8, L2: 1465.07, Queries: 201
# Attacking sample 71/100 (True: 8, Index: 905)...
#   Failed! Adv label: 8, L2: 1520.31, Queries: 201
# Attacking sample 73/100 (True: 8, Index: 919)...
#   Failed! Adv label: 8, L2: 1368.90, Queries: 201
# Attacking sample 74/100 (True: 8, Index: 923)...
#   Failed! Adv label: 8, L2: 1435.00, Queries: 201
# Attacking sample 75/100 (True: 8, Index: 926)...
#   Failed! Adv label: 8, L2: 1317.19, Queries: 201
# Attacking sample 76/100 (True: 8, Index: 933)...
#   Failed! Adv label: 8, L2: 1371.17, Queries: 201
# Attacking sample 78/100 (True: 8, Index: 971)...
#   Failed! Adv label: 8, L2: 1154.97, Queries: 201
# Attacking sample 79/100 (True: 8, Index: 1014)...
#   Failed! Adv label: 8, L2: 1346.08, Queries: 201
# Attacking sample 80/100 (True: 8, Index: 1034)...
#   Failed! Adv label: 8, L2: 1439.04, Queries: 201
# Attacking sample 81/100 (True: 8, Index: 1053)...
#   Failed! Adv label: 8, L2: 1315.06, Queries: 201
# Attacking sample 82/100 (True: 8, Index: 1057)...
#   Failed! Adv label: 8, L2: 1272.41, Queries: 201
# Attacking sample 83/100 (True: 8, Index: 1061)...
#   Failed! Adv label: 8, L2: 1169.99, Queries: 201
# Attacking sample 84/100 (True: 8, Index: 1062)...
#   Failed! Adv label: 8, L2: 1268.83, Queries: 201
# Attacking sample 85/100 (True: 8, Index: 1063)...
#   Failed! Adv label: 8, L2: 1379.41, Queries: 201
# Attacking sample 86/100 (True: 8, Index: 1078)...
#   Failed! Adv label: 8, L2: 1417.07, Queries: 201
# Attacking sample 87/100 (True: 8, Index: 1088)...
#   Failed! Adv label: 8, L2: 1212.73, Queries: 201
# Attacking sample 88/100 (True: 8, Index: 1100)...
#   Failed! Adv label: 8, L2: 1452.27, Queries: 201
# Attacking sample 89/100 (True: 8, Index: 1106)...
#   Failed! Adv label: 8, L2: 1358.84, Queries: 201
# Attacking sample 90/100 (True: 8, Index: 1120)...
#   Failed! Adv label: 8, L2: 1453.00, Queries: 201
# Attacking sample 91/100 (True: 8, Index: 1132)...
#   Failed! Adv label: 8, L2: 1199.57, Queries: 201
# Attacking sample 92/100 (True: 8, Index: 1134)...
#   Failed! Adv label: 8, L2: 1319.83, Queries: 201
# Attacking sample 93/100 (True: 8, Index: 1140)...
#   Failed! Adv label: 8, L2: 1353.09, Queries: 201
# Attacking sample 94/100 (True: 8, Index: 1150)...
#   Failed! Adv label: 8, L2: 1516.93, Queries: 201
# Attacking sample 95/100 (True: 8, Index: 1165)...
#   Failed! Adv label: 8, L2: 1223.68, Queries: 201
# Attacking sample 96/100 (True: 8, Index: 1179)...
#   Failed! Adv label: 8, L2: 1337.71, Queries: 201
# Attacking sample 97/100 (True: 8, Index: 1182)...
#   Failed! Adv label: 8, L2: 1515.47, Queries: 201
# Attacking sample 98/100 (True: 8, Index: 1186)...
#   Failed! Adv label: 8, L2: 1211.75, Queries: 201
# Attacking sample 99/100 (True: 8, Index: 1189)...
#   Success! Adv label: 3, L2: 921.93, Queries: 71
# Attacking sample 100/100 (True: 8, Index: 1207)...
#   Failed! Adv label: 8, L2: 1516.56, Queries: 201
# Attacking sample 1/100 (True: 9, Index: 6)...
#   Failed! Adv label: 9, L2: 1251.52, Queries: 201
# Attacking sample 2/100 (True: 9, Index: 38)...
#   Success! Adv label: 7, L2: 358.95, Queries: 29
# Attacking sample 3/100 (True: 9, Index: 55)...
#   Success! Adv label: 0, L2: 923.21, Queries: 71
# Attacking sample 4/100 (True: 9, Index: 56)...
#   Failed! Adv label: 9, L2: 1100.94, Queries: 201
# Attacking sample 5/100 (True: 9, Index: 91)...
#   Failed! Adv label: 9, L2: 1275.23, Queries: 201
# Attacking sample 6/100 (True: 9, Index: 99)...
#   Failed! Adv label: 9, L2: 1234.57, Queries: 201
# Attacking sample 7/100 (True: 9, Index: 101)...
#   Failed! Adv label: 9, L2: 943.82, Queries: 201
# Attacking sample 8/100 (True: 9, Index: 114)...
#   Failed! Adv label: 9, L2: 1096.36, Queries: 201
# Attacking sample 9/100 (True: 9, Index: 133)...
#   Failed! Adv label: 9, L2: 1206.65, Queries: 201
# Attacking sample 10/100 (True: 9, Index: 171)...
#   Failed! Adv label: 9, L2: 1114.80, Queries: 201
# Attacking sample 11/100 (True: 9, Index: 179)...
#   Failed! Adv label: 9, L2: 1385.03, Queries: 201
# Attacking sample 12/100 (True: 9, Index: 195)...
#   Failed! Adv label: 9, L2: 1039.18, Queries: 201
# Attacking sample 13/100 (True: 9, Index: 214)...
#   Failed! Adv label: 9, L2: 1250.16, Queries: 201
# Attacking sample 14/100 (True: 9, Index: 218)...
#   Failed! Adv label: 9, L2: 1024.05, Queries: 201
# Attacking sample 15/100 (True: 9, Index: 222)...
#   Failed! Adv label: 9, L2: 1194.92, Queries: 201
# Attacking sample 16/100 (True: 9, Index: 224)...
#   Failed! Adv label: 9, L2: 1182.44, Queries: 201
# Attacking sample 17/100 (True: 9, Index: 238)...
#   Failed! Adv label: 9, L2: 1060.45, Queries: 201
# Attacking sample 18/100 (True: 9, Index: 243)...
#   Failed! Adv label: 9, L2: 1313.68, Queries: 201
# Attacking sample 19/100 (True: 9, Index: 245)...
#   Failed! Adv label: 9, L2: 1278.52, Queries: 201
# Attacking sample 20/100 (True: 9, Index: 246)...
#   Failed! Adv label: 9, L2: 914.61, Queries: 201
# Attacking sample 21/100 (True: 9, Index: 251)...
#   Failed! Adv label: 9, L2: 1241.27, Queries: 201
# Attacking sample 22/100 (True: 9, Index: 303)...
#   Failed! Adv label: 9, L2: 1054.25, Queries: 201
# Attacking sample 23/100 (True: 9, Index: 305)...
#   Failed! Adv label: 9, L2: 1239.39, Queries: 201
# Attacking sample 24/100 (True: 9, Index: 307)...
#   Failed! Adv label: 9, L2: 1262.67, Queries: 201
# Attacking sample 25/100 (True: 9, Index: 315)...
#   Failed! Adv label: 9, L2: 1274.78, Queries: 201
# Attacking sample 26/100 (True: 9, Index: 354)...
#   Failed! Adv label: 9, L2: 1022.72, Queries: 201
# Attacking sample 27/100 (True: 9, Index: 364)...
#   Failed! Adv label: 9, L2: 1192.25, Queries: 201
# Attacking sample 28/100 (True: 9, Index: 389)...
#   Failed! Adv label: 9, L2: 1060.47, Queries: 201
# Attacking sample 29/100 (True: 9, Index: 407)...
#   Failed! Adv label: 9, L2: 960.53, Queries: 201
# Attacking sample 30/100 (True: 9, Index: 411)...
#   Failed! Adv label: 9, L2: 1085.91, Queries: 201
# Attacking sample 31/100 (True: 9, Index: 417)...
#   Success! Adv label: 7, L2: 1338.70, Queries: 103
# Attacking sample 32/100 (True: 9, Index: 421)...
#   Failed! Adv label: 9, L2: 953.19, Queries: 201
# Attacking sample 33/100 (True: 9, Index: 438)...
#   Failed! Adv label: 9, L2: 1114.19, Queries: 201
# Attacking sample 34/100 (True: 9, Index: 443)...
#   Failed! Adv label: 9, L2: 1251.50, Queries: 201
# Attacking sample 35/100 (True: 9, Index: 444)...
#   Failed! Adv label: 9, L2: 1093.33, Queries: 201
# Attacking sample 36/100 (True: 9, Index: 446)...
#   Failed! Adv label: 9, L2: 1215.61, Queries: 201
# Attacking sample 37/100 (True: 9, Index: 455)...
#   Failed! Adv label: 9, L2: 1244.78, Queries: 201
# Attacking sample 38/100 (True: 9, Index: 469)...
#   Failed! Adv label: 9, L2: 1124.66, Queries: 201
# Attacking sample 39/100 (True: 9, Index: 472)...
#   Failed! Adv label: 9, L2: 1210.59, Queries: 201
# Attacking sample 40/100 (True: 9, Index: 473)...
#   Failed! Adv label: 9, L2: 1175.11, Queries: 201
# Attacking sample 41/100 (True: 9, Index: 482)...
#   Failed! Adv label: 9, L2: 1099.33, Queries: 201
# Attacking sample 42/100 (True: 9, Index: 490)...
#   Failed! Adv label: 9, L2: 1254.78, Queries: 201
# Attacking sample 43/100 (True: 9, Index: 496)...
#   Failed! Adv label: 9, L2: 1065.71, Queries: 201
# Attacking sample 44/100 (True: 9, Index: 507)...
#   Failed! Adv label: 9, L2: 996.69, Queries: 201
# Attacking sample 45/100 (True: 9, Index: 508)...
#   Failed! Adv label: 9, L2: 1282.70, Queries: 201
# Attacking sample 46/100 (True: 9, Index: 514)...
#   Failed! Adv label: 9, L2: 879.79, Queries: 201
# Attacking sample 47/100 (True: 9, Index: 522)...
#   Success! Adv label: 4, L2: 303.14, Queries: 29
# Attacking sample 48/100 (True: 9, Index: 535)...
#   Failed! Adv label: 9, L2: 1109.17, Queries: 201
# Attacking sample 49/100 (True: 9, Index: 542)...
#   Failed! Adv label: 9, L2: 1101.03, Queries: 201
# Attacking sample 50/100 (True: 9, Index: 553)...
#   Failed! Adv label: 9, L2: 1182.55, Queries: 201
# Attacking sample 51/100 (True: 9, Index: 554)...
#   Failed! Adv label: 9, L2: 1313.55, Queries: 201
# Attacking sample 52/100 (True: 9, Index: 565)...
#   Failed! Adv label: 9, L2: 1246.18, Queries: 201
# Attacking sample 53/100 (True: 9, Index: 569)...
#   Failed! Adv label: 9, L2: 1214.30, Queries: 201
# Attacking sample 54/100 (True: 9, Index: 572)...
#   Failed! Adv label: 9, L2: 1157.34, Queries: 201
# Attacking sample 55/100 (True: 9, Index: 574)...
#   Failed! Adv label: 9, L2: 1031.48, Queries: 201
# Attacking sample 56/100 (True: 9, Index: 601)...
#   Failed! Adv label: 9, L2: 1229.05, Queries: 201
# Attacking sample 57/100 (True: 9, Index: 634)...
#   Failed! Adv label: 9, L2: 1225.81, Queries: 201
# Attacking sample 58/100 (True: 9, Index: 635)...
#   Failed! Adv label: 9, L2: 1108.54, Queries: 201
# Attacking sample 59/100 (True: 9, Index: 637)...
#   Failed! Adv label: 9, L2: 1090.49, Queries: 201
# Attacking sample 60/100 (True: 9, Index: 640)...
#   Failed! Adv label: 9, L2: 1165.80, Queries: 201
# Attacking sample 61/100 (True: 9, Index: 653)...
#   Failed! Adv label: 9, L2: 1215.18, Queries: 201
# Attacking sample 62/100 (True: 9, Index: 654)...
#   Failed! Adv label: 9, L2: 1305.92, Queries: 201
# Attacking sample 63/100 (True: 9, Index: 656)...
#   Failed! Adv label: 9, L2: 1067.12, Queries: 201
# Attacking sample 64/100 (True: 9, Index: 666)...
#   Failed! Adv label: 9, L2: 1174.91, Queries: 201
# Attacking sample 65/100 (True: 9, Index: 685)...
#   Failed! Adv label: 9, L2: 1309.70, Queries: 201
# Attacking sample 66/100 (True: 9, Index: 711)...
#   Failed! Adv label: 9, L2: 1063.95, Queries: 201
# Attacking sample 67/100 (True: 9, Index: 729)...
#   Failed! Adv label: 9, L2: 1057.39, Queries: 201
# Attacking sample 68/100 (True: 9, Index: 739)...
#   Failed! Adv label: 9, L2: 1009.11, Queries: 201
# Attacking sample 69/100 (True: 9, Index: 747)...
#   Failed! Adv label: 9, L2: 1038.78, Queries: 201
# Attacking sample 70/100 (True: 9, Index: 767)...
#   Failed! Adv label: 9, L2: 1102.23, Queries: 201
# Attacking sample 71/100 (True: 9, Index: 783)...
#   Failed! Adv label: 9, L2: 993.36, Queries: 201
# Attacking sample 72/100 (True: 9, Index: 787)...
#   Failed! Adv label: 9, L2: 1138.52, Queries: 201
# Attacking sample 73/100 (True: 9, Index: 796)...
#   Failed! Adv label: 9, L2: 1271.97, Queries: 201
# Attacking sample 74/100 (True: 9, Index: 804)...
#   Failed! Adv label: 9, L2: 1292.54, Queries: 201
# Attacking sample 75/100 (True: 9, Index: 818)...
#   Failed! Adv label: 9, L2: 1218.19, Queries: 201
# Attacking sample 76/100 (True: 9, Index: 825)...
#   Failed! Adv label: 9, L2: 1250.90, Queries: 201
# Attacking sample 77/100 (True: 9, Index: 826)...
#   Failed! Adv label: 9, L2: 1183.19, Queries: 201
# Attacking sample 78/100 (True: 9, Index: 831)...
#   Failed! Adv label: 9, L2: 1155.41, Queries: 201
# Attacking sample 79/100 (True: 9, Index: 880)...
#   Failed! Adv label: 9, L2: 1105.33, Queries: 201
# Attacking sample 80/100 (True: 9, Index: 884)...
#   Failed! Adv label: 9, L2: 1064.47, Queries: 201
# Attacking sample 81/100 (True: 9, Index: 891)...
#   Failed! Adv label: 9, L2: 885.98, Queries: 201
# Attacking sample 82/100 (True: 9, Index: 893)...
#   Failed! Adv label: 9, L2: 1363.86, Queries: 201
# Attacking sample 83/100 (True: 9, Index: 899)...
#   Failed! Adv label: 9, L2: 1173.38, Queries: 201
# Attacking sample 84/100 (True: 9, Index: 912)...
#   Failed! Adv label: 9, L2: 1105.47, Queries: 201
# Attacking sample 85/100 (True: 9, Index: 920)...
#   Failed! Adv label: 9, L2: 1140.96, Queries: 201
# Attacking sample 86/100 (True: 9, Index: 925)...
#   Failed! Adv label: 9, L2: 1290.85, Queries: 201
# Attacking sample 87/100 (True: 9, Index: 940)...
#   Failed! Adv label: 9, L2: 1212.07, Queries: 201
# Attacking sample 88/100 (True: 9, Index: 958)...
#   Failed! Adv label: 9, L2: 1150.17, Queries: 201
# Attacking sample 89/100 (True: 9, Index: 969)...
#   Failed! Adv label: 9, L2: 886.76, Queries: 201
# Attacking sample 90/100 (True: 9, Index: 978)...
#   Failed! Adv label: 9, L2: 977.67, Queries: 201
# Attacking sample 91/100 (True: 9, Index: 979)...
#   Failed! Adv label: 9, L2: 969.20, Queries: 201
# Attacking sample 92/100 (True: 9, Index: 980)...
#   Failed! Adv label: 9, L2: 1177.67, Queries: 201
# Attacking sample 93/100 (True: 9, Index: 991)...
#   Failed! Adv label: 9, L2: 1346.36, Queries: 201
# Attacking sample 94/100 (True: 9, Index: 997)...
#   Failed! Adv label: 9, L2: 1058.72, Queries: 201
# Attacking sample 95/100 (True: 9, Index: 1006)...
#   Failed! Adv label: 9, L2: 1259.51, Queries: 201
# Attacking sample 96/100 (True: 9, Index: 1011)...
#   Failed! Adv label: 9, L2: 1204.37, Queries: 201
# Attacking sample 97/100 (True: 9, Index: 1020)...
#   Failed! Adv label: 9, L2: 1273.87, Queries: 201
# Attacking sample 98/100 (True: 9, Index: 1023)...
#   Failed! Adv label: 9, L2: 1141.26, Queries: 201
# Attacking sample 99/100 (True: 9, Index: 1042)...
#   Failed! Adv label: 9, L2: 1127.70, Queries: 201
# Attacking sample 100/100 (True: 9, Index: 1046)...
#   Failed! Adv label: 9, L2: 1076.59, Queries: 201
# Time taken to generate adversarial samples: 343.0165 seconds
#
# Stats saved to: adversarial_8bit_LeaetK_test_images\per_sample_stats.csv
#
# ===== Attack Summary =====
# Total trials: 986
# Misclassified before attack: 14
# Success rate: 29/986 (2.9%)
# Mean L2 (successful): 789.79
# Mean queries (successful): 65.48
#
# Showing successful adversarial examples...
