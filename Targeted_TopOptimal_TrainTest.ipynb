# %% [markdown]
# ### Display the versions of the libraries used for reference purposes.

# %%
import sys
import numpy as np
import tensorflow as tf
import sklearn
import torch
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import notebook
import os

# Print Python version
print(f'Python version: {sys.version}')

# Print Jupyter Notebook version
print(f'Jupyter Notebook version: {notebook.__version__}')

# Print library versions
print(f'NumPy version: {np.__version__}')
print(f'TensorFlow version: {tf.__version__}')
print(f'Torch version: {torch.__version__}')
print(f'Scikit-learn version: {sklearn.__version__}')

os.makedirs("Models and Data splits", exist_ok=True)
# Out:
# Python version: 3.12.9 | packaged by Anaconda, Inc. | (main, Feb  6 2025, 18:49:16) [MSC v.1929 64 bit (AMD64)]
# Jupyter Notebook version: 7.3.2
# NumPy version: 2.0.1
# TensorFlow version: 2.19.0
# Torch version: 2.6.0+cu126
# Scikit-learn version: 1.6.1

# %% [markdown]
# ### Targeted Attack on train set

# %%
import os
import warnings
import numpy as np
import torch
import joblib
import pandas as pd
from PIL import Image
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import torch.nn.functional as F
import time

# Set seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# ─────────────── PATHS ────────────────────────────────────────────────────
LENET_MODEL_PATH = os.path.normpath("Models and Data splits/lenet.pt")  # TorchScript model
DATA_PKL = os.path.normpath("Models and Data splits/data_[SCALED] Train_Test_Splits.pkl")
RF_ALL_CLASSES_PATH = os.path.normpath("Models and Data splits/random_forest.pkl")
OUT_DIR = "Targeted_adversarial_8bit_train_images"
os.makedirs(OUT_DIR, exist_ok=True)

if not os.path.exists(RF_ALL_CLASSES_PATH):
    raise FileNotFoundError(f"Random Forest model not found at {RF_ALL_CLASSES_PATH}")

# ─────────── HYPER-PARAMETERS ─────────────────────────────────────────────
EPSILON_STEP = 0.01
ITERATIONS = 100
TOTAL_EPSILON = 0.5
TOP_K_FEATURES = 196
SAMPLES_PER_DIGIT = 100
MAX_L2 = 10000

def plot_adversarial_example(original_img, adv_img, true_label, adv_label, l2_mag, sample_idx, queries, title_suffix=""):
    if original_img.size == 784:
        original_img = original_img.reshape(28, 28)
    if adv_img.size == 784:
        adv_img = adv_img.reshape(28, 28)
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(original_img, cmap='gray')
    axes[0].set_title(f"Original\nTrue: {true_label}")
    axes[0].axis('off')
    axes[1].imshow(adv_img, cmap='gray')
    axes[1].set_title(f"Adversarial\nPred: {adv_label}")
    axes[1].axis('off')
    fig.suptitle(f"Sample {sample_idx} | L2: {l2_mag:.2f} | Queries: {queries} {title_suffix}")
    plt.show()
    plt.close(fig)  # <-- added here


# ─────────── Load Data ─────────────────────────────────────────────────────
try:
    data = joblib.load(DATA_PKL)
    X_samples, _ , y_samples, _ = data
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PKL}. Please check the path.")
    exit()

if X_samples.max() > 1.0:
    X_samples = X_samples.astype(np.float32) / 255.0
    warnings.warn("Data appeared in [0,255]; normalized to [0,1].")

# ─────────── Load TorchScripted LeNet ──────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
try:
    model = torch.jit.load(LENET_MODEL_PATH, map_location=device)
    model.eval()
    print(f"LeNet TorchScript model loaded from: {LENET_MODEL_PATH}")
except Exception as e:
    print(f"Error loading TorchScript LeNet model: {e}")
    exit()

def to_model(x01_batch):
    if x01_batch.ndim == 2 and x01_batch.shape == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)
    elif x01_batch.ndim == 3 and x01_batch.shape[1:] == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(1)
    elif x01_batch.ndim == 4 and x01_batch.shape[1] == 1:
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device)
    elif x01_batch.ndim == 1 and x01_batch.size == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(1, 1, 28, 28), dtype=torch.float32, device=device)
    elif x01_batch.ndim == 2 and x01_batch.shape[1] == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(x01_batch.shape[0], 1, 28, 28), dtype=torch.float32, device=device)
    else:
        raise ValueError(f"Unsupported input shape for to_model: {x01_batch.shape}")
    return tensor_batch


def model_query(x_tensor_batch):
    with torch.no_grad():
        return model(x_tensor_batch)

# ─────────── Load Random Forest Model ──────────────────────────────────────
rf_all_classes = None
top_feature_indices = None
print("Loading Random Forest Classifier for all classes...")
try:
    rf_all_classes = joblib.load(RF_ALL_CLASSES_PATH)
    feature_importances = rf_all_classes.feature_importances_
    top_feature_indices = np.argsort(-feature_importances)[:TOP_K_FEATURES]
    print(f"Random Forest loaded. Using top {TOP_K_FEATURES} features.")
except Exception as e:
    print(f"Error loading Random Forest: {e}")
    top_feature_indices = np.arange(28 * 28)

# ─────────── Targeted I-FGSM Attack ───────────────────────────────────────
def targeted_ifgsm_attack(original_image_np, target_label, model_target, epsilon_step, iterations,
                          total_epsilon_budget, features_to_perturb, query_count_tracker):
    if original_image_np.ndim == 1 and original_image_np.size == 784:
        original_image_np = original_image_np.reshape(28, 28)

    perturbed_image_np = original_image_np.copy()
    final_pred_label = -1  # Initialize with invalid label

    for i in range(iterations):
        image_tensor = to_model(perturbed_image_np)
        image_tensor.requires_grad = True
        output = model_target(image_tensor)
        query_count_tracker[0] += 1
        
        # Minimize loss for TARGET class (targeted attack)
        loss = F.cross_entropy(output, torch.tensor([target_label], device=device))
        model_target.zero_grad()
        loss.backward()
        
        # Get gradient sign and apply MASK to top features
        data_grad_sign = torch.sign(image_tensor.grad.data).cpu().numpy()
        gradient_mask = np.zeros_like(data_grad_sign, dtype=np.float32)
        h, w = perturbed_image_np.shape
        rows, cols = np.unravel_index(features_to_perturb, (h, w))
        gradient_mask[0, 0, rows, cols] = data_grad_sign[0, 0, rows, cols]
        gradient_mask_for_update = gradient_mask.reshape(perturbed_image_np.shape)

        # Update: SUBTRACT gradient to minimize target loss (targeted attack)
        perturbed_image_np -= epsilon_step * gradient_mask_for_update
        
        # Clamp perturbations and image values
        perturbation = perturbed_image_np - original_image_np
        perturbation = np.clip(perturbation, -total_epsilon_budget, total_epsilon_budget)
        perturbed_image_np = original_image_np + perturbation
        perturbed_image_np = np.clip(perturbed_image_np, 0, 1)

        # Check if current perturbation hits target
        adv_uint8_temp = np.round(perturbed_image_np * 255).astype(np.uint8)
        adv_float_temp = adv_uint8_temp.astype(np.float32) / 255.0
        with torch.no_grad():
            output_temp = model_target(to_model(adv_float_temp))
            pred_temp = output_temp.argmax(dim=1).item()
            query_count_tracker[0] += 1

        if pred_temp == target_label:
            final_pred_label = pred_temp
            break

    # Final evaluation
    adv_uint8 = np.round(perturbed_image_np * 255).astype(np.uint8)
    adv_float = adv_uint8.astype(np.float32) / 255.0
    with torch.no_grad():
        output_final = model_target(to_model(adv_float))
        final_pred_label = output_final.argmax(dim=1).item()

    l2_norm = np.linalg.norm(adv_uint8.astype(np.float32) - (original_image_np * 255).astype(np.float32))
    success = (final_pred_label == target_label) and (l2_norm <= MAX_L2)

    return adv_uint8, final_pred_label, l2_norm, success


# ─────────── Attack Execution ──────────────────────────────────────────────
print(f"\n===== Starting Targeted Adversarial Attacks =====")
total_trials, succ_total = 0, 0
records = []
start_time = time.time()

for digit in range(10):
    idxs = np.where(y_samples == digit)[0][:SAMPLES_PER_DIGIT]
    for rank, idx in enumerate(idxs, 1):
        x0 = X_samples[idx].copy()
        y0_true = int(y_samples[idx])
        
        # Skip misclassified original samples
        query_count_tracker = [0]
        pred0 = model_query(to_model(x0)).argmax(dim=1).item()
        query_count_tracker[0] += 1
        if pred0 != y0_true:
            records.append({
                'sample_idx': idx, 'true_label': y0_true, 'target_label': None,
                'initial_pred': pred0, 'adv_label': None, 'success': False,
                'queries': query_count_tracker[0], 'l2_mag': np.nan,
                'note': 'Already misclassified'
            })
            continue

        # Attack this sample for all 9 target digits
        for target in range(10):
            if target == y0_true:
                continue  # Skip same-digit target
                
            total_trials += 1
            query_count_tracker_target = [0]  # Reset per-target query count
            print(f"Attacking sample {idx} (True: {y0_true} → Target: {target})...")
            
            adv_img_uint8, adv_label, l2_mag, success = targeted_ifgsm_attack(
                x0, target, model, EPSILON_STEP, ITERATIONS, TOTAL_EPSILON,
                top_feature_indices, query_count_tracker_target
            )
            
            if success:
                succ_total += 1
                fname = f"true{y0_true}_target{target}_adv{adv_label}_mag{l2_mag:.1f}_sample{idx}.png"
                Image.fromarray(adv_img_uint8, mode="L").save(os.path.join(OUT_DIR, fname))
            
            records.append({
                'sample_idx': idx, 'true_label': y0_true, 'target_label': target,
                'initial_pred': pred0, 'adv_label': adv_label, 'success': success,
                'queries': query_count_tracker_target[0], 'l2_mag': l2_mag if success else np.nan,
                'note': 'Targeted I-FGSM' + (' success' if success else '')
            })
            
            print(f"  {'SUCCESS' if success else 'FAIL'} | L2: {l2_mag:.2f} | Queries: {query_count_tracker_target[0]}")


end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to generate adversarial samples: {elapsed_time:.4f} seconds")


# ─────────── Save Results ──────────────────────────────────────────────────
df = pd.DataFrame(records)
csv_path = os.path.join(OUT_DIR, "per_sample_stats.csv")
df.to_csv(csv_path, index=False)
print(f"\nStats saved to: {csv_path}")

# ─────────── Summary ───────────────────────────────────────────────────────
print(f"\n===== Attack Summary =====")
print(f"Total trials: {total_trials}")
if total_trials > 0:
    success_rate = succ_total / total_trials * 100
    print(f"Success rate: {succ_total}/{total_trials} ({success_rate:.1f}%)")
    if succ_total > 0:
        print(f"Mean L2 (successful): {df[df['success']]['l2_mag'].mean():.2f}")
        print(f"Mean queries (successful): {df[df['success']]['queries'].mean():.2f}")

# ─────────── Display Examples ──────────────────────────────────────────────
success_df = df[df['success']]
if not success_df.empty:
    print("\nShowing successful adversarial examples...")
    show_ids = success_df.sample(min(3, len(success_df))).index.tolist()
    for record_idx in show_ids:
        r = df.loc[record_idx]
        fname_prefix = f"true{r['true_label']}_target{r['target_label']}_adv{r['adv_label']}_mag{r['l2_mag']:.1f}_sample{r['sample_idx']}"
        match_files = [f for f in os.listdir(OUT_DIR) if f.startswith(fname_prefix)]
        if match_files:
            adv_img_path = os.path.join(OUT_DIR, match_files[0])
            plot_adversarial_example(X_samples[r['sample_idx']], np.array(Image.open(adv_img_path)),
                                     r['true_label'], r['adv_label'], r['l2_mag'],
                                     r['sample_idx'], r['queries'], f"(Target: {r['target_label']})")
else:
    print("No successful attacks to display. Showing original samples instead.")
    for i in range(min(3, len(df))):
        r = df.iloc[i]
        plot_adversarial_example(X_samples[r['sample_idx']], X_samples[r['sample_idx']],
                                 r['true_label'], r['initial_pred'], 0.0,
                                 r['sample_idx'], r['queries'], "(Original)")
# Out:
# LeNet TorchScript model loaded from: Models and Data splits\lenet.pt
# Loading Random Forest Classifier for all classes...
# Random Forest loaded. Using top 196 features.
#
# ===== Starting Targeted Adversarial Attacks =====
# Attacking sample 0 (True: 0 → Target: 1)...
#   FAIL | L2: 1174.09 | Queries: 200
# Attacking sample 0 (True: 0 → Target: 2)...
#   SUCCESS | L2: 917.48 | Queries: 72
# Attacking sample 0 (True: 0 → Target: 3)...
#   SUCCESS | L2: 929.48 | Queries: 76
# Attacking sample 0 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1070.52 | Queries: 156
# Attacking sample 0 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1282.26 | Queries: 164
# Attacking sample 0 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1089.81 | Queries: 110
# Attacking sample 0 (True: 0 → Target: 7)...
#   FAIL | L2: 1200.62 | Queries: 200
# Attacking sample 0 (True: 0 → Target: 8)...
#   SUCCESS | L2: 865.72 | Queries: 62
# Attacking sample 0 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1115.02 | Queries: 108
# Attacking sample 2 (True: 0 → Target: 1)...
#   FAIL | L2: 1254.67 | Queries: 200
# Attacking sample 2 (True: 0 → Target: 2)...
#   SUCCESS | L2: 888.28 | Queries: 70
# Attacking sample 2 (True: 0 → Target: 3)...
#   SUCCESS | L2: 759.30 | Queries: 62
# Attacking sample 2 (True: 0 → Target: 4)...
#   SUCCESS | L2: 890.03 | Queries: 74
# Attacking sample 2 (True: 0 → Target: 5)...
#   SUCCESS | L2: 644.14 | Queries: 50
# Attacking sample 2 (True: 0 → Target: 6)...
#   SUCCESS | L2: 901.62 | Queries: 76
# Attacking sample 2 (True: 0 → Target: 7)...
#   SUCCESS | L2: 917.10 | Queries: 78
# Attacking sample 2 (True: 0 → Target: 8)...
#   SUCCESS | L2: 691.91 | Queries: 50
# Attacking sample 2 (True: 0 → Target: 9)...
#   SUCCESS | L2: 656.24 | Queries: 54
# Attacking sample 7 (True: 0 → Target: 1)...
#   FAIL | L2: 1231.38 | Queries: 200
# Attacking sample 7 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1169.44 | Queries: 96
# Attacking sample 7 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1188.95 | Queries: 94
# Attacking sample 7 (True: 0 → Target: 4)...
#   FAIL | L2: 1188.32 | Queries: 200
# Attacking sample 7 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1068.84 | Queries: 86
# Attacking sample 7 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1087.12 | Queries: 80
# Attacking sample 7 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1161.25 | Queries: 138
# Attacking sample 7 (True: 0 → Target: 8)...
#   SUCCESS | L2: 945.27 | Queries: 70
# Attacking sample 7 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1046.06 | Queries: 86
# Attacking sample 16 (True: 0 → Target: 1)...
#   FAIL | L2: 1197.47 | Queries: 200
# Attacking sample 16 (True: 0 → Target: 2)...
#   FAIL | L2: 1311.73 | Queries: 200
# Attacking sample 16 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1187.21 | Queries: 110
# Attacking sample 16 (True: 0 → Target: 4)...
#   FAIL | L2: 1349.02 | Queries: 200
# Attacking sample 16 (True: 0 → Target: 5)...
#   SUCCESS | L2: 694.67 | Queries: 60
# Attacking sample 16 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1078.17 | Queries: 82
# Attacking sample 16 (True: 0 → Target: 7)...
#   FAIL | L2: 1164.11 | Queries: 200
# Attacking sample 16 (True: 0 → Target: 8)...
#   SUCCESS | L2: 933.09 | Queries: 72
# Attacking sample 16 (True: 0 → Target: 9)...
#   SUCCESS | L2: 665.75 | Queries: 56
# Attacking sample 35 (True: 0 → Target: 1)...
#   FAIL | L2: 1094.84 | Queries: 200
# Attacking sample 35 (True: 0 → Target: 2)...
#   SUCCESS | L2: 563.85 | Queries: 46
# Attacking sample 35 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1020.00 | Queries: 82
# Attacking sample 35 (True: 0 → Target: 4)...
#   SUCCESS | L2: 706.80 | Queries: 64
# Attacking sample 35 (True: 0 → Target: 5)...
#   SUCCESS | L2: 927.85 | Queries: 78
# Attacking sample 35 (True: 0 → Target: 6)...
#   SUCCESS | L2: 330.10 | Queries: 24
# Attacking sample 35 (True: 0 → Target: 7)...
#   SUCCESS | L2: 980.68 | Queries: 92
# Attacking sample 35 (True: 0 → Target: 8)...
#   SUCCESS | L2: 596.77 | Queries: 44
# Attacking sample 35 (True: 0 → Target: 9)...
#   SUCCESS | L2: 673.32 | Queries: 52
# Attacking sample 44 (True: 0 → Target: 1)...
#   FAIL | L2: 1261.34 | Queries: 200
# Attacking sample 44 (True: 0 → Target: 2)...
#   SUCCESS | L2: 709.82 | Queries: 52
# Attacking sample 44 (True: 0 → Target: 3)...
#   SUCCESS | L2: 698.29 | Queries: 54
# Attacking sample 44 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1082.45 | Queries: 108
# Attacking sample 44 (True: 0 → Target: 5)...
#   SUCCESS | L2: 499.86 | Queries: 40
# Attacking sample 44 (True: 0 → Target: 6)...
#   SUCCESS | L2: 675.32 | Queries: 58
# Attacking sample 44 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1010.61 | Queries: 90
# Attacking sample 44 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1120.37 | Queries: 106
# Attacking sample 44 (True: 0 → Target: 9)...
#   SUCCESS | L2: 801.40 | Queries: 78
# Attacking sample 49 (True: 0 → Target: 1)...
#   FAIL | L2: 1172.68 | Queries: 200
# Attacking sample 49 (True: 0 → Target: 2)...
#   SUCCESS | L2: 734.46 | Queries: 60
# Attacking sample 49 (True: 0 → Target: 3)...
#   SUCCESS | L2: 870.30 | Queries: 68
# Attacking sample 49 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1183.70 | Queries: 122
# Attacking sample 49 (True: 0 → Target: 5)...
#   SUCCESS | L2: 641.36 | Queries: 50
# Attacking sample 49 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1154.28 | Queries: 98
# Attacking sample 49 (True: 0 → Target: 7)...
#   SUCCESS | L2: 925.11 | Queries: 82
# Attacking sample 49 (True: 0 → Target: 8)...
#   SUCCESS | L2: 692.78 | Queries: 50
# Attacking sample 49 (True: 0 → Target: 9)...
#   SUCCESS | L2: 675.37 | Queries: 52
# Attacking sample 58 (True: 0 → Target: 1)...
#   FAIL | L2: 1244.52 | Queries: 200
# Attacking sample 58 (True: 0 → Target: 2)...
#   SUCCESS | L2: 963.16 | Queries: 76
# Attacking sample 58 (True: 0 → Target: 3)...
#   SUCCESS | L2: 833.91 | Queries: 64
# Attacking sample 58 (True: 0 → Target: 4)...
#   FAIL | L2: 1339.79 | Queries: 200
# Attacking sample 58 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1184.85 | Queries: 154
# Attacking sample 58 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1198.78 | Queries: 134
# Attacking sample 58 (True: 0 → Target: 7)...
#   FAIL | L2: 1190.65 | Queries: 200
# Attacking sample 58 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1132.44 | Queries: 90
# Attacking sample 58 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1182.03 | Queries: 126
# Attacking sample 63 (True: 0 → Target: 1)...
#   FAIL | L2: 1202.53 | Queries: 200
# Attacking sample 63 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1151.84 | Queries: 94
# Attacking sample 63 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1177.68 | Queries: 110
# Attacking sample 63 (True: 0 → Target: 4)...
#   FAIL | L2: 1386.87 | Queries: 200
# Attacking sample 63 (True: 0 → Target: 5)...
#   SUCCESS | L2: 869.82 | Queries: 74
# Attacking sample 63 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1150.89 | Queries: 96
# Attacking sample 63 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1060.45 | Queries: 96
# Attacking sample 63 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1080.30 | Queries: 82
# Attacking sample 63 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1103.95 | Queries: 102
# Attacking sample 67 (True: 0 → Target: 1)...
#   FAIL | L2: 1228.91 | Queries: 200
# Attacking sample 67 (True: 0 → Target: 2)...
#   SUCCESS | L2: 600.19 | Queries: 48
# Attacking sample 67 (True: 0 → Target: 3)...
#   SUCCESS | L2: 629.69 | Queries: 50
# Attacking sample 67 (True: 0 → Target: 4)...
#   SUCCESS | L2: 900.14 | Queries: 78
# Attacking sample 67 (True: 0 → Target: 5)...
#   SUCCESS | L2: 629.58 | Queries: 52
# Attacking sample 67 (True: 0 → Target: 6)...
#   SUCCESS | L2: 626.96 | Queries: 46
# Attacking sample 67 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1062.32 | Queries: 90
# Attacking sample 67 (True: 0 → Target: 8)...
#   SUCCESS | L2: 560.23 | Queries: 42
# Attacking sample 67 (True: 0 → Target: 9)...
#   SUCCESS | L2: 603.74 | Queries: 44
# Attacking sample 72 (True: 0 → Target: 1)...
#   FAIL | L2: 1249.97 | Queries: 200
# Attacking sample 72 (True: 0 → Target: 2)...
#   SUCCESS | L2: 947.03 | Queries: 82
# Attacking sample 72 (True: 0 → Target: 3)...
#   SUCCESS | L2: 927.40 | Queries: 76
# Attacking sample 72 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1152.57 | Queries: 96
# Attacking sample 72 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1060.50 | Queries: 90
# Attacking sample 72 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1020.32 | Queries: 82
# Attacking sample 72 (True: 0 → Target: 7)...
#   SUCCESS | L2: 957.62 | Queries: 84
# Attacking sample 72 (True: 0 → Target: 8)...
#   SUCCESS | L2: 832.14 | Queries: 60
# Attacking sample 72 (True: 0 → Target: 9)...
#   SUCCESS | L2: 840.51 | Queries: 68
# Attacking sample 73 (True: 0 → Target: 1)...
#   FAIL | L2: 1241.54 | Queries: 200
# Attacking sample 73 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1284.27 | Queries: 196
# Attacking sample 73 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1133.02 | Queries: 96
# Attacking sample 73 (True: 0 → Target: 4)...
#   FAIL | L2: 1271.28 | Queries: 200
# Attacking sample 73 (True: 0 → Target: 5)...
#   FAIL | L2: 1319.09 | Queries: 200
# Attacking sample 73 (True: 0 → Target: 6)...
#   FAIL | L2: 1291.54 | Queries: 200
# Attacking sample 73 (True: 0 → Target: 7)...
#   FAIL | L2: 1176.52 | Queries: 200
# Attacking sample 73 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1472.07 | Queries: 164
# Attacking sample 73 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1127.05 | Queries: 96
# Attacking sample 75 (True: 0 → Target: 1)...
#   FAIL | L2: 1344.91 | Queries: 200
# Attacking sample 75 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1176.10 | Queries: 98
# Attacking sample 75 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1276.79 | Queries: 106
# Attacking sample 75 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1372.90 | Queries: 168
# Attacking sample 75 (True: 0 → Target: 5)...
#   FAIL | L2: 1355.62 | Queries: 200
# Attacking sample 75 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1131.51 | Queries: 140
# Attacking sample 75 (True: 0 → Target: 7)...
#   FAIL | L2: 1243.12 | Queries: 200
# Attacking sample 75 (True: 0 → Target: 8)...
#   SUCCESS | L2: 887.88 | Queries: 66
# Attacking sample 75 (True: 0 → Target: 9)...
#   SUCCESS | L2: 984.14 | Queries: 80
# Attacking sample 97 (True: 0 → Target: 1)...
#   FAIL | L2: 1206.74 | Queries: 200
# Attacking sample 97 (True: 0 → Target: 2)...
#   SUCCESS | L2: 661.43 | Queries: 52
# Attacking sample 97 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1015.20 | Queries: 88
# Attacking sample 97 (True: 0 → Target: 4)...
#   FAIL | L2: 1369.42 | Queries: 200
# Attacking sample 97 (True: 0 → Target: 5)...
#   SUCCESS | L2: 851.24 | Queries: 76
# Attacking sample 97 (True: 0 → Target: 6)...
#   SUCCESS | L2: 991.35 | Queries: 72
# Attacking sample 97 (True: 0 → Target: 7)...
#   FAIL | L2: 1265.13 | Queries: 200
# Attacking sample 97 (True: 0 → Target: 8)...
#   SUCCESS | L2: 838.67 | Queries: 70
# Attacking sample 97 (True: 0 → Target: 9)...
#   SUCCESS | L2: 542.29 | Queries: 44
# Attacking sample 112 (True: 0 → Target: 1)...
#   FAIL | L2: 1134.84 | Queries: 200
# Attacking sample 112 (True: 0 → Target: 2)...
#   SUCCESS | L2: 975.70 | Queries: 98
# Attacking sample 112 (True: 0 → Target: 3)...
#   SUCCESS | L2: 756.93 | Queries: 62
# Attacking sample 112 (True: 0 → Target: 4)...
#   FAIL | L2: 1210.42 | Queries: 200
# Attacking sample 112 (True: 0 → Target: 5)...
#   SUCCESS | L2: 773.03 | Queries: 68
# Attacking sample 112 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1148.10 | Queries: 94
# Attacking sample 112 (True: 0 → Target: 7)...
#   FAIL | L2: 1208.19 | Queries: 200
# Attacking sample 112 (True: 0 → Target: 8)...
#   SUCCESS | L2: 976.41 | Queries: 78
# Attacking sample 112 (True: 0 → Target: 9)...
#   SUCCESS | L2: 831.46 | Queries: 76
# Attacking sample 113 (True: 0 → Target: 1)...
#   FAIL | L2: 1220.08 | Queries: 200
# Attacking sample 113 (True: 0 → Target: 2)...
#   SUCCESS | L2: 690.35 | Queries: 50
# Attacking sample 113 (True: 0 → Target: 3)...
#   SUCCESS | L2: 795.95 | Queries: 60
# Attacking sample 113 (True: 0 → Target: 4)...
#   SUCCESS | L2: 774.26 | Queries: 64
# Attacking sample 113 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1072.69 | Queries: 92
# Attacking sample 113 (True: 0 → Target: 6)...
#   SUCCESS | L2: 989.70 | Queries: 84
# Attacking sample 113 (True: 0 → Target: 7)...
#   SUCCESS | L2: 964.86 | Queries: 82
# Attacking sample 113 (True: 0 → Target: 8)...
#   SUCCESS | L2: 786.78 | Queries: 54
# Attacking sample 113 (True: 0 → Target: 9)...
#   SUCCESS | L2: 932.26 | Queries: 82
# Attacking sample 118 (True: 0 → Target: 1)...
#   SUCCESS | L2: 1212.81 | Queries: 194
# Attacking sample 118 (True: 0 → Target: 2)...
#   SUCCESS | L2: 539.55 | Queries: 38
# Attacking sample 118 (True: 0 → Target: 3)...
#   SUCCESS | L2: 653.10 | Queries: 50
# Attacking sample 118 (True: 0 → Target: 4)...
#   SUCCESS | L2: 587.51 | Queries: 48
# Attacking sample 118 (True: 0 → Target: 5)...
#   SUCCESS | L2: 452.41 | Queries: 36
# Attacking sample 118 (True: 0 → Target: 6)...
#   SUCCESS | L2: 471.69 | Queries: 38
# Attacking sample 118 (True: 0 → Target: 7)...
#   SUCCESS | L2: 492.49 | Queries: 42
# Attacking sample 118 (True: 0 → Target: 8)...
#   SUCCESS | L2: 507.38 | Queries: 36
# Attacking sample 118 (True: 0 → Target: 9)...
#   SUCCESS | L2: 492.24 | Queries: 36
# Attacking sample 135 (True: 0 → Target: 1)...
#   FAIL | L2: 1250.58 | Queries: 200
# Attacking sample 135 (True: 0 → Target: 2)...
#   SUCCESS | L2: 460.65 | Queries: 34
# Attacking sample 135 (True: 0 → Target: 3)...
#   SUCCESS | L2: 868.49 | Queries: 66
# Attacking sample 135 (True: 0 → Target: 4)...
#   SUCCESS | L2: 504.40 | Queries: 40
# Attacking sample 135 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1029.08 | Queries: 84
# Attacking sample 135 (True: 0 → Target: 6)...
#   SUCCESS | L2: 942.20 | Queries: 78
# Attacking sample 135 (True: 0 → Target: 7)...
#   SUCCESS | L2: 718.63 | Queries: 60
# Attacking sample 135 (True: 0 → Target: 8)...
#   SUCCESS | L2: 687.81 | Queries: 50
# Attacking sample 135 (True: 0 → Target: 9)...
#   SUCCESS | L2: 596.12 | Queries: 44
# Attacking sample 155 (True: 0 → Target: 1)...
#   FAIL | L2: 1184.99 | Queries: 200
# Attacking sample 155 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1004.91 | Queries: 84
# Attacking sample 155 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1046.55 | Queries: 86
# Attacking sample 155 (True: 0 → Target: 4)...
#   FAIL | L2: 1191.33 | Queries: 200
# Attacking sample 155 (True: 0 → Target: 5)...
#   FAIL | L2: 1313.94 | Queries: 200
# Attacking sample 155 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1262.55 | Queries: 144
# Attacking sample 155 (True: 0 → Target: 7)...
#   FAIL | L2: 1260.19 | Queries: 200
# Attacking sample 155 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1126.32 | Queries: 82
# Attacking sample 155 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1058.75 | Queries: 120
# Attacking sample 174 (True: 0 → Target: 1)...
#   FAIL | L2: 1210.19 | Queries: 200
# Attacking sample 174 (True: 0 → Target: 2)...
#   SUCCESS | L2: 878.09 | Queries: 68
# Attacking sample 174 (True: 0 → Target: 3)...
#   SUCCESS | L2: 870.38 | Queries: 80
# Attacking sample 174 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1031.89 | Queries: 96
# Attacking sample 174 (True: 0 → Target: 5)...
#   SUCCESS | L2: 566.36 | Queries: 48
# Attacking sample 174 (True: 0 → Target: 6)...
#   SUCCESS | L2: 529.55 | Queries: 38
# Attacking sample 174 (True: 0 → Target: 7)...
#   FAIL | L2: 1147.71 | Queries: 200
# Attacking sample 174 (True: 0 → Target: 8)...
#   SUCCESS | L2: 625.21 | Queries: 50
# Attacking sample 174 (True: 0 → Target: 9)...
#   SUCCESS | L2: 445.09 | Queries: 36
# Attacking sample 182 (True: 0 → Target: 1)...
#   FAIL | L2: 1175.81 | Queries: 200
# Attacking sample 182 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1077.61 | Queries: 88
# Attacking sample 182 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1135.63 | Queries: 90
# Attacking sample 182 (True: 0 → Target: 4)...
#   FAIL | L2: 1306.35 | Queries: 200
# Attacking sample 182 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1272.77 | Queries: 138
# Attacking sample 182 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1272.47 | Queries: 98
# Attacking sample 182 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1126.88 | Queries: 134
# Attacking sample 182 (True: 0 → Target: 8)...
#   SUCCESS | L2: 923.07 | Queries: 68
# Attacking sample 182 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1161.92 | Queries: 136
# Attacking sample 186 (True: 0 → Target: 1)...
#   FAIL | L2: 1136.52 | Queries: 200
# Attacking sample 186 (True: 0 → Target: 2)...
#   SUCCESS | L2: 799.42 | Queries: 72
# Attacking sample 186 (True: 0 → Target: 3)...
#   SUCCESS | L2: 863.41 | Queries: 74
# Attacking sample 186 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1252.74 | Queries: 160
# Attacking sample 186 (True: 0 → Target: 5)...
#   SUCCESS | L2: 892.96 | Queries: 76
# Attacking sample 186 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1027.50 | Queries: 80
# Attacking sample 186 (True: 0 → Target: 7)...
#   FAIL | L2: 1225.75 | Queries: 200
# Attacking sample 186 (True: 0 → Target: 8)...
#   SUCCESS | L2: 645.00 | Queries: 52
# Attacking sample 186 (True: 0 → Target: 9)...
#   SUCCESS | L2: 645.95 | Queries: 50
# Attacking sample 187 (True: 0 → Target: 1)...
#   SUCCESS | L2: 957.42 | Queries: 94
# Attacking sample 187 (True: 0 → Target: 2)...
#   SUCCESS | L2: 248.60 | Queries: 18
# Attacking sample 187 (True: 0 → Target: 3)...
#   SUCCESS | L2: 707.38 | Queries: 54
# Attacking sample 187 (True: 0 → Target: 4)...
#   SUCCESS | L2: 238.11 | Queries: 16
# Attacking sample 187 (True: 0 → Target: 5)...
#   SUCCESS | L2: 662.86 | Queries: 50
# Attacking sample 187 (True: 0 → Target: 6)...
#   SUCCESS | L2: 214.48 | Queries: 14
# Attacking sample 187 (True: 0 → Target: 7)...
#   SUCCESS | L2: 815.46 | Queries: 76
# Attacking sample 187 (True: 0 → Target: 8)...
#   SUCCESS | L2: 520.03 | Queries: 36
# Attacking sample 187 (True: 0 → Target: 9)...
#   SUCCESS | L2: 646.04 | Queries: 46
# Attacking sample 196 (True: 0 → Target: 1)...
#   FAIL | L2: 1276.91 | Queries: 200
# Attacking sample 196 (True: 0 → Target: 2)...
#   SUCCESS | L2: 981.63 | Queries: 76
# Attacking sample 196 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1173.19 | Queries: 96
# Attacking sample 196 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1255.91 | Queries: 132
# Attacking sample 196 (True: 0 → Target: 5)...
#   SUCCESS | L2: 937.41 | Queries: 82
# Attacking sample 196 (True: 0 → Target: 6)...
#   SUCCESS | L2: 842.19 | Queries: 66
# Attacking sample 196 (True: 0 → Target: 7)...
#   FAIL | L2: 1219.02 | Queries: 200
# Attacking sample 196 (True: 0 → Target: 8)...
#   SUCCESS | L2: 866.51 | Queries: 70
# Attacking sample 196 (True: 0 → Target: 9)...
#   SUCCESS | L2: 863.03 | Queries: 66
# Attacking sample 200 (True: 0 → Target: 1)...
#   FAIL | L2: 1080.73 | Queries: 200
# Attacking sample 200 (True: 0 → Target: 2)...
#   SUCCESS | L2: 661.44 | Queries: 58
# Attacking sample 200 (True: 0 → Target: 3)...
#   SUCCESS | L2: 819.10 | Queries: 72
# Attacking sample 200 (True: 0 → Target: 4)...
#   SUCCESS | L2: 825.36 | Queries: 76
# Attacking sample 200 (True: 0 → Target: 5)...
#   SUCCESS | L2: 874.10 | Queries: 84
# Attacking sample 200 (True: 0 → Target: 6)...
#   SUCCESS | L2: 426.59 | Queries: 32
# Attacking sample 200 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1105.07 | Queries: 152
# Attacking sample 200 (True: 0 → Target: 8)...
#   SUCCESS | L2: 535.81 | Queries: 42
# Attacking sample 200 (True: 0 → Target: 9)...
#   SUCCESS | L2: 545.79 | Queries: 42
# Attacking sample 203 (True: 0 → Target: 1)...
#   FAIL | L2: 1248.47 | Queries: 200
# Attacking sample 203 (True: 0 → Target: 2)...
#   SUCCESS | L2: 785.42 | Queries: 64
# Attacking sample 203 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1002.90 | Queries: 84
# Attacking sample 203 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1125.27 | Queries: 134
# Attacking sample 203 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1108.87 | Queries: 90
# Attacking sample 203 (True: 0 → Target: 6)...
#   SUCCESS | L2: 666.91 | Queries: 52
# Attacking sample 203 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1060.64 | Queries: 86
# Attacking sample 203 (True: 0 → Target: 8)...
#   SUCCESS | L2: 827.85 | Queries: 58
# Attacking sample 203 (True: 0 → Target: 9)...
#   SUCCESS | L2: 683.66 | Queries: 50
# Attacking sample 218 (True: 0 → Target: 1)...
#   SUCCESS | L2: 1019.65 | Queries: 120
# Attacking sample 218 (True: 0 → Target: 2)...
#   SUCCESS | L2: 255.60 | Queries: 18
# Attacking sample 218 (True: 0 → Target: 3)...
#   SUCCESS | L2: 410.39 | Queries: 30
# Attacking sample 218 (True: 0 → Target: 4)...
#   SUCCESS | L2: 721.02 | Queries: 60
# Attacking sample 218 (True: 0 → Target: 5)...
#   SUCCESS | L2: 400.40 | Queries: 32
# Attacking sample 218 (True: 0 → Target: 6)...
#   SUCCESS | L2: 666.95 | Queries: 56
# Attacking sample 218 (True: 0 → Target: 7)...
#   SUCCESS | L2: 349.51 | Queries: 26
# Attacking sample 218 (True: 0 → Target: 8)...
#   SUCCESS | L2: 404.74 | Queries: 26
# Attacking sample 218 (True: 0 → Target: 9)...
#   SUCCESS | L2: 353.69 | Queries: 24
# Attacking sample 219 (True: 0 → Target: 1)...
#   SUCCESS | L2: 1001.42 | Queries: 114
# Attacking sample 219 (True: 0 → Target: 2)...
#   SUCCESS | L2: 695.76 | Queries: 56
# Attacking sample 219 (True: 0 → Target: 3)...
#   SUCCESS | L2: 702.55 | Queries: 58
# Attacking sample 219 (True: 0 → Target: 4)...
#   SUCCESS | L2: 729.36 | Queries: 58
# Attacking sample 219 (True: 0 → Target: 5)...
#   SUCCESS | L2: 664.82 | Queries: 52
# Attacking sample 219 (True: 0 → Target: 6)...
#   SUCCESS | L2: 534.13 | Queries: 40
# Attacking sample 219 (True: 0 → Target: 7)...
#   SUCCESS | L2: 960.04 | Queries: 76
# Attacking sample 219 (True: 0 → Target: 8)...
#   SUCCESS | L2: 481.60 | Queries: 32
# Attacking sample 219 (True: 0 → Target: 9)...
#   SUCCESS | L2: 577.15 | Queries: 40
# Attacking sample 239 (True: 0 → Target: 1)...
#   FAIL | L2: 1221.62 | Queries: 200
# Attacking sample 239 (True: 0 → Target: 2)...
#   SUCCESS | L2: 912.90 | Queries: 68
# Attacking sample 239 (True: 0 → Target: 3)...
#   SUCCESS | L2: 889.34 | Queries: 74
# Attacking sample 239 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1045.48 | Queries: 92
# Attacking sample 239 (True: 0 → Target: 5)...
#   SUCCESS | L2: 678.61 | Queries: 56
# Attacking sample 239 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1027.51 | Queries: 86
# Attacking sample 239 (True: 0 → Target: 7)...
#   SUCCESS | L2: 874.20 | Queries: 80
# Attacking sample 239 (True: 0 → Target: 8)...
#   SUCCESS | L2: 899.10 | Queries: 66
# Attacking sample 239 (True: 0 → Target: 9)...
#   SUCCESS | L2: 845.90 | Queries: 72
# Attacking sample 246 (True: 0 → Target: 1)...
#   FAIL | L2: 1220.37 | Queries: 200
# Attacking sample 246 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1110.20 | Queries: 148
# Attacking sample 246 (True: 0 → Target: 3)...
#   SUCCESS | L2: 954.01 | Queries: 86
# Attacking sample 246 (True: 0 → Target: 4)...
#   FAIL | L2: 1306.54 | Queries: 200
# Attacking sample 246 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1026.22 | Queries: 90
# Attacking sample 246 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1358.84 | Queries: 146
# Attacking sample 246 (True: 0 → Target: 7)...
#   FAIL | L2: 1217.30 | Queries: 200
# Attacking sample 246 (True: 0 → Target: 8)...
#   SUCCESS | L2: 741.92 | Queries: 54
# Attacking sample 246 (True: 0 → Target: 9)...
#   SUCCESS | L2: 785.73 | Queries: 70
# Attacking sample 251 (True: 0 → Target: 1)...
#   FAIL | L2: 1278.61 | Queries: 200
# Attacking sample 251 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1065.57 | Queries: 88
# Attacking sample 251 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1072.57 | Queries: 88
# Attacking sample 251 (True: 0 → Target: 4)...
#   FAIL | L2: 1280.94 | Queries: 200
# Attacking sample 251 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1091.24 | Queries: 98
# Attacking sample 251 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1047.79 | Queries: 88
# Attacking sample 251 (True: 0 → Target: 7)...
#   FAIL | L2: 1283.23 | Queries: 200
# Attacking sample 251 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1110.23 | Queries: 84
# Attacking sample 251 (True: 0 → Target: 9)...
#   FAIL | L2: 1232.08 | Queries: 200
# Attacking sample 252 (True: 0 → Target: 1)...
#   FAIL | L2: 1217.38 | Queries: 200
# Attacking sample 252 (True: 0 → Target: 2)...
#   SUCCESS | L2: 723.70 | Queries: 56
# Attacking sample 252 (True: 0 → Target: 3)...
#   SUCCESS | L2: 944.28 | Queries: 80
# Attacking sample 252 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1039.93 | Queries: 96
# Attacking sample 252 (True: 0 → Target: 5)...
#   SUCCESS | L2: 838.30 | Queries: 78
# Attacking sample 252 (True: 0 → Target: 6)...
#   SUCCESS | L2: 792.16 | Queries: 62
# Attacking sample 252 (True: 0 → Target: 7)...
#   FAIL | L2: 1184.81 | Queries: 200
# Attacking sample 252 (True: 0 → Target: 8)...
#   SUCCESS | L2: 676.92 | Queries: 50
# Attacking sample 252 (True: 0 → Target: 9)...
#   SUCCESS | L2: 694.94 | Queries: 54
# Attacking sample 261 (True: 0 → Target: 1)...
#   FAIL | L2: 1167.86 | Queries: 200
# Attacking sample 261 (True: 0 → Target: 2)...
#   SUCCESS | L2: 985.74 | Queries: 80
# Attacking sample 261 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1243.41 | Queries: 102
# Attacking sample 261 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1083.90 | Queries: 106
# Attacking sample 261 (True: 0 → Target: 5)...
#   SUCCESS | L2: 925.15 | Queries: 74
# Attacking sample 261 (True: 0 → Target: 6)...
#   SUCCESS | L2: 867.82 | Queries: 66
# Attacking sample 261 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1011.43 | Queries: 88
# Attacking sample 261 (True: 0 → Target: 8)...
#   SUCCESS | L2: 857.25 | Queries: 62
# Attacking sample 261 (True: 0 → Target: 9)...
#   SUCCESS | L2: 671.86 | Queries: 50
# Attacking sample 273 (True: 0 → Target: 1)...
#   FAIL | L2: 1156.53 | Queries: 200
# Attacking sample 273 (True: 0 → Target: 2)...
#   SUCCESS | L2: 876.66 | Queries: 70
# Attacking sample 273 (True: 0 → Target: 3)...
#   SUCCESS | L2: 848.65 | Queries: 68
# Attacking sample 273 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1221.89 | Queries: 200
# Attacking sample 273 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1075.96 | Queries: 84
# Attacking sample 273 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1044.46 | Queries: 92
# Attacking sample 273 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1129.32 | Queries: 98
# Attacking sample 273 (True: 0 → Target: 8)...
#   SUCCESS | L2: 880.95 | Queries: 62
# Attacking sample 273 (True: 0 → Target: 9)...
#   FAIL | L2: 1138.52 | Queries: 200
# Attacking sample 282 (True: 0 → Target: 1)...
#   FAIL | L2: 1242.57 | Queries: 200
# Attacking sample 282 (True: 0 → Target: 2)...
#   SUCCESS | L2: 930.43 | Queries: 86
# Attacking sample 282 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1102.56 | Queries: 90
# Attacking sample 282 (True: 0 → Target: 4)...
#   FAIL | L2: 1277.20 | Queries: 200
# Attacking sample 282 (True: 0 → Target: 5)...
#   SUCCESS | L2: 933.48 | Queries: 88
# Attacking sample 282 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1003.10 | Queries: 76
# Attacking sample 282 (True: 0 → Target: 7)...
#   FAIL | L2: 1244.89 | Queries: 200
# Attacking sample 282 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1199.00 | Queries: 110
# Attacking sample 282 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1136.18 | Queries: 134
# Attacking sample 295 (True: 0 → Target: 1)...
#   FAIL | L2: 1176.26 | Queries: 200
# Attacking sample 295 (True: 0 → Target: 2)...
#   SUCCESS | L2: 821.34 | Queries: 64
# Attacking sample 295 (True: 0 → Target: 3)...
#   SUCCESS | L2: 909.55 | Queries: 72
# Attacking sample 295 (True: 0 → Target: 4)...
#   SUCCESS | L2: 868.30 | Queries: 68
# Attacking sample 295 (True: 0 → Target: 5)...
#   SUCCESS | L2: 831.30 | Queries: 64
# Attacking sample 295 (True: 0 → Target: 6)...
#   SUCCESS | L2: 623.50 | Queries: 46
# Attacking sample 295 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1018.17 | Queries: 82
# Attacking sample 295 (True: 0 → Target: 8)...
#   SUCCESS | L2: 777.94 | Queries: 54
# Attacking sample 295 (True: 0 → Target: 9)...
#   SUCCESS | L2: 774.55 | Queries: 56
# Attacking sample 297 (True: 0 → Target: 1)...
#   FAIL | L2: 1253.53 | Queries: 200
# Attacking sample 297 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1082.15 | Queries: 88
# Attacking sample 297 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1020.80 | Queries: 90
# Attacking sample 297 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1069.78 | Queries: 102
# Attacking sample 297 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1171.02 | Queries: 106
# Attacking sample 297 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1037.66 | Queries: 80
# Attacking sample 297 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1063.34 | Queries: 94
# Attacking sample 297 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1040.41 | Queries: 74
# Attacking sample 297 (True: 0 → Target: 9)...
#   SUCCESS | L2: 982.19 | Queries: 82
# Attacking sample 315 (True: 0 → Target: 1)...
#   FAIL | L2: 1246.72 | Queries: 200
# Attacking sample 315 (True: 0 → Target: 2)...
#   SUCCESS | L2: 926.29 | Queries: 72
# Attacking sample 315 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1079.79 | Queries: 94
# Attacking sample 315 (True: 0 → Target: 4)...
#   SUCCESS | L2: 932.40 | Queries: 88
# Attacking sample 315 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1175.57 | Queries: 102
# Attacking sample 315 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1248.47 | Queries: 130
# Attacking sample 315 (True: 0 → Target: 7)...
#   SUCCESS | L2: 942.00 | Queries: 82
# Attacking sample 315 (True: 0 → Target: 8)...
#   SUCCESS | L2: 986.65 | Queries: 72
# Attacking sample 315 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1000.20 | Queries: 96
# Attacking sample 322 (True: 0 → Target: 1)...
#   FAIL | L2: 1280.77 | Queries: 200
# Attacking sample 322 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1222.60 | Queries: 114
# Attacking sample 322 (True: 0 → Target: 3)...
#   SUCCESS | L2: 937.97 | Queries: 74
# Attacking sample 322 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1353.27 | Queries: 132
# Attacking sample 322 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1010.00 | Queries: 86
# Attacking sample 322 (True: 0 → Target: 6)...
#   SUCCESS | L2: 993.94 | Queries: 82
# Attacking sample 322 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1107.58 | Queries: 96
# Attacking sample 322 (True: 0 → Target: 8)...
#   SUCCESS | L2: 812.50 | Queries: 58
# Attacking sample 322 (True: 0 → Target: 9)...
#   SUCCESS | L2: 885.16 | Queries: 66
# Attacking sample 338 (True: 0 → Target: 1)...
#   FAIL | L2: 1173.59 | Queries: 200
# Attacking sample 338 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1242.27 | Queries: 118
# Attacking sample 338 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1300.41 | Queries: 106
# Attacking sample 338 (True: 0 → Target: 4)...
#   FAIL | L2: 1258.27 | Queries: 200
# Attacking sample 338 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1193.02 | Queries: 104
# Attacking sample 338 (True: 0 → Target: 6)...
#   SUCCESS | L2: 827.08 | Queries: 70
# Attacking sample 338 (True: 0 → Target: 7)...
#   FAIL | L2: 1229.29 | Queries: 200
# Attacking sample 338 (True: 0 → Target: 8)...
#   SUCCESS | L2: 971.67 | Queries: 74
# Attacking sample 338 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1222.23 | Queries: 98
# Attacking sample 339 (True: 0 → Target: 1)...
#   FAIL | L2: 1212.71 | Queries: 200
# Attacking sample 339 (True: 0 → Target: 2)...
#   SUCCESS | L2: 733.96 | Queries: 62
# Attacking sample 339 (True: 0 → Target: 3)...
#   SUCCESS | L2: 795.09 | Queries: 66
# Attacking sample 339 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1178.32 | Queries: 120
# Attacking sample 339 (True: 0 → Target: 5)...
#   SUCCESS | L2: 542.61 | Queries: 42
# Attacking sample 339 (True: 0 → Target: 6)...
#   SUCCESS | L2: 824.72 | Queries: 62
# Attacking sample 339 (True: 0 → Target: 7)...
#   SUCCESS | L2: 901.84 | Queries: 76
# Attacking sample 339 (True: 0 → Target: 8)...
#   SUCCESS | L2: 802.84 | Queries: 62
# Attacking sample 339 (True: 0 → Target: 9)...
#   SUCCESS | L2: 509.40 | Queries: 38
# Attacking sample 354 (True: 0 → Target: 1)...
#   FAIL | L2: 1196.10 | Queries: 200
# Attacking sample 354 (True: 0 → Target: 2)...
#   SUCCESS | L2: 585.33 | Queries: 44
# Attacking sample 354 (True: 0 → Target: 3)...
#   SUCCESS | L2: 684.16 | Queries: 50
# Attacking sample 354 (True: 0 → Target: 4)...
#   SUCCESS | L2: 762.00 | Queries: 62
# Attacking sample 354 (True: 0 → Target: 5)...
#   SUCCESS | L2: 612.85 | Queries: 48
# Attacking sample 354 (True: 0 → Target: 6)...
#   SUCCESS | L2: 810.39 | Queries: 60
# Attacking sample 354 (True: 0 → Target: 7)...
#   SUCCESS | L2: 764.32 | Queries: 64
# Attacking sample 354 (True: 0 → Target: 8)...
#   SUCCESS | L2: 608.71 | Queries: 42
# Attacking sample 354 (True: 0 → Target: 9)...
#   SUCCESS | L2: 499.93 | Queries: 36
# Attacking sample 356 (True: 0 → Target: 1)...
#   SUCCESS | L2: 1114.14 | Queries: 146
# Attacking sample 356 (True: 0 → Target: 2)...
#   SUCCESS | L2: 646.87 | Queries: 48
# Attacking sample 356 (True: 0 → Target: 3)...
#   SUCCESS | L2: 651.11 | Queries: 48
# Attacking sample 356 (True: 0 → Target: 4)...
#   SUCCESS | L2: 532.37 | Queries: 44
# Attacking sample 356 (True: 0 → Target: 5)...
#   SUCCESS | L2: 684.48 | Queries: 58
# Attacking sample 356 (True: 0 → Target: 6)...
#   SUCCESS | L2: 993.16 | Queries: 80
# Attacking sample 356 (True: 0 → Target: 7)...
#   SUCCESS | L2: 550.09 | Queries: 44
# Attacking sample 356 (True: 0 → Target: 8)...
#   SUCCESS | L2: 659.23 | Queries: 46
# Attacking sample 356 (True: 0 → Target: 9)...
#   SUCCESS | L2: 743.62 | Queries: 56
# Attacking sample 357 (True: 0 → Target: 1)...
#   SUCCESS | L2: 1061.56 | Queries: 126
# Attacking sample 357 (True: 0 → Target: 2)...
#   SUCCESS | L2: 205.76 | Queries: 14
# Attacking sample 357 (True: 0 → Target: 3)...
#   SUCCESS | L2: 500.07 | Queries: 42
# Attacking sample 357 (True: 0 → Target: 4)...
#   SUCCESS | L2: 309.27 | Queries: 22
# Attacking sample 357 (True: 0 → Target: 5)...
#   SUCCESS | L2: 745.65 | Queries: 74
# Attacking sample 357 (True: 0 → Target: 6)...
#   SUCCESS | L2: 316.89 | Queries: 24
# Attacking sample 357 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1016.69 | Queries: 110
# Attacking sample 357 (True: 0 → Target: 8)...
#   SUCCESS | L2: 260.67 | Queries: 18
# Attacking sample 357 (True: 0 → Target: 9)...
#   SUCCESS | L2: 960.72 | Queries: 82
# Attacking sample 359 (True: 0 → Target: 1)...
#   SUCCESS | L2: 1004.11 | Queries: 108
# Attacking sample 359 (True: 0 → Target: 2)...
#   SUCCESS | L2: 453.23 | Queries: 38
# Attacking sample 359 (True: 0 → Target: 3)...
#   SUCCESS | L2: 709.73 | Queries: 62
# Attacking sample 359 (True: 0 → Target: 4)...
#   SUCCESS | L2: 731.59 | Queries: 60
# Attacking sample 359 (True: 0 → Target: 5)...
#   SUCCESS | L2: 631.14 | Queries: 50
# Attacking sample 359 (True: 0 → Target: 6)...
#   SUCCESS | L2: 703.24 | Queries: 60
# Attacking sample 359 (True: 0 → Target: 7)...
#   SUCCESS | L2: 899.02 | Queries: 76
# Attacking sample 359 (True: 0 → Target: 8)...
#   SUCCESS | L2: 288.90 | Queries: 20
# Attacking sample 359 (True: 0 → Target: 9)...
#   SUCCESS | L2: 603.50 | Queries: 48
# Attacking sample 377 (True: 0 → Target: 1)...
#   FAIL | L2: 1076.62 | Queries: 200
# Attacking sample 377 (True: 0 → Target: 2)...
#   SUCCESS | L2: 801.44 | Queries: 62
# Attacking sample 377 (True: 0 → Target: 3)...
#   SUCCESS | L2: 949.48 | Queries: 76
# Attacking sample 377 (True: 0 → Target: 4)...
#   FAIL | L2: 1104.90 | Queries: 200
# Attacking sample 377 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1018.87 | Queries: 96
# Attacking sample 377 (True: 0 → Target: 6)...
#   SUCCESS | L2: 913.07 | Queries: 86
# Attacking sample 377 (True: 0 → Target: 7)...
#   FAIL | L2: 1221.91 | Queries: 200
# Attacking sample 377 (True: 0 → Target: 8)...
#   SUCCESS | L2: 786.23 | Queries: 54
# Attacking sample 377 (True: 0 → Target: 9)...
#   FAIL | L2: 1238.08 | Queries: 200
# Attacking sample 379 (True: 0 → Target: 1)...
#   FAIL | L2: 1236.67 | Queries: 200
# Attacking sample 379 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1047.86 | Queries: 92
# Attacking sample 379 (True: 0 → Target: 3)...
#   SUCCESS | L2: 728.30 | Queries: 58
# Attacking sample 379 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1102.70 | Queries: 98
# Attacking sample 379 (True: 0 → Target: 5)...
#   SUCCESS | L2: 832.52 | Queries: 68
# Attacking sample 379 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1148.39 | Queries: 98
# Attacking sample 379 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1135.64 | Queries: 98
# Attacking sample 379 (True: 0 → Target: 8)...
#   SUCCESS | L2: 706.38 | Queries: 52
# Attacking sample 379 (True: 0 → Target: 9)...
#   SUCCESS | L2: 733.84 | Queries: 62
# Attacking sample 387 (True: 0 → Target: 1)...
#   FAIL | L2: 1179.67 | Queries: 200
# Attacking sample 387 (True: 0 → Target: 2)...
#   SUCCESS | L2: 869.19 | Queries: 74
# Attacking sample 387 (True: 0 → Target: 3)...
#   SUCCESS | L2: 960.01 | Queries: 80
# Attacking sample 387 (True: 0 → Target: 4)...
#   SUCCESS | L2: 653.14 | Queries: 56
# Attacking sample 387 (True: 0 → Target: 5)...
#   SUCCESS | L2: 932.43 | Queries: 80
# Attacking sample 387 (True: 0 → Target: 6)...
#   SUCCESS | L2: 467.90 | Queries: 34
# Attacking sample 387 (True: 0 → Target: 7)...
#   SUCCESS | L2: 850.44 | Queries: 78
# Attacking sample 387 (True: 0 → Target: 8)...
#   SUCCESS | L2: 931.07 | Queries: 66
# Attacking sample 387 (True: 0 → Target: 9)...
#   SUCCESS | L2: 650.21 | Queries: 50
# Attacking sample 390 (True: 0 → Target: 1)...
#   FAIL | L2: 1188.76 | Queries: 200
# Attacking sample 390 (True: 0 → Target: 2)...
#   SUCCESS | L2: 790.51 | Queries: 58
# Attacking sample 390 (True: 0 → Target: 3)...
#   SUCCESS | L2: 992.28 | Queries: 74
# Attacking sample 390 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1042.95 | Queries: 88
# Attacking sample 390 (True: 0 → Target: 5)...
#   SUCCESS | L2: 956.03 | Queries: 76
# Attacking sample 390 (True: 0 → Target: 6)...
#   SUCCESS | L2: 790.04 | Queries: 60
# Attacking sample 390 (True: 0 → Target: 7)...
#   SUCCESS | L2: 993.32 | Queries: 86
# Attacking sample 390 (True: 0 → Target: 8)...
#   SUCCESS | L2: 867.65 | Queries: 62
# Attacking sample 390 (True: 0 → Target: 9)...
#   SUCCESS | L2: 749.16 | Queries: 54
# Attacking sample 394 (True: 0 → Target: 1)...
#   FAIL | L2: 1089.15 | Queries: 200
# Attacking sample 394 (True: 0 → Target: 2)...
#   SUCCESS | L2: 796.32 | Queries: 72
# Attacking sample 394 (True: 0 → Target: 3)...
#   SUCCESS | L2: 866.67 | Queries: 72
# Attacking sample 394 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1288.03 | Queries: 186
# Attacking sample 394 (True: 0 → Target: 5)...
#   SUCCESS | L2: 979.84 | Queries: 90
# Attacking sample 394 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1124.88 | Queries: 94
# Attacking sample 394 (True: 0 → Target: 7)...
#   SUCCESS | L2: 998.84 | Queries: 92
# Attacking sample 394 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1295.59 | Queries: 136
# Attacking sample 394 (True: 0 → Target: 9)...
#   SUCCESS | L2: 784.74 | Queries: 66
# Attacking sample 408 (True: 0 → Target: 1)...
#   FAIL | L2: 1241.46 | Queries: 200
# Attacking sample 408 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1418.77 | Queries: 160
# Attacking sample 408 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1342.91 | Queries: 190
# Attacking sample 408 (True: 0 → Target: 4)...
#   SUCCESS | L2: 695.49 | Queries: 58
# Attacking sample 408 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1190.57 | Queries: 140
# Attacking sample 408 (True: 0 → Target: 6)...
#   SUCCESS | L2: 36.58 | Queries: 2
# Attacking sample 408 (True: 0 → Target: 7)...
#   FAIL | L2: 1224.40 | Queries: 200
# Attacking sample 408 (True: 0 → Target: 8)...
#   SUCCESS | L2: 922.08 | Queries: 62
# Attacking sample 408 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1300.94 | Queries: 98
# Attacking sample 423 (True: 0 → Target: 1)...
#   FAIL | L2: 1272.26 | Queries: 200
# Attacking sample 423 (True: 0 → Target: 2)...
#   SUCCESS | L2: 832.22 | Queries: 66
# Attacking sample 423 (True: 0 → Target: 3)...
#   SUCCESS | L2: 926.32 | Queries: 78
# Attacking sample 423 (True: 0 → Target: 4)...
#   SUCCESS | L2: 986.17 | Queries: 88
# Attacking sample 423 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1128.32 | Queries: 100
# Attacking sample 423 (True: 0 → Target: 6)...
#   SUCCESS | L2: 963.03 | Queries: 88
# Attacking sample 423 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1009.71 | Queries: 88
# Attacking sample 423 (True: 0 → Target: 8)...
#   SUCCESS | L2: 936.45 | Queries: 70
# Attacking sample 423 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1050.84 | Queries: 120
# Attacking sample 434 (True: 0 → Target: 1)...
#   FAIL | L2: 1099.85 | Queries: 200
# Attacking sample 434 (True: 0 → Target: 2)...
#   SUCCESS | L2: 693.32 | Queries: 54
# Attacking sample 434 (True: 0 → Target: 3)...
#   SUCCESS | L2: 695.18 | Queries: 50
# Attacking sample 434 (True: 0 → Target: 4)...
#   SUCCESS | L2: 966.47 | Queries: 92
# Attacking sample 434 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1106.47 | Queries: 96
# Attacking sample 434 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1196.14 | Queries: 156
# Attacking sample 434 (True: 0 → Target: 7)...
#   FAIL | L2: 1125.06 | Queries: 200
# Attacking sample 434 (True: 0 → Target: 8)...
#   SUCCESS | L2: 824.44 | Queries: 58
# Attacking sample 434 (True: 0 → Target: 9)...
#   FAIL | L2: 1190.25 | Queries: 200
# Attacking sample 436 (True: 0 → Target: 1)...
#   FAIL | L2: 1106.69 | Queries: 200
# Attacking sample 436 (True: 0 → Target: 2)...
#   SUCCESS | L2: 800.39 | Queries: 64
# Attacking sample 436 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1104.43 | Queries: 88
# Attacking sample 436 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1127.89 | Queries: 108
# Attacking sample 436 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1144.36 | Queries: 92
# Attacking sample 436 (True: 0 → Target: 6)...
#   SUCCESS | L2: 748.47 | Queries: 62
# Attacking sample 436 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1177.81 | Queries: 194
# Attacking sample 436 (True: 0 → Target: 8)...
#   SUCCESS | L2: 651.59 | Queries: 46
# Attacking sample 436 (True: 0 → Target: 9)...
#   SUCCESS | L2: 933.55 | Queries: 72
# Attacking sample 454 (True: 0 → Target: 1)...
#   FAIL | L2: 1153.03 | Queries: 200
# Attacking sample 454 (True: 0 → Target: 2)...
#   SUCCESS | L2: 587.40 | Queries: 42
# Attacking sample 454 (True: 0 → Target: 3)...
#   SUCCESS | L2: 568.03 | Queries: 42
# Attacking sample 454 (True: 0 → Target: 4)...
#   FAIL | L2: 1250.60 | Queries: 200
# Attacking sample 454 (True: 0 → Target: 5)...
#   SUCCESS | L2: 784.56 | Queries: 62
# Attacking sample 454 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1200.81 | Queries: 94
# Attacking sample 454 (True: 0 → Target: 7)...
#   FAIL | L2: 1040.18 | Queries: 200
# Attacking sample 454 (True: 0 → Target: 8)...
#   SUCCESS | L2: 551.65 | Queries: 38
# Attacking sample 454 (True: 0 → Target: 9)...
#   SUCCESS | L2: 932.48 | Queries: 86
# Attacking sample 462 (True: 0 → Target: 1)...
#   FAIL | L2: 1109.75 | Queries: 200
# Attacking sample 462 (True: 0 → Target: 2)...
#   SUCCESS | L2: 802.95 | Queries: 70
# Attacking sample 462 (True: 0 → Target: 3)...
#   SUCCESS | L2: 736.91 | Queries: 60
# Attacking sample 462 (True: 0 → Target: 4)...
#   FAIL | L2: 1190.98 | Queries: 200
# Attacking sample 462 (True: 0 → Target: 5)...
#   SUCCESS | L2: 802.64 | Queries: 74
# Attacking sample 462 (True: 0 → Target: 6)...
#   SUCCESS | L2: 984.58 | Queries: 80
# Attacking sample 462 (True: 0 → Target: 7)...
#   FAIL | L2: 1138.32 | Queries: 200
# Attacking sample 462 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1159.22 | Queries: 114
# Attacking sample 462 (True: 0 → Target: 9)...
#   SUCCESS | L2: 693.67 | Queries: 66
# Attacking sample 476 (True: 0 → Target: 1)...
#   SUCCESS | L2: 916.89 | Queries: 88
# Attacking sample 476 (True: 0 → Target: 2)...
#   SUCCESS | L2: 451.29 | Queries: 34
# Attacking sample 476 (True: 0 → Target: 3)...
#   SUCCESS | L2: 780.96 | Queries: 60
# Attacking sample 476 (True: 0 → Target: 4)...
#   SUCCESS | L2: 431.54 | Queries: 32
# Attacking sample 476 (True: 0 → Target: 5)...
#   SUCCESS | L2: 798.20 | Queries: 64
# Attacking sample 476 (True: 0 → Target: 6)...
#   SUCCESS | L2: 390.75 | Queries: 28
# Attacking sample 476 (True: 0 → Target: 7)...
#   SUCCESS | L2: 646.04 | Queries: 54
# Attacking sample 476 (True: 0 → Target: 8)...
#   SUCCESS | L2: 458.68 | Queries: 32
# Attacking sample 476 (True: 0 → Target: 9)...
#   SUCCESS | L2: 499.79 | Queries: 36
# Attacking sample 497 (True: 0 → Target: 1)...
#   FAIL | L2: 1221.81 | Queries: 200
# Attacking sample 497 (True: 0 → Target: 2)...
#   SUCCESS | L2: 802.72 | Queries: 66
# Attacking sample 497 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1122.28 | Queries: 94
# Attacking sample 497 (True: 0 → Target: 4)...
#   FAIL | L2: 1176.38 | Queries: 200
# Attacking sample 497 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1332.83 | Queries: 190
# Attacking sample 497 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1119.42 | Queries: 92
# Attacking sample 497 (True: 0 → Target: 7)...
#   FAIL | L2: 1214.70 | Queries: 200
# Attacking sample 497 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1054.41 | Queries: 80
# Attacking sample 497 (True: 0 → Target: 9)...
#   FAIL | L2: 1185.39 | Queries: 200
# Attacking sample 509 (True: 0 → Target: 1)...
#   SUCCESS | L2: 1084.91 | Queries: 146
# Attacking sample 509 (True: 0 → Target: 2)...
#   SUCCESS | L2: 461.60 | Queries: 36
# Attacking sample 509 (True: 0 → Target: 3)...
#   SUCCESS | L2: 716.07 | Queries: 58
# Attacking sample 509 (True: 0 → Target: 4)...
#   SUCCESS | L2: 589.02 | Queries: 46
# Attacking sample 509 (True: 0 → Target: 5)...
#   SUCCESS | L2: 604.81 | Queries: 50
# Attacking sample 509 (True: 0 → Target: 6)...
#   SUCCESS | L2: 362.13 | Queries: 26
# Attacking sample 509 (True: 0 → Target: 7)...
#   SUCCESS | L2: 514.27 | Queries: 42
# Attacking sample 509 (True: 0 → Target: 8)...
#   SUCCESS | L2: 580.59 | Queries: 40
# Attacking sample 509 (True: 0 → Target: 9)...
#   SUCCESS | L2: 476.42 | Queries: 34
# Attacking sample 511 (True: 0 → Target: 1)...
#   FAIL | L2: 1204.70 | Queries: 200
# Attacking sample 511 (True: 0 → Target: 2)...
#   SUCCESS | L2: 832.30 | Queries: 68
# Attacking sample 511 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1235.43 | Queries: 108
# Attacking sample 511 (True: 0 → Target: 4)...
#   FAIL | L2: 1190.69 | Queries: 200
# Attacking sample 511 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1248.83 | Queries: 136
# Attacking sample 511 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1017.17 | Queries: 80
# Attacking sample 511 (True: 0 → Target: 7)...
#   FAIL | L2: 1203.33 | Queries: 200
# Attacking sample 511 (True: 0 → Target: 8)...
#   SUCCESS | L2: 982.39 | Queries: 70
# Attacking sample 511 (True: 0 → Target: 9)...
#   FAIL | L2: 1266.15 | Queries: 200
# Attacking sample 521 (True: 0 → Target: 1)...
#   FAIL | L2: 1081.97 | Queries: 200
# Attacking sample 521 (True: 0 → Target: 2)...
#   SUCCESS | L2: 309.56 | Queries: 22
# Attacking sample 521 (True: 0 → Target: 3)...
#   SUCCESS | L2: 698.68 | Queries: 56
# Attacking sample 521 (True: 0 → Target: 4)...
#   SUCCESS | L2: 547.41 | Queries: 48
# Attacking sample 521 (True: 0 → Target: 5)...
#   SUCCESS | L2: 825.30 | Queries: 74
# Attacking sample 521 (True: 0 → Target: 6)...
#   SUCCESS | L2: 719.09 | Queries: 58
# Attacking sample 521 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1037.50 | Queries: 98
# Attacking sample 521 (True: 0 → Target: 8)...
#   SUCCESS | L2: 504.66 | Queries: 34
# Attacking sample 521 (True: 0 → Target: 9)...
#   SUCCESS | L2: 896.26 | Queries: 80
# Attacking sample 523 (True: 0 → Target: 1)...
#   FAIL | L2: 1221.76 | Queries: 200
# Attacking sample 523 (True: 0 → Target: 2)...
#   SUCCESS | L2: 825.77 | Queries: 62
# Attacking sample 523 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1085.48 | Queries: 84
# Attacking sample 523 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1026.61 | Queries: 86
# Attacking sample 523 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1329.82 | Queries: 150
# Attacking sample 523 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1235.05 | Queries: 102
# Attacking sample 523 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1176.35 | Queries: 100
# Attacking sample 523 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1167.75 | Queries: 86
# Attacking sample 523 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1081.71 | Queries: 90
# Attacking sample 524 (True: 0 → Target: 1)...
#   FAIL | L2: 1197.22 | Queries: 200
# Attacking sample 524 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1035.39 | Queries: 86
# Attacking sample 524 (True: 0 → Target: 3)...
#   SUCCESS | L2: 748.56 | Queries: 58
# Attacking sample 524 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1104.25 | Queries: 94
# Attacking sample 524 (True: 0 → Target: 5)...
#   SUCCESS | L2: 825.97 | Queries: 70
# Attacking sample 524 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1065.12 | Queries: 90
# Attacking sample 524 (True: 0 → Target: 7)...
#   FAIL | L2: 1145.64 | Queries: 200
# Attacking sample 524 (True: 0 → Target: 8)...
#   SUCCESS | L2: 861.98 | Queries: 64
# Attacking sample 524 (True: 0 → Target: 9)...
#   SUCCESS | L2: 856.44 | Queries: 74
# Attacking sample 534 (True: 0 → Target: 1)...
#   FAIL | L2: 1201.61 | Queries: 200
# Attacking sample 534 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1259.74 | Queries: 134
# Attacking sample 534 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1229.53 | Queries: 104
# Attacking sample 534 (True: 0 → Target: 4)...
#   FAIL | L2: 1310.76 | Queries: 200
# Attacking sample 534 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1109.29 | Queries: 130
# Attacking sample 534 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1191.35 | Queries: 94
# Attacking sample 534 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1086.56 | Queries: 102
# Attacking sample 534 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1386.78 | Queries: 152
# Attacking sample 534 (True: 0 → Target: 9)...
# ...
# Attacking sample 898 (True: 9 → Target: 2)...
#   SUCCESS | L2: 723.11 | Queries: 56
# Attacking sample 898 (True: 9 → Target: 3)...
#   SUCCESS | L2: 640.82 | Queries: 48
# Attacking sample 898 (True: 9 → Target: 4)...
#   SUCCESS | L2: 685.92 | Queries: 54
# Attacking sample 898 (True: 9 → Target: 5)...
#   SUCCESS | L2: 833.54 | Queries: 64
# Attacking sample 898 (True: 9 → Target: 6)...
#   FAIL | L2: 1331.83 | Queries: 200
# Attacking sample 898 (True: 9 → Target: 7)...
#   SUCCESS | L2: 638.28 | Queries: 50
# Attacking sample 898 (True: 9 → Target: 8)...
#   SUCCESS | L2: 401.70 | Queries: 28
# Attacking sample 912 (True: 9 → Target: 0)...
#   SUCCESS | L2: 1063.68 | Queries: 90
# Attacking sample 912 (True: 9 → Target: 1)...
#   FAIL | L2: 1278.52 | Queries: 200
# Attacking sample 912 (True: 9 → Target: 2)...
#   SUCCESS | L2: 907.51 | Queries: 70
# Attacking sample 912 (True: 9 → Target: 3)...
#   SUCCESS | L2: 803.32 | Queries: 60
# Attacking sample 912 (True: 9 → Target: 4)...
#   SUCCESS | L2: 813.98 | Queries: 58
# Attacking sample 912 (True: 9 → Target: 5)...
#   SUCCESS | L2: 659.96 | Queries: 50
# Attacking sample 912 (True: 9 → Target: 6)...
#   SUCCESS | L2: 923.01 | Queries: 68
# Attacking sample 912 (True: 9 → Target: 7)...
#   SUCCESS | L2: 796.69 | Queries: 62
# Attacking sample 912 (True: 9 → Target: 8)...
#   SUCCESS | L2: 532.80 | Queries: 36
# Attacking sample 921 (True: 9 → Target: 0)...
#   SUCCESS | L2: 1050.29 | Queries: 90
# Attacking sample 921 (True: 9 → Target: 1)...
#   FAIL | L2: 1317.10 | Queries: 200
# Attacking sample 921 (True: 9 → Target: 2)...
#   FAIL | L2: 1345.70 | Queries: 200
# Attacking sample 921 (True: 9 → Target: 3)...
#   SUCCESS | L2: 1036.58 | Queries: 86
# Attacking sample 921 (True: 9 → Target: 4)...
#   SUCCESS | L2: 774.89 | Queries: 62
# Attacking sample 921 (True: 9 → Target: 5)...
#   SUCCESS | L2: 653.74 | Queries: 46
# Attacking sample 921 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1151.21 | Queries: 98
# Attacking sample 921 (True: 9 → Target: 7)...
#   SUCCESS | L2: 796.01 | Queries: 68
# Attacking sample 921 (True: 9 → Target: 8)...
#   SUCCESS | L2: 890.36 | Queries: 66
# Attacking sample 935 (True: 9 → Target: 0)...
#   SUCCESS | L2: 833.47 | Queries: 64
# Attacking sample 935 (True: 9 → Target: 1)...
#   SUCCESS | L2: 1158.30 | Queries: 164
# Attacking sample 935 (True: 9 → Target: 2)...
#   SUCCESS | L2: 1009.83 | Queries: 86
# Attacking sample 935 (True: 9 → Target: 3)...
#   SUCCESS | L2: 682.23 | Queries: 54
# Attacking sample 935 (True: 9 → Target: 4)...
#   SUCCESS | L2: 543.79 | Queries: 42
# Attacking sample 935 (True: 9 → Target: 5)...
#   SUCCESS | L2: 958.71 | Queries: 72
# Attacking sample 935 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1188.34 | Queries: 94
# Attacking sample 935 (True: 9 → Target: 7)...
#   SUCCESS | L2: 713.80 | Queries: 60
# Attacking sample 935 (True: 9 → Target: 8)...
#   SUCCESS | L2: 683.14 | Queries: 48
# Attacking sample 937 (True: 9 → Target: 0)...
#   SUCCESS | L2: 881.22 | Queries: 72
# Attacking sample 937 (True: 9 → Target: 1)...
#   FAIL | L2: 1194.59 | Queries: 200
# Attacking sample 937 (True: 9 → Target: 2)...
#   SUCCESS | L2: 1092.92 | Queries: 92
# Attacking sample 937 (True: 9 → Target: 3)...
#   SUCCESS | L2: 767.90 | Queries: 60
# Attacking sample 937 (True: 9 → Target: 4)...
#   SUCCESS | L2: 548.55 | Queries: 44
# Attacking sample 937 (True: 9 → Target: 5)...
#   SUCCESS | L2: 910.90 | Queries: 76
# Attacking sample 937 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1016.84 | Queries: 80
# Attacking sample 937 (True: 9 → Target: 7)...
#   SUCCESS | L2: 652.33 | Queries: 56
# Attacking sample 937 (True: 9 → Target: 8)...
#   SUCCESS | L2: 863.88 | Queries: 60
# Attacking sample 941 (True: 9 → Target: 0)...
#   SUCCESS | L2: 1061.12 | Queries: 84
# Attacking sample 941 (True: 9 → Target: 1)...
#   FAIL | L2: 1256.62 | Queries: 200
# Attacking sample 941 (True: 9 → Target: 2)...
#   FAIL | L2: 1312.73 | Queries: 200
# Attacking sample 941 (True: 9 → Target: 3)...
#   SUCCESS | L2: 945.87 | Queries: 72
# Attacking sample 941 (True: 9 → Target: 4)...
#   SUCCESS | L2: 600.90 | Queries: 46
# Attacking sample 941 (True: 9 → Target: 5)...
#   SUCCESS | L2: 710.21 | Queries: 52
# Attacking sample 941 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1131.92 | Queries: 96
# Attacking sample 941 (True: 9 → Target: 7)...
#   SUCCESS | L2: 932.33 | Queries: 86
# Attacking sample 941 (True: 9 → Target: 8)...
#   SUCCESS | L2: 814.64 | Queries: 54
# Attacking sample 973 (True: 9 → Target: 0)...
#   SUCCESS | L2: 1004.20 | Queries: 84
# Attacking sample 973 (True: 9 → Target: 1)...
#   SUCCESS | L2: 1110.62 | Queries: 120
# Attacking sample 973 (True: 9 → Target: 2)...
#   SUCCESS | L2: 1059.78 | Queries: 90
# Attacking sample 973 (True: 9 → Target: 3)...
#   SUCCESS | L2: 939.37 | Queries: 74
# Attacking sample 973 (True: 9 → Target: 4)...
#   SUCCESS | L2: 758.63 | Queries: 62
# Attacking sample 973 (True: 9 → Target: 5)...
#   SUCCESS | L2: 873.20 | Queries: 62
# Attacking sample 973 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1256.93 | Queries: 102
# Attacking sample 973 (True: 9 → Target: 7)...
#   SUCCESS | L2: 703.24 | Queries: 56
# Attacking sample 973 (True: 9 → Target: 8)...
#   SUCCESS | L2: 937.87 | Queries: 68
# Attacking sample 974 (True: 9 → Target: 0)...
#   SUCCESS | L2: 1127.79 | Queries: 84
# Attacking sample 974 (True: 9 → Target: 1)...
#   FAIL | L2: 1275.14 | Queries: 200
# Attacking sample 974 (True: 9 → Target: 2)...
#   SUCCESS | L2: 1168.83 | Queries: 92
# Attacking sample 974 (True: 9 → Target: 3)...
#   SUCCESS | L2: 1042.06 | Queries: 88
# Attacking sample 974 (True: 9 → Target: 4)...
#   SUCCESS | L2: 761.46 | Queries: 60
# Attacking sample 974 (True: 9 → Target: 5)...
#   SUCCESS | L2: 1276.88 | Queries: 124
# Attacking sample 974 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1241.42 | Queries: 92
# Attacking sample 974 (True: 9 → Target: 7)...
#   SUCCESS | L2: 1013.34 | Queries: 86
# Attacking sample 974 (True: 9 → Target: 8)...
#   SUCCESS | L2: 979.28 | Queries: 70
# Attacking sample 979 (True: 9 → Target: 0)...
#   SUCCESS | L2: 976.22 | Queries: 78
# Attacking sample 979 (True: 9 → Target: 1)...
#   FAIL | L2: 1169.81 | Queries: 200
# Attacking sample 979 (True: 9 → Target: 2)...
#   SUCCESS | L2: 953.25 | Queries: 80
# Attacking sample 979 (True: 9 → Target: 3)...
#   SUCCESS | L2: 971.07 | Queries: 80
# Attacking sample 979 (True: 9 → Target: 4)...
#   SUCCESS | L2: 760.49 | Queries: 58
# Attacking sample 979 (True: 9 → Target: 5)...
#   SUCCESS | L2: 1323.43 | Queries: 146
# Attacking sample 979 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1244.47 | Queries: 114
# Attacking sample 979 (True: 9 → Target: 7)...
#   SUCCESS | L2: 897.60 | Queries: 72
# Attacking sample 979 (True: 9 → Target: 8)...
#   SUCCESS | L2: 657.75 | Queries: 46
# Attacking sample 988 (True: 9 → Target: 0)...
#   SUCCESS | L2: 917.13 | Queries: 74
# Attacking sample 988 (True: 9 → Target: 1)...
#   SUCCESS | L2: 1159.62 | Queries: 126
# Attacking sample 988 (True: 9 → Target: 2)...
#   SUCCESS | L2: 1074.77 | Queries: 92
# Attacking sample 988 (True: 9 → Target: 3)...
#   SUCCESS | L2: 752.45 | Queries: 56
# Attacking sample 988 (True: 9 → Target: 4)...
#   SUCCESS | L2: 862.59 | Queries: 68
# Attacking sample 988 (True: 9 → Target: 5)...
#   SUCCESS | L2: 707.55 | Queries: 50
# Attacking sample 988 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1203.58 | Queries: 106
# Attacking sample 988 (True: 9 → Target: 7)...
#   SUCCESS | L2: 614.50 | Queries: 48
# Attacking sample 988 (True: 9 → Target: 8)...
#   SUCCESS | L2: 717.56 | Queries: 52
# Attacking sample 1003 (True: 9 → Target: 0)...
#   SUCCESS | L2: 1080.40 | Queries: 94
# Attacking sample 1003 (True: 9 → Target: 1)...
#   SUCCESS | L2: 1232.78 | Queries: 174
# Attacking sample 1003 (True: 9 → Target: 2)...
#   SUCCESS | L2: 742.08 | Queries: 62
# Attacking sample 1003 (True: 9 → Target: 3)...
#   SUCCESS | L2: 483.86 | Queries: 36
# Attacking sample 1003 (True: 9 → Target: 4)...
#   SUCCESS | L2: 826.82 | Queries: 68
# Attacking sample 1003 (True: 9 → Target: 5)...
#   SUCCESS | L2: 880.68 | Queries: 70
# Attacking sample 1003 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1265.25 | Queries: 108
# Attacking sample 1003 (True: 9 → Target: 7)...
#   SUCCESS | L2: 704.04 | Queries: 64
# Attacking sample 1003 (True: 9 → Target: 8)...
#   SUCCESS | L2: 773.14 | Queries: 52
# Attacking sample 1011 (True: 9 → Target: 0)...
#   SUCCESS | L2: 919.53 | Queries: 78
# Attacking sample 1011 (True: 9 → Target: 1)...
#   SUCCESS | L2: 972.12 | Queries: 94
# Attacking sample 1011 (True: 9 → Target: 2)...
#   SUCCESS | L2: 947.05 | Queries: 86
# Attacking sample 1011 (True: 9 → Target: 3)...
#   SUCCESS | L2: 768.52 | Queries: 60
# Attacking sample 1011 (True: 9 → Target: 4)...
#   SUCCESS | L2: 399.03 | Queries: 30
# Attacking sample 1011 (True: 9 → Target: 5)...
#   SUCCESS | L2: 813.79 | Queries: 64
# Attacking sample 1011 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1073.81 | Queries: 90
# Attacking sample 1011 (True: 9 → Target: 7)...
#   SUCCESS | L2: 666.13 | Queries: 58
# Attacking sample 1011 (True: 9 → Target: 8)...
#   SUCCESS | L2: 734.38 | Queries: 50
# Attacking sample 1018 (True: 9 → Target: 0)...
#   SUCCESS | L2: 824.48 | Queries: 64
# Attacking sample 1018 (True: 9 → Target: 1)...
#   SUCCESS | L2: 1015.13 | Queries: 94
# Attacking sample 1018 (True: 9 → Target: 2)...
#   SUCCESS | L2: 882.21 | Queries: 72
# Attacking sample 1018 (True: 9 → Target: 3)...
#   SUCCESS | L2: 411.42 | Queries: 30
# Attacking sample 1018 (True: 9 → Target: 4)...
#   SUCCESS | L2: 672.23 | Queries: 58
# Attacking sample 1018 (True: 9 → Target: 5)...
#   SUCCESS | L2: 574.49 | Queries: 46
# Attacking sample 1018 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1127.50 | Queries: 94
# Attacking sample 1018 (True: 9 → Target: 7)...
#   SUCCESS | L2: 797.62 | Queries: 82
# Attacking sample 1018 (True: 9 → Target: 8)...
#   SUCCESS | L2: 536.29 | Queries: 38
# Attacking sample 1024 (True: 9 → Target: 0)...
#   SUCCESS | L2: 658.50 | Queries: 54
# Attacking sample 1024 (True: 9 → Target: 1)...
#   SUCCESS | L2: 822.15 | Queries: 80
# Attacking sample 1024 (True: 9 → Target: 2)...
#   SUCCESS | L2: 457.83 | Queries: 34
# Attacking sample 1024 (True: 9 → Target: 3)...
#   SUCCESS | L2: 394.30 | Queries: 28
# Attacking sample 1024 (True: 9 → Target: 4)...
#   SUCCESS | L2: 436.72 | Queries: 36
# Attacking sample 1024 (True: 9 → Target: 5)...
#   SUCCESS | L2: 621.10 | Queries: 46
# Attacking sample 1024 (True: 9 → Target: 6)...
#   SUCCESS | L2: 857.14 | Queries: 68
# Attacking sample 1024 (True: 9 → Target: 7)...
#   SUCCESS | L2: 429.79 | Queries: 34
# Attacking sample 1024 (True: 9 → Target: 8)...
#   SUCCESS | L2: 489.28 | Queries: 32
# Attacking sample 1029 (True: 9 → Target: 0)...
#   SUCCESS | L2: 903.08 | Queries: 72
# Attacking sample 1029 (True: 9 → Target: 1)...
#   SUCCESS | L2: 1060.32 | Queries: 118
# Attacking sample 1029 (True: 9 → Target: 2)...
#   SUCCESS | L2: 878.70 | Queries: 72
# Attacking sample 1029 (True: 9 → Target: 3)...
#   SUCCESS | L2: 589.73 | Queries: 42
# Attacking sample 1029 (True: 9 → Target: 4)...
#   SUCCESS | L2: 733.02 | Queries: 56
# Attacking sample 1029 (True: 9 → Target: 5)...
#   SUCCESS | L2: 923.12 | Queries: 76
# Attacking sample 1029 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1072.93 | Queries: 84
# Attacking sample 1029 (True: 9 → Target: 7)...
#   SUCCESS | L2: 503.42 | Queries: 38
# Attacking sample 1029 (True: 9 → Target: 8)...
#   SUCCESS | L2: 538.40 | Queries: 38
# Attacking sample 1032 (True: 9 → Target: 0)...
#   SUCCESS | L2: 1082.42 | Queries: 100
# Attacking sample 1032 (True: 9 → Target: 1)...
#   SUCCESS | L2: 1004.70 | Queries: 106
# Attacking sample 1032 (True: 9 → Target: 2)...
#   SUCCESS | L2: 947.37 | Queries: 88
# Attacking sample 1032 (True: 9 → Target: 3)...
#   SUCCESS | L2: 671.06 | Queries: 52
# Attacking sample 1032 (True: 9 → Target: 4)...
#   SUCCESS | L2: 597.29 | Queries: 48
# Attacking sample 1032 (True: 9 → Target: 5)...
#   SUCCESS | L2: 856.63 | Queries: 68
# Attacking sample 1032 (True: 9 → Target: 6)...
#   FAIL | L2: 1387.02 | Queries: 200
# Attacking sample 1032 (True: 9 → Target: 7)...
#   SUCCESS | L2: 469.53 | Queries: 36
# Attacking sample 1032 (True: 9 → Target: 8)...
#   SUCCESS | L2: 366.29 | Queries: 24
# Attacking sample 1040 (True: 9 → Target: 0)...
#   SUCCESS | L2: 1069.14 | Queries: 102
# Attacking sample 1040 (True: 9 → Target: 1)...
#   FAIL | L2: 1113.13 | Queries: 200
# Attacking sample 1040 (True: 9 → Target: 2)...
#   SUCCESS | L2: 913.09 | Queries: 80
# Attacking sample 1040 (True: 9 → Target: 3)...
#   SUCCESS | L2: 732.86 | Queries: 56
# Attacking sample 1040 (True: 9 → Target: 4)...
#   SUCCESS | L2: 765.55 | Queries: 68
# Attacking sample 1040 (True: 9 → Target: 5)...
#   SUCCESS | L2: 748.99 | Queries: 62
# Attacking sample 1040 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1167.02 | Queries: 134
# Attacking sample 1040 (True: 9 → Target: 7)...
#   SUCCESS | L2: 864.80 | Queries: 78
# Attacking sample 1040 (True: 9 → Target: 8)...
#   SUCCESS | L2: 613.88 | Queries: 42
# Attacking sample 1053 (True: 9 → Target: 0)...
#   SUCCESS | L2: 1052.34 | Queries: 90
# Attacking sample 1053 (True: 9 → Target: 1)...
#   FAIL | L2: 1112.71 | Queries: 200
# Attacking sample 1053 (True: 9 → Target: 2)...
#   SUCCESS | L2: 982.35 | Queries: 88
# Attacking sample 1053 (True: 9 → Target: 3)...
#   SUCCESS | L2: 703.78 | Queries: 54
# Attacking sample 1053 (True: 9 → Target: 4)...
#   SUCCESS | L2: 615.38 | Queries: 48
# Attacking sample 1053 (True: 9 → Target: 5)...
#   SUCCESS | L2: 840.62 | Queries: 64
# Attacking sample 1053 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1279.55 | Queries: 136
# Attacking sample 1053 (True: 9 → Target: 7)...
#   SUCCESS | L2: 611.70 | Queries: 48
# Attacking sample 1053 (True: 9 → Target: 8)...
#   SUCCESS | L2: 467.56 | Queries: 34
# Attacking sample 1062 (True: 9 → Target: 0)...
#   SUCCESS | L2: 847.79 | Queries: 72
# Attacking sample 1062 (True: 9 → Target: 1)...
#   SUCCESS | L2: 1025.86 | Queries: 122
# Attacking sample 1062 (True: 9 → Target: 2)...
#   SUCCESS | L2: 945.17 | Queries: 84
# Attacking sample 1062 (True: 9 → Target: 3)...
#   SUCCESS | L2: 689.79 | Queries: 56
# Attacking sample 1062 (True: 9 → Target: 4)...
#   SUCCESS | L2: 403.12 | Queries: 30
# Attacking sample 1062 (True: 9 → Target: 5)...
#   SUCCESS | L2: 821.45 | Queries: 64
# Attacking sample 1062 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1230.10 | Queries: 106
# Attacking sample 1062 (True: 9 → Target: 7)...
#   SUCCESS | L2: 498.45 | Queries: 40
# Attacking sample 1062 (True: 9 → Target: 8)...
#   SUCCESS | L2: 419.33 | Queries: 30
# Attacking sample 1066 (True: 9 → Target: 0)...
#   SUCCESS | L2: 863.35 | Queries: 76
# Attacking sample 1066 (True: 9 → Target: 1)...
#   SUCCESS | L2: 1133.31 | Queries: 120
# Attacking sample 1066 (True: 9 → Target: 2)...
#   SUCCESS | L2: 1070.20 | Queries: 100
# Attacking sample 1066 (True: 9 → Target: 3)...
#   SUCCESS | L2: 849.26 | Queries: 70
# Attacking sample 1066 (True: 9 → Target: 4)...
#   SUCCESS | L2: 400.40 | Queries: 30
# Attacking sample 1066 (True: 9 → Target: 5)...
#   SUCCESS | L2: 791.82 | Queries: 58
# Attacking sample 1066 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1032.57 | Queries: 86
# Attacking sample 1066 (True: 9 → Target: 7)...
#   SUCCESS | L2: 485.84 | Queries: 40
# Attacking sample 1066 (True: 9 → Target: 8)...
#   SUCCESS | L2: 866.15 | Queries: 58
# Attacking sample 1092 (True: 9 → Target: 0)...
#   SUCCESS | L2: 807.31 | Queries: 70
# Attacking sample 1092 (True: 9 → Target: 1)...
#   FAIL | L2: 1246.84 | Queries: 200
# Attacking sample 1092 (True: 9 → Target: 2)...
#   SUCCESS | L2: 888.05 | Queries: 70
# Attacking sample 1092 (True: 9 → Target: 3)...
#   SUCCESS | L2: 551.38 | Queries: 44
# Attacking sample 1092 (True: 9 → Target: 4)...
#   SUCCESS | L2: 717.02 | Queries: 60
# Attacking sample 1092 (True: 9 → Target: 5)...
#   SUCCESS | L2: 445.17 | Queries: 34
# Attacking sample 1092 (True: 9 → Target: 6)...
#   SUCCESS | L2: 807.70 | Queries: 64
# Attacking sample 1092 (True: 9 → Target: 7)...
#   SUCCESS | L2: 511.95 | Queries: 42
# Attacking sample 1092 (True: 9 → Target: 8)...
#   SUCCESS | L2: 589.02 | Queries: 44
# Time taken to generate adversarial samples: 1583.4135 seconds
#
# Stats saved to: Targeted_adversarial_8bit_train_images\per_sample_stats.csv
#
# ===== Attack Summary =====
# Total trials: 8955
# Success rate: 7908/8955 (88.3%)
# Mean L2 (successful): 776.52
# Mean queries (successful): 66.44
#
# Showing successful adversarial examples...

# %% [markdown]
# ### Targeted Attack on test set

# %%
import os
import warnings
import numpy as np
import torch
import joblib
import pandas as pd
from PIL import Image
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import torch.nn.functional as F
import time

# Set seeds for reproducibility
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# ─────────────── PATHS ────────────────────────────────────────────────────
LENET_MODEL_PATH = os.path.normpath("Models and Data splits/lenet.pt")  # TorchScript model
DATA_PKL = os.path.normpath("Models and Data splits/data_[SCALED] Train_Test_Splits.pkl")
RF_ALL_CLASSES_PATH = os.path.normpath("Models and Data splits/random_forest.pkl")
OUT_DIR = "Targeted_adversarial_8bit_test_images"
os.makedirs(OUT_DIR, exist_ok=True)

if not os.path.exists(RF_ALL_CLASSES_PATH):
    raise FileNotFoundError(f"Random Forest model not found at {RF_ALL_CLASSES_PATH}")

# ─────────── HYPER-PARAMETERS ─────────────────────────────────────────────
EPSILON_STEP = 0.01
ITERATIONS = 100
TOTAL_EPSILON = 0.5
TOP_K_FEATURES = 196
SAMPLES_PER_DIGIT = 100
MAX_L2 = 10000

def plot_adversarial_example(original_img, adv_img, true_label, adv_label, l2_mag, sample_idx, queries, title_suffix=""):
    if original_img.size == 784:
        original_img = original_img.reshape(28, 28)
    if adv_img.size == 784:
        adv_img = adv_img.reshape(28, 28)
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    axes[0].imshow(original_img, cmap='gray')
    axes[0].set_title(f"Original\nTrue: {true_label}")
    axes[0].axis('off')
    axes[1].imshow(adv_img, cmap='gray')
    axes[1].set_title(f"Adversarial\nPred: {adv_label}")
    axes[1].axis('off')
    fig.suptitle(f"Sample {sample_idx} | L2: {l2_mag:.2f} | Queries: {queries} {title_suffix}")
    plt.show()
    plt.close(fig)  # <-- added here


# ─────────── Load Data ─────────────────────────────────────────────────────
try:
    data = joblib.load(DATA_PKL)
    _, X_samples , _, y_samples = data
except FileNotFoundError:
    print(f"Error: Data file not found at {DATA_PKL}. Please check the path.")
    exit()

if X_samples.max() > 1.0:
    X_samples = X_samples.astype(np.float32) / 255.0
    warnings.warn("Data appeared in [0,255]; normalized to [0,1].")

# ─────────── Load TorchScripted LeNet ──────────────────────────────────────
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
try:
    model = torch.jit.load(LENET_MODEL_PATH, map_location=device)
    model.eval()
    print(f"LeNet TorchScript model loaded from: {LENET_MODEL_PATH}")
except Exception as e:
    print(f"Error loading TorchScript LeNet model: {e}")
    exit()

def to_model(x01_batch):
    if x01_batch.ndim == 2 and x01_batch.shape == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(0).unsqueeze(0)
    elif x01_batch.ndim == 3 and x01_batch.shape[1:] == (28, 28):
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device).unsqueeze(1)
    elif x01_batch.ndim == 4 and x01_batch.shape[1] == 1:
        tensor_batch = torch.tensor(x01_batch, dtype=torch.float32, device=device)
    elif x01_batch.ndim == 1 and x01_batch.size == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(1, 1, 28, 28), dtype=torch.float32, device=device)
    elif x01_batch.ndim == 2 and x01_batch.shape[1] == 784:
        tensor_batch = torch.tensor(x01_batch.reshape(x01_batch.shape[0], 1, 28, 28), dtype=torch.float32, device=device)
    else:
        raise ValueError(f"Unsupported input shape for to_model: {x01_batch.shape}")
    return tensor_batch


def model_query(x_tensor_batch):
    with torch.no_grad():
        return model(x_tensor_batch)

# ─────────── Load Random Forest Model ──────────────────────────────────────
rf_all_classes = None
top_feature_indices = None
print("Loading Random Forest Classifier for all classes...")
try:
    rf_all_classes = joblib.load(RF_ALL_CLASSES_PATH)
    feature_importances = rf_all_classes.feature_importances_
    top_feature_indices = np.argsort(-feature_importances)[:TOP_K_FEATURES]
    print(f"Random Forest loaded. Using top {TOP_K_FEATURES} features.")
except Exception as e:
    print(f"Error loading Random Forest: {e}")
    top_feature_indices = np.arange(28 * 28)

# ─────────── Targeted I-FGSM Attack ───────────────────────────────────────
def targeted_ifgsm_attack(original_image_np, target_label, model_target, epsilon_step, iterations,
                          total_epsilon_budget, features_to_perturb, query_count_tracker):
    if original_image_np.ndim == 1 and original_image_np.size == 784:
        original_image_np = original_image_np.reshape(28, 28)

    perturbed_image_np = original_image_np.copy()
    final_pred_label = -1  # Initialize with invalid label

    for i in range(iterations):
        image_tensor = to_model(perturbed_image_np)
        image_tensor.requires_grad = True
        output = model_target(image_tensor)
        query_count_tracker[0] += 1
        
        # Minimize loss for TARGET class (targeted attack)
        loss = F.cross_entropy(output, torch.tensor([target_label], device=device))
        model_target.zero_grad()
        loss.backward()
        
        # Get gradient sign and apply MASK to top features
        data_grad_sign = torch.sign(image_tensor.grad.data).cpu().numpy()
        gradient_mask = np.zeros_like(data_grad_sign, dtype=np.float32)
        h, w = perturbed_image_np.shape
        rows, cols = np.unravel_index(features_to_perturb, (h, w))
        gradient_mask[0, 0, rows, cols] = data_grad_sign[0, 0, rows, cols]
        gradient_mask_for_update = gradient_mask.reshape(perturbed_image_np.shape)

        # Update: SUBTRACT gradient to minimize target loss (targeted attack)
        perturbed_image_np -= epsilon_step * gradient_mask_for_update
        
        # Clamp perturbations and image values
        perturbation = perturbed_image_np - original_image_np
        perturbation = np.clip(perturbation, -total_epsilon_budget, total_epsilon_budget)
        perturbed_image_np = original_image_np + perturbation
        perturbed_image_np = np.clip(perturbed_image_np, 0, 1)

        # Check if current perturbation hits target
        adv_uint8_temp = np.round(perturbed_image_np * 255).astype(np.uint8)
        adv_float_temp = adv_uint8_temp.astype(np.float32) / 255.0
        with torch.no_grad():
            output_temp = model_target(to_model(adv_float_temp))
            pred_temp = output_temp.argmax(dim=1).item()
            query_count_tracker[0] += 1

        if pred_temp == target_label:
            final_pred_label = pred_temp
            break

    # Final evaluation
    adv_uint8 = np.round(perturbed_image_np * 255).astype(np.uint8)
    adv_float = adv_uint8.astype(np.float32) / 255.0
    with torch.no_grad():
        output_final = model_target(to_model(adv_float))
        final_pred_label = output_final.argmax(dim=1).item()

    l2_norm = np.linalg.norm(adv_uint8.astype(np.float32) - (original_image_np * 255).astype(np.float32))
    success = (final_pred_label == target_label) and (l2_norm <= MAX_L2)

    return adv_uint8, final_pred_label, l2_norm, success


# ─────────── Attack Execution ──────────────────────────────────────────────
print(f"\n===== Starting Targeted Adversarial Attacks =====")
total_trials, succ_total = 0, 0
records = []
start_time = time.time()

for digit in range(10):
    idxs = np.where(y_samples == digit)[0][:SAMPLES_PER_DIGIT]
    for rank, idx in enumerate(idxs, 1):
        x0 = X_samples[idx].copy()
        y0_true = int(y_samples[idx])
        
        # Skip misclassified original samples
        query_count_tracker = [0]
        pred0 = model_query(to_model(x0)).argmax(dim=1).item()
        query_count_tracker[0] += 1
        if pred0 != y0_true:
            records.append({
                'sample_idx': idx, 'true_label': y0_true, 'target_label': None,
                'initial_pred': pred0, 'adv_label': None, 'success': False,
                'queries': query_count_tracker[0], 'l2_mag': np.nan,
                'note': 'Already misclassified'
            })
            continue

        # Attack this sample for all 9 target digits
        for target in range(10):
            if target == y0_true:
                continue  # Skip same-digit target
                
            total_trials += 1
            query_count_tracker_target = [0]  # Reset per-target query count
            print(f"Attacking sample {idx} (True: {y0_true} → Target: {target})...")
            
            adv_img_uint8, adv_label, l2_mag, success = targeted_ifgsm_attack(
                x0, target, model, EPSILON_STEP, ITERATIONS, TOTAL_EPSILON,
                top_feature_indices, query_count_tracker_target
            )
            
            if success:
                succ_total += 1
                fname = f"true{y0_true}_target{target}_adv{adv_label}_mag{l2_mag:.1f}_sample{idx}.png"
                Image.fromarray(adv_img_uint8, mode="L").save(os.path.join(OUT_DIR, fname))
            
            records.append({
                'sample_idx': idx, 'true_label': y0_true, 'target_label': target,
                'initial_pred': pred0, 'adv_label': adv_label, 'success': success,
                'queries': query_count_tracker_target[0], 'l2_mag': l2_mag if success else np.nan,
                'note': 'Targeted I-FGSM' + (' success' if success else '')
            })
            
            print(f"  {'SUCCESS' if success else 'FAIL'} | L2: {l2_mag:.2f} | Queries: {query_count_tracker_target[0]}")


end_time = time.time()
elapsed_time = end_time - start_time
print(f"Time taken to generate adversarial samples: {elapsed_time:.4f} seconds")


# ─────────── Save Results ──────────────────────────────────────────────────
df = pd.DataFrame(records)
csv_path = os.path.join(OUT_DIR, "per_sample_stats.csv")
df.to_csv(csv_path, index=False)
print(f"\nStats saved to: {csv_path}")

# ─────────── Summary ───────────────────────────────────────────────────────
print(f"\n===== Attack Summary =====")
print(f"Total trials: {total_trials}")
if total_trials > 0:
    success_rate = succ_total / total_trials * 100
    print(f"Success rate: {succ_total}/{total_trials} ({success_rate:.1f}%)")
    if succ_total > 0:
        print(f"Mean L2 (successful): {df[df['success']]['l2_mag'].mean():.2f}")
        print(f"Mean queries (successful): {df[df['success']]['queries'].mean():.2f}")

# ─────────── Display Examples ──────────────────────────────────────────────
success_df = df[df['success']]
if not success_df.empty:
    print("\nShowing successful adversarial examples...")
    show_ids = success_df.sample(min(3, len(success_df))).index.tolist()
    for record_idx in show_ids:
        r = df.loc[record_idx]
        fname_prefix = f"true{r['true_label']}_target{r['target_label']}_adv{r['adv_label']}_mag{r['l2_mag']:.1f}_sample{r['sample_idx']}"
        match_files = [f for f in os.listdir(OUT_DIR) if f.startswith(fname_prefix)]
        if match_files:
            adv_img_path = os.path.join(OUT_DIR, match_files[0])
            plot_adversarial_example(X_samples[r['sample_idx']], np.array(Image.open(adv_img_path)),
                                     r['true_label'], r['adv_label'], r['l2_mag'],
                                     r['sample_idx'], r['queries'], f"(Target: {r['target_label']})")
else:
    print("No successful attacks to display. Showing original samples instead.")
    for i in range(min(3, len(df))):
        r = df.iloc[i]
        plot_adversarial_example(X_samples[r['sample_idx']], X_samples[r['sample_idx']],
                                 r['true_label'], r['initial_pred'], 0.0,
                                 r['sample_idx'], r['queries'], "(Original)")
# Out:
# LeNet TorchScript model loaded from: Models and Data splits\lenet.pt
# Loading Random Forest Classifier for all classes...
# Random Forest loaded. Using top 196 features.
#
# ===== Starting Targeted Adversarial Attacks =====
# Attacking sample 29 (True: 0 → Target: 1)...
#   FAIL | L2: 1121.94 | Queries: 200
# Attacking sample 29 (True: 0 → Target: 2)...
#   SUCCESS | L2: 769.04 | Queries: 60
# Attacking sample 29 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1135.74 | Queries: 90
# Attacking sample 29 (True: 0 → Target: 4)...
#   FAIL | L2: 1201.17 | Queries: 200
# Attacking sample 29 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1287.65 | Queries: 120
# Attacking sample 29 (True: 0 → Target: 6)...
#   SUCCESS | L2: 837.79 | Queries: 70
# Attacking sample 29 (True: 0 → Target: 7)...
#   FAIL | L2: 1206.56 | Queries: 200
# Attacking sample 29 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1027.32 | Queries: 74
# Attacking sample 29 (True: 0 → Target: 9)...
#   FAIL | L2: 1247.99 | Queries: 200
# Attacking sample 40 (True: 0 → Target: 1)...
#   FAIL | L2: 1257.91 | Queries: 200
# Attacking sample 40 (True: 0 → Target: 2)...
#   FAIL | L2: 1293.48 | Queries: 200
# Attacking sample 40 (True: 0 → Target: 3)...
#   FAIL | L2: 1267.77 | Queries: 200
# Attacking sample 40 (True: 0 → Target: 4)...
#   FAIL | L2: 1274.46 | Queries: 200
# Attacking sample 40 (True: 0 → Target: 5)...
#   FAIL | L2: 1282.24 | Queries: 200
# Attacking sample 40 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1009.35 | Queries: 82
# Attacking sample 40 (True: 0 → Target: 7)...
#   FAIL | L2: 1260.93 | Queries: 200
# Attacking sample 40 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1019.94 | Queries: 78
# Attacking sample 40 (True: 0 → Target: 9)...
#   FAIL | L2: 1372.05 | Queries: 200
# Attacking sample 44 (True: 0 → Target: 1)...
#   FAIL | L2: 1226.49 | Queries: 200
# Attacking sample 44 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1032.70 | Queries: 86
# Attacking sample 44 (True: 0 → Target: 3)...
#   SUCCESS | L2: 582.09 | Queries: 46
# Attacking sample 44 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1021.17 | Queries: 92
# Attacking sample 44 (True: 0 → Target: 5)...
#   SUCCESS | L2: 554.47 | Queries: 44
# Attacking sample 44 (True: 0 → Target: 6)...
#   SUCCESS | L2: 897.74 | Queries: 82
# Attacking sample 44 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1092.42 | Queries: 116
# Attacking sample 44 (True: 0 → Target: 8)...
#   SUCCESS | L2: 517.39 | Queries: 38
# Attacking sample 44 (True: 0 → Target: 9)...
#   SUCCESS | L2: 804.15 | Queries: 70
# Attacking sample 59 (True: 0 → Target: 1)...
#   SUCCESS | L2: 1163.84 | Queries: 160
# Attacking sample 59 (True: 0 → Target: 2)...
#   SUCCESS | L2: 799.52 | Queries: 62
# Attacking sample 59 (True: 0 → Target: 3)...
#   SUCCESS | L2: 900.16 | Queries: 72
# Attacking sample 59 (True: 0 → Target: 4)...
#   SUCCESS | L2: 845.46 | Queries: 70
# Attacking sample 59 (True: 0 → Target: 5)...
#   SUCCESS | L2: 894.41 | Queries: 72
# Attacking sample 59 (True: 0 → Target: 6)...
#   SUCCESS | L2: 658.33 | Queries: 50
# Attacking sample 59 (True: 0 → Target: 7)...
#   SUCCESS | L2: 866.77 | Queries: 74
# Attacking sample 59 (True: 0 → Target: 8)...
#   SUCCESS | L2: 805.81 | Queries: 60
# Attacking sample 59 (True: 0 → Target: 9)...
#   SUCCESS | L2: 785.67 | Queries: 62
# Attacking sample 64 (True: 0 → Target: 1)...
#   FAIL | L2: 1205.43 | Queries: 200
# Attacking sample 64 (True: 0 → Target: 2)...
#   FAIL | L2: 1281.12 | Queries: 200
# Attacking sample 64 (True: 0 → Target: 3)...
#   FAIL | L2: 1403.67 | Queries: 200
# Attacking sample 64 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1340.65 | Queries: 150
# Attacking sample 64 (True: 0 → Target: 5)...
#   FAIL | L2: 1298.57 | Queries: 200
# Attacking sample 64 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1151.27 | Queries: 116
# Attacking sample 64 (True: 0 → Target: 7)...
#   FAIL | L2: 1256.04 | Queries: 200
# Attacking sample 64 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1260.40 | Queries: 100
# Attacking sample 64 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1144.84 | Queries: 90
# Attacking sample 75 (True: 0 → Target: 1)...
#   FAIL | L2: 1113.17 | Queries: 200
# Attacking sample 75 (True: 0 → Target: 2)...
#   SUCCESS | L2: 860.47 | Queries: 68
# Attacking sample 75 (True: 0 → Target: 3)...
#   SUCCESS | L2: 778.98 | Queries: 58
# Attacking sample 75 (True: 0 → Target: 4)...
#   SUCCESS | L2: 950.24 | Queries: 86
# Attacking sample 75 (True: 0 → Target: 5)...
#   SUCCESS | L2: 876.12 | Queries: 72
# Attacking sample 75 (True: 0 → Target: 6)...
#   SUCCESS | L2: 794.53 | Queries: 68
# Attacking sample 75 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1189.89 | Queries: 144
# Attacking sample 75 (True: 0 → Target: 8)...
#   SUCCESS | L2: 670.72 | Queries: 48
# Attacking sample 75 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1021.52 | Queries: 100
# Attacking sample 80 (True: 0 → Target: 1)...
#   FAIL | L2: 1279.19 | Queries: 200
# Attacking sample 80 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1166.88 | Queries: 86
# Attacking sample 80 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1189.01 | Queries: 90
# Attacking sample 80 (True: 0 → Target: 4)...
#   SUCCESS | L2: 902.44 | Queries: 72
# Attacking sample 80 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1267.68 | Queries: 152
# Attacking sample 80 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1166.49 | Queries: 98
# Attacking sample 80 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1166.83 | Queries: 126
# Attacking sample 80 (True: 0 → Target: 8)...
#   FAIL | L2: 1547.68 | Queries: 200
# Attacking sample 80 (True: 0 → Target: 9)...
#   SUCCESS | L2: 592.45 | Queries: 48
# Attacking sample 97 (True: 0 → Target: 1)...
#   FAIL | L2: 1177.90 | Queries: 200
# Attacking sample 97 (True: 0 → Target: 2)...
#   SUCCESS | L2: 628.17 | Queries: 50
# Attacking sample 97 (True: 0 → Target: 3)...
#   SUCCESS | L2: 898.79 | Queries: 72
# Attacking sample 97 (True: 0 → Target: 4)...
#   SUCCESS | L2: 532.64 | Queries: 44
# Attacking sample 97 (True: 0 → Target: 5)...
#   SUCCESS | L2: 890.28 | Queries: 76
# Attacking sample 97 (True: 0 → Target: 6)...
#   SUCCESS | L2: 617.71 | Queries: 48
# Attacking sample 97 (True: 0 → Target: 7)...
#   SUCCESS | L2: 912.25 | Queries: 80
# Attacking sample 97 (True: 0 → Target: 8)...
#   SUCCESS | L2: 871.60 | Queries: 64
# Attacking sample 97 (True: 0 → Target: 9)...
#   SUCCESS | L2: 996.78 | Queries: 80
# Attacking sample 115 (True: 0 → Target: 1)...
#   FAIL | L2: 1131.43 | Queries: 200
# Attacking sample 115 (True: 0 → Target: 2)...
#   FAIL | L2: 1085.07 | Queries: 200
# Attacking sample 115 (True: 0 → Target: 3)...
#   FAIL | L2: 1407.65 | Queries: 200
# Attacking sample 115 (True: 0 → Target: 4)...
#   FAIL | L2: 1198.69 | Queries: 200
# Attacking sample 115 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1156.71 | Queries: 124
# Attacking sample 115 (True: 0 → Target: 6)...
#   SUCCESS | L2: 854.34 | Queries: 64
# Attacking sample 115 (True: 0 → Target: 7)...
#   FAIL | L2: 1232.70 | Queries: 200
# Attacking sample 115 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1003.77 | Queries: 76
# Attacking sample 115 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1091.14 | Queries: 92
# Attacking sample 141 (True: 0 → Target: 1)...
#   SUCCESS | L2: 709.22 | Queries: 62
# Attacking sample 141 (True: 0 → Target: 2)...
#   SUCCESS | L2: 330.56 | Queries: 24
# Attacking sample 141 (True: 0 → Target: 3)...
#   SUCCESS | L2: 342.56 | Queries: 24
# Attacking sample 141 (True: 0 → Target: 4)...
#   SUCCESS | L2: 545.07 | Queries: 40
# Attacking sample 141 (True: 0 → Target: 5)...
#   SUCCESS | L2: 697.07 | Queries: 50
# Attacking sample 141 (True: 0 → Target: 6)...
#   SUCCESS | L2: 449.39 | Queries: 32
# Attacking sample 141 (True: 0 → Target: 7)...
#   SUCCESS | L2: 200.12 | Queries: 16
# Attacking sample 141 (True: 0 → Target: 8)...
#   SUCCESS | L2: 417.72 | Queries: 28
# Attacking sample 141 (True: 0 → Target: 9)...
#   SUCCESS | L2: 545.43 | Queries: 38
# Attacking sample 146 (True: 0 → Target: 1)...
#   FAIL | L2: 1174.60 | Queries: 200
# Attacking sample 146 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1104.12 | Queries: 90
# Attacking sample 146 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1052.27 | Queries: 88
# Attacking sample 146 (True: 0 → Target: 4)...
#   FAIL | L2: 1370.25 | Queries: 200
# Attacking sample 146 (True: 0 → Target: 5)...
#   SUCCESS | L2: 931.95 | Queries: 78
# Attacking sample 146 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1046.89 | Queries: 84
# Attacking sample 146 (True: 0 → Target: 7)...
#   FAIL | L2: 1259.02 | Queries: 200
# Attacking sample 146 (True: 0 → Target: 8)...
#   SUCCESS | L2: 923.56 | Queries: 70
# Attacking sample 146 (True: 0 → Target: 9)...
#   SUCCESS | L2: 752.10 | Queries: 58
# Attacking sample 156 (True: 0 → Target: 1)...
#   FAIL | L2: 1328.07 | Queries: 200
# Attacking sample 156 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1166.69 | Queries: 94
# Attacking sample 156 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1091.87 | Queries: 92
# Attacking sample 156 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1298.71 | Queries: 170
# Attacking sample 156 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1146.51 | Queries: 100
# Attacking sample 156 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1003.83 | Queries: 84
# Attacking sample 156 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1285.68 | Queries: 164
# Attacking sample 156 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1074.03 | Queries: 76
# Attacking sample 156 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1124.80 | Queries: 128
# Attacking sample 173 (True: 0 → Target: 1)...
#   FAIL | L2: 1316.92 | Queries: 200
# Attacking sample 173 (True: 0 → Target: 2)...
#   SUCCESS | L2: 842.33 | Queries: 66
# Attacking sample 173 (True: 0 → Target: 3)...
#   SUCCESS | L2: 747.56 | Queries: 60
# Attacking sample 173 (True: 0 → Target: 4)...
#   SUCCESS | L2: 913.83 | Queries: 86
# Attacking sample 173 (True: 0 → Target: 5)...
#   SUCCESS | L2: 874.26 | Queries: 72
# Attacking sample 173 (True: 0 → Target: 6)...
#   SUCCESS | L2: 699.01 | Queries: 62
# Attacking sample 173 (True: 0 → Target: 7)...
#   SUCCESS | L2: 914.43 | Queries: 80
# Attacking sample 173 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1032.52 | Queries: 76
# Attacking sample 173 (True: 0 → Target: 9)...
#   SUCCESS | L2: 748.88 | Queries: 58
# Attacking sample 175 (True: 0 → Target: 1)...
#   SUCCESS | L2: 998.14 | Queries: 110
# Attacking sample 175 (True: 0 → Target: 2)...
#   SUCCESS | L2: 557.32 | Queries: 42
# Attacking sample 175 (True: 0 → Target: 3)...
#   SUCCESS | L2: 806.40 | Queries: 64
# Attacking sample 175 (True: 0 → Target: 4)...
#   SUCCESS | L2: 551.93 | Queries: 40
# Attacking sample 175 (True: 0 → Target: 5)...
#   SUCCESS | L2: 672.87 | Queries: 54
# Attacking sample 175 (True: 0 → Target: 6)...
#   SUCCESS | L2: 439.43 | Queries: 32
# Attacking sample 175 (True: 0 → Target: 7)...
#   SUCCESS | L2: 676.68 | Queries: 58
# Attacking sample 175 (True: 0 → Target: 8)...
#   SUCCESS | L2: 465.15 | Queries: 32
# Attacking sample 175 (True: 0 → Target: 9)...
#   SUCCESS | L2: 530.88 | Queries: 36
# Attacking sample 193 (True: 0 → Target: 1)...
#   FAIL | L2: 1233.44 | Queries: 200
# Attacking sample 193 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1169.63 | Queries: 92
# Attacking sample 193 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1140.46 | Queries: 88
# Attacking sample 193 (True: 0 → Target: 4)...
#   FAIL | L2: 1252.15 | Queries: 200
# Attacking sample 193 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1120.10 | Queries: 92
# Attacking sample 193 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1208.50 | Queries: 100
# Attacking sample 193 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1076.58 | Queries: 96
# Attacking sample 193 (True: 0 → Target: 8)...
#   SUCCESS | L2: 973.95 | Queries: 70
# Attacking sample 193 (True: 0 → Target: 9)...
#   SUCCESS | L2: 866.25 | Queries: 80
# Attacking sample 200 (True: 0 → Target: 1)...
#   FAIL | L2: 1211.33 | Queries: 200
# Attacking sample 200 (True: 0 → Target: 2)...
#   FAIL | L2: 1162.22 | Queries: 200
# Attacking sample 200 (True: 0 → Target: 3)...
#   SUCCESS | L2: 815.60 | Queries: 72
# Attacking sample 200 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1356.79 | Queries: 182
# Attacking sample 200 (True: 0 → Target: 5)...
#   SUCCESS | L2: 858.95 | Queries: 78
# Attacking sample 200 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1181.44 | Queries: 86
# Attacking sample 200 (True: 0 → Target: 7)...
#   FAIL | L2: 1153.30 | Queries: 200
# Attacking sample 200 (True: 0 → Target: 8)...
#   SUCCESS | L2: 925.65 | Queries: 76
# Attacking sample 200 (True: 0 → Target: 9)...
#   SUCCESS | L2: 750.89 | Queries: 60
# Attacking sample 205 (True: 0 → Target: 1)...
#   FAIL | L2: 1230.63 | Queries: 200
# Attacking sample 205 (True: 0 → Target: 2)...
#   SUCCESS | L2: 863.04 | Queries: 72
# Attacking sample 205 (True: 0 → Target: 3)...
#   SUCCESS | L2: 874.77 | Queries: 74
# Attacking sample 205 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1197.13 | Queries: 104
# Attacking sample 205 (True: 0 → Target: 5)...
#   SUCCESS | L2: 932.92 | Queries: 78
# Attacking sample 205 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1066.69 | Queries: 80
# Attacking sample 205 (True: 0 → Target: 7)...
#   FAIL | L2: 1200.79 | Queries: 200
# Attacking sample 205 (True: 0 → Target: 8)...
#   SUCCESS | L2: 875.23 | Queries: 66
# Attacking sample 205 (True: 0 → Target: 9)...
#   SUCCESS | L2: 893.95 | Queries: 74
# Attacking sample 210 (True: 0 → Target: 1)...
#   FAIL | L2: 1175.38 | Queries: 200
# Attacking sample 210 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1091.62 | Queries: 114
# Attacking sample 210 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1143.28 | Queries: 98
# Attacking sample 210 (True: 0 → Target: 4)...
#   FAIL | L2: 1252.70 | Queries: 200
# Attacking sample 210 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1083.89 | Queries: 106
# Attacking sample 210 (True: 0 → Target: 6)...
#   SUCCESS | L2: 914.82 | Queries: 68
# Attacking sample 210 (True: 0 → Target: 7)...
#   FAIL | L2: 1263.39 | Queries: 200
# Attacking sample 210 (True: 0 → Target: 8)...
#   SUCCESS | L2: 763.13 | Queries: 66
# Attacking sample 210 (True: 0 → Target: 9)...
#   SUCCESS | L2: 843.34 | Queries: 68
# Attacking sample 221 (True: 0 → Target: 1)...
#   FAIL | L2: 1238.42 | Queries: 200
# Attacking sample 221 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1013.12 | Queries: 92
# Attacking sample 221 (True: 0 → Target: 3)...
#   SUCCESS | L2: 673.13 | Queries: 52
# Attacking sample 221 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1085.05 | Queries: 108
# Attacking sample 221 (True: 0 → Target: 5)...
#   SUCCESS | L2: 994.88 | Queries: 86
# Attacking sample 221 (True: 0 → Target: 6)...
#   SUCCESS | L2: 987.44 | Queries: 86
# Attacking sample 221 (True: 0 → Target: 7)...
#   FAIL | L2: 1280.48 | Queries: 200
# Attacking sample 221 (True: 0 → Target: 8)...
#   SUCCESS | L2: 848.73 | Queries: 62
# Attacking sample 221 (True: 0 → Target: 9)...
#   SUCCESS | L2: 816.57 | Queries: 62
# Attacking sample 229 (True: 0 → Target: 1)...
#   FAIL | L2: 1193.49 | Queries: 200
# Attacking sample 229 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1248.99 | Queries: 116
# Attacking sample 229 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1124.20 | Queries: 94
# Attacking sample 229 (True: 0 → Target: 4)...
#   FAIL | L2: 1271.45 | Queries: 200
# Attacking sample 229 (True: 0 → Target: 5)...
#   SUCCESS | L2: 938.01 | Queries: 82
# Attacking sample 229 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1027.07 | Queries: 84
# Attacking sample 229 (True: 0 → Target: 7)...
#   FAIL | L2: 1088.24 | Queries: 200
# Attacking sample 229 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1307.90 | Queries: 136
# Attacking sample 229 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1254.07 | Queries: 140
# Attacking sample 249 (True: 0 → Target: 1)...
#   FAIL | L2: 1123.53 | Queries: 200
# Attacking sample 249 (True: 0 → Target: 2)...
#   SUCCESS | L2: 767.55 | Queries: 58
# Attacking sample 249 (True: 0 → Target: 3)...
#   SUCCESS | L2: 837.28 | Queries: 78
# Attacking sample 249 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1200.28 | Queries: 122
# Attacking sample 249 (True: 0 → Target: 5)...
#   SUCCESS | L2: 673.85 | Queries: 60
# Attacking sample 249 (True: 0 → Target: 6)...
#   SUCCESS | L2: 693.03 | Queries: 50
# Attacking sample 249 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1031.06 | Queries: 106
# Attacking sample 249 (True: 0 → Target: 8)...
#   SUCCESS | L2: 835.04 | Queries: 62
# Attacking sample 249 (True: 0 → Target: 9)...
#   SUCCESS | L2: 580.43 | Queries: 44
# Attacking sample 258 (True: 0 → Target: 1)...
#   FAIL | L2: 1180.25 | Queries: 200
# Attacking sample 258 (True: 0 → Target: 2)...
#   SUCCESS | L2: 817.25 | Queries: 66
# Attacking sample 258 (True: 0 → Target: 3)...
#   SUCCESS | L2: 927.17 | Queries: 72
# Attacking sample 258 (True: 0 → Target: 4)...
#   FAIL | L2: 1169.04 | Queries: 200
# Attacking sample 258 (True: 0 → Target: 5)...
#   SUCCESS | L2: 856.11 | Queries: 72
# Attacking sample 258 (True: 0 → Target: 6)...
#   SUCCESS | L2: 903.53 | Queries: 80
# Attacking sample 258 (True: 0 → Target: 7)...
#   FAIL | L2: 1195.01 | Queries: 200
# Attacking sample 258 (True: 0 → Target: 8)...
#   SUCCESS | L2: 827.09 | Queries: 60
# Attacking sample 258 (True: 0 → Target: 9)...
#   SUCCESS | L2: 837.20 | Queries: 70
# Attacking sample 275 (True: 0 → Target: 1)...
#   FAIL | L2: 1292.39 | Queries: 200
# Attacking sample 275 (True: 0 → Target: 2)...
#   FAIL | L2: 1323.15 | Queries: 200
# Attacking sample 275 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1246.88 | Queries: 174
# Attacking sample 275 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1315.40 | Queries: 114
# Attacking sample 275 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1112.13 | Queries: 100
# Attacking sample 275 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1079.04 | Queries: 88
# Attacking sample 275 (True: 0 → Target: 7)...
#   FAIL | L2: 1259.78 | Queries: 200
# Attacking sample 275 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1116.55 | Queries: 76
# Attacking sample 275 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1140.87 | Queries: 134
# Attacking sample 292 (True: 0 → Target: 1)...
#   FAIL | L2: 1233.92 | Queries: 200
# Attacking sample 292 (True: 0 → Target: 2)...
#   SUCCESS | L2: 956.11 | Queries: 86
# Attacking sample 292 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1241.65 | Queries: 138
# Attacking sample 292 (True: 0 → Target: 4)...
#   FAIL | L2: 1277.86 | Queries: 200
# Attacking sample 292 (True: 0 → Target: 5)...
#   FAIL | L2: 1308.64 | Queries: 200
# Attacking sample 292 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1014.71 | Queries: 80
# Attacking sample 292 (True: 0 → Target: 7)...
#   FAIL | L2: 1307.07 | Queries: 200
# Attacking sample 292 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1282.37 | Queries: 96
# Attacking sample 292 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1201.08 | Queries: 168
# Attacking sample 296 (True: 0 → Target: 1)...
#   FAIL | L2: 1244.78 | Queries: 200
# Attacking sample 296 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1005.59 | Queries: 80
# Attacking sample 296 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1216.07 | Queries: 102
# Attacking sample 296 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1133.13 | Queries: 94
# Attacking sample 296 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1272.73 | Queries: 164
# Attacking sample 296 (True: 0 → Target: 6)...
#   SUCCESS | L2: 783.89 | Queries: 58
# Attacking sample 296 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1103.26 | Queries: 94
# Attacking sample 296 (True: 0 → Target: 8)...
#   SUCCESS | L2: 892.85 | Queries: 64
# Attacking sample 296 (True: 0 → Target: 9)...
#   SUCCESS | L2: 677.32 | Queries: 52
# Attacking sample 301 (True: 0 → Target: 1)...
#   FAIL | L2: 1193.31 | Queries: 200
# Attacking sample 301 (True: 0 → Target: 2)...
#   FAIL | L2: 1292.81 | Queries: 200
# Attacking sample 301 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1136.22 | Queries: 94
# Attacking sample 301 (True: 0 → Target: 4)...
#   FAIL | L2: 1198.73 | Queries: 200
# Attacking sample 301 (True: 0 → Target: 5)...
#   SUCCESS | L2: 973.11 | Queries: 82
# Attacking sample 301 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1013.78 | Queries: 82
# Attacking sample 301 (True: 0 → Target: 7)...
#   FAIL | L2: 1243.53 | Queries: 200
# Attacking sample 301 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1110.59 | Queries: 88
# Attacking sample 301 (True: 0 → Target: 9)...
#   SUCCESS | L2: 570.66 | Queries: 44
# Attacking sample 314 (True: 0 → Target: 1)...
#   FAIL | L2: 1152.62 | Queries: 200
# Attacking sample 314 (True: 0 → Target: 2)...
#   SUCCESS | L2: 770.80 | Queries: 60
# Attacking sample 314 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1010.20 | Queries: 86
# Attacking sample 314 (True: 0 → Target: 4)...
#   SUCCESS | L2: 679.20 | Queries: 58
# Attacking sample 314 (True: 0 → Target: 5)...
#   SUCCESS | L2: 884.64 | Queries: 74
# Attacking sample 314 (True: 0 → Target: 6)...
#   SUCCESS | L2: 685.40 | Queries: 50
# Attacking sample 314 (True: 0 → Target: 7)...
#   SUCCESS | L2: 842.94 | Queries: 74
# Attacking sample 314 (True: 0 → Target: 8)...
#   SUCCESS | L2: 729.77 | Queries: 50
# Attacking sample 314 (True: 0 → Target: 9)...
#   SUCCESS | L2: 662.68 | Queries: 48
# Attacking sample 325 (True: 0 → Target: 1)...
#   FAIL | L2: 1210.72 | Queries: 200
# Attacking sample 325 (True: 0 → Target: 2)...
#   SUCCESS | L2: 947.91 | Queries: 76
# Attacking sample 325 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1062.00 | Queries: 82
# Attacking sample 325 (True: 0 → Target: 4)...
#   SUCCESS | L2: 947.65 | Queries: 82
# Attacking sample 325 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1303.74 | Queries: 130
# Attacking sample 325 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1175.86 | Queries: 96
# Attacking sample 325 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1039.88 | Queries: 92
# Attacking sample 325 (True: 0 → Target: 8)...
#   SUCCESS | L2: 995.95 | Queries: 74
# Attacking sample 325 (True: 0 → Target: 9)...
#   SUCCESS | L2: 924.80 | Queries: 80
# Attacking sample 333 (True: 0 → Target: 1)...
#   FAIL | L2: 1222.62 | Queries: 200
# Attacking sample 333 (True: 0 → Target: 2)...
#   SUCCESS | L2: 876.68 | Queries: 74
# Attacking sample 333 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1052.66 | Queries: 86
# Attacking sample 333 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1158.64 | Queries: 116
# Attacking sample 333 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1136.89 | Queries: 94
# Attacking sample 333 (True: 0 → Target: 6)...
#   SUCCESS | L2: 970.81 | Queries: 76
# Attacking sample 333 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1179.55 | Queries: 102
# Attacking sample 333 (True: 0 → Target: 8)...
#   SUCCESS | L2: 994.15 | Queries: 78
# Attacking sample 333 (True: 0 → Target: 9)...
#   SUCCESS | L2: 818.35 | Queries: 72
# Attacking sample 345 (True: 0 → Target: 1)...
#   FAIL | L2: 1145.28 | Queries: 200
# Attacking sample 345 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1032.78 | Queries: 86
# Attacking sample 345 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1291.18 | Queries: 120
# Attacking sample 345 (True: 0 → Target: 4)...
#   FAIL | L2: 1288.59 | Queries: 200
# Attacking sample 345 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1146.95 | Queries: 100
# Attacking sample 345 (True: 0 → Target: 6)...
#   SUCCESS | L2: 659.13 | Queries: 50
# Attacking sample 345 (True: 0 → Target: 7)...
#   FAIL | L2: 1305.26 | Queries: 200
# Attacking sample 345 (True: 0 → Target: 8)...
#   SUCCESS | L2: 929.57 | Queries: 70
# Attacking sample 345 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1001.55 | Queries: 78
# Attacking sample 349 (True: 0 → Target: 1)...
#   FAIL | L2: 1252.05 | Queries: 200
# Attacking sample 349 (True: 0 → Target: 2)...
#   FAIL | L2: 1243.22 | Queries: 200
# Attacking sample 349 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1265.14 | Queries: 126
# Attacking sample 349 (True: 0 → Target: 4)...
#   FAIL | L2: 1425.59 | Queries: 200
# Attacking sample 349 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1177.22 | Queries: 128
# Attacking sample 349 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1102.09 | Queries: 84
# Attacking sample 349 (True: 0 → Target: 7)...
#   FAIL | L2: 1291.44 | Queries: 200
# Attacking sample 349 (True: 0 → Target: 8)...
#   SUCCESS | L2: 945.74 | Queries: 76
# Attacking sample 349 (True: 0 → Target: 9)...
#   SUCCESS | L2: 653.33 | Queries: 50
# Attacking sample 360 (True: 0 → Target: 1)...
#   FAIL | L2: 1299.32 | Queries: 200
# Attacking sample 360 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1265.71 | Queries: 100
# Attacking sample 360 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1229.22 | Queries: 96
# Attacking sample 360 (True: 0 → Target: 4)...
#   FAIL | L2: 1275.01 | Queries: 200
# Attacking sample 360 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1172.53 | Queries: 166
# Attacking sample 360 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1033.43 | Queries: 88
# Attacking sample 360 (True: 0 → Target: 7)...
#   FAIL | L2: 1281.58 | Queries: 200
# Attacking sample 360 (True: 0 → Target: 8)...
#   FAIL | L2: 1376.43 | Queries: 200
# Attacking sample 360 (True: 0 → Target: 9)...
#   FAIL | L2: 1180.37 | Queries: 200
# Attacking sample 365 (True: 0 → Target: 1)...
#   FAIL | L2: 1264.98 | Queries: 200
# Attacking sample 365 (True: 0 → Target: 2)...
#   FAIL | L2: 1214.80 | Queries: 200
# Attacking sample 365 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1176.07 | Queries: 106
# Attacking sample 365 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1273.10 | Queries: 140
# Attacking sample 365 (True: 0 → Target: 5)...
#   SUCCESS | L2: 890.11 | Queries: 78
# Attacking sample 365 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1241.45 | Queries: 96
# Attacking sample 365 (True: 0 → Target: 7)...
#   FAIL | L2: 1196.34 | Queries: 200
# Attacking sample 365 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1114.10 | Queries: 92
# Attacking sample 365 (True: 0 → Target: 9)...
#   SUCCESS | L2: 838.52 | Queries: 74
# Attacking sample 366 (True: 0 → Target: 1)...
#   FAIL | L2: 1236.59 | Queries: 200
# Attacking sample 366 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1087.49 | Queries: 90
# Attacking sample 366 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1039.84 | Queries: 86
# Attacking sample 366 (True: 0 → Target: 4)...
#   FAIL | L2: 1366.40 | Queries: 200
# Attacking sample 366 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1168.44 | Queries: 158
# Attacking sample 366 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1154.20 | Queries: 94
# Attacking sample 366 (True: 0 → Target: 7)...
#   FAIL | L2: 1260.81 | Queries: 200
# Attacking sample 366 (True: 0 → Target: 8)...
#   SUCCESS | L2: 886.48 | Queries: 64
# Attacking sample 366 (True: 0 → Target: 9)...
#   SUCCESS | L2: 815.13 | Queries: 66
# Attacking sample 379 (True: 0 → Target: 1)...
#   FAIL | L2: 1247.16 | Queries: 200
# Attacking sample 379 (True: 0 → Target: 2)...
#   SUCCESS | L2: 961.23 | Queries: 80
# Attacking sample 379 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1108.82 | Queries: 86
# Attacking sample 379 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1353.70 | Queries: 200
# Attacking sample 379 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1106.75 | Queries: 92
# Attacking sample 379 (True: 0 → Target: 6)...
#   SUCCESS | L2: 972.27 | Queries: 82
# Attacking sample 379 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1221.47 | Queries: 164
# Attacking sample 379 (True: 0 → Target: 8)...
#   SUCCESS | L2: 885.30 | Queries: 66
# Attacking sample 379 (True: 0 → Target: 9)...
#   SUCCESS | L2: 965.46 | Queries: 80
# Attacking sample 385 (True: 0 → Target: 1)...
#   FAIL | L2: 1231.19 | Queries: 200
# Attacking sample 385 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1153.46 | Queries: 166
# Attacking sample 385 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1061.96 | Queries: 92
# Attacking sample 385 (True: 0 → Target: 4)...
#   FAIL | L2: 1258.30 | Queries: 200
# Attacking sample 385 (True: 0 → Target: 5)...
#   FAIL | L2: 1325.02 | Queries: 200
# Attacking sample 385 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1342.34 | Queries: 136
# Attacking sample 385 (True: 0 → Target: 7)...
#   FAIL | L2: 1222.54 | Queries: 200
# Attacking sample 385 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1361.08 | Queries: 146
# Attacking sample 385 (True: 0 → Target: 9)...
#   FAIL | L2: 1217.37 | Queries: 200
# Attacking sample 397 (True: 0 → Target: 1)...
#   FAIL | L2: 1164.33 | Queries: 200
# Attacking sample 397 (True: 0 → Target: 2)...
#   SUCCESS | L2: 948.04 | Queries: 86
# Attacking sample 397 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1199.94 | Queries: 100
# Attacking sample 397 (True: 0 → Target: 4)...
#   FAIL | L2: 1305.34 | Queries: 200
# Attacking sample 397 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1191.93 | Queries: 144
# Attacking sample 397 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1112.84 | Queries: 94
# Attacking sample 397 (True: 0 → Target: 7)...
#   FAIL | L2: 1179.91 | Queries: 200
# Attacking sample 397 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1007.36 | Queries: 72
# Attacking sample 397 (True: 0 → Target: 9)...
#   FAIL | L2: 1272.81 | Queries: 200
# Attacking sample 400 (True: 0 → Target: 1)...
#   FAIL | L2: 1256.19 | Queries: 200
# Attacking sample 400 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1236.72 | Queries: 108
# Attacking sample 400 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1311.25 | Queries: 182
# Attacking sample 400 (True: 0 → Target: 4)...
#   FAIL | L2: 1294.04 | Queries: 200
# Attacking sample 400 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1183.10 | Queries: 146
# Attacking sample 400 (True: 0 → Target: 6)...
#   SUCCESS | L2: 911.44 | Queries: 72
# Attacking sample 400 (True: 0 → Target: 7)...
#   FAIL | L2: 1253.82 | Queries: 200
# Attacking sample 400 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1232.13 | Queries: 96
# Attacking sample 400 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1146.00 | Queries: 94
# Attacking sample 405 (True: 0 → Target: 1)...
#   FAIL | L2: 1170.52 | Queries: 200
# Attacking sample 405 (True: 0 → Target: 2)...
#   SUCCESS | L2: 686.29 | Queries: 50
# Attacking sample 405 (True: 0 → Target: 3)...
#   SUCCESS | L2: 960.29 | Queries: 76
# Attacking sample 405 (True: 0 → Target: 4)...
#   FAIL | L2: 1224.47 | Queries: 200
# Attacking sample 405 (True: 0 → Target: 5)...
#   FAIL | L2: 1256.32 | Queries: 200
# Attacking sample 405 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1221.87 | Queries: 120
# Attacking sample 405 (True: 0 → Target: 7)...
#   FAIL | L2: 1104.97 | Queries: 200
# Attacking sample 405 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1053.98 | Queries: 80
# Attacking sample 405 (True: 0 → Target: 9)...
#   FAIL | L2: 1200.58 | Queries: 200
# Attacking sample 410 (True: 0 → Target: 1)...
#   FAIL | L2: 1187.87 | Queries: 200
# Attacking sample 410 (True: 0 → Target: 2)...
#   SUCCESS | L2: 720.15 | Queries: 54
# Attacking sample 410 (True: 0 → Target: 3)...
#   SUCCESS | L2: 980.87 | Queries: 86
# Attacking sample 410 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1109.94 | Queries: 96
# Attacking sample 410 (True: 0 → Target: 5)...
#   SUCCESS | L2: 769.89 | Queries: 66
# Attacking sample 410 (True: 0 → Target: 6)...
#   SUCCESS | L2: 712.92 | Queries: 58
# Attacking sample 410 (True: 0 → Target: 7)...
#   SUCCESS | L2: 700.55 | Queries: 62
# Attacking sample 410 (True: 0 → Target: 8)...
#   SUCCESS | L2: 827.73 | Queries: 64
# Attacking sample 410 (True: 0 → Target: 9)...
#   SUCCESS | L2: 808.83 | Queries: 66
# Attacking sample 420 (True: 0 → Target: 1)...
#   FAIL | L2: 1243.28 | Queries: 200
# Attacking sample 420 (True: 0 → Target: 2)...
#   SUCCESS | L2: 756.21 | Queries: 64
# Attacking sample 420 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1019.05 | Queries: 88
# Attacking sample 420 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1083.52 | Queries: 122
# Attacking sample 420 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1220.36 | Queries: 148
# Attacking sample 420 (True: 0 → Target: 6)...
#   SUCCESS | L2: 940.63 | Queries: 82
# Attacking sample 420 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1120.32 | Queries: 102
# Attacking sample 420 (True: 0 → Target: 8)...
#   SUCCESS | L2: 885.08 | Queries: 70
# Attacking sample 420 (True: 0 → Target: 9)...
#   SUCCESS | L2: 892.83 | Queries: 82
# Attacking sample 424 (True: 0 → Target: 1)...
#   FAIL | L2: 1204.60 | Queries: 200
# Attacking sample 424 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1102.43 | Queries: 92
# Attacking sample 424 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1095.94 | Queries: 94
# Attacking sample 424 (True: 0 → Target: 4)...
#   SUCCESS | L2: 897.05 | Queries: 80
# Attacking sample 424 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1004.88 | Queries: 88
# Attacking sample 424 (True: 0 → Target: 6)...
#   SUCCESS | L2: 918.15 | Queries: 78
# Attacking sample 424 (True: 0 → Target: 7)...
#   FAIL | L2: 1184.27 | Queries: 200
# Attacking sample 424 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1344.32 | Queries: 118
# Attacking sample 424 (True: 0 → Target: 9)...
#   SUCCESS | L2: 787.19 | Queries: 64
# Attacking sample 447 (True: 0 → Target: 1)...
#   FAIL | L2: 1187.87 | Queries: 200
# Attacking sample 447 (True: 0 → Target: 2)...
#   SUCCESS | L2: 682.40 | Queries: 54
# Attacking sample 447 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1088.46 | Queries: 90
# Attacking sample 447 (True: 0 → Target: 4)...
#   SUCCESS | L2: 930.48 | Queries: 76
# Attacking sample 447 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1090.08 | Queries: 96
# Attacking sample 447 (True: 0 → Target: 6)...
#   SUCCESS | L2: 839.56 | Queries: 66
# Attacking sample 447 (True: 0 → Target: 7)...
#   SUCCESS | L2: 920.14 | Queries: 80
# Attacking sample 447 (True: 0 → Target: 8)...
#   SUCCESS | L2: 754.61 | Queries: 56
# Attacking sample 447 (True: 0 → Target: 9)...
#   SUCCESS | L2: 718.42 | Queries: 58
# Attacking sample 453 (True: 0 → Target: 1)...
#   FAIL | L2: 1183.20 | Queries: 200
# Attacking sample 453 (True: 0 → Target: 2)...
#   SUCCESS | L2: 862.56 | Queries: 72
# Attacking sample 453 (True: 0 → Target: 3)...
#   SUCCESS | L2: 756.68 | Queries: 60
# Attacking sample 453 (True: 0 → Target: 4)...
#   SUCCESS | L2: 985.38 | Queries: 86
# Attacking sample 453 (True: 0 → Target: 5)...
#   SUCCESS | L2: 744.35 | Queries: 58
# Attacking sample 453 (True: 0 → Target: 6)...
#   SUCCESS | L2: 649.12 | Queries: 50
# Attacking sample 453 (True: 0 → Target: 7)...
#   FAIL | L2: 1117.67 | Queries: 200
# Attacking sample 453 (True: 0 → Target: 8)...
#   SUCCESS | L2: 773.66 | Queries: 54
# Attacking sample 453 (True: 0 → Target: 9)...
#   SUCCESS | L2: 871.57 | Queries: 68
# Attacking sample 457 (True: 0 → Target: 1)...
#   FAIL | L2: 1273.37 | Queries: 200
# Attacking sample 457 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1168.30 | Queries: 98
# Attacking sample 457 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1230.13 | Queries: 94
# Attacking sample 457 (True: 0 → Target: 4)...
#   FAIL | L2: 1302.32 | Queries: 200
# Attacking sample 457 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1238.59 | Queries: 96
# Attacking sample 457 (True: 0 → Target: 6)...
#   SUCCESS | L2: 957.54 | Queries: 78
# Attacking sample 457 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1254.35 | Queries: 184
# Attacking sample 457 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1213.98 | Queries: 84
# Attacking sample 457 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1120.50 | Queries: 106
# Attacking sample 466 (True: 0 → Target: 1)...
#   FAIL | L2: 1191.56 | Queries: 200
# Attacking sample 466 (True: 0 → Target: 2)...
#   SUCCESS | L2: 790.65 | Queries: 64
# Attacking sample 466 (True: 0 → Target: 3)...
#   SUCCESS | L2: 839.83 | Queries: 70
# Attacking sample 466 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1015.12 | Queries: 92
# Attacking sample 466 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1014.50 | Queries: 78
# Attacking sample 466 (True: 0 → Target: 6)...
#   SUCCESS | L2: 936.22 | Queries: 72
# Attacking sample 466 (True: 0 → Target: 7)...
#   SUCCESS | L2: 977.41 | Queries: 80
# Attacking sample 466 (True: 0 → Target: 8)...
#   SUCCESS | L2: 923.86 | Queries: 64
# Attacking sample 466 (True: 0 → Target: 9)...
#   SUCCESS | L2: 864.29 | Queries: 68
# Attacking sample 475 (True: 0 → Target: 1)...
#   FAIL | L2: 1185.81 | Queries: 200
# Attacking sample 475 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1162.10 | Queries: 106
# Attacking sample 475 (True: 0 → Target: 3)...
#   SUCCESS | L2: 603.50 | Queries: 50
# Attacking sample 475 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1058.88 | Queries: 98
# Attacking sample 475 (True: 0 → Target: 5)...
#   SUCCESS | L2: 311.77 | Queries: 26
# Attacking sample 475 (True: 0 → Target: 6)...
#   SUCCESS | L2: 974.58 | Queries: 82
# Attacking sample 475 (True: 0 → Target: 7)...
#   SUCCESS | L2: 820.35 | Queries: 80
# Attacking sample 475 (True: 0 → Target: 8)...
#   SUCCESS | L2: 597.95 | Queries: 44
# Attacking sample 475 (True: 0 → Target: 9)...
#   SUCCESS | L2: 257.29 | Queries: 20
# Attacking sample 483 (True: 0 → Target: 1)...
#   FAIL | L2: 1239.27 | Queries: 200
# Attacking sample 483 (True: 0 → Target: 2)...
#   SUCCESS | L2: 825.08 | Queries: 62
# Attacking sample 483 (True: 0 → Target: 3)...
#   SUCCESS | L2: 854.32 | Queries: 66
# Attacking sample 483 (True: 0 → Target: 4)...
#   FAIL | L2: 1318.00 | Queries: 200
# Attacking sample 483 (True: 0 → Target: 5)...
#   SUCCESS | L2: 950.01 | Queries: 80
# Attacking sample 483 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1109.34 | Queries: 98
# Attacking sample 483 (True: 0 → Target: 7)...
#   FAIL | L2: 1227.80 | Queries: 200
# Attacking sample 483 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1153.40 | Queries: 92
# Attacking sample 483 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1061.23 | Queries: 90
# Attacking sample 484 (True: 0 → Target: 1)...
#   FAIL | L2: 1198.67 | Queries: 200
# Attacking sample 484 (True: 0 → Target: 2)...
#   SUCCESS | L2: 615.94 | Queries: 48
# Attacking sample 484 (True: 0 → Target: 3)...
#   SUCCESS | L2: 692.14 | Queries: 52
# Attacking sample 484 (True: 0 → Target: 4)...
#   SUCCESS | L2: 812.57 | Queries: 72
# Attacking sample 484 (True: 0 → Target: 5)...
#   SUCCESS | L2: 868.11 | Queries: 72
# Attacking sample 484 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1130.14 | Queries: 98
# Attacking sample 484 (True: 0 → Target: 7)...
#   FAIL | L2: 1199.20 | Queries: 200
# Attacking sample 484 (True: 0 → Target: 8)...
#   SUCCESS | L2: 441.41 | Queries: 30
# Attacking sample 484 (True: 0 → Target: 9)...
#   SUCCESS | L2: 858.81 | Queries: 74
# Attacking sample 486 (True: 0 → Target: 1)...
#   FAIL | L2: 1284.46 | Queries: 200
# Attacking sample 486 (True: 0 → Target: 2)...
#   FAIL | L2: 1335.73 | Queries: 200
# Attacking sample 486 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1448.20 | Queries: 166
# Attacking sample 486 (True: 0 → Target: 4)...
#   FAIL | L2: 1359.10 | Queries: 200
# Attacking sample 486 (True: 0 → Target: 5)...
#   FAIL | L2: 1384.23 | Queries: 200
# Attacking sample 486 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1088.43 | Queries: 90
# Attacking sample 486 (True: 0 → Target: 7)...
#   FAIL | L2: 1226.84 | Queries: 200
# Attacking sample 486 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1428.12 | Queries: 138
# Attacking sample 486 (True: 0 → Target: 9)...
#   SUCCESS | L2: 918.60 | Queries: 84
# Attacking sample 487 (True: 0 → Target: 1)...
#   FAIL | L2: 1114.76 | Queries: 200
# Attacking sample 487 (True: 0 → Target: 2)...
#   SUCCESS | L2: 795.33 | Queries: 70
# Attacking sample 487 (True: 0 → Target: 3)...
#   SUCCESS | L2: 677.65 | Queries: 56
# Attacking sample 487 (True: 0 → Target: 4)...
#   SUCCESS | L2: 773.84 | Queries: 66
# Attacking sample 487 (True: 0 → Target: 5)...
#   SUCCESS | L2: 654.04 | Queries: 52
# Attacking sample 487 (True: 0 → Target: 6)...
#   SUCCESS | L2: 632.33 | Queries: 50
# Attacking sample 487 (True: 0 → Target: 7)...
#   SUCCESS | L2: 976.05 | Queries: 96
# Attacking sample 487 (True: 0 → Target: 8)...
#   SUCCESS | L2: 524.66 | Queries: 36
# Attacking sample 487 (True: 0 → Target: 9)...
#   SUCCESS | L2: 739.19 | Queries: 62
# Attacking sample 489 (True: 0 → Target: 1)...
#   FAIL | L2: 1215.59 | Queries: 200
# Attacking sample 489 (True: 0 → Target: 2)...
#   SUCCESS | L2: 884.85 | Queries: 76
# Attacking sample 489 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1164.39 | Queries: 104
# Attacking sample 489 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1209.61 | Queries: 158
# Attacking sample 489 (True: 0 → Target: 5)...
#   FAIL | L2: 1305.97 | Queries: 200
# Attacking sample 489 (True: 0 → Target: 6)...
#   SUCCESS | L2: 953.90 | Queries: 78
# Attacking sample 489 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1174.62 | Queries: 126
# Attacking sample 489 (True: 0 → Target: 8)...
#   SUCCESS | L2: 843.11 | Queries: 64
# Attacking sample 489 (True: 0 → Target: 9)...
#   SUCCESS | L2: 698.89 | Queries: 56
# Attacking sample 492 (True: 0 → Target: 1)...
#   FAIL | L2: 1240.98 | Queries: 200
# Attacking sample 492 (True: 0 → Target: 2)...
#   SUCCESS | L2: 814.10 | Queries: 72
# Attacking sample 492 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1187.41 | Queries: 86
# Attacking sample 492 (True: 0 → Target: 4)...
#   SUCCESS | L2: 943.19 | Queries: 74
# Attacking sample 492 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1243.92 | Queries: 102
# Attacking sample 492 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1026.25 | Queries: 80
# Attacking sample 492 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1130.33 | Queries: 92
# Attacking sample 492 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1205.20 | Queries: 92
# Attacking sample 492 (True: 0 → Target: 9)...
#   SUCCESS | L2: 675.04 | Queries: 52
# Attacking sample 506 (True: 0 → Target: 1)...
#   FAIL | L2: 1231.30 | Queries: 200
# Attacking sample 506 (True: 0 → Target: 2)...
#   SUCCESS | L2: 815.42 | Queries: 60
# Attacking sample 506 (True: 0 → Target: 3)...
#   SUCCESS | L2: 961.09 | Queries: 74
# Attacking sample 506 (True: 0 → Target: 4)...
#   FAIL | L2: 1117.68 | Queries: 200
# Attacking sample 506 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1287.22 | Queries: 176
# Attacking sample 506 (True: 0 → Target: 6)...
#   FAIL | L2: 1280.31 | Queries: 200
# Attacking sample 506 (True: 0 → Target: 7)...
#   FAIL | L2: 1268.38 | Queries: 200
# Attacking sample 506 (True: 0 → Target: 8)...
#   SUCCESS | L2: 825.69 | Queries: 58
# Attacking sample 506 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1166.09 | Queries: 172
# Attacking sample 513 (True: 0 → Target: 1)...
#   FAIL | L2: 1237.23 | Queries: 200
# Attacking sample 513 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1238.22 | Queries: 118
# Attacking sample 513 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1199.57 | Queries: 98
# Attacking sample 513 (True: 0 → Target: 4)...
#   FAIL | L2: 1296.59 | Queries: 200
# Attacking sample 513 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1140.12 | Queries: 114
# Attacking sample 513 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1035.26 | Queries: 88
# Attacking sample 513 (True: 0 → Target: 7)...
#   FAIL | L2: 1151.97 | Queries: 200
# Attacking sample 513 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1391.27 | Queries: 194
# Attacking sample 513 (True: 0 → Target: 9)...
#   FAIL | L2: 1356.47 | Queries: 200
# Attacking sample 518 (True: 0 → Target: 1)...
#   FAIL | L2: 1246.72 | Queries: 200
# Attacking sample 518 (True: 0 → Target: 2)...
#   SUCCESS | L2: 924.92 | Queries: 80
# Attacking sample 518 (True: 0 → Target: 3)...
#   SUCCESS | L2: 926.23 | Queries: 76
# Attacking sample 518 (True: 0 → Target: 4)...
#   FAIL | L2: 1213.53 | Queries: 200
# Attacking sample 518 (True: 0 → Target: 5)...
#   SUCCESS | L2: 789.71 | Queries: 66
# Attacking sample 518 (True: 0 → Target: 6)...
#   SUCCESS | L2: 788.30 | Queries: 60
# Attacking sample 518 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1163.99 | Queries: 162
# Attacking sample 518 (True: 0 → Target: 8)...
#   SUCCESS | L2: 722.51 | Queries: 56
# Attacking sample 518 (True: 0 → Target: 9)...
#   SUCCESS | L2: 982.00 | Queries: 94
# Attacking sample 521 (True: 0 → Target: 1)...
#   FAIL | L2: 1319.64 | Queries: 200
# Attacking sample 521 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1282.91 | Queries: 98
# Attacking sample 521 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1245.05 | Queries: 106
# Attacking sample 521 (True: 0 → Target: 4)...
#   FAIL | L2: 1405.89 | Queries: 200
# Attacking sample 521 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1168.16 | Queries: 114
# Attacking sample 521 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1064.60 | Queries: 84
# Attacking sample 521 (True: 0 → Target: 7)...
#   FAIL | L2: 1299.76 | Queries: 200
# Attacking sample 521 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1270.25 | Queries: 94
# Attacking sample 521 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1237.21 | Queries: 114
# Attacking sample 527 (True: 0 → Target: 1)...
#   FAIL | L2: 1149.42 | Queries: 200
# Attacking sample 527 (True: 0 → Target: 2)...
#   SUCCESS | L2: 739.24 | Queries: 58
# Attacking sample 527 (True: 0 → Target: 3)...
#   SUCCESS | L2: 851.21 | Queries: 68
# Attacking sample 527 (True: 0 → Target: 4)...
#   SUCCESS | L2: 807.28 | Queries: 72
# Attacking sample 527 (True: 0 → Target: 5)...
#   SUCCESS | L2: 749.16 | Queries: 60
# Attacking sample 527 (True: 0 → Target: 6)...
#   SUCCESS | L2: 898.37 | Queries: 68
# Attacking sample 527 (True: 0 → Target: 7)...
#   SUCCESS | L2: 841.90 | Queries: 76
# Attacking sample 527 (True: 0 → Target: 8)...
#   SUCCESS | L2: 850.43 | Queries: 60
# Attacking sample 527 (True: 0 → Target: 9)...
#   SUCCESS | L2: 730.27 | Queries: 60
# Attacking sample 529 (True: 0 → Target: 1)...
#   FAIL | L2: 1228.88 | Queries: 200
# Attacking sample 529 (True: 0 → Target: 2)...
#   SUCCESS | L2: 855.87 | Queries: 72
# Attacking sample 529 (True: 0 → Target: 3)...
#   SUCCESS | L2: 787.97 | Queries: 68
# Attacking sample 529 (True: 0 → Target: 4)...
#   FAIL | L2: 1213.58 | Queries: 200
# Attacking sample 529 (True: 0 → Target: 5)...
#   SUCCESS | L2: 610.59 | Queries: 54
# Attacking sample 529 (True: 0 → Target: 6)...
#   SUCCESS | L2: 968.28 | Queries: 72
# Attacking sample 529 (True: 0 → Target: 7)...
#   SUCCESS | L2: 997.25 | Queries: 96
# Attacking sample 529 (True: 0 → Target: 8)...
#   SUCCESS | L2: 959.07 | Queries: 72
# Attacking sample 529 (True: 0 → Target: 9)...
#   SUCCESS | L2: 740.79 | Queries: 62
# Attacking sample 531 (True: 0 → Target: 1)...
#   FAIL | L2: 1163.27 | Queries: 200
# Attacking sample 531 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1030.06 | Queries: 88
# Attacking sample 531 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1152.55 | Queries: 106
# Attacking sample 531 (True: 0 → Target: 4)...
#   FAIL | L2: 1266.25 | Queries: 200
# Attacking sample 531 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1079.87 | Queries: 98
# Attacking sample 531 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1127.34 | Queries: 86
# Attacking sample 531 (True: 0 → Target: 7)...
#   FAIL | L2: 1210.24 | Queries: 200
# Attacking sample 531 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1253.10 | Queries: 98
# Attacking sample 531 (True: 0 → Target: 9)...
#   SUCCESS | L2: 1160.70 | Queries: 142
# Attacking sample 546 (True: 0 → Target: 1)...
#   FAIL | L2: 1108.36 | Queries: 200
# Attacking sample 546 (True: 0 → Target: 2)...
#   FAIL | L2: 1192.54 | Queries: 200
# Attacking sample 546 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1133.44 | Queries: 104
# Attacking sample 546 (True: 0 → Target: 4)...
#   FAIL | L2: 1398.66 | Queries: 200
# Attacking sample 546 (True: 0 → Target: 5)...
#   SUCCESS | L2: 908.72 | Queries: 80
# Attacking sample 546 (True: 0 → Target: 6)...
#   SUCCESS | L2: 1150.62 | Queries: 88
# Attacking sample 546 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1133.00 | Queries: 154
# Attacking sample 546 (True: 0 → Target: 8)...
#   SUCCESS | L2: 1137.99 | Queries: 86
# Attacking sample 546 (True: 0 → Target: 9)...
#   SUCCESS | L2: 658.21 | Queries: 52
# Attacking sample 551 (True: 0 → Target: 1)...
#   FAIL | L2: 1223.78 | Queries: 200
# Attacking sample 551 (True: 0 → Target: 2)...
#   SUCCESS | L2: 1000.32 | Queries: 76
# Attacking sample 551 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1002.05 | Queries: 74
# Attacking sample 551 (True: 0 → Target: 4)...
#   SUCCESS | L2: 789.40 | Queries: 66
# Attacking sample 551 (True: 0 → Target: 5)...
#   SUCCESS | L2: 824.00 | Queries: 62
# Attacking sample 551 (True: 0 → Target: 6)...
#   SUCCESS | L2: 377.59 | Queries: 26
# Attacking sample 551 (True: 0 → Target: 7)...
#   SUCCESS | L2: 996.31 | Queries: 84
# Attacking sample 551 (True: 0 → Target: 8)...
#   SUCCESS | L2: 989.48 | Queries: 72
# Attacking sample 551 (True: 0 → Target: 9)...
#   SUCCESS | L2: 921.16 | Queries: 68
# Attacking sample 555 (True: 0 → Target: 1)...
#   FAIL | L2: 1249.55 | Queries: 200
# Attacking sample 555 (True: 0 → Target: 2)...
#   SUCCESS | L2: 810.53 | Queries: 64
# Attacking sample 555 (True: 0 → Target: 3)...
#   SUCCESS | L2: 945.43 | Queries: 70
# Attacking sample 555 (True: 0 → Target: 4)...
#   SUCCESS | L2: 1030.80 | Queries: 98
# Attacking sample 555 (True: 0 → Target: 5)...
#   SUCCESS | L2: 829.25 | Queries: 66
# Attacking sample 555 (True: 0 → Target: 6)...
#   SUCCESS | L2: 820.36 | Queries: 66
# Attacking sample 555 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1002.74 | Queries: 84
# Attacking sample 555 (True: 0 → Target: 8)...
#   SUCCESS | L2: 823.74 | Queries: 56
# Attacking sample 555 (True: 0 → Target: 9)...
#   SUCCESS | L2: 883.89 | Queries: 74
# Attacking sample 587 (True: 0 → Target: 1)...
#   FAIL | L2: 1184.57 | Queries: 200
# Attacking sample 587 (True: 0 → Target: 2)...
#   SUCCESS | L2: 859.13 | Queries: 72
# Attacking sample 587 (True: 0 → Target: 3)...
#   SUCCESS | L2: 1012.42 | Queries: 82
# Attacking sample 587 (True: 0 → Target: 4)...
#   SUCCESS | L2: 962.45 | Queries: 84
# Attacking sample 587 (True: 0 → Target: 5)...
#   SUCCESS | L2: 1028.88 | Queries: 84
# Attacking sample 587 (True: 0 → Target: 6)...
#   SUCCESS | L2: 878.70 | Queries: 70
# Attacking sample 587 (True: 0 → Target: 7)...
#   SUCCESS | L2: 1097.50 | Queries: 124
# Attacking sample 587 (True: 0 → Target: 8)...
#   SUCCESS | L2: 733.83 | Queries: 54
# ...
#   SUCCESS | L2: 745.47 | Queries: 62
# Attacking sample 884 (True: 9 → Target: 2)...
#   SUCCESS | L2: 1013.00 | Queries: 80
# Attacking sample 884 (True: 9 → Target: 3)...
#   SUCCESS | L2: 656.21 | Queries: 48
# Attacking sample 884 (True: 9 → Target: 4)...
#   SUCCESS | L2: 448.05 | Queries: 34
# Attacking sample 884 (True: 9 → Target: 5)...
#   SUCCESS | L2: 605.37 | Queries: 46
# Attacking sample 884 (True: 9 → Target: 6)...
#   SUCCESS | L2: 741.39 | Queries: 56
# Attacking sample 884 (True: 9 → Target: 7)...
#   SUCCESS | L2: 621.65 | Queries: 50
# Attacking sample 884 (True: 9 → Target: 8)...
#   SUCCESS | L2: 567.64 | Queries: 40
# Attacking sample 891 (True: 9 → Target: 0)...
#   SUCCESS | L2: 834.90 | Queries: 76
# Attacking sample 891 (True: 9 → Target: 1)...
#   SUCCESS | L2: 586.86 | Queries: 56
# Attacking sample 891 (True: 9 → Target: 2)...
#   SUCCESS | L2: 569.41 | Queries: 46
# Attacking sample 891 (True: 9 → Target: 3)...
#   SUCCESS | L2: 470.23 | Queries: 36
# Attacking sample 891 (True: 9 → Target: 4)...
#   SUCCESS | L2: 108.84 | Queries: 8
# Attacking sample 891 (True: 9 → Target: 5)...
#   SUCCESS | L2: 871.71 | Queries: 88
# Attacking sample 891 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1041.94 | Queries: 90
# Attacking sample 891 (True: 9 → Target: 7)...
#   SUCCESS | L2: 268.34 | Queries: 22
# Attacking sample 891 (True: 9 → Target: 8)...
#   SUCCESS | L2: 254.53 | Queries: 18
# Attacking sample 893 (True: 9 → Target: 0)...
#   SUCCESS | L2: 790.88 | Queries: 68
# Attacking sample 893 (True: 9 → Target: 1)...
#   FAIL | L2: 1153.02 | Queries: 200
# Attacking sample 893 (True: 9 → Target: 2)...
#   SUCCESS | L2: 579.87 | Queries: 50
# Attacking sample 893 (True: 9 → Target: 3)...
#   SUCCESS | L2: 831.05 | Queries: 70
# Attacking sample 893 (True: 9 → Target: 4)...
#   SUCCESS | L2: 863.86 | Queries: 82
# Attacking sample 893 (True: 9 → Target: 5)...
#   SUCCESS | L2: 1045.52 | Queries: 98
# Attacking sample 893 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1155.42 | Queries: 94
# Attacking sample 893 (True: 9 → Target: 7)...
#   SUCCESS | L2: 688.02 | Queries: 66
# Attacking sample 893 (True: 9 → Target: 8)...
#   SUCCESS | L2: 1082.92 | Queries: 90
# Attacking sample 899 (True: 9 → Target: 0)...
#   SUCCESS | L2: 809.50 | Queries: 66
# Attacking sample 899 (True: 9 → Target: 1)...
#   SUCCESS | L2: 1023.47 | Queries: 98
# Attacking sample 899 (True: 9 → Target: 2)...
#   SUCCESS | L2: 723.85 | Queries: 58
# Attacking sample 899 (True: 9 → Target: 3)...
#   SUCCESS | L2: 603.78 | Queries: 44
# Attacking sample 899 (True: 9 → Target: 4)...
#   SUCCESS | L2: 424.28 | Queries: 34
# Attacking sample 899 (True: 9 → Target: 5)...
#   SUCCESS | L2: 732.15 | Queries: 52
# Attacking sample 899 (True: 9 → Target: 6)...
#   SUCCESS | L2: 993.82 | Queries: 78
# Attacking sample 899 (True: 9 → Target: 7)...
#   SUCCESS | L2: 526.70 | Queries: 42
# Attacking sample 899 (True: 9 → Target: 8)...
#   SUCCESS | L2: 519.42 | Queries: 36
# Attacking sample 912 (True: 9 → Target: 0)...
#   SUCCESS | L2: 955.24 | Queries: 82
# Attacking sample 912 (True: 9 → Target: 1)...
#   FAIL | L2: 1190.21 | Queries: 200
# Attacking sample 912 (True: 9 → Target: 2)...
#   SUCCESS | L2: 1182.26 | Queries: 124
# Attacking sample 912 (True: 9 → Target: 3)...
#   SUCCESS | L2: 814.44 | Queries: 72
# Attacking sample 912 (True: 9 → Target: 4)...
#   SUCCESS | L2: 662.59 | Queries: 54
# Attacking sample 912 (True: 9 → Target: 5)...
#   SUCCESS | L2: 459.44 | Queries: 32
# Attacking sample 912 (True: 9 → Target: 6)...
#   SUCCESS | L2: 737.71 | Queries: 58
# Attacking sample 912 (True: 9 → Target: 7)...
#   SUCCESS | L2: 723.35 | Queries: 60
# Attacking sample 912 (True: 9 → Target: 8)...
#   SUCCESS | L2: 552.65 | Queries: 40
# Attacking sample 920 (True: 9 → Target: 0)...
#   SUCCESS | L2: 821.01 | Queries: 60
# Attacking sample 920 (True: 9 → Target: 1)...
#   FAIL | L2: 1185.70 | Queries: 200
# Attacking sample 920 (True: 9 → Target: 2)...
#   SUCCESS | L2: 940.35 | Queries: 78
# Attacking sample 920 (True: 9 → Target: 3)...
#   SUCCESS | L2: 825.39 | Queries: 66
# Attacking sample 920 (True: 9 → Target: 4)...
#   SUCCESS | L2: 550.02 | Queries: 42
# Attacking sample 920 (True: 9 → Target: 5)...
#   SUCCESS | L2: 989.65 | Queries: 74
# Attacking sample 920 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1046.69 | Queries: 80
# Attacking sample 920 (True: 9 → Target: 7)...
#   SUCCESS | L2: 681.52 | Queries: 56
# Attacking sample 920 (True: 9 → Target: 8)...
#   SUCCESS | L2: 632.70 | Queries: 44
# Attacking sample 925 (True: 9 → Target: 0)...
#   SUCCESS | L2: 652.44 | Queries: 50
# Attacking sample 925 (True: 9 → Target: 1)...
#   SUCCESS | L2: 869.41 | Queries: 80
# Attacking sample 925 (True: 9 → Target: 2)...
#   SUCCESS | L2: 673.07 | Queries: 60
# Attacking sample 925 (True: 9 → Target: 3)...
#   SUCCESS | L2: 645.37 | Queries: 54
# Attacking sample 925 (True: 9 → Target: 4)...
#   SUCCESS | L2: 454.91 | Queries: 34
# Attacking sample 925 (True: 9 → Target: 5)...
#   SUCCESS | L2: 498.86 | Queries: 40
# Attacking sample 925 (True: 9 → Target: 6)...
#   SUCCESS | L2: 712.89 | Queries: 56
# Attacking sample 925 (True: 9 → Target: 7)...
#   SUCCESS | L2: 600.75 | Queries: 52
# Attacking sample 925 (True: 9 → Target: 8)...
#   SUCCESS | L2: 366.43 | Queries: 24
# Attacking sample 940 (True: 9 → Target: 0)...
#   SUCCESS | L2: 795.51 | Queries: 62
# Attacking sample 940 (True: 9 → Target: 1)...
#   SUCCESS | L2: 1054.39 | Queries: 142
# Attacking sample 940 (True: 9 → Target: 2)...
#   SUCCESS | L2: 587.68 | Queries: 44
# Attacking sample 940 (True: 9 → Target: 3)...
#   SUCCESS | L2: 512.56 | Queries: 36
# Attacking sample 940 (True: 9 → Target: 4)...
#   SUCCESS | L2: 344.98 | Queries: 28
# Attacking sample 940 (True: 9 → Target: 5)...
#   SUCCESS | L2: 638.51 | Queries: 50
# Attacking sample 940 (True: 9 → Target: 6)...
#   SUCCESS | L2: 752.26 | Queries: 56
# Attacking sample 940 (True: 9 → Target: 7)...
#   SUCCESS | L2: 513.02 | Queries: 44
# Attacking sample 940 (True: 9 → Target: 8)...
#   SUCCESS | L2: 498.53 | Queries: 32
# Attacking sample 958 (True: 9 → Target: 0)...
#   SUCCESS | L2: 557.84 | Queries: 42
# Attacking sample 958 (True: 9 → Target: 1)...
#   SUCCESS | L2: 1228.29 | Queries: 150
# Attacking sample 958 (True: 9 → Target: 2)...
#   SUCCESS | L2: 811.58 | Queries: 64
# Attacking sample 958 (True: 9 → Target: 3)...
#   SUCCESS | L2: 759.28 | Queries: 62
# Attacking sample 958 (True: 9 → Target: 4)...
#   SUCCESS | L2: 446.96 | Queries: 32
# Attacking sample 958 (True: 9 → Target: 5)...
#   SUCCESS | L2: 867.60 | Queries: 78
# Attacking sample 958 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1029.81 | Queries: 86
# Attacking sample 958 (True: 9 → Target: 7)...
#   SUCCESS | L2: 532.18 | Queries: 42
# Attacking sample 958 (True: 9 → Target: 8)...
#   SUCCESS | L2: 555.92 | Queries: 40
# Attacking sample 969 (True: 9 → Target: 0)...
#   SUCCESS | L2: 865.95 | Queries: 72
# Attacking sample 969 (True: 9 → Target: 1)...
#   SUCCESS | L2: 729.75 | Queries: 64
# Attacking sample 969 (True: 9 → Target: 2)...
#   SUCCESS | L2: 649.87 | Queries: 52
# Attacking sample 969 (True: 9 → Target: 3)...
#   SUCCESS | L2: 629.23 | Queries: 46
# Attacking sample 969 (True: 9 → Target: 4)...
#   SUCCESS | L2: 474.73 | Queries: 36
# Attacking sample 969 (True: 9 → Target: 5)...
#   SUCCESS | L2: 538.95 | Queries: 38
# Attacking sample 969 (True: 9 → Target: 6)...
#   SUCCESS | L2: 956.81 | Queries: 88
# Attacking sample 969 (True: 9 → Target: 7)...
#   SUCCESS | L2: 582.26 | Queries: 46
# Attacking sample 969 (True: 9 → Target: 8)...
#   SUCCESS | L2: 367.21 | Queries: 24
# Attacking sample 978 (True: 9 → Target: 0)...
#   SUCCESS | L2: 866.93 | Queries: 78
# Attacking sample 978 (True: 9 → Target: 1)...
#   SUCCESS | L2: 908.04 | Queries: 82
# Attacking sample 978 (True: 9 → Target: 2)...
#   SUCCESS | L2: 995.98 | Queries: 82
# Attacking sample 978 (True: 9 → Target: 3)...
#   SUCCESS | L2: 746.57 | Queries: 62
# Attacking sample 978 (True: 9 → Target: 4)...
#   SUCCESS | L2: 421.22 | Queries: 32
# Attacking sample 978 (True: 9 → Target: 5)...
#   SUCCESS | L2: 554.11 | Queries: 42
# Attacking sample 978 (True: 9 → Target: 6)...
#   SUCCESS | L2: 832.88 | Queries: 70
# Attacking sample 978 (True: 9 → Target: 7)...
#   SUCCESS | L2: 810.37 | Queries: 72
# Attacking sample 978 (True: 9 → Target: 8)...
#   SUCCESS | L2: 534.71 | Queries: 38
# Attacking sample 979 (True: 9 → Target: 0)...
#   SUCCESS | L2: 687.87 | Queries: 56
# Attacking sample 979 (True: 9 → Target: 1)...
#   SUCCESS | L2: 933.41 | Queries: 88
# Attacking sample 979 (True: 9 → Target: 2)...
#   SUCCESS | L2: 888.16 | Queries: 74
# Attacking sample 979 (True: 9 → Target: 3)...
#   SUCCESS | L2: 676.10 | Queries: 52
# Attacking sample 979 (True: 9 → Target: 4)...
#   SUCCESS | L2: 336.33 | Queries: 24
# Attacking sample 979 (True: 9 → Target: 5)...
#   SUCCESS | L2: 610.58 | Queries: 48
# Attacking sample 979 (True: 9 → Target: 6)...
#   SUCCESS | L2: 696.95 | Queries: 56
# Attacking sample 979 (True: 9 → Target: 7)...
#   SUCCESS | L2: 591.23 | Queries: 52
# Attacking sample 979 (True: 9 → Target: 8)...
#   SUCCESS | L2: 430.68 | Queries: 30
# Attacking sample 980 (True: 9 → Target: 0)...
#   SUCCESS | L2: 717.00 | Queries: 64
# Attacking sample 980 (True: 9 → Target: 1)...
#   SUCCESS | L2: 507.54 | Queries: 48
# Attacking sample 980 (True: 9 → Target: 2)...
#   SUCCESS | L2: 493.88 | Queries: 42
# Attacking sample 980 (True: 9 → Target: 3)...
#   SUCCESS | L2: 426.33 | Queries: 32
# Attacking sample 980 (True: 9 → Target: 4)...
#   SUCCESS | L2: 404.40 | Queries: 32
# Attacking sample 980 (True: 9 → Target: 5)...
#   SUCCESS | L2: 583.99 | Queries: 46
# Attacking sample 980 (True: 9 → Target: 6)...
#   SUCCESS | L2: 910.95 | Queries: 78
# Attacking sample 980 (True: 9 → Target: 7)...
#   SUCCESS | L2: 359.88 | Queries: 28
# Attacking sample 980 (True: 9 → Target: 8)...
#   SUCCESS | L2: 352.24 | Queries: 24
# Attacking sample 991 (True: 9 → Target: 0)...
#   SUCCESS | L2: 832.63 | Queries: 66
# Attacking sample 991 (True: 9 → Target: 1)...
#   SUCCESS | L2: 1198.77 | Queries: 194
# Attacking sample 991 (True: 9 → Target: 2)...
#   SUCCESS | L2: 879.15 | Queries: 76
# Attacking sample 991 (True: 9 → Target: 3)...
#   SUCCESS | L2: 697.92 | Queries: 54
# Attacking sample 991 (True: 9 → Target: 4)...
#   SUCCESS | L2: 583.05 | Queries: 48
# Attacking sample 991 (True: 9 → Target: 5)...
#   SUCCESS | L2: 883.74 | Queries: 64
# Attacking sample 991 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1136.19 | Queries: 90
# Attacking sample 991 (True: 9 → Target: 7)...
#   SUCCESS | L2: 534.21 | Queries: 42
# Attacking sample 991 (True: 9 → Target: 8)...
#   SUCCESS | L2: 631.94 | Queries: 46
# Attacking sample 997 (True: 9 → Target: 0)...
#   SUCCESS | L2: 905.46 | Queries: 80
# Attacking sample 997 (True: 9 → Target: 1)...
#   SUCCESS | L2: 526.50 | Queries: 48
# Attacking sample 997 (True: 9 → Target: 2)...
#   SUCCESS | L2: 480.51 | Queries: 40
# Attacking sample 997 (True: 9 → Target: 3)...
#   SUCCESS | L2: 332.49 | Queries: 26
# Attacking sample 997 (True: 9 → Target: 4)...
#   SUCCESS | L2: 230.17 | Queries: 18
# Attacking sample 997 (True: 9 → Target: 5)...
#   SUCCESS | L2: 543.32 | Queries: 48
# Attacking sample 997 (True: 9 → Target: 6)...
#   SUCCESS | L2: 845.16 | Queries: 64
# Attacking sample 997 (True: 9 → Target: 7)...
#   SUCCESS | L2: 346.20 | Queries: 30
# Attacking sample 997 (True: 9 → Target: 8)...
#   SUCCESS | L2: 342.53 | Queries: 24
# Attacking sample 1006 (True: 9 → Target: 0)...
#   SUCCESS | L2: 943.54 | Queries: 88
# Attacking sample 1006 (True: 9 → Target: 1)...
#   FAIL | L2: 1142.68 | Queries: 200
# Attacking sample 1006 (True: 9 → Target: 2)...
#   SUCCESS | L2: 861.37 | Queries: 76
# Attacking sample 1006 (True: 9 → Target: 3)...
#   SUCCESS | L2: 728.95 | Queries: 56
# Attacking sample 1006 (True: 9 → Target: 4)...
#   SUCCESS | L2: 677.72 | Queries: 58
# Attacking sample 1006 (True: 9 → Target: 5)...
#   SUCCESS | L2: 789.67 | Queries: 64
# Attacking sample 1006 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1185.80 | Queries: 94
# Attacking sample 1006 (True: 9 → Target: 7)...
#   SUCCESS | L2: 502.83 | Queries: 42
# Attacking sample 1006 (True: 9 → Target: 8)...
#   SUCCESS | L2: 547.76 | Queries: 40
# Attacking sample 1011 (True: 9 → Target: 0)...
#   SUCCESS | L2: 942.92 | Queries: 70
# Attacking sample 1011 (True: 9 → Target: 1)...
#   FAIL | L2: 1256.84 | Queries: 200
# Attacking sample 1011 (True: 9 → Target: 2)...
#   SUCCESS | L2: 1249.48 | Queries: 126
# Attacking sample 1011 (True: 9 → Target: 3)...
#   SUCCESS | L2: 970.07 | Queries: 76
# Attacking sample 1011 (True: 9 → Target: 4)...
#   SUCCESS | L2: 761.82 | Queries: 62
# Attacking sample 1011 (True: 9 → Target: 5)...
#   SUCCESS | L2: 1038.48 | Queries: 78
# Attacking sample 1011 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1145.92 | Queries: 86
# Attacking sample 1011 (True: 9 → Target: 7)...
#   SUCCESS | L2: 907.00 | Queries: 76
# Attacking sample 1011 (True: 9 → Target: 8)...
#   SUCCESS | L2: 1001.34 | Queries: 68
# Attacking sample 1020 (True: 9 → Target: 0)...
#   SUCCESS | L2: 710.29 | Queries: 62
# Attacking sample 1020 (True: 9 → Target: 1)...
#   SUCCESS | L2: 1152.61 | Queries: 164
# Attacking sample 1020 (True: 9 → Target: 2)...
#   SUCCESS | L2: 518.95 | Queries: 38
# Attacking sample 1020 (True: 9 → Target: 3)...
#   SUCCESS | L2: 512.47 | Queries: 36
# Attacking sample 1020 (True: 9 → Target: 4)...
#   SUCCESS | L2: 622.44 | Queries: 52
# Attacking sample 1020 (True: 9 → Target: 5)...
#   SUCCESS | L2: 615.09 | Queries: 46
# Attacking sample 1020 (True: 9 → Target: 6)...
#   SUCCESS | L2: 993.74 | Queries: 82
# Attacking sample 1020 (True: 9 → Target: 7)...
#   SUCCESS | L2: 516.93 | Queries: 42
# Attacking sample 1020 (True: 9 → Target: 8)...
#   SUCCESS | L2: 490.01 | Queries: 32
# Attacking sample 1023 (True: 9 → Target: 0)...
#   SUCCESS | L2: 1020.10 | Queries: 82
# Attacking sample 1023 (True: 9 → Target: 1)...
#   FAIL | L2: 1198.32 | Queries: 200
# Attacking sample 1023 (True: 9 → Target: 2)...
#   SUCCESS | L2: 1147.06 | Queries: 100
# Attacking sample 1023 (True: 9 → Target: 3)...
#   SUCCESS | L2: 934.02 | Queries: 72
# Attacking sample 1023 (True: 9 → Target: 4)...
#   SUCCESS | L2: 759.63 | Queries: 62
# Attacking sample 1023 (True: 9 → Target: 5)...
#   SUCCESS | L2: 896.43 | Queries: 66
# Attacking sample 1023 (True: 9 → Target: 6)...
#   SUCCESS | L2: 1174.52 | Queries: 88
# Attacking sample 1023 (True: 9 → Target: 7)...
#   SUCCESS | L2: 703.91 | Queries: 58
# Attacking sample 1023 (True: 9 → Target: 8)...
#   SUCCESS | L2: 895.11 | Queries: 62
# Attacking sample 1042 (True: 9 → Target: 0)...
#   SUCCESS | L2: 687.49 | Queries: 60
# Attacking sample 1042 (True: 9 → Target: 1)...
#   SUCCESS | L2: 737.52 | Queries: 74
# Attacking sample 1042 (True: 9 → Target: 2)...
#   SUCCESS | L2: 809.98 | Queries: 72
# Attacking sample 1042 (True: 9 → Target: 3)...
#   SUCCESS | L2: 553.25 | Queries: 44
# Attacking sample 1042 (True: 9 → Target: 4)...
#   SUCCESS | L2: 310.26 | Queries: 22
# Attacking sample 1042 (True: 9 → Target: 5)...
#   SUCCESS | L2: 615.78 | Queries: 46
# Attacking sample 1042 (True: 9 → Target: 6)...
#   SUCCESS | L2: 515.75 | Queries: 40
# Attacking sample 1042 (True: 9 → Target: 7)...
#   SUCCESS | L2: 479.92 | Queries: 40
# Attacking sample 1042 (True: 9 → Target: 8)...
#   SUCCESS | L2: 410.07 | Queries: 28
# Attacking sample 1046 (True: 9 → Target: 0)...
#   SUCCESS | L2: 678.87 | Queries: 52
# Attacking sample 1046 (True: 9 → Target: 1)...
#   SUCCESS | L2: 796.00 | Queries: 78
# Attacking sample 1046 (True: 9 → Target: 2)...
#   SUCCESS | L2: 890.02 | Queries: 84
# Attacking sample 1046 (True: 9 → Target: 3)...
#   SUCCESS | L2: 735.20 | Queries: 58
# Attacking sample 1046 (True: 9 → Target: 4)...
#   SUCCESS | L2: 364.89 | Queries: 28
# Attacking sample 1046 (True: 9 → Target: 5)...
#   SUCCESS | L2: 562.11 | Queries: 40
# Attacking sample 1046 (True: 9 → Target: 6)...
#   SUCCESS | L2: 811.86 | Queries: 64
# Attacking sample 1046 (True: 9 → Target: 7)...
#   SUCCESS | L2: 548.65 | Queries: 44
# Attacking sample 1046 (True: 9 → Target: 8)...
#   SUCCESS | L2: 591.39 | Queries: 40
# Time taken to generate adversarial samples: 1531.6402 seconds
#
# Stats saved to: Targeted_adversarial_8bit_test_images\per_sample_stats.csv
#
# ===== Attack Summary =====
# Total trials: 8874
# Success rate: 7823/8874 (88.2%)
# Mean L2 (successful): 765.87
# Mean queries (successful): 65.07
#
# Showing successful adversarial examples...
